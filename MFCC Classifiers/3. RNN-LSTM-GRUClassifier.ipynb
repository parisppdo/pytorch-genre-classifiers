# %% [markdown]
# # Music Genre Classification using Recurrent Neural Network (RNN), Long short-term memory (LSTM), Gated recurrent unit (GRU) models and Mel-frequency coefficients (MFCCs)

# %% [markdown]
# In this notebook, we evaluate recursive architecture models using MFCCs. The audio representations have been extracted in the `preprocess.py` file. All the hyperparameters and the details of the extraction process, are there. Our data will are exported using a 10 segmentation division. That means that each audio sample is 3 seconds long.

# %% [markdown]
#   ## 0. Importing libraries, setting up device agnostic code
#
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used. Furthermore, we set a random seed so that a fixed seed will maintain consistency in experimental results. This will also make it easier to compare different approaches.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torchaudio
import torch.nn as nn
from torchaudio.datasets import GTZAN
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.7.0+cu118
# 2.7.0+cu118

# %%
# Set random seeds
RANDOM_SEED = 42

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
# !nvidia-smi
# Out:
# Mon Feb  9 14:36:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   39C    P8            N/A  /  115W |    1325MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            6716    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            9264    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            9512    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            9628    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            9884    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12856    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13140    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           15444    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           16112    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           16140    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16564    C+G   ...rsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A           18680    C+G   ...AppData\Local\Viber\Viber.exe      N/A      |
# |    0   N/A  N/A           19104    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           19676    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20864    C+G   ...\v4.3.11\ProtonVPN.Client.exe      N/A      |
# |    0   N/A  N/A           21364    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           22492    C+G   ...yb3d8bbwe\Notepad\Notepad.exe      N/A      |
# |    0   N/A  N/A           23284    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           24932    C+G   ...\Proton\Drive\ProtonDrive.exe      N/A      |
# |    0   N/A  N/A           25192    C+G   ...Desktop\WDADesktopService.exe      N/A      |
# |    0   N/A  N/A           27128    C+G   ...6)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A           27472    C+G   ...der\Utility\SpyderUtility.exe      N/A      |
# |    0   N/A  N/A           30788    C+G   ...2024.3\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           30796    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           33760    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Loading data
#
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors. We are also going to create a *classes* list in order to use the name of the classes for predictions later.
#
# The RNN models expect the following shape as input: `(batch_size, seq_len, input_size)`. Those values are:
# * `seq_len`: This is the quantity of time steps that we have. In our case it is the `time_frames`.
# * `input_size`: This is the size of the "vector" that describes each step. In our case, it is the `mfcc_coefficients` which is 13. As we "describe/analyze" each step in 13 coefficients.
#
# As a result, our shape should be:  `(batch_size, time_frames, mfcc_coefficients)`. The shape we get from the `.json` file is already set to produce the following shape: `(time_frames, mfcc_coefficients)`. So, our size will be `(num_samples, time_frames, mfcc_coefficients)`. When the DataLoaders will be set, we will have `batch_size` instead of `num_samples` (the number of samples).

# %%
# Create function to load mfcc data from .json file
def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['mfcc'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from .json file
def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
DATASET_PATH = "data_full.json"

classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((9996, 130, 13), (9996,))

# %%
# Turn data into tensors, also unsqueeze , to be ready for RNN
X = torch.from_numpy(inputs).float() # weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
X.shape, y.shape
# Out:
# (torch.Size([9996, 130, 13]), torch.Size([9996]))

# %% [markdown]
# ## 2. Create DataSets and DataLoaders
#
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders.
# After loading the data, we split them into three sets: train_set, validation_set and test_set. The validation_set will be used during the training for evaluation. The test_set will be used after the model is ready. In order for it to be exposed in never seen data.
#
# After dividing the sets, we create the respective datasets and dataloaders.

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x00000183471B41A0>, <torch.utils.data.dataloader.DataLoader object at 0x00000183460FF750>)
# Length of train dataloader: 188 batches of 32
# Length of validation dataloader: 47 batches of 32
# Length of test dataloader: 79 batches of 32

# %%
# Checking the dataset shapes using test_dataset
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, time_frames, mfcc_coefficients)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample")
print(test_features_batch[0].shape, "-> (time_frames, mfcc_coefficients)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 130, 13]) -> (batch_size, time_frames, mfcc_coefficients)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample
# torch.Size([130, 13]) -> (time_frames, mfcc_coefficients)
# tensor(1) -> (label)

# %% [markdown]
# ## 3. Data visualization
#
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize an mfcc representation of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, we can distinguish the 13 coefficients in the vertical axis as parallel lines of the same thickness.
#
# A second visualization is implemented later, in order to view various representations of different genres.
#
# The music genre of each representation can also be viewed.

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
CLASS_NUM = np.random.randint(len(X))
mfcc_example = X[CLASS_NUM].numpy().T # .T is used because shape of X is (time_frames, mfcc_coefficients)
plt.imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
plt.colorbar()
plt.title(f"MFCC Example (from tensor) | label: {classes[y[CLASS_NUM]]}")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("MFCC Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    mfcc_example = X[idx].numpy().T
    im = axs[row, col].imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("MFCC coefficients")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ## 4. Building a basic RNN model
#
# The architecture of our model will be based on a simple RNN model. In order to build our model, PyTorch provides us with the `torch.nn.RNN()` class. Using that class we can set our network to have two stacked recurrent layers. The second RNN layer will take the output of the first RNN layer and compute the final results.
# After the RNN layer it is common to use a fully connected layer in order to map the hidden state features of the RNN layer, to our number of classes.

# %% [markdown]
# Defining the `forward()` method has the following steps:
# 1. First we need to set an initial hidden state. The RNN cell has two inputs. The actual data input, as well as the hidden state, which is the output of the previous step. For our first recursion, we do not have a previous step, se we define `h0` in our code as a tensor full of zeros, of the appropriate shape, as set by PyTorch.
# 2. At first we pass our data through the `RNN()` layer. This will produce two outputs:
#     * A tensor with all the outputs of each step.
#     * A tensor with the final hidden state of each of the stacked RNN layers.
#     We keep the first tensor and ignore the second output.
# 3. At this point we have two options. We can either "feed" the fully connected layer with one of the next two:
#     1. Only the outputs of the last hidden state. This state "takes in consideration" all the previous hidden states.
#     2. The outputs of all the hidden state. This will be a much larger tensor. In this manner, we have much more data in the last layer to work with.

# %% [markdown]
# For our RNN implementation, we are going to try two models:

# %% [markdown]
# 1. `model_0`: In this model we are only going to use the last hidden state of the RNN layers. In order to do that, we will use slicing. The output that we get from the `RNN()` layer, is of shape `(batch_size, sequence_length, hidden_size)` where `sequence_length` is actually the `time_frames` of the MFCCs. So with this tensor we have the neuron outputs of the network, for each MFCC time frame, for each batch. Since we just want the last hidden output, this corresponds to the recursion that took place for the last sequence. As a result we will use `[:, -1, :]` to get that from the tensor output of the `RNN()` layer. Another way to do that, is to actually not ignore the second output of the `RNN()` layer and define it as a variable. Since this tensor will include the 2 hidden states we can get the last one with the following code:
#     ```
#     out, h_n = self.rnn(x, h0)
#     out = h_n[-1]  # last layer’s hidden state
#     ```

# %% [markdown]
# 2. `model_2`: In this model we are going to use all the hidden states of the RNN layers. This means that the `nn.linear()` of the fully connected layer will expect an input of size `hidden_size * sequence_length`. This code of this model will be the same as previous except for the input if the fully connected layer that we already mentioned, as well as the tensor that will feed it. After getting the output tensor of the `RNN()`, we will use the `reshape()` method to get the appropriate tensor. More specifically, if the output tensor of the `RNN()` is named `out`, we will use `out.reshape(out.shape[0], -1)`. The tensor we want needs to have the `batch_size` on dim=0 and all the data on dim=1. The first argument (`out.shape[0]`) outputs the `batch_size` and the second argument (`-1`) is a PyTorch setting that puts all the data in the remaining dimension accordingly.

# %%
# Building an RNN model that uses only the last hidden state
INPUT_SIZE = 13 # number of mfccs
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
NUM_CLASSES = 10

class RNNClassifierV0(nn.Module):
    def __init__(self, input_size=13,
                 hidden_size=128,
                 num_layers=2,
                 num_classes=10):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.rnn = nn.RNN(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate RNN
        out, _ = self.rnn(x, h0)
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_0 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_0
# Out:
# RNNClassifierV0(
#   (rnn): RNN(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Building an RNN model that uses all the hidden states
INPUT_SIZE = 13 # number of mfccs
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
NUM_CLASSES = 10
SEQUENCE_LENGTH = 130 # number of time frames


class RNNClassifierV1(nn.Module):
    def __init__(self, input_size=13,
                 hidden_size=128,
                 num_layers=2,
                 num_classes=10,
                 sequence_length=130):
        super().__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size

        self.rnn = nn.RNN(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size * sequence_length,
                            num_classes)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.rnn(x, h0)
        out = out.reshape(out.shape[0], -1)

        out = self.fc(out)
        return out

# %% [markdown]
# > _**Disclaimer: The following commented out code, includes another version of an RNN model.\
# >  This version is taken from this paper - https://ieeexplore.ieee.org/document/9573568**_

# %%
# # TEST RNN FROM PAPER -ONLY LAST HIDDEN STATE-
# # paper here: https://ieeexplore.ieee.org/document/9573568
#
# INPUT_SIZE = 13 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class RNNClassifierV2(nn.Module):
#     def __init__(self, input_size=13, num_classes=10):
#         super().__init__()
#
#         # defining the network layers
#         self.rnn1 = nn.RNN(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.rnn2 = nn.RNN(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for RNN 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn2(out, h0_2)
#
#         # Decode the hidden state of the last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# # TEST RNN FROM PAPER -ALL HIDDEN STATES-
# The test loss increases rapidly after 2 epochs, while train loss decreases
# # paper here: https://ieeexplore.ieee.org/document/9573568
#
# INPUT_SIZE = 13 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class RNNClassifierV3(nn.Module):
#     def __init__(self, input_size=13, num_classes=10, sequence_length=130):
#         super().__init__()
#
#         # defining the network layers
#         self.rnn1 = nn.RNN(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.rnn2 = nn.RNN(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64 * sequence_length, 64 * sequence_length)
#         self.fc2 = nn.Linear(64 * sequence_length, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for RNN 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn2(out, h0_2)
#
#         out = out.reshape(out.shape[0], -1)
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_1 = RNNClassifierV1(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiation of paper version of RNN
# model_1= RNNClassifierV2().to(device)
model_1
# Out:
# RNNClassifierV1(
#   (rnn): RNN(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=16640, out_features=10, bias=True)
# )

# %%
# Extracting a sample
example, _ = next(iter(train_dataloader))
example.shape, example[0].shape
# Out:
# (torch.Size([32, 130, 13]), torch.Size([130, 13]))

# %%
# Testing with a forward pass
model_0.eval()
model_1.eval()
print(model_0(example.to(device))[:5])
print(model_1(example.to(device))[:5])
# Out:
# tensor([[ 0.0129, -0.4553, -0.8117, -0.0988,  0.0670, -0.2263, -0.0316, -0.6967,
#           0.0051,  0.3989],
#         [ 0.0850, -0.6001, -0.3765, -0.1774,  0.0554, -0.6536,  0.1785, -0.2815,
#          -0.0139,  0.3544],
#         [ 0.1043,  0.2360, -0.2278,  0.4963, -0.3136, -0.1977,  0.1220,  0.0451,
#          -0.2639,  0.2577],
#         [-0.0536, -0.2708, -0.5795, -0.0441, -0.2122, -0.4185, -0.1041, -0.5274,
#          -0.0199,  0.7123],
#         [ 0.1653, -0.3447, -0.4897, -0.4162,  0.1665, -0.6338, -0.0754, -0.1543,
#           0.1886,  0.3903]], device='cuda:0', grad_fn=<SliceBackward0>)
# tensor([[ 0.1515,  0.2071,  0.1894,  0.5262,  0.1905, -0.0081, -0.0041, -0.5339,
#           0.5900,  0.1467],
#         [-0.1889,  0.1247,  0.1185,  0.5137, -0.1768,  0.0126,  0.2322, -0.1845,
#           0.1199,  0.4720],
#         [-0.2857,  0.4039, -0.2212, -0.1483,  0.2020, -0.2339,  0.2451, -0.4919,
#           0.3799,  0.1160],
#         [ 0.0157,  0.2301,  0.1117,  0.2607, -0.0882, -0.1891,  0.4436, -0.2697,
#           0.3830,  0.2361],
#         [ 0.2127,  0.2773,  0.2872,  0.6241,  0.5217,  0.0799,  0.0869, -0.2834,
#           0.1539,  0.2422]], device='cuda:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# ## 5. Training the RNN models
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure.
#
# In order to implement the training pipeline, we will create two separate functions:
# * `train_step()`: This function is responsible for the training of the model. It also includes the logic for calculating the accuracy. We could use `torchmetrics.accuracy()`, but instead one can calculate it. We use the `argmax()` method after applying a `softmax()` on the logits that are extracted from the model. This calculation gives us the predicted label, because it returns the index of the highest probability. After that, the accuracy is calculated as the sum of predicted labels that are the same as the labels, divided by the number of samples.
# * `test_step()`: This function will evaluate the loss and accuracy on a set. Initially we will use it on the evaluation set during training.
#
# Those two functions are combined in the `train()` function in order to train the model for a set number of epochs. We also use the `timeit` library to set a timer in order to time the training. The `train()` function returns a dictionary with the results, in order to use them for plotting.

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer_0 = torch.optim.Adam(model_0.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)
optimizer_1 = torch.optim.Adam(model_1.parameters(),
                               lr=0.0001,
                               weight_decay=0.0001)

# # Optimizer according to the paper specs - https://ieeexplore.ieee.org/document/9573568
# # For use with the paper RNN models
# optimizer_1 = torch.optim.Adam(model_1.parameters(),
#                                lr=0.001)

# %% [markdown]
# ### 5.1 Implementing `SummaryWriter()`
# Before creating the training functions, we will create a function that includes a `SummaryWriter()` object to keep logs of our experiments.
# The `create_writer()` function will return a `SummaryWriter()` object. Our `train()` function has a writer parameter where we can put an object created with the `create_writer()` function in order to keep logs of a certain training procedure.

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import os

def create_writer(source: str,
                  segments: int,
                  model_name: str,
                  extra: str=None) -> torch.utils.tensorboard.writer.SummaryWriter:

    # Project root (adjust if needed)
    PROJECT_ROOT = os.path.abspath(
        os.path.join(os.getcwd(), "..")
    )

    # Get timestamp of current date (all experiments on certain day live in same folder)
    timestamp = datetime.now().strftime("%d-%m-%Y") # returns current date in DD-MM-YYYY format

    if extra:
        # Create log directory path
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name, extra
        )
    else:
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name
        )

    print(f"[INFO] Created SummaryWriter, saving to: {log_dir}...")
    return SummaryWriter(log_dir=log_dir)

# %% [markdown]
# ### 5.2 Creating training functions

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
          ):

    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
    ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %%
# Training model_0
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer_0,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0136 | train_acc: 0.2829 | test_loss: 1.8441 | test_acc: 0.3391
# Epoch: 2 | train_loss: 1.7762 | train_acc: 0.3707 | test_loss: 1.7145 | test_acc: 0.3897
# Epoch: 3 | train_loss: 1.6663 | train_acc: 0.4034 | test_loss: 1.6234 | test_acc: 0.4336
# Epoch: 4 | train_loss: 1.5690 | train_acc: 0.4469 | test_loss: 1.5755 | test_acc: 0.4403
# Epoch: 5 | train_loss: 1.5247 | train_acc: 0.4656 | test_loss: 1.5157 | test_acc: 0.4557
# Epoch: 6 | train_loss: 1.4663 | train_acc: 0.4798 | test_loss: 1.4854 | test_acc: 0.4599
# Epoch: 7 | train_loss: 1.4614 | train_acc: 0.4808 | test_loss: 1.4759 | test_acc: 0.4630
# Epoch: 8 | train_loss: 1.3895 | train_acc: 0.5078 | test_loss: 1.4107 | test_acc: 0.4969
# Epoch: 9 | train_loss: 1.3606 | train_acc: 0.5207 | test_loss: 1.3914 | test_acc: 0.4975
# Epoch: 10 | train_loss: 1.3362 | train_acc: 0.5259 | test_loss: 1.4174 | test_acc: 0.4861
# Epoch: 11 | train_loss: 1.3121 | train_acc: 0.5363 | test_loss: 1.3613 | test_acc: 0.5123
# Epoch: 12 | train_loss: 1.2876 | train_acc: 0.5467 | test_loss: 1.3828 | test_acc: 0.5014
# Epoch: 13 | train_loss: 1.2639 | train_acc: 0.5536 | test_loss: 1.3237 | test_acc: 0.5216
# Epoch: 14 | train_loss: 1.2498 | train_acc: 0.5634 | test_loss: 1.3301 | test_acc: 0.5211
# Epoch: 15 | train_loss: 1.3571 | train_acc: 0.5251 | test_loss: 1.3810 | test_acc: 0.5076
# Epoch: 16 | train_loss: 1.2726 | train_acc: 0.5547 | test_loss: 1.3242 | test_acc: 0.5276
# Epoch: 17 | train_loss: 1.2106 | train_acc: 0.5786 | test_loss: 1.3135 | test_acc: 0.5242
# Epoch: 18 | train_loss: 1.2117 | train_acc: 0.5747 | test_loss: 1.2871 | test_acc: 0.5428
# Epoch: 19 | train_loss: 1.1875 | train_acc: 0.5846 | test_loss: 1.2841 | test_acc: 0.5350
# Epoch: 20 | train_loss: 1.1847 | train_acc: 0.5875 | test_loss: 1.2754 | test_acc: 0.5462
# Epoch: 21 | train_loss: 1.1878 | train_acc: 0.5866 | test_loss: 1.2527 | test_acc: 0.5529
# Epoch: 22 | train_loss: 1.1742 | train_acc: 0.5915 | test_loss: 1.2960 | test_acc: 0.5428
# Epoch: 23 | train_loss: 1.2640 | train_acc: 0.5684 | test_loss: 1.3294 | test_acc: 0.5336
# Epoch: 24 | train_loss: 1.1805 | train_acc: 0.5884 | test_loss: 1.2909 | test_acc: 0.5317
# Epoch: 25 | train_loss: 1.1861 | train_acc: 0.5893 | test_loss: 1.4883 | test_acc: 0.4896
# Epoch: 26 | train_loss: 1.1595 | train_acc: 0.5906 | test_loss: 1.2246 | test_acc: 0.5548
# Epoch: 27 | train_loss: 1.1172 | train_acc: 0.6059 | test_loss: 1.2303 | test_acc: 0.5649
# Epoch: 28 | train_loss: 1.1272 | train_acc: 0.6024 | test_loss: 1.2519 | test_acc: 0.5561
# Epoch: 29 | train_loss: 1.1605 | train_acc: 0.5935 | test_loss: 1.2287 | test_acc: 0.5642
# Epoch: 30 | train_loss: 1.2039 | train_acc: 0.5828 | test_loss: 1.2462 | test_acc: 0.5588
# Epoch: 31 | train_loss: 1.1009 | train_acc: 0.6195 | test_loss: 1.2002 | test_acc: 0.5768
# Epoch: 32 | train_loss: 1.0557 | train_acc: 0.6337 | test_loss: 1.2330 | test_acc: 0.5709
# Epoch: 33 | train_loss: 1.0691 | train_acc: 0.6256 | test_loss: 1.1766 | test_acc: 0.5880
# Epoch: 34 | train_loss: 1.0891 | train_acc: 0.6186 | test_loss: 1.6842 | test_acc: 0.4211
# Epoch: 35 | train_loss: 1.3125 | train_acc: 0.5511 | test_loss: 1.6764 | test_acc: 0.4416
# Epoch: 36 | train_loss: 1.3600 | train_acc: 0.5287 | test_loss: 1.3397 | test_acc: 0.5198
# Epoch: 37 | train_loss: 1.2825 | train_acc: 0.5535 | test_loss: 1.2963 | test_acc: 0.5385
# Epoch: 38 | train_loss: 1.1666 | train_acc: 0.5903 | test_loss: 1.2744 | test_acc: 0.5559
# Epoch: 39 | train_loss: 1.1302 | train_acc: 0.6076 | test_loss: 1.2272 | test_acc: 0.5666
# Epoch: 40 | train_loss: 1.1225 | train_acc: 0.6029 | test_loss: 1.3510 | test_acc: 0.5099
# Epoch: 41 | train_loss: 1.1511 | train_acc: 0.5960 | test_loss: 1.2410 | test_acc: 0.5632
# Epoch: 42 | train_loss: 1.2818 | train_acc: 0.5562 | test_loss: 1.4257 | test_acc: 0.5001
# Epoch: 43 | train_loss: 1.2355 | train_acc: 0.5661 | test_loss: 1.3034 | test_acc: 0.5450
# Epoch: 44 | train_loss: 1.1646 | train_acc: 0.5934 | test_loss: 1.2820 | test_acc: 0.5586
# Epoch: 45 | train_loss: 1.1388 | train_acc: 0.6022 | test_loss: 1.2517 | test_acc: 0.5706
# Epoch: 46 | train_loss: 1.0940 | train_acc: 0.6186 | test_loss: 1.2402 | test_acc: 0.5653
# Epoch: 47 | train_loss: 1.0878 | train_acc: 0.6255 | test_loss: 1.2796 | test_acc: 0.5720
# Epoch: 48 | train_loss: 1.0679 | train_acc: 0.6311 | test_loss: 1.2767 | test_acc: 0.5517
# Epoch: 49 | train_loss: 1.0921 | train_acc: 0.6251 | test_loss: 1.2171 | test_acc: 0.5906
# Epoch: 50 | train_loss: 1.0355 | train_acc: 0.6421 | test_loss: 1.1877 | test_acc: 0.5852
# Epoch: 51 | train_loss: 1.0136 | train_acc: 0.6496 | test_loss: 1.3642 | test_acc: 0.5237
# Epoch: 52 | train_loss: 1.1175 | train_acc: 0.6102 | test_loss: 1.3556 | test_acc: 0.5356
# Epoch: 53 | train_loss: 1.1291 | train_acc: 0.6054 | test_loss: 1.2200 | test_acc: 0.5777
# Epoch: 54 | train_loss: 1.1539 | train_acc: 0.5960 | test_loss: 1.2967 | test_acc: 0.5450
# Epoch: 55 | train_loss: 1.0958 | train_acc: 0.6128 | test_loss: 1.2325 | test_acc: 0.5569
# Epoch: 56 | train_loss: 1.0176 | train_acc: 0.6466 | test_loss: 1.1903 | test_acc: 0.5785
# Epoch: 57 | train_loss: 1.0026 | train_acc: 0.6489 | test_loss: 1.2449 | test_acc: 0.5782
# Epoch: 58 | train_loss: 0.9954 | train_acc: 0.6509 | test_loss: 1.1782 | test_acc: 0.5904
# Epoch: 59 | train_loss: 1.0912 | train_acc: 0.6196 | test_loss: 1.2880 | test_acc: 0.5477
# Epoch: 60 | train_loss: 1.0048 | train_acc: 0.6530 | test_loss: 1.1473 | test_acc: 0.5917
# Epoch: 61 | train_loss: 1.0079 | train_acc: 0.6528 | test_loss: 1.2769 | test_acc: 0.5663
# Epoch: 62 | train_loss: 1.0129 | train_acc: 0.6536 | test_loss: 1.2403 | test_acc: 0.5661
# Epoch: 63 | train_loss: 1.1514 | train_acc: 0.6066 | test_loss: 1.3021 | test_acc: 0.5449
# Epoch: 64 | train_loss: 1.0214 | train_acc: 0.6457 | test_loss: 1.1846 | test_acc: 0.5837
# Epoch: 65 | train_loss: 0.9659 | train_acc: 0.6681 | test_loss: 1.2825 | test_acc: 0.5422
# Epoch: 66 | train_loss: 1.2839 | train_acc: 0.5576 | test_loss: 1.2999 | test_acc: 0.5369
# Epoch: 67 | train_loss: 1.0696 | train_acc: 0.6241 | test_loss: 1.2043 | test_acc: 0.5859
# Epoch: 68 | train_loss: 1.0576 | train_acc: 0.6373 | test_loss: 1.1552 | test_acc: 0.5964
# Epoch: 69 | train_loss: 0.9502 | train_acc: 0.6754 | test_loss: 1.4327 | test_acc: 0.5429
# Epoch: 70 | train_loss: 1.2121 | train_acc: 0.5958 | test_loss: 1.2265 | test_acc: 0.5718
# Epoch: 71 | train_loss: 1.0112 | train_acc: 0.6545 | test_loss: 1.1706 | test_acc: 0.5904
# Epoch: 72 | train_loss: 0.9629 | train_acc: 0.6653 | test_loss: 1.1480 | test_acc: 0.5879
# Epoch: 73 | train_loss: 0.9557 | train_acc: 0.6737 | test_loss: 1.1667 | test_acc: 0.5898
# Epoch: 74 | train_loss: 1.2295 | train_acc: 0.5864 | test_loss: 1.2272 | test_acc: 0.5708
# Epoch: 75 | train_loss: 1.0371 | train_acc: 0.6378 | test_loss: 1.1427 | test_acc: 0.6082
# Epoch: 76 | train_loss: 0.9930 | train_acc: 0.6568 | test_loss: 1.3017 | test_acc: 0.5683
# Epoch: 77 | train_loss: 0.9711 | train_acc: 0.6623 | test_loss: 1.1860 | test_acc: 0.5990
# Epoch: 78 | train_loss: 1.3187 | train_acc: 0.5664 | test_loss: 1.4147 | test_acc: 0.5176
# Epoch: 79 | train_loss: 1.5031 | train_acc: 0.4757 | test_loss: 1.4770 | test_acc: 0.5009
# Epoch: 80 | train_loss: 1.2975 | train_acc: 0.5524 | test_loss: 1.3551 | test_acc: 0.5282
# Epoch: 81 | train_loss: 1.2198 | train_acc: 0.5768 | test_loss: 1.3643 | test_acc: 0.5334
# Epoch: 82 | train_loss: 1.1397 | train_acc: 0.6031 | test_loss: 1.2612 | test_acc: 0.5560
# Epoch: 83 | train_loss: 1.0994 | train_acc: 0.6132 | test_loss: 1.2264 | test_acc: 0.5653
# Epoch: 84 | train_loss: 1.0478 | train_acc: 0.6274 | test_loss: 1.1806 | test_acc: 0.5796
# Epoch: 85 | train_loss: 0.9821 | train_acc: 0.6577 | test_loss: 1.1208 | test_acc: 0.5975
# Epoch: 86 | train_loss: 0.9521 | train_acc: 0.6689 | test_loss: 1.2237 | test_acc: 0.5689
# Epoch: 87 | train_loss: 0.9142 | train_acc: 0.6829 | test_loss: 1.1227 | test_acc: 0.6105
# Epoch: 88 | train_loss: 0.9337 | train_acc: 0.6845 | test_loss: 1.1103 | test_acc: 0.6089
# Epoch: 89 | train_loss: 1.1090 | train_acc: 0.6313 | test_loss: 1.1583 | test_acc: 0.5934
# Epoch: 90 | train_loss: 1.0433 | train_acc: 0.6462 | test_loss: 1.1178 | test_acc: 0.6124
# Epoch: 91 | train_loss: 0.8872 | train_acc: 0.6989 | test_loss: 1.1193 | test_acc: 0.6089
# Epoch: 92 | train_loss: 0.9358 | train_acc: 0.6793 | test_loss: 1.1568 | test_acc: 0.5989
# Epoch: 93 | train_loss: 0.9706 | train_acc: 0.6650 | test_loss: 1.1997 | test_acc: 0.5843
# Epoch: 94 | train_loss: 1.1235 | train_acc: 0.6287 | test_loss: 1.3864 | test_acc: 0.5009
# Epoch: 95 | train_loss: 1.0697 | train_acc: 0.6195 | test_loss: 1.2110 | test_acc: 0.5734
# Epoch: 96 | train_loss: 0.9667 | train_acc: 0.6677 | test_loss: 1.1526 | test_acc: 0.5961
# Epoch: 97 | train_loss: 0.9234 | train_acc: 0.6802 | test_loss: 1.2123 | test_acc: 0.5768
# Epoch: 98 | train_loss: 0.9911 | train_acc: 0.6598 | test_loss: 1.1474 | test_acc: 0.6006
# Epoch: 99 | train_loss: 0.9513 | train_acc: 0.6686 | test_loss: 1.2150 | test_acc: 0.5902
# Epoch: 100 | train_loss: 0.8953 | train_acc: 0.6936 | test_loss: 1.1070 | test_acc: 0.6142
# Epoch: 101 | train_loss: 0.8902 | train_acc: 0.6916 | test_loss: 1.1127 | test_acc: 0.6148
# Epoch: 102 | train_loss: 0.8939 | train_acc: 0.6910 | test_loss: 1.2290 | test_acc: 0.5835
# Epoch: 103 | train_loss: 0.9328 | train_acc: 0.6795 | test_loss: 1.0986 | test_acc: 0.6228
# Epoch: 104 | train_loss: 0.9000 | train_acc: 0.6901 | test_loss: 1.2350 | test_acc: 0.5828
# Epoch: 105 | train_loss: 0.8809 | train_acc: 0.6984 | test_loss: 1.1409 | test_acc: 0.6243
# Epoch: 106 | train_loss: 0.8359 | train_acc: 0.7180 | test_loss: 1.0787 | test_acc: 0.6310
# Epoch: 107 | train_loss: 0.8482 | train_acc: 0.7101 | test_loss: 1.1019 | test_acc: 0.6261
# Epoch: 108 | train_loss: 0.8264 | train_acc: 0.7169 | test_loss: 1.0567 | test_acc: 0.6433
# Epoch: 109 | train_loss: 0.9552 | train_acc: 0.6751 | test_loss: 1.5211 | test_acc: 0.5060
# Epoch: 110 | train_loss: 1.0895 | train_acc: 0.6248 | test_loss: 1.2305 | test_acc: 0.5748
# Epoch: 111 | train_loss: 0.9700 | train_acc: 0.6740 | test_loss: 1.1834 | test_acc: 0.5920
# Epoch: 112 | train_loss: 1.1365 | train_acc: 0.6160 | test_loss: 1.3024 | test_acc: 0.5622
# Epoch: 113 | train_loss: 0.9612 | train_acc: 0.6730 | test_loss: 1.1801 | test_acc: 0.6069
# Epoch: 114 | train_loss: 0.8996 | train_acc: 0.6967 | test_loss: 1.1256 | test_acc: 0.6228
# Epoch: 115 | train_loss: 0.9287 | train_acc: 0.6945 | test_loss: 1.2735 | test_acc: 0.5881
# Epoch: 116 | train_loss: 0.8572 | train_acc: 0.7083 | test_loss: 1.1151 | test_acc: 0.6227
# Epoch: 117 | train_loss: 0.9638 | train_acc: 0.6659 | test_loss: 1.3384 | test_acc: 0.5249
# Epoch: 118 | train_loss: 0.9955 | train_acc: 0.6444 | test_loss: 1.1223 | test_acc: 0.6136
# Epoch: 119 | train_loss: 0.9012 | train_acc: 0.6919 | test_loss: 1.0863 | test_acc: 0.6330
# Epoch: 120 | train_loss: 0.8859 | train_acc: 0.7007 | test_loss: 1.1015 | test_acc: 0.6180
# Epoch: 121 | train_loss: 0.7982 | train_acc: 0.7305 | test_loss: 1.0960 | test_acc: 0.6390
# Epoch: 122 | train_loss: 0.8295 | train_acc: 0.7228 | test_loss: 1.0616 | test_acc: 0.6497
# Epoch: 123 | train_loss: 0.9424 | train_acc: 0.6718 | test_loss: 1.0890 | test_acc: 0.6293
# Epoch: 124 | train_loss: 0.8271 | train_acc: 0.7175 | test_loss: 1.0657 | test_acc: 0.6354
# Epoch: 125 | train_loss: 0.7998 | train_acc: 0.7319 | test_loss: 1.0992 | test_acc: 0.6385
# Epoch: 126 | train_loss: 0.8101 | train_acc: 0.7228 | test_loss: 1.1090 | test_acc: 0.6255
# Epoch: 127 | train_loss: 0.9708 | train_acc: 0.6679 | test_loss: 1.2260 | test_acc: 0.5740
# Epoch: 128 | train_loss: 0.8965 | train_acc: 0.6918 | test_loss: 1.1084 | test_acc: 0.6341
# Epoch: 129 | train_loss: 0.7995 | train_acc: 0.7263 | test_loss: 1.1229 | test_acc: 0.6201
# Epoch: 130 | train_loss: 0.8077 | train_acc: 0.7249 | test_loss: 1.1481 | test_acc: 0.6180
# Epoch: 131 | train_loss: 0.7582 | train_acc: 0.7393 | test_loss: 1.1018 | test_acc: 0.6354
# Epoch: 132 | train_loss: 1.1118 | train_acc: 0.6359 | test_loss: 1.2746 | test_acc: 0.5534
# Epoch: 133 | train_loss: 0.9157 | train_acc: 0.6805 | test_loss: 1.1141 | test_acc: 0.6108
# Epoch: 134 | train_loss: 0.8926 | train_acc: 0.6946 | test_loss: 1.1409 | test_acc: 0.6133
# Epoch: 135 | train_loss: 0.9049 | train_acc: 0.6864 | test_loss: 1.0810 | test_acc: 0.6341
# Epoch: 136 | train_loss: 0.7865 | train_acc: 0.7326 | test_loss: 1.1595 | test_acc: 0.6100
# Epoch: 137 | train_loss: 0.7889 | train_acc: 0.7293 | test_loss: 1.0811 | test_acc: 0.6381
# Epoch: 138 | train_loss: 0.7447 | train_acc: 0.7488 | test_loss: 1.0763 | test_acc: 0.6301
# Epoch: 139 | train_loss: 0.7743 | train_acc: 0.7355 | test_loss: 1.0945 | test_acc: 0.6362
# Epoch: 140 | train_loss: 0.7517 | train_acc: 0.7455 | test_loss: 1.0311 | test_acc: 0.6548
# Epoch: 141 | train_loss: 1.2192 | train_acc: 0.6411 | test_loss: 1.7840 | test_acc: 0.4676
# Epoch: 142 | train_loss: 1.2367 | train_acc: 0.5920 | test_loss: 1.3000 | test_acc: 0.5568
# Epoch: 143 | train_loss: 1.3775 | train_acc: 0.5347 | test_loss: 1.5821 | test_acc: 0.4415
# Epoch: 144 | train_loss: 1.1739 | train_acc: 0.5786 | test_loss: 1.2764 | test_acc: 0.5521
# Epoch: 145 | train_loss: 1.0055 | train_acc: 0.6465 | test_loss: 1.2073 | test_acc: 0.5704
# Epoch: 146 | train_loss: 0.9944 | train_acc: 0.6489 | test_loss: 1.2279 | test_acc: 0.5673
# Epoch: 147 | train_loss: 0.8970 | train_acc: 0.6847 | test_loss: 1.1536 | test_acc: 0.6016
# Epoch: 148 | train_loss: 0.8675 | train_acc: 0.6990 | test_loss: 1.2728 | test_acc: 0.5736
# Epoch: 149 | train_loss: 1.0220 | train_acc: 0.6471 | test_loss: 1.3226 | test_acc: 0.5621
# Epoch: 150 | train_loss: 0.8830 | train_acc: 0.6995 | test_loss: 1.1349 | test_acc: 0.6088
# Epoch: 151 | train_loss: 0.8004 | train_acc: 0.7294 | test_loss: 1.0839 | test_acc: 0.6214
# Epoch: 152 | train_loss: 0.7680 | train_acc: 0.7379 | test_loss: 1.0909 | test_acc: 0.6301
# Epoch: 153 | train_loss: 0.7704 | train_acc: 0.7376 | test_loss: 1.0584 | test_acc: 0.6389
# Epoch: 154 | train_loss: 0.7291 | train_acc: 0.7538 | test_loss: 1.0952 | test_acc: 0.6300
# Epoch: 155 | train_loss: 0.7878 | train_acc: 0.7302 | test_loss: 1.1315 | test_acc: 0.6183
# Epoch: 156 | train_loss: 0.7809 | train_acc: 0.7371 | test_loss: 1.1313 | test_acc: 0.6218
# Epoch: 157 | train_loss: 0.7210 | train_acc: 0.7535 | test_loss: 1.1038 | test_acc: 0.6541
# Epoch: 158 | train_loss: 0.7569 | train_acc: 0.7434 | test_loss: 1.0422 | test_acc: 0.6449
# Epoch: 159 | train_loss: 0.7147 | train_acc: 0.7551 | test_loss: 1.0675 | test_acc: 0.6290
# Epoch: 160 | train_loss: 0.7276 | train_acc: 0.7526 | test_loss: 1.0285 | test_acc: 0.6624
# Epoch: 161 | train_loss: 0.8865 | train_acc: 0.7150 | test_loss: 1.0718 | test_acc: 0.6435
# Epoch: 162 | train_loss: 0.7126 | train_acc: 0.7599 | test_loss: 1.0386 | test_acc: 0.6550
# Epoch: 163 | train_loss: 0.7768 | train_acc: 0.7422 | test_loss: 1.0662 | test_acc: 0.6589
# Epoch: 164 | train_loss: 0.7165 | train_acc: 0.7641 | test_loss: 1.1041 | test_acc: 0.6515
# Epoch: 165 | train_loss: 0.8128 | train_acc: 0.7219 | test_loss: 1.0766 | test_acc: 0.6402
# Epoch: 166 | train_loss: 0.7236 | train_acc: 0.7632 | test_loss: 1.0512 | test_acc: 0.6654
# Epoch: 167 | train_loss: 0.7957 | train_acc: 0.7377 | test_loss: 1.1330 | test_acc: 0.6255
# Epoch: 168 | train_loss: 0.7580 | train_acc: 0.7470 | test_loss: 1.0956 | test_acc: 0.6395
# Epoch: 169 | train_loss: 0.7512 | train_acc: 0.7461 | test_loss: 1.0638 | test_acc: 0.6430
# Epoch: 170 | train_loss: 0.7181 | train_acc: 0.7586 | test_loss: 1.2809 | test_acc: 0.6101
# Epoch: 171 | train_loss: 0.6885 | train_acc: 0.7703 | test_loss: 1.0338 | test_acc: 0.6542
# Epoch: 172 | train_loss: 0.8550 | train_acc: 0.7067 | test_loss: 1.1059 | test_acc: 0.6336
# Epoch: 173 | train_loss: 0.7264 | train_acc: 0.7570 | test_loss: 1.0285 | test_acc: 0.6618
# Epoch: 174 | train_loss: 0.8482 | train_acc: 0.7126 | test_loss: 1.1640 | test_acc: 0.6026
# Epoch: 175 | train_loss: 0.7092 | train_acc: 0.7608 | test_loss: 1.1906 | test_acc: 0.6116
# Epoch: 176 | train_loss: 0.7122 | train_acc: 0.7607 | test_loss: 1.0385 | test_acc: 0.6664
# Epoch: 177 | train_loss: 0.6696 | train_acc: 0.7794 | test_loss: 1.0084 | test_acc: 0.6854
# Epoch: 178 | train_loss: 0.8823 | train_acc: 0.6953 | test_loss: 1.1098 | test_acc: 0.6262
# Epoch: 179 | train_loss: 0.8363 | train_acc: 0.7212 | test_loss: 1.1902 | test_acc: 0.6020
# Epoch: 180 | train_loss: 0.8484 | train_acc: 0.7230 | test_loss: 1.7371 | test_acc: 0.4468
# Epoch: 181 | train_loss: 1.0932 | train_acc: 0.6183 | test_loss: 1.3285 | test_acc: 0.5683
# Epoch: 182 | train_loss: 0.8622 | train_acc: 0.7010 | test_loss: 1.0999 | test_acc: 0.6310
# Epoch: 183 | train_loss: 0.7532 | train_acc: 0.7427 | test_loss: 1.0767 | test_acc: 0.6468
# Epoch: 184 | train_loss: 0.7172 | train_acc: 0.7616 | test_loss: 1.0613 | test_acc: 0.6474
# Epoch: 185 | train_loss: 0.6904 | train_acc: 0.7653 | test_loss: 1.1541 | test_acc: 0.6281
# Epoch: 186 | train_loss: 0.7972 | train_acc: 0.7221 | test_loss: 1.0852 | test_acc: 0.6436
# Epoch: 187 | train_loss: 1.0760 | train_acc: 0.6494 | test_loss: 1.1232 | test_acc: 0.6157
# Epoch: 188 | train_loss: 0.8018 | train_acc: 0.7308 | test_loss: 1.1140 | test_acc: 0.6335
# Epoch: 189 | train_loss: 0.7120 | train_acc: 0.7635 | test_loss: 1.0773 | test_acc: 0.6629
# Epoch: 190 | train_loss: 0.8602 | train_acc: 0.7127 | test_loss: 1.1817 | test_acc: 0.6013
# Epoch: 191 | train_loss: 0.8572 | train_acc: 0.7090 | test_loss: 1.3528 | test_acc: 0.5541
# Epoch: 192 | train_loss: 0.8129 | train_acc: 0.7239 | test_loss: 1.0588 | test_acc: 0.6422
# Epoch: 193 | train_loss: 0.7412 | train_acc: 0.7504 | test_loss: 1.0423 | test_acc: 0.6542
# Epoch: 194 | train_loss: 0.6862 | train_acc: 0.7686 | test_loss: 1.1071 | test_acc: 0.6580
# Epoch: 195 | train_loss: 0.9251 | train_acc: 0.6861 | test_loss: 1.1319 | test_acc: 0.6307
# Epoch: 196 | train_loss: 1.1008 | train_acc: 0.6378 | test_loss: 1.1391 | test_acc: 0.6107
# Epoch: 197 | train_loss: 0.7893 | train_acc: 0.7303 | test_loss: 1.1097 | test_acc: 0.6393
# Epoch: 198 | train_loss: 0.7713 | train_acc: 0.7380 | test_loss: 1.0791 | test_acc: 0.6343
# Epoch: 199 | train_loss: 0.7249 | train_acc: 0.7564 | test_loss: 1.0708 | test_acc: 0.6632
# Epoch: 200 | train_loss: 0.7365 | train_acc: 0.7493 | test_loss: 1.0778 | test_acc: 0.6635
# Epoch: 201 | train_loss: 0.6803 | train_acc: 0.7740 | test_loss: 1.0774 | test_acc: 0.6615
# Epoch: 202 | train_loss: 0.7199 | train_acc: 0.7600 | test_loss: 1.0971 | test_acc: 0.6420
# Epoch: 203 | train_loss: 0.7311 | train_acc: 0.7508 | test_loss: 1.0182 | test_acc: 0.6631
# Epoch: 204 | train_loss: 0.6942 | train_acc: 0.7661 | test_loss: 1.3118 | test_acc: 0.6316
# Epoch: 205 | train_loss: 0.8898 | train_acc: 0.7081 | test_loss: 1.1936 | test_acc: 0.6060
# Epoch: 206 | train_loss: 0.7425 | train_acc: 0.7491 | test_loss: 1.0566 | test_acc: 0.6483
# Epoch: 207 | train_loss: 1.3651 | train_acc: 0.5686 | test_loss: 1.2769 | test_acc: 0.5588
# Epoch: 208 | train_loss: 0.9495 | train_acc: 0.6628 | test_loss: 1.1540 | test_acc: 0.6043
# Epoch: 209 | train_loss: 0.8605 | train_acc: 0.7038 | test_loss: 1.1465 | test_acc: 0.6215
# Epoch: 210 | train_loss: 0.8413 | train_acc: 0.7110 | test_loss: 1.3087 | test_acc: 0.5829
# Epoch: 211 | train_loss: 0.7955 | train_acc: 0.7312 | test_loss: 1.1195 | test_acc: 0.6340
# Epoch: 212 | train_loss: 0.8596 | train_acc: 0.7103 | test_loss: 1.1347 | test_acc: 0.6173
# Epoch: 213 | train_loss: 0.7009 | train_acc: 0.7601 | test_loss: 1.3994 | test_acc: 0.5816
# Epoch: 214 | train_loss: 1.0091 | train_acc: 0.6800 | test_loss: 1.2273 | test_acc: 0.6041
# Epoch: 215 | train_loss: 0.7508 | train_acc: 0.7454 | test_loss: 1.2048 | test_acc: 0.6234
# Epoch: 216 | train_loss: 0.8779 | train_acc: 0.6953 | test_loss: 1.1747 | test_acc: 0.5929
# Epoch: 217 | train_loss: 0.7728 | train_acc: 0.7306 | test_loss: 1.0950 | test_acc: 0.6489
# Epoch: 218 | train_loss: 0.6509 | train_acc: 0.7838 | test_loss: 1.0759 | test_acc: 0.6704
# Epoch: 219 | train_loss: 0.6465 | train_acc: 0.7848 | test_loss: 1.0539 | test_acc: 0.6538
# Epoch: 220 | train_loss: 0.6817 | train_acc: 0.7681 | test_loss: 1.0889 | test_acc: 0.6361
# Epoch: 221 | train_loss: 0.6423 | train_acc: 0.7828 | test_loss: 1.1327 | test_acc: 0.6410
# Epoch: 222 | train_loss: 0.7470 | train_acc: 0.7427 | test_loss: 1.1350 | test_acc: 0.6359
# Epoch: 223 | train_loss: 0.7063 | train_acc: 0.7681 | test_loss: 1.4582 | test_acc: 0.5982
# Epoch: 224 | train_loss: 0.6753 | train_acc: 0.7782 | test_loss: 1.0199 | test_acc: 0.6695
# Epoch: 225 | train_loss: 0.6949 | train_acc: 0.7707 | test_loss: 1.0356 | test_acc: 0.6671
# Epoch: 226 | train_loss: 0.6280 | train_acc: 0.7894 | test_loss: 1.0136 | test_acc: 0.6697
# Epoch: 227 | train_loss: 1.0384 | train_acc: 0.6382 | test_loss: 1.1823 | test_acc: 0.5854
# Epoch: 228 | train_loss: 0.7933 | train_acc: 0.7203 | test_loss: 1.1435 | test_acc: 0.6098
# Epoch: 229 | train_loss: 0.9497 | train_acc: 0.6757 | test_loss: 1.1623 | test_acc: 0.6057
# Epoch: 230 | train_loss: 1.2215 | train_acc: 0.6310 | test_loss: 1.5000 | test_acc: 0.5266
# Epoch: 231 | train_loss: 1.2630 | train_acc: 0.6156 | test_loss: 1.9877 | test_acc: 0.4481
# Epoch: 232 | train_loss: 1.2073 | train_acc: 0.6032 | test_loss: 1.3635 | test_acc: 0.5484
# Epoch: 233 | train_loss: 0.9594 | train_acc: 0.6728 | test_loss: 1.2206 | test_acc: 0.5863
# Epoch: 234 | train_loss: 0.8452 | train_acc: 0.7134 | test_loss: 1.1905 | test_acc: 0.5971
# Epoch: 235 | train_loss: 0.7866 | train_acc: 0.7348 | test_loss: 1.1148 | test_acc: 0.6237
# Epoch: 236 | train_loss: 0.7228 | train_acc: 0.7618 | test_loss: 1.0775 | test_acc: 0.6437
# Epoch: 237 | train_loss: 0.7099 | train_acc: 0.7644 | test_loss: 1.1051 | test_acc: 0.6348
# Epoch: 238 | train_loss: 0.6810 | train_acc: 0.7770 | test_loss: 1.0688 | test_acc: 0.6582
# Epoch: 239 | train_loss: 0.6518 | train_acc: 0.7832 | test_loss: 1.0326 | test_acc: 0.6618
# Epoch: 240 | train_loss: 0.6335 | train_acc: 0.7894 | test_loss: 1.0269 | test_acc: 0.6663
# Epoch: 241 | train_loss: 0.6954 | train_acc: 0.7695 | test_loss: 1.1081 | test_acc: 0.6430
# Epoch: 242 | train_loss: 0.6455 | train_acc: 0.7822 | test_loss: 1.0326 | test_acc: 0.6637
# Epoch: 243 | train_loss: 0.6971 | train_acc: 0.7761 | test_loss: 1.4002 | test_acc: 0.5988
# Epoch: 244 | train_loss: 0.6625 | train_acc: 0.7811 | test_loss: 1.0854 | test_acc: 0.6515
# Epoch: 245 | train_loss: 0.5965 | train_acc: 0.8046 | test_loss: 1.5791 | test_acc: 0.5604
# Epoch: 246 | train_loss: 0.7164 | train_acc: 0.7603 | test_loss: 1.0876 | test_acc: 0.6597
# Epoch: 247 | train_loss: 0.7556 | train_acc: 0.7550 | test_loss: 1.1181 | test_acc: 0.6477
# Epoch: 248 | train_loss: 0.5968 | train_acc: 0.8047 | test_loss: 1.2365 | test_acc: 0.6289
# Epoch: 249 | train_loss: 0.7551 | train_acc: 0.7438 | test_loss: 1.0569 | test_acc: 0.6483
# Epoch: 250 | train_loss: 0.6075 | train_acc: 0.7985 | test_loss: 1.0375 | test_acc: 0.6610
# Epoch: 251 | train_loss: 0.5910 | train_acc: 0.8066 | test_loss: 1.0812 | test_acc: 0.6603
# Epoch: 252 | train_loss: 0.6600 | train_acc: 0.7816 | test_loss: 1.0410 | test_acc: 0.6664
# Epoch: 253 | train_loss: 0.6330 | train_acc: 0.7944 | test_loss: 1.5479 | test_acc: 0.5523
# Epoch: 254 | train_loss: 0.6748 | train_acc: 0.7766 | test_loss: 1.0406 | test_acc: 0.6657
# Epoch: 255 | train_loss: 0.6088 | train_acc: 0.7992 | test_loss: 1.2111 | test_acc: 0.6393
# Epoch: 256 | train_loss: 0.6387 | train_acc: 0.7904 | test_loss: 1.0555 | test_acc: 0.6721
# Epoch: 257 | train_loss: 1.4010 | train_acc: 0.5725 | test_loss: 1.5146 | test_acc: 0.4950
# Epoch: 258 | train_loss: 1.1270 | train_acc: 0.6008 | test_loss: 1.3512 | test_acc: 0.5383
# Epoch: 259 | train_loss: 1.2284 | train_acc: 0.5894 | test_loss: 1.5147 | test_acc: 0.4854
# Epoch: 260 | train_loss: 1.1184 | train_acc: 0.6114 | test_loss: 1.3691 | test_acc: 0.5336
# Epoch: 261 | train_loss: 1.0087 | train_acc: 0.6523 | test_loss: 1.3380 | test_acc: 0.5476
# Epoch: 262 | train_loss: 0.9566 | train_acc: 0.6667 | test_loss: 1.2875 | test_acc: 0.5669
# Epoch: 263 | train_loss: 0.9043 | train_acc: 0.6858 | test_loss: 1.2436 | test_acc: 0.5781
# Epoch: 264 | train_loss: 0.8616 | train_acc: 0.6999 | test_loss: 1.2247 | test_acc: 0.5941
# Epoch: 265 | train_loss: 0.8349 | train_acc: 0.7105 | test_loss: 1.2116 | test_acc: 0.6015
# Epoch: 266 | train_loss: 0.7938 | train_acc: 0.7247 | test_loss: 1.1784 | test_acc: 0.6189
# Epoch: 267 | train_loss: 0.7842 | train_acc: 0.7285 | test_loss: 1.2174 | test_acc: 0.6127
# Epoch: 268 | train_loss: 0.7538 | train_acc: 0.7424 | test_loss: 1.1266 | test_acc: 0.6329
# Epoch: 269 | train_loss: 0.7478 | train_acc: 0.7415 | test_loss: 1.1056 | test_acc: 0.6369
# Epoch: 270 | train_loss: 0.7650 | train_acc: 0.7370 | test_loss: 1.1414 | test_acc: 0.6374
# Epoch: 271 | train_loss: 0.7250 | train_acc: 0.7559 | test_loss: 1.1199 | test_acc: 0.6343
# Epoch: 272 | train_loss: 0.6578 | train_acc: 0.7779 | test_loss: 1.1284 | test_acc: 0.6343
# Epoch: 273 | train_loss: 0.6923 | train_acc: 0.7664 | test_loss: 1.1112 | test_acc: 0.6436
# Epoch: 274 | train_loss: 0.6615 | train_acc: 0.7765 | test_loss: 1.0958 | test_acc: 0.6496
# Epoch: 275 | train_loss: 0.6813 | train_acc: 0.7685 | test_loss: 1.0937 | test_acc: 0.6416
# Epoch: 276 | train_loss: 0.6515 | train_acc: 0.7814 | test_loss: 1.0845 | test_acc: 0.6476
# Epoch: 277 | train_loss: 0.6506 | train_acc: 0.7830 | test_loss: 1.1445 | test_acc: 0.6364
# Epoch: 278 | train_loss: 0.6681 | train_acc: 0.7716 | test_loss: 1.0915 | test_acc: 0.6590
# Epoch: 279 | train_loss: 0.6723 | train_acc: 0.7752 | test_loss: 1.4628 | test_acc: 0.5087
# Epoch: 280 | train_loss: 0.8032 | train_acc: 0.7186 | test_loss: 1.1473 | test_acc: 0.6251
# Epoch: 281 | train_loss: 0.7208 | train_acc: 0.7566 | test_loss: 1.1317 | test_acc: 0.6263
# Epoch: 282 | train_loss: 0.6128 | train_acc: 0.7942 | test_loss: 1.0679 | test_acc: 0.6663
# Epoch: 283 | train_loss: 0.6142 | train_acc: 0.7981 | test_loss: 1.1649 | test_acc: 0.6418
# Epoch: 284 | train_loss: 0.6515 | train_acc: 0.7819 | test_loss: 1.0746 | test_acc: 0.6603
# Epoch: 285 | train_loss: 1.4255 | train_acc: 0.5849 | test_loss: 1.6174 | test_acc: 0.4180
# Epoch: 286 | train_loss: 1.3258 | train_acc: 0.5370 | test_loss: 1.4697 | test_acc: 0.4981
# Epoch: 287 | train_loss: 1.2377 | train_acc: 0.5795 | test_loss: 2.0370 | test_acc: 0.3822
# Epoch: 288 | train_loss: 1.4733 | train_acc: 0.5054 | test_loss: 1.5018 | test_acc: 0.4840
# Epoch: 289 | train_loss: 1.2273 | train_acc: 0.5777 | test_loss: 1.4175 | test_acc: 0.5134
# Epoch: 290 | train_loss: 1.1321 | train_acc: 0.6081 | test_loss: 1.3464 | test_acc: 0.5441
# Epoch: 291 | train_loss: 1.1142 | train_acc: 0.6112 | test_loss: 1.3579 | test_acc: 0.5313
# Epoch: 292 | train_loss: 1.0465 | train_acc: 0.6309 | test_loss: 1.3449 | test_acc: 0.5458
# Epoch: 293 | train_loss: 0.9953 | train_acc: 0.6498 | test_loss: 1.3103 | test_acc: 0.5589
# Epoch: 294 | train_loss: 1.1285 | train_acc: 0.6181 | test_loss: 1.2925 | test_acc: 0.5676
# Epoch: 295 | train_loss: 0.9684 | train_acc: 0.6618 | test_loss: 1.2907 | test_acc: 0.5663
# Epoch: 296 | train_loss: 0.8985 | train_acc: 0.6879 | test_loss: 1.2655 | test_acc: 0.5823
# Epoch: 297 | train_loss: 0.8951 | train_acc: 0.6870 | test_loss: 1.2702 | test_acc: 0.5865
# Epoch: 298 | train_loss: 0.8323 | train_acc: 0.7037 | test_loss: 1.1975 | test_acc: 0.6176
# Epoch: 299 | train_loss: 0.7737 | train_acc: 0.7275 | test_loss: 1.1641 | test_acc: 0.6250
# Epoch: 300 | train_loss: 0.7421 | train_acc: 0.7408 | test_loss: 1.0968 | test_acc: 0.6411
# Total training time: 174.795 seconds

# %%
# Training model_1
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train(model=model_1,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer_1,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.5206 | train_acc: 0.4474 | test_loss: 1.3346 | test_acc: 0.5002
# Epoch: 2 | train_loss: 1.1748 | train_acc: 0.5873 | test_loss: 1.2008 | test_acc: 0.5749
# Epoch: 3 | train_loss: 1.0089 | train_acc: 0.6520 | test_loss: 1.1276 | test_acc: 0.6004
# Epoch: 4 | train_loss: 0.8918 | train_acc: 0.7021 | test_loss: 1.1151 | test_acc: 0.6055
# Epoch: 5 | train_loss: 0.7863 | train_acc: 0.7426 | test_loss: 1.0672 | test_acc: 0.6255
# Epoch: 6 | train_loss: 0.7165 | train_acc: 0.7678 | test_loss: 1.0581 | test_acc: 0.6183
# Epoch: 7 | train_loss: 0.6445 | train_acc: 0.7959 | test_loss: 1.0613 | test_acc: 0.6324
# Epoch: 8 | train_loss: 0.5810 | train_acc: 0.8263 | test_loss: 1.1958 | test_acc: 0.5856
# Epoch: 9 | train_loss: 0.5253 | train_acc: 0.8468 | test_loss: 1.0292 | test_acc: 0.6444
# Epoch: 10 | train_loss: 0.4753 | train_acc: 0.8652 | test_loss: 1.0540 | test_acc: 0.6388
# Epoch: 11 | train_loss: 0.4314 | train_acc: 0.8809 | test_loss: 1.0785 | test_acc: 0.6229
# Epoch: 12 | train_loss: 0.3824 | train_acc: 0.9021 | test_loss: 1.0780 | test_acc: 0.6309
# Epoch: 13 | train_loss: 0.3531 | train_acc: 0.9135 | test_loss: 1.0790 | test_acc: 0.6430
# Epoch: 14 | train_loss: 0.3157 | train_acc: 0.9289 | test_loss: 1.0844 | test_acc: 0.6466
# Epoch: 15 | train_loss: 0.2830 | train_acc: 0.9417 | test_loss: 1.1441 | test_acc: 0.6304
# Epoch: 16 | train_loss: 0.2574 | train_acc: 0.9477 | test_loss: 1.0975 | test_acc: 0.6545
# Epoch: 17 | train_loss: 0.2327 | train_acc: 0.9590 | test_loss: 1.1137 | test_acc: 0.6350
# Epoch: 18 | train_loss: 0.2100 | train_acc: 0.9621 | test_loss: 1.1169 | test_acc: 0.6526
# Epoch: 19 | train_loss: 0.1871 | train_acc: 0.9724 | test_loss: 1.1163 | test_acc: 0.6619
# Epoch: 20 | train_loss: 0.1707 | train_acc: 0.9764 | test_loss: 1.1333 | test_acc: 0.6518
# Epoch: 21 | train_loss: 0.1567 | train_acc: 0.9784 | test_loss: 1.1646 | test_acc: 0.6472
# Epoch: 22 | train_loss: 0.1376 | train_acc: 0.9835 | test_loss: 1.1761 | test_acc: 0.6584
# Epoch: 23 | train_loss: 0.1230 | train_acc: 0.9868 | test_loss: 1.1914 | test_acc: 0.6578
# Epoch: 24 | train_loss: 0.1094 | train_acc: 0.9919 | test_loss: 1.1906 | test_acc: 0.6599
# Epoch: 25 | train_loss: 0.0982 | train_acc: 0.9937 | test_loss: 1.2056 | test_acc: 0.6608
# Epoch: 26 | train_loss: 0.0872 | train_acc: 0.9942 | test_loss: 1.2565 | test_acc: 0.6537
# Epoch: 27 | train_loss: 0.0799 | train_acc: 0.9958 | test_loss: 1.2138 | test_acc: 0.6671
# Epoch: 28 | train_loss: 0.0693 | train_acc: 0.9977 | test_loss: 1.2474 | test_acc: 0.6664
# Epoch: 29 | train_loss: 0.0616 | train_acc: 0.9982 | test_loss: 1.2796 | test_acc: 0.6618
# Epoch: 30 | train_loss: 0.0581 | train_acc: 0.9973 | test_loss: 1.3095 | test_acc: 0.6577
# Total training time: 16.412 seconds

# %% [markdown]
# ## 6. Plotting the results of the RNN models
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys (they are the same as model_1)
print(model_0_results.keys())
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
# defining the plot function
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]],
                     Save = False,
                     filename: str = "training_curves",):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup figure
    fig, axs = plt.subplots(1, 2, figsize=(15, 7))
    fig.patch.set_facecolor('white')

    # ===== Loss plot =====
    axs[0].set_facecolor('white')

    axs[0].plot(epochs, loss, label='train_loss', color="#4195C1")
    axs[0].plot(epochs, test_loss, label='test_loss', color="#FF7B22")

    axs[0].set_title('Loss', color='black')
    axs[0].set_xlabel('Epochs', color='black')

    axs[0].tick_params(axis='x', colors='black')
    axs[0].tick_params(axis='y', colors='black')

    for spine in axs[0].spines.values():
        spine.set_color('black')

    axs[0].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # ===== Accuracy plot =====
    axs[1].set_facecolor('white')

    axs[1].plot(epochs, accuracy, label='train_accuracy', color="#4195C1")
    axs[1].plot(epochs, test_accuracy, label='test_accuracy', color="#FF7B22")

    axs[1].set_title('Accuracy', color='black')
    axs[1].set_xlabel('Epochs', color='black')

    axs[1].tick_params(axis='x', colors='black')
    axs[1].tick_params(axis='y', colors='black')

    for spine in axs[1].spines.values():
        spine.set_color('black')

    axs[1].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # Layout
    plt.tight_layout()

    # Save figure
    if Save:
        plt.savefig(
            filename + ".png",
            dpi=144,
            bbox_inches='tight',
            facecolor=fig.get_facecolor()
        )

    plt.show()

# %%
# Plotting the results of model_0
plot_loss_curves(model_0_results, Save=True, filename="model_0_training")

# %% [markdown]
# We can see that `model_0` shows signs of overfitting after some point. The loss values start to increase after the 170th epoch. Furthermore, we see rapid spikes in the graph. This is a sign of vanishing/exploding gradients according to [this paper](https://ieeexplore.ieee.org/document/8623623).

# %%
# Plotting the results of model_1
plot_loss_curves(model_1_results, Save=True, filename="model_1_training")

# %% [markdown]
# In the case of `model_1` it is obvious that overfitting occurs from the very early stages of training. This is actually a very common problem when using data from all the hidden stages and it appears to be one of the disadvantages of following this method.

# %% [markdown]
# ## 7. Building a basic LSTM model, training and plotting the results
#
# Better results are expected with the use of an LSTM model.
# This neural network is similar to the RNN architecture, though it features some extra attributes in order to fix some common issues of the RNN.
# * __Unstable gradients__: The weight of the feedback loop can cause problems on the gradient descent equation. This weight refers to the _reccurent weight matrix_ that connects the hidden state of the previous state, with the current one. In case that weight is larger than one, repeated multiplication during backpropagation can lead to a very large number, which causes __exploding gradients__. On the other hand, if the value of the weight is less than one, it can lead to a very small number, which causes __vanishing gradients__.
# * __Long term memory__: RNNs tend to "forget" old data. This happens due to exploding/vanishing gradients.
#
# In order to solve this problems, LSTMs implement a _cell state_, apart from the _hidden state_. This is responsible for storing data from older recursions in time. As a result, building the LSTM class for our model, should include an initial cell state (`c0`) apart from the initial hidden state (`ho`) in the `forward()` method. This cell state reflects a long-term memory for the network. Other than that, PyTorch includes an `LSTM()` layer, which is used same as the `RNN()` layer.
#
# After building the class and instantiatiing a model, we follow the same pipeline as with the RNNs in order to train the model and plot the results for evaluation.

# %%
# Building the LSTM model
INPUT_SIZE = 13 # number of mfccs
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked LSTM layers that are going to be used
NUM_CLASSES = 10

class LSTMClassifierV0(nn.Module):
    def __init__(self, input_size=13,
                 hidden_size=128,
                 num_layers=2,
                 num_classes=10):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.lstm = nn.LSTM(input_size,
                           hidden_size,
                           num_layers,
                           batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state and cell state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0,c0))
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# # Building the LSTM model according to paper
# INPUT_SIZE = 13 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked LSTM layers that are going to be used
# NUM_CLASSES = 10
#
# class LSTMClassifierV1(nn.Module):
#     def __init__(self, input_size=13, num_classes=10):
#         super().__init__()
#
#         # LSTM blocks
#         self.lstm1 = nn.LSTM(input_size,
#                              128,
#                              num_layers=1,
#                              batch_first=True)
#
#         self.lstm2 = nn.LSTM(128,
#                              64,
#                              num_layers=1,
#                              batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for LSTM 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#         c0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         out, _ = self.lstm1(x, (h0_1, c0_1))
#
#         # Initial states for LSTM 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#         c0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         out, _ = self.lstm2(out, (h0_2, c0_2))
#
#         # Last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_2 = LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# Instatiating the paper version of the LSTM
# model_2 = LSTMClassifierV1().to(device)
model_2
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Extracting a sample and testing it with a forward pass
example, _ = next(iter(train_dataloader))
model_2.eval()
print(model_2(example.to(device))[:5])
# Out:
# tensor([[-0.0012,  0.0032,  0.0742,  0.0058, -0.0120,  0.0419, -0.1865,  0.0657,
#          -0.0846, -0.0004],
#         [-0.0253, -0.0067,  0.1068, -0.0894, -0.0014, -0.0868, -0.0577,  0.0723,
#          -0.2152, -0.0767],
#         [ 0.0857, -0.0093,  0.0344, -0.1445,  0.0764,  0.0079, -0.0586,  0.0172,
#          -0.1553, -0.0076],
#         [ 0.0372,  0.0285,  0.0759, -0.0749, -0.0340, -0.0584, -0.1107,  0.0844,
#          -0.1450,  0.0341],
#         [ 0.0260,  0.0336,  0.0496, -0.1229,  0.0290, -0.0844, -0.0097,  0.0374,
#          -0.1436, -0.0668]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in the paper version of the LSTM
# optimizer = torch.optim.Adam(model_2.parameters(),
#                              lr=0.001)

# %%
# Training model_2
# Set number of epochs
NUM_EPOCHS = 100

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_2_results = train(model=model_2,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0891 | train_acc: 0.2828 | test_loss: 1.8229 | test_acc: 0.3608
# Epoch: 2 | train_loss: 1.6680 | train_acc: 0.4096 | test_loss: 1.5518 | test_acc: 0.4612
# Epoch: 3 | train_loss: 1.4526 | train_acc: 0.4912 | test_loss: 1.3827 | test_acc: 0.5203
# Epoch: 4 | train_loss: 1.3390 | train_acc: 0.5252 | test_loss: 1.3306 | test_acc: 0.5381
# Epoch: 5 | train_loss: 1.2543 | train_acc: 0.5620 | test_loss: 1.2790 | test_acc: 0.5502
# Epoch: 6 | train_loss: 1.1908 | train_acc: 0.5822 | test_loss: 1.2265 | test_acc: 0.5734
# Epoch: 7 | train_loss: 1.1342 | train_acc: 0.6003 | test_loss: 1.1825 | test_acc: 0.5959
# Epoch: 8 | train_loss: 1.1410 | train_acc: 0.6018 | test_loss: 1.2081 | test_acc: 0.5733
# Epoch: 9 | train_loss: 1.0904 | train_acc: 0.6204 | test_loss: 1.1596 | test_acc: 0.5919
# Epoch: 10 | train_loss: 1.0720 | train_acc: 0.6264 | test_loss: 1.1854 | test_acc: 0.5829
# Epoch: 11 | train_loss: 1.0343 | train_acc: 0.6426 | test_loss: 1.1465 | test_acc: 0.5916
# Epoch: 12 | train_loss: 0.9940 | train_acc: 0.6564 | test_loss: 1.1349 | test_acc: 0.6049
# Epoch: 13 | train_loss: 0.9587 | train_acc: 0.6668 | test_loss: 1.1050 | test_acc: 0.6193
# Epoch: 14 | train_loss: 0.9349 | train_acc: 0.6813 | test_loss: 1.1187 | test_acc: 0.6010
# Epoch: 15 | train_loss: 0.9110 | train_acc: 0.6897 | test_loss: 1.0855 | test_acc: 0.6256
# Epoch: 16 | train_loss: 0.9040 | train_acc: 0.6969 | test_loss: 1.1408 | test_acc: 0.6117
# Epoch: 17 | train_loss: 0.8869 | train_acc: 0.7025 | test_loss: 1.0697 | test_acc: 0.6335
# Epoch: 18 | train_loss: 0.9373 | train_acc: 0.6879 | test_loss: 1.1528 | test_acc: 0.5843
# Epoch: 19 | train_loss: 0.8955 | train_acc: 0.6972 | test_loss: 1.0786 | test_acc: 0.6324
# Epoch: 20 | train_loss: 0.8620 | train_acc: 0.7052 | test_loss: 1.0876 | test_acc: 0.6268
# Epoch: 21 | train_loss: 0.8296 | train_acc: 0.7207 | test_loss: 1.2452 | test_acc: 0.5857
# Epoch: 22 | train_loss: 0.8623 | train_acc: 0.7154 | test_loss: 1.0364 | test_acc: 0.6477
# Epoch: 23 | train_loss: 0.8778 | train_acc: 0.7058 | test_loss: 1.0804 | test_acc: 0.6278
# Epoch: 24 | train_loss: 0.8020 | train_acc: 0.7322 | test_loss: 1.0594 | test_acc: 0.6348
# Epoch: 25 | train_loss: 0.7673 | train_acc: 0.7456 | test_loss: 1.0243 | test_acc: 0.6534
# Epoch: 26 | train_loss: 0.7212 | train_acc: 0.7588 | test_loss: 1.0319 | test_acc: 0.6514
# Epoch: 27 | train_loss: 0.6864 | train_acc: 0.7715 | test_loss: 0.9998 | test_acc: 0.6664
# Epoch: 28 | train_loss: 0.6987 | train_acc: 0.7685 | test_loss: 1.0475 | test_acc: 0.6509
# Epoch: 29 | train_loss: 0.6809 | train_acc: 0.7744 | test_loss: 1.0701 | test_acc: 0.6443
# Epoch: 30 | train_loss: 0.6741 | train_acc: 0.7761 | test_loss: 1.0617 | test_acc: 0.6439
# Epoch: 31 | train_loss: 0.6814 | train_acc: 0.7748 | test_loss: 1.0103 | test_acc: 0.6650
# Epoch: 32 | train_loss: 0.6396 | train_acc: 0.7908 | test_loss: 1.0139 | test_acc: 0.6608
# Epoch: 33 | train_loss: 0.6706 | train_acc: 0.7771 | test_loss: 0.9987 | test_acc: 0.6683
# Epoch: 34 | train_loss: 0.6477 | train_acc: 0.7869 | test_loss: 0.9911 | test_acc: 0.6696
# Epoch: 35 | train_loss: 0.6173 | train_acc: 0.7962 | test_loss: 1.0919 | test_acc: 0.6490
# Epoch: 36 | train_loss: 0.6267 | train_acc: 0.7935 | test_loss: 1.0575 | test_acc: 0.6712
# Epoch: 37 | train_loss: 0.6290 | train_acc: 0.7907 | test_loss: 0.9855 | test_acc: 0.6831
# Epoch: 38 | train_loss: 0.5631 | train_acc: 0.8173 | test_loss: 0.9509 | test_acc: 0.6855
# Epoch: 39 | train_loss: 0.5684 | train_acc: 0.8130 | test_loss: 0.9991 | test_acc: 0.6743
# Epoch: 40 | train_loss: 0.5691 | train_acc: 0.8093 | test_loss: 0.9868 | test_acc: 0.6764
# Epoch: 41 | train_loss: 0.5583 | train_acc: 0.8171 | test_loss: 0.9979 | test_acc: 0.6777
# Epoch: 42 | train_loss: 0.5743 | train_acc: 0.8156 | test_loss: 0.9400 | test_acc: 0.6990
# Epoch: 43 | train_loss: 0.5044 | train_acc: 0.8425 | test_loss: 0.9542 | test_acc: 0.7014
# Epoch: 44 | train_loss: 0.5024 | train_acc: 0.8399 | test_loss: 0.9554 | test_acc: 0.7014
# Epoch: 45 | train_loss: 0.4981 | train_acc: 0.8345 | test_loss: 0.9988 | test_acc: 0.6902
# Epoch: 46 | train_loss: 0.5277 | train_acc: 0.8291 | test_loss: 0.9595 | test_acc: 0.6949
# Epoch: 47 | train_loss: 0.4943 | train_acc: 0.8415 | test_loss: 0.9257 | test_acc: 0.7023
# Epoch: 48 | train_loss: 0.4464 | train_acc: 0.8620 | test_loss: 0.9258 | test_acc: 0.7015
# Epoch: 49 | train_loss: 0.4418 | train_acc: 0.8617 | test_loss: 0.9335 | test_acc: 0.7067
# Epoch: 50 | train_loss: 0.4442 | train_acc: 0.8577 | test_loss: 0.9957 | test_acc: 0.6884
# Epoch: 51 | train_loss: 0.4836 | train_acc: 0.8423 | test_loss: 0.9153 | test_acc: 0.7074
# Epoch: 52 | train_loss: 0.4064 | train_acc: 0.8750 | test_loss: 0.9219 | test_acc: 0.7290
# Epoch: 53 | train_loss: 0.3822 | train_acc: 0.8821 | test_loss: 0.9572 | test_acc: 0.6981
# Epoch: 54 | train_loss: 0.4247 | train_acc: 0.8639 | test_loss: 1.0054 | test_acc: 0.6850
# Epoch: 55 | train_loss: 0.4271 | train_acc: 0.8639 | test_loss: 0.9541 | test_acc: 0.7009
# Epoch: 56 | train_loss: 0.4084 | train_acc: 0.8681 | test_loss: 0.9036 | test_acc: 0.7229
# Epoch: 57 | train_loss: 0.3720 | train_acc: 0.8878 | test_loss: 0.9773 | test_acc: 0.7055
# Epoch: 58 | train_loss: 0.3826 | train_acc: 0.8814 | test_loss: 0.9253 | test_acc: 0.7195
# Epoch: 59 | train_loss: 0.3955 | train_acc: 0.8722 | test_loss: 0.9454 | test_acc: 0.7093
# Epoch: 60 | train_loss: 0.3421 | train_acc: 0.8979 | test_loss: 0.9435 | test_acc: 0.7186
# Epoch: 61 | train_loss: 0.3486 | train_acc: 0.8935 | test_loss: 0.9230 | test_acc: 0.7225
# Epoch: 62 | train_loss: 0.3486 | train_acc: 0.8931 | test_loss: 0.9241 | test_acc: 0.7247
# Epoch: 63 | train_loss: 0.4088 | train_acc: 0.8752 | test_loss: 1.0212 | test_acc: 0.6873
# Epoch: 64 | train_loss: 0.4148 | train_acc: 0.8685 | test_loss: 0.9436 | test_acc: 0.7247
# Epoch: 65 | train_loss: 0.3600 | train_acc: 0.8876 | test_loss: 0.9024 | test_acc: 0.7376
# Epoch: 66 | train_loss: 0.2988 | train_acc: 0.9101 | test_loss: 0.9524 | test_acc: 0.7295
# Epoch: 67 | train_loss: 0.3191 | train_acc: 0.9014 | test_loss: 0.9704 | test_acc: 0.7181
# Epoch: 68 | train_loss: 0.3019 | train_acc: 0.9087 | test_loss: 0.9687 | test_acc: 0.7087
# Epoch: 69 | train_loss: 0.3936 | train_acc: 0.8752 | test_loss: 0.9184 | test_acc: 0.7202
# Epoch: 70 | train_loss: 0.3165 | train_acc: 0.9047 | test_loss: 0.9330 | test_acc: 0.7203
# Epoch: 71 | train_loss: 0.2907 | train_acc: 0.9113 | test_loss: 0.9357 | test_acc: 0.7396
# Epoch: 72 | train_loss: 0.2603 | train_acc: 0.9215 | test_loss: 0.9188 | test_acc: 0.7370
# Epoch: 73 | train_loss: 0.2290 | train_acc: 0.9329 | test_loss: 0.9495 | test_acc: 0.7235
# Epoch: 74 | train_loss: 0.2493 | train_acc: 0.9274 | test_loss: 0.9334 | test_acc: 0.7336
# Epoch: 75 | train_loss: 0.2739 | train_acc: 0.9131 | test_loss: 0.9437 | test_acc: 0.7248
# Epoch: 76 | train_loss: 0.2324 | train_acc: 0.9321 | test_loss: 0.9930 | test_acc: 0.7242
# Epoch: 77 | train_loss: 0.2445 | train_acc: 0.9270 | test_loss: 0.9412 | test_acc: 0.7296
# Epoch: 78 | train_loss: 0.2152 | train_acc: 0.9379 | test_loss: 0.9592 | test_acc: 0.7302
# Epoch: 79 | train_loss: 0.2712 | train_acc: 0.9151 | test_loss: 0.9346 | test_acc: 0.7217
# Epoch: 80 | train_loss: 0.3139 | train_acc: 0.9022 | test_loss: 1.0387 | test_acc: 0.6933
# Epoch: 81 | train_loss: 0.2666 | train_acc: 0.9206 | test_loss: 0.9142 | test_acc: 0.7536
# Epoch: 82 | train_loss: 0.2332 | train_acc: 0.9283 | test_loss: 0.9669 | test_acc: 0.7294
# Epoch: 83 | train_loss: 0.1999 | train_acc: 0.9413 | test_loss: 0.9291 | test_acc: 0.7509
# Epoch: 84 | train_loss: 0.1858 | train_acc: 0.9467 | test_loss: 0.9537 | test_acc: 0.7370
# Epoch: 85 | train_loss: 0.2008 | train_acc: 0.9398 | test_loss: 0.9382 | test_acc: 0.7322
# Epoch: 86 | train_loss: 0.1889 | train_acc: 0.9460 | test_loss: 0.9316 | test_acc: 0.7425
# Epoch: 87 | train_loss: 0.1673 | train_acc: 0.9537 | test_loss: 0.9358 | test_acc: 0.7458
# Epoch: 88 | train_loss: 0.1512 | train_acc: 0.9579 | test_loss: 0.9800 | test_acc: 0.7312
# Epoch: 89 | train_loss: 0.1507 | train_acc: 0.9603 | test_loss: 0.9368 | test_acc: 0.7436
# Epoch: 90 | train_loss: 0.1862 | train_acc: 0.9447 | test_loss: 1.0386 | test_acc: 0.7169
# Epoch: 91 | train_loss: 0.2586 | train_acc: 0.9242 | test_loss: 1.0401 | test_acc: 0.7229
# Epoch: 92 | train_loss: 0.3103 | train_acc: 0.9021 | test_loss: 0.9248 | test_acc: 0.7390
# Epoch: 93 | train_loss: 0.1950 | train_acc: 0.9430 | test_loss: 0.9174 | test_acc: 0.7450
# Epoch: 94 | train_loss: 0.1627 | train_acc: 0.9577 | test_loss: 0.9388 | test_acc: 0.7437
# Epoch: 95 | train_loss: 0.1570 | train_acc: 0.9589 | test_loss: 0.9419 | test_acc: 0.7441
# Epoch: 96 | train_loss: 0.1278 | train_acc: 0.9676 | test_loss: 0.9843 | test_acc: 0.7496
# Epoch: 97 | train_loss: 0.2532 | train_acc: 0.9250 | test_loss: 0.9954 | test_acc: 0.7431
# Epoch: 98 | train_loss: 0.1535 | train_acc: 0.9579 | test_loss: 1.0233 | test_acc: 0.7322
# Epoch: 99 | train_loss: 0.1516 | train_acc: 0.9568 | test_loss: 1.0172 | test_acc: 0.7370
# Epoch: 100 | train_loss: 0.1383 | train_acc: 0.9624 | test_loss: 0.9665 | test_acc: 0.7499
# Total training time: 80.719 seconds

# %%
# Plotting the results of model_2
plot_loss_curves(model_2_results, Save=True, filename="model_2_training")

# %% [markdown]
# The LSTM model appears to be performing better than the RNN on our problem. We see that after the 10th epoch some overfitting is starting to develop. However, we could have stopped the training at this point and `model_2` would already be performing better than `model_0`. As we see that already from the 10th epoch, the accuracy on the validation set is above 60%.

# %% [markdown]
# ## 8. Building a basic GRU model, training and plotting the results
#
# The GRU cell is a simplified version of an LSTM cell. There is not a seperate output for the long-term memory state. The whole state is output at every timestep. As a result, there is no need to define an initial cell state in the `forward()` method, like in the LSTM. PyTorch includes a `GRU()` layer that works like the `RNN()` and the `LSTM()` class. So all in all, the GRU class that we are going to build is identical to the RNN. Only difference is using the `GRU()` layer, instead of the `RNN()`.
#
# After building the class and instantiatiing a model, we follow the same pipeline as before in order to train the model and plot the results for evaluation.

# %%
# Building a GRU model
INPUT_SIZE = 13 # number of mfccs
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked GRU layers that are going to be used
NUM_CLASSES = 10

class GRUClassifierV0(nn.Module):
    def __init__(self, input_size=13,
                 hidden_size=128,
                 num_layers=2,
                 num_classes=10):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.gru = nn.GRU(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate RNN
        out, _ = self.gru(x, h0)
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# # Building the gru version of the paper RNN -ONLY LAST HIDDEN STATE-
#
# INPUT_SIZE = 13 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class GRUClassifierV1(nn.Module):
#     def __init__(self, input_size=13, num_classes=10):
#         super().__init__()
#
#         # defining the network layers
#         self.gru1 = nn.GRU(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.gru2 = nn.GRU(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for GRU 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate GRU 1
#         out, _ = self.gru1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.gru2(out, h0_2)
#
#         # Decode the hidden state of the last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_3 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instatiating the paper version of the GRU
# model_3 = GRUClassifierV1().to(device)
model_3
# Out:
# GRUClassifierV0(
#   (gru): GRU(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Extracting a sample and testing it with a forward pass
example, _ = next(iter(train_dataloader))
model_3.eval()
print(model_3(example.to(device))[:5])
# Out:
# tensor([[ 0.6876,  0.0852,  0.0276,  0.0497, -0.1413,  0.0095, -0.0322, -0.3056,
#           0.0058,  0.2349],
#         [ 0.2431, -0.0446, -0.0026, -0.0620, -0.1306, -0.3438, -0.0667, -0.3143,
#           0.0154,  0.2654],
#         [ 0.2086,  0.2507,  0.5312, -0.1034,  0.0781, -0.0421, -0.0468, -0.2080,
#           0.1386, -0.0233],
#         [ 0.2800, -0.1192,  0.6845, -0.1721,  0.0313,  0.2482, -0.3438,  0.0380,
#           0.2764, -0.2326],
#         [ 0.0088,  0.0576,  0.3357, -0.2558,  0.2235,  0.1080, -0.0647, -0.2683,
#           0.2971, -0.0058]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model_3.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # optimizer used in model from paper according to the specs there
# optimizer = torch.optim.Adam(model_3.parameters(),
#                              lr=0.001)

# Training model_3
# Set number of epochs
NUM_EPOCHS = 100

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_3_results = train(model=model_3,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.9881 | train_acc: 0.3077 | test_loss: 1.7946 | test_acc: 0.3658
# Epoch: 2 | train_loss: 1.6828 | train_acc: 0.4044 | test_loss: 1.6065 | test_acc: 0.4483
# Epoch: 3 | train_loss: 1.5076 | train_acc: 0.4747 | test_loss: 1.4582 | test_acc: 0.4943
# Epoch: 4 | train_loss: 1.3548 | train_acc: 0.5247 | test_loss: 1.3279 | test_acc: 0.5229
# Epoch: 5 | train_loss: 1.2300 | train_acc: 0.5688 | test_loss: 1.2352 | test_acc: 0.5569
# Epoch: 6 | train_loss: 1.1307 | train_acc: 0.6092 | test_loss: 1.1404 | test_acc: 0.5881
# Epoch: 7 | train_loss: 1.0482 | train_acc: 0.6374 | test_loss: 1.0850 | test_acc: 0.6140
# Epoch: 8 | train_loss: 0.9657 | train_acc: 0.6662 | test_loss: 1.0482 | test_acc: 0.6237
# Epoch: 9 | train_loss: 0.9059 | train_acc: 0.6864 | test_loss: 0.9904 | test_acc: 0.6514
# Epoch: 10 | train_loss: 0.8463 | train_acc: 0.7110 | test_loss: 0.9475 | test_acc: 0.6656
# Epoch: 11 | train_loss: 0.7847 | train_acc: 0.7317 | test_loss: 0.9197 | test_acc: 0.6789
# Epoch: 12 | train_loss: 0.7455 | train_acc: 0.7468 | test_loss: 0.9063 | test_acc: 0.6939
# Epoch: 13 | train_loss: 0.7006 | train_acc: 0.7590 | test_loss: 0.9047 | test_acc: 0.6731
# Epoch: 14 | train_loss: 0.6618 | train_acc: 0.7721 | test_loss: 0.8722 | test_acc: 0.7004
# Epoch: 15 | train_loss: 0.6364 | train_acc: 0.7833 | test_loss: 0.8571 | test_acc: 0.7084
# Epoch: 16 | train_loss: 0.5986 | train_acc: 0.7982 | test_loss: 0.8412 | test_acc: 0.7205
# Epoch: 17 | train_loss: 0.5705 | train_acc: 0.8089 | test_loss: 0.8891 | test_acc: 0.6995
# Epoch: 18 | train_loss: 0.5438 | train_acc: 0.8173 | test_loss: 0.8375 | test_acc: 0.7205
# Epoch: 19 | train_loss: 0.5152 | train_acc: 0.8306 | test_loss: 0.8316 | test_acc: 0.7145
# Epoch: 20 | train_loss: 0.5042 | train_acc: 0.8326 | test_loss: 0.8158 | test_acc: 0.7179
# Epoch: 21 | train_loss: 0.4735 | train_acc: 0.8466 | test_loss: 0.7947 | test_acc: 0.7472
# Epoch: 22 | train_loss: 0.4536 | train_acc: 0.8541 | test_loss: 0.8311 | test_acc: 0.7224
# Epoch: 23 | train_loss: 0.4254 | train_acc: 0.8637 | test_loss: 0.8192 | test_acc: 0.7353
# Epoch: 24 | train_loss: 0.4196 | train_acc: 0.8616 | test_loss: 0.8281 | test_acc: 0.7379
# Epoch: 25 | train_loss: 0.4015 | train_acc: 0.8695 | test_loss: 0.8092 | test_acc: 0.7298
# Epoch: 26 | train_loss: 0.3769 | train_acc: 0.8787 | test_loss: 0.8243 | test_acc: 0.7367
# Epoch: 27 | train_loss: 0.3641 | train_acc: 0.8849 | test_loss: 1.0158 | test_acc: 0.6920
# Epoch: 28 | train_loss: 0.3739 | train_acc: 0.8803 | test_loss: 0.8233 | test_acc: 0.7421
# Epoch: 29 | train_loss: 0.3324 | train_acc: 0.8941 | test_loss: 0.8158 | test_acc: 0.7458
# Epoch: 30 | train_loss: 0.3221 | train_acc: 0.8967 | test_loss: 0.8181 | test_acc: 0.7533
# Epoch: 31 | train_loss: 0.3099 | train_acc: 0.9016 | test_loss: 0.8306 | test_acc: 0.7515
# Epoch: 32 | train_loss: 0.3053 | train_acc: 0.9007 | test_loss: 0.8106 | test_acc: 0.7565
# Epoch: 33 | train_loss: 0.2837 | train_acc: 0.9113 | test_loss: 0.8628 | test_acc: 0.7419
# Epoch: 34 | train_loss: 0.2820 | train_acc: 0.9127 | test_loss: 0.7899 | test_acc: 0.7584
# Epoch: 35 | train_loss: 0.2588 | train_acc: 0.9220 | test_loss: 0.8951 | test_acc: 0.7454
# Epoch: 36 | train_loss: 0.2572 | train_acc: 0.9169 | test_loss: 0.8192 | test_acc: 0.7518
# Epoch: 37 | train_loss: 0.2401 | train_acc: 0.9265 | test_loss: 0.8121 | test_acc: 0.7591
# Epoch: 38 | train_loss: 0.2401 | train_acc: 0.9279 | test_loss: 0.8569 | test_acc: 0.7604
# Epoch: 39 | train_loss: 0.2345 | train_acc: 0.9270 | test_loss: 0.8453 | test_acc: 0.7585
# Epoch: 40 | train_loss: 0.2165 | train_acc: 0.9328 | test_loss: 0.8464 | test_acc: 0.7558
# Epoch: 41 | train_loss: 0.2204 | train_acc: 0.9348 | test_loss: 0.8271 | test_acc: 0.7691
# Epoch: 42 | train_loss: 0.2041 | train_acc: 0.9369 | test_loss: 0.8316 | test_acc: 0.7645
# Epoch: 43 | train_loss: 0.1976 | train_acc: 0.9411 | test_loss: 0.8220 | test_acc: 0.7639
# Epoch: 44 | train_loss: 0.1755 | train_acc: 0.9515 | test_loss: 0.9030 | test_acc: 0.7595
# Epoch: 45 | train_loss: 0.1881 | train_acc: 0.9461 | test_loss: 0.8565 | test_acc: 0.7605
# Epoch: 46 | train_loss: 0.2245 | train_acc: 0.9342 | test_loss: 0.8968 | test_acc: 0.7648
# Epoch: 47 | train_loss: 0.1871 | train_acc: 0.9443 | test_loss: 0.9237 | test_acc: 0.7606
# Epoch: 48 | train_loss: 0.1699 | train_acc: 0.9534 | test_loss: 0.8958 | test_acc: 0.7606
# Epoch: 49 | train_loss: 0.1460 | train_acc: 0.9609 | test_loss: 0.9281 | test_acc: 0.7545
# Epoch: 50 | train_loss: 0.1552 | train_acc: 0.9543 | test_loss: 0.8495 | test_acc: 0.7786
# Epoch: 51 | train_loss: 0.1599 | train_acc: 0.9516 | test_loss: 0.9677 | test_acc: 0.7511
# Epoch: 52 | train_loss: 0.1549 | train_acc: 0.9540 | test_loss: 0.8692 | test_acc: 0.7692
# Epoch: 53 | train_loss: 0.1439 | train_acc: 0.9604 | test_loss: 0.9318 | test_acc: 0.7598
# Epoch: 54 | train_loss: 0.1414 | train_acc: 0.9594 | test_loss: 0.9322 | test_acc: 0.7552
# Epoch: 55 | train_loss: 0.1323 | train_acc: 0.9638 | test_loss: 0.9589 | test_acc: 0.7598
# Epoch: 56 | train_loss: 0.1363 | train_acc: 0.9626 | test_loss: 0.9414 | test_acc: 0.7592
# Epoch: 57 | train_loss: 0.1887 | train_acc: 0.9449 | test_loss: 0.8569 | test_acc: 0.7764
# Epoch: 58 | train_loss: 0.1323 | train_acc: 0.9635 | test_loss: 0.9275 | test_acc: 0.7533
# Epoch: 59 | train_loss: 0.1025 | train_acc: 0.9751 | test_loss: 0.8778 | test_acc: 0.7777
# Epoch: 60 | train_loss: 0.0886 | train_acc: 0.9789 | test_loss: 0.9027 | test_acc: 0.7799
# Epoch: 61 | train_loss: 0.1343 | train_acc: 0.9623 | test_loss: 0.9432 | test_acc: 0.7632
# Epoch: 62 | train_loss: 0.1370 | train_acc: 0.9613 | test_loss: 0.9409 | test_acc: 0.7699
# Epoch: 63 | train_loss: 0.1146 | train_acc: 0.9697 | test_loss: 0.9134 | test_acc: 0.7635
# Epoch: 64 | train_loss: 0.1048 | train_acc: 0.9721 | test_loss: 0.9010 | test_acc: 0.7786
# Epoch: 65 | train_loss: 0.0886 | train_acc: 0.9783 | test_loss: 0.9432 | test_acc: 0.7665
# Epoch: 66 | train_loss: 0.0865 | train_acc: 0.9792 | test_loss: 0.9724 | test_acc: 0.7706
# Epoch: 67 | train_loss: 0.1021 | train_acc: 0.9721 | test_loss: 0.9329 | test_acc: 0.7733
# Epoch: 68 | train_loss: 0.0911 | train_acc: 0.9756 | test_loss: 1.0415 | test_acc: 0.7625
# Epoch: 69 | train_loss: 0.0834 | train_acc: 0.9801 | test_loss: 0.9260 | test_acc: 0.7718
# Epoch: 70 | train_loss: 0.0591 | train_acc: 0.9865 | test_loss: 0.9766 | test_acc: 0.7719
# Epoch: 71 | train_loss: 0.1178 | train_acc: 0.9658 | test_loss: 1.0834 | test_acc: 0.7508
# Epoch: 72 | train_loss: 0.1040 | train_acc: 0.9711 | test_loss: 1.0080 | test_acc: 0.7700
# Epoch: 73 | train_loss: 0.1045 | train_acc: 0.9731 | test_loss: 0.9418 | test_acc: 0.7640
# Epoch: 74 | train_loss: 0.0775 | train_acc: 0.9778 | test_loss: 1.0189 | test_acc: 0.7613
# Epoch: 75 | train_loss: 0.1032 | train_acc: 0.9694 | test_loss: 0.9583 | test_acc: 0.7671
# Epoch: 76 | train_loss: 0.0614 | train_acc: 0.9870 | test_loss: 0.9255 | test_acc: 0.7794
# Epoch: 77 | train_loss: 0.0486 | train_acc: 0.9907 | test_loss: 0.9980 | test_acc: 0.7773
# Epoch: 78 | train_loss: 0.1058 | train_acc: 0.9712 | test_loss: 0.9616 | test_acc: 0.7691
# Epoch: 79 | train_loss: 0.0876 | train_acc: 0.9766 | test_loss: 0.9632 | test_acc: 0.7817
# Epoch: 80 | train_loss: 0.0515 | train_acc: 0.9886 | test_loss: 0.9665 | test_acc: 0.7774
# Epoch: 81 | train_loss: 0.0434 | train_acc: 0.9915 | test_loss: 1.0206 | test_acc: 0.7746
# Epoch: 82 | train_loss: 0.0376 | train_acc: 0.9932 | test_loss: 1.0022 | test_acc: 0.7831
# Epoch: 83 | train_loss: 0.1096 | train_acc: 0.9699 | test_loss: 1.0475 | test_acc: 0.7703
# Epoch: 84 | train_loss: 0.1004 | train_acc: 0.9714 | test_loss: 0.9460 | test_acc: 0.7744
# Epoch: 85 | train_loss: 0.0479 | train_acc: 0.9909 | test_loss: 0.9444 | test_acc: 0.7838
# Epoch: 86 | train_loss: 0.0367 | train_acc: 0.9928 | test_loss: 0.9775 | test_acc: 0.7859
# Epoch: 87 | train_loss: 0.0333 | train_acc: 0.9943 | test_loss: 1.0145 | test_acc: 0.7846
# Epoch: 88 | train_loss: 0.0296 | train_acc: 0.9945 | test_loss: 1.0285 | test_acc: 0.7859
# Epoch: 89 | train_loss: 0.0956 | train_acc: 0.9734 | test_loss: 0.9974 | test_acc: 0.7780
# Epoch: 90 | train_loss: 0.0626 | train_acc: 0.9823 | test_loss: 1.0263 | test_acc: 0.7770
# Epoch: 91 | train_loss: 0.0997 | train_acc: 0.9735 | test_loss: 0.9467 | test_acc: 0.7775
# Epoch: 92 | train_loss: 0.0563 | train_acc: 0.9860 | test_loss: 1.0071 | test_acc: 0.7691
# Epoch: 93 | train_loss: 0.0320 | train_acc: 0.9950 | test_loss: 0.9927 | test_acc: 0.7847
# Epoch: 94 | train_loss: 0.0267 | train_acc: 0.9957 | test_loss: 1.0114 | test_acc: 0.7886
# Epoch: 95 | train_loss: 0.0258 | train_acc: 0.9947 | test_loss: 1.0245 | test_acc: 0.7860
# Epoch: 96 | train_loss: 0.0237 | train_acc: 0.9957 | test_loss: 1.0723 | test_acc: 0.7873
# Epoch: 97 | train_loss: 0.0304 | train_acc: 0.9935 | test_loss: 1.2409 | test_acc: 0.7638
# Epoch: 98 | train_loss: 0.1789 | train_acc: 0.9503 | test_loss: 1.1691 | test_acc: 0.7525
# Epoch: 99 | train_loss: 0.0972 | train_acc: 0.9716 | test_loss: 1.0189 | test_acc: 0.7736
# Epoch: 100 | train_loss: 0.0496 | train_acc: 0.9870 | test_loss: 0.9525 | test_acc: 0.7952
# Total training time: 73.789 seconds

# %%
# Plotting the results of model_3
plot_loss_curves(model_3_results, Save=True, filename="model_3_training")

# %% [markdown]
# The GRU model appears to have as similar behaviour to this of the LSTM. It performs better than the RNN, but a small overfitting appears to start occuring after the 10th epoch. As mentioned before, there are ways to deal with this problem. However up to this point it performs better than the RNN and even better than the LSTM as we see the accuracy reaching a number above 70%.

# %% [markdown]
# ## 9. Using Data Augmentation
#
# For our next models we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.
#
# We are going to train an RNN with only the last hidden state, an LSTM and a GRU model.

# %% [markdown]
# ### 7.1 Implementing `TimeMasking()` and `FrequencyMasking()` on the data
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and MFCCs respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
#
# > The `TimeMasking()` transform, "masks" the entire x-axis for a specific amount. A good option would be to mask 15% of the sample. The *time_mask_param* is responsible for the amount of time frames that will be masked. We are calculating this value and setting it in the `TimeMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__: Our x-axis is the time frames and we know that each sample has 130 time frames. We are going to mask 20 frames which is approximately 15% of the sample. This is done by setting the *time_mask_param* to 20. That means that maximum 20 consecutive frames will be masked.
#
# > The `FrequencyMasking()` transform, "masks" the entire y-axis for a specific amount. A good option would be to mask 12% of the sample. The *freq_mask_param* is responsible for the amount of coefficients that will be masked. We are calculating this value and setting it in the `FrequencyMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__:Our y-axis is the MFCCs and we know that each sample has 13 coefficients. We are going to mask 2 coefficients which is approximately 12% of the sample. This is done by setting the *freq_mask_param* to 2. That means that maximum 2 consecutive frames will be masked.
#
# The masked spectrogram are presented, to have a visualization of the augmented data. Similar methods of masking on log mel spectrogram directly are mentioned in the SpecAugment paper. More info here - https://arxiv.org/pdf/1904.08779
#
# _**Notice**: The time_mask_param and freq_mask_param will set the **maximum** amount of time_frames/mfccs that will be masked. This number will be random on each epoch._

# %% [markdown]
# In the case of our recurrent models, we have to take notice of the fact that the shape of our audio representations is "inverted". This means that according to our tensor shape which is `(time_frames, mfccs)`, the x-axis corresponds to the time frames and the y-axis corresponds to the MFCCs. However, the `TimeMasking()` and `FrequencyMasking()` methods expect the opposite. In order to make up for this difference, we write:
# ```
# time_mask_param = round(mfccs * 0.15)
# freq_mask_param = round(time_frames * 0.12)
# ```
# In this manner, we include the number of `mfccs` in the calculation of the `time_mask_param`, as well as the number of `time_frames` in the calculation of the `freq_mask_param`.

# %%
# Calculating the proper time_mask_param and freq_mask_param values
mfccs = inputs.shape[2]
time_frames = inputs.shape[1]

# In the case of RNNs, the shape is "reversed"
# instead of (mfcc, time_frame), we have (time_frame, mfcc).
# As a result, the "time_mask_param" of the masking augmentation will correspond to the mfccs
# and the "freq_mask_param" will correspond to the "time_frames"
time_mask_param = round(mfccs * 0.15)
freq_mask_param = round(time_frames * 0.12)

time_mask_param, freq_mask_param
# Out:
# (2, 16)

# %%
# Creating time masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
time_masking = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
time_masked_data = time_masking(X[INDEX].squeeze()).to('cpu')
time_masked_data.shape
# Out:
# torch.Size([130, 13])

# %%
# Creating frequency masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
freq_masking = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
freq_masked_data = freq_masking(X[INDEX].squeeze()).to('cpu')
freq_masked_data.shape
# Out:
# torch.Size([130, 13])

# %%
# Visualize data
time_masked_melspec_example = time_masked_data.numpy()
freq_masked_melspec_example = freq_masked_data.numpy()

fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharex=True, sharey=True)
im0 = axes[0].imshow(time_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[0].set_title("Frequency-masked MFCCs")
axes[0].set_ylabel("MFCCs")
fig.colorbar(im0, ax=axes[0])

im1 = axes[1].imshow(freq_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[1].set_title("Time-masked MFCCs")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("MFCCs")
fig.colorbar(im1, ax=axes[1])

fig.tight_layout()
plt.show()

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=time_mask_param),
    T.FrequencyMasking(freq_mask_param=freq_mask_param)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
     ):

    # Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
        ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ### 9.2 Training the RNN model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_4 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating RNN model from paper
# model_4 = RNNClassifierV2().to(device)
model_4
# Out:
# RNNClassifierV0(
#   (rnn): RNN(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_4.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in RNN from paper
# optimizer = torch.optim.Adam(model_4.parameters(),
#                              lr=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_4_results = train_with_augmentation(model=model_4,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0420 | train_acc: 0.2750 | test_loss: 1.8563 | test_acc: 0.3265
# Epoch: 2 | train_loss: 1.8196 | train_acc: 0.3489 | test_loss: 1.7359 | test_acc: 0.3785
# Epoch: 3 | train_loss: 1.7307 | train_acc: 0.3777 | test_loss: 1.6665 | test_acc: 0.4150
# Epoch: 4 | train_loss: 1.6636 | train_acc: 0.4064 | test_loss: 1.6266 | test_acc: 0.4032
# Epoch: 5 | train_loss: 1.6067 | train_acc: 0.4338 | test_loss: 1.5722 | test_acc: 0.4457
# Epoch: 6 | train_loss: 1.5871 | train_acc: 0.4340 | test_loss: 1.5628 | test_acc: 0.4442
# Epoch: 7 | train_loss: 1.5296 | train_acc: 0.4548 | test_loss: 1.4966 | test_acc: 0.4596
# Epoch: 8 | train_loss: 1.5112 | train_acc: 0.4623 | test_loss: 1.4791 | test_acc: 0.4595
# Epoch: 9 | train_loss: 1.5020 | train_acc: 0.4662 | test_loss: 1.4666 | test_acc: 0.4821
# Epoch: 10 | train_loss: 1.4701 | train_acc: 0.4730 | test_loss: 1.4841 | test_acc: 0.4684
# Epoch: 11 | train_loss: 1.4337 | train_acc: 0.4843 | test_loss: 1.4359 | test_acc: 0.4798
# Epoch: 12 | train_loss: 1.4264 | train_acc: 0.4921 | test_loss: 1.4228 | test_acc: 0.4885
# Epoch: 13 | train_loss: 1.3845 | train_acc: 0.5094 | test_loss: 1.3796 | test_acc: 0.4983
# Epoch: 14 | train_loss: 1.3836 | train_acc: 0.5080 | test_loss: 1.4575 | test_acc: 0.4758
# Epoch: 15 | train_loss: 1.4563 | train_acc: 0.4837 | test_loss: 1.4077 | test_acc: 0.4819
# Epoch: 16 | train_loss: 1.3766 | train_acc: 0.5114 | test_loss: 1.3456 | test_acc: 0.5071
# Epoch: 17 | train_loss: 1.3316 | train_acc: 0.5289 | test_loss: 1.3498 | test_acc: 0.5075
# Epoch: 18 | train_loss: 1.4221 | train_acc: 0.4986 | test_loss: 1.3450 | test_acc: 0.5084
# Epoch: 19 | train_loss: 1.3358 | train_acc: 0.5253 | test_loss: 1.3241 | test_acc: 0.5159
# Epoch: 20 | train_loss: 1.3291 | train_acc: 0.5335 | test_loss: 1.3820 | test_acc: 0.5090
# Epoch: 21 | train_loss: 1.3419 | train_acc: 0.5296 | test_loss: 1.3339 | test_acc: 0.5209
# Epoch: 22 | train_loss: 1.3187 | train_acc: 0.5349 | test_loss: 1.3426 | test_acc: 0.5122
# Epoch: 23 | train_loss: 1.3133 | train_acc: 0.5379 | test_loss: 1.3352 | test_acc: 0.5078
# Epoch: 24 | train_loss: 1.5264 | train_acc: 0.4677 | test_loss: 1.6203 | test_acc: 0.3996
# Epoch: 25 | train_loss: 1.6097 | train_acc: 0.4406 | test_loss: 1.5070 | test_acc: 0.4533
# Epoch: 26 | train_loss: 1.4798 | train_acc: 0.4832 | test_loss: 1.4266 | test_acc: 0.4866
# Epoch: 27 | train_loss: 1.4171 | train_acc: 0.5058 | test_loss: 1.4324 | test_acc: 0.4854
# Epoch: 28 | train_loss: 1.5125 | train_acc: 0.4610 | test_loss: 1.4233 | test_acc: 0.4899
# Epoch: 29 | train_loss: 1.3802 | train_acc: 0.5174 | test_loss: 1.3735 | test_acc: 0.5172
# Epoch: 30 | train_loss: 1.3665 | train_acc: 0.5135 | test_loss: 1.4120 | test_acc: 0.4836
# Epoch: 31 | train_loss: 1.3781 | train_acc: 0.5209 | test_loss: 1.3457 | test_acc: 0.5225
# Epoch: 32 | train_loss: 1.3329 | train_acc: 0.5291 | test_loss: 1.3731 | test_acc: 0.5118
# Epoch: 33 | train_loss: 1.3452 | train_acc: 0.5315 | test_loss: 1.3347 | test_acc: 0.5222
# Epoch: 34 | train_loss: 1.3017 | train_acc: 0.5382 | test_loss: 1.3030 | test_acc: 0.5375
# Epoch: 35 | train_loss: 1.2969 | train_acc: 0.5441 | test_loss: 1.3187 | test_acc: 0.5379
# Epoch: 36 | train_loss: 1.2942 | train_acc: 0.5459 | test_loss: 1.3243 | test_acc: 0.5291
# Epoch: 37 | train_loss: 1.3549 | train_acc: 0.5310 | test_loss: 1.3111 | test_acc: 0.5389
# Epoch: 38 | train_loss: 1.2622 | train_acc: 0.5577 | test_loss: 1.2860 | test_acc: 0.5406
# Epoch: 39 | train_loss: 1.3891 | train_acc: 0.5176 | test_loss: 1.5236 | test_acc: 0.4732
# Epoch: 40 | train_loss: 1.4258 | train_acc: 0.5054 | test_loss: 1.4089 | test_acc: 0.5037
# Epoch: 41 | train_loss: 1.3960 | train_acc: 0.5191 | test_loss: 1.5231 | test_acc: 0.4736
# Epoch: 42 | train_loss: 1.3688 | train_acc: 0.5212 | test_loss: 1.3587 | test_acc: 0.5179
# Epoch: 43 | train_loss: 1.3086 | train_acc: 0.5478 | test_loss: 1.3366 | test_acc: 0.5336
# Epoch: 44 | train_loss: 1.2919 | train_acc: 0.5542 | test_loss: 1.2966 | test_acc: 0.5485
# Epoch: 45 | train_loss: 1.2531 | train_acc: 0.5673 | test_loss: 1.2937 | test_acc: 0.5397
# Epoch: 46 | train_loss: 1.2740 | train_acc: 0.5507 | test_loss: 1.3270 | test_acc: 0.5337
# Epoch: 47 | train_loss: 1.2081 | train_acc: 0.5791 | test_loss: 1.2576 | test_acc: 0.5545
# Epoch: 48 | train_loss: 1.2210 | train_acc: 0.5673 | test_loss: 1.2542 | test_acc: 0.5456
# Epoch: 49 | train_loss: 1.2537 | train_acc: 0.5640 | test_loss: 1.2937 | test_acc: 0.5424
# Epoch: 50 | train_loss: 1.2352 | train_acc: 0.5671 | test_loss: 1.2360 | test_acc: 0.5609
# Epoch: 51 | train_loss: 1.2099 | train_acc: 0.5750 | test_loss: 1.4380 | test_acc: 0.4856
# Epoch: 52 | train_loss: 1.2583 | train_acc: 0.5537 | test_loss: 1.2337 | test_acc: 0.5588
# Epoch: 53 | train_loss: 1.2204 | train_acc: 0.5689 | test_loss: 1.2366 | test_acc: 0.5642
# Epoch: 54 | train_loss: 1.1995 | train_acc: 0.5765 | test_loss: 1.2283 | test_acc: 0.5663
# Epoch: 55 | train_loss: 1.1655 | train_acc: 0.5869 | test_loss: 1.2132 | test_acc: 0.5710
# Epoch: 56 | train_loss: 1.1896 | train_acc: 0.5848 | test_loss: 1.2251 | test_acc: 0.5550
# Epoch: 57 | train_loss: 1.1761 | train_acc: 0.5875 | test_loss: 1.3610 | test_acc: 0.5325
# Epoch: 58 | train_loss: 1.2323 | train_acc: 0.5717 | test_loss: 1.3238 | test_acc: 0.5296
# Epoch: 59 | train_loss: 1.3370 | train_acc: 0.5324 | test_loss: 1.3784 | test_acc: 0.5114
# Epoch: 60 | train_loss: 1.2179 | train_acc: 0.5684 | test_loss: 1.2329 | test_acc: 0.5537
# Epoch: 61 | train_loss: 1.1727 | train_acc: 0.5908 | test_loss: 1.2143 | test_acc: 0.5664
# Epoch: 62 | train_loss: 1.2202 | train_acc: 0.5715 | test_loss: 1.4321 | test_acc: 0.5069
# Epoch: 63 | train_loss: 1.2058 | train_acc: 0.5787 | test_loss: 1.2093 | test_acc: 0.5690
# Epoch: 64 | train_loss: 1.1509 | train_acc: 0.5930 | test_loss: 1.1774 | test_acc: 0.5756
# Epoch: 65 | train_loss: 1.2566 | train_acc: 0.5634 | test_loss: 1.2484 | test_acc: 0.5502
# Epoch: 66 | train_loss: 1.2315 | train_acc: 0.5629 | test_loss: 1.2302 | test_acc: 0.5580
# Epoch: 67 | train_loss: 1.2102 | train_acc: 0.5820 | test_loss: 1.2303 | test_acc: 0.5710
# Epoch: 68 | train_loss: 1.1978 | train_acc: 0.5835 | test_loss: 1.3704 | test_acc: 0.5098
# Epoch: 69 | train_loss: 1.2715 | train_acc: 0.5585 | test_loss: 1.6267 | test_acc: 0.4450
# Epoch: 70 | train_loss: 1.3276 | train_acc: 0.5284 | test_loss: 1.2818 | test_acc: 0.5529
# Epoch: 71 | train_loss: 1.2256 | train_acc: 0.5786 | test_loss: 1.2650 | test_acc: 0.5528
# Epoch: 72 | train_loss: 1.2136 | train_acc: 0.5763 | test_loss: 1.2446 | test_acc: 0.5623
# Epoch: 73 | train_loss: 1.2329 | train_acc: 0.5762 | test_loss: 1.6516 | test_acc: 0.4608
# Epoch: 74 | train_loss: 1.2751 | train_acc: 0.5591 | test_loss: 1.4633 | test_acc: 0.4903
# Epoch: 75 | train_loss: 1.1840 | train_acc: 0.5892 | test_loss: 1.3116 | test_acc: 0.5564
# Epoch: 76 | train_loss: 1.1643 | train_acc: 0.5937 | test_loss: 1.1802 | test_acc: 0.5849
# Epoch: 77 | train_loss: 1.1318 | train_acc: 0.6030 | test_loss: 1.2300 | test_acc: 0.5671
# Epoch: 78 | train_loss: 1.1635 | train_acc: 0.5902 | test_loss: 1.3004 | test_acc: 0.5736
# Epoch: 79 | train_loss: 1.1187 | train_acc: 0.6078 | test_loss: 1.1475 | test_acc: 0.5903
# Epoch: 80 | train_loss: 1.3664 | train_acc: 0.5273 | test_loss: 1.4742 | test_acc: 0.4938
# Epoch: 81 | train_loss: 1.3263 | train_acc: 0.5308 | test_loss: 1.2936 | test_acc: 0.5387
# Epoch: 82 | train_loss: 1.2574 | train_acc: 0.5619 | test_loss: 1.2842 | test_acc: 0.5404
# Epoch: 83 | train_loss: 1.3170 | train_acc: 0.5365 | test_loss: 1.2741 | test_acc: 0.5496
# Epoch: 84 | train_loss: 1.1997 | train_acc: 0.5799 | test_loss: 1.2449 | test_acc: 0.5649
# Epoch: 85 | train_loss: 1.1580 | train_acc: 0.5972 | test_loss: 1.2225 | test_acc: 0.5622
# Epoch: 86 | train_loss: 1.3332 | train_acc: 0.5428 | test_loss: 1.3090 | test_acc: 0.5384
# Epoch: 87 | train_loss: 1.2041 | train_acc: 0.5836 | test_loss: 1.2773 | test_acc: 0.5569
# Epoch: 88 | train_loss: 1.2925 | train_acc: 0.5396 | test_loss: 1.2805 | test_acc: 0.5557
# Epoch: 89 | train_loss: 1.1854 | train_acc: 0.5853 | test_loss: 1.2538 | test_acc: 0.5529
# Epoch: 90 | train_loss: 1.1577 | train_acc: 0.5830 | test_loss: 1.2084 | test_acc: 0.5698
# Epoch: 91 | train_loss: 1.1287 | train_acc: 0.6008 | test_loss: 1.1887 | test_acc: 0.5803
# Epoch: 92 | train_loss: 1.1174 | train_acc: 0.6096 | test_loss: 1.2352 | test_acc: 0.5716
# Epoch: 93 | train_loss: 1.0956 | train_acc: 0.6137 | test_loss: 1.1419 | test_acc: 0.5975
# Epoch: 94 | train_loss: 1.0729 | train_acc: 0.6170 | test_loss: 1.3053 | test_acc: 0.5456
# Epoch: 95 | train_loss: 1.1240 | train_acc: 0.6034 | test_loss: 1.1656 | test_acc: 0.5916
# Epoch: 96 | train_loss: 1.0955 | train_acc: 0.6169 | test_loss: 1.1949 | test_acc: 0.5754
# Epoch: 97 | train_loss: 1.0756 | train_acc: 0.6227 | test_loss: 1.1637 | test_acc: 0.5767
# Epoch: 98 | train_loss: 1.1048 | train_acc: 0.6112 | test_loss: 1.1683 | test_acc: 0.5881
# Epoch: 99 | train_loss: 1.1075 | train_acc: 0.6071 | test_loss: 1.1406 | test_acc: 0.5976
# Epoch: 100 | train_loss: 1.0803 | train_acc: 0.6246 | test_loss: 1.1498 | test_acc: 0.5916
# Epoch: 101 | train_loss: 1.0677 | train_acc: 0.6382 | test_loss: 1.1695 | test_acc: 0.5949
# Epoch: 102 | train_loss: 1.1933 | train_acc: 0.5911 | test_loss: 1.4150 | test_acc: 0.5090
# Epoch: 103 | train_loss: 1.2196 | train_acc: 0.5727 | test_loss: 1.1694 | test_acc: 0.5881
# Epoch: 104 | train_loss: 1.2092 | train_acc: 0.5869 | test_loss: 1.5468 | test_acc: 0.4322
# Epoch: 105 | train_loss: 1.3162 | train_acc: 0.5329 | test_loss: 1.2521 | test_acc: 0.5550
# Epoch: 106 | train_loss: 1.2002 | train_acc: 0.5839 | test_loss: 1.2117 | test_acc: 0.5648
# Epoch: 107 | train_loss: 1.1523 | train_acc: 0.5963 | test_loss: 1.1996 | test_acc: 0.5768
# Epoch: 108 | train_loss: 1.1254 | train_acc: 0.6067 | test_loss: 1.1508 | test_acc: 0.5823
# Epoch: 109 | train_loss: 1.1016 | train_acc: 0.6162 | test_loss: 1.1946 | test_acc: 0.5736
# Epoch: 110 | train_loss: 1.0826 | train_acc: 0.6207 | test_loss: 1.1420 | test_acc: 0.5868
# Epoch: 111 | train_loss: 1.0795 | train_acc: 0.6239 | test_loss: 1.1569 | test_acc: 0.5908
# Epoch: 112 | train_loss: 1.0579 | train_acc: 0.6326 | test_loss: 1.1358 | test_acc: 0.5916
# Epoch: 113 | train_loss: 1.0536 | train_acc: 0.6412 | test_loss: 1.1082 | test_acc: 0.6115
# Epoch: 114 | train_loss: 1.0383 | train_acc: 0.6402 | test_loss: 1.1782 | test_acc: 0.5902
# Epoch: 115 | train_loss: 1.4008 | train_acc: 0.5194 | test_loss: 1.2496 | test_acc: 0.5645
# Epoch: 116 | train_loss: 1.1234 | train_acc: 0.6107 | test_loss: 1.1654 | test_acc: 0.5923
# Epoch: 117 | train_loss: 1.0950 | train_acc: 0.6206 | test_loss: 1.1610 | test_acc: 0.5928
# Epoch: 118 | train_loss: 1.2987 | train_acc: 0.5628 | test_loss: 1.4400 | test_acc: 0.4930
# Epoch: 119 | train_loss: 1.2705 | train_acc: 0.5617 | test_loss: 1.2378 | test_acc: 0.5524
# Epoch: 120 | train_loss: 1.4383 | train_acc: 0.5139 | test_loss: 1.3491 | test_acc: 0.5138
# Epoch: 121 | train_loss: 1.2399 | train_acc: 0.5660 | test_loss: 1.2772 | test_acc: 0.5550
# Epoch: 122 | train_loss: 1.1523 | train_acc: 0.6032 | test_loss: 1.1942 | test_acc: 0.5857
# Epoch: 123 | train_loss: 1.1038 | train_acc: 0.6230 | test_loss: 1.2985 | test_acc: 0.5564
# Epoch: 124 | train_loss: 1.1355 | train_acc: 0.6008 | test_loss: 1.1909 | test_acc: 0.5885
# Epoch: 125 | train_loss: 1.0744 | train_acc: 0.6250 | test_loss: 1.1355 | test_acc: 0.6050
# Epoch: 126 | train_loss: 1.3658 | train_acc: 0.5634 | test_loss: 1.4623 | test_acc: 0.5070
# Epoch: 127 | train_loss: 1.2555 | train_acc: 0.5705 | test_loss: 1.2737 | test_acc: 0.5549
# Epoch: 128 | train_loss: 1.1512 | train_acc: 0.6031 | test_loss: 1.1933 | test_acc: 0.5929
# Epoch: 129 | train_loss: 1.0701 | train_acc: 0.6267 | test_loss: 1.1312 | test_acc: 0.6015
# Epoch: 130 | train_loss: 1.0778 | train_acc: 0.6293 | test_loss: 1.3244 | test_acc: 0.5782
# Epoch: 131 | train_loss: 1.0818 | train_acc: 0.6297 | test_loss: 1.1028 | test_acc: 0.6137
# Epoch: 132 | train_loss: 1.0730 | train_acc: 0.6314 | test_loss: 1.1318 | test_acc: 0.6035
# Epoch: 133 | train_loss: 1.0695 | train_acc: 0.6333 | test_loss: 1.1206 | test_acc: 0.5990
# Epoch: 134 | train_loss: 1.3516 | train_acc: 0.5395 | test_loss: 1.5147 | test_acc: 0.4726
# Epoch: 135 | train_loss: 1.3220 | train_acc: 0.5327 | test_loss: 1.2823 | test_acc: 0.5409
# Epoch: 136 | train_loss: 1.2120 | train_acc: 0.5820 | test_loss: 1.2175 | test_acc: 0.5748
# Epoch: 137 | train_loss: 1.1534 | train_acc: 0.5974 | test_loss: 1.1935 | test_acc: 0.5802
# Epoch: 138 | train_loss: 1.1451 | train_acc: 0.5933 | test_loss: 1.1590 | test_acc: 0.5902
# Epoch: 139 | train_loss: 1.1353 | train_acc: 0.6004 | test_loss: 1.2833 | test_acc: 0.5427
# Epoch: 140 | train_loss: 1.1289 | train_acc: 0.5967 | test_loss: 1.1653 | test_acc: 0.5860
# Epoch: 141 | train_loss: 1.1028 | train_acc: 0.6128 | test_loss: 1.1346 | test_acc: 0.5994
# Epoch: 142 | train_loss: 1.0370 | train_acc: 0.6370 | test_loss: 1.1251 | test_acc: 0.6004
# Epoch: 143 | train_loss: 1.1147 | train_acc: 0.6072 | test_loss: 1.2451 | test_acc: 0.5664
# Epoch: 144 | train_loss: 1.1500 | train_acc: 0.6146 | test_loss: 1.2287 | test_acc: 0.5801
# Epoch: 145 | train_loss: 1.1330 | train_acc: 0.5964 | test_loss: 1.2735 | test_acc: 0.5362
# Epoch: 146 | train_loss: 1.2172 | train_acc: 0.5702 | test_loss: 1.1412 | test_acc: 0.6015
# Epoch: 147 | train_loss: 1.0359 | train_acc: 0.6399 | test_loss: 1.1186 | test_acc: 0.6048
# Epoch: 148 | train_loss: 1.0344 | train_acc: 0.6427 | test_loss: 1.0960 | test_acc: 0.5981
# Epoch: 149 | train_loss: 1.0214 | train_acc: 0.6453 | test_loss: 1.1051 | test_acc: 0.6128
# Epoch: 150 | train_loss: 0.9999 | train_acc: 0.6544 | test_loss: 1.1047 | test_acc: 0.6255
# Epoch: 151 | train_loss: 1.0899 | train_acc: 0.6294 | test_loss: 1.1475 | test_acc: 0.5762
# Epoch: 152 | train_loss: 1.0301 | train_acc: 0.6497 | test_loss: 1.1054 | test_acc: 0.6070
# Epoch: 153 | train_loss: 1.0675 | train_acc: 0.6353 | test_loss: 1.2584 | test_acc: 0.5604
# Epoch: 154 | train_loss: 1.1240 | train_acc: 0.6189 | test_loss: 1.1820 | test_acc: 0.5970
# Epoch: 155 | train_loss: 1.1863 | train_acc: 0.5872 | test_loss: 1.1494 | test_acc: 0.6010
# Epoch: 156 | train_loss: 0.9842 | train_acc: 0.6586 | test_loss: 1.0822 | test_acc: 0.6315
# Epoch: 157 | train_loss: 1.0598 | train_acc: 0.6326 | test_loss: 1.1197 | test_acc: 0.6088
# Epoch: 158 | train_loss: 1.3113 | train_acc: 0.5569 | test_loss: 1.4548 | test_acc: 0.4789
# Epoch: 159 | train_loss: 1.2078 | train_acc: 0.5802 | test_loss: 1.1650 | test_acc: 0.5948
# Epoch: 160 | train_loss: 1.2325 | train_acc: 0.5700 | test_loss: 1.3912 | test_acc: 0.5141
# Epoch: 161 | train_loss: 1.2640 | train_acc: 0.5596 | test_loss: 1.2552 | test_acc: 0.5627
# Epoch: 162 | train_loss: 1.2076 | train_acc: 0.5821 | test_loss: 1.3153 | test_acc: 0.5494
# Epoch: 163 | train_loss: 1.2099 | train_acc: 0.5776 | test_loss: 1.1974 | test_acc: 0.5887
# Epoch: 164 | train_loss: 1.1163 | train_acc: 0.6141 | test_loss: 1.1690 | test_acc: 0.5981
# Epoch: 165 | train_loss: 1.0959 | train_acc: 0.6225 | test_loss: 1.2109 | test_acc: 0.5788
# Epoch: 166 | train_loss: 1.0840 | train_acc: 0.6253 | test_loss: 1.1514 | test_acc: 0.6016
# Epoch: 167 | train_loss: 1.3021 | train_acc: 0.5449 | test_loss: 1.2668 | test_acc: 0.5769
# Epoch: 168 | train_loss: 1.4656 | train_acc: 0.5077 | test_loss: 1.7467 | test_acc: 0.3742
# Epoch: 169 | train_loss: 1.4284 | train_acc: 0.4936 | test_loss: 1.3854 | test_acc: 0.5039
# Epoch: 170 | train_loss: 1.2854 | train_acc: 0.5495 | test_loss: 1.2881 | test_acc: 0.5555
# Epoch: 171 | train_loss: 1.1675 | train_acc: 0.5966 | test_loss: 1.2123 | test_acc: 0.5868
# Epoch: 172 | train_loss: 1.1312 | train_acc: 0.6087 | test_loss: 1.1878 | test_acc: 0.5888
# Epoch: 173 | train_loss: 1.1732 | train_acc: 0.5999 | test_loss: 1.1657 | test_acc: 0.5975
# Epoch: 174 | train_loss: 1.0825 | train_acc: 0.6278 | test_loss: 1.1481 | test_acc: 0.6183
# Epoch: 175 | train_loss: 1.1827 | train_acc: 0.5933 | test_loss: 1.2520 | test_acc: 0.5621
# Epoch: 176 | train_loss: 1.1780 | train_acc: 0.6006 | test_loss: 1.2756 | test_acc: 0.5537
# Epoch: 177 | train_loss: 1.1093 | train_acc: 0.6201 | test_loss: 1.1509 | test_acc: 0.6000
# Epoch: 178 | train_loss: 1.0789 | train_acc: 0.6289 | test_loss: 1.1544 | test_acc: 0.6090
# Epoch: 179 | train_loss: 1.0634 | train_acc: 0.6319 | test_loss: 1.2092 | test_acc: 0.5789
# Epoch: 180 | train_loss: 1.0686 | train_acc: 0.6349 | test_loss: 1.1275 | test_acc: 0.6123
# Epoch: 181 | train_loss: 1.0145 | train_acc: 0.6496 | test_loss: 1.1071 | test_acc: 0.6157
# Epoch: 182 | train_loss: 1.0124 | train_acc: 0.6497 | test_loss: 1.1164 | test_acc: 0.6182
# Epoch: 183 | train_loss: 1.0043 | train_acc: 0.6635 | test_loss: 1.1073 | test_acc: 0.6184
# Epoch: 184 | train_loss: 1.0427 | train_acc: 0.6445 | test_loss: 1.1367 | test_acc: 0.6096
# Epoch: 185 | train_loss: 1.0291 | train_acc: 0.6509 | test_loss: 1.1049 | test_acc: 0.6142
# Epoch: 186 | train_loss: 1.0169 | train_acc: 0.6586 | test_loss: 1.1675 | test_acc: 0.6056
# Epoch: 187 | train_loss: 1.0400 | train_acc: 0.6403 | test_loss: 1.2259 | test_acc: 0.5859
# Epoch: 188 | train_loss: 1.1130 | train_acc: 0.6169 | test_loss: 2.1315 | test_acc: 0.3619
# Epoch: 189 | train_loss: 1.3832 | train_acc: 0.5236 | test_loss: 1.2246 | test_acc: 0.5675
# Epoch: 190 | train_loss: 1.1514 | train_acc: 0.6017 | test_loss: 1.1723 | test_acc: 0.6012
# Epoch: 191 | train_loss: 1.0442 | train_acc: 0.6366 | test_loss: 1.3315 | test_acc: 0.5128
# Epoch: 192 | train_loss: 1.0924 | train_acc: 0.6186 | test_loss: 1.1033 | test_acc: 0.6229
# Epoch: 193 | train_loss: 1.0542 | train_acc: 0.6368 | test_loss: 1.1199 | test_acc: 0.6089
# Epoch: 194 | train_loss: 1.1873 | train_acc: 0.5997 | test_loss: 1.3504 | test_acc: 0.5284
# Epoch: 195 | train_loss: 1.1459 | train_acc: 0.6051 | test_loss: 1.1521 | test_acc: 0.6016
# Epoch: 196 | train_loss: 1.1242 | train_acc: 0.6063 | test_loss: 1.1500 | test_acc: 0.6014
# Epoch: 197 | train_loss: 1.1666 | train_acc: 0.6083 | test_loss: 1.2316 | test_acc: 0.5650
# Epoch: 198 | train_loss: 1.0846 | train_acc: 0.6306 | test_loss: 1.1348 | test_acc: 0.6090
# Epoch: 199 | train_loss: 1.0109 | train_acc: 0.6518 | test_loss: 1.1413 | test_acc: 0.6050
# Epoch: 200 | train_loss: 1.0568 | train_acc: 0.6405 | test_loss: 1.1257 | test_acc: 0.6104
# Epoch: 201 | train_loss: 1.0532 | train_acc: 0.6387 | test_loss: 1.0907 | test_acc: 0.6258
# Epoch: 202 | train_loss: 1.0214 | train_acc: 0.6480 | test_loss: 1.0939 | test_acc: 0.6216
# Epoch: 203 | train_loss: 1.3935 | train_acc: 0.5340 | test_loss: 1.3638 | test_acc: 0.5200
# Epoch: 204 | train_loss: 1.2186 | train_acc: 0.5782 | test_loss: 1.2485 | test_acc: 0.5649
# Epoch: 205 | train_loss: 1.1950 | train_acc: 0.5841 | test_loss: 1.2369 | test_acc: 0.5623
# Epoch: 206 | train_loss: 1.1579 | train_acc: 0.5984 | test_loss: 1.2130 | test_acc: 0.5600
# Epoch: 207 | train_loss: 1.1636 | train_acc: 0.5947 | test_loss: 1.2237 | test_acc: 0.5586
# Epoch: 208 | train_loss: 1.1067 | train_acc: 0.6117 | test_loss: 1.2352 | test_acc: 0.5634
# Epoch: 209 | train_loss: 1.1260 | train_acc: 0.6126 | test_loss: 1.4573 | test_acc: 0.4952
# Epoch: 210 | train_loss: 1.2146 | train_acc: 0.5718 | test_loss: 1.2403 | test_acc: 0.5531
# Epoch: 211 | train_loss: 1.1381 | train_acc: 0.5959 | test_loss: 1.2135 | test_acc: 0.5704
# Epoch: 212 | train_loss: 1.0794 | train_acc: 0.6214 | test_loss: 1.2205 | test_acc: 0.5790
# Epoch: 213 | train_loss: 1.0489 | train_acc: 0.6334 | test_loss: 1.1637 | test_acc: 0.5902
# Epoch: 214 | train_loss: 1.0392 | train_acc: 0.6387 | test_loss: 1.2095 | test_acc: 0.5745
# Epoch: 215 | train_loss: 1.0393 | train_acc: 0.6402 | test_loss: 1.1419 | test_acc: 0.5983
# Epoch: 216 | train_loss: 1.0434 | train_acc: 0.6335 | test_loss: 1.1321 | test_acc: 0.5971
# Epoch: 217 | train_loss: 1.0570 | train_acc: 0.6327 | test_loss: 1.1364 | test_acc: 0.5915
# Epoch: 218 | train_loss: 1.0329 | train_acc: 0.6435 | test_loss: 1.1204 | test_acc: 0.6118
# Epoch: 219 | train_loss: 1.0694 | train_acc: 0.6352 | test_loss: 1.1807 | test_acc: 0.5863
# Epoch: 220 | train_loss: 1.0375 | train_acc: 0.6408 | test_loss: 1.1154 | test_acc: 0.6170
# Epoch: 221 | train_loss: 0.9939 | train_acc: 0.6560 | test_loss: 1.1215 | test_acc: 0.6175
# Epoch: 222 | train_loss: 1.1333 | train_acc: 0.6132 | test_loss: 1.2170 | test_acc: 0.5490
# Epoch: 223 | train_loss: 1.0326 | train_acc: 0.6280 | test_loss: 1.2489 | test_acc: 0.5714
# Epoch: 224 | train_loss: 1.0328 | train_acc: 0.6415 | test_loss: 1.1282 | test_acc: 0.6129
# Epoch: 225 | train_loss: 1.1195 | train_acc: 0.6154 | test_loss: 1.5375 | test_acc: 0.4943
# Epoch: 226 | train_loss: 1.1584 | train_acc: 0.6008 | test_loss: 1.1958 | test_acc: 0.5961
# Epoch: 227 | train_loss: 1.0172 | train_acc: 0.6405 | test_loss: 1.1771 | test_acc: 0.5996
# Epoch: 228 | train_loss: 0.9868 | train_acc: 0.6524 | test_loss: 1.1002 | test_acc: 0.6122
# Epoch: 229 | train_loss: 1.2295 | train_acc: 0.5720 | test_loss: 1.3874 | test_acc: 0.5093
# Epoch: 230 | train_loss: 1.1315 | train_acc: 0.6031 | test_loss: 1.1463 | test_acc: 0.5820
# Epoch: 231 | train_loss: 1.0671 | train_acc: 0.6310 | test_loss: 1.1859 | test_acc: 0.5853
# Epoch: 232 | train_loss: 0.9859 | train_acc: 0.6552 | test_loss: 1.1018 | test_acc: 0.6049
# Epoch: 233 | train_loss: 1.0259 | train_acc: 0.6464 | test_loss: 1.1146 | test_acc: 0.6079
# Epoch: 234 | train_loss: 0.9412 | train_acc: 0.6768 | test_loss: 1.0784 | test_acc: 0.6329
# Epoch: 235 | train_loss: 1.1184 | train_acc: 0.6204 | test_loss: 1.1867 | test_acc: 0.5953
# Epoch: 236 | train_loss: 1.0033 | train_acc: 0.6595 | test_loss: 1.0990 | test_acc: 0.6182
# Epoch: 237 | train_loss: 0.9647 | train_acc: 0.6698 | test_loss: 1.0849 | test_acc: 0.6161
# Epoch: 238 | train_loss: 0.9730 | train_acc: 0.6652 | test_loss: 1.0674 | test_acc: 0.6355
# Epoch: 239 | train_loss: 0.9608 | train_acc: 0.6703 | test_loss: 1.0708 | test_acc: 0.6355
# Epoch: 240 | train_loss: 1.0370 | train_acc: 0.6515 | test_loss: 1.1544 | test_acc: 0.6049
# Epoch: 241 | train_loss: 0.9631 | train_acc: 0.6665 | test_loss: 1.7420 | test_acc: 0.4929
# Epoch: 242 | train_loss: 1.2089 | train_acc: 0.6014 | test_loss: 1.1543 | test_acc: 0.6009
# Epoch: 243 | train_loss: 0.9929 | train_acc: 0.6564 | test_loss: 1.1042 | test_acc: 0.6262
# Epoch: 244 | train_loss: 0.9558 | train_acc: 0.6744 | test_loss: 1.0673 | test_acc: 0.6309
# Epoch: 245 | train_loss: 0.9591 | train_acc: 0.6762 | test_loss: 1.0556 | test_acc: 0.6302
# Epoch: 246 | train_loss: 0.9774 | train_acc: 0.6699 | test_loss: 1.1723 | test_acc: 0.5838
# Epoch: 247 | train_loss: 0.9354 | train_acc: 0.6831 | test_loss: 1.0579 | test_acc: 0.6482
# Epoch: 248 | train_loss: 0.9033 | train_acc: 0.6938 | test_loss: 1.0293 | test_acc: 0.6429
# Epoch: 249 | train_loss: 1.0039 | train_acc: 0.6565 | test_loss: 1.0991 | test_acc: 0.6196
# Epoch: 250 | train_loss: 0.9376 | train_acc: 0.6814 | test_loss: 1.1261 | test_acc: 0.5963
# Epoch: 251 | train_loss: 1.0264 | train_acc: 0.6543 | test_loss: 1.1121 | test_acc: 0.6228
# Epoch: 252 | train_loss: 1.0873 | train_acc: 0.6379 | test_loss: 1.2176 | test_acc: 0.5847
# Epoch: 253 | train_loss: 0.9664 | train_acc: 0.6689 | test_loss: 1.0883 | test_acc: 0.6200
# Epoch: 254 | train_loss: 0.9278 | train_acc: 0.6755 | test_loss: 1.1545 | test_acc: 0.6007
# Epoch: 255 | train_loss: 0.9246 | train_acc: 0.6871 | test_loss: 1.0934 | test_acc: 0.6241
# Epoch: 256 | train_loss: 0.9870 | train_acc: 0.6603 | test_loss: 1.0723 | test_acc: 0.6235
# Epoch: 257 | train_loss: 0.9217 | train_acc: 0.6876 | test_loss: 1.0429 | test_acc: 0.6474
# Epoch: 258 | train_loss: 0.9711 | train_acc: 0.6669 | test_loss: 1.1622 | test_acc: 0.5882
# Epoch: 259 | train_loss: 0.9289 | train_acc: 0.6823 | test_loss: 1.0316 | test_acc: 0.6455
# Epoch: 260 | train_loss: 0.9547 | train_acc: 0.6755 | test_loss: 1.0458 | test_acc: 0.6354
# Epoch: 261 | train_loss: 0.9174 | train_acc: 0.6848 | test_loss: 1.0428 | test_acc: 0.6488
# Epoch: 262 | train_loss: 0.9421 | train_acc: 0.6869 | test_loss: 1.0561 | test_acc: 0.6262
# Epoch: 263 | train_loss: 1.3012 | train_acc: 0.5686 | test_loss: 1.6911 | test_acc: 0.4451
# Epoch: 264 | train_loss: 1.3284 | train_acc: 0.5298 | test_loss: 1.3368 | test_acc: 0.5218
# Epoch: 265 | train_loss: 1.1977 | train_acc: 0.5778 | test_loss: 1.2612 | test_acc: 0.5452
# Epoch: 266 | train_loss: 1.1259 | train_acc: 0.5994 | test_loss: 1.2179 | test_acc: 0.5588
# Epoch: 267 | train_loss: 1.0855 | train_acc: 0.6221 | test_loss: 1.1978 | test_acc: 0.5660
# Epoch: 268 | train_loss: 1.0549 | train_acc: 0.6253 | test_loss: 1.2038 | test_acc: 0.5765
# Epoch: 269 | train_loss: 1.0478 | train_acc: 0.6297 | test_loss: 1.1663 | test_acc: 0.5761
# Epoch: 270 | train_loss: 1.0380 | train_acc: 0.6394 | test_loss: 1.1458 | test_acc: 0.5862
# Epoch: 271 | train_loss: 1.0479 | train_acc: 0.6309 | test_loss: 1.1584 | test_acc: 0.5919
# Epoch: 272 | train_loss: 0.9727 | train_acc: 0.6605 | test_loss: 1.1903 | test_acc: 0.5743
# Epoch: 273 | train_loss: 0.9642 | train_acc: 0.6578 | test_loss: 1.1101 | test_acc: 0.6060
# Epoch: 274 | train_loss: 1.0030 | train_acc: 0.6482 | test_loss: 1.1985 | test_acc: 0.5881
# Epoch: 275 | train_loss: 1.0064 | train_acc: 0.6549 | test_loss: 1.1056 | test_acc: 0.6082
# Epoch: 276 | train_loss: 0.9805 | train_acc: 0.6638 | test_loss: 1.1116 | test_acc: 0.6021
# Epoch: 277 | train_loss: 0.9313 | train_acc: 0.6745 | test_loss: 1.0879 | test_acc: 0.6107
# Epoch: 278 | train_loss: 0.9506 | train_acc: 0.6722 | test_loss: 1.0702 | test_acc: 0.6206
# Epoch: 279 | train_loss: 0.9047 | train_acc: 0.6871 | test_loss: 1.0866 | test_acc: 0.6108
# Epoch: 280 | train_loss: 0.9380 | train_acc: 0.6739 | test_loss: 1.1173 | test_acc: 0.5974
# Epoch: 281 | train_loss: 0.9042 | train_acc: 0.6900 | test_loss: 1.1977 | test_acc: 0.5955
# Epoch: 282 | train_loss: 1.0624 | train_acc: 0.6348 | test_loss: 1.1921 | test_acc: 0.5946
# Epoch: 283 | train_loss: 0.9692 | train_acc: 0.6684 | test_loss: 1.1342 | test_acc: 0.6121
# Epoch: 284 | train_loss: 0.9250 | train_acc: 0.6824 | test_loss: 1.1020 | test_acc: 0.6259
# Epoch: 285 | train_loss: 1.0820 | train_acc: 0.6346 | test_loss: 1.2796 | test_acc: 0.5402
# Epoch: 286 | train_loss: 1.0238 | train_acc: 0.6416 | test_loss: 1.1118 | test_acc: 0.6160
# Epoch: 287 | train_loss: 0.9715 | train_acc: 0.6672 | test_loss: 1.0944 | test_acc: 0.6186
# Epoch: 288 | train_loss: 1.0233 | train_acc: 0.6537 | test_loss: 1.1366 | test_acc: 0.6054
# Epoch: 289 | train_loss: 0.9649 | train_acc: 0.6715 | test_loss: 1.1122 | test_acc: 0.6245
# Epoch: 290 | train_loss: 1.0248 | train_acc: 0.6333 | test_loss: 1.1416 | test_acc: 0.6028
# Epoch: 291 | train_loss: 0.9290 | train_acc: 0.6807 | test_loss: 1.0730 | test_acc: 0.6276
# Epoch: 292 | train_loss: 0.9606 | train_acc: 0.6675 | test_loss: 1.0561 | test_acc: 0.6360
# Epoch: 293 | train_loss: 0.9075 | train_acc: 0.6876 | test_loss: 1.0546 | test_acc: 0.6408
# Epoch: 294 | train_loss: 1.1656 | train_acc: 0.5895 | test_loss: 1.2385 | test_acc: 0.5649
# Epoch: 295 | train_loss: 1.0189 | train_acc: 0.6431 | test_loss: 1.1334 | test_acc: 0.5915
# Epoch: 296 | train_loss: 1.0058 | train_acc: 0.6481 | test_loss: 1.1326 | test_acc: 0.5994
# Epoch: 297 | train_loss: 0.9927 | train_acc: 0.6544 | test_loss: 1.1033 | test_acc: 0.6054
# Epoch: 298 | train_loss: 0.9561 | train_acc: 0.6687 | test_loss: 1.1164 | test_acc: 0.6147
# Epoch: 299 | train_loss: 1.0067 | train_acc: 0.6578 | test_loss: 1.2051 | test_acc: 0.5659
# Epoch: 300 | train_loss: 1.0374 | train_acc: 0.6352 | test_loss: 1.1343 | test_acc: 0.6059
# Total training time: 212.202 seconds

# %%
plot_loss_curves(model_4_results, Save=True, filename="model_4_training")

# %% [markdown]
# We see that using data augmentation improves the performance of the model, although some issues still occur.There is no significant overfitting, however after the 150th epoch nothing important is gained.

# %% [markdown]
# ### 9.3 Training the LSTM model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_5 =LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating the LSTM model from paper
# model_5 = LSTMClassifierV1().to(device)
model_5
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_5.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in paper according to the specs there
# optimizer = torch.optim.Adam(model_5.parameters(),
#                              lr=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_5_results = train_with_augmentation(model=model_5,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.1299 | train_acc: 0.2627 | test_loss: 1.8690 | test_acc: 0.3570
# Epoch: 2 | train_loss: 1.7577 | train_acc: 0.3698 | test_loss: 1.6153 | test_acc: 0.4177
# Epoch: 3 | train_loss: 1.5783 | train_acc: 0.4419 | test_loss: 1.4649 | test_acc: 0.4923
# Epoch: 4 | train_loss: 1.5016 | train_acc: 0.4728 | test_loss: 1.3905 | test_acc: 0.5076
# Epoch: 5 | train_loss: 1.4054 | train_acc: 0.5021 | test_loss: 1.3613 | test_acc: 0.5237
# Epoch: 6 | train_loss: 1.3785 | train_acc: 0.5093 | test_loss: 1.3150 | test_acc: 0.5437
# Epoch: 7 | train_loss: 1.3330 | train_acc: 0.5353 | test_loss: 1.2600 | test_acc: 0.5468
# Epoch: 8 | train_loss: 1.3037 | train_acc: 0.5354 | test_loss: 1.2834 | test_acc: 0.5562
# Epoch: 9 | train_loss: 1.3130 | train_acc: 0.5305 | test_loss: 1.2536 | test_acc: 0.5510
# Epoch: 10 | train_loss: 1.2546 | train_acc: 0.5537 | test_loss: 1.2546 | test_acc: 0.5463
# Epoch: 11 | train_loss: 1.2456 | train_acc: 0.5605 | test_loss: 1.3518 | test_acc: 0.5390
# Epoch: 12 | train_loss: 1.2256 | train_acc: 0.5697 | test_loss: 1.2368 | test_acc: 0.5550
# Epoch: 13 | train_loss: 1.1961 | train_acc: 0.5837 | test_loss: 1.1999 | test_acc: 0.5776
# Epoch: 14 | train_loss: 1.1729 | train_acc: 0.5885 | test_loss: 1.1479 | test_acc: 0.5882
# Epoch: 15 | train_loss: 1.1673 | train_acc: 0.5808 | test_loss: 1.1654 | test_acc: 0.5709
# Epoch: 16 | train_loss: 1.1560 | train_acc: 0.5903 | test_loss: 1.1714 | test_acc: 0.5830
# Epoch: 17 | train_loss: 1.1326 | train_acc: 0.5986 | test_loss: 1.2380 | test_acc: 0.5360
# Epoch: 18 | train_loss: 1.1545 | train_acc: 0.5963 | test_loss: 1.1301 | test_acc: 0.5937
# Epoch: 19 | train_loss: 1.1229 | train_acc: 0.6065 | test_loss: 1.1671 | test_acc: 0.5764
# Epoch: 20 | train_loss: 1.1196 | train_acc: 0.6047 | test_loss: 1.1507 | test_acc: 0.5910
# Epoch: 21 | train_loss: 1.0798 | train_acc: 0.6258 | test_loss: 1.0959 | test_acc: 0.6068
# Epoch: 22 | train_loss: 1.0559 | train_acc: 0.6322 | test_loss: 1.0798 | test_acc: 0.6134
# Epoch: 23 | train_loss: 1.1418 | train_acc: 0.5966 | test_loss: 1.1099 | test_acc: 0.6076
# Epoch: 24 | train_loss: 1.0657 | train_acc: 0.6231 | test_loss: 1.0575 | test_acc: 0.6182
# Epoch: 25 | train_loss: 1.0271 | train_acc: 0.6461 | test_loss: 1.1048 | test_acc: 0.6097
# Epoch: 26 | train_loss: 1.0072 | train_acc: 0.6575 | test_loss: 1.0544 | test_acc: 0.6341
# Epoch: 27 | train_loss: 1.0361 | train_acc: 0.6352 | test_loss: 1.0470 | test_acc: 0.6321
# Epoch: 28 | train_loss: 0.9907 | train_acc: 0.6606 | test_loss: 1.0481 | test_acc: 0.6395
# Epoch: 29 | train_loss: 0.9835 | train_acc: 0.6541 | test_loss: 1.0176 | test_acc: 0.6420
# Epoch: 30 | train_loss: 1.0021 | train_acc: 0.6461 | test_loss: 0.9947 | test_acc: 0.6490
# Epoch: 31 | train_loss: 0.9729 | train_acc: 0.6590 | test_loss: 1.0274 | test_acc: 0.6438
# Epoch: 32 | train_loss: 0.9652 | train_acc: 0.6652 | test_loss: 1.0292 | test_acc: 0.6376
# Epoch: 33 | train_loss: 0.9829 | train_acc: 0.6607 | test_loss: 0.9951 | test_acc: 0.6477
# Epoch: 34 | train_loss: 0.9299 | train_acc: 0.6745 | test_loss: 1.0297 | test_acc: 0.6389
# Epoch: 35 | train_loss: 0.9569 | train_acc: 0.6678 | test_loss: 1.0016 | test_acc: 0.6496
# Epoch: 36 | train_loss: 0.9280 | train_acc: 0.6795 | test_loss: 1.0428 | test_acc: 0.6351
# Epoch: 37 | train_loss: 0.9385 | train_acc: 0.6747 | test_loss: 1.0104 | test_acc: 0.6369
# Epoch: 38 | train_loss: 0.9395 | train_acc: 0.6811 | test_loss: 0.9850 | test_acc: 0.6542
# Epoch: 39 | train_loss: 0.9150 | train_acc: 0.6864 | test_loss: 0.9589 | test_acc: 0.6661
# Epoch: 40 | train_loss: 0.8698 | train_acc: 0.7030 | test_loss: 0.9590 | test_acc: 0.6589
# Epoch: 41 | train_loss: 0.9113 | train_acc: 0.6896 | test_loss: 1.0001 | test_acc: 0.6449
# Epoch: 42 | train_loss: 0.8898 | train_acc: 0.6870 | test_loss: 0.9663 | test_acc: 0.6644
# Epoch: 43 | train_loss: 0.8866 | train_acc: 0.6926 | test_loss: 1.0004 | test_acc: 0.6597
# Epoch: 44 | train_loss: 0.8919 | train_acc: 0.7017 | test_loss: 0.9650 | test_acc: 0.6696
# Epoch: 45 | train_loss: 0.8577 | train_acc: 0.7030 | test_loss: 0.9513 | test_acc: 0.6718
# Epoch: 46 | train_loss: 0.8364 | train_acc: 0.7181 | test_loss: 0.9406 | test_acc: 0.6823
# Epoch: 47 | train_loss: 0.8841 | train_acc: 0.7059 | test_loss: 0.9419 | test_acc: 0.6750
# Epoch: 48 | train_loss: 0.8392 | train_acc: 0.7120 | test_loss: 0.9667 | test_acc: 0.6623
# Epoch: 49 | train_loss: 0.7971 | train_acc: 0.7292 | test_loss: 0.9069 | test_acc: 0.6919
# Epoch: 50 | train_loss: 0.8291 | train_acc: 0.7164 | test_loss: 0.9140 | test_acc: 0.6761
# Epoch: 51 | train_loss: 0.8093 | train_acc: 0.7200 | test_loss: 0.9297 | test_acc: 0.6706
# Epoch: 52 | train_loss: 0.7950 | train_acc: 0.7317 | test_loss: 0.9201 | test_acc: 0.6753
# Epoch: 53 | train_loss: 0.7910 | train_acc: 0.7291 | test_loss: 0.9053 | test_acc: 0.6904
# Epoch: 54 | train_loss: 0.7634 | train_acc: 0.7410 | test_loss: 0.9423 | test_acc: 0.6737
# Epoch: 55 | train_loss: 0.7906 | train_acc: 0.7319 | test_loss: 0.8874 | test_acc: 0.6951
# Epoch: 56 | train_loss: 0.7826 | train_acc: 0.7340 | test_loss: 0.8791 | test_acc: 0.6956
# Epoch: 57 | train_loss: 0.7470 | train_acc: 0.7471 | test_loss: 0.9587 | test_acc: 0.6724
# Epoch: 58 | train_loss: 0.8293 | train_acc: 0.7223 | test_loss: 0.8869 | test_acc: 0.6891
# Epoch: 59 | train_loss: 0.7578 | train_acc: 0.7387 | test_loss: 0.8715 | test_acc: 0.7065
# Epoch: 60 | train_loss: 0.7349 | train_acc: 0.7536 | test_loss: 0.8574 | test_acc: 0.7135
# Epoch: 61 | train_loss: 0.7536 | train_acc: 0.7443 | test_loss: 0.8748 | test_acc: 0.6977
# Epoch: 62 | train_loss: 0.7583 | train_acc: 0.7440 | test_loss: 0.8977 | test_acc: 0.6911
# Epoch: 63 | train_loss: 0.7149 | train_acc: 0.7594 | test_loss: 0.8536 | test_acc: 0.7137
# Epoch: 64 | train_loss: 0.7087 | train_acc: 0.7644 | test_loss: 0.8971 | test_acc: 0.7017
# Epoch: 65 | train_loss: 0.6897 | train_acc: 0.7639 | test_loss: 0.8475 | test_acc: 0.7185
# Epoch: 66 | train_loss: 0.6963 | train_acc: 0.7626 | test_loss: 0.8383 | test_acc: 0.7164
# Epoch: 67 | train_loss: 0.7161 | train_acc: 0.7504 | test_loss: 0.8308 | test_acc: 0.7183
# Epoch: 68 | train_loss: 0.7071 | train_acc: 0.7640 | test_loss: 0.8658 | test_acc: 0.7184
# Epoch: 69 | train_loss: 0.6986 | train_acc: 0.7635 | test_loss: 0.8381 | test_acc: 0.7157
# Epoch: 70 | train_loss: 0.7048 | train_acc: 0.7568 | test_loss: 0.8421 | test_acc: 0.7291
# Epoch: 71 | train_loss: 0.7199 | train_acc: 0.7582 | test_loss: 0.8403 | test_acc: 0.7209
# Epoch: 72 | train_loss: 0.6805 | train_acc: 0.7652 | test_loss: 0.8099 | test_acc: 0.7268
# Epoch: 73 | train_loss: 0.6619 | train_acc: 0.7800 | test_loss: 1.0776 | test_acc: 0.6626
# Epoch: 74 | train_loss: 0.7123 | train_acc: 0.7573 | test_loss: 0.8300 | test_acc: 0.7248
# Epoch: 75 | train_loss: 0.6770 | train_acc: 0.7724 | test_loss: 0.8264 | test_acc: 0.7263
# Epoch: 76 | train_loss: 0.6409 | train_acc: 0.7912 | test_loss: 0.7998 | test_acc: 0.7318
# Epoch: 77 | train_loss: 0.6675 | train_acc: 0.7781 | test_loss: 0.7792 | test_acc: 0.7330
# Epoch: 78 | train_loss: 0.6415 | train_acc: 0.7845 | test_loss: 0.8425 | test_acc: 0.7178
# Epoch: 79 | train_loss: 0.6219 | train_acc: 0.7905 | test_loss: 0.7722 | test_acc: 0.7453
# Epoch: 80 | train_loss: 0.6303 | train_acc: 0.7908 | test_loss: 0.7912 | test_acc: 0.7336
# Epoch: 81 | train_loss: 0.6099 | train_acc: 0.7936 | test_loss: 0.8142 | test_acc: 0.7329
# Epoch: 82 | train_loss: 0.6067 | train_acc: 0.7951 | test_loss: 0.8102 | test_acc: 0.7388
# Epoch: 83 | train_loss: 0.6219 | train_acc: 0.7905 | test_loss: 0.7933 | test_acc: 0.7282
# Epoch: 84 | train_loss: 0.6311 | train_acc: 0.7842 | test_loss: 0.8000 | test_acc: 0.7254
# Epoch: 85 | train_loss: 0.5954 | train_acc: 0.8059 | test_loss: 0.7863 | test_acc: 0.7388
# Epoch: 86 | train_loss: 0.5774 | train_acc: 0.8080 | test_loss: 0.7673 | test_acc: 0.7467
# Epoch: 87 | train_loss: 0.6287 | train_acc: 0.7866 | test_loss: 0.7474 | test_acc: 0.7381
# Epoch: 88 | train_loss: 0.6308 | train_acc: 0.7886 | test_loss: 0.7936 | test_acc: 0.7335
# Epoch: 89 | train_loss: 0.5724 | train_acc: 0.8119 | test_loss: 0.7917 | test_acc: 0.7381
# Epoch: 90 | train_loss: 0.5682 | train_acc: 0.8136 | test_loss: 0.7770 | test_acc: 0.7425
# Epoch: 91 | train_loss: 0.5544 | train_acc: 0.8221 | test_loss: 0.7734 | test_acc: 0.7524
# Epoch: 92 | train_loss: 0.5694 | train_acc: 0.8100 | test_loss: 0.8106 | test_acc: 0.7363
# Epoch: 93 | train_loss: 0.5491 | train_acc: 0.8150 | test_loss: 0.7722 | test_acc: 0.7462
# Epoch: 94 | train_loss: 0.5407 | train_acc: 0.8170 | test_loss: 0.7455 | test_acc: 0.7523
# Epoch: 95 | train_loss: 0.5593 | train_acc: 0.8133 | test_loss: 0.7449 | test_acc: 0.7656
# Epoch: 96 | train_loss: 0.5514 | train_acc: 0.8149 | test_loss: 0.7523 | test_acc: 0.7534
# Epoch: 97 | train_loss: 0.5573 | train_acc: 0.8160 | test_loss: 0.7683 | test_acc: 0.7523
# Epoch: 98 | train_loss: 0.5704 | train_acc: 0.8142 | test_loss: 0.7465 | test_acc: 0.7562
# Epoch: 99 | train_loss: 0.4980 | train_acc: 0.8406 | test_loss: 0.7577 | test_acc: 0.7530
# Epoch: 100 | train_loss: 0.4880 | train_acc: 0.8428 | test_loss: 0.7603 | test_acc: 0.7563
# Epoch: 101 | train_loss: 0.5380 | train_acc: 0.8254 | test_loss: 0.7437 | test_acc: 0.7530
# Epoch: 102 | train_loss: 0.5146 | train_acc: 0.8365 | test_loss: 0.7465 | test_acc: 0.7603
# Epoch: 103 | train_loss: 0.5332 | train_acc: 0.8245 | test_loss: 0.7476 | test_acc: 0.7629
# Epoch: 104 | train_loss: 0.4904 | train_acc: 0.8419 | test_loss: 0.7322 | test_acc: 0.7643
# Epoch: 105 | train_loss: 0.5137 | train_acc: 0.8314 | test_loss: 0.7318 | test_acc: 0.7573
# Epoch: 106 | train_loss: 0.5127 | train_acc: 0.8322 | test_loss: 0.7386 | test_acc: 0.7658
# Epoch: 107 | train_loss: 0.4503 | train_acc: 0.8580 | test_loss: 0.7380 | test_acc: 0.7743
# Epoch: 108 | train_loss: 0.5009 | train_acc: 0.8357 | test_loss: 0.7464 | test_acc: 0.7543
# Epoch: 109 | train_loss: 0.4972 | train_acc: 0.8338 | test_loss: 0.7301 | test_acc: 0.7617
# Epoch: 110 | train_loss: 0.4370 | train_acc: 0.8604 | test_loss: 0.7545 | test_acc: 0.7584
# Epoch: 111 | train_loss: 0.4632 | train_acc: 0.8518 | test_loss: 0.7077 | test_acc: 0.7731
# Epoch: 112 | train_loss: 0.4784 | train_acc: 0.8436 | test_loss: 0.7656 | test_acc: 0.7391
# Epoch: 113 | train_loss: 0.4932 | train_acc: 0.8382 | test_loss: 0.7543 | test_acc: 0.7568
# Epoch: 114 | train_loss: 0.4808 | train_acc: 0.8424 | test_loss: 0.7341 | test_acc: 0.7562
# Epoch: 115 | train_loss: 0.4961 | train_acc: 0.8338 | test_loss: 0.7173 | test_acc: 0.7717
# Epoch: 116 | train_loss: 0.4658 | train_acc: 0.8438 | test_loss: 0.7239 | test_acc: 0.7752
# Epoch: 117 | train_loss: 0.4326 | train_acc: 0.8611 | test_loss: 0.7098 | test_acc: 0.7736
# Epoch: 118 | train_loss: 0.4638 | train_acc: 0.8507 | test_loss: 0.7198 | test_acc: 0.7662
# Epoch: 119 | train_loss: 0.4399 | train_acc: 0.8534 | test_loss: 0.7069 | test_acc: 0.7722
# Epoch: 120 | train_loss: 0.4569 | train_acc: 0.8548 | test_loss: 0.7173 | test_acc: 0.7701
# Epoch: 121 | train_loss: 0.4131 | train_acc: 0.8720 | test_loss: 0.7401 | test_acc: 0.7649
# Epoch: 122 | train_loss: 0.4113 | train_acc: 0.8679 | test_loss: 0.6915 | test_acc: 0.7756
# Epoch: 123 | train_loss: 0.4258 | train_acc: 0.8644 | test_loss: 0.6783 | test_acc: 0.7842
# Epoch: 124 | train_loss: 0.4305 | train_acc: 0.8616 | test_loss: 0.6959 | test_acc: 0.7744
# Epoch: 125 | train_loss: 0.4424 | train_acc: 0.8571 | test_loss: 0.7077 | test_acc: 0.7836
# Epoch: 126 | train_loss: 0.4378 | train_acc: 0.8592 | test_loss: 0.6893 | test_acc: 0.7842
# Epoch: 127 | train_loss: 0.3782 | train_acc: 0.8810 | test_loss: 0.7149 | test_acc: 0.7817
# Epoch: 128 | train_loss: 0.4209 | train_acc: 0.8617 | test_loss: 0.7300 | test_acc: 0.7592
# Epoch: 129 | train_loss: 0.3883 | train_acc: 0.8769 | test_loss: 0.6975 | test_acc: 0.7791
# Epoch: 130 | train_loss: 0.4515 | train_acc: 0.8536 | test_loss: 0.6935 | test_acc: 0.7817
# Epoch: 131 | train_loss: 0.4502 | train_acc: 0.8534 | test_loss: 0.6880 | test_acc: 0.7743
# Epoch: 132 | train_loss: 0.4231 | train_acc: 0.8600 | test_loss: 0.6947 | test_acc: 0.7877
# Epoch: 133 | train_loss: 0.3831 | train_acc: 0.8788 | test_loss: 0.7396 | test_acc: 0.7671
# Epoch: 134 | train_loss: 0.3757 | train_acc: 0.8821 | test_loss: 0.6625 | test_acc: 0.7905
# Epoch: 135 | train_loss: 0.4266 | train_acc: 0.8625 | test_loss: 0.7058 | test_acc: 0.7743
# Epoch: 136 | train_loss: 0.4283 | train_acc: 0.8592 | test_loss: 0.6992 | test_acc: 0.7831
# Epoch: 137 | train_loss: 0.3968 | train_acc: 0.8734 | test_loss: 0.7246 | test_acc: 0.7784
# Epoch: 138 | train_loss: 0.4068 | train_acc: 0.8701 | test_loss: 0.7085 | test_acc: 0.7751
# Epoch: 139 | train_loss: 0.3738 | train_acc: 0.8795 | test_loss: 0.6941 | test_acc: 0.7858
# Epoch: 140 | train_loss: 0.3573 | train_acc: 0.8905 | test_loss: 0.6784 | test_acc: 0.7950
# Epoch: 141 | train_loss: 0.3817 | train_acc: 0.8798 | test_loss: 0.7112 | test_acc: 0.7864
# Epoch: 142 | train_loss: 0.4140 | train_acc: 0.8676 | test_loss: 0.7012 | test_acc: 0.7850
# Epoch: 143 | train_loss: 0.3645 | train_acc: 0.8835 | test_loss: 0.8597 | test_acc: 0.7377
# Epoch: 144 | train_loss: 0.4146 | train_acc: 0.8693 | test_loss: 0.6866 | test_acc: 0.7758
# Epoch: 145 | train_loss: 0.3115 | train_acc: 0.9015 | test_loss: 0.7241 | test_acc: 0.7753
# Epoch: 146 | train_loss: 0.3681 | train_acc: 0.8863 | test_loss: 0.6638 | test_acc: 0.7911
# Epoch: 147 | train_loss: 0.3895 | train_acc: 0.8768 | test_loss: 0.6758 | test_acc: 0.7830
# Epoch: 148 | train_loss: 0.3791 | train_acc: 0.8808 | test_loss: 0.7043 | test_acc: 0.7838
# Epoch: 149 | train_loss: 0.3542 | train_acc: 0.8874 | test_loss: 0.6919 | test_acc: 0.7875
# Epoch: 150 | train_loss: 0.3354 | train_acc: 0.8943 | test_loss: 0.6963 | test_acc: 0.7897
# Total training time: 135.325 seconds

# %%
plot_loss_curves(model_5_results, Save=True, filename="model_5_training")

# %% [markdown]
# We see that using data augmentation improves the performance of the model.

# %% [markdown]
# ### 9.4 Training the GRU model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_6 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating the GRU version of the paper
# model_6 = GRUClassifierV1().to(device)
model_6
# Out:
# GRUClassifierV0(
#   (gru): GRU(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_6.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used with the paper GRU
# optimizer = torch.optim.Adam(model_6.parameters(),
#                              lr=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_6_results = train_with_augmentation(model=model_6,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0290 | train_acc: 0.2860 | test_loss: 1.8163 | test_acc: 0.3610
# Epoch: 2 | train_loss: 1.7741 | train_acc: 0.3621 | test_loss: 1.6554 | test_acc: 0.4244
# Epoch: 3 | train_loss: 1.6418 | train_acc: 0.4075 | test_loss: 1.5398 | test_acc: 0.4636
# Epoch: 4 | train_loss: 1.5346 | train_acc: 0.4586 | test_loss: 1.4477 | test_acc: 0.4911
# Epoch: 5 | train_loss: 1.4605 | train_acc: 0.4800 | test_loss: 1.3641 | test_acc: 0.5129
# Epoch: 6 | train_loss: 1.3703 | train_acc: 0.5103 | test_loss: 1.2965 | test_acc: 0.5463
# Epoch: 7 | train_loss: 1.3003 | train_acc: 0.5455 | test_loss: 1.2329 | test_acc: 0.5583
# Epoch: 8 | train_loss: 1.2483 | train_acc: 0.5572 | test_loss: 1.1601 | test_acc: 0.5755
# Epoch: 9 | train_loss: 1.1939 | train_acc: 0.5784 | test_loss: 1.1151 | test_acc: 0.5917
# Epoch: 10 | train_loss: 1.1624 | train_acc: 0.5907 | test_loss: 1.1074 | test_acc: 0.5917
# Epoch: 11 | train_loss: 1.1142 | train_acc: 0.6086 | test_loss: 1.0517 | test_acc: 0.6209
# Epoch: 12 | train_loss: 1.0852 | train_acc: 0.6196 | test_loss: 1.0191 | test_acc: 0.6361
# Epoch: 13 | train_loss: 1.0184 | train_acc: 0.6413 | test_loss: 0.9806 | test_acc: 0.6468
# Epoch: 14 | train_loss: 0.9720 | train_acc: 0.6624 | test_loss: 0.9545 | test_acc: 0.6487
# Epoch: 15 | train_loss: 0.9461 | train_acc: 0.6681 | test_loss: 0.9450 | test_acc: 0.6562
# Epoch: 16 | train_loss: 0.9213 | train_acc: 0.6716 | test_loss: 0.9188 | test_acc: 0.6715
# Epoch: 17 | train_loss: 0.8860 | train_acc: 0.6976 | test_loss: 0.8914 | test_acc: 0.6813
# Epoch: 18 | train_loss: 0.9285 | train_acc: 0.6769 | test_loss: 0.9330 | test_acc: 0.6662
# Epoch: 19 | train_loss: 0.8739 | train_acc: 0.6930 | test_loss: 0.8735 | test_acc: 0.6930
# Epoch: 20 | train_loss: 0.8447 | train_acc: 0.7056 | test_loss: 0.8475 | test_acc: 0.6940
# Epoch: 21 | train_loss: 0.8667 | train_acc: 0.6971 | test_loss: 0.8391 | test_acc: 0.7047
# Epoch: 22 | train_loss: 0.8223 | train_acc: 0.7103 | test_loss: 0.8564 | test_acc: 0.6949
# Epoch: 23 | train_loss: 0.8192 | train_acc: 0.7200 | test_loss: 0.8412 | test_acc: 0.6984
# Epoch: 24 | train_loss: 0.8095 | train_acc: 0.7202 | test_loss: 0.8517 | test_acc: 0.6955
# Epoch: 25 | train_loss: 0.7883 | train_acc: 0.7282 | test_loss: 0.8192 | test_acc: 0.7084
# Epoch: 26 | train_loss: 0.7769 | train_acc: 0.7321 | test_loss: 0.8222 | test_acc: 0.7016
# Epoch: 27 | train_loss: 0.7421 | train_acc: 0.7430 | test_loss: 0.7799 | test_acc: 0.7209
# Epoch: 28 | train_loss: 0.7303 | train_acc: 0.7500 | test_loss: 0.8068 | test_acc: 0.7138
# Epoch: 29 | train_loss: 0.6991 | train_acc: 0.7588 | test_loss: 0.7585 | test_acc: 0.7324
# Epoch: 30 | train_loss: 0.7086 | train_acc: 0.7537 | test_loss: 0.8000 | test_acc: 0.7096
# Epoch: 31 | train_loss: 0.6860 | train_acc: 0.7645 | test_loss: 0.7522 | test_acc: 0.7406
# Epoch: 32 | train_loss: 0.6873 | train_acc: 0.7662 | test_loss: 0.7367 | test_acc: 0.7465
# Epoch: 33 | train_loss: 0.6660 | train_acc: 0.7721 | test_loss: 0.7341 | test_acc: 0.7571
# Epoch: 34 | train_loss: 0.6643 | train_acc: 0.7731 | test_loss: 0.7413 | test_acc: 0.7472
# Epoch: 35 | train_loss: 0.6643 | train_acc: 0.7711 | test_loss: 0.7365 | test_acc: 0.7416
# Epoch: 36 | train_loss: 0.6379 | train_acc: 0.7804 | test_loss: 0.7304 | test_acc: 0.7452
# Epoch: 37 | train_loss: 0.6439 | train_acc: 0.7808 | test_loss: 0.7356 | test_acc: 0.7458
# Epoch: 38 | train_loss: 0.6113 | train_acc: 0.7875 | test_loss: 0.7230 | test_acc: 0.7512
# Epoch: 39 | train_loss: 0.6093 | train_acc: 0.7937 | test_loss: 0.6960 | test_acc: 0.7630
# Epoch: 40 | train_loss: 0.6424 | train_acc: 0.7808 | test_loss: 0.7018 | test_acc: 0.7604
# Epoch: 41 | train_loss: 0.5965 | train_acc: 0.7911 | test_loss: 0.7065 | test_acc: 0.7625
# Epoch: 42 | train_loss: 0.5960 | train_acc: 0.7987 | test_loss: 0.7039 | test_acc: 0.7545
# Epoch: 43 | train_loss: 0.5764 | train_acc: 0.7988 | test_loss: 0.6972 | test_acc: 0.7671
# Epoch: 44 | train_loss: 0.5485 | train_acc: 0.8145 | test_loss: 0.6886 | test_acc: 0.7608
# Epoch: 45 | train_loss: 0.5820 | train_acc: 0.8030 | test_loss: 0.7021 | test_acc: 0.7624
# Epoch: 46 | train_loss: 0.5583 | train_acc: 0.8104 | test_loss: 0.7073 | test_acc: 0.7597
# Epoch: 47 | train_loss: 0.5836 | train_acc: 0.8014 | test_loss: 0.7557 | test_acc: 0.7473
# Epoch: 48 | train_loss: 0.5310 | train_acc: 0.8207 | test_loss: 0.7015 | test_acc: 0.7671
# Epoch: 49 | train_loss: 0.5252 | train_acc: 0.8190 | test_loss: 0.6945 | test_acc: 0.7659
# Epoch: 50 | train_loss: 0.5237 | train_acc: 0.8239 | test_loss: 0.6677 | test_acc: 0.7691
# Epoch: 51 | train_loss: 0.5291 | train_acc: 0.8215 | test_loss: 0.6709 | test_acc: 0.7799
# Epoch: 52 | train_loss: 0.5172 | train_acc: 0.8286 | test_loss: 0.6577 | test_acc: 0.7765
# Epoch: 53 | train_loss: 0.4930 | train_acc: 0.8360 | test_loss: 0.6866 | test_acc: 0.7737
# Epoch: 54 | train_loss: 0.5218 | train_acc: 0.8217 | test_loss: 0.6836 | test_acc: 0.7618
# Epoch: 55 | train_loss: 0.4802 | train_acc: 0.8401 | test_loss: 0.6504 | test_acc: 0.7872
# Epoch: 56 | train_loss: 0.5455 | train_acc: 0.8176 | test_loss: 0.6596 | test_acc: 0.7831
# Epoch: 57 | train_loss: 0.5026 | train_acc: 0.8316 | test_loss: 0.6814 | test_acc: 0.7653
# Epoch: 58 | train_loss: 0.4735 | train_acc: 0.8392 | test_loss: 0.6436 | test_acc: 0.7764
# Epoch: 59 | train_loss: 0.4690 | train_acc: 0.8463 | test_loss: 0.6373 | test_acc: 0.7839
# Epoch: 60 | train_loss: 0.4572 | train_acc: 0.8489 | test_loss: 0.6316 | test_acc: 0.7879
# Epoch: 61 | train_loss: 0.4826 | train_acc: 0.8459 | test_loss: 0.6185 | test_acc: 0.7878
# Epoch: 62 | train_loss: 0.4453 | train_acc: 0.8547 | test_loss: 0.6259 | test_acc: 0.7860
# Epoch: 63 | train_loss: 0.4269 | train_acc: 0.8530 | test_loss: 0.6234 | test_acc: 0.7966
# Epoch: 64 | train_loss: 0.4542 | train_acc: 0.8450 | test_loss: 0.6090 | test_acc: 0.7946
# Epoch: 65 | train_loss: 0.4406 | train_acc: 0.8505 | test_loss: 0.6158 | test_acc: 0.7876
# Epoch: 66 | train_loss: 0.4262 | train_acc: 0.8606 | test_loss: 0.6215 | test_acc: 0.7933
# Epoch: 67 | train_loss: 0.4146 | train_acc: 0.8616 | test_loss: 0.6200 | test_acc: 0.7973
# Epoch: 68 | train_loss: 0.4268 | train_acc: 0.8599 | test_loss: 0.6280 | test_acc: 0.7918
# Epoch: 69 | train_loss: 0.4000 | train_acc: 0.8706 | test_loss: 0.5996 | test_acc: 0.8026
# Epoch: 70 | train_loss: 0.3759 | train_acc: 0.8759 | test_loss: 0.6381 | test_acc: 0.8073
# Epoch: 71 | train_loss: 0.4094 | train_acc: 0.8643 | test_loss: 0.6290 | test_acc: 0.7919
# Epoch: 72 | train_loss: 0.4064 | train_acc: 0.8624 | test_loss: 0.6716 | test_acc: 0.7918
# Epoch: 73 | train_loss: 0.4144 | train_acc: 0.8638 | test_loss: 0.5637 | test_acc: 0.8019
# Epoch: 74 | train_loss: 0.3996 | train_acc: 0.8717 | test_loss: 0.5624 | test_acc: 0.8086
# Epoch: 75 | train_loss: 0.4123 | train_acc: 0.8616 | test_loss: 0.6236 | test_acc: 0.7994
# Epoch: 76 | train_loss: 0.3856 | train_acc: 0.8731 | test_loss: 0.6264 | test_acc: 0.7852
# Epoch: 77 | train_loss: 0.4013 | train_acc: 0.8654 | test_loss: 0.6011 | test_acc: 0.8052
# Epoch: 78 | train_loss: 0.3752 | train_acc: 0.8787 | test_loss: 0.6517 | test_acc: 0.7846
# Epoch: 79 | train_loss: 0.3926 | train_acc: 0.8694 | test_loss: 0.5982 | test_acc: 0.8045
# Epoch: 80 | train_loss: 0.3455 | train_acc: 0.8885 | test_loss: 0.6309 | test_acc: 0.8021
# Epoch: 81 | train_loss: 0.3520 | train_acc: 0.8861 | test_loss: 0.5843 | test_acc: 0.8094
# Epoch: 82 | train_loss: 0.3560 | train_acc: 0.8859 | test_loss: 0.6090 | test_acc: 0.7925
# Epoch: 83 | train_loss: 0.3555 | train_acc: 0.8874 | test_loss: 0.5950 | test_acc: 0.8033
# Epoch: 84 | train_loss: 0.3640 | train_acc: 0.8822 | test_loss: 0.5761 | test_acc: 0.8093
# Epoch: 85 | train_loss: 0.3435 | train_acc: 0.8884 | test_loss: 0.5775 | test_acc: 0.8131
# Epoch: 86 | train_loss: 0.3914 | train_acc: 0.8671 | test_loss: 0.5620 | test_acc: 0.8153
# Epoch: 87 | train_loss: 0.3621 | train_acc: 0.8846 | test_loss: 0.5896 | test_acc: 0.8125
# Epoch: 88 | train_loss: 0.3575 | train_acc: 0.8858 | test_loss: 0.5921 | test_acc: 0.8072
# Epoch: 89 | train_loss: 0.3338 | train_acc: 0.8909 | test_loss: 0.5594 | test_acc: 0.8192
# Epoch: 90 | train_loss: 0.3188 | train_acc: 0.8974 | test_loss: 0.5726 | test_acc: 0.8107
# Epoch: 91 | train_loss: 0.3527 | train_acc: 0.8851 | test_loss: 0.5649 | test_acc: 0.8199
# Epoch: 92 | train_loss: 0.2962 | train_acc: 0.9074 | test_loss: 0.5718 | test_acc: 0.8021
# Epoch: 93 | train_loss: 0.3142 | train_acc: 0.8949 | test_loss: 0.5487 | test_acc: 0.8267
# Epoch: 94 | train_loss: 0.3248 | train_acc: 0.8949 | test_loss: 0.5760 | test_acc: 0.8127
# Epoch: 95 | train_loss: 0.3335 | train_acc: 0.8935 | test_loss: 0.5617 | test_acc: 0.8205
# Epoch: 96 | train_loss: 0.2793 | train_acc: 0.9152 | test_loss: 0.5612 | test_acc: 0.8134
# Epoch: 97 | train_loss: 0.3081 | train_acc: 0.9015 | test_loss: 0.5519 | test_acc: 0.8192
# Epoch: 98 | train_loss: 0.3272 | train_acc: 0.8989 | test_loss: 0.5620 | test_acc: 0.8220
# Epoch: 99 | train_loss: 0.3198 | train_acc: 0.8974 | test_loss: 0.5538 | test_acc: 0.8207
# Epoch: 100 | train_loss: 0.2905 | train_acc: 0.9057 | test_loss: 0.5931 | test_acc: 0.8148
# Epoch: 101 | train_loss: 0.3061 | train_acc: 0.9029 | test_loss: 0.5606 | test_acc: 0.8186
# Epoch: 102 | train_loss: 0.3242 | train_acc: 0.8964 | test_loss: 0.5581 | test_acc: 0.8248
# Epoch: 103 | train_loss: 0.3097 | train_acc: 0.8983 | test_loss: 0.5444 | test_acc: 0.8319
# Epoch: 104 | train_loss: 0.3103 | train_acc: 0.8971 | test_loss: 0.5999 | test_acc: 0.8133
# Epoch: 105 | train_loss: 0.2836 | train_acc: 0.9096 | test_loss: 0.5680 | test_acc: 0.8257
# Epoch: 106 | train_loss: 0.3207 | train_acc: 0.8938 | test_loss: 0.6046 | test_acc: 0.8153
# Epoch: 107 | train_loss: 0.2985 | train_acc: 0.9063 | test_loss: 0.5341 | test_acc: 0.8261
# Epoch: 108 | train_loss: 0.2906 | train_acc: 0.9050 | test_loss: 0.5951 | test_acc: 0.8073
# Epoch: 109 | train_loss: 0.2988 | train_acc: 0.9023 | test_loss: 0.5733 | test_acc: 0.8120
# Epoch: 110 | train_loss: 0.2728 | train_acc: 0.9121 | test_loss: 0.5470 | test_acc: 0.8283
# Epoch: 111 | train_loss: 0.2829 | train_acc: 0.9098 | test_loss: 0.5432 | test_acc: 0.8219
# Epoch: 112 | train_loss: 0.2954 | train_acc: 0.9062 | test_loss: 0.5640 | test_acc: 0.8153
# Epoch: 113 | train_loss: 0.2869 | train_acc: 0.9052 | test_loss: 0.5441 | test_acc: 0.8266
# Epoch: 114 | train_loss: 0.2613 | train_acc: 0.9188 | test_loss: 0.5642 | test_acc: 0.8240
# Epoch: 115 | train_loss: 0.2953 | train_acc: 0.9014 | test_loss: 0.5941 | test_acc: 0.8158
# Epoch: 116 | train_loss: 0.3072 | train_acc: 0.9035 | test_loss: 0.5414 | test_acc: 0.8258
# Epoch: 117 | train_loss: 0.2518 | train_acc: 0.9202 | test_loss: 0.5741 | test_acc: 0.8272
# Epoch: 118 | train_loss: 0.2675 | train_acc: 0.9198 | test_loss: 0.5857 | test_acc: 0.8192
# Epoch: 119 | train_loss: 0.2532 | train_acc: 0.9204 | test_loss: 0.5434 | test_acc: 0.8305
# Epoch: 120 | train_loss: 0.2294 | train_acc: 0.9264 | test_loss: 0.5611 | test_acc: 0.8174
# Epoch: 121 | train_loss: 0.2740 | train_acc: 0.9137 | test_loss: 0.5409 | test_acc: 0.8266
# Epoch: 122 | train_loss: 0.2557 | train_acc: 0.9206 | test_loss: 0.5600 | test_acc: 0.8233
# Epoch: 123 | train_loss: 0.2754 | train_acc: 0.9126 | test_loss: 0.5622 | test_acc: 0.8238
# Epoch: 124 | train_loss: 0.2585 | train_acc: 0.9182 | test_loss: 0.5555 | test_acc: 0.8258
# Epoch: 125 | train_loss: 0.2496 | train_acc: 0.9182 | test_loss: 0.5824 | test_acc: 0.8086
# Epoch: 126 | train_loss: 0.2327 | train_acc: 0.9304 | test_loss: 0.6067 | test_acc: 0.8167
# Epoch: 127 | train_loss: 0.2637 | train_acc: 0.9147 | test_loss: 0.5525 | test_acc: 0.8339
# Epoch: 128 | train_loss: 0.2414 | train_acc: 0.9249 | test_loss: 0.5337 | test_acc: 0.8285
# Epoch: 129 | train_loss: 0.2557 | train_acc: 0.9195 | test_loss: 0.5806 | test_acc: 0.8167
# Epoch: 130 | train_loss: 0.2357 | train_acc: 0.9222 | test_loss: 0.5882 | test_acc: 0.8205
# Epoch: 131 | train_loss: 0.2421 | train_acc: 0.9227 | test_loss: 0.5659 | test_acc: 0.8300
# Epoch: 132 | train_loss: 0.2524 | train_acc: 0.9187 | test_loss: 0.5141 | test_acc: 0.8400
# Epoch: 133 | train_loss: 0.2215 | train_acc: 0.9322 | test_loss: 0.5526 | test_acc: 0.8259
# Epoch: 134 | train_loss: 0.2189 | train_acc: 0.9316 | test_loss: 0.5861 | test_acc: 0.8097
# Epoch: 135 | train_loss: 0.2564 | train_acc: 0.9186 | test_loss: 0.5128 | test_acc: 0.8425
# Epoch: 136 | train_loss: 0.2433 | train_acc: 0.9240 | test_loss: 0.5580 | test_acc: 0.8252
# Epoch: 137 | train_loss: 0.2167 | train_acc: 0.9339 | test_loss: 0.5508 | test_acc: 0.8293
# Epoch: 138 | train_loss: 0.2428 | train_acc: 0.9242 | test_loss: 0.5390 | test_acc: 0.8340
# Epoch: 139 | train_loss: 0.2657 | train_acc: 0.9133 | test_loss: 0.5165 | test_acc: 0.8286
# Epoch: 140 | train_loss: 0.2177 | train_acc: 0.9288 | test_loss: 0.5062 | test_acc: 0.8412
# Epoch: 141 | train_loss: 0.2267 | train_acc: 0.9260 | test_loss: 0.5938 | test_acc: 0.8225
# Epoch: 142 | train_loss: 0.2531 | train_acc: 0.9152 | test_loss: 0.6518 | test_acc: 0.8172
# Epoch: 143 | train_loss: 0.2471 | train_acc: 0.9230 | test_loss: 0.5518 | test_acc: 0.8266
# Epoch: 144 | train_loss: 0.2302 | train_acc: 0.9253 | test_loss: 0.5340 | test_acc: 0.8332
# Epoch: 145 | train_loss: 0.2429 | train_acc: 0.9213 | test_loss: 0.5670 | test_acc: 0.8286
# Epoch: 146 | train_loss: 0.2314 | train_acc: 0.9247 | test_loss: 0.5297 | test_acc: 0.8337
# Epoch: 147 | train_loss: 0.2360 | train_acc: 0.9219 | test_loss: 0.4999 | test_acc: 0.8419
# Epoch: 148 | train_loss: 0.2135 | train_acc: 0.9350 | test_loss: 0.5706 | test_acc: 0.8247
# Epoch: 149 | train_loss: 0.2439 | train_acc: 0.9232 | test_loss: 0.6160 | test_acc: 0.8126
# Epoch: 150 | train_loss: 0.2372 | train_acc: 0.9232 | test_loss: 0.5993 | test_acc: 0.8197
# Total training time: 113.342 seconds

# %%
plot_loss_curves(model_6_results, Save=True, filename="model_6_training")

# %% [markdown]
# We see that using data augmentation improves the performance of the model. The model is allowed to reach higher values of accuracy.

# %% [markdown]
# ## 10. Using early stopping to create the best model
#
# We will use early stopping on the models trained with data augmentation, in order to have the best version of them. One for each architecture.

# %% [markdown]
# ### 10.1 Using early stopping with the RNN model
# Careful observation of previous training results lead us to the conclusion to train the next RNN model for 150 epochs.

# %%
# Instantiating a new RNN model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_7 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_7
# Out:
# RNNClassifierV0(
#   (rnn): RNN(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_7.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_7
model_7_results = train_with_augmentation(model=model_7,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="mfcc",
                                                             segments=10,
                                                             model_name="RNNClassifierV0"
                                                             )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0420 | train_acc: 0.2750 | test_loss: 1.8563 | test_acc: 0.3265
# Epoch: 2 | train_loss: 1.8196 | train_acc: 0.3489 | test_loss: 1.7359 | test_acc: 0.3785
# Epoch: 3 | train_loss: 1.7307 | train_acc: 0.3777 | test_loss: 1.6665 | test_acc: 0.4150
# Epoch: 4 | train_loss: 1.6636 | train_acc: 0.4064 | test_loss: 1.6266 | test_acc: 0.4032
# Epoch: 5 | train_loss: 1.6067 | train_acc: 0.4338 | test_loss: 1.5722 | test_acc: 0.4457
# Epoch: 6 | train_loss: 1.5871 | train_acc: 0.4340 | test_loss: 1.5628 | test_acc: 0.4442
# Epoch: 7 | train_loss: 1.5296 | train_acc: 0.4548 | test_loss: 1.4966 | test_acc: 0.4596
# Epoch: 8 | train_loss: 1.5112 | train_acc: 0.4623 | test_loss: 1.4791 | test_acc: 0.4595
# Epoch: 9 | train_loss: 1.5020 | train_acc: 0.4662 | test_loss: 1.4666 | test_acc: 0.4821
# Epoch: 10 | train_loss: 1.4701 | train_acc: 0.4730 | test_loss: 1.4841 | test_acc: 0.4684
# Epoch: 11 | train_loss: 1.4337 | train_acc: 0.4843 | test_loss: 1.4359 | test_acc: 0.4798
# Epoch: 12 | train_loss: 1.4264 | train_acc: 0.4921 | test_loss: 1.4228 | test_acc: 0.4885
# Epoch: 13 | train_loss: 1.3845 | train_acc: 0.5094 | test_loss: 1.3796 | test_acc: 0.4983
# Epoch: 14 | train_loss: 1.3836 | train_acc: 0.5080 | test_loss: 1.4575 | test_acc: 0.4758
# Epoch: 15 | train_loss: 1.4563 | train_acc: 0.4837 | test_loss: 1.4077 | test_acc: 0.4819
# Epoch: 16 | train_loss: 1.3766 | train_acc: 0.5114 | test_loss: 1.3456 | test_acc: 0.5071
# Epoch: 17 | train_loss: 1.3316 | train_acc: 0.5289 | test_loss: 1.3498 | test_acc: 0.5075
# Epoch: 18 | train_loss: 1.4221 | train_acc: 0.4986 | test_loss: 1.3450 | test_acc: 0.5084
# Epoch: 19 | train_loss: 1.3358 | train_acc: 0.5253 | test_loss: 1.3241 | test_acc: 0.5159
# Epoch: 20 | train_loss: 1.3291 | train_acc: 0.5335 | test_loss: 1.3820 | test_acc: 0.5090
# Epoch: 21 | train_loss: 1.3419 | train_acc: 0.5296 | test_loss: 1.3339 | test_acc: 0.5209
# Epoch: 22 | train_loss: 1.3187 | train_acc: 0.5349 | test_loss: 1.3426 | test_acc: 0.5122
# Epoch: 23 | train_loss: 1.3133 | train_acc: 0.5379 | test_loss: 1.3352 | test_acc: 0.5078
# Epoch: 24 | train_loss: 1.5264 | train_acc: 0.4677 | test_loss: 1.6203 | test_acc: 0.3996
# Epoch: 25 | train_loss: 1.6097 | train_acc: 0.4406 | test_loss: 1.5070 | test_acc: 0.4533
# Epoch: 26 | train_loss: 1.4798 | train_acc: 0.4832 | test_loss: 1.4266 | test_acc: 0.4866
# Epoch: 27 | train_loss: 1.4171 | train_acc: 0.5058 | test_loss: 1.4324 | test_acc: 0.4854
# Epoch: 28 | train_loss: 1.5125 | train_acc: 0.4610 | test_loss: 1.4233 | test_acc: 0.4899
# Epoch: 29 | train_loss: 1.3802 | train_acc: 0.5174 | test_loss: 1.3735 | test_acc: 0.5172
# Epoch: 30 | train_loss: 1.3665 | train_acc: 0.5135 | test_loss: 1.4120 | test_acc: 0.4836
# Epoch: 31 | train_loss: 1.3781 | train_acc: 0.5209 | test_loss: 1.3457 | test_acc: 0.5225
# Epoch: 32 | train_loss: 1.3329 | train_acc: 0.5291 | test_loss: 1.3731 | test_acc: 0.5118
# Epoch: 33 | train_loss: 1.3452 | train_acc: 0.5315 | test_loss: 1.3347 | test_acc: 0.5222
# Epoch: 34 | train_loss: 1.3017 | train_acc: 0.5382 | test_loss: 1.3030 | test_acc: 0.5375
# Epoch: 35 | train_loss: 1.2969 | train_acc: 0.5441 | test_loss: 1.3187 | test_acc: 0.5379
# Epoch: 36 | train_loss: 1.2942 | train_acc: 0.5459 | test_loss: 1.3243 | test_acc: 0.5291
# Epoch: 37 | train_loss: 1.3549 | train_acc: 0.5310 | test_loss: 1.3111 | test_acc: 0.5389
# Epoch: 38 | train_loss: 1.2622 | train_acc: 0.5577 | test_loss: 1.2860 | test_acc: 0.5406
# Epoch: 39 | train_loss: 1.3891 | train_acc: 0.5176 | test_loss: 1.5236 | test_acc: 0.4732
# Epoch: 40 | train_loss: 1.4258 | train_acc: 0.5054 | test_loss: 1.4089 | test_acc: 0.5037
# Epoch: 41 | train_loss: 1.3960 | train_acc: 0.5191 | test_loss: 1.5231 | test_acc: 0.4736
# Epoch: 42 | train_loss: 1.3688 | train_acc: 0.5212 | test_loss: 1.3587 | test_acc: 0.5179
# Epoch: 43 | train_loss: 1.3086 | train_acc: 0.5478 | test_loss: 1.3366 | test_acc: 0.5336
# Epoch: 44 | train_loss: 1.2919 | train_acc: 0.5542 | test_loss: 1.2966 | test_acc: 0.5485
# Epoch: 45 | train_loss: 1.2531 | train_acc: 0.5673 | test_loss: 1.2937 | test_acc: 0.5397
# Epoch: 46 | train_loss: 1.2740 | train_acc: 0.5507 | test_loss: 1.3270 | test_acc: 0.5337
# Epoch: 47 | train_loss: 1.2081 | train_acc: 0.5791 | test_loss: 1.2576 | test_acc: 0.5545
# Epoch: 48 | train_loss: 1.2210 | train_acc: 0.5673 | test_loss: 1.2542 | test_acc: 0.5456
# Epoch: 49 | train_loss: 1.2537 | train_acc: 0.5640 | test_loss: 1.2937 | test_acc: 0.5424
# Epoch: 50 | train_loss: 1.2352 | train_acc: 0.5671 | test_loss: 1.2360 | test_acc: 0.5609
# Epoch: 51 | train_loss: 1.2099 | train_acc: 0.5750 | test_loss: 1.4380 | test_acc: 0.4856
# Epoch: 52 | train_loss: 1.2583 | train_acc: 0.5537 | test_loss: 1.2337 | test_acc: 0.5588
# Epoch: 53 | train_loss: 1.2204 | train_acc: 0.5689 | test_loss: 1.2366 | test_acc: 0.5642
# Epoch: 54 | train_loss: 1.1995 | train_acc: 0.5765 | test_loss: 1.2283 | test_acc: 0.5663
# Epoch: 55 | train_loss: 1.1655 | train_acc: 0.5869 | test_loss: 1.2132 | test_acc: 0.5710
# Epoch: 56 | train_loss: 1.1896 | train_acc: 0.5848 | test_loss: 1.2251 | test_acc: 0.5550
# Epoch: 57 | train_loss: 1.1761 | train_acc: 0.5875 | test_loss: 1.3610 | test_acc: 0.5325
# Epoch: 58 | train_loss: 1.2323 | train_acc: 0.5717 | test_loss: 1.3238 | test_acc: 0.5296
# Epoch: 59 | train_loss: 1.3370 | train_acc: 0.5324 | test_loss: 1.3784 | test_acc: 0.5114
# Epoch: 60 | train_loss: 1.2179 | train_acc: 0.5684 | test_loss: 1.2329 | test_acc: 0.5537
# Epoch: 61 | train_loss: 1.1727 | train_acc: 0.5908 | test_loss: 1.2143 | test_acc: 0.5664
# Epoch: 62 | train_loss: 1.2202 | train_acc: 0.5715 | test_loss: 1.4321 | test_acc: 0.5069
# Epoch: 63 | train_loss: 1.2058 | train_acc: 0.5787 | test_loss: 1.2093 | test_acc: 0.5690
# Epoch: 64 | train_loss: 1.1509 | train_acc: 0.5930 | test_loss: 1.1774 | test_acc: 0.5756
# Epoch: 65 | train_loss: 1.2566 | train_acc: 0.5634 | test_loss: 1.2484 | test_acc: 0.5502
# Epoch: 66 | train_loss: 1.2315 | train_acc: 0.5629 | test_loss: 1.2302 | test_acc: 0.5580
# Epoch: 67 | train_loss: 1.2102 | train_acc: 0.5820 | test_loss: 1.2303 | test_acc: 0.5710
# Epoch: 68 | train_loss: 1.1978 | train_acc: 0.5835 | test_loss: 1.3704 | test_acc: 0.5098
# Epoch: 69 | train_loss: 1.2715 | train_acc: 0.5585 | test_loss: 1.6267 | test_acc: 0.4450
# Epoch: 70 | train_loss: 1.3276 | train_acc: 0.5284 | test_loss: 1.2818 | test_acc: 0.5529
# Epoch: 71 | train_loss: 1.2256 | train_acc: 0.5786 | test_loss: 1.2650 | test_acc: 0.5528
# Epoch: 72 | train_loss: 1.2136 | train_acc: 0.5763 | test_loss: 1.2446 | test_acc: 0.5623
# Epoch: 73 | train_loss: 1.2329 | train_acc: 0.5762 | test_loss: 1.6516 | test_acc: 0.4608
# Epoch: 74 | train_loss: 1.2751 | train_acc: 0.5591 | test_loss: 1.4633 | test_acc: 0.4903
# Epoch: 75 | train_loss: 1.1840 | train_acc: 0.5892 | test_loss: 1.3116 | test_acc: 0.5564
# Epoch: 76 | train_loss: 1.1643 | train_acc: 0.5937 | test_loss: 1.1802 | test_acc: 0.5849
# Epoch: 77 | train_loss: 1.1318 | train_acc: 0.6030 | test_loss: 1.2300 | test_acc: 0.5671
# Epoch: 78 | train_loss: 1.1635 | train_acc: 0.5902 | test_loss: 1.3004 | test_acc: 0.5736
# Epoch: 79 | train_loss: 1.1187 | train_acc: 0.6078 | test_loss: 1.1475 | test_acc: 0.5903
# Epoch: 80 | train_loss: 1.3664 | train_acc: 0.5273 | test_loss: 1.4742 | test_acc: 0.4938
# Epoch: 81 | train_loss: 1.3263 | train_acc: 0.5308 | test_loss: 1.2936 | test_acc: 0.5387
# Epoch: 82 | train_loss: 1.2574 | train_acc: 0.5619 | test_loss: 1.2842 | test_acc: 0.5404
# Epoch: 83 | train_loss: 1.3170 | train_acc: 0.5365 | test_loss: 1.2741 | test_acc: 0.5496
# Epoch: 84 | train_loss: 1.1997 | train_acc: 0.5799 | test_loss: 1.2449 | test_acc: 0.5649
# Epoch: 85 | train_loss: 1.1580 | train_acc: 0.5972 | test_loss: 1.2225 | test_acc: 0.5622
# Epoch: 86 | train_loss: 1.3332 | train_acc: 0.5428 | test_loss: 1.3090 | test_acc: 0.5384
# Epoch: 87 | train_loss: 1.2041 | train_acc: 0.5836 | test_loss: 1.2773 | test_acc: 0.5569
# Epoch: 88 | train_loss: 1.2925 | train_acc: 0.5396 | test_loss: 1.2805 | test_acc: 0.5557
# Epoch: 89 | train_loss: 1.1854 | train_acc: 0.5853 | test_loss: 1.2538 | test_acc: 0.5529
# Epoch: 90 | train_loss: 1.1577 | train_acc: 0.5830 | test_loss: 1.2084 | test_acc: 0.5698
# Epoch: 91 | train_loss: 1.1287 | train_acc: 0.6008 | test_loss: 1.1887 | test_acc: 0.5803
# Epoch: 92 | train_loss: 1.1174 | train_acc: 0.6096 | test_loss: 1.2352 | test_acc: 0.5716
# Epoch: 93 | train_loss: 1.0956 | train_acc: 0.6137 | test_loss: 1.1419 | test_acc: 0.5975
# Epoch: 94 | train_loss: 1.0729 | train_acc: 0.6170 | test_loss: 1.3053 | test_acc: 0.5456
# Epoch: 95 | train_loss: 1.1240 | train_acc: 0.6034 | test_loss: 1.1656 | test_acc: 0.5916
# Epoch: 96 | train_loss: 1.0955 | train_acc: 0.6169 | test_loss: 1.1949 | test_acc: 0.5754
# Epoch: 97 | train_loss: 1.0756 | train_acc: 0.6227 | test_loss: 1.1637 | test_acc: 0.5767
# Epoch: 98 | train_loss: 1.1048 | train_acc: 0.6112 | test_loss: 1.1683 | test_acc: 0.5881
# Epoch: 99 | train_loss: 1.1075 | train_acc: 0.6071 | test_loss: 1.1406 | test_acc: 0.5976
# Epoch: 100 | train_loss: 1.0803 | train_acc: 0.6246 | test_loss: 1.1498 | test_acc: 0.5916
# Epoch: 101 | train_loss: 1.0677 | train_acc: 0.6382 | test_loss: 1.1695 | test_acc: 0.5949
# Epoch: 102 | train_loss: 1.1933 | train_acc: 0.5911 | test_loss: 1.4150 | test_acc: 0.5090
# Epoch: 103 | train_loss: 1.2196 | train_acc: 0.5727 | test_loss: 1.1694 | test_acc: 0.5881
# Epoch: 104 | train_loss: 1.2092 | train_acc: 0.5869 | test_loss: 1.5468 | test_acc: 0.4322
# Epoch: 105 | train_loss: 1.3162 | train_acc: 0.5329 | test_loss: 1.2521 | test_acc: 0.5550
# Epoch: 106 | train_loss: 1.2002 | train_acc: 0.5839 | test_loss: 1.2117 | test_acc: 0.5648
# Epoch: 107 | train_loss: 1.1523 | train_acc: 0.5963 | test_loss: 1.1996 | test_acc: 0.5768
# Epoch: 108 | train_loss: 1.1254 | train_acc: 0.6067 | test_loss: 1.1508 | test_acc: 0.5823
# Epoch: 109 | train_loss: 1.1016 | train_acc: 0.6162 | test_loss: 1.1946 | test_acc: 0.5736
# Epoch: 110 | train_loss: 1.0826 | train_acc: 0.6207 | test_loss: 1.1420 | test_acc: 0.5868
# Epoch: 111 | train_loss: 1.0795 | train_acc: 0.6239 | test_loss: 1.1569 | test_acc: 0.5908
# Epoch: 112 | train_loss: 1.0579 | train_acc: 0.6326 | test_loss: 1.1358 | test_acc: 0.5916
# Epoch: 113 | train_loss: 1.0536 | train_acc: 0.6412 | test_loss: 1.1082 | test_acc: 0.6115
# Epoch: 114 | train_loss: 1.0383 | train_acc: 0.6402 | test_loss: 1.1782 | test_acc: 0.5902
# Epoch: 115 | train_loss: 1.4008 | train_acc: 0.5194 | test_loss: 1.2496 | test_acc: 0.5645
# Epoch: 116 | train_loss: 1.1234 | train_acc: 0.6107 | test_loss: 1.1654 | test_acc: 0.5923
# Epoch: 117 | train_loss: 1.0950 | train_acc: 0.6206 | test_loss: 1.1610 | test_acc: 0.5928
# Epoch: 118 | train_loss: 1.2987 | train_acc: 0.5628 | test_loss: 1.4400 | test_acc: 0.4930
# Epoch: 119 | train_loss: 1.2705 | train_acc: 0.5617 | test_loss: 1.2378 | test_acc: 0.5524
# Epoch: 120 | train_loss: 1.4383 | train_acc: 0.5139 | test_loss: 1.3491 | test_acc: 0.5138
# Epoch: 121 | train_loss: 1.2399 | train_acc: 0.5660 | test_loss: 1.2772 | test_acc: 0.5550
# Epoch: 122 | train_loss: 1.1523 | train_acc: 0.6032 | test_loss: 1.1942 | test_acc: 0.5857
# Epoch: 123 | train_loss: 1.1038 | train_acc: 0.6230 | test_loss: 1.2985 | test_acc: 0.5564
# Epoch: 124 | train_loss: 1.1355 | train_acc: 0.6008 | test_loss: 1.1909 | test_acc: 0.5885
# Epoch: 125 | train_loss: 1.0744 | train_acc: 0.6250 | test_loss: 1.1355 | test_acc: 0.6050
# Epoch: 126 | train_loss: 1.3658 | train_acc: 0.5634 | test_loss: 1.4623 | test_acc: 0.5070
# Epoch: 127 | train_loss: 1.2555 | train_acc: 0.5705 | test_loss: 1.2737 | test_acc: 0.5549
# Epoch: 128 | train_loss: 1.1512 | train_acc: 0.6031 | test_loss: 1.1933 | test_acc: 0.5929
# Epoch: 129 | train_loss: 1.0701 | train_acc: 0.6267 | test_loss: 1.1312 | test_acc: 0.6015
# Epoch: 130 | train_loss: 1.0778 | train_acc: 0.6293 | test_loss: 1.3244 | test_acc: 0.5782
# Epoch: 131 | train_loss: 1.0818 | train_acc: 0.6297 | test_loss: 1.1028 | test_acc: 0.6137
# Epoch: 132 | train_loss: 1.0730 | train_acc: 0.6314 | test_loss: 1.1318 | test_acc: 0.6035
# Epoch: 133 | train_loss: 1.0695 | train_acc: 0.6333 | test_loss: 1.1206 | test_acc: 0.5990
# Epoch: 134 | train_loss: 1.3516 | train_acc: 0.5395 | test_loss: 1.5147 | test_acc: 0.4726
# Epoch: 135 | train_loss: 1.3220 | train_acc: 0.5327 | test_loss: 1.2823 | test_acc: 0.5409
# Epoch: 136 | train_loss: 1.2120 | train_acc: 0.5820 | test_loss: 1.2175 | test_acc: 0.5748
# Epoch: 137 | train_loss: 1.1534 | train_acc: 0.5974 | test_loss: 1.1935 | test_acc: 0.5802
# Epoch: 138 | train_loss: 1.1451 | train_acc: 0.5933 | test_loss: 1.1590 | test_acc: 0.5902
# Epoch: 139 | train_loss: 1.1353 | train_acc: 0.6004 | test_loss: 1.2833 | test_acc: 0.5427
# Epoch: 140 | train_loss: 1.1289 | train_acc: 0.5967 | test_loss: 1.1653 | test_acc: 0.5860
# Epoch: 141 | train_loss: 1.1028 | train_acc: 0.6128 | test_loss: 1.1346 | test_acc: 0.5994
# Epoch: 142 | train_loss: 1.0370 | train_acc: 0.6370 | test_loss: 1.1251 | test_acc: 0.6004
# Epoch: 143 | train_loss: 1.1147 | train_acc: 0.6072 | test_loss: 1.2451 | test_acc: 0.5664
# Epoch: 144 | train_loss: 1.1500 | train_acc: 0.6146 | test_loss: 1.2287 | test_acc: 0.5801
# Epoch: 145 | train_loss: 1.1330 | train_acc: 0.5964 | test_loss: 1.2735 | test_acc: 0.5362
# Epoch: 146 | train_loss: 1.2172 | train_acc: 0.5702 | test_loss: 1.1412 | test_acc: 0.6015
# Epoch: 147 | train_loss: 1.0359 | train_acc: 0.6399 | test_loss: 1.1186 | test_acc: 0.6048
# Epoch: 148 | train_loss: 1.0344 | train_acc: 0.6427 | test_loss: 1.0960 | test_acc: 0.5981
# Epoch: 149 | train_loss: 1.0214 | train_acc: 0.6453 | test_loss: 1.1051 | test_acc: 0.6128
# Epoch: 150 | train_loss: 0.9999 | train_acc: 0.6544 | test_loss: 1.1047 | test_acc: 0.6255
# Total training time: 74.277 seconds

# %%
plot_loss_curves(model_7_results, Save=True, filename="model_7_training")

# %% [markdown]
# ### 10.2 Using early stopping with the LSTM model
# Careful observation of previous training results lead us to the conclusion to train the next LSTM model for 165 epochs.

# %%
# Instantiating a new LSTM model and putting it to device
torch.manual_seed(RANDOM_SEED)
model_8 = LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_8
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_8.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 165

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_8
model_8_results = train_with_augmentation(model=model_8,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="mfcc",
                                                             segments=10,
                                                             model_name="LSTMClassifierV0"
                                                             )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/165 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.1299 | train_acc: 0.2627 | test_loss: 1.8690 | test_acc: 0.3570
# Epoch: 2 | train_loss: 1.7577 | train_acc: 0.3698 | test_loss: 1.6153 | test_acc: 0.4177
# Epoch: 3 | train_loss: 1.5783 | train_acc: 0.4419 | test_loss: 1.4649 | test_acc: 0.4923
# Epoch: 4 | train_loss: 1.5016 | train_acc: 0.4728 | test_loss: 1.3905 | test_acc: 0.5076
# Epoch: 5 | train_loss: 1.4054 | train_acc: 0.5021 | test_loss: 1.3613 | test_acc: 0.5237
# Epoch: 6 | train_loss: 1.3785 | train_acc: 0.5093 | test_loss: 1.3150 | test_acc: 0.5437
# Epoch: 7 | train_loss: 1.3330 | train_acc: 0.5353 | test_loss: 1.2600 | test_acc: 0.5468
# Epoch: 8 | train_loss: 1.3037 | train_acc: 0.5354 | test_loss: 1.2834 | test_acc: 0.5562
# Epoch: 9 | train_loss: 1.3130 | train_acc: 0.5305 | test_loss: 1.2536 | test_acc: 0.5510
# Epoch: 10 | train_loss: 1.2546 | train_acc: 0.5537 | test_loss: 1.2546 | test_acc: 0.5463
# Epoch: 11 | train_loss: 1.2456 | train_acc: 0.5605 | test_loss: 1.3518 | test_acc: 0.5390
# Epoch: 12 | train_loss: 1.2256 | train_acc: 0.5697 | test_loss: 1.2368 | test_acc: 0.5550
# Epoch: 13 | train_loss: 1.1961 | train_acc: 0.5837 | test_loss: 1.1999 | test_acc: 0.5776
# Epoch: 14 | train_loss: 1.1729 | train_acc: 0.5885 | test_loss: 1.1479 | test_acc: 0.5882
# Epoch: 15 | train_loss: 1.1673 | train_acc: 0.5808 | test_loss: 1.1654 | test_acc: 0.5709
# Epoch: 16 | train_loss: 1.1560 | train_acc: 0.5903 | test_loss: 1.1714 | test_acc: 0.5830
# Epoch: 17 | train_loss: 1.1326 | train_acc: 0.5986 | test_loss: 1.2380 | test_acc: 0.5360
# Epoch: 18 | train_loss: 1.1545 | train_acc: 0.5963 | test_loss: 1.1301 | test_acc: 0.5937
# Epoch: 19 | train_loss: 1.1229 | train_acc: 0.6065 | test_loss: 1.1671 | test_acc: 0.5764
# Epoch: 20 | train_loss: 1.1196 | train_acc: 0.6047 | test_loss: 1.1507 | test_acc: 0.5910
# Epoch: 21 | train_loss: 1.0798 | train_acc: 0.6258 | test_loss: 1.0959 | test_acc: 0.6068
# Epoch: 22 | train_loss: 1.0559 | train_acc: 0.6322 | test_loss: 1.0798 | test_acc: 0.6134
# Epoch: 23 | train_loss: 1.1418 | train_acc: 0.5966 | test_loss: 1.1099 | test_acc: 0.6076
# Epoch: 24 | train_loss: 1.0657 | train_acc: 0.6231 | test_loss: 1.0575 | test_acc: 0.6182
# Epoch: 25 | train_loss: 1.0271 | train_acc: 0.6461 | test_loss: 1.1048 | test_acc: 0.6097
# Epoch: 26 | train_loss: 1.0072 | train_acc: 0.6575 | test_loss: 1.0544 | test_acc: 0.6341
# Epoch: 27 | train_loss: 1.0361 | train_acc: 0.6352 | test_loss: 1.0470 | test_acc: 0.6321
# Epoch: 28 | train_loss: 0.9907 | train_acc: 0.6606 | test_loss: 1.0481 | test_acc: 0.6395
# Epoch: 29 | train_loss: 0.9835 | train_acc: 0.6541 | test_loss: 1.0176 | test_acc: 0.6420
# Epoch: 30 | train_loss: 1.0021 | train_acc: 0.6461 | test_loss: 0.9947 | test_acc: 0.6490
# Epoch: 31 | train_loss: 0.9729 | train_acc: 0.6590 | test_loss: 1.0274 | test_acc: 0.6438
# Epoch: 32 | train_loss: 0.9652 | train_acc: 0.6652 | test_loss: 1.0292 | test_acc: 0.6376
# Epoch: 33 | train_loss: 0.9829 | train_acc: 0.6607 | test_loss: 0.9951 | test_acc: 0.6477
# Epoch: 34 | train_loss: 0.9299 | train_acc: 0.6745 | test_loss: 1.0297 | test_acc: 0.6389
# Epoch: 35 | train_loss: 0.9569 | train_acc: 0.6678 | test_loss: 1.0016 | test_acc: 0.6496
# Epoch: 36 | train_loss: 0.9280 | train_acc: 0.6795 | test_loss: 1.0428 | test_acc: 0.6351
# Epoch: 37 | train_loss: 0.9385 | train_acc: 0.6747 | test_loss: 1.0104 | test_acc: 0.6369
# Epoch: 38 | train_loss: 0.9395 | train_acc: 0.6811 | test_loss: 0.9850 | test_acc: 0.6542
# Epoch: 39 | train_loss: 0.9150 | train_acc: 0.6864 | test_loss: 0.9589 | test_acc: 0.6661
# Epoch: 40 | train_loss: 0.8698 | train_acc: 0.7030 | test_loss: 0.9590 | test_acc: 0.6589
# Epoch: 41 | train_loss: 0.9113 | train_acc: 0.6896 | test_loss: 1.0001 | test_acc: 0.6449
# Epoch: 42 | train_loss: 0.8898 | train_acc: 0.6870 | test_loss: 0.9663 | test_acc: 0.6644
# Epoch: 43 | train_loss: 0.8866 | train_acc: 0.6926 | test_loss: 1.0004 | test_acc: 0.6597
# Epoch: 44 | train_loss: 0.8919 | train_acc: 0.7017 | test_loss: 0.9650 | test_acc: 0.6696
# Epoch: 45 | train_loss: 0.8577 | train_acc: 0.7030 | test_loss: 0.9513 | test_acc: 0.6718
# Epoch: 46 | train_loss: 0.8364 | train_acc: 0.7181 | test_loss: 0.9406 | test_acc: 0.6823
# Epoch: 47 | train_loss: 0.8841 | train_acc: 0.7059 | test_loss: 0.9419 | test_acc: 0.6750
# Epoch: 48 | train_loss: 0.8392 | train_acc: 0.7120 | test_loss: 0.9667 | test_acc: 0.6623
# Epoch: 49 | train_loss: 0.7971 | train_acc: 0.7292 | test_loss: 0.9069 | test_acc: 0.6919
# Epoch: 50 | train_loss: 0.8291 | train_acc: 0.7164 | test_loss: 0.9140 | test_acc: 0.6761
# Epoch: 51 | train_loss: 0.8093 | train_acc: 0.7200 | test_loss: 0.9297 | test_acc: 0.6706
# Epoch: 52 | train_loss: 0.7950 | train_acc: 0.7317 | test_loss: 0.9201 | test_acc: 0.6753
# Epoch: 53 | train_loss: 0.7910 | train_acc: 0.7291 | test_loss: 0.9053 | test_acc: 0.6904
# Epoch: 54 | train_loss: 0.7634 | train_acc: 0.7410 | test_loss: 0.9423 | test_acc: 0.6737
# Epoch: 55 | train_loss: 0.7906 | train_acc: 0.7319 | test_loss: 0.8874 | test_acc: 0.6951
# Epoch: 56 | train_loss: 0.7826 | train_acc: 0.7340 | test_loss: 0.8791 | test_acc: 0.6956
# Epoch: 57 | train_loss: 0.7470 | train_acc: 0.7471 | test_loss: 0.9587 | test_acc: 0.6724
# Epoch: 58 | train_loss: 0.8293 | train_acc: 0.7223 | test_loss: 0.8869 | test_acc: 0.6891
# Epoch: 59 | train_loss: 0.7578 | train_acc: 0.7387 | test_loss: 0.8715 | test_acc: 0.7065
# Epoch: 60 | train_loss: 0.7349 | train_acc: 0.7536 | test_loss: 0.8574 | test_acc: 0.7135
# Epoch: 61 | train_loss: 0.7536 | train_acc: 0.7443 | test_loss: 0.8748 | test_acc: 0.6977
# Epoch: 62 | train_loss: 0.7583 | train_acc: 0.7440 | test_loss: 0.8977 | test_acc: 0.6911
# Epoch: 63 | train_loss: 0.7149 | train_acc: 0.7594 | test_loss: 0.8536 | test_acc: 0.7137
# Epoch: 64 | train_loss: 0.7087 | train_acc: 0.7644 | test_loss: 0.8971 | test_acc: 0.7017
# Epoch: 65 | train_loss: 0.6897 | train_acc: 0.7639 | test_loss: 0.8475 | test_acc: 0.7185
# Epoch: 66 | train_loss: 0.6963 | train_acc: 0.7626 | test_loss: 0.8383 | test_acc: 0.7164
# Epoch: 67 | train_loss: 0.7161 | train_acc: 0.7504 | test_loss: 0.8308 | test_acc: 0.7183
# Epoch: 68 | train_loss: 0.7071 | train_acc: 0.7640 | test_loss: 0.8658 | test_acc: 0.7184
# Epoch: 69 | train_loss: 0.6986 | train_acc: 0.7635 | test_loss: 0.8381 | test_acc: 0.7157
# Epoch: 70 | train_loss: 0.7048 | train_acc: 0.7568 | test_loss: 0.8421 | test_acc: 0.7291
# Epoch: 71 | train_loss: 0.7199 | train_acc: 0.7582 | test_loss: 0.8403 | test_acc: 0.7209
# Epoch: 72 | train_loss: 0.6805 | train_acc: 0.7652 | test_loss: 0.8099 | test_acc: 0.7268
# Epoch: 73 | train_loss: 0.6619 | train_acc: 0.7800 | test_loss: 1.0776 | test_acc: 0.6626
# Epoch: 74 | train_loss: 0.7123 | train_acc: 0.7573 | test_loss: 0.8300 | test_acc: 0.7248
# Epoch: 75 | train_loss: 0.6770 | train_acc: 0.7724 | test_loss: 0.8264 | test_acc: 0.7263
# Epoch: 76 | train_loss: 0.6409 | train_acc: 0.7912 | test_loss: 0.7998 | test_acc: 0.7318
# Epoch: 77 | train_loss: 0.6675 | train_acc: 0.7781 | test_loss: 0.7792 | test_acc: 0.7330
# Epoch: 78 | train_loss: 0.6415 | train_acc: 0.7845 | test_loss: 0.8425 | test_acc: 0.7178
# Epoch: 79 | train_loss: 0.6219 | train_acc: 0.7905 | test_loss: 0.7722 | test_acc: 0.7453
# Epoch: 80 | train_loss: 0.6303 | train_acc: 0.7908 | test_loss: 0.7912 | test_acc: 0.7336
# Epoch: 81 | train_loss: 0.6099 | train_acc: 0.7936 | test_loss: 0.8142 | test_acc: 0.7329
# Epoch: 82 | train_loss: 0.6067 | train_acc: 0.7951 | test_loss: 0.8102 | test_acc: 0.7388
# Epoch: 83 | train_loss: 0.6219 | train_acc: 0.7905 | test_loss: 0.7933 | test_acc: 0.7282
# Epoch: 84 | train_loss: 0.6311 | train_acc: 0.7842 | test_loss: 0.8000 | test_acc: 0.7254
# Epoch: 85 | train_loss: 0.5954 | train_acc: 0.8059 | test_loss: 0.7863 | test_acc: 0.7388
# Epoch: 86 | train_loss: 0.5774 | train_acc: 0.8080 | test_loss: 0.7673 | test_acc: 0.7467
# Epoch: 87 | train_loss: 0.6287 | train_acc: 0.7866 | test_loss: 0.7474 | test_acc: 0.7381
# Epoch: 88 | train_loss: 0.6308 | train_acc: 0.7886 | test_loss: 0.7936 | test_acc: 0.7335
# Epoch: 89 | train_loss: 0.5724 | train_acc: 0.8119 | test_loss: 0.7917 | test_acc: 0.7381
# Epoch: 90 | train_loss: 0.5682 | train_acc: 0.8136 | test_loss: 0.7770 | test_acc: 0.7425
# Epoch: 91 | train_loss: 0.5544 | train_acc: 0.8221 | test_loss: 0.7734 | test_acc: 0.7524
# Epoch: 92 | train_loss: 0.5694 | train_acc: 0.8100 | test_loss: 0.8106 | test_acc: 0.7363
# Epoch: 93 | train_loss: 0.5491 | train_acc: 0.8150 | test_loss: 0.7722 | test_acc: 0.7462
# Epoch: 94 | train_loss: 0.5407 | train_acc: 0.8170 | test_loss: 0.7455 | test_acc: 0.7523
# Epoch: 95 | train_loss: 0.5593 | train_acc: 0.8133 | test_loss: 0.7449 | test_acc: 0.7656
# Epoch: 96 | train_loss: 0.5514 | train_acc: 0.8149 | test_loss: 0.7523 | test_acc: 0.7534
# Epoch: 97 | train_loss: 0.5573 | train_acc: 0.8160 | test_loss: 0.7683 | test_acc: 0.7523
# Epoch: 98 | train_loss: 0.5704 | train_acc: 0.8142 | test_loss: 0.7465 | test_acc: 0.7562
# Epoch: 99 | train_loss: 0.4980 | train_acc: 0.8406 | test_loss: 0.7577 | test_acc: 0.7530
# Epoch: 100 | train_loss: 0.4880 | train_acc: 0.8428 | test_loss: 0.7603 | test_acc: 0.7563
# Epoch: 101 | train_loss: 0.5380 | train_acc: 0.8254 | test_loss: 0.7437 | test_acc: 0.7530
# Epoch: 102 | train_loss: 0.5146 | train_acc: 0.8365 | test_loss: 0.7465 | test_acc: 0.7603
# Epoch: 103 | train_loss: 0.5332 | train_acc: 0.8245 | test_loss: 0.7476 | test_acc: 0.7629
# Epoch: 104 | train_loss: 0.4904 | train_acc: 0.8419 | test_loss: 0.7322 | test_acc: 0.7643
# Epoch: 105 | train_loss: 0.5137 | train_acc: 0.8314 | test_loss: 0.7318 | test_acc: 0.7573
# Epoch: 106 | train_loss: 0.5127 | train_acc: 0.8322 | test_loss: 0.7386 | test_acc: 0.7658
# Epoch: 107 | train_loss: 0.4503 | train_acc: 0.8580 | test_loss: 0.7380 | test_acc: 0.7743
# Epoch: 108 | train_loss: 0.5009 | train_acc: 0.8357 | test_loss: 0.7464 | test_acc: 0.7543
# Epoch: 109 | train_loss: 0.4972 | train_acc: 0.8338 | test_loss: 0.7301 | test_acc: 0.7617
# Epoch: 110 | train_loss: 0.4370 | train_acc: 0.8604 | test_loss: 0.7545 | test_acc: 0.7584
# Epoch: 111 | train_loss: 0.4632 | train_acc: 0.8518 | test_loss: 0.7077 | test_acc: 0.7731
# Epoch: 112 | train_loss: 0.4784 | train_acc: 0.8436 | test_loss: 0.7656 | test_acc: 0.7391
# Epoch: 113 | train_loss: 0.4932 | train_acc: 0.8382 | test_loss: 0.7543 | test_acc: 0.7568
# Epoch: 114 | train_loss: 0.4808 | train_acc: 0.8424 | test_loss: 0.7341 | test_acc: 0.7562
# Epoch: 115 | train_loss: 0.4961 | train_acc: 0.8338 | test_loss: 0.7173 | test_acc: 0.7717
# Epoch: 116 | train_loss: 0.4658 | train_acc: 0.8438 | test_loss: 0.7239 | test_acc: 0.7752
# Epoch: 117 | train_loss: 0.4326 | train_acc: 0.8611 | test_loss: 0.7098 | test_acc: 0.7736
# Epoch: 118 | train_loss: 0.4638 | train_acc: 0.8507 | test_loss: 0.7198 | test_acc: 0.7662
# Epoch: 119 | train_loss: 0.4399 | train_acc: 0.8534 | test_loss: 0.7069 | test_acc: 0.7722
# Epoch: 120 | train_loss: 0.4569 | train_acc: 0.8548 | test_loss: 0.7173 | test_acc: 0.7701
# Epoch: 121 | train_loss: 0.4131 | train_acc: 0.8720 | test_loss: 0.7401 | test_acc: 0.7649
# Epoch: 122 | train_loss: 0.4113 | train_acc: 0.8679 | test_loss: 0.6915 | test_acc: 0.7756
# Epoch: 123 | train_loss: 0.4258 | train_acc: 0.8644 | test_loss: 0.6783 | test_acc: 0.7842
# Epoch: 124 | train_loss: 0.4305 | train_acc: 0.8616 | test_loss: 0.6959 | test_acc: 0.7744
# Epoch: 125 | train_loss: 0.4424 | train_acc: 0.8571 | test_loss: 0.7077 | test_acc: 0.7836
# Epoch: 126 | train_loss: 0.4378 | train_acc: 0.8592 | test_loss: 0.6893 | test_acc: 0.7842
# Epoch: 127 | train_loss: 0.3782 | train_acc: 0.8810 | test_loss: 0.7149 | test_acc: 0.7817
# Epoch: 128 | train_loss: 0.4209 | train_acc: 0.8617 | test_loss: 0.7300 | test_acc: 0.7592
# Epoch: 129 | train_loss: 0.3883 | train_acc: 0.8769 | test_loss: 0.6975 | test_acc: 0.7791
# Epoch: 130 | train_loss: 0.4515 | train_acc: 0.8536 | test_loss: 0.6935 | test_acc: 0.7817
# Epoch: 131 | train_loss: 0.4502 | train_acc: 0.8534 | test_loss: 0.6880 | test_acc: 0.7743
# Epoch: 132 | train_loss: 0.4231 | train_acc: 0.8600 | test_loss: 0.6947 | test_acc: 0.7877
# Epoch: 133 | train_loss: 0.3831 | train_acc: 0.8788 | test_loss: 0.7396 | test_acc: 0.7671
# Epoch: 134 | train_loss: 0.3757 | train_acc: 0.8821 | test_loss: 0.6625 | test_acc: 0.7905
# Epoch: 135 | train_loss: 0.4266 | train_acc: 0.8625 | test_loss: 0.7058 | test_acc: 0.7743
# Epoch: 136 | train_loss: 0.4283 | train_acc: 0.8592 | test_loss: 0.6992 | test_acc: 0.7831
# Epoch: 137 | train_loss: 0.3968 | train_acc: 0.8734 | test_loss: 0.7246 | test_acc: 0.7784
# Epoch: 138 | train_loss: 0.4068 | train_acc: 0.8701 | test_loss: 0.7085 | test_acc: 0.7751
# Epoch: 139 | train_loss: 0.3738 | train_acc: 0.8795 | test_loss: 0.6941 | test_acc: 0.7858
# Epoch: 140 | train_loss: 0.3573 | train_acc: 0.8905 | test_loss: 0.6784 | test_acc: 0.7950
# Epoch: 141 | train_loss: 0.3817 | train_acc: 0.8798 | test_loss: 0.7112 | test_acc: 0.7864
# Epoch: 142 | train_loss: 0.4140 | train_acc: 0.8676 | test_loss: 0.7012 | test_acc: 0.7850
# Epoch: 143 | train_loss: 0.3645 | train_acc: 0.8835 | test_loss: 0.8597 | test_acc: 0.7377
# Epoch: 144 | train_loss: 0.4146 | train_acc: 0.8693 | test_loss: 0.6866 | test_acc: 0.7758
# Epoch: 145 | train_loss: 0.3115 | train_acc: 0.9015 | test_loss: 0.7241 | test_acc: 0.7753
# Epoch: 146 | train_loss: 0.3681 | train_acc: 0.8863 | test_loss: 0.6638 | test_acc: 0.7911
# Epoch: 147 | train_loss: 0.3895 | train_acc: 0.8768 | test_loss: 0.6758 | test_acc: 0.7830
# Epoch: 148 | train_loss: 0.3791 | train_acc: 0.8808 | test_loss: 0.7043 | test_acc: 0.7838
# Epoch: 149 | train_loss: 0.3542 | train_acc: 0.8874 | test_loss: 0.6919 | test_acc: 0.7875
# Epoch: 150 | train_loss: 0.3354 | train_acc: 0.8943 | test_loss: 0.6963 | test_acc: 0.7897
# Epoch: 151 | train_loss: 0.3489 | train_acc: 0.8890 | test_loss: 0.6662 | test_acc: 0.7989
# Epoch: 152 | train_loss: 0.3087 | train_acc: 0.9030 | test_loss: 0.6835 | test_acc: 0.7952
# Epoch: 153 | train_loss: 0.3193 | train_acc: 0.9003 | test_loss: 0.6577 | test_acc: 0.8057
# Epoch: 154 | train_loss: 0.3277 | train_acc: 0.9003 | test_loss: 0.6743 | test_acc: 0.7962
# Epoch: 155 | train_loss: 0.3780 | train_acc: 0.8773 | test_loss: 0.6746 | test_acc: 0.7955
# Epoch: 156 | train_loss: 0.3474 | train_acc: 0.8901 | test_loss: 0.6626 | test_acc: 0.7996
# Epoch: 157 | train_loss: 0.3648 | train_acc: 0.8866 | test_loss: 0.6680 | test_acc: 0.7918
# Epoch: 158 | train_loss: 0.2851 | train_acc: 0.9108 | test_loss: 0.6672 | test_acc: 0.7952
# Epoch: 159 | train_loss: 0.3344 | train_acc: 0.8935 | test_loss: 0.6979 | test_acc: 0.7830
# Epoch: 160 | train_loss: 0.3585 | train_acc: 0.8828 | test_loss: 0.6875 | test_acc: 0.7856
# Epoch: 161 | train_loss: 0.3071 | train_acc: 0.9031 | test_loss: 0.6729 | test_acc: 0.8023
# Epoch: 162 | train_loss: 0.3239 | train_acc: 0.9008 | test_loss: 0.6423 | test_acc: 0.8064
# Epoch: 163 | train_loss: 0.3002 | train_acc: 0.9055 | test_loss: 0.6964 | test_acc: 0.7819
# Epoch: 164 | train_loss: 0.3057 | train_acc: 0.9034 | test_loss: 0.6884 | test_acc: 0.7989
# Epoch: 165 | train_loss: 0.3535 | train_acc: 0.8856 | test_loss: 0.6492 | test_acc: 0.8083
# Total training time: 148.133 seconds

# %%
plot_loss_curves(model_8_results, Save=True, filename="model_8_training")

# %% [markdown]
# ### 10.3 Using early stopping with the GRU model
# Careful observation of previous training results lead us to the conclusion to train the next GRU model for 110 epochs.

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_9 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_9
# Out:
# GRUClassifierV0(
#   (gru): GRU(13, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_9.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 110

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_9
model_9_results = train_with_augmentation(model=model_9,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="mfcc",
                                                             segments=10,
                                                             model_name="GRUClassifierV0"
                                                             )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0290 | train_acc: 0.2860 | test_loss: 1.8163 | test_acc: 0.3610
# Epoch: 2 | train_loss: 1.7741 | train_acc: 0.3621 | test_loss: 1.6554 | test_acc: 0.4244
# Epoch: 3 | train_loss: 1.6418 | train_acc: 0.4075 | test_loss: 1.5398 | test_acc: 0.4636
# Epoch: 4 | train_loss: 1.5346 | train_acc: 0.4586 | test_loss: 1.4477 | test_acc: 0.4911
# Epoch: 5 | train_loss: 1.4605 | train_acc: 0.4800 | test_loss: 1.3641 | test_acc: 0.5129
# Epoch: 6 | train_loss: 1.3703 | train_acc: 0.5103 | test_loss: 1.2965 | test_acc: 0.5463
# Epoch: 7 | train_loss: 1.3003 | train_acc: 0.5455 | test_loss: 1.2329 | test_acc: 0.5583
# Epoch: 8 | train_loss: 1.2483 | train_acc: 0.5572 | test_loss: 1.1601 | test_acc: 0.5755
# Epoch: 9 | train_loss: 1.1939 | train_acc: 0.5784 | test_loss: 1.1151 | test_acc: 0.5917
# Epoch: 10 | train_loss: 1.1624 | train_acc: 0.5907 | test_loss: 1.1074 | test_acc: 0.5917
# Epoch: 11 | train_loss: 1.1142 | train_acc: 0.6086 | test_loss: 1.0517 | test_acc: 0.6209
# Epoch: 12 | train_loss: 1.0852 | train_acc: 0.6196 | test_loss: 1.0191 | test_acc: 0.6361
# Epoch: 13 | train_loss: 1.0184 | train_acc: 0.6413 | test_loss: 0.9806 | test_acc: 0.6468
# Epoch: 14 | train_loss: 0.9720 | train_acc: 0.6624 | test_loss: 0.9545 | test_acc: 0.6487
# Epoch: 15 | train_loss: 0.9461 | train_acc: 0.6681 | test_loss: 0.9450 | test_acc: 0.6562
# Epoch: 16 | train_loss: 0.9213 | train_acc: 0.6716 | test_loss: 0.9188 | test_acc: 0.6715
# Epoch: 17 | train_loss: 0.8860 | train_acc: 0.6976 | test_loss: 0.8914 | test_acc: 0.6813
# Epoch: 18 | train_loss: 0.9285 | train_acc: 0.6769 | test_loss: 0.9330 | test_acc: 0.6662
# Epoch: 19 | train_loss: 0.8739 | train_acc: 0.6930 | test_loss: 0.8735 | test_acc: 0.6930
# Epoch: 20 | train_loss: 0.8447 | train_acc: 0.7056 | test_loss: 0.8475 | test_acc: 0.6940
# Epoch: 21 | train_loss: 0.8667 | train_acc: 0.6971 | test_loss: 0.8391 | test_acc: 0.7047
# Epoch: 22 | train_loss: 0.8223 | train_acc: 0.7103 | test_loss: 0.8564 | test_acc: 0.6949
# Epoch: 23 | train_loss: 0.8192 | train_acc: 0.7200 | test_loss: 0.8412 | test_acc: 0.6984
# Epoch: 24 | train_loss: 0.8095 | train_acc: 0.7202 | test_loss: 0.8517 | test_acc: 0.6955
# Epoch: 25 | train_loss: 0.7883 | train_acc: 0.7282 | test_loss: 0.8192 | test_acc: 0.7084
# Epoch: 26 | train_loss: 0.7769 | train_acc: 0.7321 | test_loss: 0.8222 | test_acc: 0.7016
# Epoch: 27 | train_loss: 0.7421 | train_acc: 0.7430 | test_loss: 0.7799 | test_acc: 0.7209
# Epoch: 28 | train_loss: 0.7303 | train_acc: 0.7500 | test_loss: 0.8068 | test_acc: 0.7138
# Epoch: 29 | train_loss: 0.6991 | train_acc: 0.7588 | test_loss: 0.7585 | test_acc: 0.7324
# Epoch: 30 | train_loss: 0.7086 | train_acc: 0.7537 | test_loss: 0.8000 | test_acc: 0.7096
# Epoch: 31 | train_loss: 0.6860 | train_acc: 0.7645 | test_loss: 0.7522 | test_acc: 0.7406
# Epoch: 32 | train_loss: 0.6873 | train_acc: 0.7662 | test_loss: 0.7367 | test_acc: 0.7465
# Epoch: 33 | train_loss: 0.6660 | train_acc: 0.7721 | test_loss: 0.7341 | test_acc: 0.7571
# Epoch: 34 | train_loss: 0.6643 | train_acc: 0.7731 | test_loss: 0.7413 | test_acc: 0.7472
# Epoch: 35 | train_loss: 0.6643 | train_acc: 0.7711 | test_loss: 0.7365 | test_acc: 0.7416
# Epoch: 36 | train_loss: 0.6379 | train_acc: 0.7804 | test_loss: 0.7304 | test_acc: 0.7452
# Epoch: 37 | train_loss: 0.6439 | train_acc: 0.7808 | test_loss: 0.7356 | test_acc: 0.7458
# Epoch: 38 | train_loss: 0.6113 | train_acc: 0.7875 | test_loss: 0.7230 | test_acc: 0.7512
# Epoch: 39 | train_loss: 0.6093 | train_acc: 0.7937 | test_loss: 0.6960 | test_acc: 0.7630
# Epoch: 40 | train_loss: 0.6424 | train_acc: 0.7808 | test_loss: 0.7018 | test_acc: 0.7604
# Epoch: 41 | train_loss: 0.5965 | train_acc: 0.7911 | test_loss: 0.7065 | test_acc: 0.7625
# Epoch: 42 | train_loss: 0.5960 | train_acc: 0.7987 | test_loss: 0.7039 | test_acc: 0.7545
# Epoch: 43 | train_loss: 0.5764 | train_acc: 0.7988 | test_loss: 0.6972 | test_acc: 0.7671
# Epoch: 44 | train_loss: 0.5485 | train_acc: 0.8145 | test_loss: 0.6886 | test_acc: 0.7608
# Epoch: 45 | train_loss: 0.5820 | train_acc: 0.8030 | test_loss: 0.7021 | test_acc: 0.7624
# Epoch: 46 | train_loss: 0.5583 | train_acc: 0.8104 | test_loss: 0.7073 | test_acc: 0.7597
# Epoch: 47 | train_loss: 0.5836 | train_acc: 0.8014 | test_loss: 0.7557 | test_acc: 0.7473
# Epoch: 48 | train_loss: 0.5310 | train_acc: 0.8207 | test_loss: 0.7015 | test_acc: 0.7671
# Epoch: 49 | train_loss: 0.5252 | train_acc: 0.8190 | test_loss: 0.6945 | test_acc: 0.7659
# Epoch: 50 | train_loss: 0.5237 | train_acc: 0.8239 | test_loss: 0.6677 | test_acc: 0.7691
# Epoch: 51 | train_loss: 0.5291 | train_acc: 0.8215 | test_loss: 0.6709 | test_acc: 0.7799
# Epoch: 52 | train_loss: 0.5172 | train_acc: 0.8286 | test_loss: 0.6577 | test_acc: 0.7765
# Epoch: 53 | train_loss: 0.4930 | train_acc: 0.8360 | test_loss: 0.6866 | test_acc: 0.7737
# Epoch: 54 | train_loss: 0.5218 | train_acc: 0.8217 | test_loss: 0.6836 | test_acc: 0.7618
# Epoch: 55 | train_loss: 0.4802 | train_acc: 0.8401 | test_loss: 0.6504 | test_acc: 0.7872
# Epoch: 56 | train_loss: 0.5455 | train_acc: 0.8176 | test_loss: 0.6596 | test_acc: 0.7831
# Epoch: 57 | train_loss: 0.5026 | train_acc: 0.8316 | test_loss: 0.6814 | test_acc: 0.7653
# Epoch: 58 | train_loss: 0.4735 | train_acc: 0.8392 | test_loss: 0.6436 | test_acc: 0.7764
# Epoch: 59 | train_loss: 0.4690 | train_acc: 0.8463 | test_loss: 0.6373 | test_acc: 0.7839
# Epoch: 60 | train_loss: 0.4572 | train_acc: 0.8489 | test_loss: 0.6316 | test_acc: 0.7879
# Epoch: 61 | train_loss: 0.4826 | train_acc: 0.8459 | test_loss: 0.6185 | test_acc: 0.7878
# Epoch: 62 | train_loss: 0.4453 | train_acc: 0.8547 | test_loss: 0.6259 | test_acc: 0.7860
# Epoch: 63 | train_loss: 0.4269 | train_acc: 0.8530 | test_loss: 0.6234 | test_acc: 0.7966
# Epoch: 64 | train_loss: 0.4542 | train_acc: 0.8450 | test_loss: 0.6090 | test_acc: 0.7946
# Epoch: 65 | train_loss: 0.4406 | train_acc: 0.8505 | test_loss: 0.6158 | test_acc: 0.7876
# Epoch: 66 | train_loss: 0.4262 | train_acc: 0.8606 | test_loss: 0.6215 | test_acc: 0.7933
# Epoch: 67 | train_loss: 0.4146 | train_acc: 0.8616 | test_loss: 0.6200 | test_acc: 0.7973
# Epoch: 68 | train_loss: 0.4268 | train_acc: 0.8599 | test_loss: 0.6280 | test_acc: 0.7918
# Epoch: 69 | train_loss: 0.4000 | train_acc: 0.8706 | test_loss: 0.5996 | test_acc: 0.8026
# Epoch: 70 | train_loss: 0.3759 | train_acc: 0.8759 | test_loss: 0.6381 | test_acc: 0.8073
# Epoch: 71 | train_loss: 0.4094 | train_acc: 0.8643 | test_loss: 0.6290 | test_acc: 0.7919
# Epoch: 72 | train_loss: 0.4064 | train_acc: 0.8624 | test_loss: 0.6716 | test_acc: 0.7918
# Epoch: 73 | train_loss: 0.4144 | train_acc: 0.8638 | test_loss: 0.5637 | test_acc: 0.8019
# Epoch: 74 | train_loss: 0.3996 | train_acc: 0.8717 | test_loss: 0.5624 | test_acc: 0.8086
# Epoch: 75 | train_loss: 0.4123 | train_acc: 0.8616 | test_loss: 0.6236 | test_acc: 0.7994
# Epoch: 76 | train_loss: 0.3856 | train_acc: 0.8731 | test_loss: 0.6264 | test_acc: 0.7852
# Epoch: 77 | train_loss: 0.4013 | train_acc: 0.8654 | test_loss: 0.6011 | test_acc: 0.8052
# Epoch: 78 | train_loss: 0.3752 | train_acc: 0.8787 | test_loss: 0.6517 | test_acc: 0.7846
# Epoch: 79 | train_loss: 0.3926 | train_acc: 0.8694 | test_loss: 0.5982 | test_acc: 0.8045
# Epoch: 80 | train_loss: 0.3455 | train_acc: 0.8885 | test_loss: 0.6309 | test_acc: 0.8021
# Epoch: 81 | train_loss: 0.3520 | train_acc: 0.8861 | test_loss: 0.5843 | test_acc: 0.8094
# Epoch: 82 | train_loss: 0.3560 | train_acc: 0.8859 | test_loss: 0.6090 | test_acc: 0.7925
# Epoch: 83 | train_loss: 0.3555 | train_acc: 0.8874 | test_loss: 0.5950 | test_acc: 0.8033
# Epoch: 84 | train_loss: 0.3640 | train_acc: 0.8822 | test_loss: 0.5761 | test_acc: 0.8093
# Epoch: 85 | train_loss: 0.3435 | train_acc: 0.8884 | test_loss: 0.5775 | test_acc: 0.8131
# Epoch: 86 | train_loss: 0.3914 | train_acc: 0.8671 | test_loss: 0.5620 | test_acc: 0.8153
# Epoch: 87 | train_loss: 0.3621 | train_acc: 0.8846 | test_loss: 0.5896 | test_acc: 0.8125
# Epoch: 88 | train_loss: 0.3575 | train_acc: 0.8858 | test_loss: 0.5921 | test_acc: 0.8072
# Epoch: 89 | train_loss: 0.3338 | train_acc: 0.8909 | test_loss: 0.5594 | test_acc: 0.8192
# Epoch: 90 | train_loss: 0.3188 | train_acc: 0.8974 | test_loss: 0.5726 | test_acc: 0.8107
# Epoch: 91 | train_loss: 0.3527 | train_acc: 0.8851 | test_loss: 0.5649 | test_acc: 0.8199
# Epoch: 92 | train_loss: 0.2962 | train_acc: 0.9074 | test_loss: 0.5718 | test_acc: 0.8021
# Epoch: 93 | train_loss: 0.3142 | train_acc: 0.8949 | test_loss: 0.5487 | test_acc: 0.8267
# Epoch: 94 | train_loss: 0.3248 | train_acc: 0.8949 | test_loss: 0.5760 | test_acc: 0.8127
# Epoch: 95 | train_loss: 0.3335 | train_acc: 0.8935 | test_loss: 0.5617 | test_acc: 0.8205
# Epoch: 96 | train_loss: 0.2793 | train_acc: 0.9152 | test_loss: 0.5612 | test_acc: 0.8134
# Epoch: 97 | train_loss: 0.3081 | train_acc: 0.9015 | test_loss: 0.5519 | test_acc: 0.8192
# Epoch: 98 | train_loss: 0.3272 | train_acc: 0.8989 | test_loss: 0.5620 | test_acc: 0.8220
# Epoch: 99 | train_loss: 0.3198 | train_acc: 0.8974 | test_loss: 0.5538 | test_acc: 0.8207
# Epoch: 100 | train_loss: 0.2905 | train_acc: 0.9057 | test_loss: 0.5931 | test_acc: 0.8148
# Epoch: 101 | train_loss: 0.3061 | train_acc: 0.9029 | test_loss: 0.5606 | test_acc: 0.8186
# Epoch: 102 | train_loss: 0.3242 | train_acc: 0.8964 | test_loss: 0.5581 | test_acc: 0.8248
# Epoch: 103 | train_loss: 0.3097 | train_acc: 0.8983 | test_loss: 0.5444 | test_acc: 0.8319
# Epoch: 104 | train_loss: 0.3103 | train_acc: 0.8971 | test_loss: 0.5999 | test_acc: 0.8133
# Epoch: 105 | train_loss: 0.2836 | train_acc: 0.9096 | test_loss: 0.5680 | test_acc: 0.8257
# Epoch: 106 | train_loss: 0.3207 | train_acc: 0.8938 | test_loss: 0.6046 | test_acc: 0.8153
# Epoch: 107 | train_loss: 0.2985 | train_acc: 0.9063 | test_loss: 0.5341 | test_acc: 0.8261
# Epoch: 108 | train_loss: 0.2906 | train_acc: 0.9050 | test_loss: 0.5951 | test_acc: 0.8073
# Epoch: 109 | train_loss: 0.2988 | train_acc: 0.9023 | test_loss: 0.5733 | test_acc: 0.8120
# Epoch: 110 | train_loss: 0.2728 | train_acc: 0.9121 | test_loss: 0.5470 | test_acc: 0.8283
# Total training time: 63.148 seconds

# %%
plot_loss_curves(model_9_results, Save=True, filename="model_9_training")

# %% [markdown]
# ## 11. Evaluating our models on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate our models.

# %%
# Evaluate the RNN on the test set
evaluation = test_step(model=model_7,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 1.1131 | test acc = 0.6127

# %%
# Evaluate the LSTM on the test set
evaluation = test_step(model=model_8,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.6053 | test acc = 0.8157

# %%
# Evaluate the GRU on the test set
evaluation = test_step(model=model_9,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.5531 | test acc = 0.8200

# %% [markdown]
# We can see that the GRU had the best performance out of the three models as it scored an accuracy of 82% which is very good considering we have 10 classes. The LSTN follows with an accuracy of 81,5%. The RNN comes next with an accuracy of 61%.

# %% [markdown]
# ## 12. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use our models to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2499 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilities first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.
#
# Changing the `model` and `index` arguments on the `predict()` function can let us make further testing.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Printing the shape to see how many indexes we have
X_test.shape
# Out:
# torch.Size([2499, 130, 13])

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("RNN prediction")
predict(model=model_7,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# RNN prediction
# Target: jazz, Predicted label: jazz

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("LSTM prediction")
predict(model=model_8,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# LSTM prediction
# Target: jazz, Predicted label: jazz

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("GRU prediction")
predict(model=model_9,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# GRU prediction
# Target: jazz, Predicted label: jazz

# %% [markdown]
# ## 13. Making a confusion matrix for further evaluation
#
# For a good visualisation of our model's performance, we can use a confusion matrix for our models. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.24.0

# %% [markdown]
# ### 13.1 RNN confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_7.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_7(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "RNN_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that our model performs relatively well. Most of the values are concentrated on the main diagonal, which is an encouraging outcome. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. The genres that the RNN model has the most mismatches are "rock" and "disco". We do not see that many errors in distinguishing that many genres for "classical". Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.

# %% [markdown]
# ### 13.2 LSTM confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_8.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_8(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "LSTM_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that the LSTM model performs relatively well. Most of the genres have a good percentage of right classifications. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. We see that the genres with the less correct classifications are "rock" and "country". The genre that is best classified is "classical". Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.

# %% [markdown]
# ### 13.3 GRU confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_9.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_9(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "GRU_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# The GRU model demonstrates solid performance, as evidenced by the high concentration of values along the main diagonal. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. We see that the genres with the less correct classifications are "rock" and "country". The genre that is best classified is "classical". Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.
