# %% [markdown]
# # Music Genre Classification using convolutional neural network (CNN) models and Mel-frequency coefficients (MFCCs)

# %% [markdown]
# ### 0. Importing libraries, setting up device agnostic code
#
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used. Furthermore, we set a random seed so that a fixed seed will maintain consistency in experimental results. This will also make it easier to compare different approaches.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torchaudio.datasets import GTZAN
import matplotlib.pyplot as plt

# %%
# Set random seeds
RANDOM_SEED = 42

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
# !nvidia-smi
# Out:
# Tue Sep 30 00:53:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.15                 Driver Version: 581.15         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce MX150         WDDM  |   00000000:02:00.0 Off |                  N/A |
# | N/A   47C    P0            N/A  / 5001W |       0MiB /   2048MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### 1. Loading data
#
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors. We are also going to create a *classes* list in order to use the name of the classes for predictions later.
#
# The CNN models expect the following shape as input: `(batch_size, channels, mfcc_coeficient, time_frame)`. As a result we are going to use the `permute()` method in order to have the tensors in the intended shape.

# %%
# Create function to load mfcc data from json file
DATASET_PATH = "data_full.json"

def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['mfcc'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from json file
DATASET_PATH = "data_full.json"

def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((9996, 130, 13), (9996,))

# %%
# Turn data into tensors, also unsqueeze and permute, to be ready for CNN
X = torch.from_numpy(inputs).float() # Weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
X = X.permute(0, 2, 1).unsqueeze(1)
X.shape, y.shape
# Out:
# (torch.Size([9996, 1, 13, 130]), torch.Size([9996]))

# %% [markdown]
# ### 2. Create DataSets and DataLoaders
#
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders.
# After loading the data, we split them into three sets: train_set, validation_set and test_set. The validation_set will be used during the training for evaluation. The test_set will be used after the model is ready. In order for it to be exposed in never seen data.
#
# After dividing the sets, we create the respective datasets and dataloaders.

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x0000014241317ED0>, <torch.utils.data.dataloader.DataLoader object at 0x000001422245A150>)
# Length of train dataloader: 188 batches of 32
# Length of validation dataloader: 47 batches of 32
# Length of test dataloader: 79 batches of 32

# %%
# Checking the dataset shapes using test_dataloader
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, num_channels, mfcc_coefficients, time_frames)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample)")
print(test_features_batch[0].shape, "-> (num_channels, mfcc_coefficients, time_frames)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 1, 13, 130]) -> (batch_size, num_channels, mfcc_coefficients, time_frames)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample)
# torch.Size([1, 13, 130]) -> (num_channels, mfcc_coefficients, time_frames)
# tensor(1) -> (label)

# %% [markdown]
# ### 3. Data visualization
#
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize an mfcc representation of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, we can distinguish the 13 coefficients in the vertical axis as parallel lines of the same thickness.
#
# A second visualization is implemented later, in order to view various representations of different genres.
#
# The music genre of each representation can also be viewed.

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
CLASS_NUM = np.random.randint(len(X))
mfcc_example = X[CLASS_NUM].squeeze(0).numpy() # squeeze is used because shape is (1, 13, 130)
plt.imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
plt.colorbar()
plt.title(f"MFCC Example (from tensor) | label: {classes[y[CLASS_NUM]]}")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("MFCC Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    mfcc_example = X[idx].squeeze(0).numpy()
    im = axs[row, col].imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("MFCC coefficients")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ### 5. Building a basic CNN model
#
# The architecture of the model is based on a CNN. It uses 3 convolution blocks. Each one consist of a `Conv2d` layer, following a `ReLu()` activation and applying pooling with `MaxPool2d()`. We also use `BatchNorm2d()` in the end. This method helps with reducing the danger of the vanishing/exploding gradients problems. The convolution blocks are followed by a classification block. This consists of two linear layers. The first is activated using `ReLu()` and also a `Dropout()` layer is implemented, to reduce the chances of overfitting. This block acts somehow like a multi-perceptron block, so it takes a vector as input. For that purpose, in the beggining we use a `Flatten()` layer.
#
# A common problem that rises when compiling a CNN model with PyTorch, is that we do not know the shape of the matrix that will occur after implementing the `Flatten()` layer. There are many ways to solve this problem. For that purpose, we include `print()` functions in the `forward()` method. What we do is, we run sample data through the model for a run that will fail. However, due to the `print()` functions, we will be able to see the shape of the matrix after the `Flatten()` layer. The numbers of the shape, are the ones we have to multiply the input_shape of the next `linear()` layer with.
#
# This model will output logits. We can apply an `nn.Softmax()` function to those logits in order to get probabilities. However it is good practise to do this later. Furthermore we are going to use `nn.CrossEntropyLoss` later and this method takes logits as arguments.

# %%
# Compile the network
class CNNClassifierV0(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.block_3(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)
model_0 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_0
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Try a forward pass to find shape that enters classifier
# Extract a sample batch and print shape
sample_batch, label_batch = next(iter(train_dataloader))
print(sample_batch.shape)
print(label_batch.shape)

# Do a test forward pass and print first five logits and probs
logits = model_0(sample_batch.to(device))
probs = torch.softmax(logits, dim=1)
print(logits[:5])
print(probs[:5])
# Out:
# torch.Size([32, 1, 13, 130])
# torch.Size([32])
# tensor([[ 0.0723,  0.1357, -0.0276, -0.2475, -0.0561,  0.0662,  0.2812,  0.1257,
#           0.3070,  0.1346],
#         [ 0.0703,  0.0691,  0.1142,  0.1514, -0.2119,  0.0564,  0.3432,  0.3610,
#          -0.1595, -0.0748],
#         [-0.5032,  0.0696, -0.0357,  0.0506,  0.1468, -0.0501,  0.2032,  0.2284,
#           0.0787, -0.1535],
#         [-0.2098,  0.2525,  0.0807,  0.4059, -0.0635, -0.1349,  0.7546,  0.4174,
#           0.2352, -0.0244],
#         [ 0.0156, -0.1172,  0.2397, -0.4165, -0.1946, -0.2428,  0.3997,  0.0473,
#           0.0521,  0.0820]], device='cuda:0', grad_fn=<SliceBackward0>)
# tensor([[0.0982, 0.1046, 0.0888, 0.0713, 0.0863, 0.0976, 0.1210, 0.1036, 0.1241,
#          0.1045],
#         [0.0982, 0.0981, 0.1027, 0.1065, 0.0741, 0.0969, 0.1291, 0.1314, 0.0781,
#          0.0850],
#         [0.0591, 0.1049, 0.0944, 0.1029, 0.1133, 0.0930, 0.1198, 0.1229, 0.1058,
#          0.0839],
#         [0.0655, 0.1040, 0.0876, 0.1212, 0.0758, 0.0706, 0.1718, 0.1226, 0.1022,
#          0.0788],
#         [0.1004, 0.0879, 0.1256, 0.0651, 0.0813, 0.0775, 0.1473, 0.1036, 0.1041,
#          0.1072]], device='cuda:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# ### 6. Training the model
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure. The optimizer carries a `weight_decay`, this is going to add an L2 regularization to avoid overfitting.
#
# In order to implement the training pipeline, we will create two separate functions:
# * `train_step()`: This function is responsible for the training of the model. It also includes the logic for calculating the accuracy. We could use `torchmetrics.accuracy()`, but instead one can calculate it. We use the `argmax()` method after applying a `softmax()` on the logits that are extracted from the model. This calculation gives us the predicted label, because it returns the index of the highest probability. After that, the accuracy is calculated as the sum of predicted labels that are the same as the labels, divided by the number of samples.
# * `test_step()`: This function will evaluate the loss and accuracy on a set. Initially we will use it on the evaluation set during training.
#
# Those two functions are combined in the `train()` function in order to train the model for a set number of epochs. We also use the `timeit` library to set a timer in order to time the training. The `train()` function returns a dictionary with the results, in order to use them for plotting.

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Train the model
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4615 | train_acc: 0.4702 | test_loss: 1.0680 | test_acc: 0.6150
# Epoch: 2 | train_loss: 1.1088 | train_acc: 0.5973 | test_loss: 0.9474 | test_acc: 0.6573
# Epoch: 3 | train_loss: 0.9440 | train_acc: 0.6652 | test_loss: 0.8247 | test_acc: 0.7007
# Epoch: 4 | train_loss: 0.8270 | train_acc: 0.7097 | test_loss: 0.7924 | test_acc: 0.7237
# Epoch: 5 | train_loss: 0.7578 | train_acc: 0.7267 | test_loss: 0.7703 | test_acc: 0.7255
# Epoch: 6 | train_loss: 0.7016 | train_acc: 0.7514 | test_loss: 0.7184 | test_acc: 0.7466
# Epoch: 7 | train_loss: 0.5984 | train_acc: 0.7856 | test_loss: 0.6855 | test_acc: 0.7809
# Epoch: 8 | train_loss: 0.5695 | train_acc: 0.7929 | test_loss: 0.7189 | test_acc: 0.7573
# Epoch: 9 | train_loss: 0.5327 | train_acc: 0.8101 | test_loss: 0.6754 | test_acc: 0.7812
# Epoch: 10 | train_loss: 0.4992 | train_acc: 0.8274 | test_loss: 0.6888 | test_acc: 0.7758
# Epoch: 11 | train_loss: 0.4505 | train_acc: 0.8390 | test_loss: 0.6397 | test_acc: 0.7849
# Epoch: 12 | train_loss: 0.4293 | train_acc: 0.8494 | test_loss: 0.6405 | test_acc: 0.7911
# Epoch: 13 | train_loss: 0.3885 | train_acc: 0.8636 | test_loss: 0.6676 | test_acc: 0.7886
# Epoch: 14 | train_loss: 0.3748 | train_acc: 0.8687 | test_loss: 0.6442 | test_acc: 0.7907
# Epoch: 15 | train_loss: 0.3097 | train_acc: 0.8897 | test_loss: 0.6560 | test_acc: 0.7953
# Epoch: 16 | train_loss: 0.3329 | train_acc: 0.8845 | test_loss: 0.6185 | test_acc: 0.8133
# Epoch: 17 | train_loss: 0.2996 | train_acc: 0.8970 | test_loss: 0.6816 | test_acc: 0.8004
# Epoch: 18 | train_loss: 0.3089 | train_acc: 0.8966 | test_loss: 0.6186 | test_acc: 0.8152
# Epoch: 19 | train_loss: 0.2500 | train_acc: 0.9119 | test_loss: 0.6649 | test_acc: 0.7898
# Epoch: 20 | train_loss: 0.2581 | train_acc: 0.9078 | test_loss: 0.6446 | test_acc: 0.8092
# Epoch: 21 | train_loss: 0.2679 | train_acc: 0.9049 | test_loss: 0.7012 | test_acc: 0.7848
# Epoch: 22 | train_loss: 0.2336 | train_acc: 0.9180 | test_loss: 0.6128 | test_acc: 0.8172
# Epoch: 23 | train_loss: 0.2286 | train_acc: 0.9197 | test_loss: 0.7275 | test_acc: 0.7738
# Epoch: 24 | train_loss: 0.2100 | train_acc: 0.9324 | test_loss: 0.6742 | test_acc: 0.8037
# Epoch: 25 | train_loss: 0.2042 | train_acc: 0.9316 | test_loss: 0.6912 | test_acc: 0.8011
# Epoch: 26 | train_loss: 0.2272 | train_acc: 0.9165 | test_loss: 0.6771 | test_acc: 0.7964
# Epoch: 27 | train_loss: 0.1994 | train_acc: 0.9305 | test_loss: 0.7103 | test_acc: 0.7898
# Epoch: 28 | train_loss: 0.2037 | train_acc: 0.9279 | test_loss: 0.7032 | test_acc: 0.7945
# Epoch: 29 | train_loss: 0.1932 | train_acc: 0.9338 | test_loss: 0.7630 | test_acc: 0.7807
# Epoch: 30 | train_loss: 0.1739 | train_acc: 0.9402 | test_loss: 0.6880 | test_acc: 0.8005
# Total training time: 53.407 seconds

# %% [markdown]
# ### 7. Plotting the results
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys
model_0_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]]):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, test_loss, label='test_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, test_accuracy, label='test_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# Judging by the plot results, we see that our model is overfitting despite using `Dropout()` layers and L2 regularization. This occurs very early, before the 10th epoch. As next steps of the pipeline, we will try some methods to avoid this phenomenon. We will create and evaluate some models, each of which uses a method to avoid overfitting, in order to see what methods fix the issue. The models and methods we are going to try, are:
# * `model_1`: The model is going to be trained using data augmentation.
# * `model_2`: We are going to use `Dropou2d()` layers in the convolution blocks.
# * `model_3`: We are going to implement _learning rate scheduling_ in the training.
# * `model_4`: We are going to improve the batch normalization by using `InstanceNorm2d()` instead of `BatchNorm2d()`
# * `model_5`: Use all of the above in a model.

# %% [markdown]
# ### 8. Using Data Augmentation
#
# For our next model we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.
#
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and coefficients respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
# We are going to create a new `train_step_with_augmentation()` and `train_with_augmentation` functions by altering our previous training functions in order to train the model with the augmented data. There is no need to use augmentation in validation and testing sets. The rest of the pipeline is the same. In the end we are going to plot the results to see if there is improvement.

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=15),
    T.FrequencyMasking(freq_mask_param=5)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Instantiating a new model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_1 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_1
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train_with_augmentation(model=model_1,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.6241 | train_acc: 0.4048 | test_loss: 1.4322 | test_acc: 0.5025
# Epoch: 2 | train_loss: 1.3209 | train_acc: 0.5113 | test_loss: 1.1584 | test_acc: 0.5562
# Epoch: 3 | train_loss: 1.1999 | train_acc: 0.5636 | test_loss: 1.0784 | test_acc: 0.6144
# Epoch: 4 | train_loss: 1.1219 | train_acc: 0.6010 | test_loss: 0.9186 | test_acc: 0.6544
# Epoch: 5 | train_loss: 1.0806 | train_acc: 0.6134 | test_loss: 1.0951 | test_acc: 0.6136
# Epoch: 6 | train_loss: 1.0257 | train_acc: 0.6363 | test_loss: 0.8886 | test_acc: 0.6735
# Epoch: 7 | train_loss: 0.9625 | train_acc: 0.6564 | test_loss: 0.8298 | test_acc: 0.7023
# Epoch: 8 | train_loss: 0.9460 | train_acc: 0.6630 | test_loss: 0.8742 | test_acc: 0.6831
# Epoch: 9 | train_loss: 0.9366 | train_acc: 0.6686 | test_loss: 1.0014 | test_acc: 0.6523
# Epoch: 10 | train_loss: 0.8914 | train_acc: 0.6894 | test_loss: 0.8591 | test_acc: 0.7045
# Epoch: 11 | train_loss: 0.8590 | train_acc: 0.7026 | test_loss: 0.9606 | test_acc: 0.6736
# Epoch: 12 | train_loss: 0.8330 | train_acc: 0.7069 | test_loss: 0.8928 | test_acc: 0.6944
# Epoch: 13 | train_loss: 0.8175 | train_acc: 0.7096 | test_loss: 0.8559 | test_acc: 0.6990
# Epoch: 14 | train_loss: 0.8048 | train_acc: 0.7147 | test_loss: 0.9182 | test_acc: 0.6658
# Epoch: 15 | train_loss: 0.7621 | train_acc: 0.7329 | test_loss: 1.0049 | test_acc: 0.6647
# Epoch: 16 | train_loss: 0.7667 | train_acc: 0.7276 | test_loss: 0.8341 | test_acc: 0.7279
# Epoch: 17 | train_loss: 0.7585 | train_acc: 0.7321 | test_loss: 0.8008 | test_acc: 0.7223
# Epoch: 18 | train_loss: 0.7184 | train_acc: 0.7436 | test_loss: 1.0503 | test_acc: 0.6791
# Epoch: 19 | train_loss: 0.7390 | train_acc: 0.7356 | test_loss: 0.9280 | test_acc: 0.6865
# Epoch: 20 | train_loss: 0.7149 | train_acc: 0.7414 | test_loss: 0.7888 | test_acc: 0.7114
# Epoch: 21 | train_loss: 0.6964 | train_acc: 0.7525 | test_loss: 1.0071 | test_acc: 0.6763
# Epoch: 22 | train_loss: 0.6521 | train_acc: 0.7796 | test_loss: 0.7237 | test_acc: 0.7434
# Epoch: 23 | train_loss: 0.6883 | train_acc: 0.7577 | test_loss: 1.0313 | test_acc: 0.6719
# Epoch: 24 | train_loss: 0.6446 | train_acc: 0.7733 | test_loss: 0.8855 | test_acc: 0.7282
# Epoch: 25 | train_loss: 0.6613 | train_acc: 0.7657 | test_loss: 0.9862 | test_acc: 0.6899
# Epoch: 26 | train_loss: 0.6726 | train_acc: 0.7600 | test_loss: 0.6944 | test_acc: 0.7631
# Epoch: 27 | train_loss: 0.6223 | train_acc: 0.7739 | test_loss: 0.7962 | test_acc: 0.7308
# Epoch: 28 | train_loss: 0.6242 | train_acc: 0.7802 | test_loss: 0.8087 | test_acc: 0.7322
# Epoch: 29 | train_loss: 0.6353 | train_acc: 0.7758 | test_loss: 0.6803 | test_acc: 0.7608
# Epoch: 30 | train_loss: 0.6114 | train_acc: 0.7870 | test_loss: 0.8258 | test_acc: 0.7320
# Total training time: 62.538 seconds

# %%
plot_loss_curves(model_1_results)

# %% [markdown]
# ### 9. Using Dropout2d
#
# We will add a `Dropout2d()` layer in each convolution block. This layer will zero out entire channels. It is a common practise in convolution networks. More info here - https://docs.pytorch.org/docs/stable/generated/torch.nn.Dropout2d.html
#
# We will have to build a new class for the classifier, as well as instantiate a new model. The rest of the pipeline is the same.

# %%
# Compile the network
class CNNClassifierV1(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_2 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_2
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_2_results = train(model=model_2,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4685 | train_acc: 0.4618 | test_loss: 1.1323 | test_acc: 0.5923
# Epoch: 2 | train_loss: 1.0845 | train_acc: 0.6135 | test_loss: 0.9716 | test_acc: 0.6345
# Epoch: 3 | train_loss: 0.9307 | train_acc: 0.6672 | test_loss: 0.8873 | test_acc: 0.6831
# Epoch: 4 | train_loss: 0.8151 | train_acc: 0.7198 | test_loss: 0.7361 | test_acc: 0.7391
# Epoch: 5 | train_loss: 0.7269 | train_acc: 0.7380 | test_loss: 0.7211 | test_acc: 0.7499
# Epoch: 6 | train_loss: 0.6636 | train_acc: 0.7700 | test_loss: 0.7011 | test_acc: 0.7514
# Epoch: 7 | train_loss: 0.6007 | train_acc: 0.7921 | test_loss: 0.6751 | test_acc: 0.7718
# Epoch: 8 | train_loss: 0.5606 | train_acc: 0.8051 | test_loss: 0.6597 | test_acc: 0.7612
# Epoch: 9 | train_loss: 0.4944 | train_acc: 0.8252 | test_loss: 0.6166 | test_acc: 0.7890
# Epoch: 10 | train_loss: 0.4428 | train_acc: 0.8443 | test_loss: 0.6012 | test_acc: 0.7999
# Epoch: 11 | train_loss: 0.4272 | train_acc: 0.8513 | test_loss: 0.5851 | test_acc: 0.7929
# Epoch: 12 | train_loss: 0.3873 | train_acc: 0.8635 | test_loss: 0.5853 | test_acc: 0.8029
# Epoch: 13 | train_loss: 0.3951 | train_acc: 0.8603 | test_loss: 0.6511 | test_acc: 0.7838
# Epoch: 14 | train_loss: 0.3436 | train_acc: 0.8768 | test_loss: 0.6434 | test_acc: 0.7900
# Epoch: 15 | train_loss: 0.3306 | train_acc: 0.8868 | test_loss: 0.6749 | test_acc: 0.7792
# Epoch: 16 | train_loss: 0.3136 | train_acc: 0.8877 | test_loss: 0.6011 | test_acc: 0.8020
# Epoch: 17 | train_loss: 0.2833 | train_acc: 0.9045 | test_loss: 0.6133 | test_acc: 0.7998
# Epoch: 18 | train_loss: 0.2791 | train_acc: 0.8987 | test_loss: 0.6739 | test_acc: 0.7970
# Epoch: 19 | train_loss: 0.2624 | train_acc: 0.9034 | test_loss: 0.6705 | test_acc: 0.7864
# Epoch: 20 | train_loss: 0.2411 | train_acc: 0.9184 | test_loss: 0.6415 | test_acc: 0.8030
# Epoch: 21 | train_loss: 0.2482 | train_acc: 0.9171 | test_loss: 0.6581 | test_acc: 0.8063
# Epoch: 22 | train_loss: 0.2409 | train_acc: 0.9142 | test_loss: 0.7322 | test_acc: 0.7791
# Epoch: 23 | train_loss: 0.2287 | train_acc: 0.9178 | test_loss: 0.6561 | test_acc: 0.7864
# Epoch: 24 | train_loss: 0.2241 | train_acc: 0.9222 | test_loss: 0.6249 | test_acc: 0.7898
# Epoch: 25 | train_loss: 0.2089 | train_acc: 0.9265 | test_loss: 0.6463 | test_acc: 0.8077
# Epoch: 26 | train_loss: 0.2014 | train_acc: 0.9302 | test_loss: 0.6662 | test_acc: 0.7993
# Epoch: 27 | train_loss: 0.2044 | train_acc: 0.9265 | test_loss: 0.6381 | test_acc: 0.8062
# Epoch: 28 | train_loss: 0.1952 | train_acc: 0.9309 | test_loss: 0.6758 | test_acc: 0.7970
# Epoch: 29 | train_loss: 0.1741 | train_acc: 0.9390 | test_loss: 0.6615 | test_acc: 0.7931
# Epoch: 30 | train_loss: 0.1866 | train_acc: 0.9364 | test_loss: 0.7573 | test_acc: 0.7889
# Total training time: 50.730 seconds

# %%
plot_loss_curves(model_2_results)

# %% [markdown]
# ### 10. Learning rate scheduling
#
# The concept of learning rate scheduling is adjusting the learning rate of the optimizer while training. The objective that we seek to achieve with the method of gradient descent is to find values for the weights and biases that produce the least error. The *learing rate* hypeprameter is very crucial to this algorithm. A very high learning rate can lead to difficulty to find the local minimum of the error function, whereas a low learning rate can lead to slow training. Learning rate scheduling, adjusts the value of the learning rate in various ways instead of having a steady value. We are going to use the *Adaptive Plateau Reduction* approach, which is implemented by the `ReduceLROnPlateau()` method. For more info on learning rate scheduling - https://machinelearningmastery.com/a-gentle-introduction-to-learning-rate-schedulers/
#
# In order to include learning rate scheduling in the training, we have to instantiate a `ReduceLROnPlateau` instance and include it in our `train()` function. In this manner, our train function will now be `train_with_scheduler()`. Furthermore, the value of the learning rate in each epoch will also be saved and included in the dictionary that the function returns. As a result, we will be able to spot when the learning rate changes, in case that happens.
#
# The rest of the pipeline is the same.

# %%
# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_3 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_3
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss, optimizer and scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_3.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

scheduler = ReduceLROnPlateau(optimizer,
                             mode='min',
                             factor=0.5,
                             patience=5)

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train_w_scheduler(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          scheduler: torch.optim.lr_scheduler._LRScheduler = None,
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "learning_rates": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Update scheduler if it exists
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_loss)
            else:
                scheduler.step()

        # Saving the current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        results["learning_rates"].append(current_lr)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"LR: {current_lr:.6f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_3_results = train_w_scheduler(model=model_3,
                                    train_dataloader=train_dataloader,
                                    test_dataloader=validation_dataloader,
                                    optimizer=optimizer,
                                    loss_fn=loss_fn,
                                    epochs=NUM_EPOCHS,
                                    scheduler=scheduler)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4687 | train_acc: 0.4627 | test_loss: 1.1061 | test_acc: 0.5963 | LR: 0.001000
# Epoch: 2 | train_loss: 1.0892 | train_acc: 0.6151 | test_loss: 0.9675 | test_acc: 0.6386 | LR: 0.001000
# Epoch: 3 | train_loss: 0.9422 | train_acc: 0.6638 | test_loss: 0.9070 | test_acc: 0.6732 | LR: 0.001000
# Epoch: 4 | train_loss: 0.8186 | train_acc: 0.7146 | test_loss: 0.7219 | test_acc: 0.7487 | LR: 0.001000
# Epoch: 5 | train_loss: 0.7270 | train_acc: 0.7401 | test_loss: 0.7038 | test_acc: 0.7528 | LR: 0.001000
# Epoch: 6 | train_loss: 0.6606 | train_acc: 0.7698 | test_loss: 0.6944 | test_acc: 0.7693 | LR: 0.001000
# Epoch: 7 | train_loss: 0.6098 | train_acc: 0.7876 | test_loss: 0.6597 | test_acc: 0.7737 | LR: 0.001000
# Epoch: 8 | train_loss: 0.5601 | train_acc: 0.8005 | test_loss: 0.6470 | test_acc: 0.7832 | LR: 0.001000
# Epoch: 9 | train_loss: 0.4943 | train_acc: 0.8262 | test_loss: 0.6252 | test_acc: 0.7918 | LR: 0.001000
# Epoch: 10 | train_loss: 0.4471 | train_acc: 0.8428 | test_loss: 0.6250 | test_acc: 0.7888 | LR: 0.001000
# Epoch: 11 | train_loss: 0.4352 | train_acc: 0.8487 | test_loss: 0.6655 | test_acc: 0.7904 | LR: 0.001000
# Epoch: 12 | train_loss: 0.3981 | train_acc: 0.8613 | test_loss: 0.6255 | test_acc: 0.7907 | LR: 0.001000
# Epoch: 13 | train_loss: 0.4048 | train_acc: 0.8555 | test_loss: 0.6664 | test_acc: 0.7761 | LR: 0.001000
# Epoch: 14 | train_loss: 0.3563 | train_acc: 0.8773 | test_loss: 0.6701 | test_acc: 0.7760 | LR: 0.001000
# Epoch: 15 | train_loss: 0.3522 | train_acc: 0.8766 | test_loss: 0.6901 | test_acc: 0.7819 | LR: 0.001000
# Epoch: 16 | train_loss: 0.3213 | train_acc: 0.8852 | test_loss: 0.6536 | test_acc: 0.7906 | LR: 0.000500
# Epoch: 17 | train_loss: 0.2274 | train_acc: 0.9236 | test_loss: 0.5693 | test_acc: 0.8210 | LR: 0.000500
# Epoch: 18 | train_loss: 0.2151 | train_acc: 0.9268 | test_loss: 0.5923 | test_acc: 0.8091 | LR: 0.000500
# Epoch: 19 | train_loss: 0.1963 | train_acc: 0.9349 | test_loss: 0.5905 | test_acc: 0.8112 | LR: 0.000500
# Epoch: 20 | train_loss: 0.1856 | train_acc: 0.9350 | test_loss: 0.5931 | test_acc: 0.8102 | LR: 0.000500
# Epoch: 21 | train_loss: 0.1864 | train_acc: 0.9407 | test_loss: 0.5903 | test_acc: 0.8142 | LR: 0.000500
# Epoch: 22 | train_loss: 0.1831 | train_acc: 0.9389 | test_loss: 0.6598 | test_acc: 0.7978 | LR: 0.000500
# Epoch: 23 | train_loss: 0.1697 | train_acc: 0.9456 | test_loss: 0.6331 | test_acc: 0.8032 | LR: 0.000250
# Epoch: 24 | train_loss: 0.1473 | train_acc: 0.9546 | test_loss: 0.6047 | test_acc: 0.8217 | LR: 0.000250
# Epoch: 25 | train_loss: 0.1265 | train_acc: 0.9639 | test_loss: 0.5705 | test_acc: 0.8339 | LR: 0.000250
# Epoch: 26 | train_loss: 0.1326 | train_acc: 0.9591 | test_loss: 0.5872 | test_acc: 0.8232 | LR: 0.000250
# Epoch: 27 | train_loss: 0.1172 | train_acc: 0.9644 | test_loss: 0.5764 | test_acc: 0.8285 | LR: 0.000250
# Epoch: 28 | train_loss: 0.1183 | train_acc: 0.9651 | test_loss: 0.5989 | test_acc: 0.8246 | LR: 0.000250
# Epoch: 29 | train_loss: 0.1126 | train_acc: 0.9679 | test_loss: 0.5949 | test_acc: 0.8364 | LR: 0.000125
# Epoch: 30 | train_loss: 0.1109 | train_acc: 0.9671 | test_loss: 0.5887 | test_acc: 0.8284 | LR: 0.000125
# Total training time: 52.199 seconds

# %% [markdown]
# We can see that the learning rate changes in epoch #16, #23, #30.

# %%
plot_loss_curves(model_3_results)

# %% [markdown]
# ## 11. Using Instance Normalization instead of Batch Normalization
#
# Instance normalization normalizes each input individually focusing only on its own features. This is more like giving personalized feedback to each student without comparing them to others. For more info - https://stackoverflow.com/questions/45463778/instance-normalisation-vs-batch-normalisation
#
# In order to use Instance Normalization, we will replace the `BatchNorm2d()` layers with `InstanceNorm2d()` in the convolution blocks. So we have to create a new Classifier class and a new model. Other than that, the pipeline is the same.

# %%
# Compile the network
class CNNClassifierV2(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_4 = CNNClassifierV2(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_4
# Out:
# CNNClassifierV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_4.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_4_results = train(model=model_4,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2932 | train_acc: 0.1357 | test_loss: 2.2090 | test_acc: 0.1907
# Epoch: 2 | train_loss: 2.0351 | train_acc: 0.2658 | test_loss: 1.9378 | test_acc: 0.2987
# Epoch: 3 | train_loss: 1.8373 | train_acc: 0.3373 | test_loss: 1.8287 | test_acc: 0.3246
# Epoch: 4 | train_loss: 1.7143 | train_acc: 0.3803 | test_loss: 1.7631 | test_acc: 0.3553
# Epoch: 5 | train_loss: 1.5946 | train_acc: 0.4266 | test_loss: 1.7305 | test_acc: 0.3673
# Epoch: 6 | train_loss: 1.5249 | train_acc: 0.4583 | test_loss: 1.7287 | test_acc: 0.3699
# Epoch: 7 | train_loss: 1.4256 | train_acc: 0.4910 | test_loss: 1.7112 | test_acc: 0.3700
# Epoch: 8 | train_loss: 1.3512 | train_acc: 0.5250 | test_loss: 1.7205 | test_acc: 0.3911
# Epoch: 9 | train_loss: 1.2638 | train_acc: 0.5573 | test_loss: 1.7335 | test_acc: 0.4019
# Epoch: 10 | train_loss: 1.2090 | train_acc: 0.5718 | test_loss: 1.7028 | test_acc: 0.4184
# Epoch: 11 | train_loss: 1.1388 | train_acc: 0.5993 | test_loss: 1.7199 | test_acc: 0.4105
# Epoch: 12 | train_loss: 1.0755 | train_acc: 0.6222 | test_loss: 1.7855 | test_acc: 0.4085
# Epoch: 13 | train_loss: 1.0453 | train_acc: 0.6290 | test_loss: 1.7936 | test_acc: 0.3905
# Epoch: 14 | train_loss: 0.9706 | train_acc: 0.6569 | test_loss: 1.7961 | test_acc: 0.4046
# Epoch: 15 | train_loss: 0.9514 | train_acc: 0.6641 | test_loss: 1.8353 | test_acc: 0.3963
# Epoch: 16 | train_loss: 0.9158 | train_acc: 0.6742 | test_loss: 1.8536 | test_acc: 0.4013
# Epoch: 17 | train_loss: 0.8840 | train_acc: 0.6923 | test_loss: 1.8499 | test_acc: 0.4110
# Epoch: 18 | train_loss: 0.8410 | train_acc: 0.7000 | test_loss: 1.9158 | test_acc: 0.3979
# Epoch: 19 | train_loss: 0.8033 | train_acc: 0.7173 | test_loss: 1.9100 | test_acc: 0.4099
# Epoch: 20 | train_loss: 0.7516 | train_acc: 0.7387 | test_loss: 1.9538 | test_acc: 0.4045
# Epoch: 21 | train_loss: 0.7251 | train_acc: 0.7492 | test_loss: 2.0033 | test_acc: 0.3992
# Epoch: 22 | train_loss: 0.7046 | train_acc: 0.7545 | test_loss: 2.0518 | test_acc: 0.3920
# Epoch: 23 | train_loss: 0.6619 | train_acc: 0.7703 | test_loss: 2.0324 | test_acc: 0.4064
# Epoch: 24 | train_loss: 0.6380 | train_acc: 0.7792 | test_loss: 2.0578 | test_acc: 0.4067
# Epoch: 25 | train_loss: 0.6016 | train_acc: 0.7954 | test_loss: 2.1135 | test_acc: 0.4031
# Epoch: 26 | train_loss: 0.5837 | train_acc: 0.7939 | test_loss: 2.1689 | test_acc: 0.3970
# Epoch: 27 | train_loss: 0.5639 | train_acc: 0.8055 | test_loss: 2.1555 | test_acc: 0.4044
# Epoch: 28 | train_loss: 0.5574 | train_acc: 0.8100 | test_loss: 2.2194 | test_acc: 0.4116
# Epoch: 29 | train_loss: 0.5478 | train_acc: 0.8073 | test_loss: 2.2036 | test_acc: 0.4085
# Epoch: 30 | train_loss: 0.5495 | train_acc: 0.8074 | test_loss: 2.2916 | test_acc: 0.3699
# Total training time: 57.164 seconds

# %%
plot_loss_curves(model_4_results)

# %% [markdown]
# ## 12. Create model to combine all previous methods
#
# We are going to combine all the previous methods. The new Classifier class is going to have `Dropout2d()` layers as well as `InstanceNorm2d()` layers. We are going to use `ReduceLROnPlateau()` for the scheduler, as well as train with augmented data. Finally, we are going to train the model for 200 epochs.

# %%
# Compile the network
class CNNClassifierV3(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_5 = CNNClassifierV3(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_5
# Out:
# CNNClassifierV3(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss, optimizer and scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_5.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

scheduler = ReduceLROnPlateau(optimizer,
                             mode='min',
                             factor=0.5,
                             patience=5)

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train_with_augmented_data_and_scheduler(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          scheduler: torch.optim.lr_scheduler._LRScheduler = None,
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "learning_rates": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer,)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # update scheduler if it exists
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_loss)
            else:
                scheduler.step()

        # saving the current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        results["learning_rates"].append(current_lr)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"LR: {current_lr:.6f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 200

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_5_results = train_with_augmented_data_and_scheduler(model=model_5,
                                                        train_dataloader=train_dataloader,
                                                        test_dataloader=validation_dataloader,
                                                        optimizer=optimizer,
                                                        loss_fn=loss_fn,
                                                        epochs=NUM_EPOCHS,
                                                        scheduler=scheduler)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.3404 | train_acc: 0.1030 | test_loss: 2.3049 | test_acc: 0.1173 | LR: 0.001000
# Epoch: 2 | train_loss: 2.3115 | train_acc: 0.1164 | test_loss: 2.2883 | test_acc: 0.1320 | LR: 0.001000
# Epoch: 3 | train_loss: 2.2889 | train_acc: 0.1341 | test_loss: 2.2623 | test_acc: 0.1406 | LR: 0.001000
# Epoch: 4 | train_loss: 2.2575 | train_acc: 0.1600 | test_loss: 2.2102 | test_acc: 0.1903 | LR: 0.001000
# Epoch: 5 | train_loss: 2.2144 | train_acc: 0.1681 | test_loss: 2.1544 | test_acc: 0.2121 | LR: 0.001000
# Epoch: 6 | train_loss: 2.1533 | train_acc: 0.2029 | test_loss: 2.0998 | test_acc: 0.2268 | LR: 0.001000
# Epoch: 7 | train_loss: 2.1212 | train_acc: 0.2176 | test_loss: 2.0622 | test_acc: 0.2221 | LR: 0.001000
# Epoch: 8 | train_loss: 2.0879 | train_acc: 0.2298 | test_loss: 2.0461 | test_acc: 0.2568 | LR: 0.001000
# Epoch: 9 | train_loss: 2.0509 | train_acc: 0.2436 | test_loss: 1.9833 | test_acc: 0.2781 | LR: 0.001000
# Epoch: 10 | train_loss: 2.0122 | train_acc: 0.2536 | test_loss: 1.9347 | test_acc: 0.2901 | LR: 0.001000
# Epoch: 11 | train_loss: 1.9719 | train_acc: 0.2807 | test_loss: 1.9509 | test_acc: 0.2764 | LR: 0.001000
# Epoch: 12 | train_loss: 1.9478 | train_acc: 0.2932 | test_loss: 1.8844 | test_acc: 0.3208 | LR: 0.001000
# Epoch: 13 | train_loss: 1.9348 | train_acc: 0.2891 | test_loss: 1.8457 | test_acc: 0.3304 | LR: 0.001000
# Epoch: 14 | train_loss: 1.9036 | train_acc: 0.3104 | test_loss: 1.8582 | test_acc: 0.3267 | LR: 0.001000
# Epoch: 15 | train_loss: 1.9033 | train_acc: 0.3186 | test_loss: 1.8536 | test_acc: 0.3262 | LR: 0.001000
# Epoch: 16 | train_loss: 1.9045 | train_acc: 0.3032 | test_loss: 1.8526 | test_acc: 0.3182 | LR: 0.001000
# Epoch: 17 | train_loss: 1.8846 | train_acc: 0.3094 | test_loss: 1.8469 | test_acc: 0.3304 | LR: 0.001000
# Epoch: 18 | train_loss: 1.8578 | train_acc: 0.3297 | test_loss: 1.8527 | test_acc: 0.3183 | LR: 0.001000
# Epoch: 19 | train_loss: 1.8587 | train_acc: 0.3241 | test_loss: 1.8022 | test_acc: 0.3348 | LR: 0.001000
# Epoch: 20 | train_loss: 1.8561 | train_acc: 0.3234 | test_loss: 1.8136 | test_acc: 0.3344 | LR: 0.001000
# Epoch: 21 | train_loss: 1.8282 | train_acc: 0.3363 | test_loss: 1.7914 | test_acc: 0.3477 | LR: 0.001000
# Epoch: 22 | train_loss: 1.8157 | train_acc: 0.3384 | test_loss: 1.7921 | test_acc: 0.3525 | LR: 0.001000
# Epoch: 23 | train_loss: 1.8290 | train_acc: 0.3381 | test_loss: 1.7812 | test_acc: 0.3560 | LR: 0.001000
# Epoch: 24 | train_loss: 1.8135 | train_acc: 0.3339 | test_loss: 1.7726 | test_acc: 0.3592 | LR: 0.001000
# Epoch: 25 | train_loss: 1.8208 | train_acc: 0.3394 | test_loss: 1.7972 | test_acc: 0.3408 | LR: 0.001000
# Epoch: 26 | train_loss: 1.8264 | train_acc: 0.3402 | test_loss: 1.7730 | test_acc: 0.3526 | LR: 0.001000
# Epoch: 27 | train_loss: 1.8105 | train_acc: 0.3426 | test_loss: 1.7562 | test_acc: 0.3620 | LR: 0.001000
# Epoch: 28 | train_loss: 1.7927 | train_acc: 0.3434 | test_loss: 1.7602 | test_acc: 0.3608 | LR: 0.001000
# Epoch: 29 | train_loss: 1.8139 | train_acc: 0.3474 | test_loss: 1.7623 | test_acc: 0.3582 | LR: 0.001000
# Epoch: 30 | train_loss: 1.7651 | train_acc: 0.3533 | test_loss: 1.7527 | test_acc: 0.3522 | LR: 0.001000
# Epoch: 31 | train_loss: 1.8042 | train_acc: 0.3518 | test_loss: 1.7566 | test_acc: 0.3534 | LR: 0.001000
# Epoch: 32 | train_loss: 1.7759 | train_acc: 0.3503 | test_loss: 1.7575 | test_acc: 0.3635 | LR: 0.001000
# Epoch: 33 | train_loss: 1.8062 | train_acc: 0.3383 | test_loss: 1.7487 | test_acc: 0.3723 | LR: 0.001000
# Epoch: 34 | train_loss: 1.7873 | train_acc: 0.3526 | test_loss: 1.7692 | test_acc: 0.3574 | LR: 0.001000
# Epoch: 35 | train_loss: 1.7659 | train_acc: 0.3628 | test_loss: 1.7170 | test_acc: 0.3795 | LR: 0.001000
# Epoch: 36 | train_loss: 1.7965 | train_acc: 0.3500 | test_loss: 1.7355 | test_acc: 0.3693 | LR: 0.001000
# Epoch: 37 | train_loss: 1.7726 | train_acc: 0.3588 | test_loss: 1.7381 | test_acc: 0.3693 | LR: 0.001000
# Epoch: 38 | train_loss: 1.7689 | train_acc: 0.3629 | test_loss: 1.7299 | test_acc: 0.3761 | LR: 0.001000
# Epoch: 39 | train_loss: 1.7793 | train_acc: 0.3616 | test_loss: 1.7278 | test_acc: 0.3654 | LR: 0.001000
# Epoch: 40 | train_loss: 1.7444 | train_acc: 0.3657 | test_loss: 1.7121 | test_acc: 0.3794 | LR: 0.001000
# Epoch: 41 | train_loss: 1.7683 | train_acc: 0.3596 | test_loss: 1.7243 | test_acc: 0.3680 | LR: 0.001000
# Epoch: 42 | train_loss: 1.7784 | train_acc: 0.3621 | test_loss: 1.7115 | test_acc: 0.3806 | LR: 0.001000
# Epoch: 43 | train_loss: 1.7492 | train_acc: 0.3637 | test_loss: 1.7235 | test_acc: 0.3609 | LR: 0.001000
# Epoch: 44 | train_loss: 1.7481 | train_acc: 0.3633 | test_loss: 1.7045 | test_acc: 0.3813 | LR: 0.001000
# Epoch: 45 | train_loss: 1.7335 | train_acc: 0.3658 | test_loss: 1.6954 | test_acc: 0.3967 | LR: 0.001000
# Epoch: 46 | train_loss: 1.7379 | train_acc: 0.3727 | test_loss: 1.6950 | test_acc: 0.3911 | LR: 0.001000
# Epoch: 47 | train_loss: 1.7331 | train_acc: 0.3751 | test_loss: 1.7072 | test_acc: 0.3705 | LR: 0.001000
# Epoch: 48 | train_loss: 1.7375 | train_acc: 0.3673 | test_loss: 1.7435 | test_acc: 0.3666 | LR: 0.001000
# Epoch: 49 | train_loss: 1.7143 | train_acc: 0.3840 | test_loss: 1.7194 | test_acc: 0.3711 | LR: 0.001000
# Epoch: 50 | train_loss: 1.7452 | train_acc: 0.3693 | test_loss: 1.7095 | test_acc: 0.3694 | LR: 0.001000
# Epoch: 51 | train_loss: 1.7120 | train_acc: 0.3824 | test_loss: 1.7112 | test_acc: 0.3720 | LR: 0.001000
# Epoch: 52 | train_loss: 1.7087 | train_acc: 0.3797 | test_loss: 1.7070 | test_acc: 0.3648 | LR: 0.000500
# Epoch: 53 | train_loss: 1.7204 | train_acc: 0.3812 | test_loss: 1.6702 | test_acc: 0.3900 | LR: 0.000500
# Epoch: 54 | train_loss: 1.6677 | train_acc: 0.3995 | test_loss: 1.6722 | test_acc: 0.3960 | LR: 0.000500
# Epoch: 55 | train_loss: 1.6730 | train_acc: 0.3936 | test_loss: 1.6438 | test_acc: 0.4054 | LR: 0.000500
# Epoch: 56 | train_loss: 1.6885 | train_acc: 0.3871 | test_loss: 1.6600 | test_acc: 0.3921 | LR: 0.000500
# Epoch: 57 | train_loss: 1.6684 | train_acc: 0.4019 | test_loss: 1.6616 | test_acc: 0.3920 | LR: 0.000500
# Epoch: 58 | train_loss: 1.6874 | train_acc: 0.3923 | test_loss: 1.6697 | test_acc: 0.3867 | LR: 0.000500
# Epoch: 59 | train_loss: 1.6907 | train_acc: 0.3936 | test_loss: 1.6757 | test_acc: 0.3874 | LR: 0.000500
# Epoch: 60 | train_loss: 1.6774 | train_acc: 0.3959 | test_loss: 1.6619 | test_acc: 0.3947 | LR: 0.000500
# Epoch: 61 | train_loss: 1.6603 | train_acc: 0.4023 | test_loss: 1.6413 | test_acc: 0.4114 | LR: 0.000500
# Epoch: 62 | train_loss: 1.6424 | train_acc: 0.4068 | test_loss: 1.6396 | test_acc: 0.4040 | LR: 0.000500
# Epoch: 63 | train_loss: 1.6673 | train_acc: 0.3941 | test_loss: 1.6478 | test_acc: 0.3967 | LR: 0.000500
# Epoch: 64 | train_loss: 1.6560 | train_acc: 0.4045 | test_loss: 1.6421 | test_acc: 0.4020 | LR: 0.000500
# Epoch: 65 | train_loss: 1.6519 | train_acc: 0.4012 | test_loss: 1.6257 | test_acc: 0.4113 | LR: 0.000500
# Epoch: 66 | train_loss: 1.6688 | train_acc: 0.3910 | test_loss: 1.6427 | test_acc: 0.4086 | LR: 0.000500
# Epoch: 67 | train_loss: 1.6756 | train_acc: 0.3974 | test_loss: 1.6273 | test_acc: 0.4100 | LR: 0.000500
# Epoch: 68 | train_loss: 1.6726 | train_acc: 0.4011 | test_loss: 1.6311 | test_acc: 0.4125 | LR: 0.000500
# Epoch: 69 | train_loss: 1.6299 | train_acc: 0.4116 | test_loss: 1.6471 | test_acc: 0.4039 | LR: 0.000500
# Epoch: 70 | train_loss: 1.6449 | train_acc: 0.3997 | test_loss: 1.6471 | test_acc: 0.4126 | LR: 0.000500
# Epoch: 71 | train_loss: 1.6503 | train_acc: 0.4008 | test_loss: 1.6416 | test_acc: 0.3973 | LR: 0.000250
# Epoch: 72 | train_loss: 1.6593 | train_acc: 0.3977 | test_loss: 1.6332 | test_acc: 0.4126 | LR: 0.000250
# Epoch: 73 | train_loss: 1.6306 | train_acc: 0.4127 | test_loss: 1.6370 | test_acc: 0.4093 | LR: 0.000250
# Epoch: 74 | train_loss: 1.6312 | train_acc: 0.4116 | test_loss: 1.6399 | test_acc: 0.4060 | LR: 0.000250
# Epoch: 75 | train_loss: 1.6244 | train_acc: 0.4126 | test_loss: 1.6359 | test_acc: 0.4146 | LR: 0.000250
# Epoch: 76 | train_loss: 1.6279 | train_acc: 0.4070 | test_loss: 1.6304 | test_acc: 0.4073 | LR: 0.000250
# Epoch: 77 | train_loss: 1.6274 | train_acc: 0.4108 | test_loss: 1.6363 | test_acc: 0.3993 | LR: 0.000125
# Epoch: 78 | train_loss: 1.6127 | train_acc: 0.4119 | test_loss: 1.6307 | test_acc: 0.4053 | LR: 0.000125
# Epoch: 79 | train_loss: 1.6283 | train_acc: 0.4155 | test_loss: 1.6300 | test_acc: 0.4066 | LR: 0.000125
# Epoch: 80 | train_loss: 1.6156 | train_acc: 0.4173 | test_loss: 1.6281 | test_acc: 0.4100 | LR: 0.000125
# Epoch: 81 | train_loss: 1.6020 | train_acc: 0.4147 | test_loss: 1.6226 | test_acc: 0.4186 | LR: 0.000125
# Epoch: 82 | train_loss: 1.6146 | train_acc: 0.4221 | test_loss: 1.6218 | test_acc: 0.4154 | LR: 0.000125
# Epoch: 83 | train_loss: 1.5988 | train_acc: 0.4215 | test_loss: 1.6278 | test_acc: 0.4094 | LR: 0.000125
# Epoch: 84 | train_loss: 1.6031 | train_acc: 0.4215 | test_loss: 1.6224 | test_acc: 0.4120 | LR: 0.000125
# Epoch: 85 | train_loss: 1.6053 | train_acc: 0.4207 | test_loss: 1.6192 | test_acc: 0.4100 | LR: 0.000125
# Epoch: 86 | train_loss: 1.6164 | train_acc: 0.4174 | test_loss: 1.6196 | test_acc: 0.4087 | LR: 0.000125
# Epoch: 87 | train_loss: 1.5953 | train_acc: 0.4283 | test_loss: 1.6123 | test_acc: 0.4061 | LR: 0.000125
# Epoch: 88 | train_loss: 1.6469 | train_acc: 0.4065 | test_loss: 1.6198 | test_acc: 0.4001 | LR: 0.000125
# Epoch: 89 | train_loss: 1.6145 | train_acc: 0.4130 | test_loss: 1.6279 | test_acc: 0.3940 | LR: 0.000125
# Epoch: 90 | train_loss: 1.6148 | train_acc: 0.4178 | test_loss: 1.6188 | test_acc: 0.4034 | LR: 0.000125
# Epoch: 91 | train_loss: 1.6174 | train_acc: 0.4141 | test_loss: 1.6208 | test_acc: 0.4100 | LR: 0.000125
# Epoch: 92 | train_loss: 1.6009 | train_acc: 0.4266 | test_loss: 1.6230 | test_acc: 0.4066 | LR: 0.000125
# Epoch: 93 | train_loss: 1.5874 | train_acc: 0.4281 | test_loss: 1.6233 | test_acc: 0.4067 | LR: 0.000063
# Epoch: 94 | train_loss: 1.5681 | train_acc: 0.4314 | test_loss: 1.6212 | test_acc: 0.4081 | LR: 0.000063
# Epoch: 95 | train_loss: 1.5839 | train_acc: 0.4373 | test_loss: 1.6192 | test_acc: 0.4034 | LR: 0.000063
# Epoch: 96 | train_loss: 1.6187 | train_acc: 0.4104 | test_loss: 1.6175 | test_acc: 0.4100 | LR: 0.000063
# Epoch: 97 | train_loss: 1.6035 | train_acc: 0.4296 | test_loss: 1.6145 | test_acc: 0.4100 | LR: 0.000063
# Epoch: 98 | train_loss: 1.6020 | train_acc: 0.4251 | test_loss: 1.6159 | test_acc: 0.4100 | LR: 0.000063
# Epoch: 99 | train_loss: 1.6003 | train_acc: 0.4198 | test_loss: 1.6122 | test_acc: 0.4200 | LR: 0.000031
# Epoch: 100 | train_loss: 1.6107 | train_acc: 0.4232 | test_loss: 1.6105 | test_acc: 0.4174 | LR: 0.000031
# Epoch: 101 | train_loss: 1.5990 | train_acc: 0.4215 | test_loss: 1.6131 | test_acc: 0.4134 | LR: 0.000031
# Epoch: 102 | train_loss: 1.6149 | train_acc: 0.4228 | test_loss: 1.6125 | test_acc: 0.4146 | LR: 0.000031
# Epoch: 103 | train_loss: 1.5777 | train_acc: 0.4321 | test_loss: 1.6138 | test_acc: 0.4126 | LR: 0.000031
# Epoch: 104 | train_loss: 1.5940 | train_acc: 0.4222 | test_loss: 1.6159 | test_acc: 0.4086 | LR: 0.000031
# Epoch: 105 | train_loss: 1.6012 | train_acc: 0.4195 | test_loss: 1.6190 | test_acc: 0.4041 | LR: 0.000031
# Epoch: 106 | train_loss: 1.5915 | train_acc: 0.4247 | test_loss: 1.6151 | test_acc: 0.4107 | LR: 0.000016
# Epoch: 107 | train_loss: 1.6110 | train_acc: 0.4106 | test_loss: 1.6138 | test_acc: 0.4120 | LR: 0.000016
# Epoch: 108 | train_loss: 1.5682 | train_acc: 0.4311 | test_loss: 1.6142 | test_acc: 0.4127 | LR: 0.000016
# Epoch: 109 | train_loss: 1.5937 | train_acc: 0.4317 | test_loss: 1.6150 | test_acc: 0.4114 | LR: 0.000016
# Epoch: 110 | train_loss: 1.5750 | train_acc: 0.4321 | test_loss: 1.6142 | test_acc: 0.4120 | LR: 0.000016
# Epoch: 111 | train_loss: 1.5911 | train_acc: 0.4204 | test_loss: 1.6145 | test_acc: 0.4100 | LR: 0.000016
# Epoch: 112 | train_loss: 1.5993 | train_acc: 0.4229 | test_loss: 1.6146 | test_acc: 0.4107 | LR: 0.000008
# Epoch: 113 | train_loss: 1.5976 | train_acc: 0.4271 | test_loss: 1.6145 | test_acc: 0.4107 | LR: 0.000008
# Epoch: 114 | train_loss: 1.6037 | train_acc: 0.4243 | test_loss: 1.6139 | test_acc: 0.4120 | LR: 0.000008
# Epoch: 115 | train_loss: 1.6073 | train_acc: 0.4263 | test_loss: 1.6142 | test_acc: 0.4127 | LR: 0.000008
# Epoch: 116 | train_loss: 1.6020 | train_acc: 0.4258 | test_loss: 1.6136 | test_acc: 0.4134 | LR: 0.000008
# Epoch: 117 | train_loss: 1.5841 | train_acc: 0.4307 | test_loss: 1.6137 | test_acc: 0.4127 | LR: 0.000008
# Epoch: 118 | train_loss: 1.6002 | train_acc: 0.4286 | test_loss: 1.6131 | test_acc: 0.4120 | LR: 0.000004
# Epoch: 119 | train_loss: 1.5950 | train_acc: 0.4257 | test_loss: 1.6129 | test_acc: 0.4120 | LR: 0.000004
# Epoch: 120 | train_loss: 1.5854 | train_acc: 0.4296 | test_loss: 1.6130 | test_acc: 0.4134 | LR: 0.000004
# Epoch: 121 | train_loss: 1.5892 | train_acc: 0.4357 | test_loss: 1.6129 | test_acc: 0.4134 | LR: 0.000004
# Epoch: 122 | train_loss: 1.5806 | train_acc: 0.4270 | test_loss: 1.6131 | test_acc: 0.4127 | LR: 0.000004
# Epoch: 123 | train_loss: 1.6036 | train_acc: 0.4197 | test_loss: 1.6129 | test_acc: 0.4134 | LR: 0.000004
# Epoch: 124 | train_loss: 1.5789 | train_acc: 0.4376 | test_loss: 1.6127 | test_acc: 0.4134 | LR: 0.000002
# Epoch: 125 | train_loss: 1.5973 | train_acc: 0.4237 | test_loss: 1.6127 | test_acc: 0.4134 | LR: 0.000002
# Epoch: 126 | train_loss: 1.6001 | train_acc: 0.4249 | test_loss: 1.6125 | test_acc: 0.4134 | LR: 0.000002
# Epoch: 127 | train_loss: 1.6272 | train_acc: 0.4164 | test_loss: 1.6126 | test_acc: 0.4127 | LR: 0.000002
# Epoch: 128 | train_loss: 1.6163 | train_acc: 0.4219 | test_loss: 1.6128 | test_acc: 0.4120 | LR: 0.000002
# Epoch: 129 | train_loss: 1.5943 | train_acc: 0.4251 | test_loss: 1.6127 | test_acc: 0.4134 | LR: 0.000002
# Epoch: 130 | train_loss: 1.5830 | train_acc: 0.4330 | test_loss: 1.6126 | test_acc: 0.4134 | LR: 0.000001
# Epoch: 131 | train_loss: 1.5675 | train_acc: 0.4370 | test_loss: 1.6126 | test_acc: 0.4127 | LR: 0.000001
# Epoch: 132 | train_loss: 1.5674 | train_acc: 0.4373 | test_loss: 1.6126 | test_acc: 0.4127 | LR: 0.000001
# Epoch: 133 | train_loss: 1.5963 | train_acc: 0.4280 | test_loss: 1.6126 | test_acc: 0.4127 | LR: 0.000001
# Epoch: 134 | train_loss: 1.5818 | train_acc: 0.4267 | test_loss: 1.6126 | test_acc: 0.4127 | LR: 0.000001
# Epoch: 135 | train_loss: 1.6013 | train_acc: 0.4229 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000001
# Epoch: 136 | train_loss: 1.5907 | train_acc: 0.4199 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 137 | train_loss: 1.5935 | train_acc: 0.4281 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 138 | train_loss: 1.5806 | train_acc: 0.4232 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 139 | train_loss: 1.5860 | train_acc: 0.4350 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 140 | train_loss: 1.5937 | train_acc: 0.4252 | test_loss: 1.6127 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 141 | train_loss: 1.6103 | train_acc: 0.4232 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 142 | train_loss: 1.5869 | train_acc: 0.4290 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 143 | train_loss: 1.5752 | train_acc: 0.4365 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 144 | train_loss: 1.5873 | train_acc: 0.4279 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 145 | train_loss: 1.6027 | train_acc: 0.4261 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 146 | train_loss: 1.6025 | train_acc: 0.4274 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 147 | train_loss: 1.5951 | train_acc: 0.4367 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 148 | train_loss: 1.5823 | train_acc: 0.4277 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 149 | train_loss: 1.5664 | train_acc: 0.4368 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 150 | train_loss: 1.6120 | train_acc: 0.4236 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 151 | train_loss: 1.5641 | train_acc: 0.4348 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 152 | train_loss: 1.5958 | train_acc: 0.4207 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 153 | train_loss: 1.5840 | train_acc: 0.4317 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 154 | train_loss: 1.5760 | train_acc: 0.4344 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 155 | train_loss: 1.6004 | train_acc: 0.4262 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 156 | train_loss: 1.5971 | train_acc: 0.4359 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 157 | train_loss: 1.5547 | train_acc: 0.4423 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 158 | train_loss: 1.5855 | train_acc: 0.4389 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 159 | train_loss: 1.5490 | train_acc: 0.4408 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 160 | train_loss: 1.5755 | train_acc: 0.4343 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 161 | train_loss: 1.6029 | train_acc: 0.4217 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 162 | train_loss: 1.6166 | train_acc: 0.4202 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 163 | train_loss: 1.5740 | train_acc: 0.4368 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 164 | train_loss: 1.6031 | train_acc: 0.4284 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 165 | train_loss: 1.6044 | train_acc: 0.4251 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 166 | train_loss: 1.5937 | train_acc: 0.4233 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 167 | train_loss: 1.5861 | train_acc: 0.4272 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 168 | train_loss: 1.6046 | train_acc: 0.4231 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 169 | train_loss: 1.6000 | train_acc: 0.4283 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 170 | train_loss: 1.6134 | train_acc: 0.4199 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 171 | train_loss: 1.5840 | train_acc: 0.4369 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 172 | train_loss: 1.5949 | train_acc: 0.4238 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 173 | train_loss: 1.6015 | train_acc: 0.4234 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 174 | train_loss: 1.5874 | train_acc: 0.4347 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 175 | train_loss: 1.5939 | train_acc: 0.4311 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 176 | train_loss: 1.5846 | train_acc: 0.4316 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 177 | train_loss: 1.5957 | train_acc: 0.4264 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 178 | train_loss: 1.6078 | train_acc: 0.4188 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 179 | train_loss: 1.5901 | train_acc: 0.4286 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 180 | train_loss: 1.5958 | train_acc: 0.4272 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 181 | train_loss: 1.6168 | train_acc: 0.4186 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 182 | train_loss: 1.5614 | train_acc: 0.4405 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 183 | train_loss: 1.6025 | train_acc: 0.4244 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 184 | train_loss: 1.5634 | train_acc: 0.4432 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 185 | train_loss: 1.5918 | train_acc: 0.4241 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 186 | train_loss: 1.5896 | train_acc: 0.4383 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 187 | train_loss: 1.5872 | train_acc: 0.4335 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 188 | train_loss: 1.5955 | train_acc: 0.4257 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 189 | train_loss: 1.5994 | train_acc: 0.4213 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 190 | train_loss: 1.5991 | train_acc: 0.4193 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 191 | train_loss: 1.5681 | train_acc: 0.4329 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 192 | train_loss: 1.6018 | train_acc: 0.4279 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 193 | train_loss: 1.5800 | train_acc: 0.4321 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 194 | train_loss: 1.5807 | train_acc: 0.4282 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 195 | train_loss: 1.6018 | train_acc: 0.4272 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 196 | train_loss: 1.5813 | train_acc: 0.4257 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 197 | train_loss: 1.6025 | train_acc: 0.4272 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 198 | train_loss: 1.5803 | train_acc: 0.4372 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 199 | train_loss: 1.6023 | train_acc: 0.4305 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Epoch: 200 | train_loss: 1.6199 | train_acc: 0.4156 | test_loss: 1.6128 | test_acc: 0.4127 | LR: 0.000000
# Total training time: 455.351 seconds

# %%
plot_loss_curves(model_5_results)

# %% [markdown]
# After considering each loss and accuracy plot, we can see the following:
# * `model_1`: This model is perhaps the best one. We can see that overfitting was fixed and only with 30 epochs, it reaches a 70% accuracy on the validation set.
# * `model_2`: The overfitting issue was not fixed.
# * `model_3`: The overfitting issue was not fixed.
# * `model_4`: The overfitting issue was not fixed. It even worsened
# * `model_5`: Overfitting was fixed. However, the model performs very poorly. After 100 epochs, accuracy plateaus at around 41%. Learning rate becomes 0 on epoch #136 after being gradually reduced, due to learning rate scheduling.

# %% [markdown]
# ## 13. Evaluating our best model on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate `model_1` which was our best performing model.

# %%
# Evaluate the CNN on the test set
evaluation = test_step(model=model_1,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.8286 | test acc = 0.7362

# %% [markdown]
# ## 14. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use `model_1` to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2499 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilites first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Checking shape of X_test. There are 2499 samples
X_test.shape
# Out:
# torch.Size([2499, 1, 13, 130])

# %%
# Set random seed to define index.
np.random.seed(0) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))

predict(model=model_1,
        X_test=X_test,
        y_test=y_test,
        index=index,
        device=device,
        classes=classes)
# Out:
# Target: metal, Predicted label: metal

# %% [markdown]
# ## 15. Making a confusion matrix for further evaluation
#
# For a good vizualization of our model's performance, we can use a confusion matrix. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.23.4

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_1.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_1(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

#  Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(), # matplotlib likes working with NumPy
    class_names=classes, # turn the row and column labels into class names
    figsize=(10, 7)
);

# %% [markdown]
# We can see that our model performs quite well. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. We can see that the highest mismatch values appear between country and rock, reggae and hiphop, rock and metal. This is interesting, because those genres could be difficult to be distinguished from a human as well. We do not see that much errors in distinguishing that many genres for classical. Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.
