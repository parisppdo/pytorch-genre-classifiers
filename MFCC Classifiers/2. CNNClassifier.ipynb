# %% [markdown]
# # Music Genre Classification using convolutional neural network (CNN) models and Mel-frequency coefficients (MFCCs)

# %% [markdown]
# ## 0. Importing libraries, setting up device agnostic code
#
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used. Furthermore, we set a random seed so that a fixed seed will maintain consistency in experimental results. This will also make it easier to compare different approaches.
#
# In the case of CNNs, setting a random seed is not enough to create results that will be consistent no matter how many times one runs the notebook code. This is due to two settings in the backend code:
# * `torch.backends.cudnn.deterministic`: Setting this bool to **True** will make the cuDNN (stands for CUDA Deep Neural Network library) to only use deterministic algorithms. However those algorithms are not always optimized and as a result, the code will run slower.
# * `torch.backends.cudnn.benchmark`: Setting this bool to **True** will make the cuDNN to benchmark multiple convolution algorithms and select the fastest. This prevents us from having the same results every time we run the code. At the same time, it is obvious that it also affects speed.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torchaudio
import torch.nn as nn
from torchaudio.datasets import GTZAN
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.7.0+cu118
# 2.7.0+cu118

# %%
# Set random seeds
RANDOM_SEED = 42

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# The following setting affect the training time (increasing it 10-20%):

# Only use deterministic convolution algorithms
torch.backends.cudnn.deterministic = True

# Turn off "benchmark of convolution algorithms and selecting the fastest", in order to have repeatability in the results
torch.backends.cudnn.benchmark = False

# %%
# !nvidia-smi
# Out:
# Sat Jan 24 01:59:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   39C    P8            N/A  /  115W |     894MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3648    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            5852    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            6540    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            7504    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A            8248    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           12016    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           12912    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           12976    C+G   ....0.3719.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15744    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           16400    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           17068    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           18968    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           19080    C+G   ...AppData\Local\Viber\Viber.exe      N/A      |
# |    0   N/A  N/A           19428    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           20888    C+G   ...rsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A           23360    C+G   ...NVIDIA app\CEF\NVIDIA App.exe      N/A      |
# |    0   N/A  N/A           25220    C+G   ...\v4.3.11\ProtonVPN.Client.exe      N/A      |
# |    0   N/A  N/A           25608    C+G   ...der\Utility\SpyderUtility.exe      N/A      |
# |    0   N/A  N/A           26984    C+G   ...Desktop\WDADesktopService.exe      N/A      |
# |    0   N/A  N/A           27004    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           27208    C+G   ...\Proton\Drive\ProtonDrive.exe      N/A      |
# |    0   N/A  N/A           28620    C+G   ...6)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A           29624    C+G   ...2024.3\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           36132    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           38608    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Loading data
#
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors. We are also going to create a *classes* list in order to use the name of the classes for predictions later.
#
# The CNN models expect the following shape as input: `(batch_size, channels, mfcc_coeficient, time_frame)`. As a result we are going to use the `permute()` method in order to have the tensors in the intended shape.

# %%
# Create function to load mfcc data from json file
DATASET_PATH = "backup data/data_full.json"

def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['mfcc'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from json file
DATASET_PATH = "backup data/data_full.json"

def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((9996, 130, 13), (9996,))

# %%
# Turn data into tensors, also unsqueeze and permute, to be ready for CNN
X = torch.from_numpy(inputs).float() # Weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
X = X.permute(0, 2, 1).unsqueeze(1)
X.shape, y.shape
# Out:
# (torch.Size([9996, 1, 13, 130]), torch.Size([9996]))

# %% [markdown]
# ## 2. Create DataSets and DataLoaders
#
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders.
# After loading the data, we split them into three sets: train_set, validation_set and test_set. The validation_set will be used during the training for evaluation. The test_set will be used after the model is ready. In order for it to be exposed in never seen data.
#
# After dividing the sets, we create the respective datasets and dataloaders.

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x00000259F95B7620>, <torch.utils.data.dataloader.DataLoader object at 0x00000259FA678190>)
# Length of train dataloader: 188 batches of 32
# Length of validation dataloader: 47 batches of 32
# Length of test dataloader: 79 batches of 32

# %%
# Checking the dataset shapes using test_dataloader
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, num_channels, mfcc_coefficients, time_frames)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample)")
print(test_features_batch[0].shape, "-> (num_channels, mfcc_coefficients, time_frames)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 1, 13, 130]) -> (batch_size, num_channels, mfcc_coefficients, time_frames)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample)
# torch.Size([1, 13, 130]) -> (num_channels, mfcc_coefficients, time_frames)
# tensor(1) -> (label)

# %% [markdown]
# ## 3. Data visualization
#
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize an mfcc representation of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, we can distinguish the 13 coefficients in the vertical axis as parallel lines of the same thickness.
#
# A second visualization is implemented later, in order to view various representations of different genres.
#
# The music genre of each representation can also be viewed.

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
CLASS_NUM = np.random.randint(len(X))
mfcc_example = X[CLASS_NUM].squeeze(0).numpy() # squeeze is used because shape is (1, 13, 130)
plt.imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
plt.colorbar()
plt.title(f"MFCC Example (from tensor) | label: {classes[y[CLASS_NUM]]}")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("MFCC Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    mfcc_example = X[idx].squeeze(0).numpy()
    im = axs[row, col].imshow(mfcc_example, cmap='hot', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("MFCC coefficients")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ## 5. Building a basic CNN model
#
# The architecture of the model is based on a CNN. It uses 3 convolution blocks. Each one consist of a `Conv2d` layer, following a `ReLu()` activation and applying pooling with `MaxPool2d()`. We also use `BatchNorm2d()` in the end. This method helps with reducing the danger of the vanishing/exploding gradients problems. The convolution blocks are followed by a classification block. This consists of two linear layers. The first is activated using `ReLu()` and also a `Dropout()` layer is implemented, to reduce the chances of overfitting. This block acts somehow like a multi-perceptron block, so it takes a vector as input. For that purpose, in the beggining we use a `Flatten()` layer.
#
# A common problem that rises when compiling a CNN model with PyTorch, is that we do not know the shape of the matrix that will occur after implementing the `Flatten()` layer. There are many ways to solve this problem. For that purpose, we include `print()` functions in the `forward()` method. What we do is, we run sample data through the model for a run that will fail. However, due to the `print()` functions, we will be able to see the shape of the matrix after the `Flatten()` layer. The numbers of the shape, are the ones we have to multiply the input_shape of the next `linear()` layer with.
#
# This model will output logits. We can apply an `nn.Softmax()` function to those logits in order to get probabilities. However it is good practise to do this later. Furthermore we are going to use `nn.CrossEntropyLoss` later and this method takes logits as arguments.

# %%
# Compile the network
class CNNClassifierV0(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.block_3(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)
model_0 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_0
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Try a forward pass to find shape that enters classifier
# Extract a sample batch and print shape
sample_batch, label_batch = next(iter(train_dataloader))
print(sample_batch.shape)
print(label_batch.shape)

# Do a test forward pass and print first five logits and probs
logits = model_0(sample_batch.to(device))
probs = torch.softmax(logits, dim=1)
print(logits[:5])
print(probs[:5])
# Out:
# torch.Size([32, 1, 13, 130])
# torch.Size([32])
# tensor([[ 0.0723,  0.1357, -0.0276, -0.2475, -0.0561,  0.0662,  0.2812,  0.1257,
#           0.3070,  0.1346],
#         [ 0.0703,  0.0691,  0.1142,  0.1514, -0.2119,  0.0564,  0.3432,  0.3610,
#          -0.1595, -0.0748],
#         [-0.5032,  0.0696, -0.0357,  0.0506,  0.1468, -0.0501,  0.2032,  0.2284,
#           0.0787, -0.1535],
#         [-0.2098,  0.2525,  0.0807,  0.4059, -0.0635, -0.1349,  0.7546,  0.4174,
#           0.2352, -0.0244],
#         [ 0.0156, -0.1172,  0.2397, -0.4165, -0.1946, -0.2428,  0.3997,  0.0473,
#           0.0521,  0.0820]], device='cuda:0', grad_fn=<SliceBackward0>)
# tensor([[0.0982, 0.1046, 0.0888, 0.0713, 0.0863, 0.0976, 0.1210, 0.1036, 0.1241,
#          0.1045],
#         [0.0982, 0.0981, 0.1027, 0.1065, 0.0741, 0.0969, 0.1291, 0.1314, 0.0781,
#          0.0850],
#         [0.0591, 0.1049, 0.0944, 0.1029, 0.1133, 0.0930, 0.1198, 0.1229, 0.1058,
#          0.0839],
#         [0.0655, 0.1040, 0.0876, 0.1212, 0.0758, 0.0706, 0.1718, 0.1226, 0.1022,
#          0.0788],
#         [0.1004, 0.0879, 0.1256, 0.0651, 0.0813, 0.0775, 0.1473, 0.1036, 0.1041,
#          0.1072]], device='cuda:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# ## 6. Training the model
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure. The optimizer carries a `weight_decay`, this is going to add an L2 regularization to avoid overfitting.
#
# In order to implement the training pipeline, we will create two separate functions:
# * `train_step()`: This function is responsible for the training of the model. It also includes the logic for calculating the accuracy. We could use `torchmetrics.accuracy()`, but instead one can calculate it. We use the `argmax()` method after applying a `softmax()` on the logits that are extracted from the model. This calculation gives us the predicted label, because it returns the index of the highest probability. After that, the accuracy is calculated as the sum of predicted labels that are the same as the labels, divided by the number of samples.
# * `test_step()`: This function will evaluate the loss and accuracy on a set. Initially we will use it on the evaluation set during training.
#
# Those two functions are combined in the `train()` function in order to train the model for a set number of epochs. We also use the `timeit` library to set a timer in order to time the training. The `train()` function returns a dictionary with the results, in order to use them for plotting.

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Train the model
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4600 | train_acc: 0.4714 | test_loss: 1.0969 | test_acc: 0.6070
# Epoch: 2 | train_loss: 1.1008 | train_acc: 0.6016 | test_loss: 0.9221 | test_acc: 0.6697
# Epoch: 3 | train_loss: 0.9494 | train_acc: 0.6611 | test_loss: 0.8224 | test_acc: 0.7101
# Epoch: 4 | train_loss: 0.8349 | train_acc: 0.7071 | test_loss: 0.8533 | test_acc: 0.6960
# Epoch: 5 | train_loss: 0.7639 | train_acc: 0.7325 | test_loss: 0.7326 | test_acc: 0.7431
# Epoch: 6 | train_loss: 0.7055 | train_acc: 0.7505 | test_loss: 0.6992 | test_acc: 0.7591
# Epoch: 7 | train_loss: 0.6006 | train_acc: 0.7823 | test_loss: 0.6747 | test_acc: 0.7678
# Epoch: 8 | train_loss: 0.5834 | train_acc: 0.7877 | test_loss: 0.7648 | test_acc: 0.7264
# Epoch: 9 | train_loss: 0.5244 | train_acc: 0.8166 | test_loss: 0.7063 | test_acc: 0.7578
# Epoch: 10 | train_loss: 0.5063 | train_acc: 0.8258 | test_loss: 0.7028 | test_acc: 0.7678
# Epoch: 11 | train_loss: 0.4556 | train_acc: 0.8430 | test_loss: 0.7090 | test_acc: 0.7689
# Epoch: 12 | train_loss: 0.4528 | train_acc: 0.8405 | test_loss: 0.6246 | test_acc: 0.7970
# Epoch: 13 | train_loss: 0.4029 | train_acc: 0.8602 | test_loss: 0.6453 | test_acc: 0.7813
# Epoch: 14 | train_loss: 0.3886 | train_acc: 0.8655 | test_loss: 0.6178 | test_acc: 0.7964
# Epoch: 15 | train_loss: 0.3389 | train_acc: 0.8822 | test_loss: 0.6243 | test_acc: 0.7990
# Epoch: 16 | train_loss: 0.3311 | train_acc: 0.8847 | test_loss: 0.6937 | test_acc: 0.7897
# Epoch: 17 | train_loss: 0.3229 | train_acc: 0.8862 | test_loss: 0.6934 | test_acc: 0.7899
# Epoch: 18 | train_loss: 0.3123 | train_acc: 0.8865 | test_loss: 0.6697 | test_acc: 0.7877
# Epoch: 19 | train_loss: 0.2649 | train_acc: 0.9051 | test_loss: 0.6848 | test_acc: 0.7831
# Epoch: 20 | train_loss: 0.2668 | train_acc: 0.9072 | test_loss: 0.6860 | test_acc: 0.8032
# Epoch: 21 | train_loss: 0.2800 | train_acc: 0.9020 | test_loss: 0.7262 | test_acc: 0.7867
# Epoch: 22 | train_loss: 0.2610 | train_acc: 0.9147 | test_loss: 0.6553 | test_acc: 0.7960
# Epoch: 23 | train_loss: 0.2477 | train_acc: 0.9127 | test_loss: 0.6935 | test_acc: 0.7984
# Epoch: 24 | train_loss: 0.2206 | train_acc: 0.9200 | test_loss: 0.6667 | test_acc: 0.8137
# Epoch: 25 | train_loss: 0.2152 | train_acc: 0.9234 | test_loss: 0.6883 | test_acc: 0.8046
# Epoch: 26 | train_loss: 0.2292 | train_acc: 0.9203 | test_loss: 0.6916 | test_acc: 0.8026
# Epoch: 27 | train_loss: 0.1959 | train_acc: 0.9318 | test_loss: 0.7496 | test_acc: 0.7780
# Epoch: 28 | train_loss: 0.1871 | train_acc: 0.9357 | test_loss: 0.7163 | test_acc: 0.7979
# Epoch: 29 | train_loss: 0.2010 | train_acc: 0.9302 | test_loss: 0.6856 | test_acc: 0.8004
# Epoch: 30 | train_loss: 0.1998 | train_acc: 0.9290 | test_loss: 0.7699 | test_acc: 0.7930
# Total training time: 12.661 seconds

# %% [markdown]
# ## 7. Plotting the results
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys
model_0_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
# defining the plot function
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]]):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, test_loss, label='test_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, test_accuracy, label='test_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# Judging by the plot results, we see that our model is overfitting despite using `Dropout()` layers and L2 regularization. This occurs very early, somewhere around the 5th epoch. As next steps of the pipeline, we will try some methods to avoid this phenomenon. We will create and evaluate some models, each of which uses a method to avoid overfitting, in order to see what methods fix the issue. The models and methods we are going to try, are:
# * `model_1`: The model is going to be trained using data augmentation.
# * `model_2`: We are going to use `Dropou2d()` layers in the convolution blocks.
# * `model_3`: We are going to implement _learning rate scheduling_ in the training.
# * `model_4`: We are going to improve the batch normalization by using `InstanceNorm2d()` instead of `BatchNorm2d()`
# * `model_5`: Use all of the above in a model.

# %% [markdown]
# ## 8. Using Data Augmentation
#
# For our next model we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.

# %% [markdown]
# ### 8.1 Implementing `TimeMasking()` and `FrequencyMasking()` on the data
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and coefficients respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
#
# > The `TimeMasking()` transform, "masks" the entire x axis for a specific amount. A good option would be to mask 15% of the sample. The *time_mask_param* is responsible for the amount of time frames that will be masked. We are calculating this value and setting it in the `TimeMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__: Our x axis is the time frames and we know that each sample has 130 time frames. We are going to mask 20 frames which is approximately 15% of the sample. This is done by setting the *time_mask_param* to 20. That means that maximum 20 consecutive frames will be masked.
#
# > The `FrequencyMasking()` transform, "masks" the entire y axis for a specific amount. A good option would be to mask 12% of the sample. The *freq_mask_param* is responsible for the amount of mel bands that will be masked. We are calculating this value and setting it in the `FrequencyMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__:Our y axis is the mel bands and we know that each sample has 64 mel bands. We are going to mask 8 frames which is approximately 12% of the sample. This is done by setting the *freq_mask_param* to 8. That means that maximum 8 consecutive frames will be masked.
#
# The masked spectograms are presented, to have a visualization of the augmented data. Similar methods of masking on log mel spectograms directly are mentioned in the SpecAugment paper. More info here - https://arxiv.org/pdf/1904.08779
#
# _**Notice**: The time_mask_param and freq_mask_param will set the **maximum** amount of frames/MFCCs that will be masked. This number will be random on each epoch._

# %%
# Calculating the proper time_mask_param anf freq_mask_param values
mfccs = inputs.shape[2]
time_frames = inputs.shape[1]

time_mask_param = round(time_frames * 0.15)
freq_mask_param = round(mfccs * 0.12)

time_mask_param, freq_mask_param
# Out:
# (20, 2)

# %%
# Creating time masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
time_masking = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
time_masked_data = time_masking(X[INDEX].squeeze()).to('cpu')
time_masked_data.shape
# Out:
# torch.Size([13, 130])

# %%
# Creating frequency masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED+8)

INDEX = np.random.randint(len(X))
freq_masking = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
freq_masked_data = freq_masking(X[INDEX].squeeze()).to('cpu')
freq_masked_data.shape
# Out:
# torch.Size([13, 130])

# %%
# Visualize data
time_masked_melspec_example = time_masked_data.numpy()
freq_masked_melspec_example = freq_masked_data.numpy()

fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharex=True, sharey=True)
im0 = axes[0].imshow(time_masked_melspec_example, cmap='hot', aspect='auto', origin='lower')
axes[0].set_title("Time-masked MFCCs")
axes[0].set_ylabel("MFCCs")
fig.colorbar(im0, ax=axes[0])

im1 = axes[1].imshow(freq_masked_melspec_example, cmap='hot', aspect='auto', origin='lower')
axes[1].set_title("Frequency-masked MFCCs")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("MFCCs")
fig.colorbar(im1, ax=axes[1])

fig.tight_layout()
plt.show()

# %% [markdown]
# In the frequency masked plot, we can see the first coefficient being masked.

# %% [markdown]
# ### 8.2 Training the model with augmented data
# We are going to create a new `train_step_with_augmentation()` and `train_with_augmentation` functions by altering our previous training functions in order to train the model with the augmented data. There is no need to use augmentation in validation and testing sets. The rest of the pipeline is the same. In the end we are going to plot the results to see if there is improvement.

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=time_mask_param),
    T.FrequencyMasking(freq_mask_param=freq_mask_param)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Instantiating a new model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_1 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_1
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train_with_augmentation(model=model_1,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.5562 | train_acc: 0.4381 | test_loss: 1.1625 | test_acc: 0.5692
# Epoch: 2 | train_loss: 1.2014 | train_acc: 0.5662 | test_loss: 0.9729 | test_acc: 0.6436
# Epoch: 3 | train_loss: 1.0748 | train_acc: 0.6089 | test_loss: 0.8574 | test_acc: 0.6989
# Epoch: 4 | train_loss: 0.9867 | train_acc: 0.6500 | test_loss: 0.8411 | test_acc: 0.6938
# Epoch: 5 | train_loss: 0.9223 | train_acc: 0.6815 | test_loss: 0.7834 | test_acc: 0.7218
# Epoch: 6 | train_loss: 0.8704 | train_acc: 0.6970 | test_loss: 0.7388 | test_acc: 0.7383
# Epoch: 7 | train_loss: 0.8002 | train_acc: 0.7234 | test_loss: 0.7082 | test_acc: 0.7563
# Epoch: 8 | train_loss: 0.7670 | train_acc: 0.7280 | test_loss: 0.6901 | test_acc: 0.7562
# Epoch: 9 | train_loss: 0.7607 | train_acc: 0.7296 | test_loss: 0.6997 | test_acc: 0.7617
# Epoch: 10 | train_loss: 0.7101 | train_acc: 0.7539 | test_loss: 0.6533 | test_acc: 0.7797
# Epoch: 11 | train_loss: 0.6912 | train_acc: 0.7569 | test_loss: 0.6507 | test_acc: 0.7850
# Epoch: 12 | train_loss: 0.6471 | train_acc: 0.7799 | test_loss: 0.6660 | test_acc: 0.7742
# Epoch: 13 | train_loss: 0.6319 | train_acc: 0.7798 | test_loss: 0.6864 | test_acc: 0.7638
# Epoch: 14 | train_loss: 0.6009 | train_acc: 0.7934 | test_loss: 0.6344 | test_acc: 0.7845
# Epoch: 15 | train_loss: 0.5903 | train_acc: 0.7906 | test_loss: 0.6470 | test_acc: 0.7816
# Epoch: 16 | train_loss: 0.5830 | train_acc: 0.7898 | test_loss: 0.6295 | test_acc: 0.7947
# Epoch: 17 | train_loss: 0.5796 | train_acc: 0.7987 | test_loss: 0.6157 | test_acc: 0.8004
# Epoch: 18 | train_loss: 0.5302 | train_acc: 0.8116 | test_loss: 0.7108 | test_acc: 0.7662
# Epoch: 19 | train_loss: 0.5565 | train_acc: 0.8035 | test_loss: 0.6471 | test_acc: 0.7877
# Epoch: 20 | train_loss: 0.5107 | train_acc: 0.8272 | test_loss: 0.5891 | test_acc: 0.8023
# Epoch: 21 | train_loss: 0.5192 | train_acc: 0.8146 | test_loss: 0.6061 | test_acc: 0.8015
# Epoch: 22 | train_loss: 0.4614 | train_acc: 0.8395 | test_loss: 0.5659 | test_acc: 0.8112
# Epoch: 23 | train_loss: 0.4934 | train_acc: 0.8230 | test_loss: 0.6058 | test_acc: 0.8017
# Epoch: 24 | train_loss: 0.4612 | train_acc: 0.8420 | test_loss: 0.7127 | test_acc: 0.7790
# Epoch: 25 | train_loss: 0.4755 | train_acc: 0.8351 | test_loss: 0.7205 | test_acc: 0.7662
# Epoch: 26 | train_loss: 0.4652 | train_acc: 0.8374 | test_loss: 0.6067 | test_acc: 0.8083
# Epoch: 27 | train_loss: 0.4281 | train_acc: 0.8527 | test_loss: 0.6575 | test_acc: 0.7915
# Epoch: 28 | train_loss: 0.4333 | train_acc: 0.8504 | test_loss: 0.5698 | test_acc: 0.8190
# Epoch: 29 | train_loss: 0.4238 | train_acc: 0.8605 | test_loss: 0.5841 | test_acc: 0.8093
# Epoch: 30 | train_loss: 0.4128 | train_acc: 0.8534 | test_loss: 0.5880 | test_acc: 0.8085
# Total training time: 18.793 seconds

# %%
plot_loss_curves(model_1_results)

# %% [markdown]
# ## 9. Using Dropout2d
#
# We will add a `Dropout2d()` layer in each convolution block. This layer will zero out entire channels. It is a common practise in convolution networks. More info here - https://docs.pytorch.org/docs/stable/generated/torch.nn.Dropout2d.html
#
# We will have to build a new class for the classifier, as well as instantiate a new model. The rest of the pipeline is the same.

# %%
# Compile the network
class CNNClassifierV1(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.BatchNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_2 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_2
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_2_results = train(model=model_2,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4716 | train_acc: 0.4617 | test_loss: 1.1049 | test_acc: 0.6073
# Epoch: 2 | train_loss: 1.0902 | train_acc: 0.6140 | test_loss: 0.9871 | test_acc: 0.6471
# Epoch: 3 | train_loss: 0.9531 | train_acc: 0.6593 | test_loss: 0.9352 | test_acc: 0.6785
# Epoch: 4 | train_loss: 0.8289 | train_acc: 0.7071 | test_loss: 0.7713 | test_acc: 0.7338
# Epoch: 5 | train_loss: 0.7408 | train_acc: 0.7367 | test_loss: 0.7164 | test_acc: 0.7494
# Epoch: 6 | train_loss: 0.6632 | train_acc: 0.7634 | test_loss: 0.6406 | test_acc: 0.7895
# Epoch: 7 | train_loss: 0.6177 | train_acc: 0.7890 | test_loss: 0.6739 | test_acc: 0.7658
# Epoch: 8 | train_loss: 0.5588 | train_acc: 0.8048 | test_loss: 0.6485 | test_acc: 0.7803
# Epoch: 9 | train_loss: 0.5031 | train_acc: 0.8234 | test_loss: 0.6313 | test_acc: 0.7926
# Epoch: 10 | train_loss: 0.4602 | train_acc: 0.8399 | test_loss: 0.7169 | test_acc: 0.7548
# Epoch: 11 | train_loss: 0.4368 | train_acc: 0.8480 | test_loss: 0.6148 | test_acc: 0.7907
# Epoch: 12 | train_loss: 0.4026 | train_acc: 0.8620 | test_loss: 0.5906 | test_acc: 0.8050
# Epoch: 13 | train_loss: 0.3884 | train_acc: 0.8686 | test_loss: 0.7259 | test_acc: 0.7578
# Epoch: 14 | train_loss: 0.3624 | train_acc: 0.8733 | test_loss: 0.7032 | test_acc: 0.7679
# Epoch: 15 | train_loss: 0.3472 | train_acc: 0.8765 | test_loss: 0.6701 | test_acc: 0.7780
# Epoch: 16 | train_loss: 0.3303 | train_acc: 0.8848 | test_loss: 0.5912 | test_acc: 0.8012
# Epoch: 17 | train_loss: 0.2906 | train_acc: 0.9034 | test_loss: 0.6197 | test_acc: 0.7991
# Epoch: 18 | train_loss: 0.2888 | train_acc: 0.8997 | test_loss: 0.6478 | test_acc: 0.8052
# Epoch: 19 | train_loss: 0.2634 | train_acc: 0.9083 | test_loss: 0.7418 | test_acc: 0.7891
# Epoch: 20 | train_loss: 0.2647 | train_acc: 0.9053 | test_loss: 0.6597 | test_acc: 0.7993
# Epoch: 21 | train_loss: 0.2600 | train_acc: 0.9112 | test_loss: 0.6663 | test_acc: 0.7858
# Epoch: 22 | train_loss: 0.2313 | train_acc: 0.9222 | test_loss: 0.7238 | test_acc: 0.7947
# Epoch: 23 | train_loss: 0.2271 | train_acc: 0.9242 | test_loss: 0.7167 | test_acc: 0.7938
# Epoch: 24 | train_loss: 0.2262 | train_acc: 0.9245 | test_loss: 0.6685 | test_acc: 0.7919
# Epoch: 25 | train_loss: 0.2121 | train_acc: 0.9240 | test_loss: 0.6943 | test_acc: 0.7946
# Epoch: 26 | train_loss: 0.2121 | train_acc: 0.9270 | test_loss: 0.6863 | test_acc: 0.7981
# Epoch: 27 | train_loss: 0.1913 | train_acc: 0.9342 | test_loss: 0.7309 | test_acc: 0.7832
# Epoch: 28 | train_loss: 0.1982 | train_acc: 0.9353 | test_loss: 0.6794 | test_acc: 0.8034
# Epoch: 29 | train_loss: 0.1926 | train_acc: 0.9292 | test_loss: 0.6458 | test_acc: 0.8120
# Epoch: 30 | train_loss: 0.2029 | train_acc: 0.9282 | test_loss: 0.6821 | test_acc: 0.8059
# Total training time: 10.894 seconds

# %%
plot_loss_curves(model_2_results)

# %% [markdown]
# ## 10. Learning rate scheduling
#
# The concept of learning rate scheduling is adjusting the learning rate of the optimizer while training. The objective that we seek to achieve with the method of gradient descent is to find values for the weights and biases that produce the least error. The *learing rate* hypeprameter is very crucial to this algorithm. A very high learning rate can lead to difficulty to find the local minimum of the error function, whereas a low learning rate can lead to slow training. Learning rate scheduling, adjusts the value of the learning rate in various ways instead of having a steady value. We are going to use the *Adaptive Plateau Reduction* approach, which is implemented by the `ReduceLROnPlateau()` method. For more info on learning rate scheduling - https://machinelearningmastery.com/a-gentle-introduction-to-learning-rate-schedulers/
#
# In order to include learning rate scheduling in the training, we have to instantiate a `ReduceLROnPlateau` instance and include it in our `train()` function. In this manner, our train function will now be `train_with_scheduler()`. Furthermore, the value of the learning rate in each epoch will also be saved and included in the dictionary that the function returns. As a result, we will be able to spot when the learning rate changes, in case that happens.
#
# The rest of the pipeline is the same.

# %%
# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_3 = CNNClassifierV0(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_3
# Out:
# CNNClassifierV0(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss, optimizer and scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_3.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

scheduler = ReduceLROnPlateau(optimizer,
                             mode='min',
                             factor=0.5,
                             patience=5)

# %%
# Create train function by combining train_step and test_step
from tqdm.notebook import tqdm

# 1. Take in various parameters required for training and test steps
def train_w_scheduler(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          scheduler: torch.optim.lr_scheduler._LRScheduler = None,
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "learning_rates": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Update scheduler if it exists
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_loss)
            else:
                scheduler.step()

        # Saving the current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        results["learning_rates"].append(current_lr)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"LR: {current_lr:.6f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_3_results = train_w_scheduler(model=model_3,
                                    train_dataloader=train_dataloader,
                                    test_dataloader=validation_dataloader,
                                    optimizer=optimizer,
                                    loss_fn=loss_fn,
                                    epochs=NUM_EPOCHS,
                                    scheduler=scheduler)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4716 | train_acc: 0.4617 | test_loss: 1.1049 | test_acc: 0.6073 | LR: 0.001000
# Epoch: 2 | train_loss: 1.0902 | train_acc: 0.6140 | test_loss: 0.9871 | test_acc: 0.6471 | LR: 0.001000
# Epoch: 3 | train_loss: 0.9531 | train_acc: 0.6593 | test_loss: 0.9352 | test_acc: 0.6785 | LR: 0.001000
# Epoch: 4 | train_loss: 0.8289 | train_acc: 0.7071 | test_loss: 0.7713 | test_acc: 0.7338 | LR: 0.001000
# Epoch: 5 | train_loss: 0.7408 | train_acc: 0.7367 | test_loss: 0.7164 | test_acc: 0.7494 | LR: 0.001000
# Epoch: 6 | train_loss: 0.6632 | train_acc: 0.7634 | test_loss: 0.6406 | test_acc: 0.7895 | LR: 0.001000
# Epoch: 7 | train_loss: 0.6177 | train_acc: 0.7890 | test_loss: 0.6739 | test_acc: 0.7658 | LR: 0.001000
# Epoch: 8 | train_loss: 0.5588 | train_acc: 0.8048 | test_loss: 0.6485 | test_acc: 0.7803 | LR: 0.001000
# Epoch: 9 | train_loss: 0.5031 | train_acc: 0.8234 | test_loss: 0.6313 | test_acc: 0.7926 | LR: 0.001000
# Epoch: 10 | train_loss: 0.4602 | train_acc: 0.8399 | test_loss: 0.7169 | test_acc: 0.7548 | LR: 0.001000
# Epoch: 11 | train_loss: 0.4368 | train_acc: 0.8480 | test_loss: 0.6148 | test_acc: 0.7907 | LR: 0.001000
# Epoch: 12 | train_loss: 0.4026 | train_acc: 0.8620 | test_loss: 0.5906 | test_acc: 0.8050 | LR: 0.001000
# Epoch: 13 | train_loss: 0.3884 | train_acc: 0.8686 | test_loss: 0.7259 | test_acc: 0.7578 | LR: 0.001000
# Epoch: 14 | train_loss: 0.3624 | train_acc: 0.8733 | test_loss: 0.7032 | test_acc: 0.7679 | LR: 0.001000
# Epoch: 15 | train_loss: 0.3472 | train_acc: 0.8765 | test_loss: 0.6701 | test_acc: 0.7780 | LR: 0.001000
# Epoch: 16 | train_loss: 0.3303 | train_acc: 0.8848 | test_loss: 0.5912 | test_acc: 0.8012 | LR: 0.001000
# Epoch: 17 | train_loss: 0.2906 | train_acc: 0.9034 | test_loss: 0.6197 | test_acc: 0.7991 | LR: 0.001000
# Epoch: 18 | train_loss: 0.2888 | train_acc: 0.8997 | test_loss: 0.6478 | test_acc: 0.8052 | LR: 0.000500
# Epoch: 19 | train_loss: 0.2129 | train_acc: 0.9299 | test_loss: 0.5956 | test_acc: 0.8194 | LR: 0.000500
# Epoch: 20 | train_loss: 0.1845 | train_acc: 0.9372 | test_loss: 0.6106 | test_acc: 0.8045 | LR: 0.000500
# Epoch: 21 | train_loss: 0.1820 | train_acc: 0.9406 | test_loss: 0.5915 | test_acc: 0.8133 | LR: 0.000500
# Epoch: 22 | train_loss: 0.1717 | train_acc: 0.9475 | test_loss: 0.6199 | test_acc: 0.8187 | LR: 0.000500
# Epoch: 23 | train_loss: 0.1692 | train_acc: 0.9455 | test_loss: 0.6342 | test_acc: 0.8033 | LR: 0.000500
# Epoch: 24 | train_loss: 0.1684 | train_acc: 0.9467 | test_loss: 0.6267 | test_acc: 0.8114 | LR: 0.000250
# Epoch: 25 | train_loss: 0.1373 | train_acc: 0.9548 | test_loss: 0.5599 | test_acc: 0.8300 | LR: 0.000250
# Epoch: 26 | train_loss: 0.1250 | train_acc: 0.9620 | test_loss: 0.5775 | test_acc: 0.8261 | LR: 0.000250
# Epoch: 27 | train_loss: 0.1205 | train_acc: 0.9641 | test_loss: 0.5817 | test_acc: 0.8307 | LR: 0.000250
# Epoch: 28 | train_loss: 0.1130 | train_acc: 0.9646 | test_loss: 0.5778 | test_acc: 0.8273 | LR: 0.000250
# Epoch: 29 | train_loss: 0.1172 | train_acc: 0.9614 | test_loss: 0.5925 | test_acc: 0.8268 | LR: 0.000250
# Epoch: 30 | train_loss: 0.1253 | train_acc: 0.9601 | test_loss: 0.6281 | test_acc: 0.8195 | LR: 0.000250
# Total training time: 11.198 seconds

# %% [markdown]
# We can see that the learning rate changes in epoch #17 and #25.

# %%
plot_loss_curves(model_3_results)

# %% [markdown]
# ## 11. Using Instance Normalization instead of Batch Normalization
#
# Instance normalization normalizes each input individually focusing only on its own features. This is more like giving personalized feedback to each student without comparing them to others. For more info - https://stackoverflow.com/questions/45463778/instance-normalisation-vs-batch-normalisation
#
# In order to use Instance Normalization, we will replace the `BatchNorm2d()` layers with `InstanceNorm2d()` in the convolution blocks. So we have to create a new Classifier class and a new model. Other than that, the pipeline is the same.

# %%
# Compile the network
class CNNClassifierV2(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_4 = CNNClassifierV2(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_4
# Out:
# CNNClassifierV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_4.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_4_results = train(model=model_4,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.3011 | train_acc: 0.1361 | test_loss: 2.2306 | test_acc: 0.1660
# Epoch: 2 | train_loss: 2.0568 | train_acc: 0.2687 | test_loss: 1.9734 | test_acc: 0.2794
# Epoch: 3 | train_loss: 1.8248 | train_acc: 0.3494 | test_loss: 1.8259 | test_acc: 0.3346
# Epoch: 4 | train_loss: 1.6612 | train_acc: 0.4013 | test_loss: 1.7352 | test_acc: 0.3642
# Epoch: 5 | train_loss: 1.5405 | train_acc: 0.4537 | test_loss: 1.7134 | test_acc: 0.3808
# Epoch: 6 | train_loss: 1.4504 | train_acc: 0.4813 | test_loss: 1.6840 | test_acc: 0.4001
# Epoch: 7 | train_loss: 1.3590 | train_acc: 0.5195 | test_loss: 1.6762 | test_acc: 0.4062
# Epoch: 8 | train_loss: 1.2713 | train_acc: 0.5482 | test_loss: 1.6694 | test_acc: 0.4214
# Epoch: 9 | train_loss: 1.1923 | train_acc: 0.5823 | test_loss: 1.6708 | test_acc: 0.4143
# Epoch: 10 | train_loss: 1.1350 | train_acc: 0.5930 | test_loss: 1.6853 | test_acc: 0.3980
# Epoch: 11 | train_loss: 1.0692 | train_acc: 0.6286 | test_loss: 1.7441 | test_acc: 0.4029
# Epoch: 12 | train_loss: 1.0160 | train_acc: 0.6507 | test_loss: 1.7471 | test_acc: 0.4076
# Epoch: 13 | train_loss: 0.9714 | train_acc: 0.6607 | test_loss: 1.7765 | test_acc: 0.3878
# Epoch: 14 | train_loss: 0.8987 | train_acc: 0.6917 | test_loss: 1.8114 | test_acc: 0.4081
# Epoch: 15 | train_loss: 0.8343 | train_acc: 0.7088 | test_loss: 1.8222 | test_acc: 0.4103
# Epoch: 16 | train_loss: 0.7897 | train_acc: 0.7242 | test_loss: 1.8749 | test_acc: 0.4002
# Epoch: 17 | train_loss: 0.7507 | train_acc: 0.7398 | test_loss: 1.8923 | test_acc: 0.3940
# Epoch: 18 | train_loss: 0.7026 | train_acc: 0.7626 | test_loss: 1.9433 | test_acc: 0.4068
# Epoch: 19 | train_loss: 0.7201 | train_acc: 0.7512 | test_loss: 1.9792 | test_acc: 0.4007
# Epoch: 20 | train_loss: 0.6753 | train_acc: 0.7656 | test_loss: 1.9866 | test_acc: 0.4033
# Epoch: 21 | train_loss: 0.6594 | train_acc: 0.7642 | test_loss: 2.0522 | test_acc: 0.4054
# Epoch: 22 | train_loss: 0.6295 | train_acc: 0.7793 | test_loss: 2.0594 | test_acc: 0.4047
# Epoch: 23 | train_loss: 0.6161 | train_acc: 0.7911 | test_loss: 2.0745 | test_acc: 0.3962
# Epoch: 24 | train_loss: 0.6003 | train_acc: 0.7942 | test_loss: 2.0930 | test_acc: 0.4027
# Epoch: 25 | train_loss: 0.5339 | train_acc: 0.8241 | test_loss: 2.1336 | test_acc: 0.4008
# Epoch: 26 | train_loss: 0.5008 | train_acc: 0.8319 | test_loss: 2.1859 | test_acc: 0.4027
# Epoch: 27 | train_loss: 0.4697 | train_acc: 0.8386 | test_loss: 2.2335 | test_acc: 0.4033
# Epoch: 28 | train_loss: 0.4502 | train_acc: 0.8502 | test_loss: 2.2804 | test_acc: 0.3982
# Epoch: 29 | train_loss: 0.4690 | train_acc: 0.8442 | test_loss: 2.3101 | test_acc: 0.3908
# Epoch: 30 | train_loss: 0.4469 | train_acc: 0.8424 | test_loss: 2.3156 | test_acc: 0.4052
# Total training time: 10.885 seconds

# %%
plot_loss_curves(model_4_results)

# %% [markdown]
# ## 12. Create model to combine all previous methods
#
# We are going to combine all the previous methods. The new Classifier class is going to have `Dropout2d()` layers as well as `InstanceNorm2d()` layers. We are going to use `ReduceLROnPlateau()` for the scheduler, as well as train with augmented data. Finally, we are going to train the model for 200 epochs.

# %%
# Compile the network
class CNNClassifierV3(nn.Module):
    def __init__(self, input_shape: int = 1,
                 hidden_units:int = 32,
                 output_shape: int = 10):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2,
                         padding=1),
            nn.InstanceNorm2d(hidden_units),
            nn.Dropout2d(0.3)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_units * 1 * 16,
                      64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, output_shape)
        )

    def forward(self, x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.classifier(x)
        return x

# Create a model and put it to device
torch.manual_seed(RANDOM_SEED)

model_5 = CNNClassifierV3(input_shape=1,
                          hidden_units=32,
                          output_shape=10).to(device)
model_5
# Out:
# CNNClassifierV3(
#   (block_1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): Dropout2d(p=0.3, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Create loss, optimizer and scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_5.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

scheduler = ReduceLROnPlateau(optimizer,
                             mode='min',
                             factor=0.5,
                             patience=5)

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train_with_augmented_data_and_scheduler(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          scheduler: torch.optim.lr_scheduler._LRScheduler = None,
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "learning_rates": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer,)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # update scheduler if it exists
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(test_loss)
            else:
                scheduler.step()

        # saving the current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        results["learning_rates"].append(current_lr)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"LR: {current_lr:.6f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Training the model using the train function
# Set number of epochs
NUM_EPOCHS = 200

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_5_results = train_with_augmented_data_and_scheduler(model=model_5,
                                                        train_dataloader=train_dataloader,
                                                        test_dataloader=validation_dataloader,
                                                        optimizer=optimizer,
                                                        loss_fn=loss_fn,
                                                        epochs=NUM_EPOCHS,
                                                        scheduler=scheduler)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.3404 | train_acc: 0.1062 | test_loss: 2.3021 | test_acc: 0.1147 | LR: 0.001000
# Epoch: 2 | train_loss: 2.3120 | train_acc: 0.1257 | test_loss: 2.2754 | test_acc: 0.1475 | LR: 0.001000
# Epoch: 3 | train_loss: 2.2586 | train_acc: 0.1468 | test_loss: 2.2157 | test_acc: 0.1696 | LR: 0.001000
# Epoch: 4 | train_loss: 2.1897 | train_acc: 0.1825 | test_loss: 2.1609 | test_acc: 0.2080 | LR: 0.001000
# Epoch: 5 | train_loss: 2.1130 | train_acc: 0.2189 | test_loss: 2.0594 | test_acc: 0.2394 | LR: 0.001000
# Epoch: 6 | train_loss: 2.0133 | train_acc: 0.2583 | test_loss: 1.9648 | test_acc: 0.2793 | LR: 0.001000
# Epoch: 7 | train_loss: 1.9630 | train_acc: 0.2719 | test_loss: 1.9074 | test_acc: 0.2974 | LR: 0.001000
# Epoch: 8 | train_loss: 1.8993 | train_acc: 0.2977 | test_loss: 1.8868 | test_acc: 0.2953 | LR: 0.001000
# Epoch: 9 | train_loss: 1.8738 | train_acc: 0.3051 | test_loss: 1.8698 | test_acc: 0.3062 | LR: 0.001000
# Epoch: 10 | train_loss: 1.8642 | train_acc: 0.3190 | test_loss: 1.8281 | test_acc: 0.3127 | LR: 0.001000
# Epoch: 11 | train_loss: 1.8260 | train_acc: 0.3327 | test_loss: 1.8605 | test_acc: 0.2982 | LR: 0.001000
# Epoch: 12 | train_loss: 1.8233 | train_acc: 0.3247 | test_loss: 1.8150 | test_acc: 0.3214 | LR: 0.001000
# Epoch: 13 | train_loss: 1.8169 | train_acc: 0.3332 | test_loss: 1.8070 | test_acc: 0.3280 | LR: 0.001000
# Epoch: 14 | train_loss: 1.7951 | train_acc: 0.3386 | test_loss: 1.8285 | test_acc: 0.3244 | LR: 0.001000
# Epoch: 15 | train_loss: 1.7798 | train_acc: 0.3448 | test_loss: 1.8025 | test_acc: 0.3308 | LR: 0.001000
# Epoch: 16 | train_loss: 1.7904 | train_acc: 0.3493 | test_loss: 1.7849 | test_acc: 0.3368 | LR: 0.001000
# Epoch: 17 | train_loss: 1.7740 | train_acc: 0.3483 | test_loss: 1.7746 | test_acc: 0.3454 | LR: 0.001000
# Epoch: 18 | train_loss: 1.7673 | train_acc: 0.3485 | test_loss: 1.7650 | test_acc: 0.3530 | LR: 0.001000
# Epoch: 19 | train_loss: 1.7490 | train_acc: 0.3484 | test_loss: 1.7364 | test_acc: 0.3549 | LR: 0.001000
# Epoch: 20 | train_loss: 1.7406 | train_acc: 0.3580 | test_loss: 1.7331 | test_acc: 0.3534 | LR: 0.001000
# Epoch: 21 | train_loss: 1.7515 | train_acc: 0.3640 | test_loss: 1.7276 | test_acc: 0.3617 | LR: 0.001000
# Epoch: 22 | train_loss: 1.7379 | train_acc: 0.3682 | test_loss: 1.7416 | test_acc: 0.3571 | LR: 0.001000
# Epoch: 23 | train_loss: 1.7563 | train_acc: 0.3520 | test_loss: 1.7307 | test_acc: 0.3755 | LR: 0.001000
# Epoch: 24 | train_loss: 1.7322 | train_acc: 0.3589 | test_loss: 1.7110 | test_acc: 0.3554 | LR: 0.001000
# Epoch: 25 | train_loss: 1.7406 | train_acc: 0.3663 | test_loss: 1.7404 | test_acc: 0.3521 | LR: 0.001000
# Epoch: 26 | train_loss: 1.7101 | train_acc: 0.3767 | test_loss: 1.6968 | test_acc: 0.3814 | LR: 0.001000
# Epoch: 27 | train_loss: 1.7165 | train_acc: 0.3809 | test_loss: 1.7134 | test_acc: 0.3774 | LR: 0.001000
# Epoch: 28 | train_loss: 1.7184 | train_acc: 0.3755 | test_loss: 1.7061 | test_acc: 0.3641 | LR: 0.001000
# Epoch: 29 | train_loss: 1.6980 | train_acc: 0.3778 | test_loss: 1.7152 | test_acc: 0.3700 | LR: 0.001000
# Epoch: 30 | train_loss: 1.6750 | train_acc: 0.3886 | test_loss: 1.6830 | test_acc: 0.3881 | LR: 0.001000
# Epoch: 31 | train_loss: 1.6934 | train_acc: 0.3793 | test_loss: 1.7105 | test_acc: 0.3693 | LR: 0.001000
# Epoch: 32 | train_loss: 1.7016 | train_acc: 0.3845 | test_loss: 1.7034 | test_acc: 0.3722 | LR: 0.001000
# Epoch: 33 | train_loss: 1.6977 | train_acc: 0.3811 | test_loss: 1.6874 | test_acc: 0.3860 | LR: 0.001000
# Epoch: 34 | train_loss: 1.6847 | train_acc: 0.3788 | test_loss: 1.7243 | test_acc: 0.3634 | LR: 0.001000
# Epoch: 35 | train_loss: 1.6979 | train_acc: 0.3787 | test_loss: 1.6869 | test_acc: 0.3734 | LR: 0.001000
# Epoch: 36 | train_loss: 1.7011 | train_acc: 0.3803 | test_loss: 1.6773 | test_acc: 0.4064 | LR: 0.001000
# Epoch: 37 | train_loss: 1.6785 | train_acc: 0.3813 | test_loss: 1.6679 | test_acc: 0.3873 | LR: 0.001000
# Epoch: 38 | train_loss: 1.6844 | train_acc: 0.3846 | test_loss: 1.7103 | test_acc: 0.3787 | LR: 0.001000
# Epoch: 39 | train_loss: 1.6969 | train_acc: 0.3825 | test_loss: 1.6855 | test_acc: 0.3873 | LR: 0.001000
# Epoch: 40 | train_loss: 1.6850 | train_acc: 0.3916 | test_loss: 1.6975 | test_acc: 0.3846 | LR: 0.001000
# Epoch: 41 | train_loss: 1.6739 | train_acc: 0.3817 | test_loss: 1.6769 | test_acc: 0.3759 | LR: 0.001000
# Epoch: 42 | train_loss: 1.6854 | train_acc: 0.3934 | test_loss: 1.6841 | test_acc: 0.3727 | LR: 0.001000
# Epoch: 43 | train_loss: 1.6742 | train_acc: 0.3934 | test_loss: 1.7319 | test_acc: 0.3613 | LR: 0.000500
# Epoch: 44 | train_loss: 1.6346 | train_acc: 0.4014 | test_loss: 1.6869 | test_acc: 0.3835 | LR: 0.000500
# Epoch: 45 | train_loss: 1.6441 | train_acc: 0.4061 | test_loss: 1.6858 | test_acc: 0.3888 | LR: 0.000500
# Epoch: 46 | train_loss: 1.6177 | train_acc: 0.4061 | test_loss: 1.6657 | test_acc: 0.3921 | LR: 0.000500
# Epoch: 47 | train_loss: 1.6325 | train_acc: 0.4043 | test_loss: 1.6678 | test_acc: 0.3893 | LR: 0.000500
# Epoch: 48 | train_loss: 1.6187 | train_acc: 0.4152 | test_loss: 1.6791 | test_acc: 0.3887 | LR: 0.000500
# Epoch: 49 | train_loss: 1.6010 | train_acc: 0.4159 | test_loss: 1.6729 | test_acc: 0.3834 | LR: 0.000500
# Epoch: 50 | train_loss: 1.6140 | train_acc: 0.4129 | test_loss: 1.6562 | test_acc: 0.3973 | LR: 0.000500
# Epoch: 51 | train_loss: 1.6133 | train_acc: 0.4150 | test_loss: 1.6561 | test_acc: 0.3920 | LR: 0.000500
# Epoch: 52 | train_loss: 1.5956 | train_acc: 0.4172 | test_loss: 1.6673 | test_acc: 0.3935 | LR: 0.000500
# Epoch: 53 | train_loss: 1.6036 | train_acc: 0.4238 | test_loss: 1.6722 | test_acc: 0.3907 | LR: 0.000500
# Epoch: 54 | train_loss: 1.5789 | train_acc: 0.4249 | test_loss: 1.6504 | test_acc: 0.4026 | LR: 0.000500
# Epoch: 55 | train_loss: 1.6011 | train_acc: 0.4212 | test_loss: 1.6117 | test_acc: 0.4153 | LR: 0.000500
# Epoch: 56 | train_loss: 1.6005 | train_acc: 0.4130 | test_loss: 1.6746 | test_acc: 0.3929 | LR: 0.000500
# Epoch: 57 | train_loss: 1.6130 | train_acc: 0.4229 | test_loss: 1.6244 | test_acc: 0.4034 | LR: 0.000500
# Epoch: 58 | train_loss: 1.6095 | train_acc: 0.4125 | test_loss: 1.6459 | test_acc: 0.4061 | LR: 0.000500
# Epoch: 59 | train_loss: 1.6011 | train_acc: 0.4156 | test_loss: 1.6456 | test_acc: 0.3999 | LR: 0.000500
# Epoch: 60 | train_loss: 1.5879 | train_acc: 0.4248 | test_loss: 1.6351 | test_acc: 0.4002 | LR: 0.000500
# Epoch: 61 | train_loss: 1.6045 | train_acc: 0.4127 | test_loss: 1.6157 | test_acc: 0.4175 | LR: 0.000250
# Epoch: 62 | train_loss: 1.5532 | train_acc: 0.4371 | test_loss: 1.6205 | test_acc: 0.4129 | LR: 0.000250
# Epoch: 63 | train_loss: 1.5814 | train_acc: 0.4242 | test_loss: 1.6240 | test_acc: 0.4188 | LR: 0.000250
# Epoch: 64 | train_loss: 1.5654 | train_acc: 0.4393 | test_loss: 1.6206 | test_acc: 0.4175 | LR: 0.000250
# Epoch: 65 | train_loss: 1.5629 | train_acc: 0.4275 | test_loss: 1.6086 | test_acc: 0.4254 | LR: 0.000250
# Epoch: 66 | train_loss: 1.5650 | train_acc: 0.4295 | test_loss: 1.6136 | test_acc: 0.4155 | LR: 0.000250
# Epoch: 67 | train_loss: 1.5607 | train_acc: 0.4395 | test_loss: 1.6125 | test_acc: 0.4181 | LR: 0.000250
# Epoch: 68 | train_loss: 1.5592 | train_acc: 0.4389 | test_loss: 1.6048 | test_acc: 0.4201 | LR: 0.000250
# Epoch: 69 | train_loss: 1.5419 | train_acc: 0.4477 | test_loss: 1.6058 | test_acc: 0.4228 | LR: 0.000250
# Epoch: 70 | train_loss: 1.5417 | train_acc: 0.4477 | test_loss: 1.6096 | test_acc: 0.4115 | LR: 0.000250
# Epoch: 71 | train_loss: 1.5413 | train_acc: 0.4430 | test_loss: 1.6150 | test_acc: 0.4195 | LR: 0.000250
# Epoch: 72 | train_loss: 1.5661 | train_acc: 0.4366 | test_loss: 1.6039 | test_acc: 0.4233 | LR: 0.000250
# Epoch: 73 | train_loss: 1.5467 | train_acc: 0.4372 | test_loss: 1.6101 | test_acc: 0.4154 | LR: 0.000250
# Epoch: 74 | train_loss: 1.5437 | train_acc: 0.4434 | test_loss: 1.6129 | test_acc: 0.4135 | LR: 0.000250
# Epoch: 75 | train_loss: 1.5397 | train_acc: 0.4549 | test_loss: 1.6026 | test_acc: 0.4175 | LR: 0.000250
# Epoch: 76 | train_loss: 1.5341 | train_acc: 0.4366 | test_loss: 1.6027 | test_acc: 0.4195 | LR: 0.000250
# Epoch: 77 | train_loss: 1.5341 | train_acc: 0.4396 | test_loss: 1.6060 | test_acc: 0.4195 | LR: 0.000250
# Epoch: 78 | train_loss: 1.5418 | train_acc: 0.4385 | test_loss: 1.5981 | test_acc: 0.4267 | LR: 0.000250
# Epoch: 79 | train_loss: 1.5424 | train_acc: 0.4415 | test_loss: 1.6002 | test_acc: 0.4253 | LR: 0.000250
# Epoch: 80 | train_loss: 1.5392 | train_acc: 0.4419 | test_loss: 1.6001 | test_acc: 0.4233 | LR: 0.000250
# Epoch: 81 | train_loss: 1.5482 | train_acc: 0.4373 | test_loss: 1.6050 | test_acc: 0.4207 | LR: 0.000250
# Epoch: 82 | train_loss: 1.5158 | train_acc: 0.4523 | test_loss: 1.5955 | test_acc: 0.4240 | LR: 0.000250
# Epoch: 83 | train_loss: 1.5357 | train_acc: 0.4491 | test_loss: 1.6059 | test_acc: 0.4220 | LR: 0.000250
# Epoch: 84 | train_loss: 1.5436 | train_acc: 0.4453 | test_loss: 1.5945 | test_acc: 0.4233 | LR: 0.000250
# Epoch: 85 | train_loss: 1.5217 | train_acc: 0.4534 | test_loss: 1.5938 | test_acc: 0.4220 | LR: 0.000250
# Epoch: 86 | train_loss: 1.5454 | train_acc: 0.4468 | test_loss: 1.5924 | test_acc: 0.4248 | LR: 0.000250
# Epoch: 87 | train_loss: 1.5208 | train_acc: 0.4616 | test_loss: 1.5839 | test_acc: 0.4254 | LR: 0.000250
# Epoch: 88 | train_loss: 1.5252 | train_acc: 0.4529 | test_loss: 1.5976 | test_acc: 0.4166 | LR: 0.000250
# Epoch: 89 | train_loss: 1.5430 | train_acc: 0.4462 | test_loss: 1.5898 | test_acc: 0.4126 | LR: 0.000250
# Epoch: 90 | train_loss: 1.5164 | train_acc: 0.4523 | test_loss: 1.5946 | test_acc: 0.4181 | LR: 0.000250
# Epoch: 91 | train_loss: 1.5239 | train_acc: 0.4436 | test_loss: 1.5926 | test_acc: 0.4186 | LR: 0.000250
# Epoch: 92 | train_loss: 1.5212 | train_acc: 0.4485 | test_loss: 1.6124 | test_acc: 0.4161 | LR: 0.000250
# Epoch: 93 | train_loss: 1.5434 | train_acc: 0.4442 | test_loss: 1.6045 | test_acc: 0.4107 | LR: 0.000125
# Epoch: 94 | train_loss: 1.5139 | train_acc: 0.4617 | test_loss: 1.5891 | test_acc: 0.4234 | LR: 0.000125
# Epoch: 95 | train_loss: 1.5097 | train_acc: 0.4539 | test_loss: 1.5934 | test_acc: 0.4148 | LR: 0.000125
# Epoch: 96 | train_loss: 1.5027 | train_acc: 0.4547 | test_loss: 1.5981 | test_acc: 0.4140 | LR: 0.000125
# Epoch: 97 | train_loss: 1.5113 | train_acc: 0.4521 | test_loss: 1.5925 | test_acc: 0.4147 | LR: 0.000125
# Epoch: 98 | train_loss: 1.5127 | train_acc: 0.4548 | test_loss: 1.5860 | test_acc: 0.4240 | LR: 0.000125
# Epoch: 99 | train_loss: 1.5091 | train_acc: 0.4612 | test_loss: 1.5775 | test_acc: 0.4247 | LR: 0.000125
# Epoch: 100 | train_loss: 1.5075 | train_acc: 0.4565 | test_loss: 1.5906 | test_acc: 0.4160 | LR: 0.000125
# Epoch: 101 | train_loss: 1.5087 | train_acc: 0.4531 | test_loss: 1.5896 | test_acc: 0.4207 | LR: 0.000125
# Epoch: 102 | train_loss: 1.5218 | train_acc: 0.4529 | test_loss: 1.5936 | test_acc: 0.4180 | LR: 0.000125
# Epoch: 103 | train_loss: 1.4912 | train_acc: 0.4639 | test_loss: 1.5875 | test_acc: 0.4207 | LR: 0.000125
# Epoch: 104 | train_loss: 1.5240 | train_acc: 0.4587 | test_loss: 1.5862 | test_acc: 0.4268 | LR: 0.000125
# Epoch: 105 | train_loss: 1.5139 | train_acc: 0.4599 | test_loss: 1.5938 | test_acc: 0.4187 | LR: 0.000063
# Epoch: 106 | train_loss: 1.5183 | train_acc: 0.4550 | test_loss: 1.5864 | test_acc: 0.4220 | LR: 0.000063
# Epoch: 107 | train_loss: 1.5029 | train_acc: 0.4587 | test_loss: 1.5822 | test_acc: 0.4187 | LR: 0.000063
# Epoch: 108 | train_loss: 1.5047 | train_acc: 0.4549 | test_loss: 1.5880 | test_acc: 0.4220 | LR: 0.000063
# Epoch: 109 | train_loss: 1.4878 | train_acc: 0.4637 | test_loss: 1.5875 | test_acc: 0.4200 | LR: 0.000063
# Epoch: 110 | train_loss: 1.4782 | train_acc: 0.4718 | test_loss: 1.5832 | test_acc: 0.4247 | LR: 0.000063
# Epoch: 111 | train_loss: 1.5094 | train_acc: 0.4553 | test_loss: 1.5836 | test_acc: 0.4233 | LR: 0.000031
# Epoch: 112 | train_loss: 1.4711 | train_acc: 0.4676 | test_loss: 1.5836 | test_acc: 0.4227 | LR: 0.000031
# Epoch: 113 | train_loss: 1.5014 | train_acc: 0.4499 | test_loss: 1.5822 | test_acc: 0.4240 | LR: 0.000031
# Epoch: 114 | train_loss: 1.5221 | train_acc: 0.4542 | test_loss: 1.5822 | test_acc: 0.4233 | LR: 0.000031
# Epoch: 115 | train_loss: 1.4935 | train_acc: 0.4592 | test_loss: 1.5793 | test_acc: 0.4233 | LR: 0.000031
# Epoch: 116 | train_loss: 1.5164 | train_acc: 0.4612 | test_loss: 1.5783 | test_acc: 0.4240 | LR: 0.000031
# Epoch: 117 | train_loss: 1.4867 | train_acc: 0.4612 | test_loss: 1.5799 | test_acc: 0.4233 | LR: 0.000016
# Epoch: 118 | train_loss: 1.4910 | train_acc: 0.4699 | test_loss: 1.5787 | test_acc: 0.4227 | LR: 0.000016
# Epoch: 119 | train_loss: 1.4876 | train_acc: 0.4615 | test_loss: 1.5801 | test_acc: 0.4227 | LR: 0.000016
# Epoch: 120 | train_loss: 1.5012 | train_acc: 0.4613 | test_loss: 1.5809 | test_acc: 0.4233 | LR: 0.000016
# Epoch: 121 | train_loss: 1.4844 | train_acc: 0.4693 | test_loss: 1.5797 | test_acc: 0.4247 | LR: 0.000016
# Epoch: 122 | train_loss: 1.5064 | train_acc: 0.4577 | test_loss: 1.5802 | test_acc: 0.4220 | LR: 0.000016
# Epoch: 123 | train_loss: 1.5031 | train_acc: 0.4575 | test_loss: 1.5785 | test_acc: 0.4214 | LR: 0.000008
# Epoch: 124 | train_loss: 1.4855 | train_acc: 0.4578 | test_loss: 1.5792 | test_acc: 0.4247 | LR: 0.000008
# Epoch: 125 | train_loss: 1.5174 | train_acc: 0.4503 | test_loss: 1.5793 | test_acc: 0.4247 | LR: 0.000008
# Epoch: 126 | train_loss: 1.4811 | train_acc: 0.4664 | test_loss: 1.5793 | test_acc: 0.4240 | LR: 0.000008
# Epoch: 127 | train_loss: 1.5107 | train_acc: 0.4557 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000008
# Epoch: 128 | train_loss: 1.5113 | train_acc: 0.4542 | test_loss: 1.5790 | test_acc: 0.4240 | LR: 0.000008
# Epoch: 129 | train_loss: 1.4807 | train_acc: 0.4626 | test_loss: 1.5795 | test_acc: 0.4240 | LR: 0.000004
# Epoch: 130 | train_loss: 1.4823 | train_acc: 0.4745 | test_loss: 1.5795 | test_acc: 0.4247 | LR: 0.000004
# Epoch: 131 | train_loss: 1.4868 | train_acc: 0.4626 | test_loss: 1.5794 | test_acc: 0.4247 | LR: 0.000004
# Epoch: 132 | train_loss: 1.4792 | train_acc: 0.4659 | test_loss: 1.5791 | test_acc: 0.4247 | LR: 0.000004
# Epoch: 133 | train_loss: 1.4876 | train_acc: 0.4696 | test_loss: 1.5788 | test_acc: 0.4240 | LR: 0.000004
# Epoch: 134 | train_loss: 1.4845 | train_acc: 0.4606 | test_loss: 1.5788 | test_acc: 0.4253 | LR: 0.000004
# Epoch: 135 | train_loss: 1.5068 | train_acc: 0.4581 | test_loss: 1.5790 | test_acc: 0.4247 | LR: 0.000002
# Epoch: 136 | train_loss: 1.4811 | train_acc: 0.4603 | test_loss: 1.5790 | test_acc: 0.4260 | LR: 0.000002
# Epoch: 137 | train_loss: 1.5056 | train_acc: 0.4602 | test_loss: 1.5790 | test_acc: 0.4260 | LR: 0.000002
# Epoch: 138 | train_loss: 1.5026 | train_acc: 0.4524 | test_loss: 1.5789 | test_acc: 0.4260 | LR: 0.000002
# Epoch: 139 | train_loss: 1.4839 | train_acc: 0.4717 | test_loss: 1.5788 | test_acc: 0.4253 | LR: 0.000002
# Epoch: 140 | train_loss: 1.4892 | train_acc: 0.4550 | test_loss: 1.5788 | test_acc: 0.4240 | LR: 0.000002
# Epoch: 141 | train_loss: 1.4903 | train_acc: 0.4660 | test_loss: 1.5787 | test_acc: 0.4240 | LR: 0.000001
# Epoch: 142 | train_loss: 1.4840 | train_acc: 0.4621 | test_loss: 1.5788 | test_acc: 0.4253 | LR: 0.000001
# Epoch: 143 | train_loss: 1.4930 | train_acc: 0.4689 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000001
# Epoch: 144 | train_loss: 1.4973 | train_acc: 0.4658 | test_loss: 1.5789 | test_acc: 0.4247 | LR: 0.000001
# Epoch: 145 | train_loss: 1.5099 | train_acc: 0.4601 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000001
# Epoch: 146 | train_loss: 1.5102 | train_acc: 0.4602 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000001
# Epoch: 147 | train_loss: 1.4829 | train_acc: 0.4670 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 148 | train_loss: 1.4948 | train_acc: 0.4645 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 149 | train_loss: 1.4740 | train_acc: 0.4705 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 150 | train_loss: 1.5114 | train_acc: 0.4639 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 151 | train_loss: 1.5026 | train_acc: 0.4597 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 152 | train_loss: 1.4947 | train_acc: 0.4580 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 153 | train_loss: 1.5095 | train_acc: 0.4552 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 154 | train_loss: 1.4908 | train_acc: 0.4588 | test_loss: 1.5788 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 155 | train_loss: 1.4901 | train_acc: 0.4661 | test_loss: 1.5787 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 156 | train_loss: 1.4821 | train_acc: 0.4692 | test_loss: 1.5787 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 157 | train_loss: 1.4716 | train_acc: 0.4687 | test_loss: 1.5787 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 158 | train_loss: 1.4803 | train_acc: 0.4700 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 159 | train_loss: 1.4811 | train_acc: 0.4646 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 160 | train_loss: 1.4862 | train_acc: 0.4698 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 161 | train_loss: 1.4940 | train_acc: 0.4638 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 162 | train_loss: 1.4973 | train_acc: 0.4611 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 163 | train_loss: 1.4768 | train_acc: 0.4650 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 164 | train_loss: 1.5130 | train_acc: 0.4602 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 165 | train_loss: 1.5009 | train_acc: 0.4575 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 166 | train_loss: 1.4790 | train_acc: 0.4640 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 167 | train_loss: 1.5087 | train_acc: 0.4538 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 168 | train_loss: 1.4900 | train_acc: 0.4625 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 169 | train_loss: 1.4872 | train_acc: 0.4629 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 170 | train_loss: 1.5003 | train_acc: 0.4662 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 171 | train_loss: 1.4726 | train_acc: 0.4699 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 172 | train_loss: 1.4809 | train_acc: 0.4649 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 173 | train_loss: 1.5036 | train_acc: 0.4627 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 174 | train_loss: 1.4812 | train_acc: 0.4630 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 175 | train_loss: 1.4954 | train_acc: 0.4602 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 176 | train_loss: 1.4831 | train_acc: 0.4601 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 177 | train_loss: 1.4833 | train_acc: 0.4603 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 178 | train_loss: 1.4961 | train_acc: 0.4612 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 179 | train_loss: 1.4989 | train_acc: 0.4545 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 180 | train_loss: 1.5108 | train_acc: 0.4523 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 181 | train_loss: 1.4889 | train_acc: 0.4623 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 182 | train_loss: 1.4839 | train_acc: 0.4655 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 183 | train_loss: 1.5018 | train_acc: 0.4608 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 184 | train_loss: 1.4714 | train_acc: 0.4708 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 185 | train_loss: 1.5080 | train_acc: 0.4610 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 186 | train_loss: 1.4957 | train_acc: 0.4597 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 187 | train_loss: 1.4839 | train_acc: 0.4680 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 188 | train_loss: 1.4954 | train_acc: 0.4636 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 189 | train_loss: 1.4935 | train_acc: 0.4628 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 190 | train_loss: 1.5086 | train_acc: 0.4567 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 191 | train_loss: 1.4799 | train_acc: 0.4635 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 192 | train_loss: 1.5120 | train_acc: 0.4562 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 193 | train_loss: 1.4926 | train_acc: 0.4671 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 194 | train_loss: 1.4935 | train_acc: 0.4602 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 195 | train_loss: 1.4974 | train_acc: 0.4658 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 196 | train_loss: 1.4936 | train_acc: 0.4631 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 197 | train_loss: 1.4868 | train_acc: 0.4643 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 198 | train_loss: 1.4801 | train_acc: 0.4687 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 199 | train_loss: 1.4999 | train_acc: 0.4593 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Epoch: 200 | train_loss: 1.5113 | train_acc: 0.4539 | test_loss: 1.5786 | test_acc: 0.4247 | LR: 0.000000
# Total training time: 94.592 seconds

# %%
plot_loss_curves(model_5_results)

# %% [markdown]
# After considering each loss and accuracy plot, we can see the following:
# * `model_1`: This model is perhaps the best one. We can see that overfitting was fixed and only with 30 epochs, it reaches an approximately 75% accuracy on the validation set.
# * `model_2`: The overfitting issue was not fixed.
# * `model_3`: The overfitting issue was not fixed.
# * `model_4`: The overfitting issue was not fixed. It even worsened
# * `model_5`: Overfitting was fixed. However, the model performs very poorly. After 100 epochs, accuracy plateaus at around 41%. Learning rate becomes 0 on epoch #136 after being gradually reduced, due to learning rate scheduling.

# %% [markdown]
# ## 13. Evaluating our best model on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate `model_1` which was our best performing model.

# %%
# Evaluate the CNN on the test set
evaluation = test_step(model=model_1,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.5757 | test acc = 0.8081

# %% [markdown]
# ## 14. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use `model_1` to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2499 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilites first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Checking shape of X_test. There are 2499 samples
X_test.shape
# Out:
# torch.Size([2499, 1, 13, 130])

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))

predict(model=model_1,
        X_test=X_test,
        y_test=y_test,
        index=index,
        device=device,
        classes=classes)
# Out:
# Target: country, Predicted label: country

# %% [markdown]
# ## 15. Making a confusion matrix for further evaluation
#
# For a good vizualization of our model's performance, we can use a confusion matrix. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.24.0

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_1.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_1(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

#  Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(), # matplotlib likes working with NumPy
    class_names=classes, # turn the row and column labels into class names
    figsize=(10, 7)
);

# %% [markdown]
# We can see that our model performs quite well. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. We can see that the highest mismatch values appear between country and rock, hiphop and reggae, metal and rock. This is interesting, because those genres could be difficult to be distinguished from a human as well. We do not see that much errors in distinguishing that many genres for classical. Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.
