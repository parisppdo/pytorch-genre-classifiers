# %% [markdown]
# # Music Genre Classification using multi-level perceptron (MLP) and Mel-frequency coefficients (MFCCs)

# %% [markdown]
# ### 0. Importing libraries, setting up device agnostic code
#
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# !nvidia-smi
# Out:
# Sun Sep 21 17:11:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.15                 Driver Version: 581.15         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce MX150         WDDM  |   00000000:02:00.0 Off |                  N/A |
# | N/A   62C    P8            N/A  / 5001W |       0MiB /   2048MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           17936      C   ...s\Python\Python311\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### 1. Loading data
#
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors.

# %%
# create method to load mfcc data from json file

DATASET_PATH = "data_full.json"

def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    #convert
    inputs = np.array(data['mfcc'])
    targets = np.array(data['labels'])

    return inputs, targets

# %%
# load data and see the shape. 130 time frames and 13 MFCC coefficients
inputs, targets = load_data(DATASET_PATH)
inputs.shape, targets.shape
# Out:
# ((9996, 130, 13), (9996,))

# %%
# turn data into tensors
inputs = torch.from_numpy(inputs).float() # weight calculations expect float
targets = torch.from_numpy(targets).long() # CrossEntropyLoss expects long
inputs.shape, targets.shape
# Out:
# (torch.Size([9996, 130, 13]), torch.Size([9996]))

# %% [markdown]
# ### 2. Data visualization
#
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize an mfcc representation of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, we can distinguish the 13 coefficients in the vertical axis as parallel lines of the same thickness.

# %%
# Visualise data
mfcc_example = inputs[0].numpy()
plt.imshow(mfcc_example.T, cmap='hot', aspect='auto', origin='lower') # .T is used because mfcc tensor is transposed in preprocess.py in line 70
plt.colorbar()
plt.title("MFCC Example (from tensor)")
plt.show()

# %% [markdown]
# ### 3. Create DataSets and DataLoaders
#
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders. First we use the `train_test_split` method that we imported from sklearn, in order to create train and test datasets. We divide our initial data into 70% for training and 30% for testing.
# We use a batch size of 32 for the DataLoaders.

# %%
# split the data into train and test sets
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)
print(f"Train set: {len(inputs_train)} samples, {len(targets_train)} labels")
print(f"Test set: {len(inputs_test)} samples, {len(targets_test)} labels")
# Out:
# Train set: 6997 samples, 6997 labels
# Test set: 2999 samples, 2999 labels

# %%
# create train/test datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32

train_dataset = TensorDataset(inputs_train, targets_train)
test_dataset = TensorDataset(inputs_test, targets_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x000002024480CB90>, <torch.utils.data.dataloader.DataLoader object at 0x00000202448CB610>)
# Length of train dataloader: 219 batches of 32
# Length of test dataloader: 94 batches of 32

# %% [markdown]
# ### 4. Building a basic MLP model
#
# The architecture of the model is based on a basic multi layer neural network. It consists of `nn.Linear()` layers and we use the `ReLu()` activation for each. First, we use an `nn.flatten()` layer because such architectures need to have vectors as in features. Those vectors have initially the tensor dimensions compressed. So in our case we input the `num_features` where `num_features = input_shape[0] * input_shape[1]`. Those two values will actually be the _time_frames * mfcc_coefficients_ which is actually 130 * 13 = 1690.
#
# This model will output logits. We can apply an `nn.Softmax()` function to those logits in order to get probabilities. However it is good practise to do this later. Furthermore we are going to use `nn.CrossEntropyLoss` later and this method takes logits as arguments.
#
# Futhermore, we use `summary()` from the torchinfo library to have a detailed perspective of the model.

# %%
# build the network architecture

NUM_CLASSES = 10
INPUT_SHAPE = (inputs.shape[1], inputs.shape[2])

class MLPClassifierV0(nn.Module):
    def __init__(self, input_shape, num_classes=10):
        super().__init__()

        num_features = input_shape[0] * input_shape[1]  # f

        self.flatten = nn.Flatten()
        self.layer_1 = nn.Linear(num_features, 512)
        self.layer_2 = nn.Linear(512, 256)
        self.layer_3 = nn.Linear(256, 64)
        self.output = nn.Linear(64, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.flatten(x)
        x = self.layer_1(x)
        x = self.relu(x)
        x = self.layer_2(x)
        x = self.relu(x)
        x = self.layer_3(x)
        x = self.relu(x)
        x = self.output(x)
        return x

# create a model and put it to device
modelMPL_0 = MLPClassifierV0(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES).to(device)
print(modelMPL_0)
print(next(modelMPL_0.parameters()).device)
# Out:
# MLPClassifierV0(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layer_1): Linear(in_features=1690, out_features=512, bias=True)
#   (layer_2): Linear(in_features=512, out_features=256, bias=True)
#   (layer_3): Linear(in_features=256, out_features=64, bias=True)
#   (output): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
# )
# cuda:0

# %%
# Perform a single forward pass on the data (we'll need to put it to the target device for it to work)
logits = modelMPL_0(inputs_train.to(device))
probs = torch.softmax(logits, dim=1)
print(logits[:5])
print(probs[:5])
# Out:
# tensor([[ 0.4038, -3.1534,  2.3214, -0.7207, -1.2010, -0.1652, -0.1961,  1.2575,
#           1.6471,  4.2178],
#         [-1.0353, -1.1886,  1.5786,  0.0771,  1.2181,  0.1259,  0.7406,  0.8312,
#           0.8658,  2.2622],
#         [ 0.4741, -1.5240,  1.1084, -1.1021, -0.4252,  0.1554,  1.4473,  0.5978,
#           1.1053,  2.8745],
#         [ 0.7450, -3.2905,  2.4823, -1.7129, -1.6641,  1.1326,  0.0603,  2.0454,
#           1.8890,  4.2684],
#         [-0.8549, -5.4276,  2.8166, -1.7742,  2.4390,  1.1086, -3.3871,  0.9691,
#           4.0593,  6.1286]], device='cuda:0', grad_fn=<SliceBackward0>)
# tensor([[1.6495e-02, 4.7045e-04, 1.1225e-01, 5.3580e-03, 3.3145e-03, 9.3381e-03,
#          9.0540e-03, 3.8739e-02, 5.7191e-02, 7.4779e-01],
#         [1.2924e-02, 1.1087e-02, 1.7645e-01, 3.9312e-02, 1.2304e-01, 4.1275e-02,
#          7.6327e-02, 8.3558e-02, 8.6503e-02, 3.4952e-01],
#         [4.7513e-02, 6.4422e-03, 8.9594e-02, 9.8232e-03, 1.9330e-02, 3.4546e-02,
#          1.2573e-01, 5.3768e-02, 8.9316e-02, 5.2394e-01],
#         [2.0177e-02, 3.5668e-04, 1.1464e-01, 1.7273e-03, 1.8138e-03, 2.9729e-02,
#          1.0174e-02, 7.4062e-02, 6.3341e-02, 6.8398e-01],
#         [7.7162e-04, 7.9709e-06, 3.0333e-02, 3.0772e-04, 2.0793e-02, 5.4972e-03,
#          6.1329e-05, 4.7815e-03, 1.0510e-01, 8.3235e-01]], device='cuda:0',
#        grad_fn=<SliceBackward0>)

# %%
# Have a summary of the model
from torchinfo import summary

summary(modelMPL_0, input_size=(32, inputs.shape[1], inputs.shape[2]))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPClassifierV0                          [32, 10]                  --
# ├─Flatten: 1-1                           [32, 1690]                --
# ├─Linear: 1-2                            [32, 512]                 865,792
# ├─ReLU: 1-3                              [32, 512]                 --
# ├─Linear: 1-4                            [32, 256]                 131,328
# ├─ReLU: 1-5                              [32, 256]                 --
# ├─Linear: 1-6                            [32, 64]                  16,448
# ├─ReLU: 1-7                              [32, 64]                  --
# ├─Linear: 1-8                            [32, 10]                  650
# ==========================================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 32.45
# ==========================================================================================
# Input size (MB): 0.22
# Forward/backward pass size (MB): 0.22
# Params size (MB): 4.06
# Estimated Total Size (MB): 4.49
# ==========================================================================================

# %% [markdown]
# ### 5. Training the model
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure.
# A helper function named `accuracy_fn()` is going to help us calculate the accuracy. We could use `torchmetrics.accuracy()`, but instead one can implement it.
# The training pipeling includes defining a dictionary for the results. This will help later on with the plots that will give us a view on how the model performs. The training also involves batching, so loss and accuracy is calculated for each batch and the result is accumulated.

# %%
# create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(modelMPL_0.parameters(),
                            lr=0.0001)

# %%
# Calculate accuracy (a classification metric)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
# train the model
EPOCHS = 100

# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the number of epochs
epochs = EPOCHS

# Create empty results dictionary
results_0 = {"train_loss": [],
    "train_acc": [],
    "test_loss": [],
    "test_acc": []
}

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    # print(f"Epoch: {epoch + 1}\n-------")
    ### Training
    train_loss, train_acc = 0, 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):

        X, y = X.to(device), y.to(device)
        modelMPL_0.train()

        # 1. Forward pass
        y_pred = modelMPL_0(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss # accumulatively add up the loss per epoch

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        #  Calculate accuracy (preds need to be same as y_true)
        train_acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1)) # argmax() is going to give us the index of the largest logit. Hence the label

        # # Print out how many samples have been seen
        # if batch % 100 == 0:
        #     print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    # Divide total train loss by length of train dataloader (average loss per batch per epoch)
    train_loss /= len(train_dataloader)

    # Divide total train accuracy by length of train dataloader (per batch)
    train_acc /= len(train_dataloader)

    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy
    test_loss, test_acc = 0, 0
    modelMPL_0.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:

            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred = modelMPL_0(X)

            # 2. Calculate loss (accumulatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculations on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by length of test dataloader (per batch)
        test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"Epoch: {epoch + 1} | Train loss: {train_loss:.5f}, Train acc: {train_acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")
    # 5. Update results dictionary
    results_0["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
    results_0["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
    results_0["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
    results_0["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | Train loss: 2.00586, Train acc: 28.83% | Test loss: 1.76593, Test acc: 36.31%
# Epoch: 2 | Train loss: 1.71434, Train acc: 38.36% | Test loss: 1.65604, Test acc: 40.01%
# Epoch: 3 | Train loss: 1.61444, Train acc: 41.51% | Test loss: 1.59188, Test acc: 41.82%
# Epoch: 4 | Train loss: 1.54217, Train acc: 43.80% | Test loss: 1.54017, Test acc: 44.16%
# Epoch: 5 | Train loss: 1.48926, Train acc: 46.12% | Test loss: 1.51203, Test acc: 45.82%
# Epoch: 6 | Train loss: 1.44464, Train acc: 47.28% | Test loss: 1.48377, Test acc: 45.57%
# Epoch: 7 | Train loss: 1.40983, Train acc: 48.67% | Test loss: 1.45419, Test acc: 47.64%
# Epoch: 8 | Train loss: 1.37843, Train acc: 49.99% | Test loss: 1.43106, Test acc: 48.03%
# Epoch: 9 | Train loss: 1.34867, Train acc: 51.07% | Test loss: 1.42281, Test acc: 47.74%
# Epoch: 10 | Train loss: 1.32423, Train acc: 52.22% | Test loss: 1.41329, Test acc: 48.27%
# Epoch: 11 | Train loss: 1.30067, Train acc: 52.77% | Test loss: 1.38929, Test acc: 49.85%
# Epoch: 12 | Train loss: 1.27727, Train acc: 53.88% | Test loss: 1.37436, Test acc: 50.16%
# Epoch: 13 | Train loss: 1.25583, Train acc: 54.77% | Test loss: 1.35605, Test acc: 50.85%
# Epoch: 14 | Train loss: 1.23665, Train acc: 55.86% | Test loss: 1.35736, Test acc: 50.24%
# Epoch: 15 | Train loss: 1.21755, Train acc: 57.08% | Test loss: 1.33522, Test acc: 51.49%
# Epoch: 16 | Train loss: 1.19941, Train acc: 57.38% | Test loss: 1.32802, Test acc: 51.84%
# Epoch: 17 | Train loss: 1.18347, Train acc: 57.92% | Test loss: 1.32201, Test acc: 51.95%
# Epoch: 18 | Train loss: 1.16816, Train acc: 58.77% | Test loss: 1.30806, Test acc: 52.56%
# Epoch: 19 | Train loss: 1.15092, Train acc: 59.57% | Test loss: 1.30175, Test acc: 53.31%
# Epoch: 20 | Train loss: 1.13638, Train acc: 60.44% | Test loss: 1.29267, Test acc: 53.47%
# Epoch: 21 | Train loss: 1.12093, Train acc: 60.80% | Test loss: 1.28657, Test acc: 53.13%
# Epoch: 22 | Train loss: 1.10762, Train acc: 61.43% | Test loss: 1.27569, Test acc: 53.51%
# Epoch: 23 | Train loss: 1.09472, Train acc: 62.33% | Test loss: 1.26912, Test acc: 53.96%
# Epoch: 24 | Train loss: 1.08146, Train acc: 62.72% | Test loss: 1.26670, Test acc: 53.93%
# Epoch: 25 | Train loss: 1.06933, Train acc: 63.25% | Test loss: 1.25873, Test acc: 53.88%
# Epoch: 26 | Train loss: 1.05582, Train acc: 63.56% | Test loss: 1.25614, Test acc: 54.44%
# Epoch: 27 | Train loss: 1.04486, Train acc: 63.96% | Test loss: 1.25633, Test acc: 54.47%
# Epoch: 28 | Train loss: 1.03118, Train acc: 64.59% | Test loss: 1.25472, Test acc: 54.68%
# Epoch: 29 | Train loss: 1.02101, Train acc: 65.14% | Test loss: 1.24154, Test acc: 54.66%
# Epoch: 30 | Train loss: 1.00877, Train acc: 65.75% | Test loss: 1.22677, Test acc: 55.82%
# Epoch: 31 | Train loss: 0.99845, Train acc: 66.59% | Test loss: 1.22798, Test acc: 55.46%
# Epoch: 32 | Train loss: 0.98499, Train acc: 66.97% | Test loss: 1.22920, Test acc: 55.48%
# Epoch: 33 | Train loss: 0.97743, Train acc: 67.48% | Test loss: 1.22616, Test acc: 55.24%
# Epoch: 34 | Train loss: 0.96612, Train acc: 67.29% | Test loss: 1.21603, Test acc: 56.07%
# Epoch: 35 | Train loss: 0.95600, Train acc: 68.44% | Test loss: 1.22044, Test acc: 55.95%
# Epoch: 36 | Train loss: 0.94571, Train acc: 68.95% | Test loss: 1.20527, Test acc: 56.19%
# Epoch: 37 | Train loss: 0.93677, Train acc: 69.20% | Test loss: 1.20375, Test acc: 56.56%
# Epoch: 38 | Train loss: 0.92723, Train acc: 69.80% | Test loss: 1.21733, Test acc: 55.57%
# Epoch: 39 | Train loss: 0.91818, Train acc: 69.68% | Test loss: 1.20338, Test acc: 56.59%
# Epoch: 40 | Train loss: 0.90646, Train acc: 70.30% | Test loss: 1.20373, Test acc: 56.19%
# Epoch: 41 | Train loss: 0.89912, Train acc: 70.64% | Test loss: 1.19012, Test acc: 56.98%
# Epoch: 42 | Train loss: 0.89016, Train acc: 70.94% | Test loss: 1.19446, Test acc: 56.32%
# Epoch: 43 | Train loss: 0.88156, Train acc: 71.12% | Test loss: 1.18837, Test acc: 56.90%
# Epoch: 44 | Train loss: 0.87398, Train acc: 71.25% | Test loss: 1.19206, Test acc: 56.59%
# Epoch: 45 | Train loss: 0.86408, Train acc: 71.69% | Test loss: 1.18201, Test acc: 57.34%
# Epoch: 46 | Train loss: 0.85634, Train acc: 72.19% | Test loss: 1.18277, Test acc: 57.44%
# Epoch: 47 | Train loss: 0.84849, Train acc: 72.65% | Test loss: 1.18238, Test acc: 57.00%
# Epoch: 48 | Train loss: 0.83926, Train acc: 72.89% | Test loss: 1.18714, Test acc: 57.35%
# Epoch: 49 | Train loss: 0.83158, Train acc: 73.34% | Test loss: 1.17916, Test acc: 57.32%
# Epoch: 50 | Train loss: 0.82232, Train acc: 73.46% | Test loss: 1.17593, Test acc: 57.10%
# Epoch: 51 | Train loss: 0.81455, Train acc: 73.98% | Test loss: 1.17117, Test acc: 58.05%
# Epoch: 52 | Train loss: 0.80755, Train acc: 74.14% | Test loss: 1.16874, Test acc: 57.68%
# Epoch: 53 | Train loss: 0.79859, Train acc: 74.52% | Test loss: 1.16719, Test acc: 57.66%
# Epoch: 54 | Train loss: 0.78966, Train acc: 75.16% | Test loss: 1.18611, Test acc: 57.35%
# Epoch: 55 | Train loss: 0.78351, Train acc: 74.98% | Test loss: 1.16160, Test acc: 58.31%
# Epoch: 56 | Train loss: 0.77636, Train acc: 75.29% | Test loss: 1.15785, Test acc: 58.62%
# Epoch: 57 | Train loss: 0.76798, Train acc: 75.51% | Test loss: 1.15348, Test acc: 58.50%
# Epoch: 58 | Train loss: 0.76101, Train acc: 76.00% | Test loss: 1.15578, Test acc: 58.05%
# Epoch: 59 | Train loss: 0.75295, Train acc: 76.32% | Test loss: 1.16477, Test acc: 58.06%
# Epoch: 60 | Train loss: 0.74741, Train acc: 76.56% | Test loss: 1.15747, Test acc: 58.63%
# Epoch: 61 | Train loss: 0.74065, Train acc: 77.11% | Test loss: 1.14873, Test acc: 58.53%
# Epoch: 62 | Train loss: 0.73254, Train acc: 77.19% | Test loss: 1.14787, Test acc: 58.37%
# Epoch: 63 | Train loss: 0.72536, Train acc: 77.46% | Test loss: 1.16610, Test acc: 57.56%
# Epoch: 64 | Train loss: 0.71896, Train acc: 77.62% | Test loss: 1.16422, Test acc: 57.50%
# Epoch: 65 | Train loss: 0.71294, Train acc: 78.05% | Test loss: 1.16346, Test acc: 58.77%
# Epoch: 66 | Train loss: 0.70474, Train acc: 78.52% | Test loss: 1.14439, Test acc: 58.91%
# Epoch: 67 | Train loss: 0.69829, Train acc: 78.26% | Test loss: 1.15221, Test acc: 58.68%
# Epoch: 68 | Train loss: 0.69218, Train acc: 78.79% | Test loss: 1.14791, Test acc: 58.37%
# Epoch: 69 | Train loss: 0.68669, Train acc: 79.19% | Test loss: 1.15415, Test acc: 57.94%
# Epoch: 70 | Train loss: 0.67958, Train acc: 79.23% | Test loss: 1.14989, Test acc: 58.58%
# Epoch: 71 | Train loss: 0.67275, Train acc: 79.61% | Test loss: 1.14427, Test acc: 58.78%
# Epoch: 72 | Train loss: 0.66503, Train acc: 79.76% | Test loss: 1.13947, Test acc: 59.15%
# Epoch: 73 | Train loss: 0.65780, Train acc: 79.80% | Test loss: 1.14223, Test acc: 58.60%
# Epoch: 74 | Train loss: 0.65404, Train acc: 80.12% | Test loss: 1.14549, Test acc: 58.98%
# Epoch: 75 | Train loss: 0.64614, Train acc: 80.74% | Test loss: 1.13489, Test acc: 59.01%
# Epoch: 76 | Train loss: 0.64127, Train acc: 80.84% | Test loss: 1.15482, Test acc: 58.04%
# Epoch: 77 | Train loss: 0.63440, Train acc: 80.96% | Test loss: 1.15036, Test acc: 58.84%
# Epoch: 78 | Train loss: 0.62916, Train acc: 81.05% | Test loss: 1.13620, Test acc: 58.93%
# Epoch: 79 | Train loss: 0.62326, Train acc: 81.50% | Test loss: 1.13914, Test acc: 59.43%
# Epoch: 80 | Train loss: 0.61596, Train acc: 81.66% | Test loss: 1.13631, Test acc: 59.53%
# Epoch: 81 | Train loss: 0.61126, Train acc: 81.94% | Test loss: 1.14664, Test acc: 59.24%
# Epoch: 82 | Train loss: 0.60563, Train acc: 81.91% | Test loss: 1.13531, Test acc: 59.29%
# Epoch: 83 | Train loss: 0.59859, Train acc: 82.69% | Test loss: 1.13246, Test acc: 59.62%
# Epoch: 84 | Train loss: 0.59440, Train acc: 82.82% | Test loss: 1.13200, Test acc: 59.54%
# Epoch: 85 | Train loss: 0.58819, Train acc: 82.76% | Test loss: 1.14500, Test acc: 59.90%
# Epoch: 86 | Train loss: 0.58094, Train acc: 82.96% | Test loss: 1.13863, Test acc: 59.19%
# Epoch: 87 | Train loss: 0.57600, Train acc: 83.32% | Test loss: 1.12792, Test acc: 59.90%
# Epoch: 88 | Train loss: 0.57020, Train acc: 83.70% | Test loss: 1.15374, Test acc: 59.27%
# Epoch: 89 | Train loss: 0.56447, Train acc: 83.85% | Test loss: 1.14421, Test acc: 59.35%
# Epoch: 90 | Train loss: 0.55856, Train acc: 84.12% | Test loss: 1.14180, Test acc: 59.58%
# Epoch: 91 | Train loss: 0.55387, Train acc: 84.33% | Test loss: 1.12861, Test acc: 60.08%
# Epoch: 92 | Train loss: 0.54857, Train acc: 84.43% | Test loss: 1.13386, Test acc: 60.11%
# Epoch: 93 | Train loss: 0.54368, Train acc: 84.67% | Test loss: 1.13831, Test acc: 59.71%
# Epoch: 94 | Train loss: 0.53903, Train acc: 84.77% | Test loss: 1.14217, Test acc: 60.14%
# Epoch: 95 | Train loss: 0.53280, Train acc: 84.66% | Test loss: 1.13138, Test acc: 60.65%
# Epoch: 96 | Train loss: 0.52575, Train acc: 85.57% | Test loss: 1.14594, Test acc: 59.31%
# Epoch: 97 | Train loss: 0.52177, Train acc: 85.66% | Test loss: 1.13393, Test acc: 60.29%
# Epoch: 98 | Train loss: 0.51715, Train acc: 85.84% | Test loss: 1.12741, Test acc: 60.12%
# Epoch: 99 | Train loss: 0.51099, Train acc: 85.65% | Test loss: 1.13613, Test acc: 60.49%
# Epoch: 100 | Train loss: 0.50606, Train acc: 86.09% | Test loss: 1.13684, Test acc: 60.73%

# %% [markdown]
# ### 6. Plotting the results
#
# We define a helper method to plot the results. We then use matplotlib to plot how our model performed.

# %%
_# method to plot loss and accuracy
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]]):

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, test_loss, label='test_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, test_accuracy, label='test_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(results_0)

# %% [markdown]
# Judging by the plot results. We see that our model is overfitting. Somewhere after the 8 epochs, the model starts going well on the train test, but not so well on the test set. As a result we will try to make a new model to avoid this.

# %% [markdown]
# ### 7. Implementing methods to avoid overfitting
#
# As we saw on the plots, our first model is overfitting. There are several methods to avoid that. We are going to create a second version of our model. It is going to be the same as the first with 2 differences. We are going to apply dropout and regularization. In order to do that, a `nn.Dropout()` layer is added in the model. We are also going to add an L2 regularization. This is added in the optimizer with the form of the `weight_decay` argument.
#
# After instatiating the new model, we follow the same training and plotting pipelines.

# %%
# build the network architecture

NUM_CLASSES = 10
INPUT_SHAPE = (inputs.shape[1], inputs.shape[2])

class MLPClassifierV1(nn.Module):
    def __init__(self, input_shape, num_classes=10):
        super().__init__()

        num_features = input_shape[0] * input_shape[1]  # f

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(num_features, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 64)
        self.output = nn.Linear(64, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)  # 30% dropout


    def forward(self, x):
        x = self.flatten(x)

        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc3(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.output(x)
        return x

# create a model and put it to device
modelMPL_1 = MLPClassifierV1(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES).to(device)
print(modelMPL_1)
# Out:
# MLPClassifierV1(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=1690, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=64, bias=True)
#   (output): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
# create loss and optimizer with L2 Regularization
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(modelMPL_1.parameters(),
                            lr=0.0001,
                            weight_decay=0.001) # added regularization

# %%
# train the model

EPOCHS = 100

# Set the number of epochs
epochs = EPOCHS

# Create empty results dictionary
results_1 = {"train_loss": [],
    "train_acc": [],
    "test_loss": [],
    "test_acc": []
}

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    # print(f"Epoch: {epoch + 1}\n-------")
    ### Training
    train_loss, train_acc = 0, 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):

        X, y = X.to(device), y.to(device)

        modelMPL_1.train()
        # 1. Forward pass
        y_pred = modelMPL_1(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss # accumulatively add up the loss per epoch

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        #  Calculate accuracy (preds need to be same as y_true)
        train_acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1))

        # # Print out how many samples have been seen
        # if batch % 100 == 0:
        #     print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    # Divide total train loss by length of train dataloader (average loss per batch per epoch)
    train_loss /= len(train_dataloader)

    # Divide total train accuracy by length of train dataloader (per batch)
    train_acc /= len(train_dataloader)

    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy
    test_loss, test_acc = 0, 0
    modelMPL_1.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:

            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred = modelMPL_1(X)

            # 2. Calculate loss (accumulatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculations on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by length of test dataloader (per batch)
        test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"Epoch: {epoch + 1} | Train loss: {train_loss:.5f}, Train acc: {train_acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")

    # 5. Update results dictionary
    results_1["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
    results_1["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
    results_1["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
    results_1["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | Train loss: 3.01910, Train acc: 15.81% | Test loss: 1.99172, Test acc: 31.37%
# Epoch: 2 | Train loss: 2.36201, Train acc: 21.16% | Test loss: 1.91222, Test acc: 32.76%
# Epoch: 3 | Train loss: 2.19520, Train acc: 24.00% | Test loss: 1.87022, Test acc: 34.58%
# Epoch: 4 | Train loss: 2.12079, Train acc: 25.74% | Test loss: 1.83817, Test acc: 35.48%
# Epoch: 5 | Train loss: 2.05209, Train acc: 27.70% | Test loss: 1.80913, Test acc: 36.56%
# Epoch: 6 | Train loss: 2.01363, Train acc: 28.59% | Test loss: 1.78204, Test acc: 37.82%
# Epoch: 7 | Train loss: 1.97682, Train acc: 29.43% | Test loss: 1.75550, Test acc: 37.96%
# Epoch: 8 | Train loss: 1.95152, Train acc: 30.04% | Test loss: 1.73713, Test acc: 38.94%
# Epoch: 9 | Train loss: 1.92136, Train acc: 30.85% | Test loss: 1.71362, Test acc: 39.17%
# Epoch: 10 | Train loss: 1.89538, Train acc: 31.79% | Test loss: 1.69640, Test acc: 39.77%
# Epoch: 11 | Train loss: 1.88295, Train acc: 32.37% | Test loss: 1.67995, Test acc: 40.70%
# Epoch: 12 | Train loss: 1.87155, Train acc: 32.71% | Test loss: 1.66288, Test acc: 41.30%
# Epoch: 13 | Train loss: 1.83453, Train acc: 34.09% | Test loss: 1.64917, Test acc: 41.67%
# Epoch: 14 | Train loss: 1.82655, Train acc: 33.34% | Test loss: 1.64094, Test acc: 41.57%
# Epoch: 15 | Train loss: 1.81320, Train acc: 34.51% | Test loss: 1.63286, Test acc: 42.30%
# Epoch: 16 | Train loss: 1.80349, Train acc: 35.33% | Test loss: 1.61641, Test acc: 42.33%
# Epoch: 17 | Train loss: 1.80377, Train acc: 34.68% | Test loss: 1.61112, Test acc: 42.40%
# Epoch: 18 | Train loss: 1.78105, Train acc: 35.35% | Test loss: 1.60320, Test acc: 42.33%
# Epoch: 19 | Train loss: 1.76142, Train acc: 36.10% | Test loss: 1.59518, Test acc: 42.53%
# Epoch: 20 | Train loss: 1.76588, Train acc: 35.45% | Test loss: 1.58469, Test acc: 42.73%
# Epoch: 21 | Train loss: 1.75237, Train acc: 35.79% | Test loss: 1.57988, Test acc: 43.26%
# Epoch: 22 | Train loss: 1.73152, Train acc: 37.06% | Test loss: 1.56884, Test acc: 43.74%
# Epoch: 23 | Train loss: 1.73266, Train acc: 37.40% | Test loss: 1.56119, Test acc: 44.49%
# Epoch: 24 | Train loss: 1.71193, Train acc: 37.37% | Test loss: 1.55426, Test acc: 43.67%
# Epoch: 25 | Train loss: 1.70286, Train acc: 37.84% | Test loss: 1.54249, Test acc: 44.62%
# Epoch: 26 | Train loss: 1.70376, Train acc: 37.70% | Test loss: 1.53858, Test acc: 44.74%
# Epoch: 27 | Train loss: 1.69240, Train acc: 37.79% | Test loss: 1.53611, Test acc: 44.58%
# Epoch: 28 | Train loss: 1.68584, Train acc: 38.55% | Test loss: 1.52437, Test acc: 44.78%
# Epoch: 29 | Train loss: 1.68091, Train acc: 38.90% | Test loss: 1.52154, Test acc: 44.84%
# Epoch: 30 | Train loss: 1.68075, Train acc: 39.34% | Test loss: 1.51651, Test acc: 45.39%
# Epoch: 31 | Train loss: 1.67071, Train acc: 39.17% | Test loss: 1.51281, Test acc: 45.48%
# Epoch: 32 | Train loss: 1.64257, Train acc: 40.11% | Test loss: 1.50429, Test acc: 45.26%
# Epoch: 33 | Train loss: 1.65845, Train acc: 39.24% | Test loss: 1.50054, Test acc: 44.94%
# Epoch: 34 | Train loss: 1.65607, Train acc: 40.03% | Test loss: 1.49998, Test acc: 45.38%
# Epoch: 35 | Train loss: 1.61641, Train acc: 40.83% | Test loss: 1.49158, Test acc: 46.02%
# Epoch: 36 | Train loss: 1.61838, Train acc: 41.27% | Test loss: 1.48483, Test acc: 45.97%
# Epoch: 37 | Train loss: 1.63625, Train acc: 40.06% | Test loss: 1.47935, Test acc: 46.23%
# Epoch: 38 | Train loss: 1.62889, Train acc: 39.47% | Test loss: 1.47491, Test acc: 46.39%
# Epoch: 39 | Train loss: 1.62045, Train acc: 40.97% | Test loss: 1.47305, Test acc: 46.77%
# Epoch: 40 | Train loss: 1.61932, Train acc: 40.93% | Test loss: 1.47065, Test acc: 46.53%
# Epoch: 41 | Train loss: 1.60071, Train acc: 41.63% | Test loss: 1.46364, Test acc: 47.30%
# Epoch: 42 | Train loss: 1.60480, Train acc: 41.65% | Test loss: 1.46467, Test acc: 47.06%
# Epoch: 43 | Train loss: 1.59525, Train acc: 42.06% | Test loss: 1.45433, Test acc: 47.60%
# Epoch: 44 | Train loss: 1.58851, Train acc: 41.11% | Test loss: 1.44935, Test acc: 47.68%
# Epoch: 45 | Train loss: 1.57830, Train acc: 42.06% | Test loss: 1.44872, Test acc: 48.15%
# Epoch: 46 | Train loss: 1.57833, Train acc: 42.09% | Test loss: 1.44411, Test acc: 48.17%
# Epoch: 47 | Train loss: 1.59466, Train acc: 41.90% | Test loss: 1.44189, Test acc: 48.02%
# Epoch: 48 | Train loss: 1.56935, Train acc: 42.55% | Test loss: 1.43985, Test acc: 47.82%
# Epoch: 49 | Train loss: 1.56535, Train acc: 42.46% | Test loss: 1.43362, Test acc: 48.12%
# Epoch: 50 | Train loss: 1.56504, Train acc: 43.62% | Test loss: 1.43014, Test acc: 48.07%
# Epoch: 51 | Train loss: 1.56128, Train acc: 42.44% | Test loss: 1.42648, Test acc: 48.58%
# Epoch: 52 | Train loss: 1.54998, Train acc: 43.85% | Test loss: 1.42339, Test acc: 49.05%
# Epoch: 53 | Train loss: 1.55664, Train acc: 43.70% | Test loss: 1.42094, Test acc: 49.52%
# Epoch: 54 | Train loss: 1.53726, Train acc: 43.65% | Test loss: 1.41690, Test acc: 48.98%
# Epoch: 55 | Train loss: 1.54913, Train acc: 43.26% | Test loss: 1.41253, Test acc: 49.29%
# Epoch: 56 | Train loss: 1.53730, Train acc: 44.14% | Test loss: 1.41100, Test acc: 49.36%
# Epoch: 57 | Train loss: 1.53111, Train acc: 44.87% | Test loss: 1.40773, Test acc: 49.11%
# Epoch: 58 | Train loss: 1.54205, Train acc: 44.42% | Test loss: 1.40703, Test acc: 49.44%
# Epoch: 59 | Train loss: 1.51046, Train acc: 44.96% | Test loss: 1.40255, Test acc: 49.25%
# Epoch: 60 | Train loss: 1.51583, Train acc: 44.30% | Test loss: 1.39872, Test acc: 49.09%
# Epoch: 61 | Train loss: 1.52877, Train acc: 44.87% | Test loss: 1.40098, Test acc: 49.15%
# Epoch: 62 | Train loss: 1.51026, Train acc: 44.92% | Test loss: 1.39601, Test acc: 50.26%
# Epoch: 63 | Train loss: 1.51327, Train acc: 44.85% | Test loss: 1.39097, Test acc: 50.18%
# Epoch: 64 | Train loss: 1.51025, Train acc: 45.05% | Test loss: 1.38765, Test acc: 50.62%
# Epoch: 65 | Train loss: 1.50840, Train acc: 44.42% | Test loss: 1.38707, Test acc: 50.39%
# Epoch: 66 | Train loss: 1.49211, Train acc: 45.74% | Test loss: 1.38191, Test acc: 50.36%
# Epoch: 67 | Train loss: 1.48164, Train acc: 45.63% | Test loss: 1.37885, Test acc: 50.21%
# Epoch: 68 | Train loss: 1.49277, Train acc: 45.62% | Test loss: 1.37877, Test acc: 50.18%
# Epoch: 69 | Train loss: 1.49625, Train acc: 45.85% | Test loss: 1.37673, Test acc: 50.41%
# Epoch: 70 | Train loss: 1.47164, Train acc: 46.36% | Test loss: 1.37276, Test acc: 50.74%
# Epoch: 71 | Train loss: 1.48708, Train acc: 45.73% | Test loss: 1.37100, Test acc: 51.21%
# Epoch: 72 | Train loss: 1.46377, Train acc: 46.61% | Test loss: 1.37054, Test acc: 51.21%
# Epoch: 73 | Train loss: 1.46430, Train acc: 47.20% | Test loss: 1.36422, Test acc: 51.21%
# Epoch: 74 | Train loss: 1.45213, Train acc: 47.98% | Test loss: 1.35921, Test acc: 51.74%
# Epoch: 75 | Train loss: 1.46968, Train acc: 45.80% | Test loss: 1.36141, Test acc: 51.27%
# Epoch: 76 | Train loss: 1.46532, Train acc: 46.34% | Test loss: 1.35963, Test acc: 51.31%
# Epoch: 77 | Train loss: 1.45501, Train acc: 46.94% | Test loss: 1.35712, Test acc: 51.21%
# Epoch: 78 | Train loss: 1.44541, Train acc: 47.09% | Test loss: 1.35349, Test acc: 51.84%
# Epoch: 79 | Train loss: 1.45708, Train acc: 46.99% | Test loss: 1.35021, Test acc: 51.57%
# Epoch: 80 | Train loss: 1.45456, Train acc: 47.64% | Test loss: 1.35005, Test acc: 51.64%
# Epoch: 81 | Train loss: 1.44752, Train acc: 48.18% | Test loss: 1.34823, Test acc: 51.74%
# Epoch: 82 | Train loss: 1.43766, Train acc: 46.80% | Test loss: 1.34527, Test acc: 51.74%
# Epoch: 83 | Train loss: 1.43987, Train acc: 48.08% | Test loss: 1.34252, Test acc: 52.17%
# Epoch: 84 | Train loss: 1.43105, Train acc: 48.50% | Test loss: 1.33650, Test acc: 52.30%
# Epoch: 85 | Train loss: 1.43410, Train acc: 48.27% | Test loss: 1.33625, Test acc: 52.24%
# Epoch: 86 | Train loss: 1.42640, Train acc: 48.23% | Test loss: 1.33563, Test acc: 52.47%
# Epoch: 87 | Train loss: 1.42396, Train acc: 48.67% | Test loss: 1.33051, Test acc: 52.44%
# Epoch: 88 | Train loss: 1.42546, Train acc: 47.51% | Test loss: 1.33443, Test acc: 52.04%
# Epoch: 89 | Train loss: 1.42033, Train acc: 48.25% | Test loss: 1.33071, Test acc: 52.27%
# Epoch: 90 | Train loss: 1.41986, Train acc: 48.80% | Test loss: 1.33065, Test acc: 51.87%
# Epoch: 91 | Train loss: 1.41886, Train acc: 48.61% | Test loss: 1.32612, Test acc: 52.30%
# Epoch: 92 | Train loss: 1.42016, Train acc: 47.49% | Test loss: 1.32404, Test acc: 52.47%
# Epoch: 93 | Train loss: 1.40160, Train acc: 48.34% | Test loss: 1.32342, Test acc: 52.17%
# Epoch: 94 | Train loss: 1.41455, Train acc: 49.18% | Test loss: 1.32419, Test acc: 52.14%
# Epoch: 95 | Train loss: 1.40130, Train acc: 49.85% | Test loss: 1.32123, Test acc: 52.57%
# Epoch: 96 | Train loss: 1.40449, Train acc: 49.13% | Test loss: 1.31731, Test acc: 52.74%
# Epoch: 97 | Train loss: 1.40023, Train acc: 49.53% | Test loss: 1.31469, Test acc: 52.47%
# Epoch: 98 | Train loss: 1.39830, Train acc: 50.07% | Test loss: 1.31534, Test acc: 52.30%
# Epoch: 99 | Train loss: 1.38664, Train acc: 49.63% | Test loss: 1.31113, Test acc: 52.70%
# Epoch: 100 | Train loss: 1.38611, Train acc: 49.38% | Test loss: 1.31425, Test acc: 52.20%

# %%
plot_loss_curves(results_1)

# %% [markdown]
# It is obvious that the overfitting issue is fixed. However, the model doesn't perform that well. This may be due to a variety of reasons. One is the fact that we used a simple MLP. Other model architectures are tested to perform better on such classification issues.
