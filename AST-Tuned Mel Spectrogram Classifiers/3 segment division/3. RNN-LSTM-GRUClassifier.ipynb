# %% [markdown]
# # Music Genre Classification using Recurrent Neural Network (RNN), Long short-term memory (LSTM), Gated recurrent unit (GRU) models and AST-style Mel Spectrograms (10 second samples)

# %% [markdown]
# In this notebook, we evaluate recursive architecture models using Mel spectrograms generated following the Audio Spectrogram Transformer (AST) input representation. Mel Spectrograms exported using the AST hyperparameters, include better resolution in the time domain than the frequency domain. The models that we are going to use are based on RNN, LSTM and GRU architectures.
#
# Furthermore, in the following experiments, our data will be exported using a 3 segmentation division. That means that each audio sample will be 10 seconds long. However, we will have a lesser amount of data.

# %% [markdown]
# ## 0. Importing libraries, setting up device agnostic code
#
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used. Furthermore, we set a random seed so that a fixed seed will maintain consistency in experimental results. This will also make it easier to compare different approaches.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torchaudio
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.7.0+cu118
# 2.7.0+cu118

# %%
# Set random seeds
RANDOM_SEED = 42

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
# !nvidia-smi
# Out:
# Wed Feb 11 12:31:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8            N/A  /  115W |    1105MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1764    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            3028    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A            4452    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A            9308    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10332    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           10356    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10760    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           11156    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           12568    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13248    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           15656    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           16684    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           16880    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           18032    C+G   ....3.2.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           18832    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20132    C+G   ...AppData\Local\Viber\Viber.exe      N/A      |
# |    0   N/A  N/A           21240    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           22184    C+G   ...\v4.3.12\ProtonVPN.Client.exe      N/A      |
# |    0   N/A  N/A           24320    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           24556    C+G   ...yb3d8bbwe\Notepad\Notepad.exe      N/A      |
# |    0   N/A  N/A           24728    C+G   ...Desktop\WDADesktopService.exe      N/A      |
# |    0   N/A  N/A           25532    C+G   ...\Proton\Drive\ProtonDrive.exe      N/A      |
# |    0   N/A  N/A           27424    C+G   ...6)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A           27740    C+G   ...der\Utility\SpyderUtility.exe      N/A      |
# |    0   N/A  N/A           27784    C+G   ...rsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A           33504    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Loading data
#
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors. We are also going to create a *classes* list in order to use the name of the classes for predictions later.
#
# The RNN models expect the following shape as input: `(batch_size, seq_len, input_size)`. Those values are:
# * `seq_len`: This is the quantity of time steps that we have. In our case it is the `time_frames`.
# * `input_size`: This is the size of the "vector" that describes each step. In our case, it is the `mel_bands` which is 128. As we defined 128 mel bands for the audio samples.
#
# As a result, our shape should be:  `(batch_size, time_frames, mel_bands)`. The shape we get from the `.json` file is already set to produce the following shape: `(time_frames, mel_bands)`. So, our size will be `(num_samples, time_frames, mel_bands)`. When the DataLoaders will be set, we will have `batch_size` instead of `num_samples` (the number of samples).

# %%
# Create function to load melspec data from .json file
def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['melspec'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from json file
def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
DATASET_PATH = "data_full.json"

classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((3000, 997, 128), (3000,))

# %%
# Turn data into tensors, also unsqueeze , to be ready for RNN
X = torch.from_numpy(inputs).float() # weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
X.shape, y.shape
# Out:
# (torch.Size([3000, 997, 128]), torch.Size([3000]))

# %% [markdown]
# ## 2. Create DataSets and DataLoaders
#
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders.
# After loading the data, we split them into three sets: train_set, validation_set and test_set. The validation_set will be used during the training for evaluation. The test_set will be used after the model is ready. In order for it to be exposed in never seen data.
#
# After dividing the sets, we create the respective datasets and dataloaders.

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x00000116E4F5C050>, <torch.utils.data.dataloader.DataLoader object at 0x00000116E4E67890>)
# Length of train dataloader: 57 batches of 32
# Length of validation dataloader: 15 batches of 32
# Length of test dataloader: 24 batches of 32

# %%
# Checking the dataset shapes using test_dataset
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, time_frames, mel_bands)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample")
print(test_features_batch[0].shape, "-> (time_frames, mel_bands)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 997, 128]) -> (batch_size, time_frames, mel_bands)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample
# torch.Size([997, 128]) -> (time_frames, mel_bands)
# tensor(6) -> (label)

# %% [markdown]
# ## 3. Data visualization
#
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize a Mel Spectrogram of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, the y-axis has the mel banks. Usually this axis shows the frequency in order to be more user-friendly. This is done by transposing the main frequency of each of the bank from mels to Hz. However, we are not going to do that, as we are interested in the visual shape of the spectrogram. But this means that one can view the y-axis as a frequency axis and indeed we see the frequencies that appear in each sample. The samples are 10 sec long.
#
# A second visualization is implemented later, in order to view various representations of different genres.
#
# The music genre of each representation can also be viewed.

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
INDEX = np.random.randint(len(X))
melspec_example = X[INDEX].numpy().T # we transpose the tensor because it originally has the shape of (time_frames, mel_bands)

plt.imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
plt.colorbar()
plt.title("Mel Spectrogram Example (from tensor)")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("Mel Spectogram Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    melspec_example = X[idx].numpy().T
    im = axs[row, col].imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("Mel Frequency Bin")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ## 4. Building a basic RNN model
#
# The architecture of our model will be based on a simple RNN model. In order to build our model, PyTorch provides us with the `torch.nn.RNN()` class. Using that class we can set our network to have two stacked recurrent layers. The second RNN will take the outputs of the first RNN and compute the final results.
# After the RNN layer it is common to use a fully connected layer in order to map the hidden state features of the RNN layer, to our number of classes.

# %% [markdown]
# Defining the `forward()` method has the following steps:
# 1. First we need to set an initial hidden state. The RNN cell has two inputs. The actual data input, as well as the hidden state, which is the output of the previous step. For our first recursion, we do not have a previous step, se we define `h0` in our code as a tensor full of zeros, of the appropriate shape, as set by PyTorch.
# 2. At first we pass our data through the `RNN()` layer. This will produce two outputs:
#     * A tensor with all the outputs of each step.
#     * A tensor with the final hidden state of each of the stacked RNN layers.
#     We keep the first tensor and ignore the second output.
# 3. At this point we have two options. We can either "feed" the fully connected layer with one of the next two:
#     1. Only the outputs of the last hidden state. This state "takes in consideration" all the previous hidden states.
#     2. The outputs of all the hidden state. This will be a much larger tensor. In this manner, we have much more data in the last layer to work with.

# %% [markdown]
# For our RNN implementation, we are going to try two models:

# %% [markdown]
# 1. `model_0`: In this model we are only going to use the last hidden state of the RNN layers. In order to do that, we will use slicing. The output that we get from the `RNN()` layer, is of shape `(batch_size, sequence_length, hidden_size)` where `sequence_length` is actually the `time_frames` of the Mel Spectogram. So with this tensor we have the neuron outputs of the network, for each time frame, for each batch. Since we just want the last hidden output, this corresponds to the recursion that took place for the last sequence. As a result we will use `[:, -1, :]` to get that from the tensor output of the `RNN()` layer.
#
# More specifically: According to the PyTorch documentation, the `nn.Linear()` layer expects an input of shape (\*, in_features). Where "\*" means any number of dimensions including none. In our case it is going to be `(batch_size, in_features)`, where the in_features of this layer, will be the output of the `RNN()` layer. Since we only use the last hidden state, the linear layer's `in_features` will be equal to the `hidden_size` of the` RNN()` layer. As the `hidden_size` of the `RNN()` is the number of features of the hidden state, or in other words the number of neurons.
#
# - If we print out the shape of the "*out*" tensor of the `forward()` method **before the slicing**, we get `(32, 997, 128)`. This shape is `(batch_size, time_frames, hidden_size)`.
# - If we print out the shape of the "*out*" tensor of the `forward()` method **after the slicing**, we get `(32, 128)`. This shape is `(batch_size hidden_size)`. It corresponds to the data from the last hidden state.
#
# As a result of the above, the first parameter of the `nn.Linear()` layer is "`hidden_size`".
#
# Another way to do that, is to actually not ignore the second output of the `RNN()` layer and define it as a variable. Since this tensor will include the 2 hidden states we can get the last one with the following code:
# ```
# out, h_n = self.rnn(x, h0)
# out = h_n[-1]  # last layer’s hidden state
# ```

# %% [markdown]
# 2. `model_2`: In this model we are going to use all the hidden states of the RNN layers. This means that in our case, the `nn.linear()` of the fully connected layer will expect an input of size `(batch_size, hidden_size * sequence_length)`. The architecture of this model will be the same as previous. Except for two differences: the input of the fully connected layer that we already mentioned, as well as the tensor that will feed it.
# Those differences are reflected in the code as such:
# * The first parameter of the `nn.Linear()` will now be "`hidden_size * sequence_length`".
# * After getting the output tensor of the `RNN()`, we will use the `reshape()` method to get the appropriate tensor. More specifically, if the output tensor of the `RNN()` is named `out`, we will use `out.reshape(out.shape[0], -1)`. The tensor we want needs to have the `batch_size` on dim=0 and all the data on dim=1. The first argument (`out.shape[0]`) outputs the `batch_size` and the second argument (`-1`) is a PyTorch setting that puts all the data in the remaining dimension accordingly.
#
# We can have a better view of the above, if we print out the shapes of the "*out*" tensor of the `forward()` method:
# - Before the `reshape()` method, the shape is `(32, 997, 128)`, which corresponds to `(batch_size, time_frames, hidden_state)`.
# - After  the `reshape()` method, the shape is `(32, 127616)`, which corresponds to `(batch_size, time_frames * hidden_state)`.

# %%
# Building an RNN model that uses only the last hidden state
INPUT_SIZE = 128 # number of mel bands
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
NUM_CLASSES = 10

class RNNClassifierV0(nn.Module):
    def __init__(self, input_size=INPUT_SIZE,
                 hidden_size=HIDDEN_SIZE,
                 num_layers=NUM_LAYERS,
                 num_classes=NUM_CLASSES):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.rnn = nn.RNN(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate RNN
        out, _ = self.rnn(x, h0)
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_0 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiation of paper version of RNN
# model_0= RNNClassifierV2().to(device)
model_0
# Out:
# RNNClassifierV0(
#   (rnn): RNN(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Building an RNN model that uses all the hidden states
INPUT_SIZE = 128 # number of mel_bands
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
NUM_CLASSES = 10
SEQUENCE_LENGTH = 997 # number of time frames


class RNNClassifierV1(nn.Module):
    def __init__(self, input_size=INPUT_SIZE,
                 hidden_size=HIDDEN_SIZE,
                 num_layers=NUM_LAYERS,
                 num_classes=NUM_CLASSES,
                 sequence_length=SEQUENCE_LENGTH):
        super().__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size

        self.rnn = nn.RNN(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size * sequence_length,
                            num_classes)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.rnn(x, h0)

        out = out.reshape(out.shape[0], -1)

        out = self.fc(out)
        return out

# %% [markdown]
# > _**Disclaimer: The following commented out code, includes another version of an RNN model.\
# >  This version is taken from this paper - https://ieeexplore.ieee.org/document/9573568**_

# %%
# # TEST RNN FROM PAPER -ONLY LAST HIDDEN STATE-
# # paper here: https://ieeexplore.ieee.org/document/9573568
#
# INPUT_SIZE = 128 # number of mel bands
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class RNNClassifierV2(nn.Module):
#     def __init__(self, input_size=128, num_classes=10):
#         super().__init__()
#
#         # defining the network layers
#         self.rnn1 = nn.RNN(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.rnn2 = nn.RNN(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for RNN 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn2(out, h0_2)
#
#         # Decode the hidden state of the last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# # TEST RNN FROM PAPER -ALL HIDDEN STATES-
# The test loss increases rapidly after 2 epochs, while train loss decreases
# # paper here: https://ieeexplore.ieee.org/document/9573568
#
# INPUT_SIZE = 128 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class RNNClassifierV3(nn.Module):
#     def __init__(self, input_size=128, num_classes=10, sequence_length=130):
#         super().__init__()
#
#         # defining the network layers
#         self.rnn1 = nn.RNN(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.rnn2 = nn.RNN(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64 * sequence_length, 64 * sequence_length)
#         self.fc2 = nn.Linear(64 * sequence_length, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for RNN 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.rnn2(out, h0_2)
#
#         out = out.reshape(out.shape[0], -1)
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_1= RNNClassifierV1(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, SEQUENCE_LENGTH).to(device)

# # Instantiation of paper version of RNN
# model_1= RNNClassifierV3().to(device)
model_1
# Out:
# RNNClassifierV1(
#   (rnn): RNN(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=127616, out_features=10, bias=True)
# )

# %%
# Extracting a sample
example, _ = next(iter(train_dataloader))
example.shape, example[0].shape
# Out:
# (torch.Size([32, 997, 128]), torch.Size([997, 128]))

# %%
# Testing with a forward pass
model_0.eval()
model_1.eval()
print(model_0(example.to(device))[:5])
print(model_1(example.to(device))[:5])
# Out:
# tensor([[-0.6766, -0.2288, -0.2886, -0.1319,  0.0437, -0.0407, -0.1248,  0.2177,
#           0.0099, -0.2714],
#         [-0.1772,  0.0782,  0.7099, -0.2371, -0.2263,  0.0110,  0.3392,  0.0203,
#           0.0203,  0.0682],
#         [-0.3714,  0.0855,  0.2849, -0.3078, -0.2343,  0.2164,  0.2101, -0.2056,
#           0.2827,  0.3555],
#         [-0.5299,  0.1759, -0.0100, -0.0396, -0.1639,  0.2526,  0.0800,  0.4316,
#           0.2047, -0.4745],
#         [-0.3743,  0.0983,  0.0734,  0.1038, -0.4373,  0.3377,  0.0832, -0.1212,
#           0.3421, -0.0098]], device='cuda:0', grad_fn=<SliceBackward0>)
# tensor([[-0.2712,  0.1491, -0.0466,  0.2781,  0.5952,  0.1420, -0.0293, -0.1070,
#          -0.3424,  0.2249],
#         [ 0.3734,  0.1591,  0.0028,  0.6826, -0.0970,  0.2223, -0.0059,  0.3525,
#           0.0087, -0.1601],
#         [ 0.2634,  0.3157, -0.0538,  0.2406,  0.1084,  0.3507, -0.4394,  0.2765,
#           0.0746,  0.1974],
#         [ 0.3438, -0.1643, -0.1299,  0.4443,  0.1544,  0.2108,  0.1835,  0.0490,
#          -0.2876, -0.5123],
#         [-0.2779,  0.1763, -0.5621,  0.3961, -0.3708,  0.2436, -0.2148,  0.5096,
#          -0.1177, -0.0308]], device='cuda:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# ## 5. Training the RNN models
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure.
#
# In order to implement the training pipeline, we will create two separate functions:
# * `train_step()`: This function is responsible for the training of the model. It also includes the logic for calculating the accuracy. We could use `torchmetrics.accuracy()`, but instead one can calculate it. We use the `argmax()` method after applying a `softmax()` on the logits that are extracted from the model. This calculation gives us the predicted label, because it returns the index of the highest probability. After that, the accuracy is calculated as the sum of predicted labels that are the same as the labels, divided by the number of samples.
# * `test_step()`: This function will evaluate the loss and accuracy on a set. Initially we will use it on the evaluation set during training.
#
# Those two functions are combined in the `train()` function in order to train the model for a set number of epochs. We also use the `timeit` library to set a timer in order to time the training. The `train()` function returns a dictionary with the results, in order to use them for plotting.

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer_0 = torch.optim.Adam(model_0.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)
optimizer_1 = torch.optim.Adam(model_1.parameters(),
                               lr=0.0001,
                               weight_decay=0.0001)

# # Optimizer according to the paper specs - https://ieeexplore.ieee.org/document/9573568
# # For use with the paper RNN models
# optimizer_1 = torch.optim.Adam(model_1.parameters(),
#                                lr=0.001)

# %% [markdown]
# ### 5.1 Implementing `SummaryWriter()`
# Before creating the training functions, we will create a function that includes a `SummaryWriter()` object to keep logs of our experiments.
# The `create_writer()` function will return a `SummaryWriter()` object. Our `train()` function has a writer parameter where we can put an object created with the `create_writer()` function in order to keep logs of a certain training procedure.

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import os

def create_writer(source: str,
                  segments: int,
                  model_name: str,
                  extra: str=None) -> torch.utils.tensorboard.writer.SummaryWriter:

    # Project root (adjust if needed)
    PROJECT_ROOT = os.path.abspath(
        os.path.join(os.getcwd(), "..", "..")
    )

    # Get timestamp of current date (all experiments on certain day live in same folder)
    timestamp = datetime.now().strftime("%d-%m-%Y") # returns current date in DD-MM-YYYY format

    if extra:
        # Create log directory path
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name, extra
        )
    else:
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name
        )

    print(f"[INFO] Created SummaryWriter, saving to: {log_dir}...")
    return SummaryWriter(log_dir=log_dir)

# %% [markdown]
# ### 5.2 Creating training functions

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
          ):

    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
    ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %%
# Training model_0
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer_0,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2259 | train_acc: 0.1875 | test_loss: 2.1090 | test_acc: 0.2500
# Epoch: 2 | train_loss: 2.0421 | train_acc: 0.2878 | test_loss: 1.9867 | test_acc: 0.3083
# Epoch: 3 | train_loss: 1.9362 | train_acc: 0.3229 | test_loss: 1.9016 | test_acc: 0.3229
# Epoch: 4 | train_loss: 1.8551 | train_acc: 0.3355 | test_loss: 1.8393 | test_acc: 0.3792
# Epoch: 5 | train_loss: 1.7983 | train_acc: 0.3586 | test_loss: 1.8071 | test_acc: 0.3688
# Epoch: 6 | train_loss: 1.7459 | train_acc: 0.3810 | test_loss: 1.7745 | test_acc: 0.3896
# Epoch: 7 | train_loss: 1.6995 | train_acc: 0.4068 | test_loss: 1.7572 | test_acc: 0.3479
# Epoch: 8 | train_loss: 1.6519 | train_acc: 0.4227 | test_loss: 1.7312 | test_acc: 0.3521
# Epoch: 9 | train_loss: 1.6181 | train_acc: 0.4359 | test_loss: 1.7220 | test_acc: 0.3458
# Epoch: 10 | train_loss: 1.5764 | train_acc: 0.4534 | test_loss: 1.6956 | test_acc: 0.3583
# Epoch: 11 | train_loss: 1.5381 | train_acc: 0.4715 | test_loss: 1.6877 | test_acc: 0.3708
# Epoch: 12 | train_loss: 1.5014 | train_acc: 0.4808 | test_loss: 1.6793 | test_acc: 0.3896
# Epoch: 13 | train_loss: 1.4744 | train_acc: 0.4989 | test_loss: 1.6882 | test_acc: 0.3583
# Epoch: 14 | train_loss: 1.4371 | train_acc: 0.5060 | test_loss: 1.6713 | test_acc: 0.3604
# Epoch: 15 | train_loss: 1.4336 | train_acc: 0.5011 | test_loss: 1.6653 | test_acc: 0.3750
# Epoch: 16 | train_loss: 1.3728 | train_acc: 0.5389 | test_loss: 1.6698 | test_acc: 0.3604
# Epoch: 17 | train_loss: 1.3533 | train_acc: 0.5307 | test_loss: 1.7034 | test_acc: 0.3625
# Epoch: 18 | train_loss: 1.3249 | train_acc: 0.5428 | test_loss: 1.6578 | test_acc: 0.3688
# Epoch: 19 | train_loss: 1.3029 | train_acc: 0.5559 | test_loss: 1.6985 | test_acc: 0.3708
# Epoch: 20 | train_loss: 1.2852 | train_acc: 0.5724 | test_loss: 1.6749 | test_acc: 0.3771
# Epoch: 21 | train_loss: 1.2460 | train_acc: 0.5817 | test_loss: 1.6673 | test_acc: 0.3750
# Epoch: 22 | train_loss: 1.2247 | train_acc: 0.5795 | test_loss: 1.6686 | test_acc: 0.3812
# Epoch: 23 | train_loss: 1.2081 | train_acc: 0.5927 | test_loss: 1.6644 | test_acc: 0.3833
# Epoch: 24 | train_loss: 1.1686 | train_acc: 0.6179 | test_loss: 1.6422 | test_acc: 0.3875
# Epoch: 25 | train_loss: 1.1545 | train_acc: 0.5992 | test_loss: 1.6535 | test_acc: 0.4062
# Epoch: 26 | train_loss: 1.1143 | train_acc: 0.6371 | test_loss: 1.6858 | test_acc: 0.4021
# Epoch: 27 | train_loss: 1.1415 | train_acc: 0.6228 | test_loss: 1.6535 | test_acc: 0.4062
# Epoch: 28 | train_loss: 1.0831 | train_acc: 0.6524 | test_loss: 1.6978 | test_acc: 0.3958
# Epoch: 29 | train_loss: 1.0999 | train_acc: 0.6250 | test_loss: 1.7095 | test_acc: 0.4146
# Epoch: 30 | train_loss: 1.0404 | train_acc: 0.6667 | test_loss: 1.7596 | test_acc: 0.4062
# Epoch: 31 | train_loss: 1.1658 | train_acc: 0.6151 | test_loss: 1.7371 | test_acc: 0.4042
# Epoch: 32 | train_loss: 1.0685 | train_acc: 0.6497 | test_loss: 1.6659 | test_acc: 0.4042
# Epoch: 33 | train_loss: 1.0592 | train_acc: 0.6497 | test_loss: 1.6847 | test_acc: 0.4000
# Epoch: 34 | train_loss: 0.9765 | train_acc: 0.6837 | test_loss: 1.7236 | test_acc: 0.3958
# Epoch: 35 | train_loss: 0.9322 | train_acc: 0.7023 | test_loss: 1.7277 | test_acc: 0.3875
# Epoch: 36 | train_loss: 0.9327 | train_acc: 0.6952 | test_loss: 1.7580 | test_acc: 0.3833
# Epoch: 37 | train_loss: 0.9401 | train_acc: 0.7056 | test_loss: 1.7042 | test_acc: 0.4104
# Epoch: 38 | train_loss: 0.9041 | train_acc: 0.7083 | test_loss: 1.6781 | test_acc: 0.4188
# Epoch: 39 | train_loss: 0.8764 | train_acc: 0.7122 | test_loss: 1.7510 | test_acc: 0.4208
# Epoch: 40 | train_loss: 0.8768 | train_acc: 0.7171 | test_loss: 1.7356 | test_acc: 0.4167
# Epoch: 41 | train_loss: 0.8938 | train_acc: 0.7034 | test_loss: 1.6878 | test_acc: 0.4354
# Epoch: 42 | train_loss: 0.8158 | train_acc: 0.7456 | test_loss: 1.7242 | test_acc: 0.3937
# Epoch: 43 | train_loss: 0.8423 | train_acc: 0.7341 | test_loss: 1.6887 | test_acc: 0.4292
# Epoch: 44 | train_loss: 0.8193 | train_acc: 0.7533 | test_loss: 1.6851 | test_acc: 0.4250
# Epoch: 45 | train_loss: 0.8068 | train_acc: 0.7495 | test_loss: 1.7047 | test_acc: 0.4354
# Epoch: 46 | train_loss: 0.7677 | train_acc: 0.7544 | test_loss: 1.7269 | test_acc: 0.4208
# Epoch: 47 | train_loss: 0.7737 | train_acc: 0.7577 | test_loss: 1.7233 | test_acc: 0.4229
# Epoch: 48 | train_loss: 0.7525 | train_acc: 0.7780 | test_loss: 1.6890 | test_acc: 0.4333
# Epoch: 49 | train_loss: 0.9304 | train_acc: 0.7034 | test_loss: 1.7389 | test_acc: 0.4333
# Epoch: 50 | train_loss: 1.1707 | train_acc: 0.6321 | test_loss: 1.9873 | test_acc: 0.3792
# Epoch: 51 | train_loss: 1.2049 | train_acc: 0.6118 | test_loss: 1.7966 | test_acc: 0.4146
# Epoch: 52 | train_loss: 0.9827 | train_acc: 0.6749 | test_loss: 1.7341 | test_acc: 0.4354
# Epoch: 53 | train_loss: 0.8652 | train_acc: 0.7155 | test_loss: 1.8015 | test_acc: 0.4188
# Epoch: 54 | train_loss: 0.8036 | train_acc: 0.7379 | test_loss: 1.7691 | test_acc: 0.4375
# Epoch: 55 | train_loss: 0.7806 | train_acc: 0.7599 | test_loss: 1.7556 | test_acc: 0.4354
# Epoch: 56 | train_loss: 0.7794 | train_acc: 0.7467 | test_loss: 1.7932 | test_acc: 0.4375
# Epoch: 57 | train_loss: 0.7678 | train_acc: 0.7560 | test_loss: 1.7368 | test_acc: 0.4333
# Epoch: 58 | train_loss: 0.7157 | train_acc: 0.7807 | test_loss: 1.7652 | test_acc: 0.4417
# Epoch: 59 | train_loss: 0.6978 | train_acc: 0.7928 | test_loss: 1.8074 | test_acc: 0.4479
# Epoch: 60 | train_loss: 0.6934 | train_acc: 0.7884 | test_loss: 1.7399 | test_acc: 0.4458
# Epoch: 61 | train_loss: 0.6693 | train_acc: 0.7993 | test_loss: 1.8269 | test_acc: 0.4396
# Epoch: 62 | train_loss: 0.9717 | train_acc: 0.6908 | test_loss: 1.8518 | test_acc: 0.3958
# Epoch: 63 | train_loss: 0.8288 | train_acc: 0.7325 | test_loss: 1.8128 | test_acc: 0.4417
# Epoch: 64 | train_loss: 0.7332 | train_acc: 0.7807 | test_loss: 1.7974 | test_acc: 0.4271
# Epoch: 65 | train_loss: 0.6893 | train_acc: 0.8004 | test_loss: 1.8356 | test_acc: 0.4146
# Epoch: 66 | train_loss: 0.6708 | train_acc: 0.8065 | test_loss: 1.7960 | test_acc: 0.4437
# Epoch: 67 | train_loss: 0.6350 | train_acc: 0.8130 | test_loss: 1.8356 | test_acc: 0.4354
# Epoch: 68 | train_loss: 0.6423 | train_acc: 0.8136 | test_loss: 1.8291 | test_acc: 0.4604
# Epoch: 69 | train_loss: 0.6100 | train_acc: 0.8224 | test_loss: 1.8142 | test_acc: 0.4625
# Epoch: 70 | train_loss: 0.5939 | train_acc: 0.8333 | test_loss: 1.8236 | test_acc: 0.4479
# Epoch: 71 | train_loss: 0.5758 | train_acc: 0.8476 | test_loss: 1.8096 | test_acc: 0.4604
# Epoch: 72 | train_loss: 0.5563 | train_acc: 0.8531 | test_loss: 1.8944 | test_acc: 0.4375
# Epoch: 73 | train_loss: 0.5669 | train_acc: 0.8421 | test_loss: 1.8386 | test_acc: 0.4646
# Epoch: 74 | train_loss: 0.5567 | train_acc: 0.8459 | test_loss: 1.8684 | test_acc: 0.4542
# Epoch: 75 | train_loss: 0.5595 | train_acc: 0.8421 | test_loss: 1.9793 | test_acc: 0.4479
# Epoch: 76 | train_loss: 0.5502 | train_acc: 0.8487 | test_loss: 1.9197 | test_acc: 0.4500
# Epoch: 77 | train_loss: 0.5273 | train_acc: 0.8547 | test_loss: 1.9151 | test_acc: 0.4625
# Epoch: 78 | train_loss: 0.5065 | train_acc: 0.8635 | test_loss: 1.9536 | test_acc: 0.4521
# Epoch: 79 | train_loss: 0.4969 | train_acc: 0.8684 | test_loss: 1.9737 | test_acc: 0.4271
# Epoch: 80 | train_loss: 0.4755 | train_acc: 0.8788 | test_loss: 1.9389 | test_acc: 0.4500
# Epoch: 81 | train_loss: 0.4631 | train_acc: 0.8843 | test_loss: 1.9489 | test_acc: 0.4583
# Epoch: 82 | train_loss: 0.6364 | train_acc: 0.8081 | test_loss: 2.1083 | test_acc: 0.4208
# Epoch: 83 | train_loss: 0.5501 | train_acc: 0.8350 | test_loss: 1.9439 | test_acc: 0.4542
# Epoch: 84 | train_loss: 0.4660 | train_acc: 0.8777 | test_loss: 1.9257 | test_acc: 0.4625
# Epoch: 85 | train_loss: 0.4537 | train_acc: 0.8860 | test_loss: 1.9802 | test_acc: 0.4542
# Epoch: 86 | train_loss: 0.4227 | train_acc: 0.8980 | test_loss: 1.9928 | test_acc: 0.4646
# Epoch: 87 | train_loss: 0.4126 | train_acc: 0.8942 | test_loss: 2.0167 | test_acc: 0.4396
# Epoch: 88 | train_loss: 0.4026 | train_acc: 0.8980 | test_loss: 2.0051 | test_acc: 0.4500
# Epoch: 89 | train_loss: 0.4005 | train_acc: 0.8964 | test_loss: 2.0694 | test_acc: 0.4396
# Epoch: 90 | train_loss: 0.4326 | train_acc: 0.8805 | test_loss: 2.0182 | test_acc: 0.4479
# Epoch: 91 | train_loss: 0.3873 | train_acc: 0.9046 | test_loss: 2.0287 | test_acc: 0.4500
# Epoch: 92 | train_loss: 0.3759 | train_acc: 0.9062 | test_loss: 2.0842 | test_acc: 0.4583
# Epoch: 93 | train_loss: 0.3560 | train_acc: 0.9150 | test_loss: 2.0547 | test_acc: 0.4583
# Epoch: 94 | train_loss: 0.3453 | train_acc: 0.9216 | test_loss: 2.0586 | test_acc: 0.4771
# Epoch: 95 | train_loss: 0.3486 | train_acc: 0.9200 | test_loss: 2.0395 | test_acc: 0.4667
# Epoch: 96 | train_loss: 0.3327 | train_acc: 0.9271 | test_loss: 2.0925 | test_acc: 0.4625
# Epoch: 97 | train_loss: 0.3236 | train_acc: 0.9298 | test_loss: 2.1515 | test_acc: 0.4500
# Epoch: 98 | train_loss: 0.3492 | train_acc: 0.9161 | test_loss: 2.0992 | test_acc: 0.4604
# Epoch: 99 | train_loss: 0.3184 | train_acc: 0.9320 | test_loss: 2.1244 | test_acc: 0.4542
# Epoch: 100 | train_loss: 0.3408 | train_acc: 0.9117 | test_loss: 2.1062 | test_acc: 0.4729
# Epoch: 101 | train_loss: 0.3646 | train_acc: 0.9030 | test_loss: 2.1047 | test_acc: 0.4542
# Epoch: 102 | train_loss: 0.2986 | train_acc: 0.9353 | test_loss: 2.1060 | test_acc: 0.4562
# Epoch: 103 | train_loss: 0.2973 | train_acc: 0.9391 | test_loss: 2.1369 | test_acc: 0.4583
# Epoch: 104 | train_loss: 0.2824 | train_acc: 0.9364 | test_loss: 2.1264 | test_acc: 0.4646
# Epoch: 105 | train_loss: 0.2911 | train_acc: 0.9391 | test_loss: 2.2386 | test_acc: 0.4500
# Epoch: 106 | train_loss: 0.3834 | train_acc: 0.9008 | test_loss: 2.1916 | test_acc: 0.4458
# Epoch: 107 | train_loss: 0.2993 | train_acc: 0.9271 | test_loss: 2.2349 | test_acc: 0.4625
# Epoch: 108 | train_loss: 0.2737 | train_acc: 0.9419 | test_loss: 2.2522 | test_acc: 0.4500
# Epoch: 109 | train_loss: 0.2631 | train_acc: 0.9457 | test_loss: 2.2189 | test_acc: 0.4583
# Epoch: 110 | train_loss: 0.2545 | train_acc: 0.9435 | test_loss: 2.2135 | test_acc: 0.4646
# Epoch: 111 | train_loss: 0.2354 | train_acc: 0.9556 | test_loss: 2.2044 | test_acc: 0.4583
# Epoch: 112 | train_loss: 0.2500 | train_acc: 0.9441 | test_loss: 2.1977 | test_acc: 0.4604
# Epoch: 113 | train_loss: 0.2619 | train_acc: 0.9359 | test_loss: 2.2366 | test_acc: 0.4542
# Epoch: 114 | train_loss: 0.2731 | train_acc: 0.9391 | test_loss: 2.3756 | test_acc: 0.4542
# Epoch: 115 | train_loss: 0.2240 | train_acc: 0.9529 | test_loss: 2.3311 | test_acc: 0.4396
# Epoch: 116 | train_loss: 0.2138 | train_acc: 0.9583 | test_loss: 2.4067 | test_acc: 0.4417
# Epoch: 117 | train_loss: 0.2547 | train_acc: 0.9468 | test_loss: 2.3498 | test_acc: 0.4354
# Epoch: 118 | train_loss: 0.2357 | train_acc: 0.9463 | test_loss: 2.3199 | test_acc: 0.4479
# Epoch: 119 | train_loss: 0.2829 | train_acc: 0.9243 | test_loss: 2.3347 | test_acc: 0.4542
# Epoch: 120 | train_loss: 0.2757 | train_acc: 0.9331 | test_loss: 2.3655 | test_acc: 0.4667
# Epoch: 121 | train_loss: 0.2185 | train_acc: 0.9529 | test_loss: 2.3262 | test_acc: 0.4479
# Epoch: 122 | train_loss: 0.1867 | train_acc: 0.9671 | test_loss: 2.3549 | test_acc: 0.4521
# Epoch: 123 | train_loss: 0.2077 | train_acc: 0.9545 | test_loss: 2.3056 | test_acc: 0.4708
# Epoch: 124 | train_loss: 0.7251 | train_acc: 0.7944 | test_loss: 2.3038 | test_acc: 0.4437
# Epoch: 125 | train_loss: 0.2970 | train_acc: 0.9331 | test_loss: 2.2517 | test_acc: 0.4458
# Epoch: 126 | train_loss: 0.1990 | train_acc: 0.9671 | test_loss: 2.2899 | test_acc: 0.4583
# Epoch: 127 | train_loss: 0.1753 | train_acc: 0.9731 | test_loss: 2.3329 | test_acc: 0.4750
# Epoch: 128 | train_loss: 0.1732 | train_acc: 0.9709 | test_loss: 2.3234 | test_acc: 0.4604
# Epoch: 129 | train_loss: 0.2159 | train_acc: 0.9545 | test_loss: 2.3566 | test_acc: 0.4521
# Epoch: 130 | train_loss: 0.1794 | train_acc: 0.9671 | test_loss: 2.3739 | test_acc: 0.4708
# Epoch: 131 | train_loss: 0.2856 | train_acc: 0.9375 | test_loss: 2.7935 | test_acc: 0.4000
# Epoch: 132 | train_loss: 0.5289 | train_acc: 0.8388 | test_loss: 2.4377 | test_acc: 0.4479
# Epoch: 133 | train_loss: 0.2402 | train_acc: 0.9512 | test_loss: 2.5027 | test_acc: 0.4437
# Epoch: 134 | train_loss: 0.2005 | train_acc: 0.9578 | test_loss: 2.4690 | test_acc: 0.4542
# Epoch: 135 | train_loss: 0.1605 | train_acc: 0.9731 | test_loss: 2.4677 | test_acc: 0.4604
# Epoch: 136 | train_loss: 0.1473 | train_acc: 0.9786 | test_loss: 2.4803 | test_acc: 0.4604
# Epoch: 137 | train_loss: 0.1358 | train_acc: 0.9836 | test_loss: 2.5392 | test_acc: 0.4625
# Epoch: 138 | train_loss: 0.1279 | train_acc: 0.9830 | test_loss: 2.5178 | test_acc: 0.4542
# Epoch: 139 | train_loss: 0.1267 | train_acc: 0.9836 | test_loss: 2.4960 | test_acc: 0.4562
# Epoch: 140 | train_loss: 0.1194 | train_acc: 0.9825 | test_loss: 2.5824 | test_acc: 0.4667
# Epoch: 141 | train_loss: 0.1179 | train_acc: 0.9857 | test_loss: 2.4993 | test_acc: 0.4354
# Epoch: 142 | train_loss: 0.2829 | train_acc: 0.9238 | test_loss: 2.4286 | test_acc: 0.4458
# Epoch: 143 | train_loss: 0.1498 | train_acc: 0.9764 | test_loss: 2.5233 | test_acc: 0.4562
# Epoch: 144 | train_loss: 0.1815 | train_acc: 0.9622 | test_loss: 2.4922 | test_acc: 0.4542
# Epoch: 145 | train_loss: 0.2046 | train_acc: 0.9545 | test_loss: 2.5621 | test_acc: 0.4562
# Epoch: 146 | train_loss: 0.2690 | train_acc: 0.9265 | test_loss: 2.5475 | test_acc: 0.4604
# Epoch: 147 | train_loss: 0.1857 | train_acc: 0.9583 | test_loss: 2.4449 | test_acc: 0.4583
# Epoch: 148 | train_loss: 0.1296 | train_acc: 0.9825 | test_loss: 2.4722 | test_acc: 0.4583
# Epoch: 149 | train_loss: 0.1232 | train_acc: 0.9852 | test_loss: 2.4587 | test_acc: 0.4542
# Epoch: 150 | train_loss: 0.1046 | train_acc: 0.9879 | test_loss: 2.4708 | test_acc: 0.4583
# Epoch: 151 | train_loss: 0.0990 | train_acc: 0.9896 | test_loss: 2.5006 | test_acc: 0.4562
# Epoch: 152 | train_loss: 0.1034 | train_acc: 0.9874 | test_loss: 2.6163 | test_acc: 0.4562
# Epoch: 153 | train_loss: 0.1051 | train_acc: 0.9825 | test_loss: 2.6216 | test_acc: 0.4375
# Epoch: 154 | train_loss: 0.1461 | train_acc: 0.9704 | test_loss: 2.5692 | test_acc: 0.4542
# Epoch: 155 | train_loss: 0.1167 | train_acc: 0.9792 | test_loss: 2.6109 | test_acc: 0.4479
# Epoch: 156 | train_loss: 0.1039 | train_acc: 0.9868 | test_loss: 2.6154 | test_acc: 0.4667
# Epoch: 157 | train_loss: 0.0940 | train_acc: 0.9863 | test_loss: 2.5539 | test_acc: 0.4521
# Epoch: 158 | train_loss: 0.0806 | train_acc: 0.9907 | test_loss: 2.5872 | test_acc: 0.4562
# Epoch: 159 | train_loss: 0.0758 | train_acc: 0.9923 | test_loss: 2.5877 | test_acc: 0.4542
# Epoch: 160 | train_loss: 0.0737 | train_acc: 0.9923 | test_loss: 2.6195 | test_acc: 0.4562
# Epoch: 161 | train_loss: 0.2621 | train_acc: 0.9227 | test_loss: 2.6814 | test_acc: 0.4646
# Epoch: 162 | train_loss: 0.2319 | train_acc: 0.9380 | test_loss: 2.8371 | test_acc: 0.4396
# Epoch: 163 | train_loss: 0.1546 | train_acc: 0.9616 | test_loss: 2.8341 | test_acc: 0.4542
# Epoch: 164 | train_loss: 0.1792 | train_acc: 0.9534 | test_loss: 2.6172 | test_acc: 0.4813
# Epoch: 165 | train_loss: 0.1032 | train_acc: 0.9857 | test_loss: 2.6016 | test_acc: 0.4604
# Epoch: 166 | train_loss: 0.1033 | train_acc: 0.9846 | test_loss: 2.6365 | test_acc: 0.4646
# Epoch: 167 | train_loss: 0.2188 | train_acc: 0.9435 | test_loss: 2.6752 | test_acc: 0.4375
# Epoch: 168 | train_loss: 0.1317 | train_acc: 0.9709 | test_loss: 2.7628 | test_acc: 0.4458
# Epoch: 169 | train_loss: 0.1283 | train_acc: 0.9737 | test_loss: 2.7008 | test_acc: 0.4583
# Epoch: 170 | train_loss: 0.0848 | train_acc: 0.9912 | test_loss: 2.6889 | test_acc: 0.4542
# Epoch: 171 | train_loss: 0.0671 | train_acc: 0.9923 | test_loss: 2.7251 | test_acc: 0.4583
# Epoch: 172 | train_loss: 0.0632 | train_acc: 0.9929 | test_loss: 2.6908 | test_acc: 0.4667
# Epoch: 173 | train_loss: 0.0604 | train_acc: 0.9934 | test_loss: 2.6881 | test_acc: 0.4521
# Epoch: 174 | train_loss: 0.0573 | train_acc: 0.9934 | test_loss: 2.6835 | test_acc: 0.4625
# Epoch: 175 | train_loss: 0.0559 | train_acc: 0.9934 | test_loss: 2.8095 | test_acc: 0.4417
# Epoch: 176 | train_loss: 0.0541 | train_acc: 0.9934 | test_loss: 2.7401 | test_acc: 0.4583
# Epoch: 177 | train_loss: 0.0580 | train_acc: 0.9934 | test_loss: 2.7793 | test_acc: 0.4583
# Epoch: 178 | train_loss: 0.0642 | train_acc: 0.9912 | test_loss: 2.8892 | test_acc: 0.4375
# Epoch: 179 | train_loss: 0.2651 | train_acc: 0.9293 | test_loss: 2.7353 | test_acc: 0.4542
# Epoch: 180 | train_loss: 0.0945 | train_acc: 0.9841 | test_loss: 2.8766 | test_acc: 0.4604
# Epoch: 181 | train_loss: 0.5967 | train_acc: 0.8339 | test_loss: 2.7168 | test_acc: 0.4417
# Epoch: 182 | train_loss: 0.3018 | train_acc: 0.9134 | test_loss: 2.6646 | test_acc: 0.4562
# Epoch: 183 | train_loss: 0.1123 | train_acc: 0.9792 | test_loss: 2.5521 | test_acc: 0.4771
# Epoch: 184 | train_loss: 0.0784 | train_acc: 0.9912 | test_loss: 2.6162 | test_acc: 0.4729
# Epoch: 185 | train_loss: 0.0635 | train_acc: 0.9929 | test_loss: 2.6334 | test_acc: 0.4646
# Epoch: 186 | train_loss: 0.0569 | train_acc: 0.9945 | test_loss: 2.6998 | test_acc: 0.4708
# Epoch: 187 | train_loss: 0.0538 | train_acc: 0.9940 | test_loss: 2.6763 | test_acc: 0.4813
# Epoch: 188 | train_loss: 0.0538 | train_acc: 0.9940 | test_loss: 2.6737 | test_acc: 0.4667
# Epoch: 189 | train_loss: 0.0524 | train_acc: 0.9945 | test_loss: 2.6902 | test_acc: 0.4646
# Epoch: 190 | train_loss: 0.0681 | train_acc: 0.9885 | test_loss: 2.7281 | test_acc: 0.4521
# Epoch: 191 | train_loss: 0.0937 | train_acc: 0.9841 | test_loss: 2.6714 | test_acc: 0.4667
# Epoch: 192 | train_loss: 0.0808 | train_acc: 0.9857 | test_loss: 2.7858 | test_acc: 0.4667
# Epoch: 193 | train_loss: 0.0478 | train_acc: 0.9945 | test_loss: 2.7206 | test_acc: 0.4729
# Epoch: 194 | train_loss: 0.0434 | train_acc: 0.9956 | test_loss: 2.7609 | test_acc: 0.4583
# Epoch: 195 | train_loss: 0.0438 | train_acc: 0.9951 | test_loss: 2.7413 | test_acc: 0.4646
# Epoch: 196 | train_loss: 0.0451 | train_acc: 0.9951 | test_loss: 2.7754 | test_acc: 0.4646
# Epoch: 197 | train_loss: 0.0375 | train_acc: 0.9967 | test_loss: 2.8253 | test_acc: 0.4667
# Epoch: 198 | train_loss: 0.0392 | train_acc: 0.9956 | test_loss: 2.7868 | test_acc: 0.4729
# Epoch: 199 | train_loss: 0.0352 | train_acc: 0.9962 | test_loss: 2.8113 | test_acc: 0.4625
# Epoch: 200 | train_loss: 0.0356 | train_acc: 0.9967 | test_loss: 2.8193 | test_acc: 0.4604
# Epoch: 201 | train_loss: 0.0374 | train_acc: 0.9962 | test_loss: 2.9243 | test_acc: 0.4500
# Epoch: 202 | train_loss: 0.0868 | train_acc: 0.9764 | test_loss: 2.8537 | test_acc: 0.4479
# Epoch: 203 | train_loss: 0.0863 | train_acc: 0.9819 | test_loss: 2.9183 | test_acc: 0.4708
# Epoch: 204 | train_loss: 0.0643 | train_acc: 0.9885 | test_loss: 3.0495 | test_acc: 0.4417
# Epoch: 205 | train_loss: 0.0809 | train_acc: 0.9852 | test_loss: 3.0077 | test_acc: 0.4458
# Epoch: 206 | train_loss: 0.0468 | train_acc: 0.9934 | test_loss: 2.8507 | test_acc: 0.4646
# Epoch: 207 | train_loss: 0.0385 | train_acc: 0.9951 | test_loss: 2.9591 | test_acc: 0.4708
# Epoch: 208 | train_loss: 0.1689 | train_acc: 0.9561 | test_loss: 3.1284 | test_acc: 0.4437
# Epoch: 209 | train_loss: 0.1944 | train_acc: 0.9441 | test_loss: 3.0557 | test_acc: 0.4479
# Epoch: 210 | train_loss: 0.0911 | train_acc: 0.9792 | test_loss: 2.9607 | test_acc: 0.4604
# Epoch: 211 | train_loss: 0.0991 | train_acc: 0.9781 | test_loss: 2.9978 | test_acc: 0.4521
# Epoch: 212 | train_loss: 0.0815 | train_acc: 0.9841 | test_loss: 3.0147 | test_acc: 0.4625
# Epoch: 213 | train_loss: 0.0787 | train_acc: 0.9857 | test_loss: 3.0879 | test_acc: 0.4417
# Epoch: 214 | train_loss: 0.0393 | train_acc: 0.9962 | test_loss: 3.0092 | test_acc: 0.4542
# Epoch: 215 | train_loss: 0.0617 | train_acc: 0.9879 | test_loss: 3.2294 | test_acc: 0.4292
# Epoch: 216 | train_loss: 0.0705 | train_acc: 0.9868 | test_loss: 3.1405 | test_acc: 0.4437
# Epoch: 217 | train_loss: 0.0325 | train_acc: 0.9978 | test_loss: 3.1274 | test_acc: 0.4562
# Epoch: 218 | train_loss: 0.0274 | train_acc: 0.9978 | test_loss: 3.0917 | test_acc: 0.4542
# Epoch: 219 | train_loss: 0.0254 | train_acc: 0.9984 | test_loss: 3.0794 | test_acc: 0.4604
# Epoch: 220 | train_loss: 0.0262 | train_acc: 0.9973 | test_loss: 3.2054 | test_acc: 0.4458
# Epoch: 221 | train_loss: 0.2446 | train_acc: 0.9320 | test_loss: 2.9604 | test_acc: 0.4792
# Epoch: 222 | train_loss: 0.1879 | train_acc: 0.9413 | test_loss: 2.9111 | test_acc: 0.4313
# Epoch: 223 | train_loss: 0.0848 | train_acc: 0.9836 | test_loss: 2.8778 | test_acc: 0.4688
# Epoch: 224 | train_loss: 0.1384 | train_acc: 0.9638 | test_loss: 3.0685 | test_acc: 0.4500
# Epoch: 225 | train_loss: 0.0779 | train_acc: 0.9819 | test_loss: 2.9027 | test_acc: 0.4604
# Epoch: 226 | train_loss: 0.0367 | train_acc: 0.9962 | test_loss: 2.9256 | test_acc: 0.4500
# Epoch: 227 | train_loss: 0.0287 | train_acc: 0.9978 | test_loss: 2.9802 | test_acc: 0.4604
# Epoch: 228 | train_loss: 0.0255 | train_acc: 0.9978 | test_loss: 2.9797 | test_acc: 0.4500
# Epoch: 229 | train_loss: 0.0236 | train_acc: 0.9984 | test_loss: 2.9946 | test_acc: 0.4583
# Epoch: 230 | train_loss: 0.0224 | train_acc: 0.9978 | test_loss: 3.0126 | test_acc: 0.4604
# Epoch: 231 | train_loss: 0.0212 | train_acc: 0.9984 | test_loss: 3.0296 | test_acc: 0.4562
# Epoch: 232 | train_loss: 0.2946 | train_acc: 0.9254 | test_loss: 3.0464 | test_acc: 0.4188
# Epoch: 233 | train_loss: 0.1651 | train_acc: 0.9567 | test_loss: 3.0991 | test_acc: 0.4542
# Epoch: 234 | train_loss: 0.0535 | train_acc: 0.9912 | test_loss: 3.0666 | test_acc: 0.4542
# Epoch: 235 | train_loss: 0.0336 | train_acc: 0.9962 | test_loss: 3.0999 | test_acc: 0.4542
# Epoch: 236 | train_loss: 0.0282 | train_acc: 0.9962 | test_loss: 3.0957 | test_acc: 0.4646
# Epoch: 237 | train_loss: 0.0245 | train_acc: 0.9978 | test_loss: 3.0746 | test_acc: 0.4625
# Epoch: 238 | train_loss: 0.0235 | train_acc: 0.9978 | test_loss: 3.2015 | test_acc: 0.4604
# Epoch: 239 | train_loss: 0.0217 | train_acc: 0.9984 | test_loss: 3.0788 | test_acc: 0.4583
# Epoch: 240 | train_loss: 0.0199 | train_acc: 0.9984 | test_loss: 3.1143 | test_acc: 0.4771
# Epoch: 241 | train_loss: 0.0184 | train_acc: 0.9984 | test_loss: 3.1312 | test_acc: 0.4583
# Epoch: 242 | train_loss: 0.0185 | train_acc: 0.9984 | test_loss: 3.0847 | test_acc: 0.4562
# Epoch: 243 | train_loss: 0.0178 | train_acc: 0.9989 | test_loss: 3.1091 | test_acc: 0.4604
# Epoch: 244 | train_loss: 0.0170 | train_acc: 0.9989 | test_loss: 3.2128 | test_acc: 0.4542
# Epoch: 245 | train_loss: 0.0166 | train_acc: 0.9989 | test_loss: 3.1833 | test_acc: 0.4625
# Epoch: 246 | train_loss: 0.0185 | train_acc: 0.9978 | test_loss: 3.2096 | test_acc: 0.4583
# Epoch: 247 | train_loss: 0.0203 | train_acc: 0.9984 | test_loss: 3.1886 | test_acc: 0.4646
# Epoch: 248 | train_loss: 0.0169 | train_acc: 0.9989 | test_loss: 3.2567 | test_acc: 0.4625
# Epoch: 249 | train_loss: 0.0571 | train_acc: 0.9852 | test_loss: 3.4308 | test_acc: 0.4292
# Epoch: 250 | train_loss: 0.2029 | train_acc: 0.9326 | test_loss: 3.1961 | test_acc: 0.4437
# Epoch: 251 | train_loss: 0.1593 | train_acc: 0.9583 | test_loss: 3.3606 | test_acc: 0.4125
# Epoch: 252 | train_loss: 0.2397 | train_acc: 0.9243 | test_loss: 3.5743 | test_acc: 0.4021
# Epoch: 253 | train_loss: 0.2278 | train_acc: 0.9315 | test_loss: 3.1290 | test_acc: 0.4250
# Epoch: 254 | train_loss: 0.0685 | train_acc: 0.9863 | test_loss: 3.1987 | test_acc: 0.4417
# Epoch: 255 | train_loss: 0.0364 | train_acc: 0.9962 | test_loss: 3.0917 | test_acc: 0.4562
# Epoch: 256 | train_loss: 0.0223 | train_acc: 0.9989 | test_loss: 3.1501 | test_acc: 0.4625
# Epoch: 257 | train_loss: 0.0196 | train_acc: 0.9989 | test_loss: 3.1782 | test_acc: 0.4625
# Epoch: 258 | train_loss: 0.0185 | train_acc: 0.9984 | test_loss: 3.1894 | test_acc: 0.4667
# Epoch: 259 | train_loss: 0.0169 | train_acc: 0.9989 | test_loss: 3.2236 | test_acc: 0.4583
# Epoch: 260 | train_loss: 0.0160 | train_acc: 0.9995 | test_loss: 3.2256 | test_acc: 0.4625
# Epoch: 261 | train_loss: 0.0153 | train_acc: 0.9995 | test_loss: 3.2440 | test_acc: 0.4708
# Epoch: 262 | train_loss: 0.0151 | train_acc: 0.9995 | test_loss: 3.2305 | test_acc: 0.4708
# Epoch: 263 | train_loss: 0.0143 | train_acc: 0.9989 | test_loss: 3.2600 | test_acc: 0.4729
# Epoch: 264 | train_loss: 0.0144 | train_acc: 0.9989 | test_loss: 3.2712 | test_acc: 0.4646
# Epoch: 265 | train_loss: 0.0136 | train_acc: 0.9995 | test_loss: 3.2789 | test_acc: 0.4542
# Epoch: 266 | train_loss: 0.0135 | train_acc: 0.9989 | test_loss: 3.2994 | test_acc: 0.4542
# Epoch: 267 | train_loss: 0.0134 | train_acc: 0.9989 | test_loss: 3.3184 | test_acc: 0.4542
# Epoch: 268 | train_loss: 0.0122 | train_acc: 0.9989 | test_loss: 3.2850 | test_acc: 0.4604
# Epoch: 269 | train_loss: 0.0119 | train_acc: 0.9995 | test_loss: 3.2855 | test_acc: 0.4708
# Epoch: 270 | train_loss: 0.0125 | train_acc: 0.9989 | test_loss: 3.3205 | test_acc: 0.4646
# Epoch: 271 | train_loss: 0.0114 | train_acc: 0.9989 | test_loss: 3.3483 | test_acc: 0.4583
# Epoch: 272 | train_loss: 0.0113 | train_acc: 0.9995 | test_loss: 3.3710 | test_acc: 0.4542
# Epoch: 273 | train_loss: 0.0108 | train_acc: 0.9989 | test_loss: 3.3710 | test_acc: 0.4542
# Epoch: 274 | train_loss: 0.0110 | train_acc: 0.9989 | test_loss: 3.3761 | test_acc: 0.4646
# Epoch: 275 | train_loss: 0.0103 | train_acc: 0.9995 | test_loss: 3.3336 | test_acc: 0.4625
# Epoch: 276 | train_loss: 0.0106 | train_acc: 0.9989 | test_loss: 3.3776 | test_acc: 0.4583
# Epoch: 277 | train_loss: 0.0106 | train_acc: 0.9989 | test_loss: 3.4210 | test_acc: 0.4583
# Epoch: 278 | train_loss: 0.0097 | train_acc: 0.9995 | test_loss: 3.3495 | test_acc: 0.4562
# Epoch: 279 | train_loss: 0.0092 | train_acc: 0.9989 | test_loss: 3.3636 | test_acc: 0.4542
# Epoch: 280 | train_loss: 0.0093 | train_acc: 0.9989 | test_loss: 3.3974 | test_acc: 0.4521
# Epoch: 281 | train_loss: 0.0102 | train_acc: 0.9989 | test_loss: 3.3581 | test_acc: 0.4562
# Epoch: 282 | train_loss: 0.0093 | train_acc: 0.9995 | test_loss: 3.3040 | test_acc: 0.4604
# Epoch: 283 | train_loss: 0.0087 | train_acc: 0.9989 | test_loss: 3.4242 | test_acc: 0.4500
# Epoch: 284 | train_loss: 0.0089 | train_acc: 0.9989 | test_loss: 3.4357 | test_acc: 0.4500
# Epoch: 285 | train_loss: 0.0082 | train_acc: 0.9995 | test_loss: 3.3588 | test_acc: 0.4625
# Epoch: 286 | train_loss: 0.0086 | train_acc: 0.9989 | test_loss: 3.3076 | test_acc: 0.4646
# Epoch: 287 | train_loss: 0.0090 | train_acc: 0.9989 | test_loss: 3.3987 | test_acc: 0.4625
# Epoch: 288 | train_loss: 0.0081 | train_acc: 0.9989 | test_loss: 3.3509 | test_acc: 0.4521
# Epoch: 289 | train_loss: 0.0073 | train_acc: 0.9995 | test_loss: 3.3953 | test_acc: 0.4500
# Epoch: 290 | train_loss: 0.0074 | train_acc: 0.9995 | test_loss: 3.5380 | test_acc: 0.4458
# Epoch: 291 | train_loss: 0.0076 | train_acc: 0.9995 | test_loss: 3.4066 | test_acc: 0.4521
# Epoch: 292 | train_loss: 0.0070 | train_acc: 0.9995 | test_loss: 3.4215 | test_acc: 0.4625
# Epoch: 293 | train_loss: 0.0076 | train_acc: 0.9989 | test_loss: 3.5564 | test_acc: 0.4521
# Epoch: 294 | train_loss: 0.0072 | train_acc: 0.9995 | test_loss: 3.4205 | test_acc: 0.4521
# Epoch: 295 | train_loss: 0.0067 | train_acc: 0.9995 | test_loss: 3.4671 | test_acc: 0.4542
# Epoch: 296 | train_loss: 0.5771 | train_acc: 0.8624 | test_loss: 3.6440 | test_acc: 0.3937
# Epoch: 297 | train_loss: 0.3699 | train_acc: 0.8942 | test_loss: 3.1682 | test_acc: 0.4167
# Epoch: 298 | train_loss: 0.0688 | train_acc: 0.9841 | test_loss: 3.1023 | test_acc: 0.4604
# Epoch: 299 | train_loss: 0.0481 | train_acc: 0.9929 | test_loss: 3.2534 | test_acc: 0.4688
# Epoch: 300 | train_loss: 0.0750 | train_acc: 0.9857 | test_loss: 3.3285 | test_acc: 0.4417
# Total training time: 206.821 seconds

# %%
# Training model_1
# Set number of epochs
NUM_EPOCHS = 30

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train(model=model_1,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer_1,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.7589 | train_acc: 0.4167 | test_loss: 1.7334 | test_acc: 0.4479
# Epoch: 2 | train_loss: 0.5491 | train_acc: 0.8492 | test_loss: 1.3359 | test_acc: 0.5104
# Epoch: 3 | train_loss: 0.1938 | train_acc: 0.9868 | test_loss: 1.2712 | test_acc: 0.5583
# Epoch: 4 | train_loss: 0.0871 | train_acc: 0.9989 | test_loss: 1.3110 | test_acc: 0.5375
# Epoch: 5 | train_loss: 0.0546 | train_acc: 0.9989 | test_loss: 1.3880 | test_acc: 0.5333
# Epoch: 6 | train_loss: 0.0386 | train_acc: 0.9995 | test_loss: 1.3111 | test_acc: 0.5479
# Epoch: 7 | train_loss: 0.0292 | train_acc: 0.9995 | test_loss: 1.2840 | test_acc: 0.5646
# Epoch: 8 | train_loss: 0.0245 | train_acc: 0.9995 | test_loss: 1.2924 | test_acc: 0.5417
# Epoch: 9 | train_loss: 0.0236 | train_acc: 0.9989 | test_loss: 1.4238 | test_acc: 0.5354
# Epoch: 10 | train_loss: 0.0211 | train_acc: 0.9989 | test_loss: 1.4163 | test_acc: 0.5417
# Epoch: 11 | train_loss: 0.0168 | train_acc: 0.9995 | test_loss: 1.4114 | test_acc: 0.5396
# Epoch: 12 | train_loss: 0.0153 | train_acc: 0.9995 | test_loss: 1.3198 | test_acc: 0.5500
# Epoch: 13 | train_loss: 0.0179 | train_acc: 0.9989 | test_loss: 1.5891 | test_acc: 0.5229
# Epoch: 14 | train_loss: 0.0142 | train_acc: 0.9995 | test_loss: 1.3971 | test_acc: 0.5521
# Epoch: 15 | train_loss: 0.0109 | train_acc: 0.9989 | test_loss: 1.3996 | test_acc: 0.5542
# Epoch: 16 | train_loss: 0.0088 | train_acc: 0.9995 | test_loss: 1.3808 | test_acc: 0.5542
# Epoch: 17 | train_loss: 0.0143 | train_acc: 0.9989 | test_loss: 1.4423 | test_acc: 0.5563
# Epoch: 18 | train_loss: 0.0114 | train_acc: 0.9995 | test_loss: 1.5033 | test_acc: 0.5563
# Epoch: 19 | train_loss: 0.0098 | train_acc: 0.9995 | test_loss: 1.5722 | test_acc: 0.5396
# Epoch: 20 | train_loss: 0.0160 | train_acc: 0.9989 | test_loss: 1.5045 | test_acc: 0.5396
# Epoch: 21 | train_loss: 0.0112 | train_acc: 0.9995 | test_loss: 1.4609 | test_acc: 0.5521
# Epoch: 22 | train_loss: 0.0093 | train_acc: 0.9995 | test_loss: 1.5851 | test_acc: 0.5417
# Epoch: 23 | train_loss: 0.0168 | train_acc: 0.9989 | test_loss: 1.7235 | test_acc: 0.5375
# Epoch: 24 | train_loss: 0.0123 | train_acc: 0.9995 | test_loss: 1.4564 | test_acc: 0.5458
# Epoch: 25 | train_loss: 0.0095 | train_acc: 0.9995 | test_loss: 1.5078 | test_acc: 0.5458
# Epoch: 26 | train_loss: 0.0114 | train_acc: 0.9995 | test_loss: 1.4618 | test_acc: 0.5437
# Epoch: 27 | train_loss: 0.0094 | train_acc: 0.9995 | test_loss: 1.5000 | test_acc: 0.5375
# Epoch: 28 | train_loss: 0.0111 | train_acc: 0.9995 | test_loss: 1.4855 | test_acc: 0.5354
# Epoch: 29 | train_loss: 0.0101 | train_acc: 0.9995 | test_loss: 1.5088 | test_acc: 0.5437
# Epoch: 30 | train_loss: 0.0115 | train_acc: 0.9995 | test_loss: 1.4891 | test_acc: 0.5542
# Total training time: 19.757 seconds

# %% [markdown]
# ## 6. Plotting the results of the RNN models
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys (they are the same as model_1)
print(model_0_results.keys())
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
# defining the plot function
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]],
                     Save = False,
                     filename: str = "training_curves",):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup figure
    fig, axs = plt.subplots(1, 2, figsize=(15, 7))
    fig.patch.set_facecolor('white')

    # ===== Loss plot =====
    axs[0].set_facecolor('white')

    axs[0].plot(epochs, loss, label='train_loss', color="#4195C1")
    axs[0].plot(epochs, test_loss, label='test_loss', color="#FF7B22")

    axs[0].set_title('Loss', color='black')
    axs[0].set_xlabel('Epochs', color='black')

    axs[0].tick_params(axis='x', colors='black')
    axs[0].tick_params(axis='y', colors='black')

    for spine in axs[0].spines.values():
        spine.set_color('black')

    axs[0].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # ===== Accuracy plot =====
    axs[1].set_facecolor('white')

    axs[1].plot(epochs, accuracy, label='train_accuracy', color="#4195C1")
    axs[1].plot(epochs, test_accuracy, label='test_accuracy', color="#FF7B22")

    axs[1].set_title('Accuracy', color='black')
    axs[1].set_xlabel('Epochs', color='black')

    axs[1].tick_params(axis='x', colors='black')
    axs[1].tick_params(axis='y', colors='black')

    for spine in axs[1].spines.values():
        spine.set_color('black')

    axs[1].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # Layout
    plt.tight_layout()

    # Save figure
    if Save:
        plt.savefig(
            filename + ".png",
            dpi=144,
            bbox_inches='tight',
            facecolor=fig.get_facecolor()
        )

    plt.show()

# %%
# Plotting the results of model_0
plot_loss_curves(model_0_results, Save=True, filename="model_0_training")

# %% [markdown]
# We can see that `model_0` is overfitting right from the very first epochs

# %%
# Plotting the results of model_1
plot_loss_curves(model_1_results, Save=True, filename="model_1_training")

# %% [markdown]
# In the case of `model_1` it is obvious that overfitting occurs from the very early stages of training. Not only that, but it adapts to the training set right from the start.

# %% [markdown]
# ## 7. Building a basic LSTM model
#
# Better results are expected with the use of an LSTM model.
# This neural network is similar to the RNN architecture, though it features some extra attributes in order to fix some common issues of the RNN.
# * __Unstable gradients__: The weight of the feedback loop can cause problems on the gradient descent equation. This weight refers to the _reccurent weight matrix_ that connects the hidden state of the previous state, with the current one. In case that weight is larger than one, repeated multiplication during backpropagation can lead to a very large number, which causes __exploding gradients__. On the other hand, if the value of the weight is less than one, it can lead to a very small number, which causes __vanishing gradients__.
# * __Long term memory__: RNNs tend to "forget" old data. This happens due to exploding/vanishing gradients.
#
# In order to solve this problems, LSTMs implement a _cell state_, apart from the _hidden state_. This is responsible for storing data from older recursions in time. As a result, building the LSTM class for our model, should include an initial cell state (`c0`) apart from the initial hidden state (`ho`) in the `forward()` method. This cell state reflects a long-term memory for the network. Other than that, PyTorch includes an `LSTM()` layer, which is used same as the `RNN()` layer.
#
# After building the class and instantiatiing a model, we follow the same pipeline as with the RNNs in order to train the model and plot the results for evaluation.

# %%
# Building the LSTM model
INPUT_SIZE = 128 # number of mel bands
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked LSTM layers that are going to be used
NUM_CLASSES = 10

class LSTMClassifierV0(nn.Module):
    def __init__(self, input_size=INPUT_SIZE,
                 hidden_size=HIDDEN_SIZE,
                 num_layers=NUM_LAYERS,
                 num_classes=NUM_CLASSES):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.lstm = nn.LSTM(input_size,
                           hidden_size,
                           num_layers,
                           batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state and cell state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0,c0))
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# # Building the LSTM model using data from all states
# INPUT_SIZE = 128 # number of mel bands
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked LSTM layers that are going to be used
# NUM_CLASSES = 10
#
# class LSTMClassifierV0(nn.Module):
#     def __init__(self, input_size=INPUT_SIZE,
#                  hidden_size=HIDDEN_SIZE,
#                  num_layers=NUM_LAYERS,
#                  num_classes=NUM_CLASSES):
#         super().__init__()
#
#         # defining the attributes here, in order to use them later in the forward() method
#         self.num_layers = num_layers
#         self.hidden_size = hidden_size
#
#         # defining the network layers
#         self.lstm = nn.LSTM(input_size,
#                            hidden_size,
#                            num_layers,
#                            batch_first=True)
#         self.fc = nn.Linear(hidden_size * 997,
#                             num_classes)
#
#     def forward(self, x):
#         # an initial hidden state and cell state must be used first.
#         # The dimensions/arguments we set it to have are predifined by PyTorch.
#         h0 = torch.zeros(self.num_layers,
#                          x.size(0),
#                          self.hidden_size).to(device)
#         c0 = torch.zeros(self.num_layers,
#                          x.size(0),
#                          self.hidden_size).to(device)
#
#         # Forward propagate LSTM
#         out, _ = self.lstm(x, (h0,c0))
#         # out: tensor of shape (batch_size, seq_length, hidden_size)
#
#         # Decode the hidden state of the last time step
#         out = out.reshape(out.shape[0], -1)
#
#         # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
#         out = self.fc(out)
#         return out

# %%
# # Building the LSTM model according to paper: https://ieeexplore.ieee.org/document/9573568
# INPUT_SIZE = 128 # number of mel bands
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked LSTM layers that are going to be used
# NUM_CLASSES = 10
#
# class LSTMClassifierV1(nn.Module):
#     def __init__(self, input_size=128, num_classes=10):
#         super().__init__()
#
#         # LSTM blocks
#         self.lstm1 = nn.LSTM(input_size,
#                              128,
#                              num_layers=1,
#                              batch_first=True)
#
#         self.lstm2 = nn.LSTM(128,
#                              64,
#                              num_layers=1,
#                              batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for LSTM 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#         c0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         out, _ = self.lstm1(x, (h0_1, c0_1))
#
#         # Initial states for LSTM 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#         c0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         out, _ = self.lstm2(out, (h0_2, c0_2))
#
#         # Last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_2 = LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# Instatiating the paper version of the LSTM
# model_2 = LSTMClassifierV1().to(device)
model_2
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Extracting a sample and testing it with a forward pass
example, _ = next(iter(train_dataloader))
model_2.eval()
print(model_2(example.to(device))[:5])
# Out:
# tensor([[-0.1001, -0.1139, -0.0457, -0.1112, -0.0551,  0.0095, -0.0703,  0.0560,
#          -0.0440,  0.0399],
#         [ 0.1408, -0.1566, -0.0282, -0.0078,  0.0016, -0.0336, -0.0322,  0.0258,
#           0.1482,  0.0099],
#         [-0.0338, -0.0934, -0.0421, -0.0110,  0.1693, -0.0499,  0.0323,  0.0300,
#           0.0397, -0.0313],
#         [-0.1046,  0.0226, -0.0557, -0.2002,  0.0075,  0.1342,  0.0178, -0.0203,
#           0.0199,  0.0453],
#         [-0.1145, -0.0775, -0.0705, -0.0536, -0.1004, -0.0174,  0.0285,  0.1323,
#           0.1064, -0.0564]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in the paper version of the LSTM
# optimizer = torch.optim.Adam(model_2.parameters(),
#                              lr=0.001)

# %%
# Training model_2
# Set number of epochs
NUM_EPOCHS = NUM_EPOCHS = 100


# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_2_results = train(model=model_2,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2621 | train_acc: 0.2111 | test_loss: 2.2137 | test_acc: 0.3417
# Epoch: 2 | train_loss: 2.1432 | train_acc: 0.3158 | test_loss: 2.0716 | test_acc: 0.3063
# Epoch: 3 | train_loss: 1.9697 | train_acc: 0.3586 | test_loss: 1.8968 | test_acc: 0.3417
# Epoch: 4 | train_loss: 1.7880 | train_acc: 0.3909 | test_loss: 1.7467 | test_acc: 0.3771
# Epoch: 5 | train_loss: 1.6542 | train_acc: 0.4375 | test_loss: 1.6522 | test_acc: 0.3896
# Epoch: 6 | train_loss: 1.5487 | train_acc: 0.4814 | test_loss: 1.5805 | test_acc: 0.4562
# Epoch: 7 | train_loss: 1.4410 | train_acc: 0.5164 | test_loss: 1.5309 | test_acc: 0.4750
# Epoch: 8 | train_loss: 1.3685 | train_acc: 0.5444 | test_loss: 1.4764 | test_acc: 0.4354
# Epoch: 9 | train_loss: 1.3354 | train_acc: 0.5537 | test_loss: 1.4892 | test_acc: 0.4583
# Epoch: 10 | train_loss: 1.2790 | train_acc: 0.5609 | test_loss: 1.4391 | test_acc: 0.4750
# Epoch: 11 | train_loss: 1.1949 | train_acc: 0.6064 | test_loss: 1.4042 | test_acc: 0.5042
# Epoch: 12 | train_loss: 1.1785 | train_acc: 0.6025 | test_loss: 1.4863 | test_acc: 0.4729
# Epoch: 13 | train_loss: 1.1167 | train_acc: 0.6245 | test_loss: 1.4243 | test_acc: 0.4562
# Epoch: 14 | train_loss: 1.1671 | train_acc: 0.5899 | test_loss: 1.6753 | test_acc: 0.4167
# Epoch: 15 | train_loss: 1.2572 | train_acc: 0.5674 | test_loss: 1.3885 | test_acc: 0.5188
# Epoch: 16 | train_loss: 1.1231 | train_acc: 0.6179 | test_loss: 1.3572 | test_acc: 0.5125
# Epoch: 17 | train_loss: 1.0570 | train_acc: 0.6431 | test_loss: 1.3683 | test_acc: 0.5125
# Epoch: 18 | train_loss: 1.0130 | train_acc: 0.6683 | test_loss: 1.2774 | test_acc: 0.5750
# Epoch: 19 | train_loss: 0.9652 | train_acc: 0.6848 | test_loss: 1.2804 | test_acc: 0.5333
# Epoch: 20 | train_loss: 0.9450 | train_acc: 0.6913 | test_loss: 1.3538 | test_acc: 0.5229
# Epoch: 21 | train_loss: 0.9974 | train_acc: 0.6546 | test_loss: 1.2955 | test_acc: 0.5542
# Epoch: 22 | train_loss: 0.9592 | train_acc: 0.6765 | test_loss: 1.4312 | test_acc: 0.5396
# Epoch: 23 | train_loss: 0.9918 | train_acc: 0.6700 | test_loss: 1.3289 | test_acc: 0.5208
# Epoch: 24 | train_loss: 0.9065 | train_acc: 0.6979 | test_loss: 1.3139 | test_acc: 0.5208
# Epoch: 25 | train_loss: 0.8359 | train_acc: 0.7357 | test_loss: 1.2791 | test_acc: 0.5687
# Epoch: 26 | train_loss: 0.8537 | train_acc: 0.7237 | test_loss: 1.3064 | test_acc: 0.5792
# Epoch: 27 | train_loss: 0.8689 | train_acc: 0.7253 | test_loss: 1.2888 | test_acc: 0.5917
# Epoch: 28 | train_loss: 0.8016 | train_acc: 0.7434 | test_loss: 1.3209 | test_acc: 0.5437
# Epoch: 29 | train_loss: 0.8266 | train_acc: 0.7368 | test_loss: 1.4048 | test_acc: 0.4833
# Epoch: 30 | train_loss: 0.7998 | train_acc: 0.7538 | test_loss: 1.3733 | test_acc: 0.5375
# Epoch: 31 | train_loss: 0.8422 | train_acc: 0.7292 | test_loss: 1.4087 | test_acc: 0.4875
# Epoch: 32 | train_loss: 0.7629 | train_acc: 0.7599 | test_loss: 1.2980 | test_acc: 0.5250
# Epoch: 33 | train_loss: 0.7244 | train_acc: 0.7851 | test_loss: 1.2949 | test_acc: 0.5292
# Epoch: 34 | train_loss: 0.6960 | train_acc: 0.7851 | test_loss: 1.3230 | test_acc: 0.5312
# Epoch: 35 | train_loss: 0.6676 | train_acc: 0.7950 | test_loss: 1.3020 | test_acc: 0.5583
# Epoch: 36 | train_loss: 0.6369 | train_acc: 0.8059 | test_loss: 1.3460 | test_acc: 0.5271
# Epoch: 37 | train_loss: 0.6432 | train_acc: 0.8081 | test_loss: 1.3746 | test_acc: 0.5479
# Epoch: 38 | train_loss: 0.7299 | train_acc: 0.7626 | test_loss: 1.2818 | test_acc: 0.6104
# Epoch: 39 | train_loss: 0.6534 | train_acc: 0.7999 | test_loss: 1.2650 | test_acc: 0.5750
# Epoch: 40 | train_loss: 0.6033 | train_acc: 0.8196 | test_loss: 1.2820 | test_acc: 0.5750
# Epoch: 41 | train_loss: 0.6128 | train_acc: 0.8224 | test_loss: 1.3297 | test_acc: 0.5521
# Epoch: 42 | train_loss: 0.5634 | train_acc: 0.8388 | test_loss: 1.3205 | test_acc: 0.5813
# Epoch: 43 | train_loss: 0.6319 | train_acc: 0.8130 | test_loss: 1.8298 | test_acc: 0.4583
# Epoch: 44 | train_loss: 0.8547 | train_acc: 0.7237 | test_loss: 1.3199 | test_acc: 0.5563
# Epoch: 45 | train_loss: 0.6590 | train_acc: 0.7961 | test_loss: 1.3782 | test_acc: 0.5271
# Epoch: 46 | train_loss: 0.5932 | train_acc: 0.8229 | test_loss: 1.3761 | test_acc: 0.5167
# Epoch: 47 | train_loss: 0.5761 | train_acc: 0.8246 | test_loss: 1.3045 | test_acc: 0.5625
# Epoch: 48 | train_loss: 0.5224 | train_acc: 0.8564 | test_loss: 1.3559 | test_acc: 0.5292
# Epoch: 49 | train_loss: 0.5705 | train_acc: 0.8262 | test_loss: 1.2994 | test_acc: 0.5833
# Epoch: 50 | train_loss: 0.5368 | train_acc: 0.8366 | test_loss: 1.2582 | test_acc: 0.5729
# Epoch: 51 | train_loss: 0.5568 | train_acc: 0.8257 | test_loss: 1.3734 | test_acc: 0.5375
# Epoch: 52 | train_loss: 0.5315 | train_acc: 0.8481 | test_loss: 1.3367 | test_acc: 0.5750
# Epoch: 53 | train_loss: 0.4659 | train_acc: 0.8673 | test_loss: 1.3128 | test_acc: 0.5917
# Epoch: 54 | train_loss: 0.4372 | train_acc: 0.8816 | test_loss: 1.3078 | test_acc: 0.5708
# Epoch: 55 | train_loss: 0.4268 | train_acc: 0.8766 | test_loss: 1.3136 | test_acc: 0.5687
# Epoch: 56 | train_loss: 0.4747 | train_acc: 0.8586 | test_loss: 1.3140 | test_acc: 0.5896
# Epoch: 57 | train_loss: 0.5712 | train_acc: 0.8229 | test_loss: 1.5048 | test_acc: 0.5062
# Epoch: 58 | train_loss: 0.7079 | train_acc: 0.7664 | test_loss: 1.4770 | test_acc: 0.4854
# Epoch: 59 | train_loss: 0.5586 | train_acc: 0.8262 | test_loss: 1.3733 | test_acc: 0.5417
# Epoch: 60 | train_loss: 0.5050 | train_acc: 0.8498 | test_loss: 1.3542 | test_acc: 0.5708
# Epoch: 61 | train_loss: 0.4639 | train_acc: 0.8712 | test_loss: 1.4327 | test_acc: 0.5687
# Epoch: 62 | train_loss: 0.4063 | train_acc: 0.8953 | test_loss: 1.4042 | test_acc: 0.5708
# Epoch: 63 | train_loss: 0.3761 | train_acc: 0.9002 | test_loss: 1.4225 | test_acc: 0.5875
# Epoch: 64 | train_loss: 0.9716 | train_acc: 0.7379 | test_loss: 1.9783 | test_acc: 0.4250
# Epoch: 65 | train_loss: 1.1272 | train_acc: 0.6541 | test_loss: 1.6262 | test_acc: 0.4458
# Epoch: 66 | train_loss: 0.8257 | train_acc: 0.7188 | test_loss: 1.4715 | test_acc: 0.5104
# Epoch: 67 | train_loss: 0.6461 | train_acc: 0.8004 | test_loss: 1.4321 | test_acc: 0.5292
# Epoch: 68 | train_loss: 0.5833 | train_acc: 0.8147 | test_loss: 1.4029 | test_acc: 0.5500
# Epoch: 69 | train_loss: 0.5262 | train_acc: 0.8432 | test_loss: 1.4932 | test_acc: 0.5188
# Epoch: 70 | train_loss: 0.4856 | train_acc: 0.8596 | test_loss: 1.4296 | test_acc: 0.5354
# Epoch: 71 | train_loss: 0.4536 | train_acc: 0.8679 | test_loss: 1.4246 | test_acc: 0.5500
# Epoch: 72 | train_loss: 0.4256 | train_acc: 0.8772 | test_loss: 1.4016 | test_acc: 0.5708
# Epoch: 73 | train_loss: 0.4065 | train_acc: 0.8854 | test_loss: 1.4783 | test_acc: 0.5167
# Epoch: 74 | train_loss: 0.4174 | train_acc: 0.8805 | test_loss: 1.4529 | test_acc: 0.5333
# Epoch: 75 | train_loss: 0.4928 | train_acc: 0.8443 | test_loss: 1.3539 | test_acc: 0.5479
# Epoch: 76 | train_loss: 0.5301 | train_acc: 0.8322 | test_loss: 1.3567 | test_acc: 0.5792
# Epoch: 77 | train_loss: 0.4325 | train_acc: 0.8745 | test_loss: 1.4014 | test_acc: 0.5479
# Epoch: 78 | train_loss: 0.3988 | train_acc: 0.8788 | test_loss: 1.4047 | test_acc: 0.5479
# Epoch: 79 | train_loss: 0.3800 | train_acc: 0.8931 | test_loss: 1.4699 | test_acc: 0.5375
# Epoch: 80 | train_loss: 0.3589 | train_acc: 0.9002 | test_loss: 1.4871 | test_acc: 0.5354
# Epoch: 81 | train_loss: 0.3256 | train_acc: 0.9084 | test_loss: 1.5192 | test_acc: 0.5333
# Epoch: 82 | train_loss: 0.3822 | train_acc: 0.8953 | test_loss: 1.5027 | test_acc: 0.5479
# Epoch: 83 | train_loss: 0.3470 | train_acc: 0.9095 | test_loss: 1.5295 | test_acc: 0.5167
# Epoch: 84 | train_loss: 0.3721 | train_acc: 0.8958 | test_loss: 1.5075 | test_acc: 0.5292
# Epoch: 85 | train_loss: 0.3177 | train_acc: 0.9156 | test_loss: 1.5486 | test_acc: 0.5104
# Epoch: 86 | train_loss: 0.3104 | train_acc: 0.9161 | test_loss: 1.5458 | test_acc: 0.5292
# Epoch: 87 | train_loss: 0.2956 | train_acc: 0.9189 | test_loss: 1.6212 | test_acc: 0.5229
# Epoch: 88 | train_loss: 0.2946 | train_acc: 0.9172 | test_loss: 1.6983 | test_acc: 0.5271
# Epoch: 89 | train_loss: 0.2866 | train_acc: 0.9194 | test_loss: 1.7515 | test_acc: 0.4896
# Epoch: 90 | train_loss: 0.3911 | train_acc: 0.8838 | test_loss: 1.5835 | test_acc: 0.5167
# Epoch: 91 | train_loss: 0.6125 | train_acc: 0.8081 | test_loss: 1.5717 | test_acc: 0.5104
# Epoch: 92 | train_loss: 0.4566 | train_acc: 0.8492 | test_loss: 1.4463 | test_acc: 0.5646
# Epoch: 93 | train_loss: 0.3925 | train_acc: 0.8788 | test_loss: 1.4212 | test_acc: 0.5667
# Epoch: 94 | train_loss: 0.5673 | train_acc: 0.8169 | test_loss: 1.6694 | test_acc: 0.4917
# Epoch: 95 | train_loss: 0.5822 | train_acc: 0.8141 | test_loss: 1.5195 | test_acc: 0.5188
# Epoch: 96 | train_loss: 0.4459 | train_acc: 0.8618 | test_loss: 1.4649 | test_acc: 0.5500
# Epoch: 97 | train_loss: 0.3526 | train_acc: 0.8991 | test_loss: 1.5259 | test_acc: 0.5125
# Epoch: 98 | train_loss: 0.3255 | train_acc: 0.9106 | test_loss: 1.5794 | test_acc: 0.5292
# Epoch: 99 | train_loss: 0.2992 | train_acc: 0.9172 | test_loss: 1.5860 | test_acc: 0.5521
# Epoch: 100 | train_loss: 0.2826 | train_acc: 0.9271 | test_loss: 1.5312 | test_acc: 0.5500
# Total training time: 133.358 seconds

# %%
# Plotting the results of model_2
plot_loss_curves(model_2_results, Save=True, filename="model_2_training")

# %% [markdown]
# The LSTM model appears to be performing better than the RNN on our problem. Overfitting occurs here as well. However, the accuracy scores are much better than the ones of the RNN.

# %% [markdown]
# ## 8. Building a basic GRU model
#
# The GRU cell is a simplified version of an LSTM cell. There is not a seperate output for the long-term memory state. The whole state is output at every timestep. As a result, there is no need to define an initial cell state in the `forward()` method, like in the LSTM. PyTorch includes a `GRU()` layer that works like the `RNN()` and the `LSTM()` class. So all in all, the GRU class that we are going to build is identical to the RNN. Only difference is using the `GRU()` layer, instead of the `RNN()`.
#
# After building the class and instantiatiing a model, we follow the same pipeline as before in order to train the model and plot the results for evaluation.

# %%
# Building a GRU model
INPUT_SIZE = 128 # number of mel_bands
HIDDEN_SIZE = 128 # number of neurons that the hidden state has
NUM_LAYERS = 2 # number of stacked GRU layers that are going to be used
NUM_CLASSES = 10

class GRUClassifierV0(nn.Module):
    def __init__(self, input_size=INPUT_SIZE,
                 hidden_size=HIDDEN_SIZE,
                 num_layers=NUM_LAYERS,
                 num_classes=NUM_CLASSES):
        super().__init__()

        # defining the attributes here, in order to use them later in the forward() method
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # defining the network layers
        self.gru = nn.GRU(input_size,
                          hidden_size,
                          num_layers,
                          batch_first=True)
        self.fc = nn.Linear(hidden_size, # using the hidden_size here because only the last hidden state will be used
                            num_classes)

    def forward(self, x):
        # an initial hidden state must be used first.
        # The dimensions/arguments we set it to have are predifined by PyTorch.
        h0 = torch.zeros(self.num_layers,
                         x.size(0),
                         self.hidden_size).to(device)

        # Forward propagate RNN
        out, _ = self.gru(x, h0)
        # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = out[:, -1, :]

        # pass through the fully connected layer, to produce logits for 10 classes by mapping last hidden state to output classes
        out = self.fc(out)
        return out

# %%
# # Building the gru version of the paper RNN -ONLY LAST HIDDEN STATE-
#
# INPUT_SIZE = 13 # number of mfccs
# HIDDEN_SIZE = 128 # number of neurons that the hidden state has
# NUM_LAYERS = 2 # number of stacked RNN layers that are going to be used
# NUM_CLASSES = 10
#
# class GRUClassifierV1(nn.Module):
#     def __init__(self, input_size=13, num_classes=10):
#         super().__init__()
#
#         # defining the network layers
#         self.gru1 = nn.GRU(input_size,
#                           128,
#                           num_layers=1,
#                           batch_first=True)
#
#         self.gru2 = nn.GRU(128,
#                           64,
#                           num_layers=1,
#                           batch_first=True)
#
#         # Dropouts
#         self.dropout1 = nn.Dropout(0.3)
#         self.dropout2 = nn.Dropout(0.3)
#
#         # Fully connected layers
#         self.fc1 = nn.Linear(64, 64)
#         self.fc2 = nn.Linear(64, num_classes)
#
#     def forward(self, x):
#         batch_size = x.size(0)
#
#         # Initial states for GRU 1
#         h0_1 = torch.zeros(1, batch_size, 128).to(x.device)
#
#         # Forward propagate GRU 1
#         out, _ = self.gru1(x, h0_1)
#
#         # Initial states for RNN 2
#         h0_2 = torch.zeros(1, batch_size, 64).to(x.device)
#
#         # Forward propagate RNN 1
#         out, _ = self.gru2(out, h0_2)
#
#         # Decode the hidden state of the last time step
#         out = out[:, -1, :]
#
#         out = self.dropout1(out)
#         out = self.fc1(out)
#         out = self.dropout2(out)
#         out = self.fc2(out)
#
#         return out

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_3 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instatiating the paper version of the GRU
# model_3 = GRUClassifierV1().to(device)
model_3
# Out:
# GRUClassifierV0(
#   (gru): GRU(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Extracting a sample and testing it with a forward pass
example, _ = next(iter(train_dataloader))
model_3.eval()
print(model_3(example.to(device))[:5])
# Out:
# tensor([[ 0.0530, -0.3019,  0.1877,  0.3386, -0.1447, -0.0117,  0.3211, -0.3412,
#          -0.2016,  0.0094],
#         [-0.1710,  0.3039,  0.0105, -0.5780,  0.0303,  0.0599,  0.3457, -0.1706,
#          -0.6562,  0.3198],
#         [-0.2066, -0.0679,  0.3368, -0.2684,  0.1194,  0.0732,  0.3339, -0.4243,
#          -0.3993,  0.4048],
#         [-0.4180,  0.0971,  0.3860, -0.3492, -0.0608, -0.1654,  0.2113, -0.3723,
#          -0.3881,  0.2949],
#         [-0.2377,  0.0342,  0.5155, -0.0267,  0.0306, -0.2040,  0.2062, -0.4442,
#          -0.0834,  0.4022]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_3.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # optimizer used in model from paper according to the specs there
# optimizer = torch.optim.Adam(model_3.parameters(),
#                              lr=0.001)

# %%
# Training model_3
# Set number of epochs
NUM_EPOCHS = 100

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_3
model_3_results = train(model=model_3,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.1894 | train_acc: 0.2209 | test_loss: 2.0943 | test_acc: 0.2437
# Epoch: 2 | train_loss: 1.9999 | train_acc: 0.3098 | test_loss: 1.9517 | test_acc: 0.3417
# Epoch: 3 | train_loss: 1.8663 | train_acc: 0.3586 | test_loss: 1.8528 | test_acc: 0.3667
# Epoch: 4 | train_loss: 1.7616 | train_acc: 0.3991 | test_loss: 1.7687 | test_acc: 0.3729
# Epoch: 5 | train_loss: 1.6659 | train_acc: 0.4128 | test_loss: 1.7121 | test_acc: 0.3521
# Epoch: 6 | train_loss: 1.5861 | train_acc: 0.4518 | test_loss: 1.6664 | test_acc: 0.3792
# Epoch: 7 | train_loss: 1.5103 | train_acc: 0.4836 | test_loss: 1.6220 | test_acc: 0.3833
# Epoch: 8 | train_loss: 1.4301 | train_acc: 0.5241 | test_loss: 1.5721 | test_acc: 0.4042
# Epoch: 9 | train_loss: 1.3680 | train_acc: 0.5367 | test_loss: 1.5327 | test_acc: 0.4271
# Epoch: 10 | train_loss: 1.3004 | train_acc: 0.5680 | test_loss: 1.4964 | test_acc: 0.4354
# Epoch: 11 | train_loss: 1.2227 | train_acc: 0.5981 | test_loss: 1.4685 | test_acc: 0.4375
# Epoch: 12 | train_loss: 1.1504 | train_acc: 0.6245 | test_loss: 1.4540 | test_acc: 0.4542
# Epoch: 13 | train_loss: 1.0726 | train_acc: 0.6491 | test_loss: 1.4768 | test_acc: 0.4562
# Epoch: 14 | train_loss: 1.0121 | train_acc: 0.6732 | test_loss: 1.4606 | test_acc: 0.4729
# Epoch: 15 | train_loss: 0.9471 | train_acc: 0.6941 | test_loss: 1.4504 | test_acc: 0.4750
# Epoch: 16 | train_loss: 0.8825 | train_acc: 0.7275 | test_loss: 1.3887 | test_acc: 0.5000
# Epoch: 17 | train_loss: 0.8153 | train_acc: 0.7478 | test_loss: 1.4286 | test_acc: 0.4958
# Epoch: 18 | train_loss: 0.7728 | train_acc: 0.7675 | test_loss: 1.3830 | test_acc: 0.4979
# Epoch: 19 | train_loss: 0.7259 | train_acc: 0.7780 | test_loss: 1.4285 | test_acc: 0.4896
# Epoch: 20 | train_loss: 0.6548 | train_acc: 0.8120 | test_loss: 1.3656 | test_acc: 0.5125
# Epoch: 21 | train_loss: 0.6155 | train_acc: 0.8235 | test_loss: 1.4111 | test_acc: 0.4958
# Epoch: 22 | train_loss: 0.5674 | train_acc: 0.8470 | test_loss: 1.3907 | test_acc: 0.5083
# Epoch: 23 | train_loss: 0.5270 | train_acc: 0.8569 | test_loss: 1.4629 | test_acc: 0.4958
# Epoch: 24 | train_loss: 0.4737 | train_acc: 0.8766 | test_loss: 1.4706 | test_acc: 0.5042
# Epoch: 25 | train_loss: 0.4374 | train_acc: 0.8898 | test_loss: 1.5027 | test_acc: 0.5125
# Epoch: 26 | train_loss: 0.4184 | train_acc: 0.8925 | test_loss: 1.4906 | test_acc: 0.5104
# Epoch: 27 | train_loss: 0.3958 | train_acc: 0.9013 | test_loss: 1.5147 | test_acc: 0.5104
# Epoch: 28 | train_loss: 0.3496 | train_acc: 0.9200 | test_loss: 1.5291 | test_acc: 0.5104
# Epoch: 29 | train_loss: 0.3498 | train_acc: 0.9095 | test_loss: 1.6522 | test_acc: 0.5062
# Epoch: 30 | train_loss: 0.3156 | train_acc: 0.9293 | test_loss: 1.5303 | test_acc: 0.5083
# Epoch: 31 | train_loss: 0.3410 | train_acc: 0.9057 | test_loss: 1.6331 | test_acc: 0.5104
# Epoch: 32 | train_loss: 0.2681 | train_acc: 0.9424 | test_loss: 1.5636 | test_acc: 0.5167
# Epoch: 33 | train_loss: 0.2346 | train_acc: 0.9539 | test_loss: 1.6545 | test_acc: 0.5125
# Epoch: 34 | train_loss: 0.2376 | train_acc: 0.9501 | test_loss: 1.7579 | test_acc: 0.5083
# Epoch: 35 | train_loss: 0.1922 | train_acc: 0.9594 | test_loss: 1.6661 | test_acc: 0.5229
# Epoch: 36 | train_loss: 0.3974 | train_acc: 0.8920 | test_loss: 1.8467 | test_acc: 0.4896
# Epoch: 37 | train_loss: 0.3610 | train_acc: 0.8997 | test_loss: 1.6346 | test_acc: 0.5208
# Epoch: 38 | train_loss: 0.2356 | train_acc: 0.9468 | test_loss: 1.6839 | test_acc: 0.5250
# Epoch: 39 | train_loss: 0.1935 | train_acc: 0.9666 | test_loss: 1.7186 | test_acc: 0.5208
# Epoch: 40 | train_loss: 0.1679 | train_acc: 0.9704 | test_loss: 1.5799 | test_acc: 0.5167
# Epoch: 41 | train_loss: 0.1477 | train_acc: 0.9726 | test_loss: 1.7581 | test_acc: 0.5167
# Epoch: 42 | train_loss: 0.1432 | train_acc: 0.9715 | test_loss: 1.7455 | test_acc: 0.5271
# Epoch: 43 | train_loss: 0.1265 | train_acc: 0.9775 | test_loss: 1.7787 | test_acc: 0.5125
# Epoch: 44 | train_loss: 0.1088 | train_acc: 0.9846 | test_loss: 1.8154 | test_acc: 0.5125
# Epoch: 45 | train_loss: 0.1077 | train_acc: 0.9819 | test_loss: 1.8499 | test_acc: 0.5208
# Epoch: 46 | train_loss: 0.0885 | train_acc: 0.9868 | test_loss: 1.8955 | test_acc: 0.5146
# Epoch: 47 | train_loss: 0.0784 | train_acc: 0.9901 | test_loss: 1.8846 | test_acc: 0.5188
# Epoch: 48 | train_loss: 0.0685 | train_acc: 0.9918 | test_loss: 1.9454 | test_acc: 0.5042
# Epoch: 49 | train_loss: 0.0883 | train_acc: 0.9830 | test_loss: 1.8623 | test_acc: 0.5188
# Epoch: 50 | train_loss: 0.2031 | train_acc: 0.9419 | test_loss: 1.8479 | test_acc: 0.5167
# Epoch: 51 | train_loss: 0.1106 | train_acc: 0.9764 | test_loss: 1.8566 | test_acc: 0.5083
# Epoch: 52 | train_loss: 0.0843 | train_acc: 0.9863 | test_loss: 1.8947 | test_acc: 0.5146
# Epoch: 53 | train_loss: 0.0556 | train_acc: 0.9940 | test_loss: 1.9106 | test_acc: 0.5104
# Epoch: 54 | train_loss: 0.0490 | train_acc: 0.9945 | test_loss: 1.9123 | test_acc: 0.5250
# Epoch: 55 | train_loss: 0.0440 | train_acc: 0.9962 | test_loss: 1.9699 | test_acc: 0.5104
# Epoch: 56 | train_loss: 0.0400 | train_acc: 0.9962 | test_loss: 1.9786 | test_acc: 0.5167
# Epoch: 57 | train_loss: 0.0364 | train_acc: 0.9967 | test_loss: 2.0328 | test_acc: 0.5167
# Epoch: 58 | train_loss: 0.0341 | train_acc: 0.9973 | test_loss: 2.0481 | test_acc: 0.5146
# Epoch: 59 | train_loss: 0.0323 | train_acc: 0.9984 | test_loss: 2.1146 | test_acc: 0.5083
# Epoch: 60 | train_loss: 0.0397 | train_acc: 0.9956 | test_loss: 2.0412 | test_acc: 0.5042
# Epoch: 61 | train_loss: 0.0443 | train_acc: 0.9912 | test_loss: 2.0555 | test_acc: 0.5208
# Epoch: 62 | train_loss: 0.0380 | train_acc: 0.9973 | test_loss: 2.1021 | test_acc: 0.5062
# Epoch: 63 | train_loss: 0.0318 | train_acc: 0.9956 | test_loss: 1.9961 | test_acc: 0.5250
# Epoch: 64 | train_loss: 0.0428 | train_acc: 0.9940 | test_loss: 2.0037 | test_acc: 0.5021
# Epoch: 65 | train_loss: 0.2557 | train_acc: 0.9254 | test_loss: 2.0184 | test_acc: 0.5125
# Epoch: 66 | train_loss: 0.2396 | train_acc: 0.9227 | test_loss: 2.0431 | test_acc: 0.4958
# Epoch: 67 | train_loss: 0.0890 | train_acc: 0.9836 | test_loss: 1.9355 | test_acc: 0.4875
# Epoch: 68 | train_loss: 0.0715 | train_acc: 0.9885 | test_loss: 1.8972 | test_acc: 0.5021
# Epoch: 69 | train_loss: 0.0494 | train_acc: 0.9929 | test_loss: 1.8538 | test_acc: 0.5437
# Epoch: 70 | train_loss: 0.0317 | train_acc: 0.9989 | test_loss: 1.9957 | test_acc: 0.5021
# Epoch: 71 | train_loss: 0.0267 | train_acc: 0.9995 | test_loss: 1.9847 | test_acc: 0.5042
# Epoch: 72 | train_loss: 0.0243 | train_acc: 0.9989 | test_loss: 1.9501 | test_acc: 0.5042
# Epoch: 73 | train_loss: 0.0218 | train_acc: 0.9995 | test_loss: 2.1179 | test_acc: 0.5021
# Epoch: 74 | train_loss: 0.0202 | train_acc: 0.9989 | test_loss: 2.1268 | test_acc: 0.5021
# Epoch: 75 | train_loss: 0.0187 | train_acc: 0.9989 | test_loss: 2.1495 | test_acc: 0.5042
# Epoch: 76 | train_loss: 0.0174 | train_acc: 0.9995 | test_loss: 2.1695 | test_acc: 0.5062
# Epoch: 77 | train_loss: 0.0169 | train_acc: 0.9989 | test_loss: 2.1626 | test_acc: 0.5042
# Epoch: 78 | train_loss: 0.0156 | train_acc: 0.9995 | test_loss: 2.2322 | test_acc: 0.5021
# Epoch: 79 | train_loss: 0.0149 | train_acc: 0.9995 | test_loss: 2.2256 | test_acc: 0.5042
# Epoch: 80 | train_loss: 0.0144 | train_acc: 0.9995 | test_loss: 2.2848 | test_acc: 0.5042
# Epoch: 81 | train_loss: 0.0135 | train_acc: 0.9989 | test_loss: 2.2871 | test_acc: 0.5000
# Epoch: 82 | train_loss: 0.0126 | train_acc: 0.9995 | test_loss: 2.2958 | test_acc: 0.5000
# Epoch: 83 | train_loss: 0.0119 | train_acc: 0.9995 | test_loss: 2.3241 | test_acc: 0.5000
# Epoch: 84 | train_loss: 0.0113 | train_acc: 0.9995 | test_loss: 2.3224 | test_acc: 0.5042
# Epoch: 85 | train_loss: 0.0108 | train_acc: 0.9995 | test_loss: 2.3533 | test_acc: 0.5042
# Epoch: 86 | train_loss: 0.0110 | train_acc: 0.9989 | test_loss: 2.3707 | test_acc: 0.5062
# Epoch: 87 | train_loss: 0.0102 | train_acc: 0.9995 | test_loss: 2.3343 | test_acc: 0.5104
# Epoch: 88 | train_loss: 0.0098 | train_acc: 0.9989 | test_loss: 2.3534 | test_acc: 0.5104
# Epoch: 89 | train_loss: 0.0093 | train_acc: 0.9995 | test_loss: 2.4191 | test_acc: 0.5104
# Epoch: 90 | train_loss: 0.0088 | train_acc: 0.9995 | test_loss: 2.3881 | test_acc: 0.5146
# Epoch: 91 | train_loss: 0.0086 | train_acc: 0.9989 | test_loss: 2.3920 | test_acc: 0.5146
# Epoch: 92 | train_loss: 0.0082 | train_acc: 0.9989 | test_loss: 2.4379 | test_acc: 0.5188
# Epoch: 93 | train_loss: 0.0097 | train_acc: 0.9989 | test_loss: 2.4072 | test_acc: 0.5271
# Epoch: 94 | train_loss: 0.1283 | train_acc: 0.9655 | test_loss: 2.3855 | test_acc: 0.5042
# Epoch: 95 | train_loss: 0.2074 | train_acc: 0.9342 | test_loss: 2.3529 | test_acc: 0.4958
# Epoch: 96 | train_loss: 0.0982 | train_acc: 0.9737 | test_loss: 2.2455 | test_acc: 0.5188
# Epoch: 97 | train_loss: 0.1129 | train_acc: 0.9649 | test_loss: 2.2518 | test_acc: 0.5146
# Epoch: 98 | train_loss: 0.0330 | train_acc: 0.9956 | test_loss: 2.2815 | test_acc: 0.5188
# Epoch: 99 | train_loss: 0.0809 | train_acc: 0.9748 | test_loss: 2.0689 | test_acc: 0.5354
# Epoch: 100 | train_loss: 0.0520 | train_acc: 0.9879 | test_loss: 2.0729 | test_acc: 0.5167
# Total training time: 91.635 seconds

# %%
# Plotting the results of model_3
plot_loss_curves(model_3_results, Save=True, filename="model_3_training")

# %% [markdown]
# The GRU model appears to perform worse than the LSTM. The loss values appear to increase after 20 epochs. Also, the model seems to adapt to the training data after some point.

# %% [markdown]
# ## 9. Using Data Augmentation
#
# For our next models we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.
#
# We are going to train an RNN with only the last hidden state, an LSTM and a GRU model.

# %% [markdown]
# ### 9.1 Implementing `TimeMasking()` and `FrequencyMasking()` on the data
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and coefficients respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
#
# > The `TimeMasking()` transform, "masks" the entire x-axis for a specific amount. A good option would be to mask 15% of the sample. The *time_mask_param* is responsible for the amount of time frames that will be masked. We are calculating this value and setting it in the `TimeMasking()` transform.
# >> __In case we divide the original GTZAN samples into 3 segments__: Our x-axis normally represents the time frames and we know that each sample has 997 time frames. We are going to mask 150 frames which is approximately 15% of the sample. This is done by setting the *time_mask_param* to 150. That means that maximum 150 consecutive frames will be masked.
#
# > The `FrequencyMasking()` transform, "masks" the entire y-axis for a specific amount. A good option would be to mask 12% of the sample. The *freq_mask_param* is responsible for the amount of mel bands that will be masked. We are calculating this value and setting it in the `FrequencyMasking()` transform.
# >> __In case we divide the original GTZAN samples into 3 segments__: Our y-axis normally is the mel bands and we know that each sample has 128 mel bands. We are going to mask 15 frames which is approximately 12% of the sample. This is done by setting the *freq_mask_param* to 15. That means that maximum 15 consecutive frames will be masked.
#
# The masked spectrogram are presented, to have a visualization of the augmented data. Similar methods of masking on log mel spectrogram directly are mentioned in the SpecAugment paper. More info here - https://arxiv.org/pdf/1904.08779
#
# _**Notice**: The time_mask_param and freq_mask_param will set the **maximum** amount of time_frames/mel_bands that will be masked. This number will be random on each epoch._

# %% [markdown]
# In the case of our recurrent models, we have to take notice of the fact that the shape of our audio representations is "inverted". This means that according to our tensor shape which is `(time_frames, mel_bands)`, the x-axis corresponds to the time frames and the y-axis corresponds to the mel-bands. However, the `TimeMasking()` and `FrequencyMasking()` methods expect the opposite. In order to make up for this difference, we write:
# ```
# time_mask_param = round(mel_bands * 0.15)
# freq_mask_param = round(time_frames * 0.12)
# ```
# In this manner, we include the number of `mel_bands` in the calculation of the `time_mask_param`, as well as the number of `time_frames` in the calculation of the `freq_mask_param`.

# %%
# Calculating the proper time_mask_param and freq_mask_param values
mel_bands = inputs.shape[2]
time_frames = inputs.shape[1]

# In the case of RNNs, the shape is "reversed"
# instead of (mel_band, time_frame), we have (time_frame, mel_band).
# As a result, the "time_mask_param" of the masking augmentation will correspond to the mel_bands
# and the "freq_mask_param" will correspond to the "time_frames"
time_mask_param = round(mel_bands * 0.15)
freq_mask_param = round(time_frames * 0.12)

time_mask_param, freq_mask_param
# Out:
# (19, 120)

# %%
# Creating time masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
time_masking = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
time_masked_data = time_masking(X[INDEX].squeeze()).to('cpu')
time_masked_data.shape
# Out:
# torch.Size([997, 128])

# %%
# Creating frequency masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
freq_masking = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
freq_masked_data = freq_masking(X[INDEX].squeeze()).to('cpu')
freq_masked_data.shape
# Out:
# torch.Size([997, 128])

# %%
# Visualize data
time_masked_melspec_example = time_masked_data.numpy()
freq_masked_melspec_example = freq_masked_data.numpy()

fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharex=True, sharey=True)
im0 = axes[0].imshow(time_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[0].set_title("Frequency-masked Mel Spectrogram")
axes[0].set_ylabel("Mel Bands")
fig.colorbar(im0, ax=axes[0])

im1 = axes[1].imshow(freq_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[1].set_title("Frequency-masked Mel Spectrogram")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Mel Bands")
fig.colorbar(im1, ax=axes[1])

fig.tight_layout()
plt.show()

# %% [markdown]
# ### 9.2 Creating training functions for data augmentation
# We are going to create a new `train_step_with_augmentation()` and `train_with_augmentation` functions by altering our previous training functions in order to train the model with the augmented data. There is no need to use augmentation in validation and testing sets. The rest of the pipeline is the same. In the end we are going to plot the results to see if there is improvement.

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=time_mask_param),
    T.FrequencyMasking(freq_mask_param=freq_mask_param)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
     ):

    # Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
        ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ### 9.3 Training the RNN model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_4 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating RNN model from paper
# model_4 = RNNClassifierV2().to(device)
model_4
# Out:
# RNNClassifierV0(
#   (rnn): RNN(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_4.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in RNN from paper
# optimizer = torch.optim.Adam(model_4.parameters(),
#                              lr=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_4_results = train_with_augmentation(model=model_4,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2333 | train_acc: 0.1897 | test_loss: 2.1237 | test_acc: 0.2375
# Epoch: 2 | train_loss: 2.0687 | train_acc: 0.2747 | test_loss: 2.0073 | test_acc: 0.2729
# Epoch: 3 | train_loss: 1.9819 | train_acc: 0.2971 | test_loss: 1.9333 | test_acc: 0.3042
# Epoch: 4 | train_loss: 1.9172 | train_acc: 0.3114 | test_loss: 1.8794 | test_acc: 0.3146
# Epoch: 5 | train_loss: 1.8691 | train_acc: 0.3289 | test_loss: 1.8405 | test_acc: 0.3042
# Epoch: 6 | train_loss: 1.8225 | train_acc: 0.3542 | test_loss: 1.7963 | test_acc: 0.3875
# Epoch: 7 | train_loss: 1.7942 | train_acc: 0.3651 | test_loss: 1.7858 | test_acc: 0.3979
# Epoch: 8 | train_loss: 1.7481 | train_acc: 0.3777 | test_loss: 1.7494 | test_acc: 0.3792
# Epoch: 9 | train_loss: 1.7201 | train_acc: 0.3827 | test_loss: 1.7319 | test_acc: 0.3729
# Epoch: 10 | train_loss: 1.6932 | train_acc: 0.4150 | test_loss: 1.7354 | test_acc: 0.3333
# Epoch: 11 | train_loss: 1.6669 | train_acc: 0.4128 | test_loss: 1.7229 | test_acc: 0.3708
# Epoch: 12 | train_loss: 1.6618 | train_acc: 0.4211 | test_loss: 1.7138 | test_acc: 0.3375
# Epoch: 13 | train_loss: 1.6238 | train_acc: 0.4380 | test_loss: 1.7121 | test_acc: 0.3521
# Epoch: 14 | train_loss: 1.6079 | train_acc: 0.4298 | test_loss: 1.7007 | test_acc: 0.3625
# Epoch: 15 | train_loss: 1.5958 | train_acc: 0.4386 | test_loss: 1.7376 | test_acc: 0.3625
# Epoch: 16 | train_loss: 1.5976 | train_acc: 0.4446 | test_loss: 1.7036 | test_acc: 0.3583
# Epoch: 17 | train_loss: 1.5386 | train_acc: 0.4512 | test_loss: 1.6967 | test_acc: 0.3833
# Epoch: 18 | train_loss: 1.5567 | train_acc: 0.4468 | test_loss: 1.6882 | test_acc: 0.3771
# Epoch: 19 | train_loss: 1.5141 | train_acc: 0.4715 | test_loss: 1.6931 | test_acc: 0.3688
# Epoch: 20 | train_loss: 1.4950 | train_acc: 0.4742 | test_loss: 1.6838 | test_acc: 0.3729
# Epoch: 21 | train_loss: 1.4609 | train_acc: 0.4973 | test_loss: 1.6775 | test_acc: 0.3854
# Epoch: 22 | train_loss: 1.4958 | train_acc: 0.4715 | test_loss: 1.6837 | test_acc: 0.3771
# Epoch: 23 | train_loss: 1.4611 | train_acc: 0.4874 | test_loss: 1.7123 | test_acc: 0.3688
# Epoch: 24 | train_loss: 1.4807 | train_acc: 0.4830 | test_loss: 1.6706 | test_acc: 0.3833
# Epoch: 25 | train_loss: 1.4271 | train_acc: 0.5016 | test_loss: 1.6525 | test_acc: 0.3854
# Epoch: 26 | train_loss: 1.4161 | train_acc: 0.5033 | test_loss: 1.6748 | test_acc: 0.4021
# Epoch: 27 | train_loss: 1.4141 | train_acc: 0.5011 | test_loss: 1.6541 | test_acc: 0.3688
# Epoch: 28 | train_loss: 1.4302 | train_acc: 0.5000 | test_loss: 1.6825 | test_acc: 0.3937
# Epoch: 29 | train_loss: 1.3913 | train_acc: 0.5164 | test_loss: 1.6697 | test_acc: 0.3812
# Epoch: 30 | train_loss: 1.3871 | train_acc: 0.5225 | test_loss: 1.6537 | test_acc: 0.3917
# Epoch: 31 | train_loss: 1.4628 | train_acc: 0.4995 | test_loss: 1.6805 | test_acc: 0.3833
# Epoch: 32 | train_loss: 1.3869 | train_acc: 0.5318 | test_loss: 1.6637 | test_acc: 0.3729
# Epoch: 33 | train_loss: 1.5356 | train_acc: 0.4868 | test_loss: 1.9476 | test_acc: 0.3271
# Epoch: 34 | train_loss: 1.5092 | train_acc: 0.4764 | test_loss: 1.6407 | test_acc: 0.3937
# Epoch: 35 | train_loss: 1.4303 | train_acc: 0.5099 | test_loss: 1.6380 | test_acc: 0.4042
# Epoch: 36 | train_loss: 1.4015 | train_acc: 0.5148 | test_loss: 1.6580 | test_acc: 0.4292
# Epoch: 37 | train_loss: 1.4053 | train_acc: 0.5093 | test_loss: 1.6518 | test_acc: 0.4062
# Epoch: 38 | train_loss: 1.3856 | train_acc: 0.5236 | test_loss: 1.6615 | test_acc: 0.4333
# Epoch: 39 | train_loss: 1.3339 | train_acc: 0.5428 | test_loss: 1.6335 | test_acc: 0.4125
# Epoch: 40 | train_loss: 1.3405 | train_acc: 0.5428 | test_loss: 1.6449 | test_acc: 0.4104
# Epoch: 41 | train_loss: 1.2807 | train_acc: 0.5620 | test_loss: 1.6619 | test_acc: 0.3937
# Epoch: 42 | train_loss: 1.2819 | train_acc: 0.5598 | test_loss: 1.6380 | test_acc: 0.4000
# Epoch: 43 | train_loss: 1.2884 | train_acc: 0.5647 | test_loss: 1.6424 | test_acc: 0.4125
# Epoch: 44 | train_loss: 1.2994 | train_acc: 0.5543 | test_loss: 1.6579 | test_acc: 0.4000
# Epoch: 45 | train_loss: 1.3309 | train_acc: 0.5389 | test_loss: 1.6740 | test_acc: 0.3937
# Epoch: 46 | train_loss: 1.2974 | train_acc: 0.5614 | test_loss: 1.6397 | test_acc: 0.4042
# Epoch: 47 | train_loss: 1.2729 | train_acc: 0.5685 | test_loss: 1.6258 | test_acc: 0.3979
# Epoch: 48 | train_loss: 1.2762 | train_acc: 0.5762 | test_loss: 1.6384 | test_acc: 0.3958
# Epoch: 49 | train_loss: 1.2455 | train_acc: 0.5795 | test_loss: 1.6312 | test_acc: 0.4000
# Epoch: 50 | train_loss: 1.2475 | train_acc: 0.5663 | test_loss: 1.6624 | test_acc: 0.4125
# Epoch: 51 | train_loss: 1.2016 | train_acc: 0.5959 | test_loss: 1.6616 | test_acc: 0.4125
# Epoch: 52 | train_loss: 1.2624 | train_acc: 0.5603 | test_loss: 1.6492 | test_acc: 0.4062
# Epoch: 53 | train_loss: 1.2141 | train_acc: 0.5883 | test_loss: 1.6459 | test_acc: 0.4125
# Epoch: 54 | train_loss: 1.2275 | train_acc: 0.5927 | test_loss: 1.6742 | test_acc: 0.3979
# Epoch: 55 | train_loss: 1.1728 | train_acc: 0.6179 | test_loss: 1.6671 | test_acc: 0.4188
# Epoch: 56 | train_loss: 1.1914 | train_acc: 0.6096 | test_loss: 1.6366 | test_acc: 0.4208
# Epoch: 57 | train_loss: 1.1675 | train_acc: 0.6058 | test_loss: 1.6288 | test_acc: 0.4188
# Epoch: 58 | train_loss: 1.1776 | train_acc: 0.5998 | test_loss: 1.6098 | test_acc: 0.4146
# Epoch: 59 | train_loss: 1.1556 | train_acc: 0.6250 | test_loss: 1.5982 | test_acc: 0.4250
# Epoch: 60 | train_loss: 1.2072 | train_acc: 0.5806 | test_loss: 1.6029 | test_acc: 0.4208
# Epoch: 61 | train_loss: 1.1511 | train_acc: 0.6064 | test_loss: 1.6308 | test_acc: 0.4146
# Epoch: 62 | train_loss: 1.1619 | train_acc: 0.6031 | test_loss: 1.6177 | test_acc: 0.4167
# Epoch: 63 | train_loss: 1.1442 | train_acc: 0.6064 | test_loss: 1.6039 | test_acc: 0.4375
# Epoch: 64 | train_loss: 1.1349 | train_acc: 0.6096 | test_loss: 1.6245 | test_acc: 0.4250
# Epoch: 65 | train_loss: 1.1446 | train_acc: 0.6173 | test_loss: 1.6071 | test_acc: 0.4417
# Epoch: 66 | train_loss: 1.1388 | train_acc: 0.6124 | test_loss: 1.5843 | test_acc: 0.4042
# Epoch: 67 | train_loss: 1.0960 | train_acc: 0.6338 | test_loss: 1.6478 | test_acc: 0.4104
# Epoch: 68 | train_loss: 1.1464 | train_acc: 0.6113 | test_loss: 1.5874 | test_acc: 0.4250
# Epoch: 69 | train_loss: 1.1010 | train_acc: 0.6414 | test_loss: 1.6400 | test_acc: 0.4125
# Epoch: 70 | train_loss: 1.0943 | train_acc: 0.6266 | test_loss: 1.5777 | test_acc: 0.4125
# Epoch: 71 | train_loss: 1.0542 | train_acc: 0.6409 | test_loss: 1.6257 | test_acc: 0.4188
# Epoch: 72 | train_loss: 1.1230 | train_acc: 0.6118 | test_loss: 1.6370 | test_acc: 0.4021
# Epoch: 73 | train_loss: 1.0781 | train_acc: 0.6442 | test_loss: 1.6114 | test_acc: 0.4042
# Epoch: 74 | train_loss: 1.0183 | train_acc: 0.6628 | test_loss: 1.6466 | test_acc: 0.4208
# Epoch: 75 | train_loss: 1.0585 | train_acc: 0.6453 | test_loss: 1.6287 | test_acc: 0.3979
# Epoch: 76 | train_loss: 1.0642 | train_acc: 0.6332 | test_loss: 1.6180 | test_acc: 0.4062
# Epoch: 77 | train_loss: 1.0516 | train_acc: 0.6338 | test_loss: 1.6145 | test_acc: 0.4167
# Epoch: 78 | train_loss: 1.0457 | train_acc: 0.6447 | test_loss: 1.6024 | test_acc: 0.4167
# Epoch: 79 | train_loss: 1.0755 | train_acc: 0.6332 | test_loss: 1.6156 | test_acc: 0.4437
# Epoch: 80 | train_loss: 1.0104 | train_acc: 0.6639 | test_loss: 1.6572 | test_acc: 0.4292
# Epoch: 81 | train_loss: 1.0088 | train_acc: 0.6612 | test_loss: 1.6422 | test_acc: 0.4125
# Epoch: 82 | train_loss: 1.0561 | train_acc: 0.6442 | test_loss: 1.6574 | test_acc: 0.4250
# Epoch: 83 | train_loss: 1.0260 | train_acc: 0.6552 | test_loss: 1.6468 | test_acc: 0.4167
# Epoch: 84 | train_loss: 0.9901 | train_acc: 0.6700 | test_loss: 1.6174 | test_acc: 0.4313
# Epoch: 85 | train_loss: 1.0081 | train_acc: 0.6683 | test_loss: 1.6040 | test_acc: 0.4313
# Epoch: 86 | train_loss: 1.0393 | train_acc: 0.6508 | test_loss: 1.5930 | test_acc: 0.4375
# Epoch: 87 | train_loss: 0.9804 | train_acc: 0.6700 | test_loss: 1.6492 | test_acc: 0.4229
# Epoch: 88 | train_loss: 0.9736 | train_acc: 0.6787 | test_loss: 1.6373 | test_acc: 0.4542
# Epoch: 89 | train_loss: 0.9535 | train_acc: 0.6804 | test_loss: 1.6684 | test_acc: 0.4208
# Epoch: 90 | train_loss: 0.9898 | train_acc: 0.6689 | test_loss: 1.6489 | test_acc: 0.4208
# Epoch: 91 | train_loss: 0.9609 | train_acc: 0.6870 | test_loss: 1.6861 | test_acc: 0.4062
# Epoch: 92 | train_loss: 0.9945 | train_acc: 0.6678 | test_loss: 1.6977 | test_acc: 0.4146
# Epoch: 93 | train_loss: 0.9444 | train_acc: 0.6826 | test_loss: 1.6309 | test_acc: 0.4229
# Epoch: 94 | train_loss: 0.9800 | train_acc: 0.6716 | test_loss: 1.7012 | test_acc: 0.4167
# Epoch: 95 | train_loss: 0.9440 | train_acc: 0.6880 | test_loss: 1.6561 | test_acc: 0.4333
# Epoch: 96 | train_loss: 0.9557 | train_acc: 0.6842 | test_loss: 1.6699 | test_acc: 0.4333
# Epoch: 97 | train_loss: 0.9447 | train_acc: 0.6968 | test_loss: 1.7262 | test_acc: 0.4333
# Epoch: 98 | train_loss: 0.9215 | train_acc: 0.6875 | test_loss: 1.6696 | test_acc: 0.4229
# Epoch: 99 | train_loss: 0.9121 | train_acc: 0.7018 | test_loss: 1.6611 | test_acc: 0.4375
# Epoch: 100 | train_loss: 0.9294 | train_acc: 0.6908 | test_loss: 1.6280 | test_acc: 0.4458
# Epoch: 101 | train_loss: 0.8915 | train_acc: 0.7001 | test_loss: 1.6928 | test_acc: 0.4354
# Epoch: 102 | train_loss: 0.8992 | train_acc: 0.7018 | test_loss: 1.7079 | test_acc: 0.4250
# Epoch: 103 | train_loss: 0.8975 | train_acc: 0.7061 | test_loss: 1.7513 | test_acc: 0.4021
# Epoch: 104 | train_loss: 0.9008 | train_acc: 0.6924 | test_loss: 1.6583 | test_acc: 0.4437
# Epoch: 105 | train_loss: 0.9063 | train_acc: 0.7083 | test_loss: 1.6944 | test_acc: 0.4208
# Epoch: 106 | train_loss: 0.9402 | train_acc: 0.6990 | test_loss: 1.6614 | test_acc: 0.4083
# Epoch: 107 | train_loss: 0.9159 | train_acc: 0.6880 | test_loss: 1.7408 | test_acc: 0.4000
# Epoch: 108 | train_loss: 0.8838 | train_acc: 0.7171 | test_loss: 1.6579 | test_acc: 0.4313
# Epoch: 109 | train_loss: 0.8999 | train_acc: 0.7105 | test_loss: 1.6845 | test_acc: 0.4292
# Epoch: 110 | train_loss: 0.9037 | train_acc: 0.6979 | test_loss: 1.6898 | test_acc: 0.4333
# Epoch: 111 | train_loss: 0.8891 | train_acc: 0.7072 | test_loss: 1.6646 | test_acc: 0.4375
# Epoch: 112 | train_loss: 0.8978 | train_acc: 0.7039 | test_loss: 1.7227 | test_acc: 0.4354
# Epoch: 113 | train_loss: 0.8837 | train_acc: 0.7105 | test_loss: 1.6984 | test_acc: 0.4292
# Epoch: 114 | train_loss: 0.8588 | train_acc: 0.7078 | test_loss: 1.6960 | test_acc: 0.4146
# Epoch: 115 | train_loss: 0.8174 | train_acc: 0.7336 | test_loss: 1.6419 | test_acc: 0.4437
# Epoch: 116 | train_loss: 0.9196 | train_acc: 0.6946 | test_loss: 1.6611 | test_acc: 0.4313
# Epoch: 117 | train_loss: 0.8530 | train_acc: 0.7237 | test_loss: 1.7051 | test_acc: 0.4250
# Epoch: 118 | train_loss: 0.8877 | train_acc: 0.7182 | test_loss: 1.7011 | test_acc: 0.4250
# Epoch: 119 | train_loss: 0.8435 | train_acc: 0.7264 | test_loss: 1.6648 | test_acc: 0.4188
# Epoch: 120 | train_loss: 0.8782 | train_acc: 0.7242 | test_loss: 1.6538 | test_acc: 0.4229
# Epoch: 121 | train_loss: 0.8322 | train_acc: 0.7248 | test_loss: 1.6623 | test_acc: 0.4208
# Epoch: 122 | train_loss: 0.8101 | train_acc: 0.7248 | test_loss: 1.7432 | test_acc: 0.4292
# Epoch: 123 | train_loss: 0.8403 | train_acc: 0.7325 | test_loss: 1.7497 | test_acc: 0.4104
# Epoch: 124 | train_loss: 0.7967 | train_acc: 0.7368 | test_loss: 1.6784 | test_acc: 0.4396
# Epoch: 125 | train_loss: 0.8275 | train_acc: 0.7346 | test_loss: 1.7446 | test_acc: 0.4396
# Epoch: 126 | train_loss: 0.8193 | train_acc: 0.7275 | test_loss: 1.6870 | test_acc: 0.4437
# Epoch: 127 | train_loss: 0.8817 | train_acc: 0.7193 | test_loss: 1.7240 | test_acc: 0.4229
# Epoch: 128 | train_loss: 0.8221 | train_acc: 0.7401 | test_loss: 1.7227 | test_acc: 0.4375
# Epoch: 129 | train_loss: 0.8084 | train_acc: 0.7418 | test_loss: 1.7310 | test_acc: 0.4208
# Epoch: 130 | train_loss: 0.7571 | train_acc: 0.7544 | test_loss: 1.6912 | test_acc: 0.4292
# Epoch: 131 | train_loss: 0.7362 | train_acc: 0.7599 | test_loss: 1.7089 | test_acc: 0.4229
# Epoch: 132 | train_loss: 0.7950 | train_acc: 0.7555 | test_loss: 1.7872 | test_acc: 0.4146
# Epoch: 133 | train_loss: 0.7824 | train_acc: 0.7478 | test_loss: 1.7051 | test_acc: 0.4417
# Epoch: 134 | train_loss: 0.7918 | train_acc: 0.7390 | test_loss: 1.7253 | test_acc: 0.4313
# Epoch: 135 | train_loss: 0.8905 | train_acc: 0.6974 | test_loss: 1.7499 | test_acc: 0.4354
# Epoch: 136 | train_loss: 0.8159 | train_acc: 0.7346 | test_loss: 1.7357 | test_acc: 0.4354
# Epoch: 137 | train_loss: 0.7235 | train_acc: 0.7708 | test_loss: 1.7748 | test_acc: 0.4354
# Epoch: 138 | train_loss: 0.7585 | train_acc: 0.7533 | test_loss: 1.6955 | test_acc: 0.4417
# Epoch: 139 | train_loss: 0.7461 | train_acc: 0.7686 | test_loss: 1.7725 | test_acc: 0.4229
# Epoch: 140 | train_loss: 0.7717 | train_acc: 0.7484 | test_loss: 1.6714 | test_acc: 0.4229
# Epoch: 141 | train_loss: 0.7978 | train_acc: 0.7434 | test_loss: 1.7231 | test_acc: 0.4375
# Epoch: 142 | train_loss: 0.7346 | train_acc: 0.7637 | test_loss: 1.7567 | test_acc: 0.4292
# Epoch: 143 | train_loss: 0.7269 | train_acc: 0.7719 | test_loss: 1.7318 | test_acc: 0.4208
# Epoch: 144 | train_loss: 0.7248 | train_acc: 0.7763 | test_loss: 1.7714 | test_acc: 0.4417
# Epoch: 145 | train_loss: 0.7012 | train_acc: 0.7862 | test_loss: 1.7314 | test_acc: 0.4354
# Epoch: 146 | train_loss: 0.6966 | train_acc: 0.7802 | test_loss: 1.7293 | test_acc: 0.4208
# Epoch: 147 | train_loss: 0.7504 | train_acc: 0.7621 | test_loss: 1.7623 | test_acc: 0.4417
# Epoch: 148 | train_loss: 0.7274 | train_acc: 0.7708 | test_loss: 1.8214 | test_acc: 0.4333
# Epoch: 149 | train_loss: 0.7854 | train_acc: 0.7467 | test_loss: 1.8226 | test_acc: 0.4313
# Epoch: 150 | train_loss: 0.6977 | train_acc: 0.7780 | test_loss: 1.7223 | test_acc: 0.4313
# Epoch: 151 | train_loss: 0.6905 | train_acc: 0.7878 | test_loss: 1.7284 | test_acc: 0.4250
# Epoch: 152 | train_loss: 0.7378 | train_acc: 0.7511 | test_loss: 1.7230 | test_acc: 0.4396
# Epoch: 153 | train_loss: 0.6833 | train_acc: 0.7780 | test_loss: 1.7878 | test_acc: 0.4250
# Epoch: 154 | train_loss: 0.7144 | train_acc: 0.7774 | test_loss: 1.7547 | test_acc: 0.4417
# Epoch: 155 | train_loss: 0.6917 | train_acc: 0.7922 | test_loss: 1.8041 | test_acc: 0.4396
# Epoch: 156 | train_loss: 0.6466 | train_acc: 0.7961 | test_loss: 1.7811 | test_acc: 0.4396
# Epoch: 157 | train_loss: 0.6619 | train_acc: 0.7993 | test_loss: 1.8241 | test_acc: 0.4125
# Epoch: 158 | train_loss: 0.6843 | train_acc: 0.7845 | test_loss: 1.8041 | test_acc: 0.4417
# Epoch: 159 | train_loss: 0.7214 | train_acc: 0.7626 | test_loss: 1.8451 | test_acc: 0.4375
# Epoch: 160 | train_loss: 0.6971 | train_acc: 0.7834 | test_loss: 1.8808 | test_acc: 0.4208
# Epoch: 161 | train_loss: 0.6768 | train_acc: 0.7752 | test_loss: 1.7768 | test_acc: 0.4250
# Epoch: 162 | train_loss: 0.6669 | train_acc: 0.7944 | test_loss: 1.7761 | test_acc: 0.4354
# Epoch: 163 | train_loss: 0.6742 | train_acc: 0.7928 | test_loss: 1.8002 | test_acc: 0.4396
# Epoch: 164 | train_loss: 0.6640 | train_acc: 0.7928 | test_loss: 1.8069 | test_acc: 0.4354
# Epoch: 165 | train_loss: 0.6787 | train_acc: 0.7812 | test_loss: 1.7964 | test_acc: 0.4313
# Epoch: 166 | train_loss: 0.6485 | train_acc: 0.7928 | test_loss: 1.7518 | test_acc: 0.4417
# Epoch: 167 | train_loss: 0.6558 | train_acc: 0.7988 | test_loss: 1.7888 | test_acc: 0.4083
# Epoch: 168 | train_loss: 0.7079 | train_acc: 0.7681 | test_loss: 1.7548 | test_acc: 0.4188
# Epoch: 169 | train_loss: 0.6821 | train_acc: 0.7774 | test_loss: 1.7753 | test_acc: 0.4500
# Epoch: 170 | train_loss: 0.6814 | train_acc: 0.7939 | test_loss: 1.8058 | test_acc: 0.4396
# Epoch: 171 | train_loss: 0.6411 | train_acc: 0.7982 | test_loss: 1.8208 | test_acc: 0.4250
# Epoch: 172 | train_loss: 0.7290 | train_acc: 0.7599 | test_loss: 2.0871 | test_acc: 0.4000
# Epoch: 173 | train_loss: 0.7697 | train_acc: 0.7555 | test_loss: 2.0994 | test_acc: 0.3729
# Epoch: 174 | train_loss: 0.8156 | train_acc: 0.7259 | test_loss: 1.7594 | test_acc: 0.4333
# Epoch: 175 | train_loss: 0.7426 | train_acc: 0.7719 | test_loss: 1.8194 | test_acc: 0.4292
# Epoch: 176 | train_loss: 0.6446 | train_acc: 0.8125 | test_loss: 1.7809 | test_acc: 0.4313
# Epoch: 177 | train_loss: 0.6449 | train_acc: 0.7961 | test_loss: 1.8172 | test_acc: 0.4479
# Epoch: 178 | train_loss: 0.5995 | train_acc: 0.8169 | test_loss: 1.8612 | test_acc: 0.4313
# Epoch: 179 | train_loss: 0.6225 | train_acc: 0.8048 | test_loss: 1.8014 | test_acc: 0.4479
# Epoch: 180 | train_loss: 0.6278 | train_acc: 0.8048 | test_loss: 1.8810 | test_acc: 0.4417
# Epoch: 181 | train_loss: 0.6236 | train_acc: 0.8004 | test_loss: 1.7697 | test_acc: 0.4479
# Epoch: 182 | train_loss: 0.6432 | train_acc: 0.8026 | test_loss: 1.8726 | test_acc: 0.4500
# Epoch: 183 | train_loss: 0.6486 | train_acc: 0.7895 | test_loss: 1.8915 | test_acc: 0.4292
# Epoch: 184 | train_loss: 0.6478 | train_acc: 0.7977 | test_loss: 1.8499 | test_acc: 0.4396
# Epoch: 185 | train_loss: 0.6062 | train_acc: 0.8136 | test_loss: 1.9027 | test_acc: 0.4146
# Epoch: 186 | train_loss: 0.6664 | train_acc: 0.7873 | test_loss: 1.9020 | test_acc: 0.4292
# Epoch: 187 | train_loss: 0.6471 | train_acc: 0.7939 | test_loss: 1.8768 | test_acc: 0.4292
# Epoch: 188 | train_loss: 0.6122 | train_acc: 0.8070 | test_loss: 1.8283 | test_acc: 0.4375
# Epoch: 189 | train_loss: 0.5884 | train_acc: 0.8196 | test_loss: 1.8459 | test_acc: 0.4271
# Epoch: 190 | train_loss: 0.5878 | train_acc: 0.8185 | test_loss: 1.8141 | test_acc: 0.4208
# Epoch: 191 | train_loss: 0.6371 | train_acc: 0.8054 | test_loss: 1.8859 | test_acc: 0.4292
# Epoch: 192 | train_loss: 0.6573 | train_acc: 0.7884 | test_loss: 1.8474 | test_acc: 0.4208
# Epoch: 193 | train_loss: 0.6945 | train_acc: 0.7747 | test_loss: 1.8074 | test_acc: 0.4375
# Epoch: 194 | train_loss: 0.5918 | train_acc: 0.8120 | test_loss: 1.7910 | test_acc: 0.4417
# Epoch: 195 | train_loss: 0.5301 | train_acc: 0.8405 | test_loss: 1.8423 | test_acc: 0.4313
# Epoch: 196 | train_loss: 0.6117 | train_acc: 0.8114 | test_loss: 1.8425 | test_acc: 0.4375
# Epoch: 197 | train_loss: 0.6154 | train_acc: 0.8026 | test_loss: 1.8270 | test_acc: 0.4458
# Epoch: 198 | train_loss: 0.6416 | train_acc: 0.8010 | test_loss: 1.8276 | test_acc: 0.4354
# Epoch: 199 | train_loss: 0.5899 | train_acc: 0.8136 | test_loss: 1.8369 | test_acc: 0.4396
# Epoch: 200 | train_loss: 0.5305 | train_acc: 0.8344 | test_loss: 1.8303 | test_acc: 0.4313
# Epoch: 201 | train_loss: 0.6269 | train_acc: 0.7950 | test_loss: 1.8612 | test_acc: 0.4208
# Epoch: 202 | train_loss: 0.6088 | train_acc: 0.8054 | test_loss: 1.8619 | test_acc: 0.4500
# Epoch: 203 | train_loss: 0.6108 | train_acc: 0.8141 | test_loss: 1.8650 | test_acc: 0.4333
# Epoch: 204 | train_loss: 0.5600 | train_acc: 0.8224 | test_loss: 1.8826 | test_acc: 0.4437
# Epoch: 205 | train_loss: 0.5530 | train_acc: 0.8251 | test_loss: 1.8232 | test_acc: 0.4521
# Epoch: 206 | train_loss: 0.5312 | train_acc: 0.8416 | test_loss: 1.8388 | test_acc: 0.4500
# Epoch: 207 | train_loss: 0.5731 | train_acc: 0.8240 | test_loss: 1.8744 | test_acc: 0.4437
# Epoch: 208 | train_loss: 0.8475 | train_acc: 0.7456 | test_loss: 2.2991 | test_acc: 0.3979
# Epoch: 209 | train_loss: 1.3012 | train_acc: 0.6003 | test_loss: 1.9631 | test_acc: 0.4000
# Epoch: 210 | train_loss: 0.9662 | train_acc: 0.6645 | test_loss: 1.8922 | test_acc: 0.4125
# Epoch: 211 | train_loss: 0.8670 | train_acc: 0.7061 | test_loss: 1.8834 | test_acc: 0.4104
# Epoch: 212 | train_loss: 0.7637 | train_acc: 0.7489 | test_loss: 1.8570 | test_acc: 0.4042
# Epoch: 213 | train_loss: 0.7798 | train_acc: 0.7522 | test_loss: 1.8989 | test_acc: 0.4104
# Epoch: 214 | train_loss: 0.7778 | train_acc: 0.7582 | test_loss: 1.9518 | test_acc: 0.4146
# Epoch: 215 | train_loss: 0.7125 | train_acc: 0.7708 | test_loss: 1.8928 | test_acc: 0.4229
# Epoch: 216 | train_loss: 0.6787 | train_acc: 0.7878 | test_loss: 1.8748 | test_acc: 0.4375
# Epoch: 217 | train_loss: 0.6634 | train_acc: 0.7840 | test_loss: 1.8598 | test_acc: 0.4083
# Epoch: 218 | train_loss: 0.7440 | train_acc: 0.7780 | test_loss: 1.8898 | test_acc: 0.4229
# Epoch: 219 | train_loss: 0.6320 | train_acc: 0.7922 | test_loss: 1.8699 | test_acc: 0.4083
# Epoch: 220 | train_loss: 0.6594 | train_acc: 0.7933 | test_loss: 1.9041 | test_acc: 0.4208
# Epoch: 221 | train_loss: 0.6945 | train_acc: 0.7878 | test_loss: 1.8669 | test_acc: 0.4083
# Epoch: 222 | train_loss: 0.6376 | train_acc: 0.8021 | test_loss: 1.8719 | test_acc: 0.4146
# Epoch: 223 | train_loss: 0.6020 | train_acc: 0.8174 | test_loss: 1.9191 | test_acc: 0.4146
# Epoch: 224 | train_loss: 0.6506 | train_acc: 0.7906 | test_loss: 1.8964 | test_acc: 0.4146
# Epoch: 225 | train_loss: 0.6026 | train_acc: 0.8065 | test_loss: 1.9085 | test_acc: 0.4375
# Epoch: 226 | train_loss: 0.6083 | train_acc: 0.8185 | test_loss: 1.8583 | test_acc: 0.4333
# Epoch: 227 | train_loss: 0.6094 | train_acc: 0.8114 | test_loss: 1.8392 | test_acc: 0.4333
# Epoch: 228 | train_loss: 0.6236 | train_acc: 0.8130 | test_loss: 1.8220 | test_acc: 0.4333
# Epoch: 229 | train_loss: 0.6117 | train_acc: 0.8076 | test_loss: 1.8000 | test_acc: 0.4417
# Epoch: 230 | train_loss: 0.6058 | train_acc: 0.8120 | test_loss: 1.8592 | test_acc: 0.4271
# Epoch: 231 | train_loss: 0.5522 | train_acc: 0.8289 | test_loss: 1.8481 | test_acc: 0.4313
# Epoch: 232 | train_loss: 0.5345 | train_acc: 0.8306 | test_loss: 1.8306 | test_acc: 0.4479
# Epoch: 233 | train_loss: 0.5718 | train_acc: 0.8284 | test_loss: 1.9447 | test_acc: 0.4354
# Epoch: 234 | train_loss: 0.6189 | train_acc: 0.8098 | test_loss: 1.9197 | test_acc: 0.4479
# Epoch: 235 | train_loss: 0.6044 | train_acc: 0.8114 | test_loss: 1.8507 | test_acc: 0.4583
# Epoch: 236 | train_loss: 0.5537 | train_acc: 0.8322 | test_loss: 1.8746 | test_acc: 0.4562
# Epoch: 237 | train_loss: 0.6266 | train_acc: 0.8026 | test_loss: 1.8867 | test_acc: 0.4458
# Epoch: 238 | train_loss: 0.6182 | train_acc: 0.8103 | test_loss: 1.9194 | test_acc: 0.4542
# Epoch: 239 | train_loss: 0.5684 | train_acc: 0.8196 | test_loss: 1.8695 | test_acc: 0.4375
# Epoch: 240 | train_loss: 0.5456 | train_acc: 0.8344 | test_loss: 1.9078 | test_acc: 0.4479
# Epoch: 241 | train_loss: 0.5362 | train_acc: 0.8317 | test_loss: 1.8594 | test_acc: 0.4375
# Epoch: 242 | train_loss: 0.5379 | train_acc: 0.8355 | test_loss: 1.9144 | test_acc: 0.4375
# Epoch: 243 | train_loss: 0.5688 | train_acc: 0.8229 | test_loss: 1.9557 | test_acc: 0.4417
# Epoch: 244 | train_loss: 0.4975 | train_acc: 0.8361 | test_loss: 1.9244 | test_acc: 0.4375
# Epoch: 245 | train_loss: 0.5995 | train_acc: 0.8026 | test_loss: 1.9387 | test_acc: 0.4417
# Epoch: 246 | train_loss: 0.5742 | train_acc: 0.8191 | test_loss: 1.9080 | test_acc: 0.4188
# Epoch: 247 | train_loss: 0.5298 | train_acc: 0.8421 | test_loss: 1.8266 | test_acc: 0.4333
# Epoch: 248 | train_loss: 0.5381 | train_acc: 0.8262 | test_loss: 1.8740 | test_acc: 0.4458
# Epoch: 249 | train_loss: 0.5089 | train_acc: 0.8416 | test_loss: 1.8669 | test_acc: 0.4437
# Epoch: 250 | train_loss: 0.5439 | train_acc: 0.8262 | test_loss: 1.9151 | test_acc: 0.4521
# Epoch: 251 | train_loss: 0.5665 | train_acc: 0.8251 | test_loss: 1.9474 | test_acc: 0.4208
# Epoch: 252 | train_loss: 0.6640 | train_acc: 0.8054 | test_loss: 1.8931 | test_acc: 0.4229
# Epoch: 253 | train_loss: 0.5639 | train_acc: 0.8289 | test_loss: 1.8713 | test_acc: 0.4333
# Epoch: 254 | train_loss: 0.5289 | train_acc: 0.8459 | test_loss: 1.8492 | test_acc: 0.4292
# Epoch: 255 | train_loss: 0.4919 | train_acc: 0.8503 | test_loss: 1.8698 | test_acc: 0.4458
# Epoch: 256 | train_loss: 0.4947 | train_acc: 0.8525 | test_loss: 1.8822 | test_acc: 0.4521
# Epoch: 257 | train_loss: 0.5630 | train_acc: 0.8289 | test_loss: 1.8678 | test_acc: 0.4313
# Epoch: 258 | train_loss: 0.5226 | train_acc: 0.8416 | test_loss: 1.8859 | test_acc: 0.4333
# Epoch: 259 | train_loss: 0.5316 | train_acc: 0.8344 | test_loss: 1.9216 | test_acc: 0.4458
# Epoch: 260 | train_loss: 0.5574 | train_acc: 0.8202 | test_loss: 1.9321 | test_acc: 0.4375
# Epoch: 261 | train_loss: 0.4596 | train_acc: 0.8476 | test_loss: 1.9069 | test_acc: 0.4437
# Epoch: 262 | train_loss: 0.5557 | train_acc: 0.8284 | test_loss: 1.9250 | test_acc: 0.4417
# Epoch: 263 | train_loss: 0.5328 | train_acc: 0.8399 | test_loss: 1.9219 | test_acc: 0.4437
# Epoch: 264 | train_loss: 0.4670 | train_acc: 0.8607 | test_loss: 1.9880 | test_acc: 0.4458
# Epoch: 265 | train_loss: 0.4851 | train_acc: 0.8542 | test_loss: 1.9534 | test_acc: 0.4437
# Epoch: 266 | train_loss: 0.4881 | train_acc: 0.8542 | test_loss: 1.9262 | test_acc: 0.4458
# Epoch: 267 | train_loss: 0.5433 | train_acc: 0.8333 | test_loss: 1.9260 | test_acc: 0.4458
# Epoch: 268 | train_loss: 0.5085 | train_acc: 0.8300 | test_loss: 2.0026 | test_acc: 0.4396
# Epoch: 269 | train_loss: 0.5419 | train_acc: 0.8339 | test_loss: 1.9207 | test_acc: 0.4479
# Epoch: 270 | train_loss: 0.5292 | train_acc: 0.8279 | test_loss: 1.9002 | test_acc: 0.4146
# Epoch: 271 | train_loss: 0.4829 | train_acc: 0.8465 | test_loss: 1.9243 | test_acc: 0.4521
# Epoch: 272 | train_loss: 0.4637 | train_acc: 0.8624 | test_loss: 1.9749 | test_acc: 0.4354
# Epoch: 273 | train_loss: 0.5023 | train_acc: 0.8361 | test_loss: 1.8612 | test_acc: 0.4354
# Epoch: 274 | train_loss: 0.4463 | train_acc: 0.8679 | test_loss: 1.8403 | test_acc: 0.4667
# Epoch: 275 | train_loss: 0.4904 | train_acc: 0.8492 | test_loss: 1.9138 | test_acc: 0.4333
# Epoch: 276 | train_loss: 0.4667 | train_acc: 0.8657 | test_loss: 1.9375 | test_acc: 0.4521
# Epoch: 277 | train_loss: 0.4594 | train_acc: 0.8624 | test_loss: 1.9453 | test_acc: 0.4354
# Epoch: 278 | train_loss: 0.4309 | train_acc: 0.8640 | test_loss: 1.9078 | test_acc: 0.4646
# Epoch: 279 | train_loss: 0.4969 | train_acc: 0.8503 | test_loss: 1.8947 | test_acc: 0.4458
# Epoch: 280 | train_loss: 0.4148 | train_acc: 0.8745 | test_loss: 1.9568 | test_acc: 0.4625
# Epoch: 281 | train_loss: 0.5491 | train_acc: 0.8311 | test_loss: 1.9394 | test_acc: 0.4500
# Epoch: 282 | train_loss: 0.5254 | train_acc: 0.8416 | test_loss: 1.9440 | test_acc: 0.4437
# Epoch: 283 | train_loss: 0.5949 | train_acc: 0.8147 | test_loss: 1.9311 | test_acc: 0.4313
# Epoch: 284 | train_loss: 0.4751 | train_acc: 0.8564 | test_loss: 1.9067 | test_acc: 0.4562
# Epoch: 285 | train_loss: 0.4623 | train_acc: 0.8575 | test_loss: 1.9027 | test_acc: 0.4542
# Epoch: 286 | train_loss: 0.4715 | train_acc: 0.8580 | test_loss: 1.8938 | test_acc: 0.4667
# Epoch: 287 | train_loss: 0.4129 | train_acc: 0.8745 | test_loss: 1.8582 | test_acc: 0.4625
# Epoch: 288 | train_loss: 0.5352 | train_acc: 0.8311 | test_loss: 1.9361 | test_acc: 0.4500
# Epoch: 289 | train_loss: 0.4435 | train_acc: 0.8723 | test_loss: 1.9509 | test_acc: 0.4396
# Epoch: 290 | train_loss: 0.4477 | train_acc: 0.8558 | test_loss: 1.9417 | test_acc: 0.4604
# Epoch: 291 | train_loss: 0.4650 | train_acc: 0.8575 | test_loss: 1.9304 | test_acc: 0.4479
# Epoch: 292 | train_loss: 0.4292 | train_acc: 0.8651 | test_loss: 1.9513 | test_acc: 0.4542
# Epoch: 293 | train_loss: 0.4532 | train_acc: 0.8580 | test_loss: 1.9450 | test_acc: 0.4625
# Epoch: 294 | train_loss: 0.5063 | train_acc: 0.8366 | test_loss: 1.9586 | test_acc: 0.4396
# Epoch: 295 | train_loss: 0.4490 | train_acc: 0.8591 | test_loss: 1.9603 | test_acc: 0.4313
# Epoch: 296 | train_loss: 0.5780 | train_acc: 0.8158 | test_loss: 2.0326 | test_acc: 0.4250
# Epoch: 297 | train_loss: 0.5112 | train_acc: 0.8536 | test_loss: 1.9803 | test_acc: 0.4375
# Epoch: 298 | train_loss: 0.4583 | train_acc: 0.8553 | test_loss: 1.9821 | test_acc: 0.4271
# Epoch: 299 | train_loss: 0.4155 | train_acc: 0.8723 | test_loss: 1.9738 | test_acc: 0.4521
# Epoch: 300 | train_loss: 0.4520 | train_acc: 0.8569 | test_loss: 1.9623 | test_acc: 0.4750
# Total training time: 156.138 seconds

# %%
plot_loss_curves(model_4_results, Save=True, filename="model_4_training")

# %% [markdown]
# We can detect significant improvement in the training, compared to the training without augmented data. Loss starts to increase after the 60th epoch, but it increases at a much lower rate.

# %% [markdown]
# ### 9.3 Training the LSTM model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_5 =LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating the LSTM model from paper
# model_5 = LSTMClassifierV1().to(device)
model_5
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_5.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used in paper according to the specs there
# optimizer = torch.optim.Adam(model_5.parameters(),
#                              lr=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_5_results = train_with_augmentation(model=model_5,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2741 | train_acc: 0.1859 | test_loss: 2.2263 | test_acc: 0.2812
# Epoch: 2 | train_loss: 2.1717 | train_acc: 0.3010 | test_loss: 2.0974 | test_acc: 0.2896
# Epoch: 3 | train_loss: 2.0286 | train_acc: 0.3070 | test_loss: 1.9568 | test_acc: 0.3146
# Epoch: 4 | train_loss: 1.8866 | train_acc: 0.3454 | test_loss: 1.7882 | test_acc: 0.3583
# Epoch: 5 | train_loss: 1.7497 | train_acc: 0.3936 | test_loss: 1.6834 | test_acc: 0.3729
# Epoch: 6 | train_loss: 1.6711 | train_acc: 0.4156 | test_loss: 1.5984 | test_acc: 0.4708
# Epoch: 7 | train_loss: 1.6191 | train_acc: 0.4364 | test_loss: 1.5782 | test_acc: 0.4021
# Epoch: 8 | train_loss: 1.5510 | train_acc: 0.4633 | test_loss: 1.6182 | test_acc: 0.3937
# Epoch: 9 | train_loss: 1.5228 | train_acc: 0.4682 | test_loss: 1.5741 | test_acc: 0.4167
# Epoch: 10 | train_loss: 1.4938 | train_acc: 0.4786 | test_loss: 1.5257 | test_acc: 0.4229
# Epoch: 11 | train_loss: 1.4609 | train_acc: 0.4803 | test_loss: 1.5030 | test_acc: 0.4375
# Epoch: 12 | train_loss: 1.4249 | train_acc: 0.4995 | test_loss: 1.4992 | test_acc: 0.4417
# Epoch: 13 | train_loss: 1.4351 | train_acc: 0.4929 | test_loss: 1.4719 | test_acc: 0.4333
# Epoch: 14 | train_loss: 1.3662 | train_acc: 0.5230 | test_loss: 1.4547 | test_acc: 0.4396
# Epoch: 15 | train_loss: 1.3609 | train_acc: 0.5345 | test_loss: 1.4220 | test_acc: 0.4375
# Epoch: 16 | train_loss: 1.3510 | train_acc: 0.5214 | test_loss: 1.4317 | test_acc: 0.4708
# Epoch: 17 | train_loss: 1.3132 | train_acc: 0.5466 | test_loss: 1.4992 | test_acc: 0.4375
# Epoch: 18 | train_loss: 1.3458 | train_acc: 0.5126 | test_loss: 1.4641 | test_acc: 0.4417
# Epoch: 19 | train_loss: 1.2740 | train_acc: 0.5504 | test_loss: 1.4412 | test_acc: 0.4562
# Epoch: 20 | train_loss: 1.3054 | train_acc: 0.5258 | test_loss: 1.4959 | test_acc: 0.4667
# Epoch: 21 | train_loss: 1.2668 | train_acc: 0.5609 | test_loss: 1.4783 | test_acc: 0.4625
# Epoch: 22 | train_loss: 1.2384 | train_acc: 0.5685 | test_loss: 1.4884 | test_acc: 0.4667
# Epoch: 23 | train_loss: 1.2275 | train_acc: 0.5768 | test_loss: 1.4527 | test_acc: 0.5062
# Epoch: 24 | train_loss: 1.2486 | train_acc: 0.5630 | test_loss: 1.4131 | test_acc: 0.4750
# Epoch: 25 | train_loss: 1.2179 | train_acc: 0.5888 | test_loss: 1.3769 | test_acc: 0.5042
# Epoch: 26 | train_loss: 1.2209 | train_acc: 0.5844 | test_loss: 1.4131 | test_acc: 0.4646
# Epoch: 27 | train_loss: 1.1793 | train_acc: 0.5970 | test_loss: 1.3770 | test_acc: 0.5000
# Epoch: 28 | train_loss: 1.1416 | train_acc: 0.6009 | test_loss: 1.3785 | test_acc: 0.5000
# Epoch: 29 | train_loss: 1.1493 | train_acc: 0.6091 | test_loss: 1.3685 | test_acc: 0.4938
# Epoch: 30 | train_loss: 1.1088 | train_acc: 0.6255 | test_loss: 1.3513 | test_acc: 0.5083
# Epoch: 31 | train_loss: 1.0997 | train_acc: 0.6124 | test_loss: 1.3387 | test_acc: 0.5188
# Epoch: 32 | train_loss: 1.1422 | train_acc: 0.6020 | test_loss: 1.3811 | test_acc: 0.4958
# Epoch: 33 | train_loss: 1.1497 | train_acc: 0.6069 | test_loss: 1.7557 | test_acc: 0.3563
# Epoch: 34 | train_loss: 1.3533 | train_acc: 0.5280 | test_loss: 1.4675 | test_acc: 0.4646
# Epoch: 35 | train_loss: 1.1971 | train_acc: 0.5855 | test_loss: 1.4038 | test_acc: 0.4792
# Epoch: 36 | train_loss: 1.1527 | train_acc: 0.5976 | test_loss: 1.4132 | test_acc: 0.4792
# Epoch: 37 | train_loss: 1.1072 | train_acc: 0.6228 | test_loss: 1.3770 | test_acc: 0.5042
# Epoch: 38 | train_loss: 1.0867 | train_acc: 0.6365 | test_loss: 1.3571 | test_acc: 0.5104
# Epoch: 39 | train_loss: 1.0622 | train_acc: 0.6349 | test_loss: 1.3946 | test_acc: 0.4729
# Epoch: 40 | train_loss: 1.1041 | train_acc: 0.6080 | test_loss: 1.3996 | test_acc: 0.4813
# Epoch: 41 | train_loss: 1.0631 | train_acc: 0.6261 | test_loss: 1.4007 | test_acc: 0.4750
# Epoch: 42 | train_loss: 1.0339 | train_acc: 0.6447 | test_loss: 1.4218 | test_acc: 0.4708
# Epoch: 43 | train_loss: 1.0923 | train_acc: 0.6239 | test_loss: 1.3634 | test_acc: 0.4979
# Epoch: 44 | train_loss: 1.2615 | train_acc: 0.5768 | test_loss: 1.4147 | test_acc: 0.4979
# Epoch: 45 | train_loss: 1.1412 | train_acc: 0.5992 | test_loss: 1.4403 | test_acc: 0.4917
# Epoch: 46 | train_loss: 1.1478 | train_acc: 0.6003 | test_loss: 1.4219 | test_acc: 0.4708
# Epoch: 47 | train_loss: 1.0626 | train_acc: 0.6436 | test_loss: 1.4563 | test_acc: 0.4979
# Epoch: 48 | train_loss: 1.0482 | train_acc: 0.6398 | test_loss: 1.4465 | test_acc: 0.4771
# Epoch: 49 | train_loss: 1.0523 | train_acc: 0.6332 | test_loss: 1.3946 | test_acc: 0.4833
# Epoch: 50 | train_loss: 1.0628 | train_acc: 0.6299 | test_loss: 1.4228 | test_acc: 0.5208
# Epoch: 51 | train_loss: 1.0769 | train_acc: 0.6332 | test_loss: 2.2441 | test_acc: 0.3896
# Epoch: 52 | train_loss: 1.5540 | train_acc: 0.5104 | test_loss: 1.6996 | test_acc: 0.4562
# Epoch: 53 | train_loss: 1.2599 | train_acc: 0.5515 | test_loss: 1.5237 | test_acc: 0.4813
# Epoch: 54 | train_loss: 1.1832 | train_acc: 0.5927 | test_loss: 1.4686 | test_acc: 0.5021
# Epoch: 55 | train_loss: 1.1546 | train_acc: 0.6047 | test_loss: 1.4566 | test_acc: 0.4750
# Epoch: 56 | train_loss: 1.0735 | train_acc: 0.6316 | test_loss: 1.4081 | test_acc: 0.5208
# Epoch: 57 | train_loss: 1.0652 | train_acc: 0.6436 | test_loss: 1.3780 | test_acc: 0.5104
# Epoch: 58 | train_loss: 1.0306 | train_acc: 0.6562 | test_loss: 1.3907 | test_acc: 0.5188
# Epoch: 59 | train_loss: 0.9427 | train_acc: 0.6963 | test_loss: 1.3555 | test_acc: 0.5188
# Epoch: 60 | train_loss: 1.0039 | train_acc: 0.6683 | test_loss: 1.3686 | test_acc: 0.5188
# Epoch: 61 | train_loss: 1.0287 | train_acc: 0.6524 | test_loss: 1.3110 | test_acc: 0.5167
# Epoch: 62 | train_loss: 0.9749 | train_acc: 0.6798 | test_loss: 1.3790 | test_acc: 0.5167
# Epoch: 63 | train_loss: 0.9153 | train_acc: 0.6859 | test_loss: 1.3743 | test_acc: 0.5062
# Epoch: 64 | train_loss: 0.9389 | train_acc: 0.6853 | test_loss: 1.4289 | test_acc: 0.5125
# Epoch: 65 | train_loss: 0.9276 | train_acc: 0.6798 | test_loss: 1.4753 | test_acc: 0.5021
# Epoch: 66 | train_loss: 0.8645 | train_acc: 0.7188 | test_loss: 1.4082 | test_acc: 0.5271
# Epoch: 67 | train_loss: 0.8546 | train_acc: 0.7155 | test_loss: 1.3675 | test_acc: 0.5312
# Epoch: 68 | train_loss: 0.8966 | train_acc: 0.7007 | test_loss: 1.3300 | test_acc: 0.5354
# Epoch: 69 | train_loss: 0.8502 | train_acc: 0.7122 | test_loss: 1.3632 | test_acc: 0.5292
# Epoch: 70 | train_loss: 0.8819 | train_acc: 0.7039 | test_loss: 1.3355 | test_acc: 0.5750
# Epoch: 71 | train_loss: 0.8739 | train_acc: 0.7067 | test_loss: 1.3636 | test_acc: 0.5312
# Epoch: 72 | train_loss: 0.9182 | train_acc: 0.6957 | test_loss: 1.3756 | test_acc: 0.5271
# Epoch: 73 | train_loss: 0.9024 | train_acc: 0.6919 | test_loss: 1.3373 | test_acc: 0.5271
# Epoch: 74 | train_loss: 0.9048 | train_acc: 0.7061 | test_loss: 1.3359 | test_acc: 0.5229
# Epoch: 75 | train_loss: 0.9196 | train_acc: 0.6968 | test_loss: 1.4841 | test_acc: 0.4979
# Epoch: 76 | train_loss: 0.9030 | train_acc: 0.7001 | test_loss: 1.3501 | test_acc: 0.5167
# Epoch: 77 | train_loss: 0.8649 | train_acc: 0.7155 | test_loss: 1.3463 | test_acc: 0.5312
# Epoch: 78 | train_loss: 0.8537 | train_acc: 0.7177 | test_loss: 1.4690 | test_acc: 0.4875
# Epoch: 79 | train_loss: 0.8313 | train_acc: 0.7149 | test_loss: 1.4011 | test_acc: 0.5062
# Epoch: 80 | train_loss: 0.8135 | train_acc: 0.7314 | test_loss: 1.3910 | test_acc: 0.5188
# Epoch: 81 | train_loss: 0.8706 | train_acc: 0.7001 | test_loss: 1.4030 | test_acc: 0.4875
# Epoch: 82 | train_loss: 0.8000 | train_acc: 0.7286 | test_loss: 1.3674 | test_acc: 0.5333
# Epoch: 83 | train_loss: 0.8717 | train_acc: 0.7105 | test_loss: 1.3070 | test_acc: 0.5146
# Epoch: 84 | train_loss: 0.7630 | train_acc: 0.7566 | test_loss: 1.3442 | test_acc: 0.5563
# Epoch: 85 | train_loss: 0.7809 | train_acc: 0.7462 | test_loss: 1.3517 | test_acc: 0.5479
# Epoch: 86 | train_loss: 0.7901 | train_acc: 0.7297 | test_loss: 1.3352 | test_acc: 0.5292
# Epoch: 87 | train_loss: 0.6650 | train_acc: 0.7763 | test_loss: 1.4447 | test_acc: 0.5312
# Epoch: 88 | train_loss: 0.8216 | train_acc: 0.7379 | test_loss: 1.3885 | test_acc: 0.5292
# Epoch: 89 | train_loss: 0.7595 | train_acc: 0.7516 | test_loss: 1.4113 | test_acc: 0.5354
# Epoch: 90 | train_loss: 0.7666 | train_acc: 0.7451 | test_loss: 1.3562 | test_acc: 0.5250
# Epoch: 91 | train_loss: 0.7968 | train_acc: 0.7368 | test_loss: 1.3727 | test_acc: 0.5292
# Epoch: 92 | train_loss: 0.8149 | train_acc: 0.7215 | test_loss: 1.3847 | test_acc: 0.5250
# Epoch: 93 | train_loss: 0.8672 | train_acc: 0.7094 | test_loss: 1.4176 | test_acc: 0.5188
# Epoch: 94 | train_loss: 0.8230 | train_acc: 0.7401 | test_loss: 1.3753 | test_acc: 0.5271
# Epoch: 95 | train_loss: 0.7331 | train_acc: 0.7516 | test_loss: 1.3444 | test_acc: 0.5167
# Epoch: 96 | train_loss: 0.7442 | train_acc: 0.7505 | test_loss: 1.3581 | test_acc: 0.5521
# Epoch: 97 | train_loss: 0.7306 | train_acc: 0.7533 | test_loss: 1.3664 | test_acc: 0.5354
# Epoch: 98 | train_loss: 0.7031 | train_acc: 0.7675 | test_loss: 1.4083 | test_acc: 0.5417
# Epoch: 99 | train_loss: 0.7383 | train_acc: 0.7566 | test_loss: 1.3766 | test_acc: 0.5229
# Epoch: 100 | train_loss: 0.6935 | train_acc: 0.7758 | test_loss: 1.3978 | test_acc: 0.5188
# Epoch: 101 | train_loss: 0.7176 | train_acc: 0.7577 | test_loss: 1.3965 | test_acc: 0.5354
# Epoch: 102 | train_loss: 0.6522 | train_acc: 0.7928 | test_loss: 1.3291 | test_acc: 0.5896
# Epoch: 103 | train_loss: 0.7257 | train_acc: 0.7632 | test_loss: 1.3544 | test_acc: 0.5125
# Epoch: 104 | train_loss: 0.7213 | train_acc: 0.7610 | test_loss: 1.3794 | test_acc: 0.5312
# Epoch: 105 | train_loss: 0.6541 | train_acc: 0.7856 | test_loss: 1.3143 | test_acc: 0.5396
# Epoch: 106 | train_loss: 0.7282 | train_acc: 0.7697 | test_loss: 1.4302 | test_acc: 0.5396
# Epoch: 107 | train_loss: 0.7094 | train_acc: 0.7758 | test_loss: 1.3705 | test_acc: 0.5208
# Epoch: 108 | train_loss: 0.6943 | train_acc: 0.7692 | test_loss: 1.3166 | test_acc: 0.5729
# Epoch: 109 | train_loss: 0.6172 | train_acc: 0.8004 | test_loss: 1.5104 | test_acc: 0.5312
# Epoch: 110 | train_loss: 0.6664 | train_acc: 0.7725 | test_loss: 1.3802 | test_acc: 0.5271
# Epoch: 111 | train_loss: 0.6725 | train_acc: 0.7812 | test_loss: 1.3924 | test_acc: 0.5375
# Epoch: 112 | train_loss: 0.6719 | train_acc: 0.7802 | test_loss: 1.4222 | test_acc: 0.5437
# Epoch: 113 | train_loss: 0.6606 | train_acc: 0.7818 | test_loss: 1.4222 | test_acc: 0.5417
# Epoch: 114 | train_loss: 0.6837 | train_acc: 0.7845 | test_loss: 1.3644 | test_acc: 0.5792
# Epoch: 115 | train_loss: 0.6340 | train_acc: 0.7867 | test_loss: 1.3675 | test_acc: 0.5583
# Epoch: 116 | train_loss: 0.6684 | train_acc: 0.7818 | test_loss: 1.3441 | test_acc: 0.5687
# Epoch: 117 | train_loss: 0.6413 | train_acc: 0.7895 | test_loss: 1.2861 | test_acc: 0.6250
# Epoch: 118 | train_loss: 0.6473 | train_acc: 0.7873 | test_loss: 1.3959 | test_acc: 0.5479
# Epoch: 119 | train_loss: 0.6762 | train_acc: 0.7818 | test_loss: 1.4925 | test_acc: 0.5292
# Epoch: 120 | train_loss: 0.6499 | train_acc: 0.7906 | test_loss: 1.2948 | test_acc: 0.5708
# Epoch: 121 | train_loss: 0.5852 | train_acc: 0.8087 | test_loss: 1.3198 | test_acc: 0.5729
# Epoch: 122 | train_loss: 0.5669 | train_acc: 0.8191 | test_loss: 1.3521 | test_acc: 0.5437
# Epoch: 123 | train_loss: 0.6163 | train_acc: 0.8059 | test_loss: 1.4049 | test_acc: 0.5583
# Epoch: 124 | train_loss: 0.6695 | train_acc: 0.7675 | test_loss: 1.3721 | test_acc: 0.5583
# Epoch: 125 | train_loss: 0.5863 | train_acc: 0.8004 | test_loss: 1.3281 | test_acc: 0.5854
# Epoch: 126 | train_loss: 0.6415 | train_acc: 0.7939 | test_loss: 1.3594 | test_acc: 0.5500
# Epoch: 127 | train_loss: 0.6031 | train_acc: 0.8081 | test_loss: 1.3527 | test_acc: 0.5938
# Epoch: 128 | train_loss: 0.6447 | train_acc: 0.7900 | test_loss: 1.4764 | test_acc: 0.5354
# Epoch: 129 | train_loss: 0.6252 | train_acc: 0.7961 | test_loss: 1.3545 | test_acc: 0.5521
# Epoch: 130 | train_loss: 0.5611 | train_acc: 0.8185 | test_loss: 1.3754 | test_acc: 0.5646
# Epoch: 131 | train_loss: 0.5235 | train_acc: 0.8328 | test_loss: 1.3680 | test_acc: 0.5729
# Epoch: 132 | train_loss: 0.6498 | train_acc: 0.7873 | test_loss: 1.4383 | test_acc: 0.5396
# Epoch: 133 | train_loss: 0.5642 | train_acc: 0.8152 | test_loss: 1.4126 | test_acc: 0.5646
# Epoch: 134 | train_loss: 0.6045 | train_acc: 0.8076 | test_loss: 1.3435 | test_acc: 0.5646
# Epoch: 135 | train_loss: 0.5607 | train_acc: 0.8196 | test_loss: 1.4282 | test_acc: 0.5625
# Epoch: 136 | train_loss: 0.6030 | train_acc: 0.8004 | test_loss: 1.4550 | test_acc: 0.5479
# Epoch: 137 | train_loss: 0.5331 | train_acc: 0.8240 | test_loss: 1.4467 | test_acc: 0.5521
# Epoch: 138 | train_loss: 0.5953 | train_acc: 0.8065 | test_loss: 1.4529 | test_acc: 0.5604
# Epoch: 139 | train_loss: 0.5185 | train_acc: 0.8421 | test_loss: 1.4583 | test_acc: 0.5500
# Epoch: 140 | train_loss: 0.5439 | train_acc: 0.8322 | test_loss: 1.3757 | test_acc: 0.5938
# Epoch: 141 | train_loss: 0.5720 | train_acc: 0.8207 | test_loss: 1.3033 | test_acc: 0.6354
# Epoch: 142 | train_loss: 0.5314 | train_acc: 0.8377 | test_loss: 1.3234 | test_acc: 0.6167
# Epoch: 143 | train_loss: 0.5174 | train_acc: 0.8328 | test_loss: 1.4192 | test_acc: 0.5542
# Epoch: 144 | train_loss: 0.5644 | train_acc: 0.8163 | test_loss: 1.5036 | test_acc: 0.5771
# Epoch: 145 | train_loss: 0.6244 | train_acc: 0.8026 | test_loss: 1.3177 | test_acc: 0.6146
# Epoch: 146 | train_loss: 0.6761 | train_acc: 0.7692 | test_loss: 1.2995 | test_acc: 0.6000
# Epoch: 147 | train_loss: 0.4778 | train_acc: 0.8432 | test_loss: 1.2587 | test_acc: 0.6042
# Epoch: 148 | train_loss: 0.5064 | train_acc: 0.8427 | test_loss: 1.3179 | test_acc: 0.5917
# Epoch: 149 | train_loss: 0.5195 | train_acc: 0.8350 | test_loss: 1.4394 | test_acc: 0.6000
# Epoch: 150 | train_loss: 0.5282 | train_acc: 0.8355 | test_loss: 1.3354 | test_acc: 0.5792
# Epoch: 151 | train_loss: 0.4716 | train_acc: 0.8514 | test_loss: 1.2873 | test_acc: 0.6229
# Epoch: 152 | train_loss: 0.5604 | train_acc: 0.8207 | test_loss: 1.3092 | test_acc: 0.5750
# Epoch: 153 | train_loss: 0.5772 | train_acc: 0.8087 | test_loss: 1.3321 | test_acc: 0.5708
# Epoch: 154 | train_loss: 0.5464 | train_acc: 0.8279 | test_loss: 1.3889 | test_acc: 0.5729
# Epoch: 155 | train_loss: 0.4886 | train_acc: 0.8427 | test_loss: 1.3247 | test_acc: 0.6208
# Epoch: 156 | train_loss: 0.4513 | train_acc: 0.8553 | test_loss: 1.4614 | test_acc: 0.5604
# Epoch: 157 | train_loss: 0.4777 | train_acc: 0.8377 | test_loss: 1.3468 | test_acc: 0.5813
# Epoch: 158 | train_loss: 0.4885 | train_acc: 0.8509 | test_loss: 1.3697 | test_acc: 0.5667
# Epoch: 159 | train_loss: 0.4858 | train_acc: 0.8525 | test_loss: 1.2767 | test_acc: 0.6104
# Epoch: 160 | train_loss: 0.4308 | train_acc: 0.8668 | test_loss: 1.3508 | test_acc: 0.5833
# Epoch: 161 | train_loss: 0.4756 | train_acc: 0.8470 | test_loss: 1.4101 | test_acc: 0.5625
# Epoch: 162 | train_loss: 0.5044 | train_acc: 0.8355 | test_loss: 1.3930 | test_acc: 0.5604
# Epoch: 163 | train_loss: 0.4372 | train_acc: 0.8701 | test_loss: 1.3697 | test_acc: 0.5667
# Epoch: 164 | train_loss: 0.4096 | train_acc: 0.8690 | test_loss: 1.3082 | test_acc: 0.5917
# Epoch: 165 | train_loss: 0.4875 | train_acc: 0.8470 | test_loss: 1.3628 | test_acc: 0.5667
# Epoch: 166 | train_loss: 0.4023 | train_acc: 0.8772 | test_loss: 1.4142 | test_acc: 0.5646
# Epoch: 167 | train_loss: 0.4902 | train_acc: 0.8481 | test_loss: 1.3976 | test_acc: 0.5604
# Epoch: 168 | train_loss: 0.4665 | train_acc: 0.8487 | test_loss: 1.3447 | test_acc: 0.5813
# Epoch: 169 | train_loss: 0.4556 | train_acc: 0.8520 | test_loss: 1.3111 | test_acc: 0.5917
# Epoch: 170 | train_loss: 0.4724 | train_acc: 0.8542 | test_loss: 1.3094 | test_acc: 0.5979
# Epoch: 171 | train_loss: 0.4433 | train_acc: 0.8629 | test_loss: 1.3850 | test_acc: 0.5938
# Epoch: 172 | train_loss: 0.4587 | train_acc: 0.8586 | test_loss: 1.3962 | test_acc: 0.6104
# Epoch: 173 | train_loss: 0.4530 | train_acc: 0.8629 | test_loss: 1.3620 | test_acc: 0.6167
# Epoch: 174 | train_loss: 0.3727 | train_acc: 0.8931 | test_loss: 1.3292 | test_acc: 0.5896
# Epoch: 175 | train_loss: 0.4055 | train_acc: 0.8745 | test_loss: 1.3298 | test_acc: 0.6062
# Epoch: 176 | train_loss: 0.4073 | train_acc: 0.8777 | test_loss: 1.3005 | test_acc: 0.5896
# Epoch: 177 | train_loss: 0.3449 | train_acc: 0.8920 | test_loss: 1.2845 | test_acc: 0.6292
# Epoch: 178 | train_loss: 0.4092 | train_acc: 0.8679 | test_loss: 1.3811 | test_acc: 0.5750
# Epoch: 179 | train_loss: 0.3827 | train_acc: 0.8794 | test_loss: 1.3325 | test_acc: 0.5771
# Epoch: 180 | train_loss: 0.4794 | train_acc: 0.8547 | test_loss: 1.3127 | test_acc: 0.5708
# Epoch: 181 | train_loss: 0.4034 | train_acc: 0.8662 | test_loss: 1.3592 | test_acc: 0.5813
# Epoch: 182 | train_loss: 0.4689 | train_acc: 0.8459 | test_loss: 1.3567 | test_acc: 0.5958
# Epoch: 183 | train_loss: 0.3891 | train_acc: 0.8755 | test_loss: 1.4509 | test_acc: 0.5813
# Epoch: 184 | train_loss: 0.4469 | train_acc: 0.8629 | test_loss: 1.4087 | test_acc: 0.5854
# Epoch: 185 | train_loss: 0.4533 | train_acc: 0.8575 | test_loss: 1.3406 | test_acc: 0.5979
# Epoch: 186 | train_loss: 0.3977 | train_acc: 0.8788 | test_loss: 1.3242 | test_acc: 0.6083
# Epoch: 187 | train_loss: 0.3788 | train_acc: 0.8810 | test_loss: 1.3252 | test_acc: 0.5917
# Epoch: 188 | train_loss: 0.4352 | train_acc: 0.8657 | test_loss: 1.2730 | test_acc: 0.6458
# Epoch: 189 | train_loss: 0.5122 | train_acc: 0.8268 | test_loss: 1.3749 | test_acc: 0.5896
# Epoch: 190 | train_loss: 0.3883 | train_acc: 0.8810 | test_loss: 1.3657 | test_acc: 0.5771
# Epoch: 191 | train_loss: 0.3883 | train_acc: 0.8821 | test_loss: 1.4466 | test_acc: 0.5813
# Epoch: 192 | train_loss: 0.3615 | train_acc: 0.8898 | test_loss: 1.4275 | test_acc: 0.5729
# Epoch: 193 | train_loss: 0.3837 | train_acc: 0.8766 | test_loss: 1.3801 | test_acc: 0.5771
# Epoch: 194 | train_loss: 0.3550 | train_acc: 0.8893 | test_loss: 1.4731 | test_acc: 0.5625
# Epoch: 195 | train_loss: 0.4365 | train_acc: 0.8596 | test_loss: 1.4329 | test_acc: 0.5437
# Epoch: 196 | train_loss: 0.3635 | train_acc: 0.8920 | test_loss: 1.3756 | test_acc: 0.6104
# Epoch: 197 | train_loss: 0.3502 | train_acc: 0.8947 | test_loss: 1.4160 | test_acc: 0.5563
# Epoch: 198 | train_loss: 0.4069 | train_acc: 0.8788 | test_loss: 1.3680 | test_acc: 0.5938
# Epoch: 199 | train_loss: 0.3668 | train_acc: 0.8843 | test_loss: 1.5092 | test_acc: 0.5500
# Epoch: 200 | train_loss: 0.3333 | train_acc: 0.8964 | test_loss: 1.3950 | test_acc: 0.5708
# Epoch: 201 | train_loss: 0.3846 | train_acc: 0.8799 | test_loss: 1.3958 | test_acc: 0.5854
# Epoch: 202 | train_loss: 0.3092 | train_acc: 0.9084 | test_loss: 1.3856 | test_acc: 0.5854
# Epoch: 203 | train_loss: 0.4111 | train_acc: 0.8542 | test_loss: 1.4264 | test_acc: 0.5625
# Epoch: 204 | train_loss: 0.4105 | train_acc: 0.8695 | test_loss: 1.4504 | test_acc: 0.6000
# Epoch: 205 | train_loss: 0.3963 | train_acc: 0.8690 | test_loss: 1.3449 | test_acc: 0.6333
# Epoch: 206 | train_loss: 0.3617 | train_acc: 0.8871 | test_loss: 1.3362 | test_acc: 0.6208
# Epoch: 207 | train_loss: 0.3941 | train_acc: 0.8827 | test_loss: 1.3449 | test_acc: 0.6167
# Epoch: 208 | train_loss: 0.3495 | train_acc: 0.8920 | test_loss: 1.4240 | test_acc: 0.5896
# Epoch: 209 | train_loss: 0.3561 | train_acc: 0.8931 | test_loss: 1.5182 | test_acc: 0.5667
# Epoch: 210 | train_loss: 0.4270 | train_acc: 0.8613 | test_loss: 1.6360 | test_acc: 0.5458
# Epoch: 211 | train_loss: 0.3722 | train_acc: 0.8849 | test_loss: 1.4136 | test_acc: 0.5583
# Epoch: 212 | train_loss: 0.3802 | train_acc: 0.8914 | test_loss: 1.4069 | test_acc: 0.5896
# Epoch: 213 | train_loss: 0.3676 | train_acc: 0.8876 | test_loss: 1.3321 | test_acc: 0.5875
# Epoch: 214 | train_loss: 0.3901 | train_acc: 0.8816 | test_loss: 1.3875 | test_acc: 0.5979
# Epoch: 215 | train_loss: 0.3407 | train_acc: 0.8865 | test_loss: 1.3827 | test_acc: 0.6062
# Epoch: 216 | train_loss: 0.3531 | train_acc: 0.8816 | test_loss: 1.3903 | test_acc: 0.6042
# Epoch: 217 | train_loss: 0.3946 | train_acc: 0.8695 | test_loss: 1.3877 | test_acc: 0.5792
# Epoch: 218 | train_loss: 0.4051 | train_acc: 0.8772 | test_loss: 1.4257 | test_acc: 0.5854
# Epoch: 219 | train_loss: 0.3784 | train_acc: 0.8904 | test_loss: 1.3953 | test_acc: 0.5813
# Epoch: 220 | train_loss: 0.2967 | train_acc: 0.9139 | test_loss: 1.4654 | test_acc: 0.6208
# Epoch: 221 | train_loss: 0.3312 | train_acc: 0.8925 | test_loss: 1.3713 | test_acc: 0.5833
# Epoch: 222 | train_loss: 0.3301 | train_acc: 0.8947 | test_loss: 1.4126 | test_acc: 0.6292
# Epoch: 223 | train_loss: 0.3358 | train_acc: 0.8975 | test_loss: 1.4046 | test_acc: 0.6083
# Epoch: 224 | train_loss: 0.3737 | train_acc: 0.8821 | test_loss: 1.4083 | test_acc: 0.6250
# Epoch: 225 | train_loss: 0.3037 | train_acc: 0.9123 | test_loss: 1.4161 | test_acc: 0.6208
# Epoch: 226 | train_loss: 0.3664 | train_acc: 0.8909 | test_loss: 1.5568 | test_acc: 0.5792
# Epoch: 227 | train_loss: 0.3703 | train_acc: 0.8794 | test_loss: 1.4185 | test_acc: 0.5833
# Epoch: 228 | train_loss: 0.3363 | train_acc: 0.9046 | test_loss: 1.4054 | test_acc: 0.6083
# Epoch: 229 | train_loss: 0.3329 | train_acc: 0.8936 | test_loss: 1.4172 | test_acc: 0.5729
# Epoch: 230 | train_loss: 0.3141 | train_acc: 0.9090 | test_loss: 1.4848 | test_acc: 0.6062
# Epoch: 231 | train_loss: 0.3428 | train_acc: 0.8953 | test_loss: 1.4606 | test_acc: 0.6104
# Epoch: 232 | train_loss: 0.3150 | train_acc: 0.9019 | test_loss: 1.4863 | test_acc: 0.5729
# Epoch: 233 | train_loss: 0.4437 | train_acc: 0.8646 | test_loss: 1.4305 | test_acc: 0.5667
# Epoch: 234 | train_loss: 0.3628 | train_acc: 0.8827 | test_loss: 1.3966 | test_acc: 0.6271
# Epoch: 235 | train_loss: 0.2660 | train_acc: 0.9227 | test_loss: 1.4205 | test_acc: 0.6104
# Epoch: 236 | train_loss: 0.3733 | train_acc: 0.8860 | test_loss: 1.4420 | test_acc: 0.5563
# Epoch: 237 | train_loss: 0.2670 | train_acc: 0.9243 | test_loss: 1.5225 | test_acc: 0.5646
# Epoch: 238 | train_loss: 0.3218 | train_acc: 0.9041 | test_loss: 1.4571 | test_acc: 0.6312
# Epoch: 239 | train_loss: 0.3619 | train_acc: 0.8854 | test_loss: 1.4192 | test_acc: 0.5625
# Epoch: 240 | train_loss: 0.2823 | train_acc: 0.9139 | test_loss: 1.4426 | test_acc: 0.5667
# Epoch: 241 | train_loss: 0.3034 | train_acc: 0.9123 | test_loss: 1.3780 | test_acc: 0.5938
# Epoch: 242 | train_loss: 0.3220 | train_acc: 0.9035 | test_loss: 1.4721 | test_acc: 0.5938
# Epoch: 243 | train_loss: 0.2816 | train_acc: 0.9194 | test_loss: 1.3961 | test_acc: 0.6000
# Epoch: 244 | train_loss: 0.3052 | train_acc: 0.9019 | test_loss: 1.4565 | test_acc: 0.5792
# Epoch: 245 | train_loss: 0.3765 | train_acc: 0.8772 | test_loss: 1.4456 | test_acc: 0.6208
# Epoch: 246 | train_loss: 0.2953 | train_acc: 0.9117 | test_loss: 1.6341 | test_acc: 0.5542
# Epoch: 247 | train_loss: 0.2949 | train_acc: 0.9013 | test_loss: 1.7061 | test_acc: 0.5521
# Epoch: 248 | train_loss: 0.4001 | train_acc: 0.8690 | test_loss: 1.4955 | test_acc: 0.5625
# Epoch: 249 | train_loss: 0.3388 | train_acc: 0.8975 | test_loss: 1.4481 | test_acc: 0.6062
# Epoch: 250 | train_loss: 0.3381 | train_acc: 0.8920 | test_loss: 1.4889 | test_acc: 0.5667
# Epoch: 251 | train_loss: 0.3339 | train_acc: 0.8914 | test_loss: 1.5305 | test_acc: 0.5583
# Epoch: 252 | train_loss: 0.2673 | train_acc: 0.9172 | test_loss: 1.5786 | test_acc: 0.5625
# Epoch: 253 | train_loss: 0.3035 | train_acc: 0.9057 | test_loss: 1.5027 | test_acc: 0.5813
# Epoch: 254 | train_loss: 0.3627 | train_acc: 0.8860 | test_loss: 1.5203 | test_acc: 0.6062
# Epoch: 255 | train_loss: 0.3095 | train_acc: 0.8964 | test_loss: 1.4784 | test_acc: 0.5938
# Epoch: 256 | train_loss: 0.2925 | train_acc: 0.9128 | test_loss: 1.4868 | test_acc: 0.6021
# Epoch: 257 | train_loss: 0.2982 | train_acc: 0.9106 | test_loss: 1.5004 | test_acc: 0.5771
# Epoch: 258 | train_loss: 0.3444 | train_acc: 0.8964 | test_loss: 1.5048 | test_acc: 0.6042
# Epoch: 259 | train_loss: 0.3953 | train_acc: 0.8766 | test_loss: 1.4462 | test_acc: 0.6062
# Epoch: 260 | train_loss: 0.2959 | train_acc: 0.9035 | test_loss: 1.4663 | test_acc: 0.6083
# Epoch: 261 | train_loss: 0.3533 | train_acc: 0.8871 | test_loss: 1.4152 | test_acc: 0.6292
# Epoch: 262 | train_loss: 0.2854 | train_acc: 0.9139 | test_loss: 1.4606 | test_acc: 0.6188
# Epoch: 263 | train_loss: 0.3342 | train_acc: 0.8947 | test_loss: 1.3747 | test_acc: 0.6479
# Epoch: 264 | train_loss: 0.2619 | train_acc: 0.9249 | test_loss: 1.4687 | test_acc: 0.5813
# Epoch: 265 | train_loss: 0.2610 | train_acc: 0.9205 | test_loss: 1.4926 | test_acc: 0.5813
# Epoch: 266 | train_loss: 0.3375 | train_acc: 0.9008 | test_loss: 1.5299 | test_acc: 0.5750
# Epoch: 267 | train_loss: 0.3131 | train_acc: 0.8947 | test_loss: 1.4296 | test_acc: 0.6083
# Epoch: 268 | train_loss: 0.2666 | train_acc: 0.9183 | test_loss: 1.4748 | test_acc: 0.5833
# Epoch: 269 | train_loss: 0.2748 | train_acc: 0.9150 | test_loss: 1.4146 | test_acc: 0.6125
# Epoch: 270 | train_loss: 0.3324 | train_acc: 0.8969 | test_loss: 1.4496 | test_acc: 0.5792
# Epoch: 271 | train_loss: 0.1997 | train_acc: 0.9408 | test_loss: 1.5317 | test_acc: 0.5771
# Epoch: 272 | train_loss: 0.2422 | train_acc: 0.9249 | test_loss: 1.4338 | test_acc: 0.5896
# Epoch: 273 | train_loss: 0.2915 | train_acc: 0.9112 | test_loss: 1.4317 | test_acc: 0.5938
# Epoch: 274 | train_loss: 0.2366 | train_acc: 0.9293 | test_loss: 1.3239 | test_acc: 0.6667
# Epoch: 275 | train_loss: 0.2574 | train_acc: 0.9183 | test_loss: 1.3412 | test_acc: 0.6708
# Epoch: 276 | train_loss: 0.2951 | train_acc: 0.9068 | test_loss: 1.5070 | test_acc: 0.5813
# Epoch: 277 | train_loss: 0.2543 | train_acc: 0.9134 | test_loss: 1.4384 | test_acc: 0.5958
# Epoch: 278 | train_loss: 0.2928 | train_acc: 0.9117 | test_loss: 1.3929 | test_acc: 0.6125
# Epoch: 279 | train_loss: 0.2811 | train_acc: 0.9156 | test_loss: 1.4390 | test_acc: 0.6125
# Epoch: 280 | train_loss: 0.2718 | train_acc: 0.9145 | test_loss: 1.4043 | test_acc: 0.6167
# Epoch: 281 | train_loss: 0.3013 | train_acc: 0.9123 | test_loss: 1.4520 | test_acc: 0.5729
# Epoch: 282 | train_loss: 0.3063 | train_acc: 0.9052 | test_loss: 1.4485 | test_acc: 0.6083
# Epoch: 283 | train_loss: 0.3152 | train_acc: 0.9019 | test_loss: 1.4256 | test_acc: 0.6375
# Epoch: 284 | train_loss: 0.3092 | train_acc: 0.9041 | test_loss: 1.3610 | test_acc: 0.6625
# Epoch: 285 | train_loss: 0.2462 | train_acc: 0.9211 | test_loss: 1.3923 | test_acc: 0.6271
# Epoch: 286 | train_loss: 0.3099 | train_acc: 0.8936 | test_loss: 1.3941 | test_acc: 0.6083
# Epoch: 287 | train_loss: 0.2379 | train_acc: 0.9304 | test_loss: 1.4446 | test_acc: 0.5938
# Epoch: 288 | train_loss: 0.2403 | train_acc: 0.9227 | test_loss: 1.4435 | test_acc: 0.5854
# Epoch: 289 | train_loss: 0.2215 | train_acc: 0.9315 | test_loss: 1.4732 | test_acc: 0.5833
# Epoch: 290 | train_loss: 0.2116 | train_acc: 0.9331 | test_loss: 1.4092 | test_acc: 0.6125
# Epoch: 291 | train_loss: 0.1906 | train_acc: 0.9468 | test_loss: 1.4981 | test_acc: 0.5833
# Epoch: 292 | train_loss: 0.2880 | train_acc: 0.9128 | test_loss: 1.4706 | test_acc: 0.6188
# Epoch: 293 | train_loss: 0.2521 | train_acc: 0.9282 | test_loss: 1.4919 | test_acc: 0.6000
# Epoch: 294 | train_loss: 0.2637 | train_acc: 0.9172 | test_loss: 1.4414 | test_acc: 0.6146
# Epoch: 295 | train_loss: 0.2147 | train_acc: 0.9320 | test_loss: 1.3814 | test_acc: 0.6542
# Epoch: 296 | train_loss: 0.2291 | train_acc: 0.9287 | test_loss: 1.3467 | test_acc: 0.6417
# Epoch: 297 | train_loss: 0.2708 | train_acc: 0.9123 | test_loss: 1.3279 | test_acc: 0.6562
# Epoch: 298 | train_loss: 0.2290 | train_acc: 0.9309 | test_loss: 1.4763 | test_acc: 0.6000
# Epoch: 299 | train_loss: 0.3222 | train_acc: 0.8997 | test_loss: 1.4910 | test_acc: 0.5979
# Epoch: 300 | train_loss: 0.2212 | train_acc: 0.9271 | test_loss: 1.5487 | test_acc: 0.5792
# Total training time: 412.488 seconds

# %%
plot_loss_curves(model_5_results, Save=True, filename="model_5_training")

# %% [markdown]
# We see that there is improvement in the LSTM training as well. The model seems to reach higher accuracy values

# %% [markdown]
# ### 9.4 Training the GRU model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_6 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)

# # Instantiating the GRU version of the paper
# model_6 = GRUClassifierV1().to(device)
model_6
# Out:
# GRUClassifierV0(
#   (gru): GRU(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_6.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# # Optimizer used with the paper GRU
# optimizer = torch.optim.Adam(model_6.parameters(),
#                              lr=0.001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 300

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_6_results = train_with_augmentation(model=model_6,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2144 | train_acc: 0.1985 | test_loss: 2.1101 | test_acc: 0.2604
# Epoch: 2 | train_loss: 2.0469 | train_acc: 0.2829 | test_loss: 1.9773 | test_acc: 0.3083
# Epoch: 3 | train_loss: 1.9238 | train_acc: 0.3273 | test_loss: 1.8861 | test_acc: 0.3312
# Epoch: 4 | train_loss: 1.8381 | train_acc: 0.3586 | test_loss: 1.8053 | test_acc: 0.3479
# Epoch: 5 | train_loss: 1.7784 | train_acc: 0.3717 | test_loss: 1.7510 | test_acc: 0.3604
# Epoch: 6 | train_loss: 1.7073 | train_acc: 0.4024 | test_loss: 1.7057 | test_acc: 0.3625
# Epoch: 7 | train_loss: 1.6792 | train_acc: 0.3914 | test_loss: 1.6672 | test_acc: 0.3833
# Epoch: 8 | train_loss: 1.6025 | train_acc: 0.4304 | test_loss: 1.6328 | test_acc: 0.3937
# Epoch: 9 | train_loss: 1.5564 | train_acc: 0.4550 | test_loss: 1.5958 | test_acc: 0.4125
# Epoch: 10 | train_loss: 1.5011 | train_acc: 0.4770 | test_loss: 1.5658 | test_acc: 0.4271
# Epoch: 11 | train_loss: 1.4824 | train_acc: 0.4912 | test_loss: 1.5330 | test_acc: 0.4313
# Epoch: 12 | train_loss: 1.4557 | train_acc: 0.4940 | test_loss: 1.5242 | test_acc: 0.4542
# Epoch: 13 | train_loss: 1.4032 | train_acc: 0.5121 | test_loss: 1.4961 | test_acc: 0.4625
# Epoch: 14 | train_loss: 1.3693 | train_acc: 0.5258 | test_loss: 1.5015 | test_acc: 0.4521
# Epoch: 15 | train_loss: 1.3323 | train_acc: 0.5493 | test_loss: 1.4489 | test_acc: 0.4708
# Epoch: 16 | train_loss: 1.2802 | train_acc: 0.5614 | test_loss: 1.4466 | test_acc: 0.4583
# Epoch: 17 | train_loss: 1.2736 | train_acc: 0.5592 | test_loss: 1.4330 | test_acc: 0.4875
# Epoch: 18 | train_loss: 1.2261 | train_acc: 0.5905 | test_loss: 1.4498 | test_acc: 0.4771
# Epoch: 19 | train_loss: 1.1774 | train_acc: 0.5992 | test_loss: 1.4193 | test_acc: 0.5042
# Epoch: 20 | train_loss: 1.2285 | train_acc: 0.5866 | test_loss: 1.3845 | test_acc: 0.4979
# Epoch: 21 | train_loss: 1.1662 | train_acc: 0.5954 | test_loss: 1.3643 | test_acc: 0.4875
# Epoch: 22 | train_loss: 1.1133 | train_acc: 0.6354 | test_loss: 1.3748 | test_acc: 0.4875
# Epoch: 23 | train_loss: 1.0818 | train_acc: 0.6398 | test_loss: 1.3842 | test_acc: 0.5042
# Epoch: 24 | train_loss: 1.0650 | train_acc: 0.6414 | test_loss: 1.3409 | test_acc: 0.4958
# Epoch: 25 | train_loss: 1.0316 | train_acc: 0.6645 | test_loss: 1.3298 | test_acc: 0.4896
# Epoch: 26 | train_loss: 0.9945 | train_acc: 0.6617 | test_loss: 1.4671 | test_acc: 0.4875
# Epoch: 27 | train_loss: 0.9806 | train_acc: 0.6732 | test_loss: 1.4127 | test_acc: 0.5083
# Epoch: 28 | train_loss: 0.9621 | train_acc: 0.6842 | test_loss: 1.3597 | test_acc: 0.5083
# Epoch: 29 | train_loss: 0.9485 | train_acc: 0.6826 | test_loss: 1.3498 | test_acc: 0.5167
# Epoch: 30 | train_loss: 0.9226 | train_acc: 0.6897 | test_loss: 1.3146 | test_acc: 0.5125
# Epoch: 31 | train_loss: 0.9174 | train_acc: 0.6913 | test_loss: 1.3721 | test_acc: 0.5125
# Epoch: 32 | train_loss: 0.9470 | train_acc: 0.6732 | test_loss: 1.3020 | test_acc: 0.5208
# Epoch: 33 | train_loss: 0.9002 | train_acc: 0.6974 | test_loss: 1.2924 | test_acc: 0.5417
# Epoch: 34 | train_loss: 0.8442 | train_acc: 0.7237 | test_loss: 1.3176 | test_acc: 0.5229
# Epoch: 35 | train_loss: 0.8198 | train_acc: 0.7336 | test_loss: 1.3358 | test_acc: 0.5250
# Epoch: 36 | train_loss: 0.7940 | train_acc: 0.7330 | test_loss: 1.3251 | test_acc: 0.5292
# Epoch: 37 | train_loss: 0.8253 | train_acc: 0.7368 | test_loss: 1.3504 | test_acc: 0.5271
# Epoch: 38 | train_loss: 0.7849 | train_acc: 0.7511 | test_loss: 1.3947 | test_acc: 0.5188
# Epoch: 39 | train_loss: 0.7666 | train_acc: 0.7516 | test_loss: 1.3449 | test_acc: 0.5229
# Epoch: 40 | train_loss: 0.7712 | train_acc: 0.7544 | test_loss: 1.3608 | test_acc: 0.5229
# Epoch: 41 | train_loss: 0.7834 | train_acc: 0.7374 | test_loss: 1.4341 | test_acc: 0.5292
# Epoch: 42 | train_loss: 0.7257 | train_acc: 0.7610 | test_loss: 1.3243 | test_acc: 0.5667
# Epoch: 43 | train_loss: 0.7023 | train_acc: 0.7741 | test_loss: 1.3929 | test_acc: 0.5333
# Epoch: 44 | train_loss: 0.7472 | train_acc: 0.7664 | test_loss: 1.2781 | test_acc: 0.5792
# Epoch: 45 | train_loss: 0.6520 | train_acc: 0.7878 | test_loss: 1.3619 | test_acc: 0.5646
# Epoch: 46 | train_loss: 0.6946 | train_acc: 0.7648 | test_loss: 1.4450 | test_acc: 0.5292
# Epoch: 47 | train_loss: 0.6520 | train_acc: 0.7906 | test_loss: 1.3042 | test_acc: 0.5417
# Epoch: 48 | train_loss: 0.6837 | train_acc: 0.7802 | test_loss: 1.3699 | test_acc: 0.5271
# Epoch: 49 | train_loss: 0.6015 | train_acc: 0.8169 | test_loss: 1.3393 | test_acc: 0.5583
# Epoch: 50 | train_loss: 0.6320 | train_acc: 0.7834 | test_loss: 1.3795 | test_acc: 0.5771
# Epoch: 51 | train_loss: 0.6683 | train_acc: 0.7851 | test_loss: 1.3118 | test_acc: 0.5750
# Epoch: 52 | train_loss: 0.6485 | train_acc: 0.7971 | test_loss: 1.3042 | test_acc: 0.5687
# Epoch: 53 | train_loss: 0.6224 | train_acc: 0.8010 | test_loss: 1.3642 | test_acc: 0.5729
# Epoch: 54 | train_loss: 0.5388 | train_acc: 0.8273 | test_loss: 1.3157 | test_acc: 0.5479
# Epoch: 55 | train_loss: 0.5339 | train_acc: 0.8295 | test_loss: 1.3338 | test_acc: 0.5667
# Epoch: 56 | train_loss: 0.5597 | train_acc: 0.8344 | test_loss: 1.3845 | test_acc: 0.5646
# Epoch: 57 | train_loss: 0.5866 | train_acc: 0.8180 | test_loss: 1.3456 | test_acc: 0.5417
# Epoch: 58 | train_loss: 0.5850 | train_acc: 0.8136 | test_loss: 1.3759 | test_acc: 0.5542
# Epoch: 59 | train_loss: 0.6025 | train_acc: 0.8202 | test_loss: 1.3277 | test_acc: 0.5875
# Epoch: 60 | train_loss: 0.5976 | train_acc: 0.8037 | test_loss: 1.3735 | test_acc: 0.5771
# Epoch: 61 | train_loss: 0.5410 | train_acc: 0.8289 | test_loss: 1.3834 | test_acc: 0.5458
# Epoch: 62 | train_loss: 0.5577 | train_acc: 0.8251 | test_loss: 1.4155 | test_acc: 0.5312
# Epoch: 63 | train_loss: 0.5998 | train_acc: 0.8120 | test_loss: 1.3272 | test_acc: 0.5750
# Epoch: 64 | train_loss: 0.4902 | train_acc: 0.8536 | test_loss: 1.4016 | test_acc: 0.5375
# Epoch: 65 | train_loss: 0.5251 | train_acc: 0.8333 | test_loss: 1.2832 | test_acc: 0.5979
# Epoch: 66 | train_loss: 0.5674 | train_acc: 0.8207 | test_loss: 1.3350 | test_acc: 0.5479
# Epoch: 67 | train_loss: 0.5575 | train_acc: 0.8257 | test_loss: 1.2861 | test_acc: 0.5875
# Epoch: 68 | train_loss: 0.5344 | train_acc: 0.8317 | test_loss: 1.3298 | test_acc: 0.5667
# Epoch: 69 | train_loss: 0.5292 | train_acc: 0.8284 | test_loss: 1.3731 | test_acc: 0.5771
# Epoch: 70 | train_loss: 0.4613 | train_acc: 0.8509 | test_loss: 1.3256 | test_acc: 0.5417
# Epoch: 71 | train_loss: 0.4902 | train_acc: 0.8399 | test_loss: 1.3250 | test_acc: 0.5813
# Epoch: 72 | train_loss: 0.4947 | train_acc: 0.8421 | test_loss: 1.3614 | test_acc: 0.5625
# Epoch: 73 | train_loss: 0.4472 | train_acc: 0.8629 | test_loss: 1.3310 | test_acc: 0.5833
# Epoch: 74 | train_loss: 0.3788 | train_acc: 0.8843 | test_loss: 1.3312 | test_acc: 0.5708
# Epoch: 75 | train_loss: 0.4389 | train_acc: 0.8558 | test_loss: 1.3560 | test_acc: 0.5729
# Epoch: 76 | train_loss: 0.4508 | train_acc: 0.8596 | test_loss: 1.3098 | test_acc: 0.5875
# Epoch: 77 | train_loss: 0.4635 | train_acc: 0.8492 | test_loss: 1.3324 | test_acc: 0.5917
# Epoch: 78 | train_loss: 0.4317 | train_acc: 0.8673 | test_loss: 1.3458 | test_acc: 0.5771
# Epoch: 79 | train_loss: 0.4662 | train_acc: 0.8569 | test_loss: 1.3951 | test_acc: 0.5312
# Epoch: 80 | train_loss: 0.4611 | train_acc: 0.8569 | test_loss: 1.4125 | test_acc: 0.5354
# Epoch: 81 | train_loss: 0.4308 | train_acc: 0.8684 | test_loss: 1.4344 | test_acc: 0.5750
# Epoch: 82 | train_loss: 0.4440 | train_acc: 0.8569 | test_loss: 1.3824 | test_acc: 0.5979
# Epoch: 83 | train_loss: 0.4221 | train_acc: 0.8635 | test_loss: 1.4393 | test_acc: 0.5667
# Epoch: 84 | train_loss: 0.3922 | train_acc: 0.8860 | test_loss: 1.3978 | test_acc: 0.5646
# Epoch: 85 | train_loss: 0.3564 | train_acc: 0.8904 | test_loss: 1.4210 | test_acc: 0.5708
# Epoch: 86 | train_loss: 0.4202 | train_acc: 0.8695 | test_loss: 1.4180 | test_acc: 0.5687
# Epoch: 87 | train_loss: 0.3867 | train_acc: 0.8788 | test_loss: 1.3924 | test_acc: 0.5875
# Epoch: 88 | train_loss: 0.4164 | train_acc: 0.8624 | test_loss: 1.3572 | test_acc: 0.5896
# Epoch: 89 | train_loss: 0.3305 | train_acc: 0.8942 | test_loss: 1.4843 | test_acc: 0.5458
# Epoch: 90 | train_loss: 0.5023 | train_acc: 0.8361 | test_loss: 1.4189 | test_acc: 0.5833
# Epoch: 91 | train_loss: 0.3683 | train_acc: 0.8898 | test_loss: 1.4432 | test_acc: 0.5771
# Epoch: 92 | train_loss: 0.3610 | train_acc: 0.8909 | test_loss: 1.4043 | test_acc: 0.5833
# Epoch: 93 | train_loss: 0.3699 | train_acc: 0.8794 | test_loss: 1.4159 | test_acc: 0.5938
# Epoch: 94 | train_loss: 0.3525 | train_acc: 0.8904 | test_loss: 1.4514 | test_acc: 0.5813
# Epoch: 95 | train_loss: 0.3459 | train_acc: 0.8925 | test_loss: 1.3929 | test_acc: 0.5854
# Epoch: 96 | train_loss: 0.3931 | train_acc: 0.8717 | test_loss: 1.4392 | test_acc: 0.5687
# Epoch: 97 | train_loss: 0.4073 | train_acc: 0.8662 | test_loss: 1.4199 | test_acc: 0.6000
# Epoch: 98 | train_loss: 0.3335 | train_acc: 0.9008 | test_loss: 1.4083 | test_acc: 0.5813
# Epoch: 99 | train_loss: 0.3638 | train_acc: 0.8882 | test_loss: 1.4372 | test_acc: 0.5896
# Epoch: 100 | train_loss: 0.3453 | train_acc: 0.8871 | test_loss: 1.3628 | test_acc: 0.5750
# Epoch: 101 | train_loss: 0.3611 | train_acc: 0.8849 | test_loss: 1.3792 | test_acc: 0.6000
# Epoch: 102 | train_loss: 0.3025 | train_acc: 0.9079 | test_loss: 1.4372 | test_acc: 0.6000
# Epoch: 103 | train_loss: 0.2745 | train_acc: 0.9200 | test_loss: 1.4087 | test_acc: 0.5875
# Epoch: 104 | train_loss: 0.3332 | train_acc: 0.8975 | test_loss: 1.4278 | test_acc: 0.5875
# Epoch: 105 | train_loss: 0.2929 | train_acc: 0.9123 | test_loss: 1.3967 | test_acc: 0.5917
# Epoch: 106 | train_loss: 0.2793 | train_acc: 0.9101 | test_loss: 1.4068 | test_acc: 0.6021
# Epoch: 107 | train_loss: 0.3191 | train_acc: 0.8986 | test_loss: 1.4258 | test_acc: 0.5979
# Epoch: 108 | train_loss: 0.2613 | train_acc: 0.9161 | test_loss: 1.4574 | test_acc: 0.5854
# Epoch: 109 | train_loss: 0.3214 | train_acc: 0.8936 | test_loss: 1.4413 | test_acc: 0.5917
# Epoch: 110 | train_loss: 0.3329 | train_acc: 0.8898 | test_loss: 1.5941 | test_acc: 0.5229
# Epoch: 111 | train_loss: 0.3891 | train_acc: 0.8723 | test_loss: 1.4506 | test_acc: 0.5854
# Epoch: 112 | train_loss: 0.2686 | train_acc: 0.9134 | test_loss: 1.4339 | test_acc: 0.5979
# Epoch: 113 | train_loss: 0.3568 | train_acc: 0.8832 | test_loss: 1.4178 | test_acc: 0.6000
# Epoch: 114 | train_loss: 0.2838 | train_acc: 0.9150 | test_loss: 1.3973 | test_acc: 0.5917
# Epoch: 115 | train_loss: 0.2913 | train_acc: 0.9095 | test_loss: 1.4174 | test_acc: 0.6062
# Epoch: 116 | train_loss: 0.2632 | train_acc: 0.9260 | test_loss: 1.4339 | test_acc: 0.5854
# Epoch: 117 | train_loss: 0.2941 | train_acc: 0.8969 | test_loss: 1.4742 | test_acc: 0.5875
# Epoch: 118 | train_loss: 0.2895 | train_acc: 0.9139 | test_loss: 1.4715 | test_acc: 0.5917
# Epoch: 119 | train_loss: 0.2649 | train_acc: 0.9243 | test_loss: 1.4220 | test_acc: 0.5896
# Epoch: 120 | train_loss: 0.2545 | train_acc: 0.9189 | test_loss: 1.4501 | test_acc: 0.5917
# Epoch: 121 | train_loss: 0.2993 | train_acc: 0.9062 | test_loss: 1.4776 | test_acc: 0.5625
# Epoch: 122 | train_loss: 0.2728 | train_acc: 0.9112 | test_loss: 1.4812 | test_acc: 0.6083
# Epoch: 123 | train_loss: 0.3050 | train_acc: 0.8986 | test_loss: 1.4557 | test_acc: 0.6208
# Epoch: 124 | train_loss: 0.2825 | train_acc: 0.9238 | test_loss: 1.5048 | test_acc: 0.6000
# Epoch: 125 | train_loss: 0.3137 | train_acc: 0.8942 | test_loss: 1.4281 | test_acc: 0.6208
# Epoch: 126 | train_loss: 0.3138 | train_acc: 0.9002 | test_loss: 1.4005 | test_acc: 0.6062
# Epoch: 127 | train_loss: 0.2995 | train_acc: 0.9008 | test_loss: 1.4610 | test_acc: 0.6000
# Epoch: 128 | train_loss: 0.2125 | train_acc: 0.9342 | test_loss: 1.4491 | test_acc: 0.6167
# Epoch: 129 | train_loss: 0.2035 | train_acc: 0.9359 | test_loss: 1.4594 | test_acc: 0.6125
# Epoch: 130 | train_loss: 0.3037 | train_acc: 0.9112 | test_loss: 1.4948 | test_acc: 0.5604
# Epoch: 131 | train_loss: 0.3128 | train_acc: 0.9079 | test_loss: 1.4184 | test_acc: 0.5938
# Epoch: 132 | train_loss: 0.2472 | train_acc: 0.9178 | test_loss: 1.4329 | test_acc: 0.6062
# Epoch: 133 | train_loss: 0.2975 | train_acc: 0.9052 | test_loss: 1.3907 | test_acc: 0.6083
# Epoch: 134 | train_loss: 0.2353 | train_acc: 0.9243 | test_loss: 1.4310 | test_acc: 0.6042
# Epoch: 135 | train_loss: 0.3293 | train_acc: 0.8964 | test_loss: 1.4444 | test_acc: 0.5896
# Epoch: 136 | train_loss: 0.2020 | train_acc: 0.9419 | test_loss: 1.4204 | test_acc: 0.6250
# Epoch: 137 | train_loss: 0.2807 | train_acc: 0.9084 | test_loss: 1.4690 | test_acc: 0.6000
# Epoch: 138 | train_loss: 0.2149 | train_acc: 0.9326 | test_loss: 1.7094 | test_acc: 0.5500
# Epoch: 139 | train_loss: 0.1787 | train_acc: 0.9463 | test_loss: 1.4864 | test_acc: 0.6000
# Epoch: 140 | train_loss: 0.2339 | train_acc: 0.9249 | test_loss: 1.4774 | test_acc: 0.6104
# Epoch: 141 | train_loss: 0.2638 | train_acc: 0.9183 | test_loss: 1.4483 | test_acc: 0.5875
# Epoch: 142 | train_loss: 0.3223 | train_acc: 0.9030 | test_loss: 1.4598 | test_acc: 0.5938
# Epoch: 143 | train_loss: 0.2477 | train_acc: 0.9276 | test_loss: 1.4621 | test_acc: 0.5792
# Epoch: 144 | train_loss: 0.1973 | train_acc: 0.9364 | test_loss: 1.4179 | test_acc: 0.6083
# Epoch: 145 | train_loss: 0.2342 | train_acc: 0.9156 | test_loss: 1.3906 | test_acc: 0.6250
# Epoch: 146 | train_loss: 0.1992 | train_acc: 0.9435 | test_loss: 1.4559 | test_acc: 0.6021
# Epoch: 147 | train_loss: 0.1966 | train_acc: 0.9397 | test_loss: 1.5018 | test_acc: 0.6104
# Epoch: 148 | train_loss: 0.2468 | train_acc: 0.9227 | test_loss: 1.4968 | test_acc: 0.5979
# Epoch: 149 | train_loss: 0.2571 | train_acc: 0.9249 | test_loss: 1.4751 | test_acc: 0.6104
# Epoch: 150 | train_loss: 0.2697 | train_acc: 0.9161 | test_loss: 1.4914 | test_acc: 0.6021
# Epoch: 151 | train_loss: 0.2562 | train_acc: 0.9156 | test_loss: 1.3940 | test_acc: 0.6271
# Epoch: 152 | train_loss: 0.2309 | train_acc: 0.9298 | test_loss: 1.3623 | test_acc: 0.6417
# Epoch: 153 | train_loss: 0.2126 | train_acc: 0.9282 | test_loss: 1.4844 | test_acc: 0.6125
# Epoch: 154 | train_loss: 0.2176 | train_acc: 0.9326 | test_loss: 1.4651 | test_acc: 0.6167
# Epoch: 155 | train_loss: 0.2211 | train_acc: 0.9276 | test_loss: 1.4524 | test_acc: 0.5979
# Epoch: 156 | train_loss: 0.2224 | train_acc: 0.9320 | test_loss: 1.4920 | test_acc: 0.6125
# Epoch: 157 | train_loss: 0.2211 | train_acc: 0.9298 | test_loss: 1.4864 | test_acc: 0.5958
# Epoch: 158 | train_loss: 0.2443 | train_acc: 0.9200 | test_loss: 1.4674 | test_acc: 0.6062
# Epoch: 159 | train_loss: 0.1650 | train_acc: 0.9490 | test_loss: 1.4247 | test_acc: 0.6083
# Epoch: 160 | train_loss: 0.2337 | train_acc: 0.9298 | test_loss: 1.4512 | test_acc: 0.5938
# Epoch: 161 | train_loss: 0.2298 | train_acc: 0.9309 | test_loss: 1.4415 | test_acc: 0.5917
# Epoch: 162 | train_loss: 0.2133 | train_acc: 0.9326 | test_loss: 1.4431 | test_acc: 0.5833
# Epoch: 163 | train_loss: 0.1881 | train_acc: 0.9408 | test_loss: 1.4787 | test_acc: 0.6104
# Epoch: 164 | train_loss: 0.2015 | train_acc: 0.9391 | test_loss: 1.4296 | test_acc: 0.6167
# Epoch: 165 | train_loss: 0.1799 | train_acc: 0.9463 | test_loss: 1.4312 | test_acc: 0.6167
# Epoch: 166 | train_loss: 0.1346 | train_acc: 0.9633 | test_loss: 1.4423 | test_acc: 0.6250
# Epoch: 167 | train_loss: 0.1791 | train_acc: 0.9435 | test_loss: 1.4647 | test_acc: 0.6271
# Epoch: 168 | train_loss: 0.2040 | train_acc: 0.9364 | test_loss: 1.4714 | test_acc: 0.6104
# Epoch: 169 | train_loss: 0.1860 | train_acc: 0.9397 | test_loss: 1.5260 | test_acc: 0.6104
# Epoch: 170 | train_loss: 0.1882 | train_acc: 0.9435 | test_loss: 1.5224 | test_acc: 0.6188
# Epoch: 171 | train_loss: 0.1959 | train_acc: 0.9430 | test_loss: 1.4969 | test_acc: 0.5875
# Epoch: 172 | train_loss: 0.2051 | train_acc: 0.9348 | test_loss: 1.4350 | test_acc: 0.6292
# Epoch: 173 | train_loss: 0.2239 | train_acc: 0.9315 | test_loss: 1.5636 | test_acc: 0.5729
# Epoch: 174 | train_loss: 0.1793 | train_acc: 0.9435 | test_loss: 1.5495 | test_acc: 0.6250
# Epoch: 175 | train_loss: 0.1864 | train_acc: 0.9463 | test_loss: 1.5751 | test_acc: 0.6104
# Epoch: 176 | train_loss: 0.1638 | train_acc: 0.9529 | test_loss: 1.5106 | test_acc: 0.6083
# Epoch: 177 | train_loss: 0.2292 | train_acc: 0.9282 | test_loss: 1.5004 | test_acc: 0.6354
# Epoch: 178 | train_loss: 0.2472 | train_acc: 0.9178 | test_loss: 1.5186 | test_acc: 0.6250
# Epoch: 179 | train_loss: 0.1897 | train_acc: 0.9408 | test_loss: 1.5123 | test_acc: 0.6208
# Epoch: 180 | train_loss: 0.1639 | train_acc: 0.9518 | test_loss: 1.4589 | test_acc: 0.6125
# Epoch: 181 | train_loss: 0.1700 | train_acc: 0.9441 | test_loss: 1.4436 | test_acc: 0.6312
# Epoch: 182 | train_loss: 0.2313 | train_acc: 0.9293 | test_loss: 1.4220 | test_acc: 0.6229
# Epoch: 183 | train_loss: 0.1902 | train_acc: 0.9424 | test_loss: 1.4606 | test_acc: 0.6229
# Epoch: 184 | train_loss: 0.2267 | train_acc: 0.9254 | test_loss: 1.4879 | test_acc: 0.6000
# Epoch: 185 | train_loss: 0.2001 | train_acc: 0.9435 | test_loss: 1.4344 | test_acc: 0.6167
# Epoch: 186 | train_loss: 0.2795 | train_acc: 0.9095 | test_loss: 1.5966 | test_acc: 0.5542
# Epoch: 187 | train_loss: 0.2747 | train_acc: 0.9079 | test_loss: 1.3936 | test_acc: 0.6042
# Epoch: 188 | train_loss: 0.1303 | train_acc: 0.9660 | test_loss: 1.4112 | test_acc: 0.6167
# Epoch: 189 | train_loss: 0.1729 | train_acc: 0.9402 | test_loss: 1.4772 | test_acc: 0.5958
# Epoch: 190 | train_loss: 0.1736 | train_acc: 0.9485 | test_loss: 1.4863 | test_acc: 0.6208
# Epoch: 191 | train_loss: 0.1818 | train_acc: 0.9441 | test_loss: 1.4012 | test_acc: 0.6375
# Epoch: 192 | train_loss: 0.1956 | train_acc: 0.9402 | test_loss: 1.5050 | test_acc: 0.6167
# Epoch: 193 | train_loss: 0.1397 | train_acc: 0.9561 | test_loss: 1.5211 | test_acc: 0.6188
# Epoch: 194 | train_loss: 0.1831 | train_acc: 0.9402 | test_loss: 1.5733 | test_acc: 0.5792
# Epoch: 195 | train_loss: 0.1525 | train_acc: 0.9496 | test_loss: 1.4387 | test_acc: 0.6438
# Epoch: 196 | train_loss: 0.1338 | train_acc: 0.9589 | test_loss: 1.4673 | test_acc: 0.6125
# Epoch: 197 | train_loss: 0.2219 | train_acc: 0.9211 | test_loss: 1.5541 | test_acc: 0.5958
# Epoch: 198 | train_loss: 0.1840 | train_acc: 0.9408 | test_loss: 1.4428 | test_acc: 0.6167
# Epoch: 199 | train_loss: 0.1516 | train_acc: 0.9507 | test_loss: 1.5403 | test_acc: 0.5563
# Epoch: 200 | train_loss: 0.1696 | train_acc: 0.9496 | test_loss: 1.4930 | test_acc: 0.5979
# Epoch: 201 | train_loss: 0.1379 | train_acc: 0.9572 | test_loss: 1.5274 | test_acc: 0.6125
# Epoch: 202 | train_loss: 0.2332 | train_acc: 0.9249 | test_loss: 1.4955 | test_acc: 0.6271
# Epoch: 203 | train_loss: 0.1757 | train_acc: 0.9402 | test_loss: 1.5331 | test_acc: 0.6083
# Epoch: 204 | train_loss: 0.1613 | train_acc: 0.9539 | test_loss: 1.4730 | test_acc: 0.6125
# Epoch: 205 | train_loss: 0.1272 | train_acc: 0.9638 | test_loss: 1.4846 | test_acc: 0.6271
# Epoch: 206 | train_loss: 0.1959 | train_acc: 0.9386 | test_loss: 1.5072 | test_acc: 0.6229
# Epoch: 207 | train_loss: 0.1671 | train_acc: 0.9474 | test_loss: 1.5007 | test_acc: 0.6104
# Epoch: 208 | train_loss: 0.2260 | train_acc: 0.9287 | test_loss: 1.5432 | test_acc: 0.6167
# Epoch: 209 | train_loss: 0.1660 | train_acc: 0.9490 | test_loss: 1.5221 | test_acc: 0.6062
# Epoch: 210 | train_loss: 0.1695 | train_acc: 0.9452 | test_loss: 1.6139 | test_acc: 0.5667
# Epoch: 211 | train_loss: 0.2064 | train_acc: 0.9276 | test_loss: 1.4906 | test_acc: 0.6104
# Epoch: 212 | train_loss: 0.1497 | train_acc: 0.9556 | test_loss: 1.4435 | test_acc: 0.6125
# Epoch: 213 | train_loss: 0.1718 | train_acc: 0.9457 | test_loss: 1.4700 | test_acc: 0.6229
# Epoch: 214 | train_loss: 0.1853 | train_acc: 0.9413 | test_loss: 1.4366 | test_acc: 0.6208
# Epoch: 215 | train_loss: 0.1347 | train_acc: 0.9622 | test_loss: 1.4063 | test_acc: 0.6188
# Epoch: 216 | train_loss: 0.1121 | train_acc: 0.9644 | test_loss: 1.4958 | test_acc: 0.6312
# Epoch: 217 | train_loss: 0.1526 | train_acc: 0.9534 | test_loss: 1.5514 | test_acc: 0.6167
# Epoch: 218 | train_loss: 0.1166 | train_acc: 0.9677 | test_loss: 1.5151 | test_acc: 0.6312
# Epoch: 219 | train_loss: 0.1368 | train_acc: 0.9556 | test_loss: 1.4450 | test_acc: 0.6250
# Epoch: 220 | train_loss: 0.1634 | train_acc: 0.9463 | test_loss: 1.4677 | test_acc: 0.5583
# Epoch: 221 | train_loss: 0.1340 | train_acc: 0.9572 | test_loss: 1.5067 | test_acc: 0.6125
# Epoch: 222 | train_loss: 0.1564 | train_acc: 0.9501 | test_loss: 1.5013 | test_acc: 0.6062
# Epoch: 223 | train_loss: 0.1336 | train_acc: 0.9600 | test_loss: 1.4922 | test_acc: 0.6229
# Epoch: 224 | train_loss: 0.1741 | train_acc: 0.9424 | test_loss: 1.5022 | test_acc: 0.6104
# Epoch: 225 | train_loss: 0.2381 | train_acc: 0.9221 | test_loss: 1.4308 | test_acc: 0.6188
# Epoch: 226 | train_loss: 0.1367 | train_acc: 0.9611 | test_loss: 1.5216 | test_acc: 0.6000
# Epoch: 227 | train_loss: 0.1308 | train_acc: 0.9583 | test_loss: 1.5332 | test_acc: 0.6125
# Epoch: 228 | train_loss: 0.1651 | train_acc: 0.9452 | test_loss: 1.5499 | test_acc: 0.6062
# Epoch: 229 | train_loss: 0.1734 | train_acc: 0.9446 | test_loss: 1.5275 | test_acc: 0.6021
# Epoch: 230 | train_loss: 0.1466 | train_acc: 0.9501 | test_loss: 1.5022 | test_acc: 0.6354
# Epoch: 231 | train_loss: 0.1724 | train_acc: 0.9441 | test_loss: 1.4602 | test_acc: 0.6229
# Epoch: 232 | train_loss: 0.1587 | train_acc: 0.9501 | test_loss: 1.4755 | test_acc: 0.6250
# Epoch: 233 | train_loss: 0.1452 | train_acc: 0.9545 | test_loss: 1.5123 | test_acc: 0.6250
# Epoch: 234 | train_loss: 0.1588 | train_acc: 0.9512 | test_loss: 1.5610 | test_acc: 0.6229
# Epoch: 235 | train_loss: 0.1691 | train_acc: 0.9435 | test_loss: 1.5071 | test_acc: 0.6375
# Epoch: 236 | train_loss: 0.1224 | train_acc: 0.9638 | test_loss: 1.5750 | test_acc: 0.6292
# Epoch: 237 | train_loss: 0.1509 | train_acc: 0.9561 | test_loss: 1.5131 | test_acc: 0.6271
# Epoch: 238 | train_loss: 0.1427 | train_acc: 0.9572 | test_loss: 1.4928 | test_acc: 0.6021
# Epoch: 239 | train_loss: 0.1592 | train_acc: 0.9485 | test_loss: 1.6575 | test_acc: 0.6083
# Epoch: 240 | train_loss: 0.1072 | train_acc: 0.9693 | test_loss: 1.5324 | test_acc: 0.6167
# Epoch: 241 | train_loss: 0.1293 | train_acc: 0.9594 | test_loss: 1.5269 | test_acc: 0.6250
# Epoch: 242 | train_loss: 0.1286 | train_acc: 0.9644 | test_loss: 1.5474 | test_acc: 0.6333
# Epoch: 243 | train_loss: 0.1405 | train_acc: 0.9523 | test_loss: 1.5597 | test_acc: 0.6333
# Epoch: 244 | train_loss: 0.0870 | train_acc: 0.9731 | test_loss: 1.5166 | test_acc: 0.6104
# Epoch: 245 | train_loss: 0.1375 | train_acc: 0.9594 | test_loss: 1.4909 | test_acc: 0.6271
# Epoch: 246 | train_loss: 0.1436 | train_acc: 0.9539 | test_loss: 1.6328 | test_acc: 0.6250
# Epoch: 247 | train_loss: 0.1803 | train_acc: 0.9386 | test_loss: 1.5600 | test_acc: 0.6333
# Epoch: 248 | train_loss: 0.1454 | train_acc: 0.9545 | test_loss: 1.5324 | test_acc: 0.6188
# Epoch: 249 | train_loss: 0.1768 | train_acc: 0.9485 | test_loss: 1.4747 | test_acc: 0.6229
# Epoch: 250 | train_loss: 0.1445 | train_acc: 0.9594 | test_loss: 1.4864 | test_acc: 0.6312
# Epoch: 251 | train_loss: 0.1391 | train_acc: 0.9534 | test_loss: 1.5908 | test_acc: 0.6333
# Epoch: 252 | train_loss: 0.1158 | train_acc: 0.9605 | test_loss: 1.5201 | test_acc: 0.6188
# Epoch: 253 | train_loss: 0.1117 | train_acc: 0.9644 | test_loss: 1.4931 | test_acc: 0.6292
# Epoch: 254 | train_loss: 0.1328 | train_acc: 0.9518 | test_loss: 1.6283 | test_acc: 0.6229
# Epoch: 255 | train_loss: 0.1085 | train_acc: 0.9649 | test_loss: 1.5513 | test_acc: 0.6188
# Epoch: 256 | train_loss: 0.1573 | train_acc: 0.9512 | test_loss: 1.5063 | test_acc: 0.6083
# Epoch: 257 | train_loss: 0.2122 | train_acc: 0.9238 | test_loss: 1.5376 | test_acc: 0.6229
# Epoch: 258 | train_loss: 0.1747 | train_acc: 0.9441 | test_loss: 1.6388 | test_acc: 0.6167
# Epoch: 259 | train_loss: 0.1346 | train_acc: 0.9611 | test_loss: 1.6277 | test_acc: 0.5750
# Epoch: 260 | train_loss: 0.1522 | train_acc: 0.9490 | test_loss: 1.5489 | test_acc: 0.6208
# Epoch: 261 | train_loss: 0.1331 | train_acc: 0.9567 | test_loss: 1.5887 | test_acc: 0.6125
# Epoch: 262 | train_loss: 0.1488 | train_acc: 0.9501 | test_loss: 1.7267 | test_acc: 0.6104
# Epoch: 263 | train_loss: 0.1696 | train_acc: 0.9479 | test_loss: 1.4797 | test_acc: 0.6208
# Epoch: 264 | train_loss: 0.1264 | train_acc: 0.9649 | test_loss: 1.4993 | test_acc: 0.6375
# Epoch: 265 | train_loss: 0.1560 | train_acc: 0.9485 | test_loss: 1.5160 | test_acc: 0.6354
# Epoch: 266 | train_loss: 0.0966 | train_acc: 0.9759 | test_loss: 1.4827 | test_acc: 0.6312
# Epoch: 267 | train_loss: 0.1368 | train_acc: 0.9611 | test_loss: 1.6439 | test_acc: 0.6167
# Epoch: 268 | train_loss: 0.1348 | train_acc: 0.9556 | test_loss: 1.5476 | test_acc: 0.6250
# Epoch: 269 | train_loss: 0.1667 | train_acc: 0.9479 | test_loss: 1.6684 | test_acc: 0.6271
# Epoch: 270 | train_loss: 0.1186 | train_acc: 0.9556 | test_loss: 1.5096 | test_acc: 0.6167
# Epoch: 271 | train_loss: 0.1235 | train_acc: 0.9611 | test_loss: 1.7080 | test_acc: 0.5583
# Epoch: 272 | train_loss: 0.1530 | train_acc: 0.9496 | test_loss: 1.5216 | test_acc: 0.6146
# Epoch: 273 | train_loss: 0.1165 | train_acc: 0.9622 | test_loss: 1.4464 | test_acc: 0.6167
# Epoch: 274 | train_loss: 0.1372 | train_acc: 0.9567 | test_loss: 1.4724 | test_acc: 0.6125
# Epoch: 275 | train_loss: 0.1484 | train_acc: 0.9529 | test_loss: 1.5317 | test_acc: 0.6479
# Epoch: 276 | train_loss: 0.1296 | train_acc: 0.9600 | test_loss: 1.4742 | test_acc: 0.6292
# Epoch: 277 | train_loss: 0.1213 | train_acc: 0.9600 | test_loss: 1.4067 | test_acc: 0.6354
# Epoch: 278 | train_loss: 0.1117 | train_acc: 0.9693 | test_loss: 1.4354 | test_acc: 0.6396
# Epoch: 279 | train_loss: 0.1401 | train_acc: 0.9550 | test_loss: 1.4365 | test_acc: 0.6375
# Epoch: 280 | train_loss: 0.0924 | train_acc: 0.9731 | test_loss: 1.4818 | test_acc: 0.6375
# Epoch: 281 | train_loss: 0.0883 | train_acc: 0.9698 | test_loss: 1.5002 | test_acc: 0.6354
# Epoch: 282 | train_loss: 0.1302 | train_acc: 0.9589 | test_loss: 1.4453 | test_acc: 0.6333
# Epoch: 283 | train_loss: 0.0933 | train_acc: 0.9693 | test_loss: 1.4806 | test_acc: 0.6458
# Epoch: 284 | train_loss: 0.1142 | train_acc: 0.9655 | test_loss: 1.4649 | test_acc: 0.6333
# Epoch: 285 | train_loss: 0.1059 | train_acc: 0.9698 | test_loss: 1.5314 | test_acc: 0.6125
# Epoch: 286 | train_loss: 0.0716 | train_acc: 0.9797 | test_loss: 1.4739 | test_acc: 0.6500
# Epoch: 287 | train_loss: 0.0818 | train_acc: 0.9742 | test_loss: 1.5710 | test_acc: 0.6375
# Epoch: 288 | train_loss: 0.0933 | train_acc: 0.9742 | test_loss: 1.5075 | test_acc: 0.6312
# Epoch: 289 | train_loss: 0.1399 | train_acc: 0.9567 | test_loss: 1.5623 | test_acc: 0.6042
# Epoch: 290 | train_loss: 0.0949 | train_acc: 0.9698 | test_loss: 1.5195 | test_acc: 0.6229
# Epoch: 291 | train_loss: 0.0878 | train_acc: 0.9720 | test_loss: 1.5612 | test_acc: 0.6208
# Epoch: 292 | train_loss: 0.1232 | train_acc: 0.9627 | test_loss: 1.4853 | test_acc: 0.6188
# Epoch: 293 | train_loss: 0.0985 | train_acc: 0.9671 | test_loss: 1.5522 | test_acc: 0.6104
# Epoch: 294 | train_loss: 0.1440 | train_acc: 0.9523 | test_loss: 1.6417 | test_acc: 0.6250
# Epoch: 295 | train_loss: 0.1380 | train_acc: 0.9583 | test_loss: 1.7156 | test_acc: 0.6271
# Epoch: 296 | train_loss: 0.0898 | train_acc: 0.9682 | test_loss: 1.5917 | test_acc: 0.6125
# Epoch: 297 | train_loss: 0.1036 | train_acc: 0.9709 | test_loss: 1.6230 | test_acc: 0.6125
# Epoch: 298 | train_loss: 0.0947 | train_acc: 0.9715 | test_loss: 1.5797 | test_acc: 0.6146
# Epoch: 299 | train_loss: 0.1226 | train_acc: 0.9677 | test_loss: 1.7548 | test_acc: 0.6229
# Epoch: 300 | train_loss: 0.1421 | train_acc: 0.9534 | test_loss: 1.5627 | test_acc: 0.6167
# Total training time: 327.153 seconds

# %%
plot_loss_curves(model_6_results, Save=True, filename="model_6_training")

# %% [markdown]
# Using data augmentation has helped in the training of the GRU as well. Overfitting is delayed and we see that the sudden increase of the loss values that appeared early in the training, has disappeared. There is an increase in the loss values here as well. However, it occurs after the 70th epoch and it happens more smoothly.

# %% [markdown]
# ## 10. Using early stopping to create the best model
#
# Using data augmentation helped our models a lot. We are going to include this method in the training of the best model of each architecture.
# Furthermore, we will use early stopping on the models trained with data augmentation, in order to have the best version of them. One for each architecture.

# %% [markdown]
# ### 10.1 Using early stopping with the RNN model
#
# Careful observation of previous training results lead us to the conclusion to train the next RNN model for 90 epochs.

# %%
# Instantiating a new RNN model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_7 = RNNClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_7
# Out:
# RNNClassifierV0(
#   (rnn): RNN(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_7.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 90

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_7
model_7_results = train_with_augmentation(model=model_7,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="melspec",
                                                             segments=3,
                                                             model_name="RNNClassifierV0",
                                                             extra="AST_options"
                                                             )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
# [INFO] Created SummaryWriter, saving to: C:\Users\thebo\Desktop\pytorch-genre-classifiers\runs\10-02-2026\melspec\3_segments\RNNClassifierV0\AST_options...
#   0%|          | 0/90 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2333 | train_acc: 0.1897 | test_loss: 2.1237 | test_acc: 0.2375
# Epoch: 2 | train_loss: 2.0687 | train_acc: 0.2747 | test_loss: 2.0073 | test_acc: 0.2729
# Epoch: 3 | train_loss: 1.9819 | train_acc: 0.2971 | test_loss: 1.9333 | test_acc: 0.3042
# Epoch: 4 | train_loss: 1.9172 | train_acc: 0.3114 | test_loss: 1.8794 | test_acc: 0.3146
# Epoch: 5 | train_loss: 1.8691 | train_acc: 0.3289 | test_loss: 1.8405 | test_acc: 0.3042
# Epoch: 6 | train_loss: 1.8225 | train_acc: 0.3542 | test_loss: 1.7963 | test_acc: 0.3875
# Epoch: 7 | train_loss: 1.7942 | train_acc: 0.3651 | test_loss: 1.7858 | test_acc: 0.3979
# Epoch: 8 | train_loss: 1.7481 | train_acc: 0.3777 | test_loss: 1.7494 | test_acc: 0.3792
# Epoch: 9 | train_loss: 1.7201 | train_acc: 0.3827 | test_loss: 1.7319 | test_acc: 0.3729
# Epoch: 10 | train_loss: 1.6932 | train_acc: 0.4150 | test_loss: 1.7354 | test_acc: 0.3333
# Epoch: 11 | train_loss: 1.6669 | train_acc: 0.4128 | test_loss: 1.7229 | test_acc: 0.3708
# Epoch: 12 | train_loss: 1.6618 | train_acc: 0.4211 | test_loss: 1.7138 | test_acc: 0.3375
# Epoch: 13 | train_loss: 1.6238 | train_acc: 0.4380 | test_loss: 1.7121 | test_acc: 0.3521
# Epoch: 14 | train_loss: 1.6079 | train_acc: 0.4298 | test_loss: 1.7007 | test_acc: 0.3625
# Epoch: 15 | train_loss: 1.5958 | train_acc: 0.4386 | test_loss: 1.7376 | test_acc: 0.3625
# Epoch: 16 | train_loss: 1.5976 | train_acc: 0.4446 | test_loss: 1.7036 | test_acc: 0.3583
# Epoch: 17 | train_loss: 1.5386 | train_acc: 0.4512 | test_loss: 1.6967 | test_acc: 0.3833
# Epoch: 18 | train_loss: 1.5567 | train_acc: 0.4468 | test_loss: 1.6882 | test_acc: 0.3771
# Epoch: 19 | train_loss: 1.5141 | train_acc: 0.4715 | test_loss: 1.6931 | test_acc: 0.3688
# Epoch: 20 | train_loss: 1.4950 | train_acc: 0.4742 | test_loss: 1.6838 | test_acc: 0.3729
# Epoch: 21 | train_loss: 1.4609 | train_acc: 0.4973 | test_loss: 1.6775 | test_acc: 0.3854
# Epoch: 22 | train_loss: 1.4958 | train_acc: 0.4715 | test_loss: 1.6837 | test_acc: 0.3771
# Epoch: 23 | train_loss: 1.4611 | train_acc: 0.4874 | test_loss: 1.7123 | test_acc: 0.3688
# Epoch: 24 | train_loss: 1.4807 | train_acc: 0.4830 | test_loss: 1.6706 | test_acc: 0.3833
# Epoch: 25 | train_loss: 1.4271 | train_acc: 0.5016 | test_loss: 1.6525 | test_acc: 0.3854
# Epoch: 26 | train_loss: 1.4161 | train_acc: 0.5033 | test_loss: 1.6748 | test_acc: 0.4021
# Epoch: 27 | train_loss: 1.4141 | train_acc: 0.5011 | test_loss: 1.6541 | test_acc: 0.3688
# Epoch: 28 | train_loss: 1.4302 | train_acc: 0.5000 | test_loss: 1.6825 | test_acc: 0.3937
# Epoch: 29 | train_loss: 1.3913 | train_acc: 0.5164 | test_loss: 1.6697 | test_acc: 0.3812
# Epoch: 30 | train_loss: 1.3871 | train_acc: 0.5225 | test_loss: 1.6537 | test_acc: 0.3917
# Epoch: 31 | train_loss: 1.4628 | train_acc: 0.4995 | test_loss: 1.6805 | test_acc: 0.3833
# Epoch: 32 | train_loss: 1.3869 | train_acc: 0.5318 | test_loss: 1.6637 | test_acc: 0.3729
# Epoch: 33 | train_loss: 1.5356 | train_acc: 0.4868 | test_loss: 1.9476 | test_acc: 0.3271
# Epoch: 34 | train_loss: 1.5092 | train_acc: 0.4764 | test_loss: 1.6407 | test_acc: 0.3937
# Epoch: 35 | train_loss: 1.4303 | train_acc: 0.5099 | test_loss: 1.6380 | test_acc: 0.4042
# Epoch: 36 | train_loss: 1.4015 | train_acc: 0.5148 | test_loss: 1.6580 | test_acc: 0.4292
# Epoch: 37 | train_loss: 1.4053 | train_acc: 0.5093 | test_loss: 1.6518 | test_acc: 0.4062
# Epoch: 38 | train_loss: 1.3856 | train_acc: 0.5236 | test_loss: 1.6615 | test_acc: 0.4333
# Epoch: 39 | train_loss: 1.3339 | train_acc: 0.5428 | test_loss: 1.6335 | test_acc: 0.4125
# Epoch: 40 | train_loss: 1.3405 | train_acc: 0.5428 | test_loss: 1.6449 | test_acc: 0.4104
# Epoch: 41 | train_loss: 1.2807 | train_acc: 0.5620 | test_loss: 1.6619 | test_acc: 0.3937
# Epoch: 42 | train_loss: 1.2819 | train_acc: 0.5598 | test_loss: 1.6380 | test_acc: 0.4000
# Epoch: 43 | train_loss: 1.2884 | train_acc: 0.5647 | test_loss: 1.6424 | test_acc: 0.4125
# Epoch: 44 | train_loss: 1.2994 | train_acc: 0.5543 | test_loss: 1.6579 | test_acc: 0.4000
# Epoch: 45 | train_loss: 1.3309 | train_acc: 0.5389 | test_loss: 1.6740 | test_acc: 0.3937
# Epoch: 46 | train_loss: 1.2974 | train_acc: 0.5614 | test_loss: 1.6397 | test_acc: 0.4042
# Epoch: 47 | train_loss: 1.2729 | train_acc: 0.5685 | test_loss: 1.6258 | test_acc: 0.3979
# Epoch: 48 | train_loss: 1.2762 | train_acc: 0.5762 | test_loss: 1.6384 | test_acc: 0.3958
# Epoch: 49 | train_loss: 1.2455 | train_acc: 0.5795 | test_loss: 1.6312 | test_acc: 0.4000
# Epoch: 50 | train_loss: 1.2475 | train_acc: 0.5663 | test_loss: 1.6624 | test_acc: 0.4125
# Epoch: 51 | train_loss: 1.2016 | train_acc: 0.5959 | test_loss: 1.6616 | test_acc: 0.4125
# Epoch: 52 | train_loss: 1.2624 | train_acc: 0.5603 | test_loss: 1.6492 | test_acc: 0.4062
# Epoch: 53 | train_loss: 1.2141 | train_acc: 0.5883 | test_loss: 1.6459 | test_acc: 0.4125
# Epoch: 54 | train_loss: 1.2275 | train_acc: 0.5927 | test_loss: 1.6742 | test_acc: 0.3979
# Epoch: 55 | train_loss: 1.1728 | train_acc: 0.6179 | test_loss: 1.6671 | test_acc: 0.4188
# Epoch: 56 | train_loss: 1.1914 | train_acc: 0.6096 | test_loss: 1.6366 | test_acc: 0.4208
# Epoch: 57 | train_loss: 1.1675 | train_acc: 0.6058 | test_loss: 1.6288 | test_acc: 0.4188
# Epoch: 58 | train_loss: 1.1776 | train_acc: 0.5998 | test_loss: 1.6098 | test_acc: 0.4146
# Epoch: 59 | train_loss: 1.1556 | train_acc: 0.6250 | test_loss: 1.5982 | test_acc: 0.4250
# Epoch: 60 | train_loss: 1.2072 | train_acc: 0.5806 | test_loss: 1.6029 | test_acc: 0.4208
# Epoch: 61 | train_loss: 1.1511 | train_acc: 0.6064 | test_loss: 1.6308 | test_acc: 0.4146
# Epoch: 62 | train_loss: 1.1619 | train_acc: 0.6031 | test_loss: 1.6177 | test_acc: 0.4167
# Epoch: 63 | train_loss: 1.1442 | train_acc: 0.6064 | test_loss: 1.6039 | test_acc: 0.4375
# Epoch: 64 | train_loss: 1.1349 | train_acc: 0.6096 | test_loss: 1.6245 | test_acc: 0.4250
# Epoch: 65 | train_loss: 1.1446 | train_acc: 0.6173 | test_loss: 1.6071 | test_acc: 0.4417
# Epoch: 66 | train_loss: 1.1388 | train_acc: 0.6124 | test_loss: 1.5843 | test_acc: 0.4042
# Epoch: 67 | train_loss: 1.0960 | train_acc: 0.6338 | test_loss: 1.6478 | test_acc: 0.4104
# Epoch: 68 | train_loss: 1.1464 | train_acc: 0.6113 | test_loss: 1.5874 | test_acc: 0.4250
# Epoch: 69 | train_loss: 1.1010 | train_acc: 0.6414 | test_loss: 1.6400 | test_acc: 0.4125
# Epoch: 70 | train_loss: 1.0943 | train_acc: 0.6266 | test_loss: 1.5777 | test_acc: 0.4125
# Epoch: 71 | train_loss: 1.0542 | train_acc: 0.6409 | test_loss: 1.6257 | test_acc: 0.4188
# Epoch: 72 | train_loss: 1.1230 | train_acc: 0.6118 | test_loss: 1.6370 | test_acc: 0.4021
# Epoch: 73 | train_loss: 1.0781 | train_acc: 0.6442 | test_loss: 1.6114 | test_acc: 0.4042
# Epoch: 74 | train_loss: 1.0183 | train_acc: 0.6628 | test_loss: 1.6466 | test_acc: 0.4208
# Epoch: 75 | train_loss: 1.0585 | train_acc: 0.6453 | test_loss: 1.6287 | test_acc: 0.3979
# Epoch: 76 | train_loss: 1.0642 | train_acc: 0.6332 | test_loss: 1.6180 | test_acc: 0.4062
# Epoch: 77 | train_loss: 1.0516 | train_acc: 0.6338 | test_loss: 1.6145 | test_acc: 0.4167
# Epoch: 78 | train_loss: 1.0457 | train_acc: 0.6447 | test_loss: 1.6024 | test_acc: 0.4167
# Epoch: 79 | train_loss: 1.0755 | train_acc: 0.6332 | test_loss: 1.6156 | test_acc: 0.4437
# Epoch: 80 | train_loss: 1.0104 | train_acc: 0.6639 | test_loss: 1.6572 | test_acc: 0.4292
# Epoch: 81 | train_loss: 1.0088 | train_acc: 0.6612 | test_loss: 1.6422 | test_acc: 0.4125
# Epoch: 82 | train_loss: 1.0561 | train_acc: 0.6442 | test_loss: 1.6574 | test_acc: 0.4250
# Epoch: 83 | train_loss: 1.0260 | train_acc: 0.6552 | test_loss: 1.6468 | test_acc: 0.4167
# Epoch: 84 | train_loss: 0.9901 | train_acc: 0.6700 | test_loss: 1.6174 | test_acc: 0.4313
# Epoch: 85 | train_loss: 1.0081 | train_acc: 0.6683 | test_loss: 1.6040 | test_acc: 0.4313
# Epoch: 86 | train_loss: 1.0393 | train_acc: 0.6508 | test_loss: 1.5930 | test_acc: 0.4375
# Epoch: 87 | train_loss: 0.9804 | train_acc: 0.6700 | test_loss: 1.6492 | test_acc: 0.4229
# Epoch: 88 | train_loss: 0.9736 | train_acc: 0.6787 | test_loss: 1.6373 | test_acc: 0.4542
# Epoch: 89 | train_loss: 0.9535 | train_acc: 0.6804 | test_loss: 1.6684 | test_acc: 0.4208
# Epoch: 90 | train_loss: 0.9898 | train_acc: 0.6689 | test_loss: 1.6489 | test_acc: 0.4208
# Total training time: 62.299 seconds

# %%
plot_loss_curves(model_7_results, Save=True, filename="model_7_training")

# %% [markdown]
# ### 10.2 Using early stopping with the LSTM model
#
# Careful observation of previous training results lead us to the conclusion to train the next RNN model for 120 epochs.

# %%
# Instantiating a new LSTM model and putting it to device
torch.manual_seed(RANDOM_SEED)
model_8 = LSTMClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_8
# Out:
# LSTMClassifierV0(
#   (lstm): LSTM(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_8.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 120

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_8
model_8_results = train_with_augmentation(model=model_8,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="melspec",
                                                             segments=3,
                                                             model_name="LSTMClassifierV0",
                                                             extra="AST_options"
                                                             )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
# [INFO] Created SummaryWriter, saving to: C:\Users\thebo\Desktop\pytorch-genre-classifiers\runs\10-02-2026\melspec\3_segments\LSTMClassifierV0\AST_options...
#   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2741 | train_acc: 0.1859 | test_loss: 2.2263 | test_acc: 0.2812
# Epoch: 2 | train_loss: 2.1717 | train_acc: 0.3010 | test_loss: 2.0974 | test_acc: 0.2896
# Epoch: 3 | train_loss: 2.0286 | train_acc: 0.3070 | test_loss: 1.9568 | test_acc: 0.3146
# Epoch: 4 | train_loss: 1.8866 | train_acc: 0.3454 | test_loss: 1.7882 | test_acc: 0.3583
# Epoch: 5 | train_loss: 1.7497 | train_acc: 0.3936 | test_loss: 1.6834 | test_acc: 0.3729
# Epoch: 6 | train_loss: 1.6711 | train_acc: 0.4156 | test_loss: 1.5984 | test_acc: 0.4708
# Epoch: 7 | train_loss: 1.6191 | train_acc: 0.4364 | test_loss: 1.5782 | test_acc: 0.4021
# Epoch: 8 | train_loss: 1.5510 | train_acc: 0.4633 | test_loss: 1.6182 | test_acc: 0.3937
# Epoch: 9 | train_loss: 1.5228 | train_acc: 0.4682 | test_loss: 1.5741 | test_acc: 0.4167
# Epoch: 10 | train_loss: 1.4938 | train_acc: 0.4786 | test_loss: 1.5257 | test_acc: 0.4229
# Epoch: 11 | train_loss: 1.4609 | train_acc: 0.4803 | test_loss: 1.5030 | test_acc: 0.4375
# Epoch: 12 | train_loss: 1.4249 | train_acc: 0.4995 | test_loss: 1.4992 | test_acc: 0.4417
# Epoch: 13 | train_loss: 1.4351 | train_acc: 0.4929 | test_loss: 1.4719 | test_acc: 0.4333
# Epoch: 14 | train_loss: 1.3662 | train_acc: 0.5230 | test_loss: 1.4547 | test_acc: 0.4396
# Epoch: 15 | train_loss: 1.3609 | train_acc: 0.5345 | test_loss: 1.4220 | test_acc: 0.4375
# Epoch: 16 | train_loss: 1.3510 | train_acc: 0.5214 | test_loss: 1.4317 | test_acc: 0.4708
# Epoch: 17 | train_loss: 1.3132 | train_acc: 0.5466 | test_loss: 1.4992 | test_acc: 0.4375
# Epoch: 18 | train_loss: 1.3458 | train_acc: 0.5126 | test_loss: 1.4641 | test_acc: 0.4417
# Epoch: 19 | train_loss: 1.2740 | train_acc: 0.5504 | test_loss: 1.4412 | test_acc: 0.4562
# Epoch: 20 | train_loss: 1.3054 | train_acc: 0.5258 | test_loss: 1.4959 | test_acc: 0.4667
# Epoch: 21 | train_loss: 1.2668 | train_acc: 0.5609 | test_loss: 1.4783 | test_acc: 0.4625
# Epoch: 22 | train_loss: 1.2384 | train_acc: 0.5685 | test_loss: 1.4884 | test_acc: 0.4667
# Epoch: 23 | train_loss: 1.2275 | train_acc: 0.5768 | test_loss: 1.4527 | test_acc: 0.5062
# Epoch: 24 | train_loss: 1.2486 | train_acc: 0.5630 | test_loss: 1.4131 | test_acc: 0.4750
# Epoch: 25 | train_loss: 1.2179 | train_acc: 0.5888 | test_loss: 1.3769 | test_acc: 0.5042
# Epoch: 26 | train_loss: 1.2209 | train_acc: 0.5844 | test_loss: 1.4131 | test_acc: 0.4646
# Epoch: 27 | train_loss: 1.1793 | train_acc: 0.5970 | test_loss: 1.3770 | test_acc: 0.5000
# Epoch: 28 | train_loss: 1.1416 | train_acc: 0.6009 | test_loss: 1.3785 | test_acc: 0.5000
# Epoch: 29 | train_loss: 1.1493 | train_acc: 0.6091 | test_loss: 1.3685 | test_acc: 0.4938
# Epoch: 30 | train_loss: 1.1088 | train_acc: 0.6255 | test_loss: 1.3513 | test_acc: 0.5083
# Epoch: 31 | train_loss: 1.0997 | train_acc: 0.6124 | test_loss: 1.3387 | test_acc: 0.5188
# Epoch: 32 | train_loss: 1.1422 | train_acc: 0.6020 | test_loss: 1.3811 | test_acc: 0.4958
# Epoch: 33 | train_loss: 1.1497 | train_acc: 0.6069 | test_loss: 1.7557 | test_acc: 0.3563
# Epoch: 34 | train_loss: 1.3533 | train_acc: 0.5280 | test_loss: 1.4675 | test_acc: 0.4646
# Epoch: 35 | train_loss: 1.1971 | train_acc: 0.5855 | test_loss: 1.4038 | test_acc: 0.4792
# Epoch: 36 | train_loss: 1.1527 | train_acc: 0.5976 | test_loss: 1.4132 | test_acc: 0.4792
# Epoch: 37 | train_loss: 1.1072 | train_acc: 0.6228 | test_loss: 1.3770 | test_acc: 0.5042
# Epoch: 38 | train_loss: 1.0867 | train_acc: 0.6365 | test_loss: 1.3571 | test_acc: 0.5104
# Epoch: 39 | train_loss: 1.0622 | train_acc: 0.6349 | test_loss: 1.3946 | test_acc: 0.4729
# Epoch: 40 | train_loss: 1.1041 | train_acc: 0.6080 | test_loss: 1.3996 | test_acc: 0.4813
# Epoch: 41 | train_loss: 1.0631 | train_acc: 0.6261 | test_loss: 1.4007 | test_acc: 0.4750
# Epoch: 42 | train_loss: 1.0339 | train_acc: 0.6447 | test_loss: 1.4218 | test_acc: 0.4708
# Epoch: 43 | train_loss: 1.0923 | train_acc: 0.6239 | test_loss: 1.3634 | test_acc: 0.4979
# Epoch: 44 | train_loss: 1.2615 | train_acc: 0.5768 | test_loss: 1.4147 | test_acc: 0.4979
# Epoch: 45 | train_loss: 1.1412 | train_acc: 0.5992 | test_loss: 1.4403 | test_acc: 0.4917
# Epoch: 46 | train_loss: 1.1478 | train_acc: 0.6003 | test_loss: 1.4219 | test_acc: 0.4708
# Epoch: 47 | train_loss: 1.0626 | train_acc: 0.6436 | test_loss: 1.4563 | test_acc: 0.4979
# Epoch: 48 | train_loss: 1.0482 | train_acc: 0.6398 | test_loss: 1.4465 | test_acc: 0.4771
# Epoch: 49 | train_loss: 1.0523 | train_acc: 0.6332 | test_loss: 1.3946 | test_acc: 0.4833
# Epoch: 50 | train_loss: 1.0628 | train_acc: 0.6299 | test_loss: 1.4228 | test_acc: 0.5208
# Epoch: 51 | train_loss: 1.0769 | train_acc: 0.6332 | test_loss: 2.2441 | test_acc: 0.3896
# Epoch: 52 | train_loss: 1.5540 | train_acc: 0.5104 | test_loss: 1.6996 | test_acc: 0.4562
# Epoch: 53 | train_loss: 1.2599 | train_acc: 0.5515 | test_loss: 1.5237 | test_acc: 0.4813
# Epoch: 54 | train_loss: 1.1832 | train_acc: 0.5927 | test_loss: 1.4686 | test_acc: 0.5021
# Epoch: 55 | train_loss: 1.1546 | train_acc: 0.6047 | test_loss: 1.4566 | test_acc: 0.4750
# Epoch: 56 | train_loss: 1.0735 | train_acc: 0.6316 | test_loss: 1.4081 | test_acc: 0.5208
# Epoch: 57 | train_loss: 1.0652 | train_acc: 0.6436 | test_loss: 1.3780 | test_acc: 0.5104
# Epoch: 58 | train_loss: 1.0306 | train_acc: 0.6562 | test_loss: 1.3907 | test_acc: 0.5188
# Epoch: 59 | train_loss: 0.9427 | train_acc: 0.6963 | test_loss: 1.3555 | test_acc: 0.5188
# Epoch: 60 | train_loss: 1.0039 | train_acc: 0.6683 | test_loss: 1.3686 | test_acc: 0.5188
# Epoch: 61 | train_loss: 1.0287 | train_acc: 0.6524 | test_loss: 1.3110 | test_acc: 0.5167
# Epoch: 62 | train_loss: 0.9749 | train_acc: 0.6798 | test_loss: 1.3790 | test_acc: 0.5167
# Epoch: 63 | train_loss: 0.9153 | train_acc: 0.6859 | test_loss: 1.3743 | test_acc: 0.5062
# Epoch: 64 | train_loss: 0.9389 | train_acc: 0.6853 | test_loss: 1.4289 | test_acc: 0.5125
# Epoch: 65 | train_loss: 0.9276 | train_acc: 0.6798 | test_loss: 1.4753 | test_acc: 0.5021
# Epoch: 66 | train_loss: 0.8645 | train_acc: 0.7188 | test_loss: 1.4082 | test_acc: 0.5271
# Epoch: 67 | train_loss: 0.8546 | train_acc: 0.7155 | test_loss: 1.3675 | test_acc: 0.5312
# Epoch: 68 | train_loss: 0.8966 | train_acc: 0.7007 | test_loss: 1.3300 | test_acc: 0.5354
# Epoch: 69 | train_loss: 0.8502 | train_acc: 0.7122 | test_loss: 1.3632 | test_acc: 0.5292
# Epoch: 70 | train_loss: 0.8819 | train_acc: 0.7039 | test_loss: 1.3355 | test_acc: 0.5750
# Epoch: 71 | train_loss: 0.8739 | train_acc: 0.7067 | test_loss: 1.3636 | test_acc: 0.5312
# Epoch: 72 | train_loss: 0.9182 | train_acc: 0.6957 | test_loss: 1.3756 | test_acc: 0.5271
# Epoch: 73 | train_loss: 0.9024 | train_acc: 0.6919 | test_loss: 1.3373 | test_acc: 0.5271
# Epoch: 74 | train_loss: 0.9048 | train_acc: 0.7061 | test_loss: 1.3359 | test_acc: 0.5229
# Epoch: 75 | train_loss: 0.9196 | train_acc: 0.6968 | test_loss: 1.4841 | test_acc: 0.4979
# Epoch: 76 | train_loss: 0.9030 | train_acc: 0.7001 | test_loss: 1.3501 | test_acc: 0.5167
# Epoch: 77 | train_loss: 0.8649 | train_acc: 0.7155 | test_loss: 1.3463 | test_acc: 0.5312
# Epoch: 78 | train_loss: 0.8537 | train_acc: 0.7177 | test_loss: 1.4690 | test_acc: 0.4875
# Epoch: 79 | train_loss: 0.8313 | train_acc: 0.7149 | test_loss: 1.4011 | test_acc: 0.5062
# Epoch: 80 | train_loss: 0.8135 | train_acc: 0.7314 | test_loss: 1.3910 | test_acc: 0.5188
# Epoch: 81 | train_loss: 0.8706 | train_acc: 0.7001 | test_loss: 1.4030 | test_acc: 0.4875
# Epoch: 82 | train_loss: 0.8000 | train_acc: 0.7286 | test_loss: 1.3674 | test_acc: 0.5333
# Epoch: 83 | train_loss: 0.8717 | train_acc: 0.7105 | test_loss: 1.3070 | test_acc: 0.5146
# Epoch: 84 | train_loss: 0.7630 | train_acc: 0.7566 | test_loss: 1.3442 | test_acc: 0.5563
# Epoch: 85 | train_loss: 0.7809 | train_acc: 0.7462 | test_loss: 1.3517 | test_acc: 0.5479
# Epoch: 86 | train_loss: 0.7901 | train_acc: 0.7297 | test_loss: 1.3352 | test_acc: 0.5292
# Epoch: 87 | train_loss: 0.6650 | train_acc: 0.7763 | test_loss: 1.4447 | test_acc: 0.5312
# Epoch: 88 | train_loss: 0.8216 | train_acc: 0.7379 | test_loss: 1.3885 | test_acc: 0.5292
# Epoch: 89 | train_loss: 0.7595 | train_acc: 0.7516 | test_loss: 1.4113 | test_acc: 0.5354
# Epoch: 90 | train_loss: 0.7666 | train_acc: 0.7451 | test_loss: 1.3562 | test_acc: 0.5250
# Epoch: 91 | train_loss: 0.7968 | train_acc: 0.7368 | test_loss: 1.3727 | test_acc: 0.5292
# Epoch: 92 | train_loss: 0.8149 | train_acc: 0.7215 | test_loss: 1.3847 | test_acc: 0.5250
# Epoch: 93 | train_loss: 0.8672 | train_acc: 0.7094 | test_loss: 1.4176 | test_acc: 0.5188
# Epoch: 94 | train_loss: 0.8230 | train_acc: 0.7401 | test_loss: 1.3753 | test_acc: 0.5271
# Epoch: 95 | train_loss: 0.7331 | train_acc: 0.7516 | test_loss: 1.3444 | test_acc: 0.5167
# Epoch: 96 | train_loss: 0.7442 | train_acc: 0.7505 | test_loss: 1.3581 | test_acc: 0.5521
# Epoch: 97 | train_loss: 0.7306 | train_acc: 0.7533 | test_loss: 1.3664 | test_acc: 0.5354
# Epoch: 98 | train_loss: 0.7031 | train_acc: 0.7675 | test_loss: 1.4083 | test_acc: 0.5417
# Epoch: 99 | train_loss: 0.7383 | train_acc: 0.7566 | test_loss: 1.3766 | test_acc: 0.5229
# Epoch: 100 | train_loss: 0.6935 | train_acc: 0.7758 | test_loss: 1.3978 | test_acc: 0.5188
# Epoch: 101 | train_loss: 0.7176 | train_acc: 0.7577 | test_loss: 1.3965 | test_acc: 0.5354
# Epoch: 102 | train_loss: 0.6522 | train_acc: 0.7928 | test_loss: 1.3291 | test_acc: 0.5896
# Epoch: 103 | train_loss: 0.7257 | train_acc: 0.7632 | test_loss: 1.3544 | test_acc: 0.5125
# Epoch: 104 | train_loss: 0.7213 | train_acc: 0.7610 | test_loss: 1.3794 | test_acc: 0.5312
# Epoch: 105 | train_loss: 0.6541 | train_acc: 0.7856 | test_loss: 1.3143 | test_acc: 0.5396
# Epoch: 106 | train_loss: 0.7282 | train_acc: 0.7697 | test_loss: 1.4302 | test_acc: 0.5396
# Epoch: 107 | train_loss: 0.7094 | train_acc: 0.7758 | test_loss: 1.3705 | test_acc: 0.5208
# Epoch: 108 | train_loss: 0.6943 | train_acc: 0.7692 | test_loss: 1.3166 | test_acc: 0.5729
# Epoch: 109 | train_loss: 0.6172 | train_acc: 0.8004 | test_loss: 1.5104 | test_acc: 0.5312
# Epoch: 110 | train_loss: 0.6664 | train_acc: 0.7725 | test_loss: 1.3802 | test_acc: 0.5271
# Epoch: 111 | train_loss: 0.6725 | train_acc: 0.7812 | test_loss: 1.3924 | test_acc: 0.5375
# Epoch: 112 | train_loss: 0.6719 | train_acc: 0.7802 | test_loss: 1.4222 | test_acc: 0.5437
# Epoch: 113 | train_loss: 0.6606 | train_acc: 0.7818 | test_loss: 1.4222 | test_acc: 0.5417
# Epoch: 114 | train_loss: 0.6837 | train_acc: 0.7845 | test_loss: 1.3644 | test_acc: 0.5792
# Epoch: 115 | train_loss: 0.6340 | train_acc: 0.7867 | test_loss: 1.3675 | test_acc: 0.5583
# Epoch: 116 | train_loss: 0.6684 | train_acc: 0.7818 | test_loss: 1.3441 | test_acc: 0.5687
# Epoch: 117 | train_loss: 0.6413 | train_acc: 0.7895 | test_loss: 1.2861 | test_acc: 0.6250
# Epoch: 118 | train_loss: 0.6473 | train_acc: 0.7873 | test_loss: 1.3959 | test_acc: 0.5479
# Epoch: 119 | train_loss: 0.6762 | train_acc: 0.7818 | test_loss: 1.4925 | test_acc: 0.5292
# Epoch: 120 | train_loss: 0.6499 | train_acc: 0.7906 | test_loss: 1.2948 | test_acc: 0.5708
# Total training time: 196.806 seconds

# %%
plot_loss_curves(model_8_results, Save=True, filename="model_8_training")

# %% [markdown]
# ### 10.3 Using early stopping with the GRU model
#
# Careful observation of previous training results lead us to the conclusion to train the next RNN model for 40 epochs.

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_9 = GRUClassifierV0(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES).to(device)
model_9
# Out:
# GRUClassifierV0(
#   (gru): GRU(128, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_9.parameters(),
                             lr=0.0001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 40

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_9
model_9_results = train_with_augmentation(model=model_9,
                                        train_dataloader=train_dataloader,
                                        test_dataloader=validation_dataloader,
                                        optimizer=optimizer,
                                        loss_fn=loss_fn,
                                        epochs=NUM_EPOCHS,
                                        writer=create_writer(source="melspec",
                                                             segments=3,
                                                             model_name="GRUClassifierV0",
                                                             extra="AST_options"
                                                             )
                                        )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
# [INFO] Created SummaryWriter, saving to: C:\Users\thebo\Desktop\pytorch-genre-classifiers\runs\11-02-2026\melspec\3_segments\GRUClassifierV0\AST_options...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.2144 | train_acc: 0.1985 | test_loss: 2.1101 | test_acc: 0.2604
# Epoch: 2 | train_loss: 2.0469 | train_acc: 0.2829 | test_loss: 1.9773 | test_acc: 0.3083
# Epoch: 3 | train_loss: 1.9238 | train_acc: 0.3273 | test_loss: 1.8861 | test_acc: 0.3312
# Epoch: 4 | train_loss: 1.8381 | train_acc: 0.3586 | test_loss: 1.8053 | test_acc: 0.3479
# Epoch: 5 | train_loss: 1.7784 | train_acc: 0.3717 | test_loss: 1.7510 | test_acc: 0.3604
# Epoch: 6 | train_loss: 1.7073 | train_acc: 0.4024 | test_loss: 1.7057 | test_acc: 0.3625
# Epoch: 7 | train_loss: 1.6792 | train_acc: 0.3914 | test_loss: 1.6672 | test_acc: 0.3833
# Epoch: 8 | train_loss: 1.6025 | train_acc: 0.4304 | test_loss: 1.6328 | test_acc: 0.3937
# Epoch: 9 | train_loss: 1.5564 | train_acc: 0.4550 | test_loss: 1.5958 | test_acc: 0.4125
# Epoch: 10 | train_loss: 1.5011 | train_acc: 0.4770 | test_loss: 1.5658 | test_acc: 0.4271
# Epoch: 11 | train_loss: 1.4824 | train_acc: 0.4912 | test_loss: 1.5330 | test_acc: 0.4313
# Epoch: 12 | train_loss: 1.4557 | train_acc: 0.4940 | test_loss: 1.5242 | test_acc: 0.4542
# Epoch: 13 | train_loss: 1.4032 | train_acc: 0.5121 | test_loss: 1.4961 | test_acc: 0.4625
# Epoch: 14 | train_loss: 1.3693 | train_acc: 0.5258 | test_loss: 1.5015 | test_acc: 0.4521
# Epoch: 15 | train_loss: 1.3323 | train_acc: 0.5493 | test_loss: 1.4489 | test_acc: 0.4708
# Epoch: 16 | train_loss: 1.2802 | train_acc: 0.5614 | test_loss: 1.4466 | test_acc: 0.4583
# Epoch: 17 | train_loss: 1.2736 | train_acc: 0.5592 | test_loss: 1.4330 | test_acc: 0.4875
# Epoch: 18 | train_loss: 1.2261 | train_acc: 0.5905 | test_loss: 1.4498 | test_acc: 0.4771
# Epoch: 19 | train_loss: 1.1774 | train_acc: 0.5992 | test_loss: 1.4193 | test_acc: 0.5042
# Epoch: 20 | train_loss: 1.2285 | train_acc: 0.5866 | test_loss: 1.3845 | test_acc: 0.4979
# Epoch: 21 | train_loss: 1.1662 | train_acc: 0.5954 | test_loss: 1.3643 | test_acc: 0.4875
# Epoch: 22 | train_loss: 1.1133 | train_acc: 0.6354 | test_loss: 1.3748 | test_acc: 0.4875
# Epoch: 23 | train_loss: 1.0818 | train_acc: 0.6398 | test_loss: 1.3842 | test_acc: 0.5042
# Epoch: 24 | train_loss: 1.0650 | train_acc: 0.6414 | test_loss: 1.3409 | test_acc: 0.4958
# Epoch: 25 | train_loss: 1.0316 | train_acc: 0.6645 | test_loss: 1.3298 | test_acc: 0.4896
# Epoch: 26 | train_loss: 0.9945 | train_acc: 0.6617 | test_loss: 1.4671 | test_acc: 0.4875
# Epoch: 27 | train_loss: 0.9806 | train_acc: 0.6732 | test_loss: 1.4127 | test_acc: 0.5083
# Epoch: 28 | train_loss: 0.9621 | train_acc: 0.6842 | test_loss: 1.3597 | test_acc: 0.5083
# Epoch: 29 | train_loss: 0.9485 | train_acc: 0.6826 | test_loss: 1.3498 | test_acc: 0.5167
# Epoch: 30 | train_loss: 0.9226 | train_acc: 0.6897 | test_loss: 1.3146 | test_acc: 0.5125
# Epoch: 31 | train_loss: 0.9174 | train_acc: 0.6913 | test_loss: 1.3721 | test_acc: 0.5125
# Epoch: 32 | train_loss: 0.9470 | train_acc: 0.6732 | test_loss: 1.3020 | test_acc: 0.5208
# Epoch: 33 | train_loss: 0.9002 | train_acc: 0.6974 | test_loss: 1.2924 | test_acc: 0.5417
# Epoch: 34 | train_loss: 0.8442 | train_acc: 0.7237 | test_loss: 1.3176 | test_acc: 0.5229
# Epoch: 35 | train_loss: 0.8198 | train_acc: 0.7336 | test_loss: 1.3358 | test_acc: 0.5250
# Epoch: 36 | train_loss: 0.7940 | train_acc: 0.7330 | test_loss: 1.3251 | test_acc: 0.5292
# Epoch: 37 | train_loss: 0.8253 | train_acc: 0.7368 | test_loss: 1.3504 | test_acc: 0.5271
# Epoch: 38 | train_loss: 0.7849 | train_acc: 0.7511 | test_loss: 1.3947 | test_acc: 0.5188
# Epoch: 39 | train_loss: 0.7666 | train_acc: 0.7516 | test_loss: 1.3449 | test_acc: 0.5229
# Epoch: 40 | train_loss: 0.7712 | train_acc: 0.7544 | test_loss: 1.3608 | test_acc: 0.5229
# Total training time: 39.170 seconds

# %%
plot_loss_curves(model_9_results, Save=True, filename="model_9_training")

# %% [markdown]
# ## 11. Evaluating our models on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate our models.

# %%
# Evaluate the RNN on the test set
evaluation = test_step(model=model_7,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 1.6383 | test acc = 0.4459

# %%
# Evaluate the LSTM on the test set
evaluation = test_step(model=model_8,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 1.2629 | test acc = 0.5859

# %%
# Evaluate the GRU on the test set
evaluation = test_step(model=model_9,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 1.2127 | test acc = 0.5712

# %% [markdown]
# We can see that the GRU had the best performance out of the three models as it scored an accuracy of 85% which is very good considering we have 10 classes. The LSTN follows with an accuracy of 83%. The RNN comes next with an accuracy of 68%.

# %% [markdown]
# ## 12. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use `model_3` to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2499 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilites first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.
#
# Changing the `model` and `index` arguments on the `predict()` function can let us make further testing.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Printing the shape to see how many indexes we have
X_test.shape
# Out:
# torch.Size([750, 997, 128])

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("RNN prediction")
predict(model=model_7,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# RNN prediction
# Target: hiphop, Predicted label: disco

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("LSTM prediction")
predict(model=model_8,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# LSTM prediction
# Target: hiphop, Predicted label: hiphop

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
print("GRU prediction")
predict(model=model_9,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# GRU prediction
# Target: hiphop, Predicted label: hiphop

# %% [markdown]
# ## 13. Making a confusion matrix for further evaluation
#
# For a good vizualization of our models' performance, we can use a confusion matrix for each one. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.24.0

# %% [markdown]
# ### 13.1 RNN confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_7.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_7(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "RNN_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that although our model performs relatively good on most of the genres, it doesn't seem to be able to distinguish "country" and "disco" very well. Most of the "country" samples were mismatched with "blues". Most of "disco" samples were falsely classified as "hiphop".

# %% [markdown]
# ### 13.2 LSTM confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_8.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_8(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "LSTM_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that our model performs relatively well. Most of the values are concentrated on the main diagonal, which is an encouraging outcome. The genres that are least recognized are "country" and "disco" as well.

# %% [markdown]
# ### 13.3 GRU confusion matrix

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_9.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_9(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "GRU_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that our model performs relatively well. The GRU model performed worse than the LSTM. Here "country" and "disco" were also classified poorly, however most of the samples were classified correctly. Our model fails to classify "rock" samples, as most of them were considered "blues".
