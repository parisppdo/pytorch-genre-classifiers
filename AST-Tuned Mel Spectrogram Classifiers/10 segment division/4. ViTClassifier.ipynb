# %% [markdown]
# # Music Genre Classification using ViT and Mel Spectograms

# %% [markdown]
# ## 0. Importing libraries, setting up device agnostic code

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torchaudio
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.7.0+cu118
# 2.7.0+cu118

# %%
# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)

# %%
# Set random seeds
RANDOM_SEED = 42

set_seeds()
np.random.seed(RANDOM_SEED)

# %%
# !nvidia-smi
# Out:
# Thu Feb  5 22:43:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   44C    P8            N/A  /  115W |    1224MiB /   8188MiB |      7%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            6096    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A            6196    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            6984    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            8196    C+G   ...rsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A            8824    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10248    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           10272    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12604    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13116    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           15848    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           16040    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16488    C+G   ...\v4.3.11\ProtonVPN.Client.exe      N/A      |
# |    0   N/A  N/A           17084    C+G   ...AppData\Local\Viber\Viber.exe      N/A      |
# |    0   N/A  N/A           19428    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           19752    C+G   ....0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20540    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           20844    C+G   ...der\Utility\SpyderUtility.exe      N/A      |
# |    0   N/A  N/A           21308    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           22632    C+G   ...\Proton\Drive\ProtonDrive.exe      N/A      |
# |    0   N/A  N/A           22880    C+G   ...2024.3\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           23108    C+G   ...Desktop\WDADesktopService.exe      N/A      |
# |    0   N/A  N/A           23664    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           24280    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           27088    C+G   ...6)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A           29772    C+G   C:\Windows\explorer.exe               N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Loading data
# We will load the data and after loading them in shape of `(batch_size, time_frames, mel_bands)`. Then we will reshape into a 72x72 matrix, all according to the following paper - https://ieeexplore.ieee.org/document/9573568
# We could optionally permute the tensor to have the shape of `(batch_size, time_frames, mel_bands)`, however this is not the shape mentioned in the paper. We could test it though.

# %%
# Create function to load melspec data from .json file
def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['melspec'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from .json file
def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
DATASET_PATH = "data_full.json"

classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((9996, 130, 128), (9996,))

# %%
# Turn data into tensors, also unsqueeze and permute, to be ready for Transformer
X = torch.from_numpy(inputs).float() # Weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
# X = X.permute(0, 2, 1).unsqueeze(1)
X = X.unsqueeze(1)
X.shape, y.shape
# Out:
# (torch.Size([9996, 1, 130, 128]), torch.Size([9996]))

# %%
# Resize Spectrogram
import torch.nn.functional as F
X = F.interpolate(X, size=(72, 72), mode="bilinear", align_corners=False)
X.shape
# Out:
# torch.Size([9996, 1, 72, 72])

# %% [markdown]
# ## 2. Create DataSets and DataLoaders

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):
    # create train/validation split

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x000001F92DB102F0>, <torch.utils.data.dataloader.DataLoader object at 0x000001F92CA239D0>)
# Length of train dataloader: 188 batches of 32
# Length of validation dataloader: 47 batches of 32
# Length of test dataloader: 79 batches of 32

# %%
# Checking the dataset shapes using test_dataset
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, time_frames, mel_bands)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample")
print(test_features_batch[0].shape, "-> (time_frames, mel_bands)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 1, 72, 72]) -> (batch_size, time_frames, mel_bands)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample
# torch.Size([1, 72, 72]) -> (time_frames, mel_bands)
# tensor(1) -> (label)

# %% [markdown]
# ## 3. Data visualization

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
INDEX = np.random.randint(len(X))
melspec_example = X[INDEX].squeeze(0).numpy()

plt.imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
plt.colorbar()
plt.title("Mel Spectrogram Example (from tensor)")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("Mel Spectogram Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    melspec_example = X[idx].squeeze(0).numpy()
    im = axs[row, col].imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("Mel Frequency Bin")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ## 4. Building a ViT Model

# %% [markdown]
# ### Create patch embeddings

# %%
# 1. Create a class called PatchEmbedding
class PatchEmbedding(nn.Module):
  # 2. Initilaize the layer with appropriate hyperparameters
  def __init__(self,
               in_channels:int=1,
               patch_size:int=12,
               embedding_dim:int=768): # from Table 1 for ViT-Base
    super().__init__()

    self.patch_size = patch_size

    # 3. Create a layer to turn an image into embedded patches
    self.patcher = nn.Conv2d(in_channels=in_channels,
                             out_channels=embedding_dim,
                             kernel_size=patch_size,
                             stride=patch_size,
                             padding=0)

    # 4. Create a layer to flatten feature map outputs of Conv2d
    self.flatten = nn.Flatten(start_dim=2,
                              end_dim=3)

  # 5. Define a forward method to define the forward computation steps
  def forward(self, x):
    # Create assertion to check that inputs are the correct shape
    graph_resolution = x.shape[-1]
    assert graph_resolution % self.patch_size == 0, f"Input image size must be divisible by patch size, image shape: {graph_resolution}, patch size: {self.patch_size}"

    # Perform the forward pass
    x_patched = self.patcher(x)
    x_flattened = self.flatten(x_patched)
    # 6. Make the returned sequence embedding dimensions are in the right order (batch_size, number_of_patches, embedding_dimension)
    return x_flattened.permute(0, 2, 1)

# %%
# Patchify a random sample

# Select a sample
np.random.seed(RANDOM_SEED)
INDEX = np.random.randint(len(X))
melspec_sample = X[INDEX]

# Create an instance of patch embedding layer
patchify = PatchEmbedding(in_channels=1,
                          patch_size=12,
                          embedding_dim=768)

# Pass the sample through patch embedding layer
print(f"Input image size: {melspec_sample.unsqueeze(0).shape}")
patch_embedded_image = patchify(melspec_sample.unsqueeze(0)) # add an extra batch dimension
print(f"Output patch embedding sequence shape: {patch_embedded_image.shape}")
# Out:
# Input image size: torch.Size([1, 1, 72, 72])
# Output patch embedding sequence shape: torch.Size([1, 36, 768])

# %%
class ViT(nn.Module):
  def __init__(self,
               graph_size=72,
               num_channels=1,
               patch_size=12,
               embedding_dim=768,  # from Table 1
               dropout=0.1,
               mlp_size=3072,  # from Table 1
               num_transformer_layers=12,  # from Table 1
               num_heads=12,  # from Table 1 (number of multi-head self attention heads)
               num_classes=10): # number of GTZAN classes
    super().__init__()

    # Assert image size is divisible by patch size
    assert graph_size % patch_size == 0, "Graph size must be divisble by patch size."

    # 1. Create patch embedding
    self.patch_embedding = PatchEmbedding(in_channels=num_channels,
                                          patch_size=patch_size,
                                          embedding_dim=embedding_dim)

    # 2. Create class token
    self.class_token = nn.Parameter(torch.randn(1, 1, embedding_dim),
                                    requires_grad=True)

    # 3. Create positional embedding
    num_patches = (graph_size * graph_size) // patch_size ** 2 # N = HW/P^2
    self.positional_embedding = nn.Parameter(torch.randn(1, num_patches+1, embedding_dim))

    # 4. Create patch + position embedding dropout
    self.embedding_dropout = nn.Dropout(p=dropout)

    # # 5. Create Transformer Encoder layer (single)
    # self.transformer_encoder_layer = nn.TransformerEncoderLayer(d_model=embedding_dim,
    #                                                             nhead=num_heads,
    #                                                             dim_feedforward=mlp_size,
    #                                                             activation="gelu",
    #                                                             batch_first=True,
    #                                                             norm_first=True)

    # 5. Create stack Transformer Encoder layers (stacked single layers)
    self.transformer_encoder = nn.TransformerEncoder(encoder_layer=nn.TransformerEncoderLayer(d_model=embedding_dim,
                                                                                              nhead=num_heads,
                                                                                              dim_feedforward=mlp_size,
                                                                                              activation="gelu",
                                                                                              batch_first=True,
                                                                                              norm_first=True), # Create a single Transformer Encoder Layer
                                                     num_layers=num_transformer_layers) # Stack it N times

    # 7. Create MLP head
    self.mlp_head = nn.Sequential(
        nn.LayerNorm(normalized_shape=embedding_dim),
        nn.Linear(in_features=embedding_dim,
                  out_features=num_classes)
    )

  def forward(self, x):
    # Get some dimensions from x
    batch_size = x.shape[0]

    # Create the patch embedding
    x = self.patch_embedding(x)
    # print(x.shape)

    # First, expand the class token across the batch size
    class_token = self.class_token.expand(batch_size, -1, -1) # "-1" means infer the dimension

    # Prepend the class token to the patch embedding
    x = torch.cat((class_token, x), dim=1)
    # print(x.shape)

    # Add the positional embedding to patch embedding with class token
    x = self.positional_embedding + x
    # print(x.shape)

    # Dropout on patch + positional embedding
    x = self.embedding_dropout(x)

    # Pass embedding through Transformer Encoder stack
    x = self.transformer_encoder(x)

    # Pass 0th index of x through MLP head
    x = self.mlp_head(x[:, 0])

    return x

# %%
# Create demo tensor
demo_tensor = torch.randn(1, 1, 72, 72).to(device)
print(demo_tensor.shape)
# Out:
# torch.Size([1, 1, 72, 72])

# %%
# Create ViT and do a test pass
torch.manual_seed(RANDOM_SEED)
model_0 = ViT().to(device)
print(model_0(demo_tensor))
# Out:
# C:\Users\thebo\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# tensor([[-0.1794,  0.0371, -0.3629,  0.4621,  0.3358, -0.4676, -0.1972,  0.5001,
#          -0.3213,  0.2869]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
from torchinfo import summary
summary(model=ViT(),
        input_size=demo_tensor.shape)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ViT                                           [1, 10]                   29,184
# ├─PatchEmbedding: 1-1                         [1, 36, 768]              --
# │    └─Conv2d: 2-1                            [1, 768, 6, 6]            111,360
# │    └─Flatten: 2-2                           [1, 768, 36]              --
# ├─Dropout: 1-2                                [1, 37, 768]              --
# ├─TransformerEncoder: 1-3                     [1, 37, 768]              --
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-2      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-3      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-4      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-5      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-6      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-7      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-8      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-9      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-10     [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-11     [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-12     [1, 37, 768]              7,087,872
# ├─Sequential: 1-4                             [1, 10]                   --
# │    └─LayerNorm: 2-4                         [1, 768]                  1,536
# │    └─Linear: 2-5                            [1, 10]                   7,690
# ===============================================================================================
# Total params: 85,204,234
# Trainable params: 85,204,234
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 60.72
# ===============================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 19.32
# Params size (MB): 227.31
# Estimated Total Size (MB): 246.65
# ===============================================================================================

# %% [markdown]
# ## 6. Training the model

# %%
# Optimizer values are according to this paper - https://ieeexplore.ieee.org/document/9573568
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

loss_fn = torch.nn.CrossEntropyLoss()

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %%
# Train the model
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.9696 | train_acc: 0.3083 | test_loss: 1.6541 | test_acc: 0.3995
# Epoch: 2 | train_loss: 1.6540 | train_acc: 0.3928 | test_loss: 1.4811 | test_acc: 0.4610
# Epoch: 3 | train_loss: 1.4665 | train_acc: 0.4539 | test_loss: 1.2906 | test_acc: 0.5262
# Epoch: 4 | train_loss: 1.3542 | train_acc: 0.5073 | test_loss: 1.3521 | test_acc: 0.4859
# Epoch: 5 | train_loss: 1.2345 | train_acc: 0.5590 | test_loss: 1.2046 | test_acc: 0.5568
# Epoch: 6 | train_loss: 1.1844 | train_acc: 0.5709 | test_loss: 1.2122 | test_acc: 0.5572
# Epoch: 7 | train_loss: 1.1051 | train_acc: 0.6010 | test_loss: 1.2044 | test_acc: 0.5566
# Epoch: 8 | train_loss: 1.0473 | train_acc: 0.6269 | test_loss: 1.1228 | test_acc: 0.6077
# Epoch: 9 | train_loss: 1.0035 | train_acc: 0.6427 | test_loss: 1.0246 | test_acc: 0.6198
# Epoch: 10 | train_loss: 0.9346 | train_acc: 0.6629 | test_loss: 1.0838 | test_acc: 0.6103
# Epoch: 11 | train_loss: 0.9111 | train_acc: 0.6808 | test_loss: 0.9894 | test_acc: 0.6449
# Epoch: 12 | train_loss: 0.8641 | train_acc: 0.6929 | test_loss: 0.9340 | test_acc: 0.6600
# Epoch: 13 | train_loss: 0.8296 | train_acc: 0.7102 | test_loss: 0.9145 | test_acc: 0.6729
# Epoch: 14 | train_loss: 0.8137 | train_acc: 0.7175 | test_loss: 0.9941 | test_acc: 0.6311
# Epoch: 15 | train_loss: 0.7777 | train_acc: 0.7244 | test_loss: 1.1086 | test_acc: 0.6298
# Epoch: 16 | train_loss: 0.7560 | train_acc: 0.7373 | test_loss: 0.9728 | test_acc: 0.6518
# Epoch: 17 | train_loss: 0.7399 | train_acc: 0.7410 | test_loss: 0.9222 | test_acc: 0.6676
# Epoch: 18 | train_loss: 0.7165 | train_acc: 0.7360 | test_loss: 0.9395 | test_acc: 0.6554
# Epoch: 19 | train_loss: 0.6800 | train_acc: 0.7628 | test_loss: 0.8767 | test_acc: 0.6978
# Epoch: 20 | train_loss: 0.6681 | train_acc: 0.7626 | test_loss: 0.9963 | test_acc: 0.6539
# Epoch: 21 | train_loss: 0.6493 | train_acc: 0.7723 | test_loss: 1.0045 | test_acc: 0.6627
# Epoch: 22 | train_loss: 0.6479 | train_acc: 0.7746 | test_loss: 0.9725 | test_acc: 0.6623
# Epoch: 23 | train_loss: 0.6062 | train_acc: 0.7869 | test_loss: 0.9726 | test_acc: 0.6726
# Epoch: 24 | train_loss: 0.6176 | train_acc: 0.7850 | test_loss: 0.9283 | test_acc: 0.6819
# Epoch: 25 | train_loss: 0.5865 | train_acc: 0.7913 | test_loss: 0.9052 | test_acc: 0.6872
# Epoch: 26 | train_loss: 0.5868 | train_acc: 0.7932 | test_loss: 0.8990 | test_acc: 0.6880
# Epoch: 27 | train_loss: 0.5569 | train_acc: 0.8057 | test_loss: 0.8595 | test_acc: 0.7141
# Epoch: 28 | train_loss: 0.5305 | train_acc: 0.8092 | test_loss: 0.8794 | test_acc: 0.6927
# Epoch: 29 | train_loss: 0.5546 | train_acc: 0.8036 | test_loss: 0.8658 | test_acc: 0.7026
# Epoch: 30 | train_loss: 0.5556 | train_acc: 0.8016 | test_loss: 0.9549 | test_acc: 0.6924
# Epoch: 31 | train_loss: 0.5263 | train_acc: 0.8114 | test_loss: 0.9364 | test_acc: 0.6907
# Epoch: 32 | train_loss: 0.5040 | train_acc: 0.8211 | test_loss: 0.8963 | test_acc: 0.6934
# Epoch: 33 | train_loss: 0.4850 | train_acc: 0.8309 | test_loss: 1.0449 | test_acc: 0.6715
# Epoch: 34 | train_loss: 0.4871 | train_acc: 0.8321 | test_loss: 0.8101 | test_acc: 0.7267
# Epoch: 35 | train_loss: 0.4946 | train_acc: 0.8250 | test_loss: 1.0952 | test_acc: 0.6480
# Epoch: 36 | train_loss: 0.4709 | train_acc: 0.8309 | test_loss: 0.9495 | test_acc: 0.6974
# Epoch: 37 | train_loss: 0.4711 | train_acc: 0.8324 | test_loss: 0.9499 | test_acc: 0.6866
# Epoch: 38 | train_loss: 0.4401 | train_acc: 0.8448 | test_loss: 0.8560 | test_acc: 0.7221
# Epoch: 39 | train_loss: 0.4390 | train_acc: 0.8460 | test_loss: 0.8662 | test_acc: 0.7160
# Epoch: 40 | train_loss: 0.4365 | train_acc: 0.8423 | test_loss: 0.8555 | test_acc: 0.7054
# Epoch: 41 | train_loss: 0.4083 | train_acc: 0.8554 | test_loss: 0.9399 | test_acc: 0.6919
# Epoch: 42 | train_loss: 0.4099 | train_acc: 0.8616 | test_loss: 0.9401 | test_acc: 0.7075
# Epoch: 43 | train_loss: 0.4055 | train_acc: 0.8563 | test_loss: 0.9393 | test_acc: 0.7043
# Epoch: 44 | train_loss: 0.4078 | train_acc: 0.8538 | test_loss: 0.9062 | test_acc: 0.7149
# Epoch: 45 | train_loss: 0.4176 | train_acc: 0.8502 | test_loss: 0.9014 | test_acc: 0.7169
# Epoch: 46 | train_loss: 0.3820 | train_acc: 0.8633 | test_loss: 1.0305 | test_acc: 0.6900
# Epoch: 47 | train_loss: 0.3796 | train_acc: 0.8664 | test_loss: 1.0187 | test_acc: 0.6884
# Epoch: 48 | train_loss: 0.3826 | train_acc: 0.8609 | test_loss: 0.9709 | test_acc: 0.6992
# Epoch: 49 | train_loss: 0.3846 | train_acc: 0.8635 | test_loss: 1.0374 | test_acc: 0.6985
# Epoch: 50 | train_loss: 0.3732 | train_acc: 0.8660 | test_loss: 0.8995 | test_acc: 0.7199
# Epoch: 51 | train_loss: 0.3577 | train_acc: 0.8708 | test_loss: 0.9886 | test_acc: 0.7049
# Epoch: 52 | train_loss: 0.3609 | train_acc: 0.8686 | test_loss: 0.9828 | test_acc: 0.7070
# Epoch: 53 | train_loss: 0.3640 | train_acc: 0.8700 | test_loss: 1.0690 | test_acc: 0.6770
# Epoch: 54 | train_loss: 0.3490 | train_acc: 0.8758 | test_loss: 0.9508 | test_acc: 0.7188
# Epoch: 55 | train_loss: 0.3504 | train_acc: 0.8731 | test_loss: 0.9482 | test_acc: 0.7222
# Epoch: 56 | train_loss: 0.3333 | train_acc: 0.8791 | test_loss: 1.0293 | test_acc: 0.6943
# Epoch: 57 | train_loss: 0.3392 | train_acc: 0.8812 | test_loss: 1.1059 | test_acc: 0.6797
# Epoch: 58 | train_loss: 0.3462 | train_acc: 0.8735 | test_loss: 0.9941 | test_acc: 0.7103
# Epoch: 59 | train_loss: 0.3433 | train_acc: 0.8753 | test_loss: 1.0263 | test_acc: 0.7035
# Epoch: 60 | train_loss: 0.3338 | train_acc: 0.8761 | test_loss: 1.1030 | test_acc: 0.6843
# Epoch: 61 | train_loss: 0.3507 | train_acc: 0.8755 | test_loss: 1.0288 | test_acc: 0.7041
# Epoch: 62 | train_loss: 0.3380 | train_acc: 0.8777 | test_loss: 1.0769 | test_acc: 0.6920
# Epoch: 63 | train_loss: 0.3150 | train_acc: 0.8881 | test_loss: 1.0284 | test_acc: 0.6910
# Epoch: 64 | train_loss: 0.3266 | train_acc: 0.8845 | test_loss: 0.9717 | test_acc: 0.7282
# Epoch: 65 | train_loss: 0.3013 | train_acc: 0.8926 | test_loss: 1.0208 | test_acc: 0.7107
# Epoch: 66 | train_loss: 0.2991 | train_acc: 0.8922 | test_loss: 1.0029 | test_acc: 0.7050
# Epoch: 67 | train_loss: 0.2921 | train_acc: 0.9003 | test_loss: 1.0146 | test_acc: 0.7223
# Epoch: 68 | train_loss: 0.3169 | train_acc: 0.8866 | test_loss: 0.9681 | test_acc: 0.7093
# Epoch: 69 | train_loss: 0.3190 | train_acc: 0.8816 | test_loss: 0.9702 | test_acc: 0.7092
# Epoch: 70 | train_loss: 0.2958 | train_acc: 0.8959 | test_loss: 0.9878 | test_acc: 0.7122
# Epoch: 71 | train_loss: 0.2910 | train_acc: 0.8956 | test_loss: 1.1292 | test_acc: 0.6896
# Epoch: 72 | train_loss: 0.3220 | train_acc: 0.8902 | test_loss: 0.9468 | test_acc: 0.7231
# Epoch: 73 | train_loss: 0.2921 | train_acc: 0.8941 | test_loss: 1.0375 | test_acc: 0.7101
# Epoch: 74 | train_loss: 0.2904 | train_acc: 0.8926 | test_loss: 0.9867 | test_acc: 0.7263
# Epoch: 75 | train_loss: 0.2843 | train_acc: 0.8989 | test_loss: 1.0086 | test_acc: 0.7195
# Epoch: 76 | train_loss: 0.2835 | train_acc: 0.8978 | test_loss: 1.0467 | test_acc: 0.7080
# Epoch: 77 | train_loss: 0.2879 | train_acc: 0.8974 | test_loss: 1.0924 | test_acc: 0.7055
# Epoch: 78 | train_loss: 0.2768 | train_acc: 0.9013 | test_loss: 0.9825 | test_acc: 0.7331
# Epoch: 79 | train_loss: 0.2748 | train_acc: 0.9000 | test_loss: 0.9777 | test_acc: 0.7222
# Epoch: 80 | train_loss: 0.2890 | train_acc: 0.8939 | test_loss: 1.0027 | test_acc: 0.7196
# Epoch: 81 | train_loss: 0.2528 | train_acc: 0.9103 | test_loss: 1.1333 | test_acc: 0.6907
# Epoch: 82 | train_loss: 0.2779 | train_acc: 0.8979 | test_loss: 0.9758 | test_acc: 0.7388
# Epoch: 83 | train_loss: 0.2731 | train_acc: 0.8994 | test_loss: 1.0314 | test_acc: 0.7030
# Epoch: 84 | train_loss: 0.2686 | train_acc: 0.8999 | test_loss: 1.1302 | test_acc: 0.6828
# Epoch: 85 | train_loss: 0.2750 | train_acc: 0.9038 | test_loss: 1.1102 | test_acc: 0.6953
# Epoch: 86 | train_loss: 0.2816 | train_acc: 0.8977 | test_loss: 1.0639 | test_acc: 0.7041
# Epoch: 87 | train_loss: 0.2611 | train_acc: 0.9045 | test_loss: 0.9980 | test_acc: 0.7169
# Epoch: 88 | train_loss: 0.2673 | train_acc: 0.9039 | test_loss: 1.0233 | test_acc: 0.7238
# Epoch: 89 | train_loss: 0.2672 | train_acc: 0.9024 | test_loss: 0.9643 | test_acc: 0.7237
# Epoch: 90 | train_loss: 0.2609 | train_acc: 0.9090 | test_loss: 1.0633 | test_acc: 0.7044
# Epoch: 91 | train_loss: 0.2668 | train_acc: 0.9028 | test_loss: 1.0650 | test_acc: 0.7130
# Epoch: 92 | train_loss: 0.2598 | train_acc: 0.9091 | test_loss: 1.0320 | test_acc: 0.7093
# Epoch: 93 | train_loss: 0.2598 | train_acc: 0.9048 | test_loss: 1.0876 | test_acc: 0.6981
# Epoch: 94 | train_loss: 0.2398 | train_acc: 0.9169 | test_loss: 1.1087 | test_acc: 0.6992
# Epoch: 95 | train_loss: 0.2573 | train_acc: 0.9088 | test_loss: 0.9764 | test_acc: 0.7229
# Epoch: 96 | train_loss: 0.2560 | train_acc: 0.9096 | test_loss: 0.9624 | test_acc: 0.7196
# Epoch: 97 | train_loss: 0.2503 | train_acc: 0.9098 | test_loss: 1.1189 | test_acc: 0.6994
# Epoch: 98 | train_loss: 0.2492 | train_acc: 0.9118 | test_loss: 1.1201 | test_acc: 0.6997
# Epoch: 99 | train_loss: 0.2476 | train_acc: 0.9111 | test_loss: 1.0682 | test_acc: 0.7142
# Epoch: 100 | train_loss: 0.2617 | train_acc: 0.9053 | test_loss: 1.0272 | test_acc: 0.7138
# Epoch: 101 | train_loss: 0.2469 | train_acc: 0.9123 | test_loss: 1.1305 | test_acc: 0.7016
# Epoch: 102 | train_loss: 0.2407 | train_acc: 0.9137 | test_loss: 1.0516 | test_acc: 0.7096
# Epoch: 103 | train_loss: 0.2693 | train_acc: 0.9026 | test_loss: 0.9892 | test_acc: 0.7037
# Epoch: 104 | train_loss: 0.2417 | train_acc: 0.9105 | test_loss: 1.0487 | test_acc: 0.7148
# Epoch: 105 | train_loss: 0.2316 | train_acc: 0.9131 | test_loss: 1.1277 | test_acc: 0.6777
# Epoch: 106 | train_loss: 0.2317 | train_acc: 0.9158 | test_loss: 1.0628 | test_acc: 0.7090
# Epoch: 107 | train_loss: 0.2340 | train_acc: 0.9182 | test_loss: 1.0753 | test_acc: 0.7002
# Epoch: 108 | train_loss: 0.2143 | train_acc: 0.9225 | test_loss: 1.0730 | test_acc: 0.7151
# Epoch: 109 | train_loss: 0.2203 | train_acc: 0.9207 | test_loss: 1.2359 | test_acc: 0.6917
# Epoch: 110 | train_loss: 0.2416 | train_acc: 0.9107 | test_loss: 1.0670 | test_acc: 0.7017
# Epoch: 111 | train_loss: 0.2296 | train_acc: 0.9143 | test_loss: 1.2291 | test_acc: 0.6749
# Epoch: 112 | train_loss: 0.2598 | train_acc: 0.9106 | test_loss: 1.1191 | test_acc: 0.7055
# Epoch: 113 | train_loss: 0.2420 | train_acc: 0.9106 | test_loss: 1.1078 | test_acc: 0.7131
# Epoch: 114 | train_loss: 0.2404 | train_acc: 0.9137 | test_loss: 1.1059 | test_acc: 0.7037
# Epoch: 115 | train_loss: 0.2458 | train_acc: 0.9152 | test_loss: 1.0270 | test_acc: 0.7100
# Epoch: 116 | train_loss: 0.2373 | train_acc: 0.9134 | test_loss: 1.0942 | test_acc: 0.7015
# Epoch: 117 | train_loss: 0.2134 | train_acc: 0.9241 | test_loss: 1.1542 | test_acc: 0.7102
# Epoch: 118 | train_loss: 0.2273 | train_acc: 0.9151 | test_loss: 1.1056 | test_acc: 0.7032
# Epoch: 119 | train_loss: 0.2379 | train_acc: 0.9152 | test_loss: 1.1665 | test_acc: 0.6943
# Epoch: 120 | train_loss: 0.2122 | train_acc: 0.9257 | test_loss: 1.0495 | test_acc: 0.7270
# Epoch: 121 | train_loss: 0.2386 | train_acc: 0.9146 | test_loss: 1.1248 | test_acc: 0.7029
# Epoch: 122 | train_loss: 0.2144 | train_acc: 0.9260 | test_loss: 1.0625 | test_acc: 0.7108
# Epoch: 123 | train_loss: 0.2215 | train_acc: 0.9214 | test_loss: 1.1075 | test_acc: 0.6990
# Epoch: 124 | train_loss: 0.2196 | train_acc: 0.9255 | test_loss: 1.0357 | test_acc: 0.7016
# Epoch: 125 | train_loss: 0.2473 | train_acc: 0.9121 | test_loss: 1.1051 | test_acc: 0.6957
# Epoch: 126 | train_loss: 0.2061 | train_acc: 0.9280 | test_loss: 1.0423 | test_acc: 0.7189
# Epoch: 127 | train_loss: 0.2176 | train_acc: 0.9225 | test_loss: 1.0864 | test_acc: 0.7056
# Epoch: 128 | train_loss: 0.2072 | train_acc: 0.9252 | test_loss: 1.0823 | test_acc: 0.7189
# Epoch: 129 | train_loss: 0.2105 | train_acc: 0.9263 | test_loss: 1.1540 | test_acc: 0.6982
# Epoch: 130 | train_loss: 0.2248 | train_acc: 0.9247 | test_loss: 1.1430 | test_acc: 0.6942
# Epoch: 131 | train_loss: 0.2236 | train_acc: 0.9195 | test_loss: 1.1431 | test_acc: 0.7016
# Epoch: 132 | train_loss: 0.2258 | train_acc: 0.9180 | test_loss: 1.0890 | test_acc: 0.7210
# Epoch: 133 | train_loss: 0.2242 | train_acc: 0.9194 | test_loss: 1.1008 | test_acc: 0.7144
# Epoch: 134 | train_loss: 0.2274 | train_acc: 0.9184 | test_loss: 1.1932 | test_acc: 0.6754
# Epoch: 135 | train_loss: 0.2031 | train_acc: 0.9279 | test_loss: 1.1075 | test_acc: 0.6933
# Epoch: 136 | train_loss: 0.2279 | train_acc: 0.9164 | test_loss: 1.1714 | test_acc: 0.7050
# Epoch: 137 | train_loss: 0.2178 | train_acc: 0.9228 | test_loss: 0.9397 | test_acc: 0.7314
# Epoch: 138 | train_loss: 0.2147 | train_acc: 0.9231 | test_loss: 1.0862 | test_acc: 0.6928
# Epoch: 139 | train_loss: 0.2161 | train_acc: 0.9243 | test_loss: 1.1765 | test_acc: 0.6903
# Epoch: 140 | train_loss: 0.2270 | train_acc: 0.9205 | test_loss: 1.0873 | test_acc: 0.7225
# Epoch: 141 | train_loss: 0.1836 | train_acc: 0.9390 | test_loss: 1.0623 | test_acc: 0.7244
# Epoch: 142 | train_loss: 0.2099 | train_acc: 0.9251 | test_loss: 1.0558 | test_acc: 0.7277
# Epoch: 143 | train_loss: 0.2157 | train_acc: 0.9216 | test_loss: 1.1819 | test_acc: 0.7023
# Epoch: 144 | train_loss: 0.2278 | train_acc: 0.9167 | test_loss: 1.1071 | test_acc: 0.7204
# Epoch: 145 | train_loss: 0.2200 | train_acc: 0.9230 | test_loss: 1.1439 | test_acc: 0.6981
# Epoch: 146 | train_loss: 0.2107 | train_acc: 0.9251 | test_loss: 1.0084 | test_acc: 0.7184
# Epoch: 147 | train_loss: 0.1977 | train_acc: 0.9323 | test_loss: 1.1259 | test_acc: 0.7117
# Epoch: 148 | train_loss: 0.2164 | train_acc: 0.9237 | test_loss: 1.0616 | test_acc: 0.7258
# Epoch: 149 | train_loss: 0.2059 | train_acc: 0.9274 | test_loss: 1.1237 | test_acc: 0.7030
# Epoch: 150 | train_loss: 0.2044 | train_acc: 0.9259 | test_loss: 1.1094 | test_acc: 0.7156
# Total training time: 3653.874 seconds

# %% [markdown]
# ## 7. Plotting the results
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys
model_0_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
# defining the plot function
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]],
                     Save = False):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup figure
    fig, axs = plt.subplots(1, 2, figsize=(15, 7))
    fig.patch.set_facecolor('white')

    # ===== Loss plot =====
    axs[0].set_facecolor('white')

    axs[0].plot(epochs, loss, label='train_loss', color="#4195C1")
    axs[0].plot(epochs, test_loss, label='test_loss', color="#FF7B22")

    axs[0].set_title('Loss', color='black')
    axs[0].set_xlabel('Epochs', color='black')

    axs[0].tick_params(axis='x', colors='black')
    axs[0].tick_params(axis='y', colors='black')

    for spine in axs[0].spines.values():
        spine.set_color('black')

    axs[0].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # ===== Accuracy plot =====
    axs[1].set_facecolor('white')

    axs[1].plot(epochs, accuracy, label='train_accuracy', color="#4195C1")
    axs[1].plot(epochs, test_accuracy, label='test_accuracy', color="#FF7B22")

    axs[1].set_title('Accuracy', color='black')
    axs[1].set_xlabel('Epochs', color='black')

    axs[1].tick_params(axis='x', colors='black')
    axs[1].tick_params(axis='y', colors='black')

    for spine in axs[1].spines.values():
        spine.set_color('black')

    axs[1].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # Layout
    plt.tight_layout()

    # Save figure
    if Save:
        plt.savefig(
            "training_curves.png",
            dpi=144,
            bbox_inches='tight',
            facecolor=fig.get_facecolor()
        )

    plt.show()

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# ## 8. Using Data Augmentation
#
# For our next models we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.

# %% [markdown]
# ### 8.1 Implementing `TimeMasking()` and `FrequencyMasking()` on the data
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and coefficients respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
#
# > The `TimeMasking()` transform, "masks" the entire x axis for a specific amount. A good option would be to mask 15% of the sample. The *time_mask_param* is responsible for the amount of time frames that will be masked. We are calculating this value and setting it in the `TimeMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__: Our x axis is the time frames and we know that each sample has 130 time frames. We are going to mask 20 frames which is approximately 15% of the sample. This is done by setting the *time_mask_param* to 20. That means that maximum 20 consecutive frames will be masked.
#
# > The `FrequencyMasking()` transform, "masks" the entire y axis for a specific amount. A good option would be to mask 12% of the sample. The *freq_mask_param* is responsible for the amount of mel bands that will be masked. We are calculating this value and setting it in the `FrequencyMasking()` transform.
# >> __In case we divided the original GTZAN samples into 10 segments__:Our y axis is the mel bands and we know that each sample has 64 mel bands. We are going to mask 8 frames which is approximately 12% of the sample. This is done by setting the *freq_mask_param* to 8. That means that maximum 8 consecutive frames will be masked.
#
# The masked spectograms are presented, to have a visualization of the augmented data. Similar methods of masking on log mel spectograms directly are mentioned in the SpecAugment paper. More info here - https://arxiv.org/pdf/1904.08779
#
# _**Notice**: The time_mask_param and freq_mask_param will set the **maximum** amount of frames/mel banks that will be masked. This number will be random on each epoch._

# %%
# Calculating the proper time_mask_param and freq_mask_param values

# Shape is 72x72 so we cover 10 indices
time_mask_param = round(10)
freq_mask_param = round(10)

time_mask_param, freq_mask_param
# Out:
# (10, 10)

# %%
# Creating time masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
time_masking = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
time_masked_data = time_masking(X[INDEX].squeeze()).to('cpu')
time_masked_data.shape
# Out:
# torch.Size([72, 72])

# %%
# Creating frequency masking transform and checking the shape of sample data
# np.random.seed(RANDOM_SEED)
# torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
freq_masking = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
freq_masked_data = freq_masking(X[INDEX].squeeze()).to('cpu')
freq_masked_data.shape
# Out:
# torch.Size([72, 72])

# %%
# Visualize data
time_masked_melspec_example = time_masked_data.numpy()
freq_masked_melspec_example = freq_masked_data.numpy()

fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharex=True, sharey=True)
im0 = axes[0].imshow(time_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[0].set_title("Frequency-masked Mel Spectrogram")
axes[0].set_ylabel("MFCCs")
fig.colorbar(im0, ax=axes[0])

im1 = axes[1].imshow(freq_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[1].set_title("Time-masked Mel Spectrogram")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("MFCCs")
fig.colorbar(im1, ax=axes[1])

fig.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Creating training functions for data augmentation

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=time_mask_param),
    T.FrequencyMasking(freq_mask_param=freq_mask_param)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ### 8.3 Training the Transformer model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_1 = ViT().to(device)
model_1
# Out:
# C:\Users\thebo\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ViT(
#   (patch_embedding): PatchEmbedding(
#     (patcher): Conv2d(1, 768, kernel_size=(12, 12), stride=(12, 12))
#     (flatten): Flatten(start_dim=2, end_dim=3)
#   )
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=3072, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=3072, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(),
                             lr=0.001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train_with_augmentation(model=model_1,
                                          train_dataloader=train_dataloader,
                                          test_dataloader=validation_dataloader,
                                          optimizer=optimizer,
                                          loss_fn=loss_fn,
                                          epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0515 | train_acc: 0.2756 | test_loss: 1.8984 | test_acc: 0.3273
# Epoch: 2 | train_loss: 1.8968 | train_acc: 0.2941 | test_loss: 1.9073 | test_acc: 0.3032
# Epoch: 3 | train_loss: 1.8355 | train_acc: 0.3233 | test_loss: 1.8779 | test_acc: 0.3556
# Epoch: 4 | train_loss: 1.7651 | train_acc: 0.3384 | test_loss: 1.7089 | test_acc: 0.3740
# Epoch: 5 | train_loss: 1.7466 | train_acc: 0.3589 | test_loss: 1.6369 | test_acc: 0.3964
# Epoch: 6 | train_loss: 1.7462 | train_acc: 0.3550 | test_loss: 1.6738 | test_acc: 0.3922
# Epoch: 7 | train_loss: 1.7285 | train_acc: 0.3619 | test_loss: 1.6324 | test_acc: 0.4062
# Epoch: 8 | train_loss: 1.6826 | train_acc: 0.3744 | test_loss: 1.5902 | test_acc: 0.4144
# Epoch: 9 | train_loss: 1.6612 | train_acc: 0.3814 | test_loss: 1.6932 | test_acc: 0.3714
# Epoch: 10 | train_loss: 1.6297 | train_acc: 0.3909 | test_loss: 1.5688 | test_acc: 0.4130
# Epoch: 11 | train_loss: 1.6380 | train_acc: 0.3981 | test_loss: 1.4935 | test_acc: 0.4422
# Epoch: 12 | train_loss: 1.5864 | train_acc: 0.4120 | test_loss: 1.5063 | test_acc: 0.4580
# Epoch: 13 | train_loss: 1.5888 | train_acc: 0.4114 | test_loss: 1.5689 | test_acc: 0.4369
# Epoch: 14 | train_loss: 1.5507 | train_acc: 0.4332 | test_loss: 1.5248 | test_acc: 0.4422
# Epoch: 15 | train_loss: 1.5403 | train_acc: 0.4375 | test_loss: 1.5707 | test_acc: 0.4189
# Epoch: 16 | train_loss: 1.5111 | train_acc: 0.4495 | test_loss: 1.3605 | test_acc: 0.4926
# Epoch: 17 | train_loss: 1.4995 | train_acc: 0.4528 | test_loss: 1.4659 | test_acc: 0.4487
# Epoch: 18 | train_loss: 1.4926 | train_acc: 0.4618 | test_loss: 1.3844 | test_acc: 0.4825
# Epoch: 19 | train_loss: 1.4562 | train_acc: 0.4691 | test_loss: 1.3526 | test_acc: 0.4779
# Epoch: 20 | train_loss: 1.4641 | train_acc: 0.4686 | test_loss: 1.3327 | test_acc: 0.5105
# Epoch: 21 | train_loss: 1.3895 | train_acc: 0.4933 | test_loss: 1.3697 | test_acc: 0.4906
# Epoch: 22 | train_loss: 1.4014 | train_acc: 0.4903 | test_loss: 1.3604 | test_acc: 0.5051
# Epoch: 23 | train_loss: 1.3815 | train_acc: 0.4935 | test_loss: 1.4145 | test_acc: 0.5020
# Epoch: 24 | train_loss: 1.3621 | train_acc: 0.5088 | test_loss: 1.2437 | test_acc: 0.5431
# Epoch: 25 | train_loss: 1.3446 | train_acc: 0.5029 | test_loss: 1.2333 | test_acc: 0.5617
# Epoch: 26 | train_loss: 1.3268 | train_acc: 0.5143 | test_loss: 1.2224 | test_acc: 0.5538
# Epoch: 27 | train_loss: 1.3442 | train_acc: 0.5114 | test_loss: 1.2724 | test_acc: 0.5391
# Epoch: 28 | train_loss: 1.2892 | train_acc: 0.5321 | test_loss: 1.1756 | test_acc: 0.5772
# Epoch: 29 | train_loss: 1.2830 | train_acc: 0.5353 | test_loss: 1.1821 | test_acc: 0.5693
# Epoch: 30 | train_loss: 1.2418 | train_acc: 0.5430 | test_loss: 1.1494 | test_acc: 0.5745
# Epoch: 31 | train_loss: 1.2617 | train_acc: 0.5376 | test_loss: 1.1663 | test_acc: 0.5806
# Epoch: 32 | train_loss: 1.2144 | train_acc: 0.5563 | test_loss: 1.2846 | test_acc: 0.5594
# Epoch: 33 | train_loss: 1.1878 | train_acc: 0.5698 | test_loss: 1.1230 | test_acc: 0.5956
# Epoch: 34 | train_loss: 1.1981 | train_acc: 0.5683 | test_loss: 1.1482 | test_acc: 0.5998
# Epoch: 35 | train_loss: 1.1576 | train_acc: 0.5818 | test_loss: 1.0912 | test_acc: 0.6089
# Epoch: 36 | train_loss: 1.1338 | train_acc: 0.5909 | test_loss: 1.2416 | test_acc: 0.5682
# Epoch: 37 | train_loss: 1.1564 | train_acc: 0.5855 | test_loss: 1.1031 | test_acc: 0.6141
# Epoch: 38 | train_loss: 1.1242 | train_acc: 0.5955 | test_loss: 1.2190 | test_acc: 0.5694
# Epoch: 39 | train_loss: 1.1133 | train_acc: 0.5916 | test_loss: 1.0148 | test_acc: 0.6232
# Epoch: 40 | train_loss: 1.0625 | train_acc: 0.6203 | test_loss: 1.1424 | test_acc: 0.5719
# Epoch: 41 | train_loss: 1.0605 | train_acc: 0.6253 | test_loss: 0.9709 | test_acc: 0.6656
# Epoch: 42 | train_loss: 1.0449 | train_acc: 0.6254 | test_loss: 1.0201 | test_acc: 0.6471
# Epoch: 43 | train_loss: 1.0407 | train_acc: 0.6246 | test_loss: 0.9924 | test_acc: 0.6614
# Epoch: 44 | train_loss: 1.0057 | train_acc: 0.6441 | test_loss: 1.1018 | test_acc: 0.6014
# Epoch: 45 | train_loss: 1.0062 | train_acc: 0.6343 | test_loss: 0.9891 | test_acc: 0.6367
# Epoch: 46 | train_loss: 0.9888 | train_acc: 0.6466 | test_loss: 1.0480 | test_acc: 0.6249
# Epoch: 47 | train_loss: 0.9857 | train_acc: 0.6432 | test_loss: 1.0671 | test_acc: 0.6052
# Epoch: 48 | train_loss: 0.9476 | train_acc: 0.6629 | test_loss: 0.9277 | test_acc: 0.6754
# Epoch: 49 | train_loss: 0.9457 | train_acc: 0.6627 | test_loss: 1.1136 | test_acc: 0.6047
# Epoch: 50 | train_loss: 0.9436 | train_acc: 0.6684 | test_loss: 0.9873 | test_acc: 0.6554
# Epoch: 51 | train_loss: 0.9229 | train_acc: 0.6729 | test_loss: 0.9268 | test_acc: 0.6755
# Epoch: 52 | train_loss: 0.8806 | train_acc: 0.6804 | test_loss: 0.9459 | test_acc: 0.6633
# Epoch: 53 | train_loss: 0.8851 | train_acc: 0.6850 | test_loss: 0.9599 | test_acc: 0.6613
# Epoch: 54 | train_loss: 0.8713 | train_acc: 0.6890 | test_loss: 0.8573 | test_acc: 0.6881
# Epoch: 55 | train_loss: 0.8609 | train_acc: 0.6928 | test_loss: 0.9347 | test_acc: 0.6659
# Epoch: 56 | train_loss: 0.8382 | train_acc: 0.7022 | test_loss: 0.9775 | test_acc: 0.6566
# Epoch: 57 | train_loss: 0.8437 | train_acc: 0.7046 | test_loss: 0.8904 | test_acc: 0.6973
# Epoch: 58 | train_loss: 0.8257 | train_acc: 0.7081 | test_loss: 0.7700 | test_acc: 0.7284
# Epoch: 59 | train_loss: 0.7916 | train_acc: 0.7177 | test_loss: 1.0423 | test_acc: 0.6374
# Epoch: 60 | train_loss: 0.8113 | train_acc: 0.7115 | test_loss: 0.9705 | test_acc: 0.6613
# Epoch: 61 | train_loss: 0.7739 | train_acc: 0.7322 | test_loss: 0.8021 | test_acc: 0.7330
# Epoch: 62 | train_loss: 0.7739 | train_acc: 0.7293 | test_loss: 0.7902 | test_acc: 0.7208
# Epoch: 63 | train_loss: 0.7636 | train_acc: 0.7248 | test_loss: 0.8299 | test_acc: 0.7093
# Epoch: 64 | train_loss: 0.7613 | train_acc: 0.7366 | test_loss: 0.7623 | test_acc: 0.7296
# Epoch: 65 | train_loss: 0.7411 | train_acc: 0.7450 | test_loss: 0.8560 | test_acc: 0.6867
# Epoch: 66 | train_loss: 0.7389 | train_acc: 0.7347 | test_loss: 0.8639 | test_acc: 0.7001
# Epoch: 67 | train_loss: 0.7276 | train_acc: 0.7435 | test_loss: 0.8392 | test_acc: 0.7037
# Epoch: 68 | train_loss: 0.7067 | train_acc: 0.7436 | test_loss: 0.7289 | test_acc: 0.7383
# Epoch: 69 | train_loss: 0.6693 | train_acc: 0.7672 | test_loss: 0.7883 | test_acc: 0.7280
# Epoch: 70 | train_loss: 0.6765 | train_acc: 0.7568 | test_loss: 0.8201 | test_acc: 0.7126
# Epoch: 71 | train_loss: 0.6307 | train_acc: 0.7736 | test_loss: 0.7044 | test_acc: 0.7491
# Epoch: 72 | train_loss: 0.6776 | train_acc: 0.7560 | test_loss: 0.6988 | test_acc: 0.7499
# Epoch: 73 | train_loss: 0.6737 | train_acc: 0.7650 | test_loss: 0.8508 | test_acc: 0.6982
# Epoch: 74 | train_loss: 0.6631 | train_acc: 0.7617 | test_loss: 0.7993 | test_acc: 0.7258
# Epoch: 75 | train_loss: 0.6279 | train_acc: 0.7805 | test_loss: 0.9404 | test_acc: 0.6602
# Epoch: 76 | train_loss: 0.6402 | train_acc: 0.7722 | test_loss: 0.7389 | test_acc: 0.7406
# Epoch: 77 | train_loss: 0.6189 | train_acc: 0.7818 | test_loss: 0.7425 | test_acc: 0.7514
# Epoch: 78 | train_loss: 0.6249 | train_acc: 0.7780 | test_loss: 0.8504 | test_acc: 0.7026
# Epoch: 79 | train_loss: 0.5917 | train_acc: 0.7887 | test_loss: 0.8273 | test_acc: 0.7106
# Epoch: 80 | train_loss: 0.5822 | train_acc: 0.7930 | test_loss: 0.8401 | test_acc: 0.7080
# Epoch: 81 | train_loss: 0.6148 | train_acc: 0.7809 | test_loss: 0.7976 | test_acc: 0.7195
# Epoch: 82 | train_loss: 0.5670 | train_acc: 0.8015 | test_loss: 0.7071 | test_acc: 0.7521
# Epoch: 83 | train_loss: 0.5907 | train_acc: 0.7827 | test_loss: 0.6928 | test_acc: 0.7590
# Epoch: 84 | train_loss: 0.5851 | train_acc: 0.7932 | test_loss: 0.7653 | test_acc: 0.7457
# Epoch: 85 | train_loss: 0.5857 | train_acc: 0.7880 | test_loss: 0.7777 | test_acc: 0.7336
# Epoch: 86 | train_loss: 0.5512 | train_acc: 0.8061 | test_loss: 0.6853 | test_acc: 0.7578
# Epoch: 87 | train_loss: 0.5591 | train_acc: 0.8028 | test_loss: 0.7825 | test_acc: 0.7215
# Epoch: 88 | train_loss: 0.5707 | train_acc: 0.7964 | test_loss: 0.7020 | test_acc: 0.7657
# Epoch: 89 | train_loss: 0.4985 | train_acc: 0.8203 | test_loss: 0.7198 | test_acc: 0.7509
# Epoch: 90 | train_loss: 0.5461 | train_acc: 0.8080 | test_loss: 0.8388 | test_acc: 0.7282
# Epoch: 91 | train_loss: 0.4978 | train_acc: 0.8248 | test_loss: 0.7707 | test_acc: 0.7510
# Epoch: 92 | train_loss: 0.5220 | train_acc: 0.8144 | test_loss: 0.6360 | test_acc: 0.7724
# Epoch: 93 | train_loss: 0.5000 | train_acc: 0.8241 | test_loss: 0.6542 | test_acc: 0.7738
# Epoch: 94 | train_loss: 0.4811 | train_acc: 0.8257 | test_loss: 0.6659 | test_acc: 0.7726
# Epoch: 95 | train_loss: 0.5016 | train_acc: 0.8257 | test_loss: 0.5839 | test_acc: 0.7911
# Epoch: 96 | train_loss: 0.4952 | train_acc: 0.8245 | test_loss: 0.7617 | test_acc: 0.7403
# Epoch: 97 | train_loss: 0.5038 | train_acc: 0.8298 | test_loss: 0.7474 | test_acc: 0.7428
# Epoch: 98 | train_loss: 0.4661 | train_acc: 0.8369 | test_loss: 0.6910 | test_acc: 0.7716
# Epoch: 99 | train_loss: 0.4681 | train_acc: 0.8320 | test_loss: 0.6695 | test_acc: 0.7719
# Epoch: 100 | train_loss: 0.4628 | train_acc: 0.8374 | test_loss: 0.6710 | test_acc: 0.7825
# Epoch: 101 | train_loss: 0.4494 | train_acc: 0.8444 | test_loss: 0.6798 | test_acc: 0.7569
# Epoch: 102 | train_loss: 0.4671 | train_acc: 0.8367 | test_loss: 0.6436 | test_acc: 0.7895
# Epoch: 103 | train_loss: 0.4252 | train_acc: 0.8474 | test_loss: 0.7047 | test_acc: 0.7630
# Epoch: 104 | train_loss: 0.4558 | train_acc: 0.8392 | test_loss: 0.7322 | test_acc: 0.7456
# Epoch: 105 | train_loss: 0.4506 | train_acc: 0.8423 | test_loss: 0.7604 | test_acc: 0.7441
# Epoch: 106 | train_loss: 0.4545 | train_acc: 0.8383 | test_loss: 0.7083 | test_acc: 0.7593
# Epoch: 107 | train_loss: 0.4593 | train_acc: 0.8340 | test_loss: 0.5978 | test_acc: 0.7931
# Epoch: 108 | train_loss: 0.4394 | train_acc: 0.8461 | test_loss: 0.6513 | test_acc: 0.7849
# Epoch: 109 | train_loss: 0.4242 | train_acc: 0.8505 | test_loss: 0.8984 | test_acc: 0.7138
# Epoch: 110 | train_loss: 0.4252 | train_acc: 0.8492 | test_loss: 0.6474 | test_acc: 0.7796
# Epoch: 111 | train_loss: 0.3816 | train_acc: 0.8667 | test_loss: 0.6134 | test_acc: 0.8002
# Epoch: 112 | train_loss: 0.4219 | train_acc: 0.8519 | test_loss: 0.6080 | test_acc: 0.8078
# Epoch: 113 | train_loss: 0.4309 | train_acc: 0.8464 | test_loss: 0.6769 | test_acc: 0.7837
# Epoch: 114 | train_loss: 0.3905 | train_acc: 0.8629 | test_loss: 0.7274 | test_acc: 0.7729
# Epoch: 115 | train_loss: 0.3964 | train_acc: 0.8581 | test_loss: 0.6541 | test_acc: 0.7843
# Epoch: 116 | train_loss: 0.3789 | train_acc: 0.8618 | test_loss: 0.7214 | test_acc: 0.7657
# Epoch: 117 | train_loss: 0.3796 | train_acc: 0.8662 | test_loss: 0.6427 | test_acc: 0.7951
# Epoch: 118 | train_loss: 0.4026 | train_acc: 0.8616 | test_loss: 0.7249 | test_acc: 0.7539
# Epoch: 119 | train_loss: 0.3938 | train_acc: 0.8605 | test_loss: 0.6300 | test_acc: 0.7957
# Epoch: 120 | train_loss: 0.3822 | train_acc: 0.8644 | test_loss: 0.8694 | test_acc: 0.7370
# Epoch: 121 | train_loss: 0.3739 | train_acc: 0.8688 | test_loss: 0.5593 | test_acc: 0.8096
# Epoch: 122 | train_loss: 0.3599 | train_acc: 0.8726 | test_loss: 0.6369 | test_acc: 0.7878
# Epoch: 123 | train_loss: 0.3702 | train_acc: 0.8717 | test_loss: 0.7041 | test_acc: 0.7649
# Epoch: 124 | train_loss: 0.3514 | train_acc: 0.8788 | test_loss: 0.6105 | test_acc: 0.7937
# Epoch: 125 | train_loss: 0.3701 | train_acc: 0.8708 | test_loss: 0.7094 | test_acc: 0.7728
# Epoch: 126 | train_loss: 0.3508 | train_acc: 0.8780 | test_loss: 0.5697 | test_acc: 0.8143
# Epoch: 127 | train_loss: 0.3440 | train_acc: 0.8758 | test_loss: 0.6325 | test_acc: 0.7948
# Epoch: 128 | train_loss: 0.3389 | train_acc: 0.8848 | test_loss: 0.7057 | test_acc: 0.7681
# Epoch: 129 | train_loss: 0.3744 | train_acc: 0.8672 | test_loss: 0.6521 | test_acc: 0.7925
# Epoch: 130 | train_loss: 0.3436 | train_acc: 0.8779 | test_loss: 0.6589 | test_acc: 0.7958
# Epoch: 131 | train_loss: 0.3403 | train_acc: 0.8850 | test_loss: 0.6742 | test_acc: 0.7899
# Epoch: 132 | train_loss: 0.3639 | train_acc: 0.8779 | test_loss: 0.7139 | test_acc: 0.7607
# Epoch: 133 | train_loss: 0.3322 | train_acc: 0.8825 | test_loss: 0.6465 | test_acc: 0.7944
# Epoch: 134 | train_loss: 0.3616 | train_acc: 0.8743 | test_loss: 0.6330 | test_acc: 0.7917
# Epoch: 135 | train_loss: 0.3145 | train_acc: 0.8900 | test_loss: 0.6515 | test_acc: 0.7963
# Epoch: 136 | train_loss: 0.3417 | train_acc: 0.8767 | test_loss: 0.6471 | test_acc: 0.7973
# Epoch: 137 | train_loss: 0.3022 | train_acc: 0.8891 | test_loss: 0.7372 | test_acc: 0.7794
# Epoch: 138 | train_loss: 0.3244 | train_acc: 0.8848 | test_loss: 0.7125 | test_acc: 0.7775
# Epoch: 139 | train_loss: 0.2993 | train_acc: 0.8966 | test_loss: 0.7373 | test_acc: 0.7604
# Epoch: 140 | train_loss: 0.3270 | train_acc: 0.8861 | test_loss: 0.7072 | test_acc: 0.7800
# Epoch: 141 | train_loss: 0.3335 | train_acc: 0.8830 | test_loss: 0.6238 | test_acc: 0.8008
# Epoch: 142 | train_loss: 0.3377 | train_acc: 0.8836 | test_loss: 0.6462 | test_acc: 0.8009
# Epoch: 143 | train_loss: 0.3184 | train_acc: 0.8890 | test_loss: 0.6804 | test_acc: 0.7837
# Epoch: 144 | train_loss: 0.3310 | train_acc: 0.8866 | test_loss: 0.7356 | test_acc: 0.7623
# Epoch: 145 | train_loss: 0.3222 | train_acc: 0.8872 | test_loss: 0.6528 | test_acc: 0.7913
# Epoch: 146 | train_loss: 0.3553 | train_acc: 0.8768 | test_loss: 0.5986 | test_acc: 0.7974
# Epoch: 147 | train_loss: 0.2936 | train_acc: 0.8981 | test_loss: 0.6293 | test_acc: 0.8022
# Epoch: 148 | train_loss: 0.3112 | train_acc: 0.8914 | test_loss: 0.7610 | test_acc: 0.7643
# Epoch: 149 | train_loss: 0.3127 | train_acc: 0.8936 | test_loss: 0.6944 | test_acc: 0.7885
# Epoch: 150 | train_loss: 0.3056 | train_acc: 0.8954 | test_loss: 0.7272 | test_acc: 0.7687
# Total training time: 3700.102 seconds

# %%
plot_loss_curves(model_1_results)

# %% [markdown]
# ## 10. Using early stopping to create the best model
#
# We will use early stopping on the models trained with data augmentation, in order to have the best version of them. One for each architecture.

# %%
# Instantiating a new Transformer model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_2 = ViT().to(device)
model_2
# Out:
# ViT(
#   (patch_embedding): PatchEmbedding(
#     (patcher): Conv2d(1, 768, kernel_size=(12, 12), stride=(12, 12))
#     (flatten): Flatten(start_dim=2, end_dim=3)
#   )
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=3072, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=3072, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 121

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_7_results = train_with_augmentation(model=model_2,
                                          train_dataloader=train_dataloader,
                                          test_dataloader=validation_dataloader,
                                          optimizer=optimizer,
                                          loss_fn=loss_fn,
                                          epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0515 | train_acc: 0.2756 | test_loss: 1.8984 | test_acc: 0.3273
# Epoch: 2 | train_loss: 1.8968 | train_acc: 0.2941 | test_loss: 1.9073 | test_acc: 0.3032
# Epoch: 3 | train_loss: 1.8355 | train_acc: 0.3233 | test_loss: 1.8779 | test_acc: 0.3556
# Epoch: 4 | train_loss: 1.7651 | train_acc: 0.3384 | test_loss: 1.7089 | test_acc: 0.3740
# Epoch: 5 | train_loss: 1.7466 | train_acc: 0.3589 | test_loss: 1.6369 | test_acc: 0.3964
# Epoch: 6 | train_loss: 1.7462 | train_acc: 0.3550 | test_loss: 1.6738 | test_acc: 0.3922
# Epoch: 7 | train_loss: 1.7285 | train_acc: 0.3619 | test_loss: 1.6324 | test_acc: 0.4062
# Epoch: 8 | train_loss: 1.6826 | train_acc: 0.3744 | test_loss: 1.5902 | test_acc: 0.4144
# Epoch: 9 | train_loss: 1.6578 | train_acc: 0.3849 | test_loss: 1.6607 | test_acc: 0.3836
# Epoch: 10 | train_loss: 1.6416 | train_acc: 0.3924 | test_loss: 1.5694 | test_acc: 0.4084
# Epoch: 11 | train_loss: 1.6047 | train_acc: 0.4080 | test_loss: 1.4875 | test_acc: 0.4456
# Epoch: 12 | train_loss: 1.5878 | train_acc: 0.4174 | test_loss: 1.4855 | test_acc: 0.4793
# Epoch: 13 | train_loss: 1.5580 | train_acc: 0.4307 | test_loss: 1.5517 | test_acc: 0.4223
# Epoch: 14 | train_loss: 1.5501 | train_acc: 0.4353 | test_loss: 1.4836 | test_acc: 0.4567
# Epoch: 15 | train_loss: 1.5340 | train_acc: 0.4376 | test_loss: 1.5920 | test_acc: 0.4008
# Epoch: 16 | train_loss: 1.5216 | train_acc: 0.4407 | test_loss: 1.3877 | test_acc: 0.4920
# Epoch: 17 | train_loss: 1.5058 | train_acc: 0.4434 | test_loss: 1.4306 | test_acc: 0.4706
# Epoch: 18 | train_loss: 1.4660 | train_acc: 0.4651 | test_loss: 1.3350 | test_acc: 0.4916
# Epoch: 19 | train_loss: 1.4398 | train_acc: 0.4685 | test_loss: 1.3385 | test_acc: 0.4928
# Epoch: 20 | train_loss: 1.4528 | train_acc: 0.4719 | test_loss: 1.3002 | test_acc: 0.5312
# Epoch: 21 | train_loss: 1.3743 | train_acc: 0.5006 | test_loss: 1.3598 | test_acc: 0.5147
# Epoch: 22 | train_loss: 1.4154 | train_acc: 0.4814 | test_loss: 1.3162 | test_acc: 0.5235
# Epoch: 23 | train_loss: 1.3767 | train_acc: 0.4861 | test_loss: 1.4035 | test_acc: 0.4939
# Epoch: 24 | train_loss: 1.3219 | train_acc: 0.5225 | test_loss: 1.3039 | test_acc: 0.5416
# Epoch: 25 | train_loss: 1.3322 | train_acc: 0.5130 | test_loss: 1.2315 | test_acc: 0.5347
# Epoch: 26 | train_loss: 1.3025 | train_acc: 0.5274 | test_loss: 1.1606 | test_acc: 0.5750
# Epoch: 27 | train_loss: 1.3260 | train_acc: 0.5104 | test_loss: 1.2319 | test_acc: 0.5474
# Epoch: 28 | train_loss: 1.2696 | train_acc: 0.5347 | test_loss: 1.2714 | test_acc: 0.5460
# Epoch: 29 | train_loss: 1.2644 | train_acc: 0.5394 | test_loss: 1.2527 | test_acc: 0.5418
# Epoch: 30 | train_loss: 1.2361 | train_acc: 0.5410 | test_loss: 1.2261 | test_acc: 0.5497
# Epoch: 31 | train_loss: 1.2243 | train_acc: 0.5624 | test_loss: 1.1480 | test_acc: 0.5878
# Epoch: 32 | train_loss: 1.1922 | train_acc: 0.5697 | test_loss: 1.2304 | test_acc: 0.5638
# Epoch: 33 | train_loss: 1.1827 | train_acc: 0.5683 | test_loss: 1.2064 | test_acc: 0.5632
# Epoch: 34 | train_loss: 1.2005 | train_acc: 0.5606 | test_loss: 1.1151 | test_acc: 0.6056
# Epoch: 35 | train_loss: 1.1545 | train_acc: 0.5913 | test_loss: 1.0816 | test_acc: 0.6050
# Epoch: 36 | train_loss: 1.1357 | train_acc: 0.5870 | test_loss: 1.1998 | test_acc: 0.5860
# Epoch: 37 | train_loss: 1.1402 | train_acc: 0.5890 | test_loss: 1.1786 | test_acc: 0.5808
# Epoch: 38 | train_loss: 1.1025 | train_acc: 0.6046 | test_loss: 1.2317 | test_acc: 0.5616
# Epoch: 39 | train_loss: 1.1119 | train_acc: 0.6010 | test_loss: 1.0235 | test_acc: 0.6398
# Epoch: 40 | train_loss: 1.1036 | train_acc: 0.6043 | test_loss: 1.0901 | test_acc: 0.5977
# Epoch: 41 | train_loss: 1.0696 | train_acc: 0.6137 | test_loss: 1.0239 | test_acc: 0.6432
# Epoch: 42 | train_loss: 1.0250 | train_acc: 0.6343 | test_loss: 1.0736 | test_acc: 0.6282
# Epoch: 43 | train_loss: 1.0463 | train_acc: 0.6181 | test_loss: 1.0962 | test_acc: 0.6165
# Epoch: 44 | train_loss: 1.0105 | train_acc: 0.6355 | test_loss: 1.0114 | test_acc: 0.6412
# Epoch: 45 | train_loss: 0.9955 | train_acc: 0.6446 | test_loss: 1.0392 | test_acc: 0.6309
# Epoch: 46 | train_loss: 0.9706 | train_acc: 0.6498 | test_loss: 1.0860 | test_acc: 0.6202
# Epoch: 47 | train_loss: 0.9560 | train_acc: 0.6596 | test_loss: 0.9547 | test_acc: 0.6625
# Epoch: 48 | train_loss: 0.9337 | train_acc: 0.6596 | test_loss: 0.9410 | test_acc: 0.6780
# Epoch: 49 | train_loss: 0.9261 | train_acc: 0.6693 | test_loss: 1.1453 | test_acc: 0.5997
# Epoch: 50 | train_loss: 0.9330 | train_acc: 0.6635 | test_loss: 1.0398 | test_acc: 0.6314
# Epoch: 51 | train_loss: 0.9096 | train_acc: 0.6742 | test_loss: 0.9029 | test_acc: 0.6754
# Epoch: 52 | train_loss: 0.8654 | train_acc: 0.6913 | test_loss: 1.0946 | test_acc: 0.6251
# Epoch: 53 | train_loss: 0.8702 | train_acc: 0.6899 | test_loss: 1.0598 | test_acc: 0.6392
# Epoch: 54 | train_loss: 0.8868 | train_acc: 0.6884 | test_loss: 0.8858 | test_acc: 0.6914
# Epoch: 55 | train_loss: 0.8335 | train_acc: 0.7032 | test_loss: 0.9347 | test_acc: 0.6838
# Epoch: 56 | train_loss: 0.8008 | train_acc: 0.7157 | test_loss: 0.9654 | test_acc: 0.6625
# Epoch: 57 | train_loss: 0.8331 | train_acc: 0.7036 | test_loss: 0.8882 | test_acc: 0.6875
# Epoch: 58 | train_loss: 0.8044 | train_acc: 0.7107 | test_loss: 0.8514 | test_acc: 0.7116
# Epoch: 59 | train_loss: 0.7713 | train_acc: 0.7278 | test_loss: 0.9541 | test_acc: 0.6680
# Epoch: 60 | train_loss: 0.8142 | train_acc: 0.7107 | test_loss: 0.9139 | test_acc: 0.6800
# Epoch: 61 | train_loss: 0.7942 | train_acc: 0.7218 | test_loss: 0.7938 | test_acc: 0.7320
# Epoch: 62 | train_loss: 0.7629 | train_acc: 0.7294 | test_loss: 0.9197 | test_acc: 0.6889
# Epoch: 63 | train_loss: 0.7423 | train_acc: 0.7370 | test_loss: 0.9214 | test_acc: 0.6690
# Epoch: 64 | train_loss: 0.7600 | train_acc: 0.7313 | test_loss: 0.7572 | test_acc: 0.7375
# Epoch: 65 | train_loss: 0.7234 | train_acc: 0.7432 | test_loss: 0.8644 | test_acc: 0.6986
# Epoch: 66 | train_loss: 0.7335 | train_acc: 0.7432 | test_loss: 0.8861 | test_acc: 0.6981
# Epoch: 67 | train_loss: 0.7331 | train_acc: 0.7423 | test_loss: 0.8192 | test_acc: 0.7242
# Epoch: 68 | train_loss: 0.7010 | train_acc: 0.7523 | test_loss: 0.7911 | test_acc: 0.7263
# Epoch: 69 | train_loss: 0.6811 | train_acc: 0.7546 | test_loss: 0.7476 | test_acc: 0.7432
# Epoch: 70 | train_loss: 0.6892 | train_acc: 0.7576 | test_loss: 0.7396 | test_acc: 0.7340
# Epoch: 71 | train_loss: 0.6286 | train_acc: 0.7780 | test_loss: 0.6827 | test_acc: 0.7722
# Epoch: 72 | train_loss: 0.6638 | train_acc: 0.7655 | test_loss: 0.7505 | test_acc: 0.7445
# Epoch: 73 | train_loss: 0.6831 | train_acc: 0.7508 | test_loss: 0.7864 | test_acc: 0.7184
# Epoch: 74 | train_loss: 0.6588 | train_acc: 0.7679 | test_loss: 0.7880 | test_acc: 0.7202
# Epoch: 75 | train_loss: 0.6136 | train_acc: 0.7822 | test_loss: 0.8000 | test_acc: 0.7264
# Epoch: 76 | train_loss: 0.6321 | train_acc: 0.7740 | test_loss: 0.7705 | test_acc: 0.7339
# Epoch: 77 | train_loss: 0.6220 | train_acc: 0.7834 | test_loss: 0.7142 | test_acc: 0.7586
# Epoch: 78 | train_loss: 0.6244 | train_acc: 0.7769 | test_loss: 0.6951 | test_acc: 0.7560
# Epoch: 79 | train_loss: 0.5818 | train_acc: 0.7949 | test_loss: 0.7664 | test_acc: 0.7389
# Epoch: 80 | train_loss: 0.5808 | train_acc: 0.7931 | test_loss: 0.6843 | test_acc: 0.7622
# Epoch: 81 | train_loss: 0.6131 | train_acc: 0.7818 | test_loss: 0.7866 | test_acc: 0.7287
# Epoch: 82 | train_loss: 0.5729 | train_acc: 0.7912 | test_loss: 0.7024 | test_acc: 0.7640
# Epoch: 83 | train_loss: 0.5805 | train_acc: 0.7988 | test_loss: 0.7831 | test_acc: 0.7480
# Epoch: 84 | train_loss: 0.5475 | train_acc: 0.8122 | test_loss: 0.7084 | test_acc: 0.7514
# Epoch: 85 | train_loss: 0.5900 | train_acc: 0.7912 | test_loss: 0.9754 | test_acc: 0.6690
# Epoch: 86 | train_loss: 0.5461 | train_acc: 0.8031 | test_loss: 0.6167 | test_acc: 0.8014
# Epoch: 87 | train_loss: 0.5433 | train_acc: 0.8098 | test_loss: 0.6101 | test_acc: 0.7847
# Epoch: 88 | train_loss: 0.5580 | train_acc: 0.8045 | test_loss: 0.7271 | test_acc: 0.7498
# Epoch: 89 | train_loss: 0.4939 | train_acc: 0.8273 | test_loss: 0.6602 | test_acc: 0.7580
# Epoch: 90 | train_loss: 0.5246 | train_acc: 0.8167 | test_loss: 0.8974 | test_acc: 0.6941
# Epoch: 91 | train_loss: 0.4940 | train_acc: 0.8300 | test_loss: 0.7102 | test_acc: 0.7543
# Epoch: 92 | train_loss: 0.5036 | train_acc: 0.8250 | test_loss: 0.7195 | test_acc: 0.7616
# Epoch: 93 | train_loss: 0.4899 | train_acc: 0.8289 | test_loss: 0.6699 | test_acc: 0.7751
# Epoch: 94 | train_loss: 0.4901 | train_acc: 0.8301 | test_loss: 0.6527 | test_acc: 0.7824
# Epoch: 95 | train_loss: 0.5016 | train_acc: 0.8214 | test_loss: 0.5628 | test_acc: 0.8040
# Epoch: 96 | train_loss: 0.4919 | train_acc: 0.8266 | test_loss: 0.7079 | test_acc: 0.7496
# Epoch: 97 | train_loss: 0.4861 | train_acc: 0.8355 | test_loss: 0.7034 | test_acc: 0.7751
# Epoch: 98 | train_loss: 0.4801 | train_acc: 0.8300 | test_loss: 0.8368 | test_acc: 0.7210
# Epoch: 99 | train_loss: 0.4564 | train_acc: 0.8400 | test_loss: 0.6739 | test_acc: 0.7794
# Epoch: 100 | train_loss: 0.4203 | train_acc: 0.8515 | test_loss: 0.7621 | test_acc: 0.7515
# Epoch: 101 | train_loss: 0.4602 | train_acc: 0.8367 | test_loss: 0.6758 | test_acc: 0.7831
# Epoch: 102 | train_loss: 0.4605 | train_acc: 0.8371 | test_loss: 0.6591 | test_acc: 0.7775
# Epoch: 103 | train_loss: 0.4436 | train_acc: 0.8428 | test_loss: 0.6391 | test_acc: 0.7796
# Epoch: 104 | train_loss: 0.4281 | train_acc: 0.8472 | test_loss: 0.6502 | test_acc: 0.7796
# Epoch: 105 | train_loss: 0.4466 | train_acc: 0.8488 | test_loss: 0.8971 | test_acc: 0.7115
# Epoch: 106 | train_loss: 0.4322 | train_acc: 0.8427 | test_loss: 0.7189 | test_acc: 0.7641
# Epoch: 107 | train_loss: 0.4288 | train_acc: 0.8516 | test_loss: 0.6386 | test_acc: 0.7845
# Epoch: 108 | train_loss: 0.4445 | train_acc: 0.8450 | test_loss: 0.7001 | test_acc: 0.7607
# Epoch: 109 | train_loss: 0.3944 | train_acc: 0.8600 | test_loss: 0.7534 | test_acc: 0.7629
# Epoch: 110 | train_loss: 0.4009 | train_acc: 0.8583 | test_loss: 0.6567 | test_acc: 0.7851
# Epoch: 111 | train_loss: 0.4046 | train_acc: 0.8576 | test_loss: 0.6026 | test_acc: 0.7987
# Epoch: 112 | train_loss: 0.3968 | train_acc: 0.8568 | test_loss: 0.6387 | test_acc: 0.7836
# Epoch: 113 | train_loss: 0.4340 | train_acc: 0.8490 | test_loss: 0.6001 | test_acc: 0.7881
# Epoch: 114 | train_loss: 0.3874 | train_acc: 0.8664 | test_loss: 0.6335 | test_acc: 0.7989
# Epoch: 115 | train_loss: 0.3999 | train_acc: 0.8633 | test_loss: 0.6390 | test_acc: 0.7874
# Epoch: 116 | train_loss: 0.3798 | train_acc: 0.8705 | test_loss: 0.7645 | test_acc: 0.7561
# Epoch: 117 | train_loss: 0.3529 | train_acc: 0.8774 | test_loss: 0.6445 | test_acc: 0.7817
# Epoch: 118 | train_loss: 0.4041 | train_acc: 0.8612 | test_loss: 0.7427 | test_acc: 0.7421
# Epoch: 119 | train_loss: 0.4018 | train_acc: 0.8595 | test_loss: 0.6138 | test_acc: 0.8003
# Epoch: 120 | train_loss: 0.3780 | train_acc: 0.8670 | test_loss: 0.6195 | test_acc: 0.8043
# Epoch: 121 | train_loss: 0.3655 | train_acc: 0.8744 | test_loss: 0.6334 | test_acc: 0.7873
# Total training time: 3016.402 seconds

# %%
plot_loss_curves(model_7_results)

# %% [markdown]
# ## 10. Evaluating our model on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate our models.

# %%
# Evaluate the RNN on the test set
evaluation = test_step(model=model_2,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.6530 | test acc = 0.7927

# %% [markdown]
# ## 12. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use our models to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2499 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilites first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.
#
# Changing the `model` and `index` arguments on the `predict()` function can let us make further testing.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Printing the shape to see how many indexes we have
X_test.shape
# Out:
# torch.Size([2499, 1, 72, 72])

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
predict(model=model_2,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# Target: jazz, Predicted label: jazz

# %% [markdown]
# ## 13. Making a confusion matrix for further evaluation
#
# For a good vizualization of our model's performance, we can use a confusion matrix for our models. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.24.0

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_2.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_2(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# # Save
# plt.savefig(
#     "MLP_confusion_matrix.png",
#     dpi=144,
#     bbox_inches='tight',
#     facecolor=fig.get_facecolor()
# )

plt.show()
