# %% [markdown]
# # Music Genre Classification using Vision Transformer (ViT) and AST-style Mel Spectrograms (10 second samples)

# %% [markdown]
# In this notebook, we evaluate the Transformer architecture using Mel spectrograms.
#
# The Transformer architecture appears to be used with audio in various occasions. The Transformer neural network architecture was originally intended for use with text. However, with further research a version of the Transformer architecture was proposed for use with images. This version is know as the Vision Transformer (ViT) and it has been used with audio as well. In this case the ViT is used with audio representations such as MFCCs or Mel Spectrograms. This is why, in order to study the Transformer architecture, we will use the ViT rather than other Transformer variants.
#
# Furthermore, in the following experiments, our data will be exported using a 10 segmentation division. That means that each audio sample will be 3 seconds long.

# %% [markdown]
# ## 0. Importing libraries, setting up device agnostic code
# We start by importing the main needed libraries to run the script. Then we check the GPU properties and set up device agnostic code. In this manner, if a GPU is available, it will be used. Furthermore, we set a random seed so that a fixed seed will maintain consistency in experimental results. This will also make it easier to compare different approaches.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torchaudio
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchaudio.__version__)
# Out:
# 2.7.0+cu118
# 2.7.0+cu118

# %%
# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)

# %%
# Set random seeds
RANDOM_SEED = 42

set_seeds()
np.random.seed(RANDOM_SEED)

# %%
# !nvidia-smi
# Out:
# Wed Feb 11 14:40:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   41C    P8            N/A  /  115W |    1153MiB /   8188MiB |     57%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1764    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            3028    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A            4452    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A            9308    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10332    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           10356    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10760    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           11156    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           12568    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13248    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           15656    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           16684    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           16880    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           18032    C+G   ....3.2.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           18832    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20132    C+G   ...AppData\Local\Viber\Viber.exe      N/A      |
# |    0   N/A  N/A           21240    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           22184    C+G   ...\v4.3.12\ProtonVPN.Client.exe      N/A      |
# |    0   N/A  N/A           24320    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           24556    C+G   ...yb3d8bbwe\Notepad\Notepad.exe      N/A      |
# |    0   N/A  N/A           24728    C+G   ...Desktop\WDADesktopService.exe      N/A      |
# |    0   N/A  N/A           25532    C+G   ...\Proton\Drive\ProtonDrive.exe      N/A      |
# |    0   N/A  N/A           27424    C+G   ...6)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A           27740    C+G   ...der\Utility\SpyderUtility.exe      N/A      |
# |    0   N/A  N/A           27784    C+G   ...rsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A           33504    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Create device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Loading data
# We load the data from the respective `.json` file in the current directory. Data is loaded as numpy arrays. Those arrays are used to create PyTorch tensors. We are also going to create a *classes* list in order to use the name of the classes for predictions later.
#
# Data is loaded in the shape of `(batch_size, time_frames, mel_bands)`.\
# We will then reshape it into a 72x72 matrix, all according to the following paper - https://ieeexplore.ieee.org/document/9573568 \
# We could optionally permute the tensor to have the shape of `(batch_size, time_frames, mel_bands)`, however this is not the shape mentioned in the paper.

# %%
# Create function to load melspec data from .json file
def load_data(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)

    # Convert
    X = np.array(data['melspec'])
    y = np.array(data['labels'])

    return X, y

# %%
# Create function to load classes from .json file
def load_classes(dataset_path):
    with open(dataset_path, 'r') as fp:
        data = json.load(fp)
    classes = data['mapping']
    return classes

# %%
# Load classes
DATASET_PATH = "data_full.json"

classes = load_classes(DATASET_PATH)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Load data
inputs, labels = load_data(DATASET_PATH)
inputs.shape, labels.shape
# Out:
# ((10000, 297, 128), (10000,))

# %%
# Turn data into tensors, also unsqueeze and permute, to be ready for Transformer
X = torch.from_numpy(inputs).float() # Weight calculations expect float
y = torch.from_numpy(labels).long() # CrossEntropyLoss expects long
# X = X.permute(0, 2, 1).unsqueeze(1)
X = X.unsqueeze(1)
X.shape, y.shape
# Out:
# (torch.Size([10000, 1, 297, 128]), torch.Size([10000]))

# %%
# Resize Spectrogram
import torch.nn.functional as F
X = F.interpolate(X, size=(72, 72), mode="bilinear", align_corners=False)
X.shape
# Out:
# torch.Size([10000, 1, 72, 72])

# %% [markdown]
# ## 2. Create DataSets and DataLoaders
# In order to use the data in our model, we have to organize it into PyTorch DataLoaders.
# After loading the data, we split them into three sets: train_set, validation_set and test_set. The validation_set will be used during the training for evaluation. The test_set will be used after the model is ready. In order for it to be exposed in never seen data.
#
# After dividing the sets, we create the respective datasets and dataloaders.

# %%
# Creating a function to divide the sets
def divide_sets(X, y, test_size, validation_size, random_state=None):
    # create train/validation split

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=random_state)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Create train, validation and test sets test size is 25% of the whole set. Validation size is 20% of the remaining train_set
X_train, X_validation, X_test, y_train, y_validation, y_test = divide_sets(X, y, test_size=0.25,
                                                                                validation_size=0.2,
                                                                                random_state=RANDOM_SEED)

# %%
# Check if data is divided correctly
print(X.shape[0] == X_train.shape[0] + X_validation.shape[0] + X_test.shape[0])
print(y.shape[0] == y_train.shape[0] + y_validation.shape[0] + y_test.shape[0])
# Out:
# True
# True

# %%
# Create datasets and dataloaders
from torch.utils.data import TensorDataset, DataLoader

BATCH_SIZE=32
torch.manual_seed(RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
validation_dataset = TensorDataset(X_validation, y_validation)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True)
validation_dataloader = DataLoader(validation_dataset,
                                   batch_size=BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset,
                         batch_size=BATCH_SIZE)

print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x000002141890C1A0>, <torch.utils.data.dataloader.DataLoader object at 0x000002141881F9D0>)
# Length of train dataloader: 188 batches of 32
# Length of validation dataloader: 47 batches of 32
# Length of test dataloader: 79 batches of 32

# %%
# Checking the dataset shapes using test_dataset
test_features_batch, test_labels_batch = next(iter(test_dataloader))
print(test_features_batch.shape, "-> (batch_size, time_frames, mel_bands)")
print(test_labels_batch.shape, "-> (batch_size,) each entry is the class index of a sample")
print(test_features_batch[0].shape, "-> (time_frames, mel_bands)")
print(test_labels_batch[0], "-> (label)")
# Out:
# torch.Size([32, 1, 72, 72]) -> (batch_size, time_frames, mel_bands)
# torch.Size([32]) -> (batch_size,) each entry is the class index of a sample
# torch.Size([1, 72, 72]) -> (time_frames, mel_bands)
# tensor(6) -> (label)

# %% [markdown]
# ## 3. Data visualization
# For better perception of the subject, we implement some visualization of the data. We use matplotlib libraries to visualize a Mel Spectrogram of the first example. The data has to be turned into numpy arrays in order to be processed by matplotlib.
# In the picture, the y-axis has the mel banks. Usually this axis shows the frequency in order to be more user-friendly. This is done by transposing the main frequency of each of the bank from mels to Hz. However, we are not going to do that, as we are interested in the visual shape of the spectrogram. But this means that one can view the y-axis as a frequency axis and indeed we see the frequencies that appear in each sample. The samples are 3 sec long.
#
# A second visualization is implemented later, in order to view various representations of different genres.
#
# The music genre of each representation can also be viewed.

# %%
# Visualise data
np.random.seed(RANDOM_SEED)
INDEX = np.random.randint(len(X))
melspec_example = X[INDEX].squeeze(0).numpy()

plt.imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
plt.colorbar()
plt.title("Mel Spectrogram Example (from tensor)")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
# Vizualize different genres
np.random.seed(RANDOM_SEED)
indices = np.random.choice(len(X), size=6, replace=False)

fig, axs = plt.subplots(2, 3, figsize=(15, 6),constrained_layout=False)
fig.suptitle("Mel Spectogram Examples of Different Music Genres", fontsize=18)

for i, idx in enumerate(indices):
    row = i // 3
    col = i % 3
    melspec_example = X[idx].squeeze(0).numpy()
    im = axs[row, col].imshow(melspec_example, cmap='turbo', aspect='auto', origin='lower')
    axs[row, col].set_title(f"Label: {classes[y[idx]]}")
    axs[row, col].set_xlabel("Time frames")
    axs[row, col].set_ylabel("Mel Frequency Bin")
    axs[row, col].tick_params(axis='both', which='both', length=5)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# ## 4. Building a ViT Model
# In order to build our ViT model, we will replicate the guidelines of the original ViT paper. PyTorch provides all the needed classes in order to implement a ViT model.\
# Our model will make use of two classes:
# * The `PatchEmbedding` class is responsible for creating the embeddings. It uses convolution layers in order to divide the original audio representation into patches.
# * The `ViT` class uses the output of the `PatchEmbedding` class. It follows the ViT architecture as it is defined in the original ViT paper.
#
# The original ViT paper is here - https://arxiv.org/abs/2010.11929

# %% [markdown]
# ### 4.1 Create patch embeddings
# Our audio representation is already resized into a 72x72 matrix. Ths matrix will be divided into 36 patches, each being a 12x12 matrix. We follow this division convention as it is defined in the "Vision Transformer for Music Genre Classification using Mel-frequency Cepstrum Coefficient" paper.
#
# Full paper here - https://ieeexplore.ieee.org/document/9573568

# %%
# 1. Create a class called PatchEmbedding
class PatchEmbedding(nn.Module):
  # 2. Initialize the layer with appropriate hyperparameters
  def __init__(self,
               in_channels:int=1,
               patch_size:int=12,
               embedding_dim:int=768): # from Table 1 for ViT-Base
    super().__init__()

    self.patch_size = patch_size

    # 3. Create a layer to turn an image into embedded patches
    self.patcher = nn.Conv2d(in_channels=in_channels,
                             out_channels=embedding_dim,
                             kernel_size=patch_size,
                             stride=patch_size,
                             padding=0)

    # 4. Create a layer to flatten feature map outputs of Conv2d
    self.flatten = nn.Flatten(start_dim=2,
                              end_dim=3)

  # 5. Define a forward method to define the forward computation steps
  def forward(self, x):
    # Create assertion to check that inputs are the correct shape
    graph_resolution = x.shape[-1]
    assert graph_resolution % self.patch_size == 0, f"Input image size must be divisible by patch size, image shape: {graph_resolution}, patch size: {self.patch_size}"

    # Perform the forward pass
    x_patched = self.patcher(x)
    x_flattened = self.flatten(x_patched)
    # 6. Make the returned sequence embedding dimensions are in the right order (batch_size, number_of_patches, embedding_dimension)
    return x_flattened.permute(0, 2, 1)

# %%
# Patchify a random sample

# Select a sample
np.random.seed(RANDOM_SEED)
INDEX = np.random.randint(len(X))
melspec_sample = X[INDEX]

# Create an instance of patch embedding layer
patchify = PatchEmbedding(in_channels=1,
                          patch_size=12,
                          embedding_dim=768)

# Pass the sample through patch embedding layer
print(f"Input image size: {melspec_sample.unsqueeze(0).shape}")
patch_embedded_image = patchify(melspec_sample.unsqueeze(0)) # add an extra batch dimension
print(f"Output patch embedding sequence shape: {patch_embedded_image.shape}")
# Out:
# Input image size: torch.Size([1, 1, 72, 72])
# Output patch embedding sequence shape: torch.Size([1, 36, 768])

# %% [markdown]
# ### 4.2 Create ViT class
# Our ViT class uses the PatchEmbedding class in order to create the embeddings and then handle them according to the ViT paper.

# %%
class ViT(nn.Module):
  def __init__(self,
               graph_size=72,
               num_channels=1,
               patch_size=12,
               embedding_dim=768,  # from Table 1
               dropout=0.1,
               mlp_size=3072,  # from Table 1
               num_transformer_layers=12,  # from Table 1
               num_heads=12,  # from Table 1 (number of multi-head self attention heads)
               num_classes=10): # number of GTZAN classes
    super().__init__()

    # Assert image size is divisible by patch size
    assert graph_size % patch_size == 0, "Graph size must be divisible by patch size."

    # 1. Create patch embedding
    self.patch_embedding = PatchEmbedding(in_channels=num_channels,
                                          patch_size=patch_size,
                                          embedding_dim=embedding_dim)

    # 2. Create class token
    self.class_token = nn.Parameter(torch.randn(1, 1, embedding_dim),
                                    requires_grad=True)

    # 3. Create positional embedding
    num_patches = (graph_size * graph_size) // patch_size ** 2 # N = HW/P^2
    self.positional_embedding = nn.Parameter(torch.randn(1, num_patches+1, embedding_dim))

    # 4. Create patch + position embedding dropout
    self.embedding_dropout = nn.Dropout(p=dropout)

    # # 5. Create Transformer Encoder layer (single)
    # self.transformer_encoder_layer = nn.TransformerEncoderLayer(d_model=embedding_dim,
    #                                                             nhead=num_heads,
    #                                                             dim_feedforward=mlp_size,
    #                                                             activation="gelu",
    #                                                             batch_first=True,
    #                                                             norm_first=True)

    # 5. Create stack Transformer Encoder layers (stacked single layers)
    self.transformer_encoder = nn.TransformerEncoder(encoder_layer=nn.TransformerEncoderLayer(d_model=embedding_dim,
                                                                                              nhead=num_heads,
                                                                                              dim_feedforward=mlp_size,
                                                                                              activation="gelu",
                                                                                              batch_first=True,
                                                                                              norm_first=True), # Create a single Transformer Encoder Layer
                                                     num_layers=num_transformer_layers) # Stack it N times

    # 7. Create MLP head
    self.mlp_head = nn.Sequential(
        nn.LayerNorm(normalized_shape=embedding_dim),
        nn.Linear(in_features=embedding_dim,
                  out_features=num_classes)
    )

  def forward(self, x):
    # Get some dimensions from x
    batch_size = x.shape[0]

    # Create the patch embedding
    x = self.patch_embedding(x)
    # print(x.shape)

    # First, expand the class token across the batch size
    class_token = self.class_token.expand(batch_size, -1, -1) # "-1" means infer the dimension

    # Prepend the class token to the patch embedding
    x = torch.cat((class_token, x), dim=1)
    # print(x.shape)

    # Add the positional embedding to patch embedding with class token
    x = self.positional_embedding + x
    # print(x.shape)

    # Dropout on patch + positional embedding
    x = self.embedding_dropout(x)

    # Pass embedding through Transformer Encoder stack
    x = self.transformer_encoder(x)

    # Pass 0th index of x through MLP head
    x = self.mlp_head(x[:, 0])

    return x

# %%
# Create demo tensor
demo_tensor = torch.randn(1, 1, 72, 72).to(device)
print(demo_tensor.shape)
# Out:
# torch.Size([1, 1, 72, 72])

# %%
# Create ViT and do a test pass
torch.manual_seed(RANDOM_SEED)
model_0 = ViT().to(device)
print(model_0(demo_tensor))
# Out:
# C:\Users\thebo\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# tensor([[-0.1794,  0.0371, -0.3629,  0.4621,  0.3358, -0.4676, -0.1972,  0.5001,
#          -0.3213,  0.2869]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
from torchinfo import summary
summary(model=ViT(),
        input_size=demo_tensor.shape)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ViT                                           [1, 10]                   29,184
# ├─PatchEmbedding: 1-1                         [1, 36, 768]              --
# │    └─Conv2d: 2-1                            [1, 768, 6, 6]            111,360
# │    └─Flatten: 2-2                           [1, 768, 36]              --
# ├─Dropout: 1-2                                [1, 37, 768]              --
# ├─TransformerEncoder: 1-3                     [1, 37, 768]              --
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-2      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-3      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-4      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-5      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-6      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-7      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-8      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-9      [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-10     [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-11     [1, 37, 768]              7,087,872
# │    │    └─TransformerEncoderLayer: 3-12     [1, 37, 768]              7,087,872
# ├─Sequential: 1-4                             [1, 10]                   --
# │    └─LayerNorm: 2-4                         [1, 768]                  1,536
# │    └─Linear: 2-5                            [1, 10]                   7,690
# ===============================================================================================
# Total params: 85,204,234
# Trainable params: 85,204,234
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 60.72
# ===============================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 19.32
# Params size (MB): 227.31
# Estimated Total Size (MB): 246.65
# ===============================================================================================

# %% [markdown]
# ## 5. Training the ViT model
#
# We start by setting a loss function and an optimizer. Two crucial elements of the training procedure.
#
# In order to implement the training pipeline, we will create two separate functions:
# * `train_step()`: This function is responsible for the training of the model. It also includes the logic for calculating the accuracy. We could use `torchmetrics.accuracy()`, but instead one can calculate it. We use the `argmax()` method after applying a `softmax()` on the logits that are extracted from the model. This calculation gives us the predicted label, because it returns the index of the highest probability. After that, the accuracy is calculated as the sum of predicted labels that are the same as the labels, divided by the number of samples.
# * `test_step()`: This function will evaluate the loss and accuracy on a set. Initially we will use it on the evaluation set during training.
#
# Those two functions are combined in the `train()` function in order to train the model for a set number of epochs. We also use the `timeit` library to set a timer in order to time the training. The `train()` function returns a dictionary with the results, in order to use them for plotting.

# %%
# Optimizer values are according to this paper - https://ieeexplore.ieee.org/document/9573568
optimizer = torch.optim.Adam(model_0.parameters(),
                             lr=0.001,
                             weight_decay=0.001)

loss_fn = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ### 5.1 Implementing `SummaryWriter()`
# Before creating the training functions, we will create a function that includes a `SummaryWriter()` object to keep logs of our experiments.
# The `create_writer()` function will return a `SummaryWriter()` object. Our `train()` function has a writer parameter where we can put an object created with the `create_writer()` function in order to keep logs of a certain training procedure.

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import os

def create_writer(source: str,
                  segments: int,
                  model_name: str,
                  extra: str=None) -> torch.utils.tensorboard.writer.SummaryWriter:

    # Project root (adjust if needed)
    PROJECT_ROOT = os.path.abspath(
        os.path.join(os.getcwd(), "..", "..")
    )

    # Get timestamp of current date (all experiments on certain day live in same folder)
    timestamp = datetime.now().strftime("%d-%m-%Y") # returns current date in DD-MM-YYYY format

    if extra:
        # Create log directory path
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name, extra
        )
    else:
        log_dir = os.path.join(
            PROJECT_ROOT, "runs", timestamp, source, f"{segments}_segments", model_name
        )

    print(f"[INFO] Created SummaryWriter, saving to: {log_dir}...")
    return SummaryWriter(log_dir=log_dir)

# %% [markdown]
# ### 5.2 Creating training functions

# %%
# Create a train loop function
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Create test loop function
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create train function by combining train_step and test_step
from tqdm.auto import tqdm

# Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
          ):

    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
    ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %%
# Train the model
# Set number of epochs
NUM_EPOCHS = 150

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=validation_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.8952 | train_acc: 0.3399 | test_loss: 1.4981 | test_acc: 0.4348
# Epoch: 2 | train_loss: 1.5371 | train_acc: 0.4382 | test_loss: 1.4739 | test_acc: 0.4688
# Epoch: 3 | train_loss: 1.4409 | train_acc: 0.4815 | test_loss: 1.3326 | test_acc: 0.5265
# Epoch: 4 | train_loss: 1.3367 | train_acc: 0.5178 | test_loss: 1.1448 | test_acc: 0.5765
# Epoch: 5 | train_loss: 1.2286 | train_acc: 0.5577 | test_loss: 1.1486 | test_acc: 0.5903
# Epoch: 6 | train_loss: 1.1832 | train_acc: 0.5751 | test_loss: 1.0788 | test_acc: 0.6064
# Epoch: 7 | train_loss: 1.0982 | train_acc: 0.6080 | test_loss: 1.1387 | test_acc: 0.5918
# Epoch: 8 | train_loss: 1.0908 | train_acc: 0.6127 | test_loss: 1.0145 | test_acc: 0.6361
# Epoch: 9 | train_loss: 1.0161 | train_acc: 0.6416 | test_loss: 1.0140 | test_acc: 0.6265
# Epoch: 10 | train_loss: 0.9868 | train_acc: 0.6449 | test_loss: 1.0009 | test_acc: 0.6437
# Epoch: 11 | train_loss: 0.9512 | train_acc: 0.6692 | test_loss: 1.0198 | test_acc: 0.6262
# Epoch: 12 | train_loss: 0.9221 | train_acc: 0.6767 | test_loss: 1.0389 | test_acc: 0.6207
# Epoch: 13 | train_loss: 0.8886 | train_acc: 0.6835 | test_loss: 0.9102 | test_acc: 0.6761
# Epoch: 14 | train_loss: 0.8750 | train_acc: 0.6943 | test_loss: 0.9706 | test_acc: 0.6454
# Epoch: 15 | train_loss: 0.8521 | train_acc: 0.7026 | test_loss: 0.9155 | test_acc: 0.6747
# Epoch: 16 | train_loss: 0.8185 | train_acc: 0.7151 | test_loss: 0.8763 | test_acc: 0.6740
# Epoch: 17 | train_loss: 0.7850 | train_acc: 0.7212 | test_loss: 0.9628 | test_acc: 0.6411
# Epoch: 18 | train_loss: 0.7758 | train_acc: 0.7296 | test_loss: 0.9393 | test_acc: 0.6579
# Epoch: 19 | train_loss: 0.7389 | train_acc: 0.7417 | test_loss: 0.9864 | test_acc: 0.6607
# Epoch: 20 | train_loss: 0.7273 | train_acc: 0.7429 | test_loss: 0.9741 | test_acc: 0.6522
# Epoch: 21 | train_loss: 0.7047 | train_acc: 0.7503 | test_loss: 0.9621 | test_acc: 0.6575
# Epoch: 22 | train_loss: 0.6832 | train_acc: 0.7560 | test_loss: 0.9508 | test_acc: 0.6644
# Epoch: 23 | train_loss: 0.6661 | train_acc: 0.7638 | test_loss: 0.8704 | test_acc: 0.6827
# Epoch: 24 | train_loss: 0.6641 | train_acc: 0.7673 | test_loss: 0.8845 | test_acc: 0.6847
# Epoch: 25 | train_loss: 0.6297 | train_acc: 0.7793 | test_loss: 0.8637 | test_acc: 0.6934
# Epoch: 26 | train_loss: 0.6288 | train_acc: 0.7781 | test_loss: 0.9930 | test_acc: 0.6539
# Epoch: 27 | train_loss: 0.6208 | train_acc: 0.7774 | test_loss: 0.9195 | test_acc: 0.6667
# Epoch: 28 | train_loss: 0.5999 | train_acc: 0.7857 | test_loss: 0.9224 | test_acc: 0.6892
# Epoch: 29 | train_loss: 0.5955 | train_acc: 0.7952 | test_loss: 0.9425 | test_acc: 0.6703
# Epoch: 30 | train_loss: 0.5779 | train_acc: 0.7970 | test_loss: 0.9311 | test_acc: 0.6780
# Epoch: 31 | train_loss: 0.5627 | train_acc: 0.7975 | test_loss: 0.9661 | test_acc: 0.6847
# Epoch: 32 | train_loss: 0.5685 | train_acc: 0.7954 | test_loss: 0.9504 | test_acc: 0.6780
# Epoch: 33 | train_loss: 0.5314 | train_acc: 0.8108 | test_loss: 0.9047 | test_acc: 0.7039
# Epoch: 34 | train_loss: 0.5259 | train_acc: 0.8167 | test_loss: 0.9645 | test_acc: 0.6900
# Epoch: 35 | train_loss: 0.5144 | train_acc: 0.8115 | test_loss: 0.9574 | test_acc: 0.6843
# Epoch: 36 | train_loss: 0.5101 | train_acc: 0.8221 | test_loss: 0.9789 | test_acc: 0.6968
# Epoch: 37 | train_loss: 0.5024 | train_acc: 0.8226 | test_loss: 0.9870 | test_acc: 0.6736
# Epoch: 38 | train_loss: 0.4810 | train_acc: 0.8298 | test_loss: 0.9485 | test_acc: 0.6946
# Epoch: 39 | train_loss: 0.4937 | train_acc: 0.8256 | test_loss: 1.0355 | test_acc: 0.6580
# Epoch: 40 | train_loss: 0.4801 | train_acc: 0.8324 | test_loss: 1.0810 | test_acc: 0.6628
# Epoch: 41 | train_loss: 0.4685 | train_acc: 0.8356 | test_loss: 0.9621 | test_acc: 0.6781
# Epoch: 42 | train_loss: 0.4343 | train_acc: 0.8504 | test_loss: 0.9918 | test_acc: 0.6833
# Epoch: 43 | train_loss: 0.4526 | train_acc: 0.8406 | test_loss: 1.0181 | test_acc: 0.7055
# Epoch: 44 | train_loss: 0.4437 | train_acc: 0.8428 | test_loss: 1.0827 | test_acc: 0.6836
# Epoch: 45 | train_loss: 0.4454 | train_acc: 0.8408 | test_loss: 0.9641 | test_acc: 0.7041
# Epoch: 46 | train_loss: 0.4344 | train_acc: 0.8431 | test_loss: 1.0172 | test_acc: 0.6686
# Epoch: 47 | train_loss: 0.4196 | train_acc: 0.8509 | test_loss: 1.0143 | test_acc: 0.6860
# Epoch: 48 | train_loss: 0.4057 | train_acc: 0.8567 | test_loss: 0.9488 | test_acc: 0.7032
# Epoch: 49 | train_loss: 0.4280 | train_acc: 0.8462 | test_loss: 1.0053 | test_acc: 0.6995
# Epoch: 50 | train_loss: 0.4082 | train_acc: 0.8519 | test_loss: 1.0672 | test_acc: 0.6638
# Epoch: 51 | train_loss: 0.4125 | train_acc: 0.8544 | test_loss: 0.9706 | test_acc: 0.7073
# Epoch: 52 | train_loss: 0.3887 | train_acc: 0.8609 | test_loss: 0.9718 | test_acc: 0.7094
# Epoch: 53 | train_loss: 0.3773 | train_acc: 0.8672 | test_loss: 0.9915 | test_acc: 0.6975
# Epoch: 54 | train_loss: 0.3775 | train_acc: 0.8660 | test_loss: 0.9449 | test_acc: 0.6995
# Epoch: 55 | train_loss: 0.3781 | train_acc: 0.8654 | test_loss: 1.0447 | test_acc: 0.7015
# Epoch: 56 | train_loss: 0.3851 | train_acc: 0.8642 | test_loss: 1.0359 | test_acc: 0.6960
# Epoch: 57 | train_loss: 0.3731 | train_acc: 0.8649 | test_loss: 1.0406 | test_acc: 0.6913
# Epoch: 58 | train_loss: 0.3573 | train_acc: 0.8747 | test_loss: 1.1337 | test_acc: 0.6615
# Epoch: 59 | train_loss: 0.3558 | train_acc: 0.8674 | test_loss: 1.0754 | test_acc: 0.6866
# Epoch: 60 | train_loss: 0.3437 | train_acc: 0.8798 | test_loss: 0.9786 | test_acc: 0.7127
# Epoch: 61 | train_loss: 0.3747 | train_acc: 0.8630 | test_loss: 1.0269 | test_acc: 0.7101
# Epoch: 62 | train_loss: 0.3507 | train_acc: 0.8712 | test_loss: 0.9603 | test_acc: 0.7109
# Epoch: 63 | train_loss: 0.3452 | train_acc: 0.8767 | test_loss: 1.0904 | test_acc: 0.6745
# Epoch: 64 | train_loss: 0.3464 | train_acc: 0.8778 | test_loss: 1.0060 | test_acc: 0.7016
# Epoch: 65 | train_loss: 0.3431 | train_acc: 0.8757 | test_loss: 1.0552 | test_acc: 0.6967
# Epoch: 66 | train_loss: 0.3357 | train_acc: 0.8797 | test_loss: 1.0278 | test_acc: 0.7040
# Epoch: 67 | train_loss: 0.3114 | train_acc: 0.8848 | test_loss: 1.0789 | test_acc: 0.7073
# Epoch: 68 | train_loss: 0.3366 | train_acc: 0.8803 | test_loss: 1.0151 | test_acc: 0.7093
# Epoch: 69 | train_loss: 0.3243 | train_acc: 0.8870 | test_loss: 1.1385 | test_acc: 0.6774
# Epoch: 70 | train_loss: 0.3188 | train_acc: 0.8820 | test_loss: 1.0737 | test_acc: 0.7108
# Epoch: 71 | train_loss: 0.3153 | train_acc: 0.8873 | test_loss: 1.0868 | test_acc: 0.6979
# Epoch: 72 | train_loss: 0.3156 | train_acc: 0.8836 | test_loss: 1.0743 | test_acc: 0.6860
# Epoch: 73 | train_loss: 0.3301 | train_acc: 0.8828 | test_loss: 1.1343 | test_acc: 0.6647
# Epoch: 74 | train_loss: 0.3019 | train_acc: 0.8898 | test_loss: 1.0510 | test_acc: 0.6879
# Epoch: 75 | train_loss: 0.3119 | train_acc: 0.8895 | test_loss: 1.0369 | test_acc: 0.7111
# Epoch: 76 | train_loss: 0.3036 | train_acc: 0.8911 | test_loss: 1.0738 | test_acc: 0.6920
# Epoch: 77 | train_loss: 0.3283 | train_acc: 0.8851 | test_loss: 1.3113 | test_acc: 0.6459
# Epoch: 78 | train_loss: 0.2994 | train_acc: 0.8941 | test_loss: 1.0607 | test_acc: 0.6900
# Epoch: 79 | train_loss: 0.3085 | train_acc: 0.8918 | test_loss: 1.1212 | test_acc: 0.6933
# Epoch: 80 | train_loss: 0.3011 | train_acc: 0.8949 | test_loss: 1.1697 | test_acc: 0.6884
# Epoch: 81 | train_loss: 0.2943 | train_acc: 0.8986 | test_loss: 1.1058 | test_acc: 0.6847
# Epoch: 82 | train_loss: 0.2836 | train_acc: 0.8984 | test_loss: 1.0686 | test_acc: 0.6901
# Epoch: 83 | train_loss: 0.3036 | train_acc: 0.8944 | test_loss: 1.0596 | test_acc: 0.6913
# Epoch: 84 | train_loss: 0.2974 | train_acc: 0.8913 | test_loss: 1.0597 | test_acc: 0.7201
# Epoch: 85 | train_loss: 0.2920 | train_acc: 0.8939 | test_loss: 1.0967 | test_acc: 0.7100
# Epoch: 86 | train_loss: 0.2692 | train_acc: 0.9023 | test_loss: 1.1611 | test_acc: 0.6847
# Epoch: 87 | train_loss: 0.2932 | train_acc: 0.8991 | test_loss: 1.0172 | test_acc: 0.7020
# Epoch: 88 | train_loss: 0.2713 | train_acc: 0.9029 | test_loss: 1.0768 | test_acc: 0.7140
# Epoch: 89 | train_loss: 0.2802 | train_acc: 0.8988 | test_loss: 1.0949 | test_acc: 0.6928
# Epoch: 90 | train_loss: 0.2936 | train_acc: 0.8946 | test_loss: 1.0697 | test_acc: 0.7004
# Epoch: 91 | train_loss: 0.2741 | train_acc: 0.9038 | test_loss: 1.1498 | test_acc: 0.6954
# Epoch: 92 | train_loss: 0.2903 | train_acc: 0.8964 | test_loss: 1.2907 | test_acc: 0.6798
# Epoch: 93 | train_loss: 0.2914 | train_acc: 0.8954 | test_loss: 1.1773 | test_acc: 0.7031
# Epoch: 94 | train_loss: 0.2662 | train_acc: 0.9081 | test_loss: 1.0957 | test_acc: 0.6905
# Epoch: 95 | train_loss: 0.2725 | train_acc: 0.9058 | test_loss: 1.2962 | test_acc: 0.6554
# Epoch: 96 | train_loss: 0.2814 | train_acc: 0.8976 | test_loss: 1.0779 | test_acc: 0.7194
# Epoch: 97 | train_loss: 0.2716 | train_acc: 0.9003 | test_loss: 1.0318 | test_acc: 0.7075
# Epoch: 98 | train_loss: 0.2706 | train_acc: 0.9041 | test_loss: 1.1097 | test_acc: 0.7010
# Epoch: 99 | train_loss: 0.2792 | train_acc: 0.8993 | test_loss: 1.1366 | test_acc: 0.6853
# Epoch: 100 | train_loss: 0.2666 | train_acc: 0.9031 | test_loss: 1.0688 | test_acc: 0.7000
# Epoch: 101 | train_loss: 0.2545 | train_acc: 0.9132 | test_loss: 1.1336 | test_acc: 0.7033
# Epoch: 102 | train_loss: 0.2742 | train_acc: 0.9009 | test_loss: 1.0456 | test_acc: 0.7206
# Epoch: 103 | train_loss: 0.2575 | train_acc: 0.9058 | test_loss: 1.0869 | test_acc: 0.7107
# Epoch: 104 | train_loss: 0.2702 | train_acc: 0.9051 | test_loss: 1.0562 | test_acc: 0.7048
# Epoch: 105 | train_loss: 0.2824 | train_acc: 0.9018 | test_loss: 1.1026 | test_acc: 0.7028
# Epoch: 106 | train_loss: 0.2474 | train_acc: 0.9114 | test_loss: 1.1671 | test_acc: 0.6785
# Epoch: 107 | train_loss: 0.2470 | train_acc: 0.9136 | test_loss: 1.1095 | test_acc: 0.7072
# Epoch: 108 | train_loss: 0.2738 | train_acc: 0.9039 | test_loss: 1.0207 | test_acc: 0.7089
# Epoch: 109 | train_loss: 0.2373 | train_acc: 0.9179 | test_loss: 1.0950 | test_acc: 0.7101
# Epoch: 110 | train_loss: 0.2387 | train_acc: 0.9195 | test_loss: 1.1107 | test_acc: 0.6948
# Epoch: 111 | train_loss: 0.2596 | train_acc: 0.9056 | test_loss: 1.2133 | test_acc: 0.6914
# Epoch: 112 | train_loss: 0.2756 | train_acc: 0.9026 | test_loss: 1.1361 | test_acc: 0.6941
# Epoch: 113 | train_loss: 0.2459 | train_acc: 0.9097 | test_loss: 1.1962 | test_acc: 0.6781
# Epoch: 114 | train_loss: 0.2412 | train_acc: 0.9182 | test_loss: 1.2431 | test_acc: 0.6900
# Epoch: 115 | train_loss: 0.2723 | train_acc: 0.9014 | test_loss: 1.0989 | test_acc: 0.7066
# Epoch: 116 | train_loss: 0.2584 | train_acc: 0.9067 | test_loss: 1.2183 | test_acc: 0.6925
# Epoch: 117 | train_loss: 0.2577 | train_acc: 0.9086 | test_loss: 1.1674 | test_acc: 0.6960
# Epoch: 118 | train_loss: 0.2253 | train_acc: 0.9239 | test_loss: 1.0943 | test_acc: 0.7121
# Epoch: 119 | train_loss: 0.2479 | train_acc: 0.9127 | test_loss: 1.1257 | test_acc: 0.6979
# Epoch: 120 | train_loss: 0.2705 | train_acc: 0.9044 | test_loss: 1.0705 | test_acc: 0.7180
# Epoch: 121 | train_loss: 0.2550 | train_acc: 0.9109 | test_loss: 1.0320 | test_acc: 0.6999
# Epoch: 122 | train_loss: 0.2246 | train_acc: 0.9161 | test_loss: 1.2195 | test_acc: 0.6979
# Epoch: 123 | train_loss: 0.2494 | train_acc: 0.9084 | test_loss: 1.0861 | test_acc: 0.7039
# Epoch: 124 | train_loss: 0.2291 | train_acc: 0.9214 | test_loss: 1.1537 | test_acc: 0.7053
# Epoch: 125 | train_loss: 0.2417 | train_acc: 0.9097 | test_loss: 1.1175 | test_acc: 0.7079
# Epoch: 126 | train_loss: 0.2264 | train_acc: 0.9184 | test_loss: 1.2350 | test_acc: 0.6898
# Epoch: 127 | train_loss: 0.2293 | train_acc: 0.9172 | test_loss: 1.1427 | test_acc: 0.6940
# Epoch: 128 | train_loss: 0.2373 | train_acc: 0.9195 | test_loss: 1.1422 | test_acc: 0.7015
# Epoch: 129 | train_loss: 0.2515 | train_acc: 0.9089 | test_loss: 1.2011 | test_acc: 0.6814
# Epoch: 130 | train_loss: 0.2417 | train_acc: 0.9157 | test_loss: 1.3833 | test_acc: 0.6338
# Epoch: 131 | train_loss: 0.2338 | train_acc: 0.9210 | test_loss: 1.1516 | test_acc: 0.6982
# Epoch: 132 | train_loss: 0.2496 | train_acc: 0.9129 | test_loss: 1.1789 | test_acc: 0.7008
# Epoch: 133 | train_loss: 0.2395 | train_acc: 0.9189 | test_loss: 1.1834 | test_acc: 0.6822
# Epoch: 134 | train_loss: 0.2211 | train_acc: 0.9195 | test_loss: 1.2962 | test_acc: 0.6961
# Epoch: 135 | train_loss: 0.2399 | train_acc: 0.9121 | test_loss: 1.0751 | test_acc: 0.7107
# Epoch: 136 | train_loss: 0.2474 | train_acc: 0.9137 | test_loss: 1.0790 | test_acc: 0.7035
# Epoch: 137 | train_loss: 0.2146 | train_acc: 0.9240 | test_loss: 1.1739 | test_acc: 0.6961
# Epoch: 138 | train_loss: 0.2394 | train_acc: 0.9127 | test_loss: 1.1202 | test_acc: 0.7068
# Epoch: 139 | train_loss: 0.2422 | train_acc: 0.9167 | test_loss: 1.1280 | test_acc: 0.7127
# Epoch: 140 | train_loss: 0.1954 | train_acc: 0.9318 | test_loss: 1.0793 | test_acc: 0.7021
# Epoch: 141 | train_loss: 0.2233 | train_acc: 0.9184 | test_loss: 1.1522 | test_acc: 0.7005
# Epoch: 142 | train_loss: 0.2273 | train_acc: 0.9204 | test_loss: 1.0904 | test_acc: 0.7026
# Epoch: 143 | train_loss: 0.2119 | train_acc: 0.9234 | test_loss: 1.0914 | test_acc: 0.7056
# Epoch: 144 | train_loss: 0.2374 | train_acc: 0.9134 | test_loss: 1.1281 | test_acc: 0.6994
# Epoch: 145 | train_loss: 0.2142 | train_acc: 0.9249 | test_loss: 1.3950 | test_acc: 0.6493
# Epoch: 146 | train_loss: 0.2328 | train_acc: 0.9156 | test_loss: 1.1673 | test_acc: 0.6741
# Epoch: 147 | train_loss: 0.2282 | train_acc: 0.9195 | test_loss: 1.2267 | test_acc: 0.6902
# Epoch: 148 | train_loss: 0.2204 | train_acc: 0.9195 | test_loss: 1.0743 | test_acc: 0.6987
# Epoch: 149 | train_loss: 0.2055 | train_acc: 0.9318 | test_loss: 1.2066 | test_acc: 0.7120
# Epoch: 150 | train_loss: 0.2321 | train_acc: 0.9167 | test_loss: 1.1620 | test_acc: 0.6789
# Total training time: 3622.486 seconds

# %% [markdown]
# ## 6. Plotting the results
#
# We define a helper function named `plot_loss_curves()` to plot the results. We then use matplotlib to see how our model performed.

# %%
# Check the model_0_results keys
model_0_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
# defining the plot function
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]],
                     Save = False,
                     filename: str = "training_curves",):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup figure
    fig, axs = plt.subplots(1, 2, figsize=(15, 7))
    fig.patch.set_facecolor('white')

    # ===== Loss plot =====
    axs[0].set_facecolor('white')

    axs[0].plot(epochs, loss, label='train_loss', color="#4195C1")
    axs[0].plot(epochs, test_loss, label='test_loss', color="#FF7B22")

    axs[0].set_title('Loss', color='black')
    axs[0].set_xlabel('Epochs', color='black')

    axs[0].tick_params(axis='x', colors='black')
    axs[0].tick_params(axis='y', colors='black')

    for spine in axs[0].spines.values():
        spine.set_color('black')

    axs[0].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # ===== Accuracy plot =====
    axs[1].set_facecolor('white')

    axs[1].plot(epochs, accuracy, label='train_accuracy', color="#4195C1")
    axs[1].plot(epochs, test_accuracy, label='test_accuracy', color="#FF7B22")

    axs[1].set_title('Accuracy', color='black')
    axs[1].set_xlabel('Epochs', color='black')

    axs[1].tick_params(axis='x', colors='black')
    axs[1].tick_params(axis='y', colors='black')

    for spine in axs[1].spines.values():
        spine.set_color('black')

    axs[1].legend(frameon=True,
                  facecolor='white',
                  edgecolor='black',
                  labelcolor='black'
                  )

    # Layout
    plt.tight_layout()

    # Save figure
    if Save:
        plt.savefig(
            filename + ".png",
            dpi=144,
            bbox_inches='tight',
            facecolor=fig.get_facecolor()
        )

    plt.show()

# %%
plot_loss_curves(model_0_results, Save=True, filename="model_0_training")

# %% [markdown]
# We can notice that overfitting occurs at the very early stages of training. After the 30th epoch we also observe a slow but steady increase in the loss values.

# %% [markdown]
# ## 7. Using Data Augmentation
#
# For our next models we are going to use data augmentation. This is a very common method to avoid overfitting. The method works as following:
#
# During training, the model is exposed to the same data during each epoch. When implementing data augmentation, we alter the data on each epoch. In this way, the model is exposed to different data on each epoch, thus increasing the variety of data that it is exposed to. On each epoch a random alternation on the data is applied.

# %% [markdown]
# ### 7.1 Implementing `TimeMasking()` and `FrequencyMasking()` on the data
# The data augmentation we are going to use is `TimeMasking()` and `FrequencyMasking()`, both from the `torchaudio` library. Those methods will randomly mask up to a number of time frames and mel bands respectively. For more info - https://docs.pytorch.org/audio/main/tutorials/audio_feature_augmentation_tutorial.html#time-and-frequency-masking
#
#
# > The `TimeMasking()` transform, "masks" the entire x-axis for a specific amount. The `FrequencyMasking()` transform, "masks" the entire y-axis for a specific amount. We have resized the audio representation into a 72x72 matrix. An approximately 14% of the sample will be masked in each axis. This will be done by setting the `time_mask_param` and the `freq_mask_param` to 10.
#
# The masked spectrogram are presented, to have a visualization of the augmented data. Similar methods of masking on log mel spectrogram directly are mentioned in the SpecAugment paper. More info here - https://arxiv.org/pdf/1904.08779
#
# _**Notice**: The time_mask_param and freq_mask_param will set the **maximum** amount of time_frames/mel_bands that will be masked. This number will be random on each epoch._

# %%
# Calculating the proper time_mask_param and freq_mask_param values

# Shape is 72x72 so we cover 10 indices
time_mask_param = round(10)
freq_mask_param = round(10)

time_mask_param, freq_mask_param
# Out:
# (10, 10)

# %%
# Creating time masking transform and checking the shape of sample data
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
time_masking = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
time_masked_data = time_masking(X[INDEX].squeeze()).to('cpu')
time_masked_data.shape
# Out:
# torch.Size([72, 72])

# %%
# Creating frequency masking transform and checking the shape of sample data
# np.random.seed(RANDOM_SEED)
# torch.manual_seed(RANDOM_SEED)

INDEX = np.random.randint(len(X))
freq_masking = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
freq_masked_data = freq_masking(X[INDEX].squeeze()).to('cpu')
freq_masked_data.shape
# Out:
# torch.Size([72, 72])

# %%
# Visualize data
time_masked_melspec_example = time_masked_data.numpy()
freq_masked_melspec_example = freq_masked_data.numpy()

fig, axes = plt.subplots(2, 1, figsize=(6, 6), sharex=True, sharey=True)
im0 = axes[0].imshow(time_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[0].set_title("Frequency-masked Mel Spectrogram")
axes[0].set_ylabel("MFCCs")
fig.colorbar(im0, ax=axes[0])

im1 = axes[1].imshow(freq_masked_melspec_example.T, cmap='hot', aspect='auto', origin='lower')
axes[1].set_title("Time-masked Mel Spectrogram")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("MFCCs")
fig.colorbar(im1, ax=axes[1])

fig.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2 Creating training functions for data augmentation

# %%
# Creating the transform instance
from torchaudio import transforms as T

torch.manual_seed(RANDOM_SEED)

train_transforms = nn.Sequential(
    T.TimeMasking(time_mask_param=time_mask_param),
    T.FrequencyMasking(freq_mask_param=freq_mask_param)
)

# Create a train loop function
def train_step_with_augmentation(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               use_augmentation=True):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # Implement augmentation
        if use_augmentation:
            X = train_transforms(X)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metrics across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
# Creating the function for training with data that have been augmented
def train_with_augmentation(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          writer: torch.utils.tensorboard.writer.SummaryWriter = None # new parameter to take in a writer
     ):

    # Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step_with_augmentation(model=model,
                                                            dataloader=train_dataloader,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                             use_augmentation=True)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        # Ensure all data is moved to CPU and converted to float for storage
        results["train_loss"].append(train_loss.item() if isinstance(train_loss, torch.Tensor) else train_loss)
        results["train_acc"].append(train_acc.item() if isinstance(train_acc, torch.Tensor) else train_acc)
        results["test_loss"].append(test_loss.item() if isinstance(test_loss, torch.Tensor) else test_loss)
        results["test_acc"].append(test_acc.item() if isinstance(test_acc, torch.Tensor) else test_acc)

        ### New: Use the writer parameter to track experiments ###
        # See if there's a writer, if so, log to it
        if writer:
            # Add results to SummaryWriter
            writer.add_scalars(main_tag="Loss",
                               tag_scalar_dict={"train_loss": train_loss,
                                                "test_loss": test_loss},
                               global_step=epoch)
            writer.add_scalars(main_tag="Accuracy",
                               tag_scalar_dict={"train_acc": train_acc,
                                                "test_acc": test_acc},
                               global_step=epoch)

            # Close the writer
            writer.close()
        else:
            pass
        ### End new ###

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ### 7.3 Training the ViT model using data augmentation

# %%
# Create model and put it to device
torch.manual_seed(RANDOM_SEED)
model_1 = ViT().to(device)
model_1
# Out:
# C:\Users\thebo\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ViT(
#   (patch_embedding): PatchEmbedding(
#     (patcher): Conv2d(1, 768, kernel_size=(12, 12), stride=(12, 12))
#     (flatten): Flatten(start_dim=2, end_dim=3)
#   )
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=3072, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=3072, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(),
                             lr=0.001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 250

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_1
model_1_results = train_with_augmentation(model=model_1,
                                          train_dataloader=train_dataloader,
                                          test_dataloader=validation_dataloader,
                                          optimizer=optimizer,
                                          loss_fn=loss_fn,
                                          epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0113 | train_acc: 0.2937 | test_loss: 1.7963 | test_acc: 0.3400
# Epoch: 2 | train_loss: 1.8443 | train_acc: 0.3238 | test_loss: 1.8266 | test_acc: 0.3179
# Epoch: 3 | train_loss: 1.7801 | train_acc: 0.3582 | test_loss: 1.5955 | test_acc: 0.4074
# Epoch: 4 | train_loss: 1.7254 | train_acc: 0.3710 | test_loss: 1.6739 | test_acc: 0.3490
# Epoch: 5 | train_loss: 1.7294 | train_acc: 0.3657 | test_loss: 1.5916 | test_acc: 0.4231
# Epoch: 6 | train_loss: 1.7300 | train_acc: 0.3692 | test_loss: 1.6048 | test_acc: 0.3947
# Epoch: 7 | train_loss: 1.7001 | train_acc: 0.3743 | test_loss: 1.6703 | test_acc: 0.3738
# Epoch: 8 | train_loss: 1.7322 | train_acc: 0.3738 | test_loss: 1.5717 | test_acc: 0.4205
# Epoch: 9 | train_loss: 1.6569 | train_acc: 0.3981 | test_loss: 1.4944 | test_acc: 0.4416
# Epoch: 10 | train_loss: 1.6746 | train_acc: 0.3921 | test_loss: 1.5942 | test_acc: 0.4040
# Epoch: 11 | train_loss: 1.6481 | train_acc: 0.3964 | test_loss: 1.5192 | test_acc: 0.4239
# Epoch: 12 | train_loss: 1.6286 | train_acc: 0.4011 | test_loss: 1.5219 | test_acc: 0.4287
# Epoch: 13 | train_loss: 1.5589 | train_acc: 0.4313 | test_loss: 1.4412 | test_acc: 0.4584
# Epoch: 14 | train_loss: 1.5520 | train_acc: 0.4299 | test_loss: 1.4605 | test_acc: 0.4350
# Epoch: 15 | train_loss: 1.5569 | train_acc: 0.4352 | test_loss: 1.3894 | test_acc: 0.4806
# Epoch: 16 | train_loss: 1.5265 | train_acc: 0.4435 | test_loss: 1.4659 | test_acc: 0.4564
# Epoch: 17 | train_loss: 1.5087 | train_acc: 0.4438 | test_loss: 1.3471 | test_acc: 0.4912
# Epoch: 18 | train_loss: 1.4704 | train_acc: 0.4629 | test_loss: 1.4196 | test_acc: 0.4891
# Epoch: 19 | train_loss: 1.4418 | train_acc: 0.4787 | test_loss: 1.3793 | test_acc: 0.4902
# Epoch: 20 | train_loss: 1.4340 | train_acc: 0.4782 | test_loss: 1.3213 | test_acc: 0.5245
# Epoch: 21 | train_loss: 1.3907 | train_acc: 0.4934 | test_loss: 1.2771 | test_acc: 0.5336
# Epoch: 22 | train_loss: 1.3975 | train_acc: 0.4948 | test_loss: 1.2568 | test_acc: 0.5215
# Epoch: 23 | train_loss: 1.3401 | train_acc: 0.5052 | test_loss: 1.2202 | test_acc: 0.5460
# Epoch: 24 | train_loss: 1.3467 | train_acc: 0.5126 | test_loss: 1.2059 | test_acc: 0.5685
# Epoch: 25 | train_loss: 1.3356 | train_acc: 0.5176 | test_loss: 1.1650 | test_acc: 0.5786
# Epoch: 26 | train_loss: 1.3014 | train_acc: 0.5274 | test_loss: 1.2459 | test_acc: 0.5463
# Epoch: 27 | train_loss: 1.3045 | train_acc: 0.5276 | test_loss: 1.2455 | test_acc: 0.5386
# Epoch: 28 | train_loss: 1.2715 | train_acc: 0.5372 | test_loss: 1.2263 | test_acc: 0.5488
# Epoch: 29 | train_loss: 1.2705 | train_acc: 0.5342 | test_loss: 1.0880 | test_acc: 0.6202
# Epoch: 30 | train_loss: 1.2530 | train_acc: 0.5539 | test_loss: 1.3055 | test_acc: 0.5467
# Epoch: 31 | train_loss: 1.2796 | train_acc: 0.5442 | test_loss: 1.1821 | test_acc: 0.5561
# Epoch: 32 | train_loss: 1.2052 | train_acc: 0.5642 | test_loss: 1.0368 | test_acc: 0.6263
# Epoch: 33 | train_loss: 1.1767 | train_acc: 0.5748 | test_loss: 1.0962 | test_acc: 0.5971
# Epoch: 34 | train_loss: 1.1655 | train_acc: 0.5781 | test_loss: 1.0965 | test_acc: 0.6020
# Epoch: 35 | train_loss: 1.1448 | train_acc: 0.5824 | test_loss: 1.0445 | test_acc: 0.6177
# Epoch: 36 | train_loss: 1.1206 | train_acc: 0.5959 | test_loss: 1.0123 | test_acc: 0.6155
# Epoch: 37 | train_loss: 1.1018 | train_acc: 0.6021 | test_loss: 1.0926 | test_acc: 0.5862
# Epoch: 38 | train_loss: 1.0834 | train_acc: 0.6165 | test_loss: 0.9631 | test_acc: 0.6441
# Epoch: 39 | train_loss: 1.0774 | train_acc: 0.6134 | test_loss: 1.0506 | test_acc: 0.6050
# Epoch: 40 | train_loss: 1.0677 | train_acc: 0.6187 | test_loss: 1.0442 | test_acc: 0.6163
# Epoch: 41 | train_loss: 1.0207 | train_acc: 0.6360 | test_loss: 0.9966 | test_acc: 0.6449
# Epoch: 42 | train_loss: 1.0003 | train_acc: 0.6511 | test_loss: 0.9720 | test_acc: 0.6329
# Epoch: 43 | train_loss: 1.0197 | train_acc: 0.6318 | test_loss: 1.0088 | test_acc: 0.6423
# Epoch: 44 | train_loss: 0.9886 | train_acc: 0.6543 | test_loss: 0.9470 | test_acc: 0.6475
# Epoch: 45 | train_loss: 0.9573 | train_acc: 0.6601 | test_loss: 0.9833 | test_acc: 0.6363
# Epoch: 46 | train_loss: 0.9445 | train_acc: 0.6657 | test_loss: 0.8849 | test_acc: 0.6672
# Epoch: 47 | train_loss: 0.9153 | train_acc: 0.6734 | test_loss: 1.0012 | test_acc: 0.6216
# Epoch: 48 | train_loss: 0.9228 | train_acc: 0.6694 | test_loss: 0.9714 | test_acc: 0.6436
# Epoch: 49 | train_loss: 0.9081 | train_acc: 0.6765 | test_loss: 1.0604 | test_acc: 0.6203
# Epoch: 50 | train_loss: 0.9006 | train_acc: 0.6779 | test_loss: 0.8727 | test_acc: 0.6784
# Epoch: 51 | train_loss: 0.8748 | train_acc: 0.6946 | test_loss: 0.8863 | test_acc: 0.6757
# Epoch: 52 | train_loss: 0.8737 | train_acc: 0.6893 | test_loss: 0.8216 | test_acc: 0.7041
# Epoch: 53 | train_loss: 0.8439 | train_acc: 0.6970 | test_loss: 0.9026 | test_acc: 0.6650
# Epoch: 54 | train_loss: 0.8475 | train_acc: 0.7026 | test_loss: 0.8769 | test_acc: 0.6693
# Epoch: 55 | train_loss: 0.8101 | train_acc: 0.7129 | test_loss: 0.8451 | test_acc: 0.6811
# Epoch: 56 | train_loss: 0.8003 | train_acc: 0.7138 | test_loss: 0.9149 | test_acc: 0.6630
# Epoch: 57 | train_loss: 0.7984 | train_acc: 0.7207 | test_loss: 0.8478 | test_acc: 0.6957
# Epoch: 58 | train_loss: 0.8042 | train_acc: 0.7231 | test_loss: 0.8306 | test_acc: 0.6979
# Epoch: 59 | train_loss: 0.7749 | train_acc: 0.7281 | test_loss: 0.8645 | test_acc: 0.6681
# Epoch: 60 | train_loss: 0.7751 | train_acc: 0.7256 | test_loss: 0.8326 | test_acc: 0.6963
# Epoch: 61 | train_loss: 0.7400 | train_acc: 0.7394 | test_loss: 0.8028 | test_acc: 0.6948
# Epoch: 62 | train_loss: 0.7372 | train_acc: 0.7372 | test_loss: 0.8664 | test_acc: 0.6736
# Epoch: 63 | train_loss: 0.7232 | train_acc: 0.7447 | test_loss: 0.8569 | test_acc: 0.6932
# Epoch: 64 | train_loss: 0.7322 | train_acc: 0.7385 | test_loss: 0.8534 | test_acc: 0.7003
# Epoch: 65 | train_loss: 0.7308 | train_acc: 0.7389 | test_loss: 0.8946 | test_acc: 0.6698
# Epoch: 66 | train_loss: 0.7026 | train_acc: 0.7443 | test_loss: 0.7734 | test_acc: 0.7176
# Epoch: 67 | train_loss: 0.6929 | train_acc: 0.7513 | test_loss: 0.8267 | test_acc: 0.6950
# Epoch: 68 | train_loss: 0.6855 | train_acc: 0.7547 | test_loss: 0.8310 | test_acc: 0.7042
# Epoch: 69 | train_loss: 0.6769 | train_acc: 0.7616 | test_loss: 0.7690 | test_acc: 0.7372
# Epoch: 70 | train_loss: 0.6459 | train_acc: 0.7749 | test_loss: 0.7975 | test_acc: 0.7270
# Epoch: 71 | train_loss: 0.6318 | train_acc: 0.7754 | test_loss: 0.7762 | test_acc: 0.7288
# Epoch: 72 | train_loss: 0.6425 | train_acc: 0.7771 | test_loss: 0.7517 | test_acc: 0.7364
# Epoch: 73 | train_loss: 0.6496 | train_acc: 0.7708 | test_loss: 0.7823 | test_acc: 0.7155
# Epoch: 74 | train_loss: 0.6360 | train_acc: 0.7743 | test_loss: 0.7326 | test_acc: 0.7361
# Epoch: 75 | train_loss: 0.5903 | train_acc: 0.7911 | test_loss: 0.7461 | test_acc: 0.7370
# Epoch: 76 | train_loss: 0.6252 | train_acc: 0.7812 | test_loss: 0.8204 | test_acc: 0.7126
# Epoch: 77 | train_loss: 0.5851 | train_acc: 0.7891 | test_loss: 0.7433 | test_acc: 0.7398
# Epoch: 78 | train_loss: 0.5932 | train_acc: 0.7871 | test_loss: 0.8297 | test_acc: 0.7172
# Epoch: 79 | train_loss: 0.5733 | train_acc: 0.7964 | test_loss: 0.7732 | test_acc: 0.7377
# Epoch: 80 | train_loss: 0.5437 | train_acc: 0.8103 | test_loss: 0.7904 | test_acc: 0.7360
# Epoch: 81 | train_loss: 0.5601 | train_acc: 0.8004 | test_loss: 0.7483 | test_acc: 0.7409
# Epoch: 82 | train_loss: 0.5487 | train_acc: 0.8042 | test_loss: 0.7457 | test_acc: 0.7509
# Epoch: 83 | train_loss: 0.5491 | train_acc: 0.8113 | test_loss: 0.7755 | test_acc: 0.7357
# Epoch: 84 | train_loss: 0.5204 | train_acc: 0.8152 | test_loss: 0.8738 | test_acc: 0.7062
# Epoch: 85 | train_loss: 0.5238 | train_acc: 0.8168 | test_loss: 0.7448 | test_acc: 0.7524
# Epoch: 86 | train_loss: 0.5168 | train_acc: 0.8145 | test_loss: 0.7978 | test_acc: 0.7363
# Epoch: 87 | train_loss: 0.5023 | train_acc: 0.8165 | test_loss: 0.7411 | test_acc: 0.7451
# Epoch: 88 | train_loss: 0.5132 | train_acc: 0.8140 | test_loss: 0.8597 | test_acc: 0.7213
# Epoch: 89 | train_loss: 0.4721 | train_acc: 0.8413 | test_loss: 0.7667 | test_acc: 0.7350
# Epoch: 90 | train_loss: 0.4739 | train_acc: 0.8283 | test_loss: 0.7527 | test_acc: 0.7471
# Epoch: 91 | train_loss: 0.4532 | train_acc: 0.8408 | test_loss: 0.7341 | test_acc: 0.7564
# Epoch: 92 | train_loss: 0.4855 | train_acc: 0.8270 | test_loss: 0.7525 | test_acc: 0.7521
# Epoch: 93 | train_loss: 0.4620 | train_acc: 0.8384 | test_loss: 0.6746 | test_acc: 0.7744
# Epoch: 94 | train_loss: 0.4476 | train_acc: 0.8411 | test_loss: 0.7422 | test_acc: 0.7568
# Epoch: 95 | train_loss: 0.4771 | train_acc: 0.8328 | test_loss: 0.8153 | test_acc: 0.7176
# Epoch: 96 | train_loss: 0.4666 | train_acc: 0.8301 | test_loss: 0.7966 | test_acc: 0.7355
# Epoch: 97 | train_loss: 0.4639 | train_acc: 0.8346 | test_loss: 0.7373 | test_acc: 0.7556
# Epoch: 98 | train_loss: 0.4307 | train_acc: 0.8474 | test_loss: 0.7513 | test_acc: 0.7595
# Epoch: 99 | train_loss: 0.4363 | train_acc: 0.8418 | test_loss: 0.8720 | test_acc: 0.7200
# Epoch: 100 | train_loss: 0.4135 | train_acc: 0.8575 | test_loss: 0.7619 | test_acc: 0.7323
# Epoch: 101 | train_loss: 0.4052 | train_acc: 0.8594 | test_loss: 0.8233 | test_acc: 0.7330
# Epoch: 102 | train_loss: 0.4135 | train_acc: 0.8539 | test_loss: 0.7479 | test_acc: 0.7530
# Epoch: 103 | train_loss: 0.4239 | train_acc: 0.8527 | test_loss: 0.7419 | test_acc: 0.7668
# Epoch: 104 | train_loss: 0.3903 | train_acc: 0.8664 | test_loss: 0.8238 | test_acc: 0.7362
# Epoch: 105 | train_loss: 0.3828 | train_acc: 0.8669 | test_loss: 0.7775 | test_acc: 0.7548
# Epoch: 106 | train_loss: 0.4230 | train_acc: 0.8524 | test_loss: 0.6943 | test_acc: 0.7749
# Epoch: 107 | train_loss: 0.3983 | train_acc: 0.8599 | test_loss: 0.7446 | test_acc: 0.7543
# Epoch: 108 | train_loss: 0.3827 | train_acc: 0.8649 | test_loss: 0.7547 | test_acc: 0.7583
# Epoch: 109 | train_loss: 0.3853 | train_acc: 0.8659 | test_loss: 0.7506 | test_acc: 0.7588
# Epoch: 110 | train_loss: 0.3900 | train_acc: 0.8642 | test_loss: 0.7108 | test_acc: 0.7698
# Epoch: 111 | train_loss: 0.3816 | train_acc: 0.8710 | test_loss: 0.7122 | test_acc: 0.7657
# Epoch: 112 | train_loss: 0.3483 | train_acc: 0.8805 | test_loss: 0.8166 | test_acc: 0.7455
# Epoch: 113 | train_loss: 0.4024 | train_acc: 0.8619 | test_loss: 0.7704 | test_acc: 0.7588
# Epoch: 114 | train_loss: 0.3496 | train_acc: 0.8772 | test_loss: 0.7639 | test_acc: 0.7662
# Epoch: 115 | train_loss: 0.3601 | train_acc: 0.8707 | test_loss: 0.8626 | test_acc: 0.7429
# Epoch: 116 | train_loss: 0.3566 | train_acc: 0.8735 | test_loss: 0.8148 | test_acc: 0.7502
# Epoch: 117 | train_loss: 0.3532 | train_acc: 0.8770 | test_loss: 0.7676 | test_acc: 0.7678
# Epoch: 118 | train_loss: 0.3606 | train_acc: 0.8718 | test_loss: 0.8040 | test_acc: 0.7541
# Epoch: 119 | train_loss: 0.3567 | train_acc: 0.8752 | test_loss: 0.7693 | test_acc: 0.7602
# Epoch: 120 | train_loss: 0.3336 | train_acc: 0.8866 | test_loss: 0.7861 | test_acc: 0.7669
# Epoch: 121 | train_loss: 0.3221 | train_acc: 0.8886 | test_loss: 0.8424 | test_acc: 0.7440
# Epoch: 122 | train_loss: 0.3190 | train_acc: 0.8911 | test_loss: 0.8222 | test_acc: 0.7575
# Epoch: 123 | train_loss: 0.3226 | train_acc: 0.8883 | test_loss: 0.7671 | test_acc: 0.7557
# Epoch: 124 | train_loss: 0.3060 | train_acc: 0.8928 | test_loss: 0.7396 | test_acc: 0.7784
# Epoch: 125 | train_loss: 0.3220 | train_acc: 0.8923 | test_loss: 0.9451 | test_acc: 0.7375
# Epoch: 126 | train_loss: 0.3084 | train_acc: 0.8930 | test_loss: 0.8502 | test_acc: 0.7411
# Epoch: 127 | train_loss: 0.3355 | train_acc: 0.8875 | test_loss: 0.6929 | test_acc: 0.7830
# Epoch: 128 | train_loss: 0.2867 | train_acc: 0.9003 | test_loss: 0.8190 | test_acc: 0.7549
# Epoch: 129 | train_loss: 0.3149 | train_acc: 0.8895 | test_loss: 0.7681 | test_acc: 0.7699
# Epoch: 130 | train_loss: 0.3201 | train_acc: 0.8885 | test_loss: 0.7701 | test_acc: 0.7722
# Epoch: 131 | train_loss: 0.3172 | train_acc: 0.8901 | test_loss: 0.7735 | test_acc: 0.7615
# Epoch: 132 | train_loss: 0.3064 | train_acc: 0.8913 | test_loss: 0.7929 | test_acc: 0.7576
# Epoch: 133 | train_loss: 0.3216 | train_acc: 0.8856 | test_loss: 0.7523 | test_acc: 0.7715
# Epoch: 134 | train_loss: 0.3142 | train_acc: 0.8918 | test_loss: 0.7922 | test_acc: 0.7630
# Epoch: 135 | train_loss: 0.2893 | train_acc: 0.8999 | test_loss: 0.8743 | test_acc: 0.7358
# Epoch: 136 | train_loss: 0.3216 | train_acc: 0.8876 | test_loss: 0.7397 | test_acc: 0.7722
# Epoch: 137 | train_loss: 0.2518 | train_acc: 0.9132 | test_loss: 0.8287 | test_acc: 0.7524
# Epoch: 138 | train_loss: 0.2962 | train_acc: 0.8953 | test_loss: 0.8933 | test_acc: 0.7476
# Epoch: 139 | train_loss: 0.2719 | train_acc: 0.9038 | test_loss: 0.8849 | test_acc: 0.7243
# Epoch: 140 | train_loss: 0.3191 | train_acc: 0.8871 | test_loss: 0.7740 | test_acc: 0.7629
# Epoch: 141 | train_loss: 0.3021 | train_acc: 0.8880 | test_loss: 0.7665 | test_acc: 0.7696
# Epoch: 142 | train_loss: 0.3176 | train_acc: 0.8855 | test_loss: 0.8091 | test_acc: 0.7502
# Epoch: 143 | train_loss: 0.2679 | train_acc: 0.9058 | test_loss: 0.7731 | test_acc: 0.7604
# Epoch: 144 | train_loss: 0.3011 | train_acc: 0.8949 | test_loss: 0.8109 | test_acc: 0.7470
# Epoch: 145 | train_loss: 0.3032 | train_acc: 0.8996 | test_loss: 0.8809 | test_acc: 0.7491
# Epoch: 146 | train_loss: 0.2795 | train_acc: 0.9048 | test_loss: 0.7964 | test_acc: 0.7691
# Epoch: 147 | train_loss: 0.2573 | train_acc: 0.9101 | test_loss: 0.7822 | test_acc: 0.7716
# Epoch: 148 | train_loss: 0.2911 | train_acc: 0.9033 | test_loss: 0.7734 | test_acc: 0.7776
# Epoch: 149 | train_loss: 0.3083 | train_acc: 0.8983 | test_loss: 0.7007 | test_acc: 0.7822
# Epoch: 150 | train_loss: 0.2750 | train_acc: 0.9014 | test_loss: 0.7200 | test_acc: 0.7824
# Epoch: 151 | train_loss: 0.2872 | train_acc: 0.8979 | test_loss: 0.7880 | test_acc: 0.7549
# Epoch: 152 | train_loss: 0.2723 | train_acc: 0.9094 | test_loss: 0.7594 | test_acc: 0.7744
# Epoch: 153 | train_loss: 0.2648 | train_acc: 0.9109 | test_loss: 0.7743 | test_acc: 0.7703
# Epoch: 154 | train_loss: 0.2907 | train_acc: 0.8988 | test_loss: 0.6881 | test_acc: 0.7949
# Epoch: 155 | train_loss: 0.2979 | train_acc: 0.8944 | test_loss: 0.8206 | test_acc: 0.7704
# Epoch: 156 | train_loss: 0.2849 | train_acc: 0.9008 | test_loss: 0.7217 | test_acc: 0.7843
# Epoch: 157 | train_loss: 0.2494 | train_acc: 0.9149 | test_loss: 0.7998 | test_acc: 0.7722
# Epoch: 158 | train_loss: 0.2858 | train_acc: 0.9019 | test_loss: 0.7503 | test_acc: 0.7708
# Epoch: 159 | train_loss: 0.2730 | train_acc: 0.9034 | test_loss: 0.7384 | test_acc: 0.7810
# Epoch: 160 | train_loss: 0.2481 | train_acc: 0.9161 | test_loss: 0.8030 | test_acc: 0.7789
# Epoch: 161 | train_loss: 0.2280 | train_acc: 0.9255 | test_loss: 0.7596 | test_acc: 0.7750
# Epoch: 162 | train_loss: 0.2587 | train_acc: 0.9087 | test_loss: 0.8176 | test_acc: 0.7695
# Epoch: 163 | train_loss: 0.2410 | train_acc: 0.9184 | test_loss: 0.7571 | test_acc: 0.7708
# Epoch: 164 | train_loss: 0.2742 | train_acc: 0.9061 | test_loss: 0.8171 | test_acc: 0.7525
# Epoch: 165 | train_loss: 0.2633 | train_acc: 0.9097 | test_loss: 0.8657 | test_acc: 0.7562
# Epoch: 166 | train_loss: 0.2454 | train_acc: 0.9144 | test_loss: 0.8405 | test_acc: 0.7537
# Epoch: 167 | train_loss: 0.2865 | train_acc: 0.9058 | test_loss: 0.8436 | test_acc: 0.7509
# Epoch: 168 | train_loss: 0.2745 | train_acc: 0.9041 | test_loss: 0.7439 | test_acc: 0.7854
# Epoch: 169 | train_loss: 0.2643 | train_acc: 0.9081 | test_loss: 0.8089 | test_acc: 0.7697
# Epoch: 170 | train_loss: 0.2525 | train_acc: 0.9124 | test_loss: 0.8656 | test_acc: 0.7741
# Epoch: 171 | train_loss: 0.2369 | train_acc: 0.9164 | test_loss: 0.8277 | test_acc: 0.7537
# Epoch: 172 | train_loss: 0.2414 | train_acc: 0.9151 | test_loss: 0.8144 | test_acc: 0.7716
# Epoch: 173 | train_loss: 0.2144 | train_acc: 0.9270 | test_loss: 0.7682 | test_acc: 0.7810
# Epoch: 174 | train_loss: 0.2265 | train_acc: 0.9234 | test_loss: 0.7792 | test_acc: 0.7689
# Epoch: 175 | train_loss: 0.2278 | train_acc: 0.9192 | test_loss: 0.7421 | test_acc: 0.7903
# Epoch: 176 | train_loss: 0.2406 | train_acc: 0.9161 | test_loss: 0.7823 | test_acc: 0.7802
# Epoch: 177 | train_loss: 0.2650 | train_acc: 0.9082 | test_loss: 0.9155 | test_acc: 0.7422
# Epoch: 178 | train_loss: 0.2444 | train_acc: 0.9131 | test_loss: 0.7631 | test_acc: 0.7809
# Epoch: 179 | train_loss: 0.2463 | train_acc: 0.9144 | test_loss: 0.8582 | test_acc: 0.7674
# Epoch: 180 | train_loss: 0.2266 | train_acc: 0.9186 | test_loss: 0.7921 | test_acc: 0.7795
# Epoch: 181 | train_loss: 0.2061 | train_acc: 0.9317 | test_loss: 0.7937 | test_acc: 0.7957
# Epoch: 182 | train_loss: 0.2744 | train_acc: 0.9038 | test_loss: 0.8216 | test_acc: 0.7676
# Epoch: 183 | train_loss: 0.2635 | train_acc: 0.9076 | test_loss: 0.7407 | test_acc: 0.7789
# Epoch: 184 | train_loss: 0.2430 | train_acc: 0.9172 | test_loss: 0.7692 | test_acc: 0.7850
# Epoch: 185 | train_loss: 0.2446 | train_acc: 0.9139 | test_loss: 0.7708 | test_acc: 0.7830
# Epoch: 186 | train_loss: 0.2404 | train_acc: 0.9129 | test_loss: 0.8598 | test_acc: 0.7630
# Epoch: 187 | train_loss: 0.2490 | train_acc: 0.9129 | test_loss: 0.8259 | test_acc: 0.7661
# Epoch: 188 | train_loss: 0.2345 | train_acc: 0.9181 | test_loss: 0.7812 | test_acc: 0.7860
# Epoch: 189 | train_loss: 0.2485 | train_acc: 0.9161 | test_loss: 0.7774 | test_acc: 0.7827
# Epoch: 190 | train_loss: 0.2221 | train_acc: 0.9234 | test_loss: 0.7897 | test_acc: 0.7708
# Epoch: 191 | train_loss: 0.2501 | train_acc: 0.9171 | test_loss: 0.7523 | test_acc: 0.7881
# Epoch: 192 | train_loss: 0.2380 | train_acc: 0.9172 | test_loss: 0.8698 | test_acc: 0.7504
# Epoch: 193 | train_loss: 0.2192 | train_acc: 0.9227 | test_loss: 0.8688 | test_acc: 0.7629
# Epoch: 194 | train_loss: 0.2469 | train_acc: 0.9157 | test_loss: 0.8155 | test_acc: 0.7789
# Epoch: 195 | train_loss: 0.1980 | train_acc: 0.9330 | test_loss: 0.8207 | test_acc: 0.7666
# Epoch: 196 | train_loss: 0.2480 | train_acc: 0.9152 | test_loss: 0.8717 | test_acc: 0.7573
# Epoch: 197 | train_loss: 0.2044 | train_acc: 0.9320 | test_loss: 0.8416 | test_acc: 0.7648
# Epoch: 198 | train_loss: 0.2372 | train_acc: 0.9186 | test_loss: 0.8469 | test_acc: 0.7554
# Epoch: 199 | train_loss: 0.2303 | train_acc: 0.9219 | test_loss: 0.7974 | test_acc: 0.7688
# Epoch: 200 | train_loss: 0.2179 | train_acc: 0.9220 | test_loss: 0.7282 | test_acc: 0.8017
# Epoch: 201 | train_loss: 0.2165 | train_acc: 0.9250 | test_loss: 0.8379 | test_acc: 0.7849
# Epoch: 202 | train_loss: 0.2415 | train_acc: 0.9156 | test_loss: 0.8135 | test_acc: 0.7802
# Epoch: 203 | train_loss: 0.2259 | train_acc: 0.9217 | test_loss: 0.9162 | test_acc: 0.7702
# Epoch: 204 | train_loss: 0.2212 | train_acc: 0.9227 | test_loss: 0.7623 | test_acc: 0.7776
# Epoch: 205 | train_loss: 0.2197 | train_acc: 0.9245 | test_loss: 0.8039 | test_acc: 0.7854
# Epoch: 206 | train_loss: 0.2380 | train_acc: 0.9177 | test_loss: 0.7575 | test_acc: 0.7877
# Epoch: 207 | train_loss: 0.1946 | train_acc: 0.9357 | test_loss: 0.8201 | test_acc: 0.7643
# Epoch: 208 | train_loss: 0.1920 | train_acc: 0.9350 | test_loss: 0.9316 | test_acc: 0.7463
# Epoch: 209 | train_loss: 0.2351 | train_acc: 0.9204 | test_loss: 0.7650 | test_acc: 0.7743
# Epoch: 210 | train_loss: 0.1844 | train_acc: 0.9377 | test_loss: 0.9291 | test_acc: 0.7429
# Epoch: 211 | train_loss: 0.2324 | train_acc: 0.9222 | test_loss: 0.8551 | test_acc: 0.7615
# Epoch: 212 | train_loss: 0.2213 | train_acc: 0.9267 | test_loss: 0.8194 | test_acc: 0.7596
# Epoch: 213 | train_loss: 0.2369 | train_acc: 0.9220 | test_loss: 0.7670 | test_acc: 0.7855
# Epoch: 214 | train_loss: 0.2393 | train_acc: 0.9192 | test_loss: 0.8343 | test_acc: 0.7730
# Epoch: 215 | train_loss: 0.2309 | train_acc: 0.9224 | test_loss: 0.7609 | test_acc: 0.7848
# Epoch: 216 | train_loss: 0.2167 | train_acc: 0.9239 | test_loss: 0.8214 | test_acc: 0.7735
# Epoch: 217 | train_loss: 0.2203 | train_acc: 0.9257 | test_loss: 0.9186 | test_acc: 0.7585
# Epoch: 218 | train_loss: 0.1947 | train_acc: 0.9332 | test_loss: 0.7994 | test_acc: 0.7822
# Epoch: 219 | train_loss: 0.2231 | train_acc: 0.9270 | test_loss: 0.7699 | test_acc: 0.7788
# Epoch: 220 | train_loss: 0.2211 | train_acc: 0.9250 | test_loss: 0.7681 | test_acc: 0.7882
# Epoch: 221 | train_loss: 0.1863 | train_acc: 0.9367 | test_loss: 0.8606 | test_acc: 0.7667
# Epoch: 222 | train_loss: 0.2088 | train_acc: 0.9240 | test_loss: 0.7756 | test_acc: 0.7829
# Epoch: 223 | train_loss: 0.2091 | train_acc: 0.9279 | test_loss: 0.8501 | test_acc: 0.7782
# Epoch: 224 | train_loss: 0.2001 | train_acc: 0.9309 | test_loss: 0.7491 | test_acc: 0.7820
# Epoch: 225 | train_loss: 0.2264 | train_acc: 0.9202 | test_loss: 0.7847 | test_acc: 0.7750
# Epoch: 226 | train_loss: 0.2200 | train_acc: 0.9257 | test_loss: 0.8135 | test_acc: 0.7663
# Epoch: 227 | train_loss: 0.2158 | train_acc: 0.9267 | test_loss: 0.9070 | test_acc: 0.7597
# Epoch: 228 | train_loss: 0.2306 | train_acc: 0.9220 | test_loss: 0.8015 | test_acc: 0.7770
# Epoch: 229 | train_loss: 0.2198 | train_acc: 0.9255 | test_loss: 0.7830 | test_acc: 0.7820
# Epoch: 230 | train_loss: 0.2007 | train_acc: 0.9312 | test_loss: 0.7995 | test_acc: 0.7910
# Epoch: 231 | train_loss: 0.2041 | train_acc: 0.9292 | test_loss: 0.7577 | test_acc: 0.7837
# Epoch: 232 | train_loss: 0.2072 | train_acc: 0.9325 | test_loss: 0.8153 | test_acc: 0.7850
# Epoch: 233 | train_loss: 0.1994 | train_acc: 0.9252 | test_loss: 0.8117 | test_acc: 0.7824
# Epoch: 234 | train_loss: 0.2144 | train_acc: 0.9267 | test_loss: 0.8775 | test_acc: 0.7721
# Epoch: 235 | train_loss: 0.2200 | train_acc: 0.9260 | test_loss: 0.7833 | test_acc: 0.7757
# Epoch: 236 | train_loss: 0.2142 | train_acc: 0.9274 | test_loss: 0.7809 | test_acc: 0.7769
# Epoch: 237 | train_loss: 0.2199 | train_acc: 0.9245 | test_loss: 0.7710 | test_acc: 0.7863
# Epoch: 238 | train_loss: 0.2101 | train_acc: 0.9304 | test_loss: 0.8090 | test_acc: 0.7776
# Epoch: 239 | train_loss: 0.1923 | train_acc: 0.9332 | test_loss: 0.8233 | test_acc: 0.7764
# Epoch: 240 | train_loss: 0.2169 | train_acc: 0.9277 | test_loss: 0.7908 | test_acc: 0.7696
# Epoch: 241 | train_loss: 0.2030 | train_acc: 0.9292 | test_loss: 0.7909 | test_acc: 0.7850
# Epoch: 242 | train_loss: 0.1977 | train_acc: 0.9300 | test_loss: 0.7740 | test_acc: 0.7884
# Epoch: 243 | train_loss: 0.2037 | train_acc: 0.9309 | test_loss: 0.8059 | test_acc: 0.7788
# Epoch: 244 | train_loss: 0.2180 | train_acc: 0.9294 | test_loss: 0.8378 | test_acc: 0.7658
# Epoch: 245 | train_loss: 0.2043 | train_acc: 0.9343 | test_loss: 0.7961 | test_acc: 0.7850
# Epoch: 246 | train_loss: 0.1952 | train_acc: 0.9335 | test_loss: 0.8386 | test_acc: 0.7783
# Epoch: 247 | train_loss: 0.2348 | train_acc: 0.9157 | test_loss: 0.7448 | test_acc: 0.7850
# Epoch: 248 | train_loss: 0.1872 | train_acc: 0.9340 | test_loss: 0.7680 | test_acc: 0.7936
# Epoch: 249 | train_loss: 0.1937 | train_acc: 0.9352 | test_loss: 0.8893 | test_acc: 0.7564
# Epoch: 250 | train_loss: 0.1808 | train_acc: 0.9393 | test_loss: 0.8351 | test_acc: 0.7768
# Total training time: 6037.158 seconds

# %%
plot_loss_curves(model_1_results, Save=True, filename="model_1_training")

# %% [markdown]
# We see that data augmentation has allowed our model to train for more epochs. This, allows the model to reach higher values of accuracy, thus resulting in abetter performing model

# %% [markdown]
# ## 8. Using early stopping to create the best model
#
# Using data augmentation was beneficial for the training procedure. However, after some point, overfitting occurs. We will use early stopping in order to have the best possible version of our ViT model. Careful observation of previous training results lead us to the conclusion to train the next model for 110 epochs. **This very method of early stopping is actually a method to fix overfitting**.
#
# For that reason, we are going to train a new model, using data augmentation and only train it for 110 epochs.

# %%
# Instantiating a new Transformer model and putting it to device
torch.manual_seed(RANDOM_SEED)

model_2 = ViT().to(device)
model_2
# Out:
# ViT(
#   (patch_embedding): PatchEmbedding(
#     (patcher): Conv2d(1, 768, kernel_size=(12, 12), stride=(12, 12))
#     (flatten): Flatten(start_dim=2, end_dim=3)
#   )
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=3072, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=3072, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=10, bias=True)
#   )
# )

# %%
# Create loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(),
                             lr=0.001,
                             weight_decay=0.0001)

# %%
# Training the model using the train_with_augmentation function
# Set number of epochs
NUM_EPOCHS = 110

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_2
model_2_results = train_with_augmentation(model=model_2,
                                          train_dataloader=train_dataloader,
                                          test_dataloader=validation_dataloader,
                                          optimizer=optimizer,
                                          loss_fn=loss_fn,
                                          epochs=NUM_EPOCHS,
                                          writer=create_writer(source="melspec",
                                                               segments=10,
                                                               model_name="ViT",
                                                               extra="AST_options"
                                                               )
                                          )

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
# [INFO] Created SummaryWriter, saving to: C:\Users\thebo\Desktop\pytorch-genre-classifiers\runs\11-02-2026\melspec\10_segments\ViT\AST_options...
#   0%|          | 0/110 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0113 | train_acc: 0.2937 | test_loss: 1.7963 | test_acc: 0.3400
# Epoch: 2 | train_loss: 1.8443 | train_acc: 0.3238 | test_loss: 1.8266 | test_acc: 0.3179
# Epoch: 3 | train_loss: 1.7801 | train_acc: 0.3582 | test_loss: 1.5955 | test_acc: 0.4074
# Epoch: 4 | train_loss: 1.7254 | train_acc: 0.3710 | test_loss: 1.6739 | test_acc: 0.3490
# Epoch: 5 | train_loss: 1.7294 | train_acc: 0.3657 | test_loss: 1.5916 | test_acc: 0.4231
# Epoch: 6 | train_loss: 1.7300 | train_acc: 0.3692 | test_loss: 1.6048 | test_acc: 0.3947
# Epoch: 7 | train_loss: 1.7001 | train_acc: 0.3743 | test_loss: 1.6703 | test_acc: 0.3738
# Epoch: 8 | train_loss: 1.7322 | train_acc: 0.3738 | test_loss: 1.5717 | test_acc: 0.4205
# Epoch: 9 | train_loss: 1.6569 | train_acc: 0.3981 | test_loss: 1.4944 | test_acc: 0.4416
# Epoch: 10 | train_loss: 1.6746 | train_acc: 0.3921 | test_loss: 1.5942 | test_acc: 0.4040
# Epoch: 11 | train_loss: 1.6481 | train_acc: 0.3964 | test_loss: 1.5192 | test_acc: 0.4239
# Epoch: 12 | train_loss: 1.6286 | train_acc: 0.4011 | test_loss: 1.5219 | test_acc: 0.4287
# Epoch: 13 | train_loss: 1.5589 | train_acc: 0.4313 | test_loss: 1.4412 | test_acc: 0.4584
# Epoch: 14 | train_loss: 1.5520 | train_acc: 0.4299 | test_loss: 1.4605 | test_acc: 0.4350
# Epoch: 15 | train_loss: 1.5569 | train_acc: 0.4352 | test_loss: 1.3894 | test_acc: 0.4806
# Epoch: 16 | train_loss: 1.5265 | train_acc: 0.4435 | test_loss: 1.4659 | test_acc: 0.4564
# Epoch: 17 | train_loss: 1.5087 | train_acc: 0.4438 | test_loss: 1.3471 | test_acc: 0.4912
# Epoch: 18 | train_loss: 1.4704 | train_acc: 0.4629 | test_loss: 1.4196 | test_acc: 0.4891
# Epoch: 19 | train_loss: 1.4418 | train_acc: 0.4787 | test_loss: 1.3793 | test_acc: 0.4902
# Epoch: 20 | train_loss: 1.4340 | train_acc: 0.4782 | test_loss: 1.3213 | test_acc: 0.5245
# Epoch: 21 | train_loss: 1.3907 | train_acc: 0.4934 | test_loss: 1.2771 | test_acc: 0.5336
# Epoch: 22 | train_loss: 1.3975 | train_acc: 0.4948 | test_loss: 1.2568 | test_acc: 0.5215
# Epoch: 23 | train_loss: 1.3401 | train_acc: 0.5052 | test_loss: 1.2202 | test_acc: 0.5460
# Epoch: 24 | train_loss: 1.3467 | train_acc: 0.5126 | test_loss: 1.2059 | test_acc: 0.5685
# Epoch: 25 | train_loss: 1.3356 | train_acc: 0.5176 | test_loss: 1.1650 | test_acc: 0.5786
# Epoch: 26 | train_loss: 1.3014 | train_acc: 0.5274 | test_loss: 1.2459 | test_acc: 0.5463
# Epoch: 27 | train_loss: 1.3045 | train_acc: 0.5276 | test_loss: 1.2455 | test_acc: 0.5386
# Epoch: 28 | train_loss: 1.2715 | train_acc: 0.5372 | test_loss: 1.2263 | test_acc: 0.5488
# Epoch: 29 | train_loss: 1.2705 | train_acc: 0.5342 | test_loss: 1.0880 | test_acc: 0.6202
# Epoch: 30 | train_loss: 1.2530 | train_acc: 0.5539 | test_loss: 1.3055 | test_acc: 0.5467
# Epoch: 31 | train_loss: 1.2796 | train_acc: 0.5442 | test_loss: 1.1821 | test_acc: 0.5561
# Epoch: 32 | train_loss: 1.2052 | train_acc: 0.5642 | test_loss: 1.0368 | test_acc: 0.6263
# Epoch: 33 | train_loss: 1.1767 | train_acc: 0.5748 | test_loss: 1.0962 | test_acc: 0.5971
# Epoch: 34 | train_loss: 1.1655 | train_acc: 0.5781 | test_loss: 1.0965 | test_acc: 0.6020
# Epoch: 35 | train_loss: 1.1448 | train_acc: 0.5824 | test_loss: 1.0445 | test_acc: 0.6177
# Epoch: 36 | train_loss: 1.1206 | train_acc: 0.5959 | test_loss: 1.0123 | test_acc: 0.6155
# Epoch: 37 | train_loss: 1.1018 | train_acc: 0.6021 | test_loss: 1.0926 | test_acc: 0.5862
# Epoch: 38 | train_loss: 1.0834 | train_acc: 0.6165 | test_loss: 0.9631 | test_acc: 0.6441
# Epoch: 39 | train_loss: 1.0774 | train_acc: 0.6134 | test_loss: 1.0506 | test_acc: 0.6050
# Epoch: 40 | train_loss: 1.0677 | train_acc: 0.6187 | test_loss: 1.0442 | test_acc: 0.6163
# Epoch: 41 | train_loss: 1.0207 | train_acc: 0.6360 | test_loss: 0.9966 | test_acc: 0.6449
# Epoch: 42 | train_loss: 1.0003 | train_acc: 0.6511 | test_loss: 0.9720 | test_acc: 0.6329
# Epoch: 43 | train_loss: 1.0197 | train_acc: 0.6318 | test_loss: 1.0088 | test_acc: 0.6423
# Epoch: 44 | train_loss: 0.9886 | train_acc: 0.6543 | test_loss: 0.9470 | test_acc: 0.6475
# Epoch: 45 | train_loss: 0.9573 | train_acc: 0.6601 | test_loss: 0.9833 | test_acc: 0.6363
# Epoch: 46 | train_loss: 0.9445 | train_acc: 0.6657 | test_loss: 0.8849 | test_acc: 0.6672
# Epoch: 47 | train_loss: 0.9153 | train_acc: 0.6734 | test_loss: 1.0012 | test_acc: 0.6216
# Epoch: 48 | train_loss: 0.9228 | train_acc: 0.6694 | test_loss: 0.9714 | test_acc: 0.6436
# Epoch: 49 | train_loss: 0.9081 | train_acc: 0.6765 | test_loss: 1.0604 | test_acc: 0.6203
# Epoch: 50 | train_loss: 0.9006 | train_acc: 0.6779 | test_loss: 0.8727 | test_acc: 0.6784
# Epoch: 51 | train_loss: 0.8748 | train_acc: 0.6946 | test_loss: 0.8863 | test_acc: 0.6757
# Epoch: 52 | train_loss: 0.8737 | train_acc: 0.6893 | test_loss: 0.8216 | test_acc: 0.7041
# Epoch: 53 | train_loss: 0.8439 | train_acc: 0.6970 | test_loss: 0.9026 | test_acc: 0.6650
# Epoch: 54 | train_loss: 0.8475 | train_acc: 0.7026 | test_loss: 0.8769 | test_acc: 0.6693
# Epoch: 55 | train_loss: 0.8101 | train_acc: 0.7129 | test_loss: 0.8451 | test_acc: 0.6811
# Epoch: 56 | train_loss: 0.8003 | train_acc: 0.7138 | test_loss: 0.9149 | test_acc: 0.6630
# Epoch: 57 | train_loss: 0.7984 | train_acc: 0.7207 | test_loss: 0.8478 | test_acc: 0.6957
# Epoch: 58 | train_loss: 0.8042 | train_acc: 0.7231 | test_loss: 0.8306 | test_acc: 0.6979
# Epoch: 59 | train_loss: 0.7749 | train_acc: 0.7281 | test_loss: 0.8645 | test_acc: 0.6681
# Epoch: 60 | train_loss: 0.7751 | train_acc: 0.7256 | test_loss: 0.8326 | test_acc: 0.6963
# Epoch: 61 | train_loss: 0.7400 | train_acc: 0.7394 | test_loss: 0.8028 | test_acc: 0.6948
# Epoch: 62 | train_loss: 0.7372 | train_acc: 0.7372 | test_loss: 0.8664 | test_acc: 0.6736
# Epoch: 63 | train_loss: 0.7232 | train_acc: 0.7447 | test_loss: 0.8569 | test_acc: 0.6932
# Epoch: 64 | train_loss: 0.7322 | train_acc: 0.7385 | test_loss: 0.8534 | test_acc: 0.7003
# Epoch: 65 | train_loss: 0.7308 | train_acc: 0.7389 | test_loss: 0.8946 | test_acc: 0.6698
# Epoch: 66 | train_loss: 0.7026 | train_acc: 0.7443 | test_loss: 0.7734 | test_acc: 0.7176
# Epoch: 67 | train_loss: 0.6929 | train_acc: 0.7513 | test_loss: 0.8267 | test_acc: 0.6950
# Epoch: 68 | train_loss: 0.6855 | train_acc: 0.7547 | test_loss: 0.8310 | test_acc: 0.7042
# Epoch: 69 | train_loss: 0.6769 | train_acc: 0.7616 | test_loss: 0.7690 | test_acc: 0.7372
# Epoch: 70 | train_loss: 0.6459 | train_acc: 0.7749 | test_loss: 0.7975 | test_acc: 0.7270
# Epoch: 71 | train_loss: 0.6318 | train_acc: 0.7754 | test_loss: 0.7762 | test_acc: 0.7288
# Epoch: 72 | train_loss: 0.6425 | train_acc: 0.7771 | test_loss: 0.7517 | test_acc: 0.7364
# Epoch: 73 | train_loss: 0.6496 | train_acc: 0.7708 | test_loss: 0.7823 | test_acc: 0.7155
# Epoch: 74 | train_loss: 0.6360 | train_acc: 0.7743 | test_loss: 0.7326 | test_acc: 0.7361
# Epoch: 75 | train_loss: 0.5903 | train_acc: 0.7911 | test_loss: 0.7461 | test_acc: 0.7370
# Epoch: 76 | train_loss: 0.6261 | train_acc: 0.7756 | test_loss: 0.7651 | test_acc: 0.7280
# Epoch: 77 | train_loss: 0.5742 | train_acc: 0.8009 | test_loss: 0.7788 | test_acc: 0.7276
# Epoch: 78 | train_loss: 0.6133 | train_acc: 0.7851 | test_loss: 0.7965 | test_acc: 0.7031
# Epoch: 79 | train_loss: 0.5770 | train_acc: 0.8002 | test_loss: 0.8072 | test_acc: 0.7163
# Epoch: 80 | train_loss: 0.5515 | train_acc: 0.8037 | test_loss: 0.8228 | test_acc: 0.7235
# Epoch: 81 | train_loss: 0.5572 | train_acc: 0.8034 | test_loss: 0.7701 | test_acc: 0.7333
# Epoch: 82 | train_loss: 0.5585 | train_acc: 0.8044 | test_loss: 0.7638 | test_acc: 0.7415
# Epoch: 83 | train_loss: 0.5742 | train_acc: 0.7940 | test_loss: 0.7981 | test_acc: 0.7303
# Epoch: 84 | train_loss: 0.5343 | train_acc: 0.8127 | test_loss: 0.7842 | test_acc: 0.7471
# Epoch: 85 | train_loss: 0.5330 | train_acc: 0.8070 | test_loss: 0.7341 | test_acc: 0.7584
# Epoch: 86 | train_loss: 0.5367 | train_acc: 0.8100 | test_loss: 0.7551 | test_acc: 0.7549
# Epoch: 87 | train_loss: 0.5064 | train_acc: 0.8158 | test_loss: 0.7880 | test_acc: 0.7350
# Epoch: 88 | train_loss: 0.5230 | train_acc: 0.8118 | test_loss: 0.7909 | test_acc: 0.7383
# Epoch: 89 | train_loss: 0.4600 | train_acc: 0.8393 | test_loss: 0.8600 | test_acc: 0.7309
# Epoch: 90 | train_loss: 0.4832 | train_acc: 0.8354 | test_loss: 0.7542 | test_acc: 0.7415
# Epoch: 91 | train_loss: 0.4612 | train_acc: 0.8361 | test_loss: 0.7060 | test_acc: 0.7610
# Epoch: 92 | train_loss: 0.4916 | train_acc: 0.8280 | test_loss: 0.7871 | test_acc: 0.7450
# Epoch: 93 | train_loss: 0.4701 | train_acc: 0.8376 | test_loss: 0.7340 | test_acc: 0.7610
# Epoch: 94 | train_loss: 0.4391 | train_acc: 0.8421 | test_loss: 0.6990 | test_acc: 0.7603
# Epoch: 95 | train_loss: 0.4491 | train_acc: 0.8399 | test_loss: 0.7651 | test_acc: 0.7436
# Epoch: 96 | train_loss: 0.4646 | train_acc: 0.8394 | test_loss: 0.8151 | test_acc: 0.7388
# Epoch: 97 | train_loss: 0.4624 | train_acc: 0.8383 | test_loss: 0.7994 | test_acc: 0.7370
# Epoch: 98 | train_loss: 0.4513 | train_acc: 0.8419 | test_loss: 0.7369 | test_acc: 0.7556
# Epoch: 99 | train_loss: 0.4303 | train_acc: 0.8496 | test_loss: 0.8780 | test_acc: 0.7247
# Epoch: 100 | train_loss: 0.4252 | train_acc: 0.8556 | test_loss: 0.7568 | test_acc: 0.7422
# Epoch: 101 | train_loss: 0.4082 | train_acc: 0.8624 | test_loss: 0.8406 | test_acc: 0.7299
# Epoch: 102 | train_loss: 0.4239 | train_acc: 0.8487 | test_loss: 0.7819 | test_acc: 0.7510
# Epoch: 103 | train_loss: 0.4328 | train_acc: 0.8479 | test_loss: 0.7475 | test_acc: 0.7538
# Epoch: 104 | train_loss: 0.3849 | train_acc: 0.8664 | test_loss: 0.7947 | test_acc: 0.7489
# Epoch: 105 | train_loss: 0.3874 | train_acc: 0.8667 | test_loss: 0.7410 | test_acc: 0.7635
# Epoch: 106 | train_loss: 0.4140 | train_acc: 0.8502 | test_loss: 0.7247 | test_acc: 0.7687
# Epoch: 107 | train_loss: 0.4116 | train_acc: 0.8542 | test_loss: 0.6984 | test_acc: 0.7653
# Epoch: 108 | train_loss: 0.3902 | train_acc: 0.8670 | test_loss: 0.7787 | test_acc: 0.7450
# Epoch: 109 | train_loss: 0.3920 | train_acc: 0.8630 | test_loss: 0.7643 | test_acc: 0.7390
# Epoch: 110 | train_loss: 0.3894 | train_acc: 0.8605 | test_loss: 0.7668 | test_acc: 0.7504
# Total training time: 2660.566 seconds

# %%
plot_loss_curves(model_2_results, Save=True, filename="model_2_training")

# %% [markdown]
# ## 9. Evaluating our model on never seen data
#
# Finally, we are going to use the `test_dataloader` to evaluate our models.

# %%
# Evaluate the RNN on the test set
evaluation = test_step(model=model_2,
                       dataloader=test_dataloader,
                       loss_fn=loss_fn,
                       )
print(f"test loss = {evaluation[0]:.4f} | test acc = {evaluation[1]:.4f}")
# Out:
# test loss = 0.7888 | test acc = 0.7484

# %% [markdown]
# ## 10. Creating a `predict()` function, to make predictions on unseen data
#
# We are going to use our model to make predictions. First we use the test dataloader to extract the first sample. Then we create the predict function that among other arguments, we can enter the index of the sample we want to predict. We see that we have 2500 indexes available.
# The tensor that represents the sample has to be unsqueezed because the model expects a `batch_size` on dim=0. The model exports logits. Using `softmax()` we turn the logits into probabilities and with `argmax()` we take the index of the highest probability. This is actually the predicted index class. However, we can use `argmax()` right away without having the probabilites first. This is because logit values are respective to the probability values. This is actually the predicted index class. We also do that for time complexity reasons.
#
# Changing the `model` and `index` arguments on the `predict()` function can let us make further testing.

# %%
# Creating the predict() function
def predict(model: torch.nn.Module,
            X_test: torch.Tensor,
            y_test: torch.Tensor,
            index: int = 0,
            device: str = "cpu",
            classes: list = classes):

    X_sample = X_test[index].unsqueeze(0).to(device)  # (1, C, H, W)
    y_sample = y_test[index].item() if isinstance(y_test[index], torch.Tensor) else y_test[index]

    model.eval()
    with torch.inference_mode():
        logits = model(X_sample)
        predicted_index = torch.argmax(logits, dim=1).item()

    print(f"Target: {classes[y_sample]}, Predicted label: {classes[predicted_index]}")

# %%
# Printing the shape to see how many indexes we have
X_test.shape
# Out:
# torch.Size([2500, 1, 72, 72])

# %%
# Set random seed to define index.
np.random.seed(RANDOM_SEED) # remove this line to set a random index, for further testing
index = np.random.randint(len(X_test))
predict(model=model_2,
        X_test=X_test,
        y_test=y_test,
        index=200,
        device=device,
        classes=classes)
# Out:
# Target: jazz, Predicted label: jazz

# %% [markdown]
# ## 11. Making a confusion matrix for further evaluation
#
# For a good vizualization of our model's performance, we can use a confusion matrix. For that purpose we will use the `torchmetrics` and `mlxtend` library.
# First we will make predictions on a test set and save the results on a tensor. Then we can use this tensor along with `y_test` which is a tensor containing the correct values for the labels of the test set.

# %%
# Importing libraries
import mlxtend
print(f"mlxtend version: {mlxtend.__version__}")
assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher. use pip install -q torchmetrics -U mlxtend"
# Out:
# mlxtend version: 0.24.0

# %%
# Make predictions on test_set and get tensor with predictions
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_2.eval()
with torch.inference_mode():
  for X, y in tqdm(test_dataloader, desc="Making predictions"):
    # Send data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = model_2(X)
    # Turn predictions from logits -> prediction probabilities -> predictions labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1) # note: perform softmax on the "logits" dimension, not "batch" dimension (in this case we have a batch size of 32, so can perform on dim=1)
    # Put predictions on CPU for evaluation
    y_preds.append(y_pred.cpu())
# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Importing libraries
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(classes), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=y_test)

# %%
# Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=classes,
    figsize=(10, 7)
)

# Figure & axes background
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

# Axis labels styling
ax.set_xlabel("predicted label", color='black')
ax.set_ylabel("true label", color='black')

ax.tick_params(axis='x', colors='black', rotation=45)
ax.tick_params(axis='y', colors='black')

# Spines
for spine in ax.spines.values():
    spine.set_color('black')

# Cell text (numbers inside matrix)
# We take each tex
# Retrieve all text annotations added by plot_confusion_matrix
for text in ax.texts:
    text.set_color('white' if float(text.get_text()) > confmat_tensor.max() / 2 else 'black')

# Colorbar styling
if len(fig.axes) > 1:  # second axis = colorbar
    cbar_ax = fig.axes[1]
    cbar_ax.tick_params(color='black')
    plt.setp(cbar_ax.get_yticklabels(), color='black')

# Layout
plt.tight_layout()

# Save
plt.savefig(
    "ViT_confusion_matrix.png",
    dpi=144,
    bbox_inches='tight',
    facecolor=fig.get_facecolor()
)

plt.show()

# %% [markdown]
# We can see that our model performs relatively well. Most of the values are concentrated on the main diagonal, which is an encouraging outcome. One of the benefits of the confusion matrix, is that we can see what labels our model mismatches. We can see that the hardest genres for our model to classify were "country" and "rock". Our model had the best results in classifying "metal" samples. We also see that the "classical" genre which is quite unique compared to the others, is mainly mispatched with "jazz". Furthermore, one must bear in mind that the distinction of genres is based on audio features. As a result, one can expect mismatches genres that use similar instruments or music production.
